# %% [markdown]
# #Ajuste fino do conjunto de dados SQUAD 2 P(1,0%) pt-br usando BERT Transformers by HuggingFace e Lotes Inteligentes e Validação Cruzada para todos os Folds
#
# Realiza o ajuste fino do modelo BERT pré-treinado com os dados do Cohebert para discriminar documentos originais e modificados e avalia utilizando validação cruzada 10 fold.
#
# Classes:
# - 1 - Documento original
# - 0 - Documento modificado
#
# Características:
# - Realiza o ajuste fino utilizando documentos originais e modificados em pares.
# - O Treinamento do modelo utiliza o conjunto de dados com um treinamento para um fold com 90% dos dados.
# - A avaliação do modelo utiliza o conjunto de dados de teste para um fold com 10% dos dados.
# - Realiza o ajuste fino em 10 pares de folds de treino e teste.
# - Utiliza Lotes Inteligentes para otimizar o tempo de execução de treinamento.
#
# - A seção 2 - parametrização define os argumentos da execução.
#
# Utiliza o arquivo `COHEBERT_KFOLD_10_PX_KY.zip`, X é o número de documentos modificados e Y o valor de top K predições.
#
# ----------------------------
#
# **Link biblioteca Transformers:**
# https://github.com/huggingface/transformers
#
#
# **Artigo original BERT:**
# https://arxiv.org/pdf/1506.06724.pdf
#
# **Artigo padding dinâmico:**
# https://towardsdatascience.com/divide-hugging-face-transformers-training-time-by-2-or-more-21bf7129db9q-21bf7129db9e

# %% [markdown]
# # 1 Preparação do ambiente
# Preparação do ambiente para execução do notebook.

# %% [markdown]
# ## 1.1 Tempo inicial de processamento

# %%
import time
import datetime

# Marca o tempo de início do processamento
inicio_processamento = time.time()

# %%
print("  Tempo de início de processamento:  {:} (h:mm:ss)".format(inicio_processamento))
# Out:
#   Tempo de início de processamento:  1651535440.0010211 (h:mm:ss)

# %% [markdown]
# ## 1.2 Funções e classes auxiliares

# %% [markdown]
# Verifica se existe o diretório cohebert no diretório corrente.

# %%
# Import das bibliotecas.
import os # Biblioteca para manipular arquivos

# ============================  
def verificaDiretorioCoheBERT():
    """
      Verifica se existe o diretório cohebert no diretório corrente.    
    """
    
    # Verifica se o diretório existe
    if not os.path.exists(DIRETORIO_COHEBERT):  
        # Cria o diretório
        os.makedirs(DIRETORIO_COHEBERT)
        logging.info("Diretório Cohebert criado: {}".format(DIRETORIO_COHEBERT))
    
    return DIRETORIO_COHEBERT

# %% [markdown]
# Realiza o download e um arquivo

# %%
# Import das bibliotecas.
import requests # Biblioteca de download
from tqdm.notebook import tqdm as tqdm_notebook # Biblioteca para barra de progresso
import os # Biblioteca para manipular arquivos

def downloadArquivo(url_arquivo, nome_arquivo_destino):
    """    
      Realiza o download de um arquivo de uma url em salva em nome_arquivo_destino.
    
      Parâmetros:
        `url_arquivo` - URL do arquivo a ser feito download.      
        `nome_arquivo_destino` - Nome do arquivo a ser salvo.      
    """
    
    # Verifica se existe o diretório base
    DIRETORIO_COHEBERT = verificaDiretorioCoheBERT()
    
    # Realiza o download de um arquivo em uma url
    data = requests.get(url_arquivo, stream=True)
    
    # Verifica se o arquivo existe
    if data.status_code != 200:
        logging.info("Exceção ao tentar realizar download {}. Response {}.".format(url_arquivo, data.status_code))
        data.raise_for_status()
        return

    # Recupera o nome do arquivo a ser realizado o download    
    nome_arquivo = nome_arquivo_destino.split("/")[-1]  

    # Define o nome e caminho do arquivo temporário    
    nome_arquivo_temporario = DIRETORIO_COHEBERT + "/" + nome_arquivo + "_part"
    
    logging.info("Download do arquivo: {}.".format(nome_arquivo_destino))
    
    # Baixa o arquivo
    with open(nome_arquivo_temporario, "wb") as arquivo_binario:        
        tamanho_conteudo = data.headers.get("Content-Length")        
        total = int(tamanho_conteudo) if tamanho_conteudo is not None else None
        # Barra de progresso de download
        progresso_bar = tqdm_notebook(unit="B", total=total, unit_scale=True)                
        # Atualiza a barra de progresso
        for chunk in data.iter_content(chunk_size=1024):        
            if chunk:                
                progresso_bar.update(len(chunk))
                arquivo_binario.write(chunk)
    
    # Renomeia o arquivo temporário para o arquivo definitivo
    os.rename(nome_arquivo_temporario, nome_arquivo_destino)
    
    # Fecha a barra de progresso.
    progresso_bar.close()

# %% [markdown]
# Remove tags de um documento

# %%
def remove_tags(documento):
    """
      Remove tags de um documento
    """
    
    import re

    documento_limpo = re.compile("<.*?>")
    return re.sub(documento_limpo, "", documento)

# %% [markdown]
# Funções auxiliares de arquivos

# %%
def carregar(nome_arquivo, encoding="Windows-1252"):
    """
      Carrega um arquivo texto e retorna as linhas como um único parágrafo(texto).
    
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser carregado.  
    """

    # Abre o arquivo
    arquivo = open(nome_arquivo, "r", encoding= encoding)
    
    paragrafo = ""
    for linha in arquivo:
        linha = linha.splitlines()
        linha = " ".join(linha)
        # Remove as tags existentes no final das linhas
        linha = remove_tags(linha)
        if linha != "":
          paragrafo = paragrafo + linha.strip() + " "
    
    # Fecha o arquivo
    arquivo.close()

    # Remove os espaços em branco antes e depois do parágrafo
    return paragrafo.strip()

# %%
def carregarLista(nome_arquivo, encoding="Windows-1252"):
    """
      Carrega um arquivo texto e retorna as linhas como uma lista de sentenças(texto).
    
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser carregado.   
        `encoding` - Codificação dos caracteres do arquivo.
    """

    # Abre o arquivo
    arquivo = open(nome_arquivo, "r", encoding= encoding)
    
    sentencas = []
    for linha in arquivo:        
        linha = linha.splitlines()
        linha = " ".join(linha)
        linha = remove_tags(linha)
        if linha != "":
          sentencas.append(linha.strip())
    
    # Fecha o arquivo
    arquivo.close()

    return sentencas

# %%
def salvar(nome_arquivo,texto):                       
    """
      Salva um texto em arquivo.
     
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser salvo.
        `texto` - Texto a ser salvo.     
    """

    arquivo = open(nome_arquivo, "w")
    arquivo.write(str(texto))
    arquivo.close()

# %% [markdown]
# Função auxiliar para formatar o tempo como `hh: mm: ss`

# %%
import time
import datetime

def formataTempo(tempo):
    '''
    Pega a tempo em segundos e retorna uma string hh:mm:ss
    '''
    # Arredonda para o segundo mais próximo.
    tempo_arredondado = int(round((tempo)))
    
    # Formata como hh:mm:ss
    return str(datetime.timedelta(seconds=tempo_arredondado))

# %% [markdown]
# Calcula a média de uma lista tempo string no formato hh:mm:ss.

# %%
# Import das bibliotecas.
from cmath import rect, phase
from math import radians, degrees
  
def mediaAngulo(deg):
    return degrees(phase(sum(rect(1, radians(d)) for d in deg)/len(deg)))
 
def mediaTempo(tempos):
    '''
    Calcula a média de uma lista de tempo string no formato hh:mm:ss
    '''
    t = (tempo.split(':') for tempo in tempos)
    # Converte para segundos
    segundos = ((float(s) + int(m) * 60 + int(h) * 3600) for h, m, s in t)
    # Verifica se deu algum dia
    dia = 24 * 60 * 60
    # Converte para angulos
    paraAngulos = [s * 360. / dia for s in segundos]
    # Calcula a média dos angulos
    mediaComoAngulo = mediaAngulo(paraAngulos)
    media_segundos = mediaComoAngulo * dia / 360.
    if media_segundos < 0:
        media_segundos += dia
    # Recupera as horas e os minutos  
    h, m = divmod(media_segundos, 3600)
    # Recupera os minutos e os segundos
    m, s = divmod(m, 60)    
    return '{:02d}:{:02d}:{:02d}'.format(int(h), int(m), int(s))

# %% [markdown]
# Calcula a soma de uma lista de tempo string no formato hh:mm:ss

# %%
def somaTempo(tempos):
    '''
    Calcula a soma de uma lista de tempo string no formato hh:mm:ss
    '''
    t = (tempo.split(':') for tempo in tempos)
    # Converte para segundos
    segundos = ((float(s) + int(m) * 60 + int(h) * 3600) for h, m, s in t)
    # Soma os segundos
    soma_segundos = sum([s * 1. for s in segundos])
    # Recupera as horas e os minutos   
    h, m = divmod(soma_segundos, 3600)
    # Recupera os minutos e os segundos
    m, s = divmod(m, 60)    
    return '{:02d}:{:02d}:{:02d}'.format(int(h), int(m), int(s))

# %% [markdown]
# Em muitos dos meus loops for (de longa duração), imprimirei atualizações periódicas de progresso. Normalmente, eu escolho o intervalo de atualização manualmente, mas para este Notebook, defini uma função auxiliar para fazer essa escolha para mim :)

# %%
def obterIntervaloAtualizacao(total_iteracoes, numero_atualizacoes):
    '''
     Esta função tentará escolher um intervalo de atualização de progresso inteligente
     com base na magnitude das iterações totais.

     Parâmetros:
       `total_iteracoes` - O número de iterações no loop for.
       `numero_atualizacoes` - Quantas vezes queremos ver uma atualização sobre o
                               curso do loop for.
     '''
    
    # Divida o total de iterações pelo número desejado de atualizações. Provavelmente
    # este será um número feio.
    intervalo_exato = total_iteracoes / numero_atualizacoes

    # A função `arredondar` tem a capacidade de arredondar um número para, por exemplo, o
    # milésimo mais próximo: round (intervalo_exato, -3)
    #
    # Para determinar a magnitude para arredondar, encontre a magnitude do total,
    # e então vá uma magnitude abaixo disso.
    
    # Obtenha a ordem de magnitude do total.
    ordem_magnitude = len(str(total_iteracoes)) - 1
    
    # Nosso intervalo de atualização deve ser arredondado para uma ordem de magnitude menor.
    magnitude_arrendonda = ordem_magnitude - 1

    # Arredonde para baixo e lance para um int.
    intervalo_atualizacao = int(round(intervalo_exato, -magnitude_arrendonda))

    # Não permita que o intervalo seja zero!
    if intervalo_atualizacao == 0:
        intervalo_atualizacao = 1

    return intervalo_atualizacao

# %% [markdown]
# Classe(ModeloArgumentosMedida) de definição dos parâmetros do modelo para medida

# %%
# Import das bibliotecas.
from dataclasses import dataclass, field
from typing import Dict, Optional
from typing import List

@dataclass
class ModeloArgumentosMedida:
    max_seq_len: Optional[int] = field(
        default=None,
        metadata={"help": "max seq len"},
    )    
    pretrained_model_name_or_path: str = field(
        default="neuralmind/bert-base-portuguese-cased",
        metadata={"help": "nome do modelo pré-treinado do BERT."},
    )
    modelo_spacy: str = field(
        default="pt_core_news_lg",
        metadata={"help": "nome do modelo do spaCy."},
    )
    versao_modelo_spacy: str = field(
        default="-3.2.0",
        metadata={"help": "versão do nome do modelo no spaCy."},
    )
    sentenciar_documento: bool = field(
        default=True,
        metadata={"help": "Dividir o documento em sentenças(frases)."},
    )
    do_lower_case: bool = field(
        default=False,
        metadata={"help": "define se o texto do modelo deve ser todo em minúsculo."},
    )    
    output_attentions: bool = field(
        default=False,
        metadata={"help": "habilita se o modelo retorna os pesos de atenção."},
    )
    output_hidden_states: bool = field(
        default=False,
        metadata={"help": "habilita gerar as camadas ocultas do modelo."},
    )
    usar_mcl_ajustado : bool = field(
        default=False,
        metadata={"help": "habilita o carragamento de mcl ajustado."},
    )

# %% [markdown]
# Classe(ModeloArgumentosClassificacao) de definição dos parâmetros do modelo para classificação

# %%
# Import das bibliotecas.
from dataclasses import dataclass, field
from typing import Dict, Optional
from typing import List

@dataclass
class ModeloArgumentosClassificacao:
    '''
    Classe(ModeloArgumentosClassificacao) de definição dos parâmetros do modelo BERT para a classificação de coerência.
    '''
    max_seq_len: Optional[int] = field(
        default=None,
        metadata={"help": "max seq len"},
    )    
    pretrained_model_name_or_path: str = field(
        default="neuralmind/bert-base-portuguese-cased",
        metadata={"help": "nome do modelo pré-treinado do BERT."},
    )
    do_lower_case: bool = field(
        default=False,
        metadata={"help": "define se o texto do modelo deve ser todo em minúsculo."},
    )
    num_labels: int = field(
        default=2,
        metadata={"help": "número de rótulos a serem classificados."},
    )
    output_attentions: bool = field(
        default=False,
        metadata={"help": "habilita se o modelo retorna os pesos de atenção."},
    )
    output_hidden_states: bool = field(
        default=False,
        metadata={"help": "habilita gerar as camadas ocultas do modelo."},
    )
    optimizer: str = field(
        default="AdamW",
        metadata={"help": "otimizador do modelo."},
    )
    use_wandb : bool = field(
        default=True,
        metadata={"help": "habilita o uso do wandb."},
    )
    salvar_modelo_wandb : bool = field(
        default=True,
        metadata={"help": "habilita o salvamento do modelo no wandb."},
    )
    salvar_modelo : bool = field(
        default=False,
        metadata={"help": "habilita o salvamento do modelo."},
    )
    salvar_avaliacao : bool = field(
        default=True,
        metadata={"help": "habilita o salvamento do resultado da avaliação."},
    )     
    salvar_classificacao : bool = field(
        default=False,
        metadata={"help": "habilita o salvamento da classificação."},
    )
    usar_mcl_ajustado: bool = field(
        default=False,
        metadata={'help': 'habilita o carragamento de mcl ajustado.'},
    )
    top_k_predicao: int = field(
        default="100",
        metadata={"help": "Quantidade de previsões de palavras recuperadas mais próximas da máscara."},
    )
    documentos_perturbados: int = field(
        default="1",
        metadata={"help": "Quantidade de documentos perturbados comparados com o seu original."},
    ) 
    epoca: int = field(
        default="1",
        metadata={"help": "Época a ser avaliada."},
    )    
    fold: int = field(
        default="1",
        metadata={"help": "Fold a ser avaliado."},
    )

# %% [markdown]
# Biblioteca de limpeza de tela

# %%
from IPython.display import clear_output

# %% [markdown]
# ## 1.3 Tratamento de logs

# %%
# Import das bibliotecas.
import logging # Biblioteca de logging

# Formatando a mensagem de logging
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s")

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ## 1.4 Identificando o ambiente Colab

# %%
# Se estiver executando no Google Colaboratory
import sys

# Retorna true ou false se estiver no Google Colaboratory
IN_COLAB = 'google.colab' in sys.modules

# %% [markdown]
# ## 1.5 Colaboratory

# %% [markdown]
# Usando Colab GPU para Treinamento

# %% [markdown]
# Uma GPU pode ser adicionada acessando o menu e selecionando:
#
# `Edit -> Notebook Settings -> Hardware accelerator -> (GPU)`
#
# Em seguida, execute a célula a seguir para confirmar que a GPU foi detectada.

# %%
# Import das bibliotecas.
import tensorflow as tf

# Recupera o nome do dispositido da GPU.
device_name = tf.test.gpu_device_name()

# O nome do dispositivo deve ser parecido com o seguinte:
if device_name == "/device:GPU:0":
    logging.info("Encontrei GPU em: {}".format(device_name))
else:
    logging.info("Dispositivo GPU não encontrado")
    #raise SystemError("Dispositivo GPU não encontrado")
# Out:
# 2022-05-02 23:50:44,057 : INFO : NumExpr defaulting to 2 threads.
# 2022-05-02 23:50:48,063 : INFO : Encontrei GPU em: /device:GPU:0

# %% [markdown]
# Nome da GPU
#
# Para que a torch use a GPU, precisamos identificar e especificar a GPU como o dispositivo. Posteriormente, em nosso ciclo de treinamento, carregaremos dados no dispositivo.
#
# Vale a pena observar qual GPU você recebeu. A GPU Tesla P100 é muito mais rápido que as outras GPUs, abaixo uma lista ordenada:
# - 1o Tesla P100
# - 2o Tesla T4
# - 3o Tesla P4 (Não tem memória para execução 4 x 8, somente 2 x 4)
# - 4o Tesla K80 (Não tem memória para execução 4 x 8, somente 2 x 4)

# %%
# Import das bibliotecas.
import torch # Biblioteca para manipular os tensores

def getDeviceGPU():
    """
    Retorna um dispositivo de GPU se disponível ou CPU.
    
    Retorno:
    `device` - Um device de GPU ou CPU.       
    """
        
    # Se existe GPU disponível.
    if torch.cuda.is_available():
        
        # Diz ao PyTorch para usar GPU.    
        device = torch.device("cuda")
        
        logging.info("Existem {} GPU(s) disponíveis.".format(torch.cuda.device_count()))
        logging.info("Iremos usar a GPU: {}.".format(torch.cuda.get_device_name(0)))

    # Senão.
    else:        
        logging.info("Sem GPU disponível, usando CPU.")
        device = torch.device("cpu")
        
    return device

# %%
device = getDeviceGPU()
# Out:
# 2022-05-02 23:50:51,089 : INFO : Existem 1 GPU(s) disponíveis.
# 2022-05-02 23:51:00,105 : INFO : Iremos usar a GPU: Tesla P100-PCIE-16GB.

# %% [markdown]
# Conecta o modelo ao device

# %%
# Import das bibliotecas.
import torch # Biblioteca para manipular os tensores

def conectaGPU(model, device):
    """
      Conecta um modelo BERT a GPU.

      Parâmetros:
        `model` - Um modelo BERT carregado.       
        `device` - Um device de GPU.     
    
      Retorno:
        `model` - Um objeto model BERT conectado a GPU.     
    """
    # Associa a GPU ao modelo.
    model.to(device)

    # Se existe GPU disponível.
    if torch.cuda.is_available():    
        # Diga ao pytorch para rodar este modelo na GPU.
        logging.info("Pytorch rodando o modelo na GPU.")
        model.cuda()
        
    else:
        logging.info("Pytorch rodando sem GPU.")

    return model

# %% [markdown]
# Memória
#
# Memória disponível no ambiente

# %%
# Import das bibliotecas.
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
logging.info("Seu ambiente de execução tem {: .1f} gigabytes de RAM disponível\n".format(ram_gb))

if ram_gb < 20:
  logging.info("Para habilitar um tempo de execução de RAM alta, selecione menu o ambiente de execução> \"Alterar tipo de tempo de execução\"")
  logging.info("e selecione High-RAM. Então, execute novamente está célula")
else:
  logging.info("Você está usando um ambiente de execução de memória RAM alta!")
# Out:
# 2022-05-02 23:51:00,139 : INFO : Seu ambiente de execução tem  13.6 gigabytes de RAM disponível
#
# 2022-05-02 23:51:00,145 : INFO : Para habilitar um tempo de execução de RAM alta, selecione menu o ambiente de execução> "Alterar tipo de tempo de execução"
# 2022-05-02 23:51:00,145 : INFO : e selecione High-RAM. Então, execute novamente está célula

# %% [markdown]
# ## 1.6 Monta uma pasta no google drive para carregar os arquivos de dados.

# %%
# Monta o Google Drive para esta instância de notebook.
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.7 Instalação do wandb

# %% [markdown]
# Instalação

# %%
# !pip install --upgrade wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.12.15-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 4.3 MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.10-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 73.2 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 74.3 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.4 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=448f9366adae73cdacc5166dda293211f0454852169312e357ee437aad8fdc4d
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.10 setproctitle-1.2.3 shortuuid-1.0.8 smmap-5.0.0 wandb-0.12.15

# %% [markdown]
# Login via linha de comando

# %%
# !wandb login aded3bc0ea651fff536cc08ba69caf8ac4141cfd
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## 1.8 Instalação BERT da Hugging Face

# %% [markdown]
# Instala a interface pytorch para o BERT by Hugging Face.

# %%
# !pip install -U transformers==4.5.1
# Out:
# Collecting transformers==4.5.1
#   Downloading transformers-4.5.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 3.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (3.6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.51.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 52.9 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 54.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (4.11.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.5.1) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.5.1) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.5.1) (3.0.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1) (1.15.0)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1) (1.1.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.51-py3-none-any.whl size=895170 sha256=238efcc9e921f3838caf3fab8502bf5456421cb8163b19ea56be96561bf9515b
#   Stored in directory: /root/.cache/pip/wheels/a0/95/bf/f9b021d14dbea2160ac68cbdf606e42e01119e0ba7206a6157
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.51 tokenizers-0.10.3 transformers-4.5.1

# %% [markdown]
# # 2 Parametrização

# %% [markdown]
# ## Gerais

# %%
# Nome base das saidas do projeto C = Cris, SB = SmartBatch, KF = KFold
NOME_BASE_SAIDA = "AjusteFinoSquad2_P_C_SB_KF_v1"

# Definição dos parâmetros a serem avaliados

######## Parâmetros Individuais ########

# Quantidade de documentos a serem perturbados a partir do original. Usar 1, 20 ou 100.  
DOCUMENTOS_PERTURBADOS = 100

# Quantidade de palavras a serem recuperadas mais próximas da máscara. 
TOP_K_PREDICAO = 100 # Conjunto de valores: 1, 20 ou 100.

# Tamanho dos lotes de treino e avaliação. Usar 16 ou 32
TAMANHO_LOTE = 16

######## Parâmetros de conjunto ########
# Taxas de aprendizagem a serem avaliadas
#TAXAS_DE_APRENDIZAGEM = [1e-5, 2e-5, 3e-5, 4e-5, 5e-5]
TAXAS_DE_APRENDIZAGEM = [1e-5, 2e-5, 3e-5, 4e-5, 5e-5]

# MCLs a serem avaliados
#NOMES_MODELO = ['https://neuralmind-ai.s3.us-east-2.amazonaws.com/nlp/bert-base-portuguese-cased/bert-base-portuguese-cased_pytorch_checkpoint.zip',
#                'https://neuralmind-ai.s3.us-east-2.amazonaws.com/nlp/bert-large-portuguese-cased/bert-large-portuguese-cased_pytorch_checkpoint.zip',
#                'bert-base-multilingual-cased']
NOMES_MODELO = ['neuralmind/bert-large-portuguese-cased']

######## Parâmetros de intervalo ########
# Número de épocas a serem avaliadas
# Todas as épocas são avaliadas e os resultados da classificação são salvos de 0 até 4.
# A época 0 avalia o modelo sem realizar ajuste fino.
EPOCAS = 4

# Determina o intervalo de folds a ser avaliado. De 1 até 10
inicioFold = 1
fimFold = 10

# %% [markdown]
# ## Específicos

# %% [markdown]
# Parâmetros do treinamento

# %%
# Importando as bibliotecas.
from transformers import TrainingArguments

# Definição dos parâmetros de Treinamento
training_args = TrainingArguments(    
    # NOME_BASE_SAIDA = Nome base do arquivo de saída
    # P = documentos perturbados
    # K = previsões palavras 
    # E = número total de épocas de treinamento
    # e = número da época executada
    # lr = taxa de aprendizagem
    # b = lotes de treino e avaliação    
    # f = número do fold
    output_dir = NOME_BASE_SAIDA + "K_1_P_1_E_4_e_1_lr_5_b_8_4_f", # É utilizado somente para logs de arquivo e wandb   
    save_steps = 0,    
    seed = 42,
    num_train_epochs = EPOCAS, # Intervalo de valores: 2, 3, 4. É utilizado somente para logs.
    learning_rate = 5e-5, # Intervalo de valores: 1e-5, 2e-5, 3e-5, 4e-5, 5e-5. É utilizado somente para logs.
    gradient_accumulation_steps = 1,
    per_device_train_batch_size = TAMANHO_LOTE, 
    per_device_eval_batch_size = TAMANHO_LOTE,        
    evaluation_strategy = 'epoch',    
)

# %% [markdown]
# Parâmetros do modelo

# %%
# Definição dos parâmetros do Modelo.
model_args = ModeloArgumentosClassificacao(     
    max_seq_len = 512,
    pretrained_model_name_or_path = "https://neuralmind-ai.s3.us-east-2.amazonaws.com/nlp/bert-large-portuguese-cased/bert-large-portuguese-cased_pytorch_checkpoint.zip",
    #pretrained_model_name_or_path = "https://neuralmind-ai.s3.us-east-2.amazonaws.com/nlp/bert-base-portuguese-cased/bert-base-portuguese-cased_pytorch_checkpoint.zip",
    #pretrained_model_name_or_path = "neuralmind/bert-large-portuguese-cased",
    #pretrained_model_name_or_path = "neuralmind/bert-base-portuguese-cased",    
    #pretrained_model_name_or_path = "bert-base-multilingual-cased",
    #pretrained_model_name_or_path = "bert-base-multilingual-uncased",   
    do_lower_case = False, # default True
    num_labels = 2,
    output_attentions = False, # default False
    output_hidden_states = False, # default False 
    optimizer = 'AdamW',
    use_wandb = True, # Ativa a gravação de logs no wandb
    salvar_modelo_wandb = False, # Ativa o salvamento do MCL no wandb
    salvar_modelo = False, # Ativa o salvamento do MCL no googledrive
    salvar_avaliacao = True, # Salva o resultado classificações
    salvar_classificacao = True, # Salva o resultado da avaliação das classificações
    usar_mcl_ajustado = False, # Especifica se deve ser carregado um MCL ajustado ou pré-treinado. Necessário especificar o tipo do modelo em pretrained_model_name_or_path. 
    documentos_perturbados = DOCUMENTOS_PERTURBADOS, # Quantidade de documentos a serem perturbados a partir do original.    
    top_k_predicao = TOP_K_PREDICAO, # Conjunto de valores: 1, 10, 100, 500 e 1000. Quantidade de palavras a serem recuperadas mais próximas da máscara. 
    fold = 10 # Intervalo de valores: 1 a 10, É utilizado somente para logs. Use as variáveis do bloco a seguir para definir um intervalo dos folds
)

# %% [markdown]
# ## Define o caminho para os arquivos de dados

# %%
# Diretório do cohebert
DIRETORIO_COHEBERT = "SQUAD2_P"

# %% [markdown]
# ## Define o caminho para os arquivos de dados

# %%
# Diretório local para os arquivos pré-processados
DIRETORIO_LOCAL = "/content/" + DIRETORIO_COHEBERT + "/"

# Diretório no google drive com os arquivos pré-processados
DIRETORIO_DRIVE = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/"

# %% [markdown]
# ## Inicialização diretórios

# %% [markdown]
# Diretório base local

# %%
# Importando as bibliotecas.
import os

def criaDiretorioLocal():

  # Cria o diretório para receber os arquivos Originais e Permutados
  # Diretório a ser criado
  dirbase = DIRETORIO_LOCAL[:-1]

  if not os.path.exists(dirbase):  
      # Cria o diretório
      os.makedirs(dirbase)    
      logging.info("Diretório criado: {}.".format(dirbase))
  else:    
      logging.info("Diretório já existe: {}.".format(dirbase))

# %%
criaDiretorioLocal()
# Out:
# 2022-05-02 23:51:35,069 : INFO : Diretório criado: /content/SQUAD2_P.

# %% [markdown]
# Diretório para conter as os resultados das classificações

# %%
# Import de bibliotecas.
import os

def criaDiretorioClassificacao():
  DIRETORIO_BASE = DIRETORIO_DRIVE + "/validacao_classificacao_palavra"

  # Verifica se o diretório existe
  if not os.path.exists(DIRETORIO_BASE):  
    # Cria o diretório
    os.makedirs(DIRETORIO_BASE)
    logging.info("Diretório criado: {}.".format(DIRETORIO_BASE))
  else:
    logging.info("Diretório já existe: {}.".format(DIRETORIO_BASE))

# %%
criaDiretorioClassificacao()
# Out:
# 2022-05-02 23:51:35,968 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P//validacao_classificacao_palavra.

# %% [markdown]
# Diretório para conter os arquivos da avaliação kfold

# %%
# Import de bibliotecas.
import os

def criaDiretorioClassificacaoKfold():
  DIRETORIO_BASE = DIRETORIO_DRIVE + "validacao_classificacao_palavra/kfold"

  # Verifica se o diretório existe
  if not os.path.exists(DIRETORIO_BASE):  
    # Cria o diretório
    os.makedirs(DIRETORIO_BASE)
    logging.info("Diretório criado: {}.".format(DIRETORIO_BASE))
  else:
    logging.info("Diretório já existe: {}.".format(DIRETORIO_BASE))

# %%
criaDiretorioClassificacaoKfold()
# Out:
# 2022-05-02 23:51:36,392 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold.

# %% [markdown]
# Diretório para conter os arquivos de classificação da avaliação kfold

# %%
# Import de bibliotecas.
import os

def criaDiretorioClassificacaoKfoldClassificacao():

  DIRETORIO_BASE = DIRETORIO_DRIVE + "validacao_classificacao_palavra/kfold/Classificacao"

  # Verifica se o diretório existe
  if not os.path.exists(DIRETORIO_BASE):  
    # Cria o diretório
    os.makedirs(DIRETORIO_BASE)
    logging.info("Diretório criado: {}.".format(DIRETORIO_BASE))
  else:
    logging.info("Diretório já existe: {}.".format(DIRETORIO_BASE))

# %%
criaDiretorioClassificacaoKfoldClassificacao()
# Out:
# 2022-05-02 23:51:36,739 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao.

# %% [markdown]
# Diretório para conter os arquivos de resultado da avaliação kfold

# %%
# Import de bibliotecas.
import os

def criaDiretorioClassificacaoKfoldAvaliacao():

  DIRETORIO_BASE = DIRETORIO_DRIVE + "validacao_classificacao_palavra/kfold/Avaliacao"

  # Verifica se o diretório existe
  if not os.path.exists(DIRETORIO_BASE):  
    # Cria o diretório
    os.makedirs(DIRETORIO_BASE)
    logging.info("Diretório criado: {}.".format(DIRETORIO_BASE))
  else:
    logging.info("Diretório já existe: {}.".format(DIRETORIO_BASE))

# %%
criaDiretorioClassificacaoKfoldAvaliacao()
# Out:
# 2022-05-02 23:51:36,764 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao.

# %% [markdown]
# # 3 BERT

# %% [markdown]
# ## 3.1 Modelo Pré-treinado BERT

# %% [markdown]
# ### Funções Auxiliares

# %%
def getNomeModeloBERT(model_args):
    '''    
    Recupera uma string com uma descrição do modelo BERT para nomes de arquivos e diretórios.
    
    Parâmetros:
    `model_args` - Objeto com os argumentos do modelo.       
    
    Retorno:
    `MODELO_BERT` - Nome do modelo BERT.
    '''

    # Verifica o nome do modelo(default SEM_MODELO_BERT)
    MODELO_BERT = "SEM_MODELO_BERT"
    
    if 'neuralmind' in model_args.pretrained_model_name_or_path:
        MODELO_BERT = "_BERTimbau"        
    else:
        if 'multilingual' in model_args.pretrained_model_name_or_path:
            MODELO_BERT = "_BERTmultilingual"
        else:
            if 'bert' in model_args.pretrained_model_name_or_path:
                MODELO_BERT = "_BERT"  
            
    return MODELO_BERT

# %%
def getTamanhoBERT(model_args):
    '''    
    Recupera uma string com o tamanho(dimensão) do modelo BERT para nomes de arquivos e diretórios.
    
    Parâmetros:
    `model_args` - Objeto com os argumentos do modelo.       
    
    Retorno:
    `TAMANHO_BERT` - Nome do tamanho do modelo BERT.
    '''
    
    # Verifica o tamanho do modelo(default large)
    TAMANHO_BERT = "_large"
    
    if 'base' in model_args.pretrained_model_name_or_path:
        TAMANHO_BERT = "_base"
        
    return TAMANHO_BERT

# %% [markdown]
# ### Função download Modelo Pre-treinado BERT

# %%
# Import das bibliotecas.
import zipfile # Biblioteca para descompactar
import shutil # iblioteca de manipulação arquivos de alto nível

def downloadModeloPretreinado(model_args):
    """
      Realiza o download do modelo BERT(MODELO) e retorna o diretório onde o modelo BERT(MODELO) foi descompactado.
    
      Parâmetros:
        `model_args` - Objeto com os argumentos do modelo.
    
      Retorno:
        `DIRETORIO_MODELO` - Diretório de download do modelo.
    """ 
    
    # Nome diretório base modelo BERT
    NOME_DIRETORIO_BASE_MODELO = "modeloBERT"
    
    # Verifica se existe o diretório base do cohebert e retorna o nome do diretório
    DIRETORIO_COHEBERT = verificaDiretorioCoheBERT()
    
    # Recupera o nome ou caminho do modelo
    MODELO = model_args.pretrained_model_name_or_path

    # Variável para setar o arquivo.
    URL_MODELO = None

    if "http" in MODELO:
        URL_MODELO = MODELO

    # Se a variável foi setada.
    if URL_MODELO:

        # Diretório do modelo.
        DIRETORIO_MODELO = DIRETORIO_COHEBERT + "/" + NOME_DIRETORIO_BASE_MODELO
        
        # Recupera o nome do arquivo do modelo da url.
        NOME_ARQUIVO = URL_MODELO.split("/")[-1]

        # Nome do arquivo do vocabulário.
        ARQUIVO_VOCAB = "vocab.txt"
        
        # Caminho do arquivo na url.
        CAMINHO_ARQUIVO = URL_MODELO[0:len(URL_MODELO)-len(NOME_ARQUIVO)]

        # Verifica se o diretório de descompactação existe no diretório corrente
        if os.path.exists(DIRETORIO_MODELO):
            logging.info("Apagando diretório existente do modelo.")
            # Apaga o diretório e os arquivos existentes                     
            shutil.rmtree(DIRETORIO_MODELO)
        
        # Realiza o download do arquivo do modelo        
        downloadArquivo(URL_MODELO, NOME_ARQUIVO)

        # Descompacta o arquivo no diretório de descompactação.                
        arquivo_zip = zipfile.ZipFile(NOME_ARQUIVO, "r")
        arquivo_zip.extractall(DIRETORIO_MODELO)

        # Baixa o arquivo do vocabulário.
        # O vocabulário não está no arquivo compactado acima, mesma url mas arquivo diferente.
        URL_MODELO_VOCAB = CAMINHO_ARQUIVO + ARQUIVO_VOCAB
        # Coloca o arquivo do vocabulário no diretório do modelo.        
        downloadArquivo(URL_MODELO_VOCAB, DIRETORIO_MODELO + "/" + ARQUIVO_VOCAB)
        
        # Apaga o arquivo compactado
        os.remove(NOME_ARQUIVO)

        del arquivo_zip

        logging.info("Diretório {} do modelo BERT pronta.".format(DIRETORIO_MODELO))

    else:
        DIRETORIO_MODELO = MODELO
        logging.info("Variável URL_MODELO não setada.")

    return DIRETORIO_MODELO

# %% [markdown]
# ### Copia o modelo do BERT ajustado

# %%
# Import das bibliotecas.
import shutil # iblioteca de manipulação arquivos de alto nível

def copiaModeloAjustado(model_args):
    """ 
      Copia o modelo ajustado BERT do GoogleDrive para o projeto.
    
      Parâmetros:
        `model_args` - Objeto com os argumentos do modelo.
    
      Retorno:
        `DIRETORIO_LOCAL_MODELO_AJUSTADO` - Diretório de download ajustado do modelo.
    """

    # Verifica o nome do modelo BERT a ser utilizado
    MODELO_BERT = getNomeModeloBERT(model_args)

    # Verifica o tamanho do modelo(default large)
    TAMANHO_BERT = getTamanhoBERT(model_args)

    # Verifica se existe o diretório base do cohebert e retorna o nome do diretório
    DIRETORIO_COHEBERT = verificaDiretorioCoheBERT()

    # Diretório local de salvamento do modelo.
    DIRETORIO_LOCAL_MODELO_AJUSTADO = DIRETORIO_COHEBERT + "/modelo_ajustado/"

    # Diretório remoto de salvamento do modelo no google drive.
    DIRETORIO_REMOTO_MODELO_AJUSTADO = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_classificacao_palavra/holdout/modelo/" + MODELO_BERT + TAMANHO_BERT

    # Copia o arquivo do modelo para o diretório no Google Drive.
    shutil.copytree(DIRETORIO_REMOTO_MODELO_AJUSTADO, DIRETORIO_LOCAL_MODELO_AJUSTADO) 
   
    logging.info("Modelo BERT ajustado copiado!")

    return DIRETORIO_LOCAL_MODELO_AJUSTADO

# %% [markdown]
# ### Verifica de onde utilizar o modelo do BERT

# %%
def verificaModelo(model_args):
    """ 
    Verifica de onde utilizar o modelo.
    
    Parâmetros:
    `model_args` - Objeto com os argumentos do modelo.
    
    Retorno:
    `DIRETORIO_MODELO` - Diretório de download do modelo.
    """ 

    DIRETORIO_MODELO = None
    
    if model_args.usar_mcl_ajustado == True:        
        # Diretório do modelo
        DIRETORIO_MODELO = copiaModeloAjustado()
        
        logging.info("Usando modelo BERT ajustado.")
        
    else:
        DIRETORIO_MODELO = downloadModeloPretreinado(model_args)
        logging.info("Usando modelo BERT pré-treinado.")        
        
    return DIRETORIO_MODELO

# %% [markdown]
# ## 3.2 Tokenizador BERT

# %% [markdown]
# ### Função carrega Tokenizador BERT
#
# O tokenizador utiliza WordPiece, veja em [artigo original](https://arxiv.org/pdf/1609.08144.pdf).

# %%
# Import das bibliotecas.
from transformers import BertTokenizer # Importando as bibliotecas do tokenizador BERT.

def carregaTokenizadorModeloPretreinado(DIRETORIO_MODELO, model_args):
    """
      Carrega o tokenizador do DIRETORIO_MODELO.
      O tokenizador utiliza WordPiece.
      Carregando o tokenizador do diretório "./modelo/" do diretório padrão se variável `DIRETORIO_MODELO` setada.
      Caso contrário carrega da comunidade
      Por default(`do_lower_case=True`) todas as letras são colocadas para minúsculas. Para ignorar a conversão para minúsculo use o parâmetro `do_lower_case=False`. Esta opção também considera as letras acentuadas(ãçéí...), que são necessárias a língua portuguesa.
      O parâmetro `do_lower_case` interfere na quantidade tokens a ser gerado a partir de um texto. Quando igual a `False` reduz a quantidade de tokens gerados.
    
      Parâmetros:
        `DIRETORIO_MODELO` - Diretório a ser utilizado pelo modelo BERT.           
        `model_args` - Objeto com os argumentos do modelo.       
    
      Retorno:
        `tokenizer` - Tokenizador BERT.
    """

    tokenizer = None
    
    # Se a variável DIRETORIO_MODELO foi setada.
    if DIRETORIO_MODELO:
        # Carregando o Tokenizador.
        logging.info("Carregando o tokenizador BERT do diretório {}.".format(DIRETORIO_MODELO))

        tokenizer = BertTokenizer.from_pretrained(DIRETORIO_MODELO, do_lower_case=model_args.do_lower_case)

    else:
        # Carregando o Tokenizador da comunidade.
        logging.info("Carregando o tokenizador BERT da comunidade.")

        tokenizer = BertTokenizer.from_pretrained(model_args.pretrained_model_name_or_path, do_lower_case=model_args.do_lower_case)

    return tokenizer

# %% [markdown]
# ## 3.3 Carrega o modelo e tokenizador BERT
#
# Lista de modelos da comunidade:
# * https://huggingface.co/models
#
# Português(https://github.com/neuralmind-ai/portuguese-bert):
# * **"neuralmind/bert-base-portuguese-cased"**
# * **"neuralmind/bert-large-portuguese-cased"**
#
# A implementação do huggingface pytorch inclui um conjunto de interfaces projetadas para uma variedade de tarefas de PNL. Embora essas interfaces sejam todas construídas sobre um modelo treinado de BERT, cada uma possui diferentes camadas superiores e tipos de saída projetados para acomodar suas tarefas específicas de PNL.

# %% [markdown]
# ### Função carrega modelo BERT medida

# %%
# Import das bibliotecas.
from transformers import BertModel # Importando as bibliotecas do Modelo BERT.

def carregaModeloMedida(DIRETORIO_MODELO, model_args):
    """
      Carrega o modelo e retorna o modelo.
    
      Parâmetros:
        `DIRETORIO_MODELO` - Diretório a ser utilizado pelo modelo BERT.           
        `model_args` - Objeto com os argumentos do modelo.   
    
      Retorno:
        `model` - Um objeto do modelo BERT carregado.
    """

    # Variável para setar o arquivo.
    URL_MODELO = None

    if "http" in model_args.pretrained_model_name_or_path:
        URL_MODELO = model_args.pretrained_model_name_or_path

    # Se a variável URL_MODELO foi setada
    if URL_MODELO:        
        # Carregando o Modelo BERT
        logging.info("Carregando o modelo BERT do diretório {} para cálculo de medidas.".format(DIRETORIO_MODELO))

        model = BertModel.from_pretrained(DIRETORIO_MODELO,
                                          output_attentions=model_args.output_attentions,
                                          output_hidden_states=model_args.output_hidden_states)
        
    else:
        # Carregando o Modelo BERT da comunidade
        logging.info("Carregando o modelo BERT da comunidade {} para cálculo de medidas.".format(model_args.pretrained_model_name_or_path))

        model = BertModel.from_pretrained(model_args.pretrained_model_name_or_path,
                                          output_attentions=model_args.output_attentions,
                                          output_hidden_states=model_args.output_hidden_states)

    return model

# %% [markdown]
# ### Função carrega modelo BERT classificação

# %%
# Import das bibliotecas.
from transformers import BertForSequenceClassification # Importando as bibliotecas do Modelo BERT.

def carregaModeloClassifica(DIRETORIO_MODELO, model_args):
    ''' 
    Carrega o modelo e retorna o modelo.
    
    Parâmetros:
    `DIRETORIO_MODELO` - Diretório a ser utilizado pelo modelo BERT.           
    `model_args` - Objeto com os argumentos do modelo.
    
    Retorno:
    `model` - Um objeto do modelo BERT carregado.
    ''' 

    # Variável para setar o arquivo.
    URL_MODELO = None

    if 'http' in model_args.pretrained_model_name_or_path:
        URL_MODELO = model_args.pretrained_model_name_or_path

    # Se a variável URL_MODELO foi setada
    if URL_MODELO:
        # Carregando o Modelo BERT
        logging.info("Carregando o modelo BERT do diretório {} para classificação.".format(DIRETORIO_MODELO))

        model = BertForSequenceClassification.from_pretrained(DIRETORIO_MODELO, 
                                                              num_labels=model_args.num_labels,
                                                              output_attentions=model_args.output_attentions,
                                                              output_hidden_states=model_args.output_hidden_states)
            
    else:
        # Carregando o Modelo BERT da comunidade
        logging.info("Carregando o modelo BERT da comunidade {} para classificação.".format(model_args.pretrained_model_name_or_path))

        model = BertForSequenceClassification.from_pretrained(model_args.pretrained_model_name_or_path,
                                                              num_labels=model_args.num_labels,
                                                              output_attentions=model_args.output_attentions,
                                                              output_hidden_states=model_args.output_hidden_states)
    return model

# %% [markdown]
# ### Função carrega o BERT

# %%
def carregaBERT(model_args):
    """ 
      Carrega o BERT para cálculo de medida ou classificação e retorna o modelo e o tokenizador.
      O tipo do model retornado pode ser BertModel ou BertForSequenceClassification, depende do tipo de model_args.
    
      Parâmetros:
        `model_args` - Objeto com os argumentos do modelo.       
          - Se model_args = ModeloArgumentosClassificacao deve ser carregado o BERT para classificação(BertForSequenceClassification).
          - Se model_args = ModeloArgumentosMedida deve ser carregado o BERT para cálculo de medida(BertModel).

      Retorno:    
        `model` - Um objeto do modelo BERT carregado.       
        `tokenizer` - Um objeto tokenizador BERT carregado.       
    """
            
    # Verifica a origem do modelo
    DIRETORIO_MODELO = verificaModelo(model_args)
    
    # Variável para conter o modelo
    model = None
    
    # Verifica o tipo do modelo em model_args    
    if type(model_args) == ModeloArgumentosMedida:
        # Carrega o modelo para cálculo da medida
        model = carregaModeloMedida(DIRETORIO_MODELO, model_args)
        
    else:
        # Carrega o modelo para classificação
        model = carregaModeloClassifica(DIRETORIO_MODELO, model_args)
        
        # Recupera o dispositivo da GPU 
        device = getDeviceGPU()
    
        # Conecta o modelo a GPU
        model = conectaGPU(model, device)
                       
    # Carrega o tokenizador. 
    # O tokenizador é o mesmo para o classificador e medidor.
    tokenizer = carregaTokenizadorModeloPretreinado(DIRETORIO_MODELO, model_args)
    
    return model, tokenizer

# %% [markdown]
# ### Recupera detalhes do BERT

# %%
# Verifica o nome do modelo BERT a ser utilizado
MODELO_BERT = getNomeModeloBERT(model_args)

# Verifica o tamanho do modelo(default large)
TAMANHO_BERT = getTamanhoBERT(model_args)

# %% [markdown]
# # 4 Treino

# %% [markdown]
# ## 4.1 Wandb
#
# https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/table?workspace=user-osmar-braz

# %% [markdown]
# ### Função de inicialização wandb

# %%
# Importando a biblioteca.
import wandb

def inicializacaoWandb():

  if model_args.use_wandb:

    #Login via linha de comando
    # !wandb login aded3bc0ea651fff536cc08ba69caf8ac4141cfd

    # Inicializando o registro do experimento.
    # Na execução só pode existir de um init  para que não gere dois registros no wandb.
    # O projeto no wandb recebe o nome base mais o número de um fold especifico.
    wandb.init(project=NOME_BASE_SAIDA, name=training_args.output_dir + str(model_args.fold))
    
    # Atualiza os parâmetros do modelo no wandb.
    wandb.config.update(model_args)
    # Atualiza os parâmetros de treinamento no wandb.
    wandb.config.update(training_args)
    wandb.config.dataset = DIRETORIO_COHEBERT
    wandb.config.batch_size = training_args.per_device_train_batch_size
    
    # Registra os parämetros não literais do model_args.    
    wandb.log({"max_seq_len": model_args.max_seq_len})
    wandb.log({"do_lower_case": model_args.do_lower_case})
    wandb.log({"output_hidden_states": model_args.output_hidden_states})
  
    return wandb

# %% [markdown]
# ## 4.2 Carregamento dos arquivos de dados kfold

# %% [markdown]
# ### Especifica os nomes dos arquivos de dados

# %%
# Nome do arquivo
NOME_ARQUIVO_FOLD_COMPACTADO = DIRETORIO_COHEBERT + "_KFOLD_10" + "_P" +  str(model_args.documentos_perturbados) + "_K" + str(model_args.top_k_predicao) + ".zip"

# %% [markdown]
# ### Copia os arquivos do Google Drive para o Colaboratory

# %%
def copiaArquivoFold():
  
  # Se estiver executando no Google Colaboratory
  if IN_COLAB:

    criaDiretorioLocal()
    
    # !cp "$DIRETORIO_DRIVE""/validacao_classificacao_palavra/kfold/""$NOME_ARQUIVO_FOLD_COMPACTADO" "$DIRETORIO_LOCAL"
      
    logging.info("Terminei a cópia.")

# %%
copiaArquivoFold()
# Out:
# 2022-05-02 23:51:38,925 : INFO : Terminei a cópia.

# %% [markdown]
# Descompacta os arquivos
#
# Usa o unzip para descompactar:
# *   `-o` sobrescreve o arquivo se existir
# *   `-j` Não cria nenhum diretório
# *   `-q` Desliga as mensagens
# *   `-d` Diretório de destino

# %%
def descompactaArquivoFold():
  
  # Se estiver executando no Google Colaboratory
  if IN_COLAB:
    # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_FOLD_COMPACTADO" -d "/content/validacao_kfold"

    logging.info("Terminei a descompactação.")

# %%
descompactaArquivoFold()
# Out:
# 2022-05-02 23:51:40,410 : INFO : Terminei a descompactação.

# %% [markdown]
# ### 4.2.4 Função de carregamento dos dados de um fold

# %%
# Import das bibliotecas.
import pandas as pd

def carregamentoDadosFold(fold):

  logging.info("Carregando os arquivos do fold de treino e avaliação.")
  
  # Diretório dos arquivos de dados.
  DIRETORIO = "/content/validacao_kfold"

  # Define o prefixo do nome dos arquivos dos folds
  PREFIXO_NOME_ARQUIVO_TREINO = DIRETORIO_COHEBERT + "_Train_f"
  PREFIXO_NOME_ARQUIVO_TESTE = DIRETORIO_COHEBERT + "_Test_f"

  # Nome dos arquivos.
  ARQUIVO_TREINO = DIRETORIO + "/" + PREFIXO_NOME_ARQUIVO_TREINO + str(fold) + ".csv"
  ARQUIVO_TESTE = DIRETORIO + "/" + PREFIXO_NOME_ARQUIVO_TESTE + str(fold) + ".csv" 

  logging.info("Carregando arquivo de treino: {}.".format(ARQUIVO_TREINO))
  logging.info("Carregando arquivo de teste: {}.".format(ARQUIVO_TESTE))

  # Verifica se o arquivo existe
  if not os.path.isfile(ARQUIVO_TREINO):
      # Caso contrário copia o arquivo do drive e descompacta
      copiaArquivoFold()
      descompactaArquivoFold()

  # Carrega o conjunto de dados de treino e teste.
  df_dados_train = pd.read_csv(ARQUIVO_TREINO, sep=';')  
  df_dados_test = pd.read_csv(ARQUIVO_TESTE, sep=';')  
  #logging.info("Qtde de dados de treino: {} e teste {}.".format(len(df_dados_train), len(df_dados_test)))

  return df_dados_train, df_dados_test

# %% [markdown]
# ## 4.3 Análise

# %% [markdown]
# ### Função descarte documentos muito grandes

# %%
def descarteDocumentosGrandes(tokenizer, tamanho_maximo_token, df_dados_train, df_dados_test):

  logging.info("Descartando documentos grandes dos conjuntos de dados.")

  # Define o tamanho máximo para os tokens.
  tamanho_maximo = tamanho_maximo_token

  # Tokenize a codifica as setenças para o BERT.     
  df_dados_train["input_ids"] = df_dados_train["documento"].apply(lambda tokens: tokenizer.encode(tokens, add_special_tokens=True))
        
  df_dados_train = df_dados_train[df_dados_train["input_ids"].apply(len)<tamanho_maximo]

  # Remove as colunas desnecessárias.
  df_dados_train = df_dados_train.drop(columns=["input_ids"])

  # Tokenize a codifica as setenças para o BERT.     
  df_dados_test["input_ids"] = df_dados_test["documento"].apply(lambda tokens: tokenizer.encode(tokens, add_special_tokens=True))

  # Corta os inputs para o tamanho máximo 512.
  df_dados_test = df_dados_test[df_dados_test["input_ids"].apply(len)<tamanho_maximo]

  #logging.info("Tamanho do conjunto de dados: {} / Treino: {} / Teste: {}.".format((len(df_dados_train)+len(df_dados_test)),len(df_dados_train), len(df_dados_test)))
    
  # Remove as colunas desnecessárias.
  df_dados_test = df_dados_test.drop(columns=["input_ids"])

  del tokenizer
  del tamanho_maximo

  return df_dados_train, df_dados_test

# %% [markdown]
# ## 4.4 Treinando o modelo de classificação

# %% [markdown]
# ### Otimizador e Agendador de Taxas de Aprendizado/Optimizer & Learning Rate Scheduler

# %% [markdown]
# Agora que temos nosso modelo carregado, precisamos pegar os hiperparâmetros de treinamento no modelo armazenado.
#
# Para fins de ajuste fino, os autores recomendam escolher entre os seguintes valores (no Apêndice A.3 do [artigo BERT](https://arxiv.org/pdf/1810.04805.pdf)):
#
# > - **Tamanho do lote(Batch size):** 16, 32
# - **Taxa de aprendizado (Adam):** 5e-5, 3e-5, 2e-5
# - **Número de épocas:** 2, 3, 4
#
# O parâmetro epsilon `eps = 1e-6` é" um número muito pequeno para impedir qualquer divisão por zero na implementação "(a partir de [aqui](https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/)).
#
# Você pode encontrar a criação do otimizador do AdamW em `run_glue.py` [aqui](https://github.com/huggingface/transformers/blob/5bfcd0485ece086ebcbed2d008813037968a9e58/examples/run_glue.py#L109).

# %% [markdown]
# ### Função carrega otimizador

# %%
# Import das bibliotecas.
from transformers import AdamW

def carregaOtimizador(training_args, model):
  '''
    Esta função carrega o otimizador utilizado no agendador de aprendizado.
  '''

  # Nota: AdamW é uma classe da biblioteca huggingface (ao contrário de pytorch).
  # Eu acredito que o 'W' significa 'Correção de redução de peso "
  optimizer = AdamW(model.parameters(),
                  lr = training_args.learning_rate, # (ou alfa) A taxa de aprendizado a ser usada. - default é 3e-5
                  # betas = (0.9, 0.999), # (beta1, beta2) - default é (0.9, 0.999)
                    # beta1 é taxa de decaimento exponencial para as estimativas do primeiro momento. 
                    # beta2 é taxa de decaimento exponencial para as estimativas do segundo momento. Este valor deve ser definido próximo a 1,0 em problemas com gradiente esparso (por exemplo, PNL e problemas de visão de computacional)
                  # eps = 1e-6, #  É um número muito pequeno para evitar qualquer divisão por zero na implementação - default é 1e-6.
                  # weight_decay = 0.0, # Correção de redução de peso. - default é 0.0
                    # A redução da taxa de aprendizagem também pode ser usada com Adam. A taxa de decaimento é atualizada a cada época para a demonstração da regressão logística.
                  # correct_bias = True #  Se não deve corrigir o viés(bias) no Adam mudar para False.- default é True
                )
  
  return optimizer

# %% [markdown]
# ### Função carrega agendador

# %% [markdown]
# A função **get_linear_schedule_with_warmup** cria um agendador com uma taxa de aprendizado que diminua linearmente da taxa de aprendizagem inicial definido no otimizador até 0, após um período de aquecimento durante o qual ele aumenta linearmente de 0 para a taxa de aprendizagem inicial definido no otimizador.
#
# Se `num_warmup_steps=0` e `weight_decay=0`(otimizador) não ocorre a etapa de aquecimento.

# %%
# Import das bibliotecas.
from transformers import get_linear_schedule_with_warmup

def carregaAgendador(training_args, optimizer, numero_etapas):
  '''
    Esta função carrega o agendador com um taxa de aprendizado que diminua linearmente até 0.
  '''

  # O número total de etapas de ajuste fino é [número de lotes] x [número de épocas].
  # (Observe que este não é o mesmo que o número de amostras de ajuste fino).
  total_etapas = numero_etapas * training_args.num_train_epochs

  #Cria o agendador de taxa de aprendizagem.
  scheduler = get_linear_schedule_with_warmup(optimizer, # O otimizador para o qual agendar a taxa de aprendizado.
                                            num_warmup_steps = 0, # O número de etapas para a fase de aquecimento. Valor default value em run_glue.py
                                            num_training_steps = total_etapas) # O número total de etapas de treinamento.


  logging.info("Total de etapas: {}".format(total_etapas))

  return scheduler

# %% [markdown]
# ### Função cria lotes inteligentes

# %%
# Import das bibliotecas.
from tqdm.notebook import tqdm as tqdm_notebook
import random

def criarLotesInteligentes(tokenizer,
                           documentos, 
                           classes, 
                           id_documentos, 
                           batch_size):
    '''
    Esta função combina todos os passos para preparar os lotes.
    '''
    logging.info("Criando Lotes Inteligentes de {:,} amostras com tamanho de lote {:,}...".format(len(documentos), batch_size))

    # ============================
    #   Tokenização & Truncamento
    # ============================

    input_ids_completos = []
    
    # Tokeniza todas as amostras de treinamento
    logging.info("Tokenizando {:,} amostra...".format(len(classes)))
    
    # Escolha o intervalo que o progresso será atualizado.
    intervalo_atualizacao = obterIntervaloAtualizacao(total_iteracoes=len(classes), numero_atualizacoes=10)
    
    # Barra de progresso dos documentos
    documentos_bar = tqdm_notebook(documentos, desc=f'Documentos ', unit=f'documento', total=len(documentos))

    # Para cada amostra de treinamento...
    for documento in documentos_bar:
    
        # Relatório de progresso
        #if ((len(input_ids_completos) % intervalo_atualizacao) == 0):
        #    logging.info("  Tokenizado {:,} amostras.".format(len(input_ids_completos)))

        # Tokeniza a amostra.
        input_ids = tokenizer.encode(text=documento,                    # Documento a ser codificado.
                                    add_special_tokens=True,            # Adiciona os ttokens especiais.
                                    max_length=model_args.max_seq_len,  # Tamanho do truncamento!
                                    truncation=True,                    # Faz o truncamento!
                                    padding=False)                      # Não preenche.
                
        # Adicione o resultado tokenizado à nossa lista.
        input_ids_completos.append(input_ids)

        del input_ids
    
    del documentos    
    
    logging.info("{:>10,} amostras tokenizadas.".format(len(input_ids_completos)))

    # =========================
    #      Seleciona os Lotes
    # =========================    
    
    # Classifique as duas listas pelo comprimento da sequência de entrada.
    amostras = sorted(zip(input_ids_completos, classes, id_documentos), key=lambda x: len(x[0]))

    del input_ids_completos
    del classes
    del id_documentos

    logging.info("{:>10,} amostras após classificação.".format(len(amostras)))

    # Lista de lotes que iremos construir.
    batch_ordered_documentos = []
    batch_ordered_classes = []
    batch_ordered_id_documentos = []

    logging.info("Criando lotes de tamanho {:}...".format(batch_size))

    # Escolha um intervalo no qual imprimir atualizações de progresso.
    intervalo_atualizacao = obterIntervaloAtualizacao(total_iteracoes=len(amostras), numero_atualizacoes=10)
        
    # Faça um loop em todas as amostras de entrada ... 
    while len(amostras) > 0:
        
        # Mostra o progresso.
        if ((len(batch_ordered_documentos) % intervalo_atualizacao) == 0 \
            and not len(batch_ordered_documentos) == 0):
            logging.info("  Selecionado {:,} lotes.".format(len(batch_ordered_documentos)))
        
        # `to_take` é o tamanho real do nosso lote. Será `batch_size` até
        # chegamos ao último lote, que pode ser menor.
        to_take = min(batch_size, len(amostras))
        
        # Escolha um índice aleatório na lista de amostras restantes para começar o nosso lote.
        select = random.randint(0, len(amostras) - to_take)

        # Selecione um lote contíguo de amostras começando em `select`.
        #print ("Selecionando lote de {:} a {:}".format(select, select+to_take))
        batch = amostras[select:(select + to_take)]

        #print("Tamanho do lote:", len(batch))
        
        # Cada amostra é uma tupla --divida para criar uma lista separada de
        # sequências e uma lista de rótulos para este lote.
        batch_ordered_documentos.append([s[0] for s in batch])
        batch_ordered_classes.append([s[1] for s in batch])
        batch_ordered_id_documentos.append([s[2] for s in batch])
        
        # Remova a amostra da lista
        del amostras[select:select + to_take]

    logging.info("  FEITO - Selecionado {:,} lotes.".format(len(batch_ordered_documentos)))

    # =========================
    #        Adicionando o preenchimento
    # =========================    

    logging.info("Preenchendo sequências dentro de cada lote...")

    py_input_ids = []
    py_attention_masks = []
    py_labels = []
    list_id_documentos = []

    # Para cada lote...
    for (batch_input_ids, batch_labels, batch_id_documentos) in zip(batch_ordered_documentos, batch_ordered_classes, batch_ordered_id_documentos):

        # Nova versão do lote, desta vez com sequências preenchidas e agora com
        # as máscaras de atenção definidas.
        batch_padded_input_ids = []
        batch_attention_masks = []
                
        # Primeiro, encontre a amostra mais longa do lote.
        # Observe que as sequências atualmente incluem os tokens especiais!
        max_size = max([len(input) for input in batch_input_ids])
        
        # Para cada entrada neste lote...
        for input in batch_input_ids:
                        
            # Quantos tokens pad precisam ser adicionados
            num_pads = max_size - len(input)

            # Adiciona `num_pads` do pad token(tokenizer.pad_token_id) até o final da sequência.
            padded_input = input + [tokenizer.pad_token_id] * num_pads

            # Define a máscara de atenção --é apenas um `1` para cada token real
            # e um `0` para cada token de preenchimento(pad).
            attention_mask = [1] * len(input) + [0] * num_pads
            
            # Adiciona o resultado preenchido ao lote.
            batch_padded_input_ids.append(padded_input)
            batch_attention_masks.append(attention_mask)

            del padded_input
            del attention_mask
        
        # Nosso lote foi preenchido, portanto, precisamos salvar este lote atualizado.
        # Também precisamos que as entradas sejam tensores PyTorch, então faremos isso aqui.
        py_input_ids.append(torch.tensor(batch_padded_input_ids))
        py_attention_masks.append(torch.tensor(batch_attention_masks))
        py_labels.append(torch.tensor(batch_labels))
        list_id_documentos.append(batch_id_documentos)
        
        del batch_padded_input_ids
        del batch_attention_masks

    del batch_ordered_documentos
    del batch_ordered_classes
    del batch_ordered_id_documentos
    
    del tokenizer    

    # Retorna o conjunto de dados em lotes inteligentes!
    return (py_input_ids, py_attention_masks, py_labels, list_id_documentos)

# %% [markdown]
# ### Função de Treinamento

# %%
# Import das bibliotecas
import random
import numpy as np
from tqdm.notebook import tqdm as tqdm_notebook

def realizaTreinamento(model, 
                       tokenizer, 
                       optimizer, 
                       scheduler,  
                       documentos_treino, 
                       classes_treino, 
                       id_documentos_treino, 
                       documentos_teste, 
                       classes_teste, 
                       id_documentos_teste, 
                       EPOCAS = 4):
  
  #logging.info("Realizando treinamento e avaliação do fold: {}".format(model_args.fold))

  # Defina o valor da semente em todos os lugares para torná-lo reproduzível.
  seed_val = training_args.seed
  random.seed(seed_val)
  np.random.seed(seed_val)
  torch.manual_seed(seed_val)
  torch.cuda.manual_seed_all(seed_val)

  # Medida do tempo total de treinamento e avaliação.
  treinamento_avaliacao_t0 = time.time()

  # Limpa o cache da GPU.
  torch.cuda.empty_cache()

  # Coloque o modelo em modo de treinamento. 
  model.train()

  # Acumula as perdas do treinamento.
  train_losses = []
  test_losses = []
   
  # Barra de progresso da época.
  epoca_bar = tqdm_notebook(range(0,training_args.num_train_epochs+1), desc=f'Épocas', unit=f'épocas')
  
  # Para cada época.
  for epoca_i in epoca_bar:
  
    # ========================================
    #               Inicialização
    # ========================================

    # Atualiza a época corrente      
    model_args.epoca = epoca_i

    # Atualiza o nome da saída corrente
    training_args.output_dir = NOME_BASE_SAIDA + getSufixoNomeArquivoSaida(training_args, model_args)

    # Inicializa o wandb para registro
    # Gera uma entrada para cada todas as epocas, com a taxa de aprendizagem, lote e fold    
    wandb = inicializacaoWandb()
    
    # Log das métidas com wandb.
    if model_args.use_wandb:    
      wandb.watch(model)  

    # Recupera o lote inteligente
    (py_input_ids, py_attention_masks, py_labels, documentoids) = criarLotesInteligentes(tokenizer, 
                                                                                         documentos_treino, 
                                                                                         classes_treino, 
                                                                                         id_documentos_treino, 
                                                                                         training_args.per_device_train_batch_size)
   
    # ========================================
    #               Avaliação época 0, sem treinamento
    # ========================================
    if epoca_i == 0:

      # Registra o tempo inicial.
      avaliacao_epoca_t0 = time.time()
      
      # Realiza a avaliação do modelo.    
      media_test_epoca_loss, acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s, lista_resultado_avaliacao = realizaAvaliacao(epoca_i, 
                                                                                                                     model, 
                                                                                                                     tokenizer, 
                                                                                                                     optimizer, 
                                                                                                                     scheduler, 
                                                                                                                     wandb, 
                                                                                                                     documentos_teste, 
                                                                                                                     classes_teste, 
                                                                                                                     id_documentos_teste)

      logging.info("   Avaliação loss: {:.8f}; Acc: {:.8f}; Rec: {:.8f}; Pre: {:.8f}, F1:{:.8f}, vp: {:3d}; vn: {:3d}; fp: {:3d}; fn: {:3d}".format(media_test_epoca_loss, acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s))      
      logging.info("   Acurácia do fold {} na época {}: {:.8f}.".format(model_args.fold, epoca_i, acc))  

      # Não acura acumula a perda de treinamento da época pois não ocorreu treinamento.
      # test_losses.append(media_test_epoca_loss)

      # Medida de quanto tempo levou a execução da avaliação.
      avaliacao_epoca_total = formataTempo(time.time() - avaliacao_epoca_t0)

      logging.info("   Média perda(loss) do avaliação da época   : {0:.8f}.".format(media_test_epoca_loss))
      logging.info("   Tempo de avaliação da época               : {:}.".format(avaliacao_epoca_total))    
      logging.info("   Tempo parcial do processamento            : {:} (h:mm:ss)".format(formataTempo(time.time()-treinamento_avaliacao_t0)))

      ################# Salva a classificação e avaliação para a época

      # Salva o resultado da classificação da época
      salvaResultadoClassificacao(lista_resultado_avaliacao)

      # Salva o resultado da avaliação da épóca
      treinamento_avaliacao_total_t0 = format(formataTempo(time.time()-treinamento_avaliacao_t0))
      salvaResultadoAvaliacao(media_test_epoca_loss, 
                              acc, 
                              rec, 
                              pre, 
                              f1, 
                              vp_s, 
                              vn_s, 
                              fp_s, 
                              fn_s, 
                              treinamento_avaliacao_total_t0)

      # Log das métricas com wandb.
      if model_args.use_wandb:    
        NOME_EXECUCAO = NOME_BASE_SAIDA + getSufixoNomeArquivoSaida(training_args,model_args)
        wandb.log({"nome_execucao": NOME_EXECUCAO[:-2], # -2 para retirar "_f" do fina do nome da execução
                  "acuracia": acc,
                  "vp": vp_s , 
                  "vn": vn_s,  
                  "fp": fp_s,
                  "fn": fn_s, 
                  "media_train_epoca_loss" : 0,
                  "tempo_train" : 0,
                  "media_test_epoca_loss" : media_test_epoca_loss,
                  "tempo_test" : avaliacao_epoca_total})
      
    else:
      # ========================================
      #               Treinamento e Avaliação para as épocas > 0
      # ========================================

      # Execute uma passada completa sobre o conjunto de treinamento.
      logging.info("Realizando treinamento do fold {} na época: {}.".format(model_args.fold, model_args.epoca))

      # Medida de quanto tempo leva o período de treinamento.
      treinamento_epoca_t0 = time.time()

      # Acumula as perdas do treinamento da época.
      train_batch_losses = []

      # Barras de progresso.    
      lote_treino_bar = tqdm_notebook(range(0, len(py_input_ids)), desc=f'Epoca {epoca_i}', unit=f'lotes', total=len(py_input_ids) )

      # Para cada lote dos dados de treinamento.
      for index in lote_treino_bar:      

          # Descompacte este lote de treinamento de nosso dataloader.
          #
          # À medida que descompactamos o lote, também copiaremos cada tensor para a GPU usando o
          # o método `to`
          #
          # `lote` é uma lista contém três tensores pytorch:
          #   [0]: input ids 
          #   [1]: attention masks
          #   [2]: labels 

          # Recupera os tensores do lote e copia para a GPU usando o método `to` 
          d_input_ids = py_input_ids[index].to(device)
          d_input_mask = py_attention_masks[index].to(device)
          d_labels = py_labels[index].to(device)     
          
          # Sempre limpe quaisquer gradientes calculados anteriormente antes de realizar um
          # passe para trás. PyTorch não faz isso automaticamente porque
          # acumular os gradientes é "conveniente durante o treinamento de RNNs".
          # (source: https://stackoverflow.com/questions/48001598/why-do-we-need-to-call-zero-grad-in-pytorch)
          model.zero_grad()

          # Execute um passe para frente (avalie o modelo neste lote de treinamento).
          # A documentação para esta função `model` está aqui:
          # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
          # Ele retorna diferentes números de parâmetros dependendo de quais argumentos
          # são fornecidos e quais sinalizadores estão definidos. Para nosso uso aqui, ele retorna
          # a perda (porque fornecemos rótulos) e os "logits" - o modelo de saídas antes da ativação.     

          # last_hidden_state = outputs[0], pooler_output = outputs[1], hidden_states = outputs[2]
          outputs = model(d_input_ids, 
                          token_type_ids=None, 
                          attention_mask=d_input_mask, 
                          labels=d_labels)
          
          # A perda(loss) é retornado em outputs[0] porque fornecemos rótulos(labels))                  
          loss = outputs[0]

          # E outputs[1] os "logits" - o modelo de saídas antes da ativação.
          # logits possui duas dimensões, a primeira do lote e a segunda do rótulo da predição                        
          # A função `.detach().cpu()` retira da gpu.
          logits = outputs[1].detach().cpu()
    
          # Acumule a perda de treinamento em todos os lotes da época para que possamos
          # calcular a perda média no final da época. `loss` é um tensor contendo um único valor.   
          # A função `.item ()` retorna apenas o valor Python do tensor.
          train_batch_losses.append(loss.item())

          # Mostra a perda na barra de progresso.
          lote_treino_bar.set_postfix(loss=loss.item())

          # Log das métricas com wandb.
          if model_args.use_wandb:          
            wandb.log({"train_batch_loss": loss.item()})

          # Execute uma passagem para trás para calcular os gradientes.
          # Todos os parâmetros do modelo deve ter sido setado para param.requires_grad = False
          loss.backward()            

          # Corte a norma dos gradientes para 1.0.
          # Isso ajuda a evitar o problema de "gradientes explosivos".
          torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
          # Atualize os parâmetros e dê um passo usando o gradiente calculado.
          # O otimizador dita a "regra de atualização" - como os parâmetros são
          # modificados com base em seus gradientes, taxa de aprendizagem, etc.
          optimizer.step()
                            
          # Atualize a taxa de aprendizagem.
          scheduler.step()

          # Apaga variáveis não utilizadas
          del outputs

      # Média da perda do treinamento de todos os lotes da época.
      media_train_epoca_loss = np.mean(train_batch_losses)

      # Acumule a perda de treinamento de todas as épocas para calcular a perda média do treinamento.    
      train_losses.append(media_train_epoca_loss)

      # Medida de quanto tempo levou o treinamento desta época.
      treinamento_epoca_total = formataTempo(time.time() - treinamento_epoca_t0)

      logging.info("   Média perda(loss) do treinamento da época : {0:.8f}.".format(media_train_epoca_loss))
      logging.info("   Tempo de treinamento da época             : {:}.".format(treinamento_epoca_total))    
      logging.info("   Tempo parcial processamento               : {:} (h:mm:ss)".format(formataTempo(time.time()-treinamento_avaliacao_t0)))

      ################# Avaliação da época
      
      # Registra o tempo inicial.
      avaliacao_epoca_t0 = time.time()

      # Realiza a avaliação do modelo.    
      media_test_epoca_loss, acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s, lista_resultado_avaliacao = realizaAvaliacao(epoca_i, model, 
                                                                                                                     tokenizer, 
                                                                                                                     optimizer, 
                                                                                                                     scheduler, 
                                                                                                                     wandb, 
                                                                                                                     documentos_teste, 
                                                                                                                     classes_teste, 
                                                                                                                     id_documentos_teste)

      logging.info("   Avaliação loss: {:.8f}; Acc: {:.8f}; Rec: {:.8f}; Pre: {:.8f}, F1:{:.8f}, vp: {:3d}; vn: {:3d}; fp: {:3d}; fn: {:3d}".format(media_test_epoca_loss, acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s))      
      logging.info("   Acurácia do fold {} na época {}: {:.8f}.".format(model_args.fold, epoca_i, acc))  
      
      # Acumule a perda de treinamento da época para calcular a perda média do treinamento.    
      test_losses.append(media_test_epoca_loss)

      # Medida de quanto tempo levou a execução da avaliação
      avaliacao_epoca_total = formataTempo(time.time() - avaliacao_epoca_t0)

      logging.info("   Média perda(loss) do avaliação da época   : {0:.8f}.".format(media_test_epoca_loss))
      logging.info("   Tempo de avaliação da época               : {:}.".format(avaliacao_epoca_total))    
      logging.info("   Tempo parcial do processamento            : {:} (h:mm:ss)".format(formataTempo(time.time()-treinamento_avaliacao_t0)))

      ################# Salva a classificação e avaliação para a época

      # Salva o resultado da classificação da época
      salvaResultadoClassificacao(lista_resultado_avaliacao)

      # Salva o resultado da avaliação da épóca
      treinamento_avaliacao_total_t0 = format(formataTempo(time.time()-treinamento_avaliacao_t0))
      salvaResultadoAvaliacao(media_test_epoca_loss, 
                              acc, 
                              rec, 
                              pre, 
                              f1, 
                              vp_s, 
                              vn_s, 
                              fp_s, 
                              fn_s, 
                              treinamento_avaliacao_total_t0)

      ################# Salva o modelo ajustado no wandb
      salvaModeloWandb(model, model_args)

      ################# Salva o modelo ajustado
      salvaModelo(model, tokenizer, model_args)

      # Apaga variáveis não utilizadas
      del py_input_ids
      del py_attention_masks
      del py_labels
      del train_batch_losses
      del lote_treino_bar

      # Log das métricas com wandb.
      if model_args.use_wandb:    
        NOME_EXECUCAO = NOME_BASE_SAIDA + getSufixoNomeArquivoSaida(training_args,model_args)
        wandb.log({"nome_execucao": NOME_EXECUCAO[:-2], # -2 para retirar "_f" do fina do nome da execução
                  "acuracia": acc,
                  "vp": vp_s , 
                  "vn": vn_s,  
                  "fp": fp_s,
                  "fn": fn_s, 
                  "media_train_epoca_loss" : media_train_epoca_loss,
                  "tempo_train" : treinamento_epoca_total,
                  "media_test_epoca_loss" : media_test_epoca_loss,
                  "tempo_test" : avaliacao_epoca_total})
        
    # Finaliza o wandb
    if model_args.use_wandb:
      wandb.finish()  
     
  # Média da perda do treinamento de todas as épocas.
  media_train_loss = np.mean(train_losses)
  media_test_loss = np.mean(test_losses)

  logging.info("  Média perda(loss) treinamento : {0:.8f}.".format(media_train_loss))
  logging.info("  Média perda(loss) avaliação   : {0:.8f}.".format(media_test_loss))

  # Apaga variáveis não utilizadas
  del train_losses
  del epoca_bar
  
  del model
  del tokenizer  
  del documentos_treino
  del classes_treino
  del id_documentos_treino
  del documentos_teste
  del classes_teste
  del id_documentos_teste

# %% [markdown]
# ## 4.5 Avaliação
#
# Avaliando o modelo treinado no conjunto de dados de teste.

# %% [markdown]
# ### Função de avaliação

# %%
# Import das bibliotecas.
import torch
from tqdm.notebook import tqdm as tqdm_notebook

def realizaAvaliacao(epoca, 
                     model, 
                     tokenizer, 
                     optimizer, 
                     scheduler, 
                     wandb,
                     documentos_teste, 
                     classes_teste, 
                     id_documentos_teste):
   
  # Armazena o resultado da avaliação executada
  lista_resultado_avaliacao = []

  logging.info("Realizando avaliação do fold {} na época: {}.".format(model_args.fold, epoca))

  # Use nossa nova função para preparar completamente nosso conjunto de dados.
  (py_input_ids, py_attention_masks, py_labels, documentosids) = criarLotesInteligentes(tokenizer, documentos_teste, classes_teste, id_documentos_teste, training_args.per_device_eval_batch_size)

  # Coloque o modelo em modo de avaliação.
  model.eval()

  # Acumula as perdas dos testes dos lotes.
  test_batch_losses = []

  # Acumula os resultados dos testes.
  vp = [] # Verdadeiro positivo
  vn = [] # Verdadeiro negativo
  fp = [] # Falso positivo
  fn = [] # Falso negativo

  # Barra de progresso dos lotes de teste.
  lote_teste_bar = tqdm_notebook(range(0, len(py_input_ids)), desc=f'Lotes ', unit=f'lotes', total=len(py_input_ids))

  # Para cada lote dos dados de avaliação(teste).
  for index in lote_teste_bar:

    # Copia o lote para a GPU.
    d_input_ids = py_input_ids[index].to(device)
    d_input_mask = py_attention_masks[index].to(device)
    d_labels = py_labels[index].to(device)
    d_documentoids = documentosids[index]

    # Diga a pytorch para não se preocupar em construir o gráfico de computação durante
    # o passe para frente, já que isso só é necessário para backprop (treinamento).
    with torch.no_grad():
        # Obtenha a saída de "logits" pelo modelo. Os "logits" são a saída
        # valores antes de aplicar uma função de ativação como o softmax.        
        # Retorno de model quando ´last_hidden_state=True´ é setado:    
        # last_hidden_state = outputs[0], pooler_output = outputs[1], hidden_states = outputs[2]
        outputs = model(d_input_ids,
                        token_type_ids=None, 
                        attention_mask=d_input_mask, 
                        labels=d_labels)
        
    # A perda(loss) é retornado em outputs[0] porque fornecemos rótulos(labels). 
    # É útil para comparar com a perda do treinamento, quando é realizado a avaliação entre as épocas de treinamento.
    loss = outputs[0]

    # E outputs[1] os "logits" - o modelo de saídas antes da ativação.
    # logits possui duas dimensões, a primeira do lote e a segunda do rótulo da predição                        
    logits = outputs[1]
        
    # Acumule a perda da avaliação em todos os lotes para que possamos
    # calcular a perda média no final. `loss` é um tensor contendo um único valor.
    # A função '.cpu()' move loss para a cpu.
    # A função `.item ()` retorna apenas o valor Python do tensor.         
    test_batch_losses.append(loss.cpu().item())

    # Log das métricas com wandb.
    if model_args.use_wandb:
        wandb.log({"test_batch_loss": loss.cpu().item()})

    # Recupera o índice do melhor resultado, maior valor dos tensores para coluna(1)
    _, classificacao = torch.max(logits, 1)

    # Verifica a classificação realizada e o rótulo previsto
    vp.append(((classificacao==1) & (d_labels==1)).sum().cpu().item())
    vn.append(((classificacao==0) & (d_labels==0)).sum().cpu().item())
    fp.append(((classificacao==1) & (d_labels==0)).sum().cpu().item())
    fn.append(((classificacao==0) & (d_labels==1)).sum().cpu().item())

    # Adiciona o documento de teste, o rótulo e a classificação realizada a lista de resultado
    for lote in range(len(d_labels)):
                
        lista_resultado_avaliacao.append([d_documentoids[lote],
                                d_labels[lote].cpu().item(), 
                                classificacao[lote].cpu().item()])

    del outputs
    del d_input_ids
    del d_input_mask
    del d_labels
    del d_documentoids

  # Soma as classificações realizadas
  vp_s, vn_s, fp_s, fn_s = sum(vp), sum(vn), sum(fp), sum(fn)
  
  # Acurácia indica uma performance geral do modelo. 
  # Dentre todas as classificações, quantas o modelo classificou corretamente(vp=1 e vn=0).
  if (vp_s+vn_s+fp_s+fn_s) != 0:
      acc = (vp_s+vn_s)/(vp_s+vn_s+fp_s+fn_s)
  else:
      acc = 0

  # Recall(Revocação) avalia todas as situações da classe Positivo(vp=1) com o valor esperado e quantas estão corretas.
  if (vp_s+fn_s) != 0:
      rec = (vp_s)/(vp_s+fn_s)
  else:
      rec = 0
  
  # Precisão avalia as classificações da classe positivo(vp=1 e fp=0) que o modelo fez e quantas estão corretas.
  if (vp_s+fp_s) != 0:
      pre = (vp_s)/(vp_s+fp_s)
  else:
      pre = 0  

  # F1 é a média harmônica entre precisão e recall.
  if (pre + rec) != 0:  
    f1 = 2 * ((pre * rec)/(pre + rec))
  else:
    f1 = 0

  # Média da perda da avaliação  
  media_test_epoca_loss = np.mean(test_batch_losses)

  del py_input_ids
  del py_attention_masks
  del py_labels
  del test_batch_losses
  del lote_teste_bar
  
  del model
  del tokenizer
  del documentos_teste
  del classes_teste
  del id_documentos_teste

  return media_test_epoca_loss, acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s, lista_resultado_avaliacao

# %% [markdown]
# ### Função que salva o resultado da classificação

# %%
def getNomeDiretorioResultados(training_args, model_args):
  
  # Monta o nome do arquivo com parâmetros
  nome_arquivo = ""
  nome_arquivo = nome_arquivo + "P_" + str(model_args.documentos_perturbados)
  nome_arquivo = nome_arquivo + "_K_" + str(model_args.top_k_predicao) 
     
  return nome_arquivo

# %%
# Import das bibliotecas.
import os
import datetime

def salvaResultadoClassificacao(lista_resultado_avaliacao):

  if model_args.salvar_classificacao:

    # Recupera a hora do sistema.
    data_e_hora = datetime.datetime.now()
    
    # Nome arquivo resultado
    NOME_ARQUIVO_CLASSIFICACAO = NOME_BASE_SAIDA + getSufixoNomeArquivoSaida(training_args, model_args) + str(model_args.fold) + MODELO_BERT + TAMANHO_BERT 
  
    # Diretório para salvar o arquivo.
    DIRETORIO_CLASSIFICACAO_DRIVE = DIRETORIO_DRIVE + "validacao_classificacao_palavra/kfold/Classificacao/" + getNomeDiretorioResultados(training_args, model_args) + "/"

    # Diretório local para salvar o arquivo
    DIRETORIO_CLASSIFICACAO_LOCAL = DIRETORIO_LOCAL + "Classificacao/"

    # Verifica se o diretório existe
    if not os.path.exists(DIRETORIO_CLASSIFICACAO_DRIVE):  
      # Cria o diretório
      os.makedirs(DIRETORIO_CLASSIFICACAO_DRIVE)
      logging.info("Diretório criado: {}.".format(DIRETORIO_CLASSIFICACAO_DRIVE))
    else:
      logging.info("Diretório já existe: {}.".format(DIRETORIO_CLASSIFICACAO_DRIVE))

    # Verifica se o diretório existe
    if not os.path.exists(DIRETORIO_CLASSIFICACAO_LOCAL):  
      # Cria o diretório
      os.makedirs(DIRETORIO_CLASSIFICACAO_LOCAL)
      logging.info("Diretório criado: {}.".format(DIRETORIO_CLASSIFICACAO_LOCAL))
    else:
      logging.info("Diretório já existe: {}.".format(DIRETORIO_CLASSIFICACAO_LOCAL))      

    # Caminho completo do arquivo compactado no drive
    NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO = DIRETORIO_CLASSIFICACAO_DRIVE + NOME_ARQUIVO_CLASSIFICACAO + ".zip"
    # print("NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO:", NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO)

    # Caminho completo do arquivo compactado no local
    NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO = DIRETORIO_CLASSIFICACAO_LOCAL + NOME_ARQUIVO_CLASSIFICACAO + ".zip"
    # print("NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO:", NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO)

    # Caminho completo do arquivo no local
    NOME_ARQUIVO_CLASSIFICACAO_LOCAL = DIRETORIO_CLASSIFICACAO_LOCAL + NOME_ARQUIVO_CLASSIFICACAO + ".csv"
    # print("NOME_ARQUIVO_CLASSIFICACAO_LOCAL:", NOME_ARQUIVO_CLASSIFICACAO_LOCAL)

    # Gera todo o conteúdo a ser salvo no arquivo
    novo_conteudo = ""        
    for resultado in lista_resultado_avaliacao:      
      novo_conteudo = novo_conteudo + data_e_hora.strftime("%d/%m/%Y %H:%M") + ";" + str(resultado[0]) + ";" + str(resultado[1]) + ";" + str(resultado[2]) + "\n"

    # Verifica se o arquivo existe.
    if os.path.isfile(NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO):

      # Copia arquivo da classificação compactado do google drive para o drive local
      # !cp "$NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO" "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO"  
      # Descompacta arquivo da classificação compactado no drive local
      # !unzip -o -j -q "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO" -d "$DIRETORIO_CLASSIFICACAO_LOCAL"

      logging.info("Atualizando arquivo classificação: {}.".format(NOME_ARQUIVO_CLASSIFICACAO_LOCAL))
      # Abre o arquivo para leitura.
      arquivo = open(NOME_ARQUIVO_CLASSIFICACAO_LOCAL,'r')
      # Leitura de todas as linhas do arquivo.
      conteudo = arquivo.readlines()
      # Conteúdo a ser adicionado.
      conteudo.append(novo_conteudo)

      # Abre novamente o arquivo (escrita).
      arquivo = open(NOME_ARQUIVO_CLASSIFICACAO_LOCAL,'w')
      # escreva o conteúdo criado anteriormente nele.
      arquivo.writelines(conteudo)  
      # Fecha o arquivo.
      arquivo.close()

      # Compacta o arquivo da classificação
      # !zip -o -q -j "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO" "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL"
      # Copia o arquivo da classificação compactado para o drive
      # !cp "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO" "$NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO"

      del conteudo
      del arquivo
      del lista_resultado_avaliacao
      
    else:
      logging.info("Criando arquivo classificação: {}.".format(NOME_ARQUIVO_CLASSIFICACAO_LOCAL))
      # Abre novamente o arquivo (escrita).
      arquivo = open(NOME_ARQUIVO_CLASSIFICACAO_LOCAL,'w')
      arquivo.writelines('data;id;classe;predicao\n' + novo_conteudo)  # escreva o conteúdo criado anteriormente nele.
      # Fecha o arquivo.
      arquivo.close()

      # Compacta o arquivo da classificação
      # !zip -o -q -j "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO" "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL"
      # Copia o arquivo da classificação compactado para o drive
      # !cp "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO" "$NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO"

      del arquivo
      del lista_resultado_avaliacao

# %% [markdown]
# ### Função que salva o resultado da avaliação
#
# Salva o resultado da avaliação do conjunto de dados de teste do fold especificado.

# %%
# Import das bibliotecas.
import os
import datetime

def salvaResultadoAvaliacao(media_test_loss, acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s, treinamento_total):

  if model_args.salvar_avaliacao:
    
    # Recupera a hora do sistema.
    data_e_hora = datetime.datetime.now()

    # Nome arquivo resultado
    NOME_ARQUIVO_AVALIACAO = NOME_BASE_SAIDA + getSufixoNomeArquivoSaida(training_args, model_args) + str(model_args.fold) + MODELO_BERT + TAMANHO_BERT 

    # Diretório para salvar o arquivo.
    DIRETORIO_AVALIACAO = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_classificacao_palavra/kfold/Avaliacao/" + getNomeDiretorioResultados(training_args, model_args) + "/"

    # Verifica se o diretório existe
    if not os.path.exists(DIRETORIO_AVALIACAO):  
      # Cria o diretório
      os.makedirs(DIRETORIO_AVALIACAO)
      logging.info("Diretório criado: {}.".format(DIRETORIO_AVALIACAO))
    else:
      logging.info("Diretório já existe: {}.".format(DIRETORIO_AVALIACAO))

    # Nome do arquivo a ser aberto.
    NOME_ARQUIVO_AVALIACAO_COMPLETO = DIRETORIO_AVALIACAO + NOME_ARQUIVO_AVALIACAO + ".csv"

    # Conteúdo a ser adicionado.
    novo_conteudo = NOME_ARQUIVO_AVALIACAO + ";" +  data_e_hora.strftime("%d/%m/%Y %H:%M") + ";"  + treinamento_total + ";"  + str(acc) + ";"  +  str(vp_s) + ";"  +  str(vn_s) + ";" +  str(fp_s) + ";" +  str(fn_s) + "\n"

    # Verifica se o arquivo existe.
    if os.path.isfile(NOME_ARQUIVO_AVALIACAO_COMPLETO):
      logging.info("Atualizando arquivo resultado: {}.".format(NOME_ARQUIVO_AVALIACAO_COMPLETO))
      # Abre o arquivo para leitura.
      arquivo = open(NOME_ARQUIVO_AVALIACAO_COMPLETO,'r')
      # Leitura de todas as linhas do arquivo.
      conteudo = arquivo.readlines()
      # Conteúdo a ser adicionado.
      conteudo.append(novo_conteudo)

      # Abre novamente o arquivo (escrita).
      arquivo = open(NOME_ARQUIVO_AVALIACAO_COMPLETO,'w')
      # escreva o conteúdo criado anteriormente nele.
      arquivo.writelines(conteudo)  
      # Fecha o arquivo.
      arquivo.close()

      del conteudo
      del arquivo

    else:
      logging.info("Criando arquivo resultado: {}.".format(NOME_ARQUIVO_AVALIACAO_COMPLETO))
      # Abre novamente o arquivo (escrita).
      arquivo = open(NOME_ARQUIVO_AVALIACAO_COMPLETO,'w')
      arquivo.writelines('arquivo;data;tempo;acuracia;vp;vn;fp;fn\n' + novo_conteudo)  # escreva o conteúdo criado anteriormente nele.
      # Fecha o arquivo.
      arquivo.close()

      del arquivo

# %% [markdown]
# ### Função que carrega e calcula a média da acurácia dos folds

# %%
# Import das bibliotecas.
import os
import pandas as pd

def carregaResultadoAvaliacao(NOME_ARQUIVO_AVALIACAO):

  NOME_ARQUIVO_EXECUCAO = NOME_ARQUIVO_AVALIACAO + "X" + MODELO_BERT + TAMANHO_BERT

  logging.info("Média dos arquivos: {}".format(NOME_ARQUIVO_EXECUCAO))

  # Diretório para salvar o arquivo.
  DIRETORIO_AVALIACAO = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_classificacao_palavra/kfold/Avaliacao/" + getNomeDiretorioResultados(training_args, model_args) + "/"

  # Verifica se o diretório dos resultados existem.
  if os.path.exists(DIRETORIO_AVALIACAO):
    # Acumuladores.
    soma_acuracia = 0
    listaTempo = []
    conta_folds = 0

    # Percorre os arquivos de resultados.
    for f in range(10):  
      # Nome do arquivo a ser aberto.
      NOME_ARQUIVO_AVALIACAO_COMPLETO = DIRETORIO_AVALIACAO + NOME_ARQUIVO_AVALIACAO + str(f+1) + MODELO_BERT + TAMANHO_BERT + ".csv"    
      # Verifica se o arquivo existe.
      if os.path.isfile(NOME_ARQUIVO_AVALIACAO_COMPLETO):
        
        # Carrega os dados do arquivo  
        dados = pd.read_csv(NOME_ARQUIVO_AVALIACAO_COMPLETO, sep=';')
        # Mostra os dados do teste do fold.
        for index, linha in dados.iterrows():
        
          # Cálculo das estatísticas
          acc = (linha['vp']+linha['vn'])/(linha['vp']+linha['vn']+linha['fp']+linha['fn'])
          if (linha['vp']+linha['fn']) != 0:
              rec = (linha['vp'])/(linha['vp']+linha['fn'])
          else:
              rec = 0
          if (linha['vp']+linha['fp']) != 0:
              pre = (linha['vp'])/(linha['vp']+linha['fp'])
          else:  
              pre = 0
          if (pre + rec) != 0:  
              f1 = 2 * ((pre * rec)/(pre + rec))
          else:
              f1 = 0
          qtde_testes = linha['vp']+linha['vn']+linha['fp']+linha['fn']
          logging.info("Arquivo: {}, Data: {}, Tempo: {}, QtdeTeste: {:3d}, Acc: {:.8f}, Rec: {:.8f}, Pre: {:.8f}, F1:{:.8f}, vp: {:4d}; vn: {:4d}; fp: {:4d}; fn: {:4d}".format( 
               linha["arquivo"], linha["data"], linha["tempo"], qtde_testes, acc, rec, pre, f1, linha["vp"], linha["vn"], linha["fp"], linha["fn"]))    
           
          # Guarda o tempo.
          listaTempo.append(str(linha['tempo']))

        # Procura a maior acurácia.
        soma_acuracia = soma_acuracia + dados['acuracia'].max()
        # Conta o número de folds.
        conta_folds = conta_folds + 1

        del dados
    
    # Mostra a soma da acurácia . 
    logging.info("Total acurácia                                       : {:.8f}.".format(soma_acuracia))
    # Mostra a quantidade de folds.
    logging.info("Quantidade de folds                                  : {}.".format(conta_folds))  
    # Calcula a média.
    if conta_folds != 0:
      media = soma_acuracia/conta_folds
      logging.info("A média da acurácia de {:2d} folds é                    : {:.8f}.".format(conta_folds, media))
      logging.info("O tempo gasto na execução do treinamentoa {:2d} folds é : {}.".format(conta_folds, somaTempo(listaTempo)))
      logging.info("A média de tempo de execução de {:2d} folds é           : {}.".format(conta_folds, mediaTempo(listaTempo)))
      # Guarda o resultado da execução
      lista_resultado_execucoes.append(NOME_ARQUIVO_EXECUCAO + ";" + str(media) + ";" + str(somaTempo(listaTempo)))
  else:
    logging.info("Diretório com os resultados não encontrado.")
  
  del listaTempo

# %% [markdown]
# ## 4.6 Salva e copia o modelo ajustado

# %% [markdown]
# ### Função que salva o modelo ajustado no wandb

# %%
def salvaModeloWandb(model, model_args):
  
  # Salvando o Modelo para o wandb
  if model_args.use_wandb and model_args.salvar_modelo_wandb:
  
    # Salva o modelo para o wandb    
    torch.save(model.state_dict(), os.path.join(wandb.run.dir, 'model_dict.pt'))

    logging.info("Modelo salvo no wandb.")

# %% [markdown]
# ### Função que salva e copia o modelo ajustado
#
# Salva e  modelo e o tokenizador no disco e copia para o google drive.

# %%
# Import de bibliotecas.
import os

def salvaModelo(model, tokenizer, model_args):
  
  if model_args.salvar_modelo:

    # Salvando as melhores práticas: se você usar nomes padrão para o modelo, você pode recarregá-lo usando from_pretrained ()

    # Diretório de salvamento do modelo.
    DIRETORIO_LOCAL_MODELO_AJUSTADO = '/content/modelo_ajustado/' + model_args.fold

    # Cria o diretório de saída se necessário.
    if not os.path.exists(DIRETORIO_LOCAL_MODELO_AJUSTADO):
      os.makedirs(DIRETORIO_LOCAL_MODELO_AJUSTADO)

    logging.info("Salvando o modelo para {}.".format(DIRETORIO_LOCAL_MODELO_AJUSTADO))

    # Salve um modelo treinado, configuração e tokenizer usando `save_pretrained ()`.
    # Eles podem então ser recarregados usando `from_pretrained ()`.
    model_to_save = model.module if hasattr(model, 'module') else model  # Cuide do treinamento distribuído/paralelo
    model_to_save.save_pretrained(DIRETORIO_LOCAL_MODELO_AJUSTADO)
    tokenizer.save_pretrained(DIRETORIO_LOCAL_MODELO_AJUSTADO)

    # Boa prática: salve seus argumentos de treinamento junto com o modelo treinado.
    torch.save(model_args, os.path.join (DIRETORIO_LOCAL_MODELO_AJUSTADO, 'mode_args.bin'))
    torch.save(training_args, os.path.join (DIRETORIO_LOCAL_MODELO_AJUSTADO, 'training_args.bin'))

    logging.info("Modelo salvo.")

    # Para salvar seu modelo nas sessões do Colab Notebook, faça o download no seu computador local ou, idealmente, copie-o no seu Google Drive.
    # Copia o arquivo do modelo para o diretório no Google Drive.
    # !cp -r '$DIRETORIO_LOCAL_MODELO_AJUSTADO'* '$DIRETORIO_REMOTO_MODELO_AJUSTADO'

    logging.info("Modelo copiado.")

# %% [markdown]
# # 5 Execução do treinamento e avaliação

# %% [markdown]
# Gera o sufixo do nome do arquivo de saída com os parâmetros da execução
#
# Exemplo de formado de sufixo.
# `K_1_P_1_E_4_e_1_lr_5_b_8_4_f`
#   - P = documentos perturbados
#   - K = previsões palavras
#   - E = número total de épocas de treinamento
#   - e = número da época executada
#   - lr = taxa de aprendizagem
#   - b = lotes de treino e avaliação
#   - f = número do fold

# %%
def getSufixoNomeArquivoSaida(training_args, model_args):

  # Recupera o número inteiro da taxa de aprendizagem
  taxa_inteiro = int(training_args.learning_rate*100000)

  # Monta o nome do arquivo com parâmetros
  nome_arquivo = ""
  nome_arquivo = nome_arquivo + "_P_" + str(model_args.documentos_perturbados) 
  nome_arquivo = nome_arquivo + "_K_" + str(model_args.top_k_predicao) 
  nome_arquivo = nome_arquivo + "_E_" + str(training_args.num_train_epochs)
  nome_arquivo = nome_arquivo + "_e_" + str(model_args.epoca)   
  nome_arquivo = nome_arquivo + "_lr_" + str(taxa_inteiro)  
  nome_arquivo = nome_arquivo + "_b_" + str(training_args.per_device_train_batch_size) 
  nome_arquivo = nome_arquivo + "_" + str( training_args.per_device_eval_batch_size) 
  nome_arquivo = nome_arquivo + "_f" 
   
  return nome_arquivo

# %% [markdown]
# ## 5.1 Função de treinamento e avaliação de todos os folds
#
# Carrega os folds para serem avaliados

# %%
# Import das bibliotecas
from tqdm.notebook import tqdm as tqdm_notebook
import time
import datetime
import gc

def procedimentoTreinamentoAvaliacaoFolds(modelo, taxa_de_aprendizagem):

  # Barra de progresso dos folds
  fold_bar = tqdm_notebook(range(inicioFold, fimFold+1), desc=f'Folds ', unit=f'fold', total=fimFold)

  # Percorre todos os folds do intervalo de inicioFold até fimFold
  for ifold in fold_bar:

    # Seta o parâmetro do fold
    model_args.fold = ifold

    logging.info("Processamendo do fold: {}.".format(model_args.fold))
    logging.info("   com o modelo: {}".format(modelo))
    logging.info("   até época {} e taxa de aprendizagem {}.".format(training_args.num_train_epochs, taxa_de_aprendizagem))  
    
    # Marca o tempo de início do processamento
    processamento_fold_t0 = time.time()

    # Carregando o modelo   
    model, tokenizer = carregaBERT(model_args)
        
    # Conecta o modelo a GPU
    model = conectaGPU(model, device)

    # Função de carregamento dos dados de um fold
    df_dados_train, df_dados_test = carregamentoDadosFold(model_args.fold)

    # Descartando documentos muito grandes
    df_dados_train, df_dados_test = descarteDocumentosGrandes(tokenizer, model_args.max_seq_len, df_dados_train, df_dados_test)
    
    # Pega as listas de documentos de treino e seus rótulos.
    documentos_treino = df_dados_train.documento.values
    classes_treino = df_dados_train.classe.values
    id_documentos_treino = df_dados_train.id.values

    # Pega as listas de documentos teste e seus rótulos.
    documentos_teste = df_dados_test.documento.values
    classes_teste = df_dados_test.classe.values
    id_documentos_teste = df_dados_test.id.values

    del df_dados_train
    del df_dados_test

    # Mostra o resultado dos dados carregados.
    logging.info("Tamanho do conjunto de dados : {} / Treino: {} / Teste: {}.".format(len(documentos_treino) + len(documentos_teste), len(documentos_treino), len(documentos_teste)))
    
    #################  Treinamento

    # Carrega o otimizador
    optimizer = carregaOtimizador(training_args, model)

    # Carrega o agendador
    scheduler = carregaAgendador(training_args, optimizer, numero_etapas=len(documentos_treino))

    # Registra o tempo inicial.
    treinamento_t0 = time.time()
    
    # Realiza o treinamento.
    realizaTreinamento(model, tokenizer, optimizer, scheduler, 
                       documentos_treino, classes_treino, id_documentos_treino, 
                       documentos_teste, classes_teste, id_documentos_teste, training_args.num_train_epochs)
    
    # Medida de quanto tempo levou a execução do treinamento.
    treinamento_f = time.time()
    treinamento_total = formataTempo(treinamento_f - treinamento_t0)  
    logging.info("  Tempo total treinamento       : {:}.".format(treinamento_total))
    
    #################  Treinamento

    # Apaga os dados
    del documentos_treino
    del classes_treino
    del id_documentos_treino
    
    del documentos_teste
    del classes_teste
    del id_documentos_teste

    del optimizer
    del scheduler
    del model
    del tokenizer

    # Pega o tempo atual menos o tempo do início do processamento.
    processamento_fold_f = time.time()
    processamento_fold_total = formataTempo(processamento_fold_f - processamento_fold_t0)    
    logging.info("  Tempo processamento fold: {:} (h:mm:ss)\n".format(processamento_fold_total))    

    # Chama o coletor de lixo para esvaziar a memória
    gc.collect()

# %% [markdown]
# ## 5.2 Execução o procedimento de treinamento e avaliação para todos os parâmetros

# %%
# Import das bibliotecas
from tqdm.notebook import tqdm as tqdm_notebook

# Barra de progresso modelos
modelo_bar = tqdm_notebook(enumerate(NOMES_MODELO), desc=f'Modelos ', unit=f'modelo', total=len(NOMES_MODELO))

# Percorre todos os modelos a serem avaliados
for modelo_i, modelo in modelo_bar:

  # Seta o parâmetro do modelo
  model_args.pretrained_model_name_or_path = modelo

  # Barra de progresso das taxas de aprendizagem
  taxa_de_aprendizagem_bar = tqdm_notebook(enumerate(TAXAS_DE_APRENDIZAGEM), desc=f'Taxas de aprendizagem ', unit=f'taxa', total=len(TAXAS_DE_APRENDIZAGEM))

  # Executa o treinamento e avaliação para diversas taxas de aprendizagem
  for taxas_de_aprendizagem_i, taxa_de_aprendizagem in taxa_de_aprendizagem_bar:

    # Atualiza a taxa de aprendizagem da avaliação
    training_args.learning_rate = taxa_de_aprendizagem

    # Marca o tempo de início do processamento dos folds
    processamento_todos_fold_t0 = time.time()

    # Executa o treinamento e avaliacao de todos folds para o modelo e taxa de aprendizagem
    procedimentoTreinamentoAvaliacaoFolds(modelo, taxa_de_aprendizagem)

    # Pega o tempo atual menos o tempo do início do processamento.
    processamento_todos_fold_f = time.time()
    processamento_todos_fold_total = formataTempo(processamento_todos_fold_f - processamento_todos_fold_t0)    
    logging.info("  Tempo processamento de todos os folds: {:} (h:mm:ss)\n".format(processamento_todos_fold_total))
# Out:
# Modelos :   0%|          | 0/1 [00:00<?, ?modelo/s]
# Taxas de aprendizagem :   0%|          | 0/1 [00:00<?, ?taxa/s]
# Folds :   0%|          | 0/10 [00:00<?, ?fold/s]
# 2022-05-02 23:51:41,561 : INFO : Processamendo do fold: 9.
# 2022-05-02 23:51:41,565 : INFO :    com o modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-02 23:51:41,566 : INFO :    até época 4 e taxa de aprendizagem 4e-05.
# 2022-05-02 23:51:41,567 : INFO : Variável URL_MODELO não setada.
# 2022-05-02 23:51:41,570 : INFO : Usando modelo BERT pré-treinado.
# 2022-05-02 23:51:41,571 : INFO : Carregando o modelo BERT da comunidade neuralmind/bert-large-portuguese-cased para classificação.
# Downloading:   0%|          | 0.00/648 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at neuralmind/bert-large-portuguese-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-large-portuguese-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2022-05-02 23:53:01,062 : INFO : Existem 1 GPU(s) disponíveis.
# 2022-05-02 23:53:01,063 : INFO : Iremos usar a GPU: Tesla P100-PCIE-16GB.
# 2022-05-02 23:53:01,467 : INFO : Pytorch rodando o modelo na GPU.
# 2022-05-02 23:53:01,475 : INFO : Carregando o tokenizador BERT do diretório neuralmind/bert-large-portuguese-cased.
# Downloading:   0%|          | 0.00/210k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/155 [00:00<?, ?B/s]
# 2022-05-02 23:53:09,102 : INFO : Pytorch rodando o modelo na GPU.
# 2022-05-02 23:53:09,111 : INFO : Carregando os arquivos do fold de treino e avaliação.
# 2022-05-02 23:53:09,114 : INFO : Carregando arquivo de treino: /content/validacao_kfold/SQUAD2_P_Train_f9.csv.
# 2022-05-02 23:53:09,115 : INFO : Carregando arquivo de teste: /content/validacao_kfold/SQUAD2_P_Test_f9.csv.
# 2022-05-02 23:53:09,542 : INFO : Descartando documentos grandes dos conjuntos de dados.
# 2022-05-02 23:54:29,066 : INFO : Tamanho do conjunto de dados : 283800 / Treino: 255420 / Teste: 28380.
# 2022-05-02 23:54:29,069 : INFO : Total de etapas: 1021680
# Épocas:   0%|          | 0/4 [00:00<?, ?épocas/s]
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: osmar-braz (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220502_235433-3999uc7o</code>
# Syncing run <strong><a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/3999uc7o" target="_blank">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f9</a></strong> to <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-05-02 23:54:40,043 : INFO : Realizando treinamento do fold 9 na época: 1.
# 2022-05-02 23:54:40,045 : INFO : Criando Lotes Inteligentes de 255,420 amostras com tamanho de lote 16...
# 2022-05-02 23:54:40,048 : INFO : Tokenizando 255,420 amostra...
# Documentos :   0%|          | 0/255420 [00:00<?, ?documento/s]
# 2022-05-02 23:55:56,301 : INFO :    255,420 amostras tokenizadas.
# 2022-05-02 23:55:56,656 : INFO :    255,420 amostras após classificação.
# 2022-05-02 23:55:56,657 : INFO : Criando lotes de tamanho 16...
# 2022-05-02 23:55:56,994 : INFO :   FEITO - Selecionado 15,964 lotes.
# 2022-05-02 23:55:56,995 : INFO : Preenchendo sequências dentro de cada lote...
# Epoca 1:   0%|          | 0/15964 [00:00<?, ?lotes/s]
# 2022-05-03 00:41:55,759 : INFO :    Média perda(loss) do treinamento da época : 0.66527893.
# 2022-05-03 00:41:55,763 : INFO :    Tempo de treinamento da época             : 0:45:56.
# 2022-05-03 00:41:55,767 : INFO :    Tempo parcial processamento               : 0:47:27 (h:mm:ss)
# 2022-05-03 00:41:55,769 : INFO : Realizando avaliação do fold 9 na época: 1.
# 2022-05-03 00:41:55,770 : INFO : Criando Lotes Inteligentes de 28,380 amostras com tamanho de lote 16...
# 2022-05-03 00:41:55,772 : INFO : Tokenizando 28,380 amostra...
# Documentos :   0%|          | 0/28380 [00:00<?, ?documento/s]
# 2022-05-03 00:42:04,453 : INFO :     28,380 amostras tokenizadas.
# 2022-05-03 00:42:04,475 : INFO :     28,380 amostras após classificação.
# 2022-05-03 00:42:04,476 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 00:42:04,493 : INFO :   FEITO - Selecionado 1,774 lotes.
# 2022-05-03 00:42:04,494 : INFO : Preenchendo sequências dentro de cada lote...
# Lotes :   0%|          | 0/1774 [00:00<?, ?lotes/s]
# 2022-05-03 00:43:09,952 : INFO :    Avaliação loss: 0.69466833; Acc: 0.50000000; Rec: 1.00000000; Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:   0; fp: 14190; fn:   0
# 2022-05-03 00:43:09,954 : INFO :    Acurácia do fold 9 na época 1: 0.50000000.
# 2022-05-03 00:43:09,956 : INFO :    Média perda(loss) do avaliação da época   : 0.69466833.
# 2022-05-03 00:43:09,958 : INFO :    Tempo de avaliação da época               : 0:01:14.
# 2022-05-03 00:43:09,960 : INFO :    Tempo parcial do processamento            : 0:48:41 (h:mm:ss)
# 2022-05-03 00:43:09,969 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/.
# 2022-05-03 00:43:17,989 : INFO : Criando arquivo classificação: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f9_BERTimbau_large.csv.
# 2022-05-03 00:43:18,353 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/.
# 2022-05-03 00:43:24,946 : INFO : Criando arquivo resultado: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f9_BERTimbau_large.csv.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>▁</td></tr><tr><td>do_lower_case</td><td>▁</td></tr><tr><td>fn</td><td>▁</td></tr><tr><td>fp</td><td>▁</td></tr><tr><td>max_seq_len</td><td>▁</td></tr><tr><td>media_test_epoca_loss</td><td>▁</td></tr><tr><td>media_train_epoca_loss</td><td>▁</td></tr><tr><td>output_hidden_states</td><td>▁</td></tr><tr><td>test_batch_loss</td><td>▂█▆▃▃▃▅▃▃▃▃▃▃▂▃▃▃▂▂▄▃▃▃▅▃▄▃▁▃▃▅▃▃▂▃▄▃▃▃▄</td></tr><tr><td>train_batch_loss</td><td>▆▃▄█▃▁▅▅▂▅▁█▁▅▁▂▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>vn</td><td>▁</td></tr><tr><td>vp</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>0.5</td></tr><tr><td>do_lower_case</td><td>False</td></tr><tr><td>fn</td><td>0</td></tr><tr><td>fp</td><td>14190</td></tr><tr><td>max_seq_len</td><td>512</td></tr><tr><td>media_test_epoca_loss</td><td>0.69467</td></tr><tr><td>media_train_epoca_loss</td><td>0.66528</td></tr><tr><td>nome_execucao</td><td>AjusteFinoSquad2_P_C...</td></tr><tr><td>output_hidden_states</td><td>False</td></tr><tr><td>tempo_test</td><td>0:01:14</td></tr><tr><td>tempo_train</td><td>0:45:56</td></tr><tr><td>test_batch_loss</td><td>0.70386</td></tr><tr><td>train_batch_loss</td><td>0.68929</td></tr><tr><td>vn</td><td>0</td></tr><tr><td>vp</td><td>14190</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f9</strong>: <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/3999uc7o" target="_blank">https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/3999uc7o</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220502_235433-3999uc7o/logs</code>
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220503_004451-18ti9y3g</code>
# Syncing run <strong><a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/18ti9y3g" target="_blank">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_f9</a></strong> to <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-05-03 00:44:57,246 : INFO : Realizando treinamento do fold 9 na época: 2.
# 2022-05-03 00:44:57,247 : INFO : Criando Lotes Inteligentes de 255,420 amostras com tamanho de lote 16...
# 2022-05-03 00:44:57,252 : INFO : Tokenizando 255,420 amostra...
# Documentos :   0%|          | 0/255420 [00:00<?, ?documento/s]
# 2022-05-03 00:46:13,361 : INFO :    255,420 amostras tokenizadas.
# 2022-05-03 00:46:13,740 : INFO :    255,420 amostras após classificação.
# 2022-05-03 00:46:13,742 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 00:46:14,080 : INFO :   FEITO - Selecionado 15,964 lotes.
# 2022-05-03 00:46:14,081 : INFO : Preenchendo sequências dentro de cada lote...
# Epoca 2:   0%|          | 0/15964 [00:00<?, ?lotes/s]
# 2022-05-03 01:33:01,330 : INFO :    Média perda(loss) do treinamento da época : 0.69354708.
# 2022-05-03 01:33:01,333 : INFO :    Tempo de treinamento da época             : 0:46:45.
# 2022-05-03 01:33:01,335 : INFO :    Tempo parcial processamento               : 1:38:32 (h:mm:ss)
# 2022-05-03 01:33:01,337 : INFO : Realizando avaliação do fold 9 na época: 2.
# 2022-05-03 01:33:01,339 : INFO : Criando Lotes Inteligentes de 28,380 amostras com tamanho de lote 16...
# 2022-05-03 01:33:01,341 : INFO : Tokenizando 28,380 amostra...
# Documentos :   0%|          | 0/28380 [00:00<?, ?documento/s]
# 2022-05-03 01:33:18,103 : INFO :     28,380 amostras tokenizadas.
# 2022-05-03 01:33:18,132 : INFO :     28,380 amostras após classificação.
# 2022-05-03 01:33:18,138 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 01:33:18,169 : INFO :   FEITO - Selecionado 1,774 lotes.
# 2022-05-03 01:33:18,174 : INFO : Preenchendo sequências dentro de cada lote...
# Lotes :   0%|          | 0/1774 [00:00<?, ?lotes/s]
# 2022-05-03 01:34:23,592 : INFO :    Avaliação loss: 0.69488953; Acc: 0.50000000; Rec: 0.00000000; Pre: 0.00000000, F1:0.00000000, vp:   0; vn: 14190; fp:   0; fn: 14190
# 2022-05-03 01:34:23,593 : INFO :    Acurácia do fold 9 na época 2: 0.50000000.
# 2022-05-03 01:34:23,597 : INFO :    Média perda(loss) do avaliação da época   : 0.69488953.
# 2022-05-03 01:34:23,599 : INFO :    Tempo de avaliação da época               : 0:01:22.
# 2022-05-03 01:34:23,600 : INFO :    Tempo parcial do processamento            : 1:39:55 (h:mm:ss)
# 2022-05-03 01:34:23,602 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/.
# 2022-05-03 01:34:27,268 : INFO : Criando arquivo classificação: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_f9_BERTimbau_large.csv.
# 2022-05-03 01:34:27,625 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/.
# 2022-05-03 01:34:27,632 : INFO : Criando arquivo resultado: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_f9_BERTimbau_large.csv.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>▁</td></tr><tr><td>do_lower_case</td><td>▁</td></tr><tr><td>fn</td><td>▁</td></tr><tr><td>fp</td><td>▁</td></tr><tr><td>max_seq_len</td><td>▁</td></tr><tr><td>media_test_epoca_loss</td><td>▁</td></tr><tr><td>media_train_epoca_loss</td><td>▁</td></tr><tr><td>output_hidden_states</td><td>▁</td></tr><tr><td>test_batch_loss</td><td>▆▇▆▆▆▆▆▆█▆▇▁▆▆▆▆▃▆▆▇▅▇▆▆▆▆▆▆▆▅▆▆▆▆▇▆▆▂▆▆</td></tr><tr><td>train_batch_loss</td><td>▄▄▄▅▄▄▄▅▄▃▄▄▄▄▄▄▄▄▄▄▄▄▅▂▁▄▄▃▄█▄█▄▄▄▅▄▅▅▄</td></tr><tr><td>vn</td><td>▁</td></tr><tr><td>vp</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>0.5</td></tr><tr><td>do_lower_case</td><td>False</td></tr><tr><td>fn</td><td>14190</td></tr><tr><td>fp</td><td>0</td></tr><tr><td>max_seq_len</td><td>512</td></tr><tr><td>media_test_epoca_loss</td><td>0.69489</td></tr><tr><td>media_train_epoca_loss</td><td>0.69355</td></tr><tr><td>nome_execucao</td><td>AjusteFinoSquad2_P_C...</td></tr><tr><td>output_hidden_states</td><td>False</td></tr><tr><td>tempo_test</td><td>0:01:22</td></tr><tr><td>tempo_train</td><td>0:46:45</td></tr><tr><td>test_batch_loss</td><td>0.67519</td></tr><tr><td>train_batch_loss</td><td>0.67159</td></tr><tr><td>vn</td><td>14190</td></tr><tr><td>vp</td><td>0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_f9</strong>: <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/18ti9y3g" target="_blank">https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/18ti9y3g</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220503_004451-18ti9y3g/logs</code>
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220503_015047-hk4dznbx</code>
# Syncing run <strong><a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/hk4dznbx" target="_blank">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_f9</a></strong> to <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-05-03 01:50:54,535 : INFO : Realizando treinamento do fold 9 na época: 3.
# 2022-05-03 01:50:54,538 : INFO : Criando Lotes Inteligentes de 255,420 amostras com tamanho de lote 16...
# 2022-05-03 01:50:54,540 : INFO : Tokenizando 255,420 amostra...
# Documentos :   0%|          | 0/255420 [00:00<?, ?documento/s]
# 2022-05-03 01:52:10,781 : INFO :    255,420 amostras tokenizadas.
# 2022-05-03 01:52:11,180 : INFO :    255,420 amostras após classificação.
# 2022-05-03 01:52:11,182 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 01:52:11,519 : INFO :   FEITO - Selecionado 15,964 lotes.
# 2022-05-03 01:52:11,520 : INFO : Preenchendo sequências dentro de cada lote...
# Epoca 3:   0%|          | 0/15964 [00:00<?, ?lotes/s]
# 2022-05-03 02:39:33,135 : INFO :    Média perda(loss) do treinamento da época : 0.69345127.
# 2022-05-03 02:39:33,139 : INFO :    Tempo de treinamento da época             : 0:47:19.
# 2022-05-03 02:39:33,143 : INFO :    Tempo parcial processamento               : 2:45:04 (h:mm:ss)
# 2022-05-03 02:39:33,145 : INFO : Realizando avaliação do fold 9 na época: 3.
# 2022-05-03 02:39:33,147 : INFO : Criando Lotes Inteligentes de 28,380 amostras com tamanho de lote 16...
# 2022-05-03 02:39:33,149 : INFO : Tokenizando 28,380 amostra...
# Documentos :   0%|          | 0/28380 [00:00<?, ?documento/s]
# 2022-05-03 02:39:50,228 : INFO :     28,380 amostras tokenizadas.
# 2022-05-03 02:39:50,259 : INFO :     28,380 amostras após classificação.
# 2022-05-03 02:39:50,261 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 02:39:50,289 : INFO :   FEITO - Selecionado 1,774 lotes.
# 2022-05-03 02:39:50,291 : INFO : Preenchendo sequências dentro de cada lote...
# Lotes :   0%|          | 0/1774 [00:00<?, ?lotes/s]
# 2022-05-03 02:40:56,597 : INFO :    Avaliação loss: 0.69363077; Acc: 0.50000000; Rec: 0.00000000; Pre: 0.00000000, F1:0.00000000, vp:   0; vn: 14190; fp:   0; fn: 14190
# 2022-05-03 02:40:56,612 : INFO :    Acurácia do fold 9 na época 3: 0.50000000.
# 2022-05-03 02:40:56,621 : INFO :    Média perda(loss) do avaliação da época   : 0.69363077.
# 2022-05-03 02:40:56,622 : INFO :    Tempo de avaliação da época               : 0:01:23.
# 2022-05-03 02:40:56,626 : INFO :    Tempo parcial do processamento            : 2:46:28 (h:mm:ss)
# 2022-05-03 02:40:56,632 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/.
# 2022-05-03 02:41:00,027 : INFO : Criando arquivo classificação: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_f9_BERTimbau_large.csv.
# 2022-05-03 02:41:00,391 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/.
# 2022-05-03 02:41:00,393 : INFO : Criando arquivo resultado: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_f9_BERTimbau_large.csv.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>▁</td></tr><tr><td>do_lower_case</td><td>▁</td></tr><tr><td>fn</td><td>▁</td></tr><tr><td>fp</td><td>▁</td></tr><tr><td>max_seq_len</td><td>▁</td></tr><tr><td>media_test_epoca_loss</td><td>▁</td></tr><tr><td>media_train_epoca_loss</td><td>▁</td></tr><tr><td>output_hidden_states</td><td>▁</td></tr><tr><td>test_batch_loss</td><td>█▅▅▄▇▅▅▃▅▅▅▅▁▇▅▆▅▆▅▄▇▅▆▅▅▅▄▄▅▅▃▆▅▅▅▇▆▅▅▅</td></tr><tr><td>train_batch_loss</td><td>▃▃▂▅▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▃▂▂▃▂▃▂▂▃▃▂▂█▄</td></tr><tr><td>vn</td><td>▁</td></tr><tr><td>vp</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>0.5</td></tr><tr><td>do_lower_case</td><td>False</td></tr><tr><td>fn</td><td>14190</td></tr><tr><td>fp</td><td>0</td></tr><tr><td>max_seq_len</td><td>512</td></tr><tr><td>media_test_epoca_loss</td><td>0.69363</td></tr><tr><td>media_train_epoca_loss</td><td>0.69345</td></tr><tr><td>nome_execucao</td><td>AjusteFinoSquad2_P_C...</td></tr><tr><td>output_hidden_states</td><td>False</td></tr><tr><td>tempo_test</td><td>0:01:23</td></tr><tr><td>tempo_train</td><td>0:47:19</td></tr><tr><td>test_batch_loss</td><td>0.69363</td></tr><tr><td>train_batch_loss</td><td>0.7031</td></tr><tr><td>vn</td><td>14190</td></tr><tr><td>vp</td><td>0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_f9</strong>: <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/hk4dznbx" target="_blank">https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/hk4dznbx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220503_015047-hk4dznbx/logs</code>
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220503_031935-3silmkmi</code>
# Syncing run <strong><a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/3silmkmi" target="_blank">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f9</a></strong> to <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-05-03 03:19:41,926 : INFO : Realizando treinamento do fold 9 na época: 4.
# 2022-05-03 03:19:41,927 : INFO : Criando Lotes Inteligentes de 255,420 amostras com tamanho de lote 16...
# 2022-05-03 03:19:41,930 : INFO : Tokenizando 255,420 amostra...
# Documentos :   0%|          | 0/255420 [00:00<?, ?documento/s]
# 2022-05-03 03:20:59,287 : INFO :    255,420 amostras tokenizadas.
# 2022-05-03 03:20:59,686 : INFO :    255,420 amostras após classificação.
# 2022-05-03 03:20:59,687 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 03:21:00,034 : INFO :   FEITO - Selecionado 15,964 lotes.
# 2022-05-03 03:21:00,035 : INFO : Preenchendo sequências dentro de cada lote...
# Epoca 4:   0%|          | 0/15964 [00:00<?, ?lotes/s]
# 2022-05-03 04:08:55,498 : INFO :    Média perda(loss) do treinamento da época : 0.69339644.
# 2022-05-03 04:08:55,502 : INFO :    Tempo de treinamento da época             : 0:47:53.
# 2022-05-03 04:08:55,506 : INFO :    Tempo parcial processamento               : 4:14:26 (h:mm:ss)
# 2022-05-03 04:08:55,513 : INFO : Realizando avaliação do fold 9 na época: 4.
# 2022-05-03 04:08:55,518 : INFO : Criando Lotes Inteligentes de 28,380 amostras com tamanho de lote 16...
# 2022-05-03 04:08:55,522 : INFO : Tokenizando 28,380 amostra...
# Documentos :   0%|          | 0/28380 [00:00<?, ?documento/s]
# 2022-05-03 04:09:12,881 : INFO :     28,380 amostras tokenizadas.
# 2022-05-03 04:09:12,908 : INFO :     28,380 amostras após classificação.
# 2022-05-03 04:09:12,913 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 04:09:12,937 : INFO :   FEITO - Selecionado 1,774 lotes.
# 2022-05-03 04:09:12,942 : INFO : Preenchendo sequências dentro de cada lote...
# Lotes :   0%|          | 0/1774 [00:00<?, ?lotes/s]
# 2022-05-03 04:10:19,031 : INFO :    Avaliação loss: 0.69818728; Acc: 0.50000000; Rec: 1.00000000; Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:   0; fp: 14190; fn:   0
# 2022-05-03 04:10:19,044 : INFO :    Acurácia do fold 9 na época 4: 0.50000000.
# 2022-05-03 04:10:19,046 : INFO :    Média perda(loss) do avaliação da época   : 0.69818728.
# 2022-05-03 04:10:19,050 : INFO :    Tempo de avaliação da época               : 0:01:24.
# 2022-05-03 04:10:19,051 : INFO :    Tempo parcial do processamento            : 4:15:50 (h:mm:ss)
# 2022-05-03 04:10:19,054 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/.
# 2022-05-03 04:10:22,326 : INFO : Criando arquivo classificação: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f9_BERTimbau_large.csv.
# 2022-05-03 04:10:22,669 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/.
# 2022-05-03 04:10:22,671 : INFO : Criando arquivo resultado: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f9_BERTimbau_large.csv.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>▁</td></tr><tr><td>do_lower_case</td><td>▁</td></tr><tr><td>fn</td><td>▁</td></tr><tr><td>fp</td><td>▁</td></tr><tr><td>max_seq_len</td><td>▁</td></tr><tr><td>media_test_epoca_loss</td><td>▁</td></tr><tr><td>media_train_epoca_loss</td><td>▁</td></tr><tr><td>output_hidden_states</td><td>▁</td></tr><tr><td>test_batch_loss</td><td>▂▄▃▃▄▃▃▃▃▂▄▂▁▂▃▅▃▇▃▃█▃▃▄▅▃▃▃▂▄▃▃▂▃▄▃▂▂▄▄</td></tr><tr><td>train_batch_loss</td><td>▅▅▅▅▅▅▅▅▅▅▅▅▅█▅▄▄▅▅▅▅▅▅▅▄▅▅▅▅▅▄▅▅▅▅▁▅█▄▅</td></tr><tr><td>vn</td><td>▁</td></tr><tr><td>vp</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>0.5</td></tr><tr><td>do_lower_case</td><td>False</td></tr><tr><td>fn</td><td>0</td></tr><tr><td>fp</td><td>14190</td></tr><tr><td>max_seq_len</td><td>512</td></tr><tr><td>media_test_epoca_loss</td><td>0.69819</td></tr><tr><td>media_train_epoca_loss</td><td>0.6934</td></tr><tr><td>nome_execucao</td><td>AjusteFinoSquad2_P_C...</td></tr><tr><td>output_hidden_states</td><td>False</td></tr><tr><td>tempo_test</td><td>0:01:24</td></tr><tr><td>tempo_train</td><td>0:47:53</td></tr><tr><td>test_batch_loss</td><td>0.74839</td></tr><tr><td>train_batch_loss</td><td>0.69767</td></tr><tr><td>vn</td><td>0</td></tr><tr><td>vp</td><td>14190</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f9</strong>: <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/3silmkmi" target="_blank">https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/3silmkmi</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220503_031935-3silmkmi/logs</code>
# 2022-05-03 05:11:53,052 : INFO :   Média perda(loss) treinamento : 0.68641843.
# 2022-05-03 05:11:53,062 : INFO :   Média perda(loss) avaliação   : 0.69534398.
# 2022-05-03 05:11:53,074 : INFO :   Tempo total treinamento       : 5:17:24.
# 2022-05-03 05:11:53,084 : INFO :   Tempo processamento fold: 5:20:12 (h:mm:ss)
#
# 2022-05-03 05:11:53,263 : INFO : Processamendo do fold: 10.
# 2022-05-03 05:11:53,270 : INFO :    com o modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 05:11:53,274 : INFO :    até época 4 e taxa de aprendizagem 4e-05.
# 2022-05-03 05:11:53,281 : INFO : Variável URL_MODELO não setada.
# 2022-05-03 05:11:53,283 : INFO : Usando modelo BERT pré-treinado.
# 2022-05-03 05:11:53,284 : INFO : Carregando o modelo BERT da comunidade neuralmind/bert-large-portuguese-cased para classificação.
# Some weights of the model checkpoint at neuralmind/bert-large-portuguese-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-large-portuguese-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2022-05-03 05:12:03,068 : INFO : Existem 1 GPU(s) disponíveis.
# 2022-05-03 05:12:03,069 : INFO : Iremos usar a GPU: Tesla P100-PCIE-16GB.
# 2022-05-03 05:12:03,439 : INFO : Pytorch rodando o modelo na GPU.
# 2022-05-03 05:12:03,446 : INFO : Carregando o tokenizador BERT do diretório neuralmind/bert-large-portuguese-cased.
# 2022-05-03 05:12:07,252 : INFO : Pytorch rodando o modelo na GPU.
# 2022-05-03 05:12:07,261 : INFO : Carregando os arquivos do fold de treino e avaliação.
# 2022-05-03 05:12:07,262 : INFO : Carregando arquivo de treino: /content/validacao_kfold/SQUAD2_P_Train_f10.csv.
# 2022-05-03 05:12:07,266 : INFO : Carregando arquivo de teste: /content/validacao_kfold/SQUAD2_P_Test_f10.csv.
# 2022-05-03 05:12:07,712 : INFO : Descartando documentos grandes dos conjuntos de dados.
# 2022-05-03 05:13:26,157 : INFO : Tamanho do conjunto de dados : 283800 / Treino: 255420 / Teste: 28380.
# 2022-05-03 05:13:26,160 : INFO : Total de etapas: 1021680
# Épocas:   0%|          | 0/4 [00:00<?, ?épocas/s]
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220503_051327-2skqbtpe</code>
# Syncing run <strong><a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/2skqbtpe" target="_blank">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f10</a></strong> to <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-05-03 05:13:33,926 : INFO : Realizando treinamento do fold 10 na época: 1.
# 2022-05-03 05:13:33,928 : INFO : Criando Lotes Inteligentes de 255,420 amostras com tamanho de lote 16...
# 2022-05-03 05:13:33,933 : INFO : Tokenizando 255,420 amostra...
# Documentos :   0%|          | 0/255420 [00:00<?, ?documento/s]
# 2022-05-03 05:14:51,904 : INFO :    255,420 amostras tokenizadas.
# 2022-05-03 05:14:52,513 : INFO :    255,420 amostras após classificação.
# 2022-05-03 05:14:52,519 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 05:14:52,858 : INFO :   FEITO - Selecionado 15,964 lotes.
# 2022-05-03 05:14:52,859 : INFO : Preenchendo sequências dentro de cada lote...
# Epoca 1:   0%|          | 0/15964 [00:00<?, ?lotes/s]
# 2022-05-03 06:01:09,002 : INFO :    Média perda(loss) do treinamento da época : 0.69824357.
# 2022-05-03 06:01:09,004 : INFO :    Tempo de treinamento da época             : 0:46:14.
# 2022-05-03 06:01:09,006 : INFO :    Tempo parcial processamento               : 0:47:43 (h:mm:ss)
# 2022-05-03 06:01:09,008 : INFO : Realizando avaliação do fold 10 na época: 1.
# 2022-05-03 06:01:09,010 : INFO : Criando Lotes Inteligentes de 28,380 amostras com tamanho de lote 16...
# 2022-05-03 06:01:09,011 : INFO : Tokenizando 28,380 amostra...
# Documentos :   0%|          | 0/28380 [00:00<?, ?documento/s]
# 2022-05-03 06:01:18,047 : INFO :     28,380 amostras tokenizadas.
# 2022-05-03 06:01:18,071 : INFO :     28,380 amostras após classificação.
# 2022-05-03 06:01:18,072 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 06:01:18,089 : INFO :   FEITO - Selecionado 1,774 lotes.
# 2022-05-03 06:01:18,090 : INFO : Preenchendo sequências dentro de cada lote...
# Lotes :   0%|          | 0/1774 [00:00<?, ?lotes/s]
# 2022-05-03 06:02:24,272 : INFO :    Avaliação loss: 0.69447803; Acc: 0.50000000; Rec: 0.00000000; Pre: 0.00000000, F1:0.00000000, vp:   0; vn: 14190; fp:   0; fn: 14190
# 2022-05-03 06:02:24,273 : INFO :    Acurácia do fold 10 na época 1: 0.50000000.
# 2022-05-03 06:02:24,277 : INFO :    Média perda(loss) do avaliação da época   : 0.69447803.
# 2022-05-03 06:02:24,283 : INFO :    Tempo de avaliação da época               : 0:01:15.
# 2022-05-03 06:02:24,284 : INFO :    Tempo parcial do processamento            : 0:48:58 (h:mm:ss)
# 2022-05-03 06:02:24,291 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/.
# 2022-05-03 06:02:27,502 : INFO : Criando arquivo classificação: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f10_BERTimbau_large.csv.
# 2022-05-03 06:02:27,851 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/.
# 2022-05-03 06:02:27,857 : INFO : Criando arquivo resultado: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f10_BERTimbau_large.csv.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>▁</td></tr><tr><td>do_lower_case</td><td>▁</td></tr><tr><td>fn</td><td>▁</td></tr><tr><td>fp</td><td>▁</td></tr><tr><td>max_seq_len</td><td>▁</td></tr><tr><td>media_test_epoca_loss</td><td>▁</td></tr><tr><td>media_train_epoca_loss</td><td>▁</td></tr><tr><td>output_hidden_states</td><td>▁</td></tr><tr><td>test_batch_loss</td><td>█▁▅▅▅▅▅▅▂▅▅▅▅▅▃▅▅▅▅▅▅▂▂▅▆▆▅▅▄▅▅▅▅▅▅▄▄▃▆▅</td></tr><tr><td>train_batch_loss</td><td>▆█▁▇▇▆▇▇▇▇▆▇▇▇▇▆▆▇▇▇▆▇▇▆▇▇▆▇▇▇▇█▇▇▆▇▇▇▇▇</td></tr><tr><td>vn</td><td>▁</td></tr><tr><td>vp</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>0.5</td></tr><tr><td>do_lower_case</td><td>False</td></tr><tr><td>fn</td><td>14190</td></tr><tr><td>fp</td><td>0</td></tr><tr><td>max_seq_len</td><td>512</td></tr><tr><td>media_test_epoca_loss</td><td>0.69448</td></tr><tr><td>media_train_epoca_loss</td><td>0.69824</td></tr><tr><td>nome_execucao</td><td>AjusteFinoSquad2_P_C...</td></tr><tr><td>output_hidden_states</td><td>False</td></tr><tr><td>tempo_test</td><td>0:01:15</td></tr><tr><td>tempo_train</td><td>0:46:14</td></tr><tr><td>test_batch_loss</td><td>0.69448</td></tr><tr><td>train_batch_loss</td><td>0.70879</td></tr><tr><td>vn</td><td>14190</td></tr><tr><td>vp</td><td>0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f10</strong>: <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/2skqbtpe" target="_blank">https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/2skqbtpe</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220503_051327-2skqbtpe/logs</code>
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220503_060403-7xkun32s</code>
# Syncing run <strong><a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/7xkun32s" target="_blank">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_f10</a></strong> to <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-05-03 06:04:09,533 : INFO : Realizando treinamento do fold 10 na época: 2.
# 2022-05-03 06:04:09,534 : INFO : Criando Lotes Inteligentes de 255,420 amostras com tamanho de lote 16...
# 2022-05-03 06:04:09,539 : INFO : Tokenizando 255,420 amostra...
# Documentos :   0%|          | 0/255420 [00:00<?, ?documento/s]
# 2022-05-03 06:05:27,307 : INFO :    255,420 amostras tokenizadas.
# 2022-05-03 06:05:27,972 : INFO :    255,420 amostras após classificação.
# 2022-05-03 06:05:27,973 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 06:05:28,326 : INFO :   FEITO - Selecionado 15,964 lotes.
# 2022-05-03 06:05:28,327 : INFO : Preenchendo sequências dentro de cada lote...
# Epoca 2:   0%|          | 0/15964 [00:00<?, ?lotes/s]
# 2022-05-03 06:52:22,620 : INFO :    Média perda(loss) do treinamento da época : 0.69348549.
# 2022-05-03 06:52:22,622 : INFO :    Tempo de treinamento da época             : 0:46:52.
# 2022-05-03 06:52:22,630 : INFO :    Tempo parcial processamento               : 1:38:56 (h:mm:ss)
# 2022-05-03 06:52:22,634 : INFO : Realizando avaliação do fold 10 na época: 2.
# 2022-05-03 06:52:22,641 : INFO : Criando Lotes Inteligentes de 28,380 amostras com tamanho de lote 16...
# 2022-05-03 06:52:22,645 : INFO : Tokenizando 28,380 amostra...
# Documentos :   0%|          | 0/28380 [00:00<?, ?documento/s]
# 2022-05-03 06:52:39,988 : INFO :     28,380 amostras tokenizadas.
# 2022-05-03 06:52:40,017 : INFO :     28,380 amostras após classificação.
# 2022-05-03 06:52:40,021 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 06:52:40,046 : INFO :   FEITO - Selecionado 1,774 lotes.
# 2022-05-03 06:52:40,050 : INFO : Preenchendo sequências dentro de cada lote...
# Lotes :   0%|          | 0/1774 [00:00<?, ?lotes/s]
# 2022-05-03 06:53:46,643 : INFO :    Avaliação loss: 0.70014114; Acc: 0.50000000; Rec: 1.00000000; Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:   0; fp: 14190; fn:   0
# 2022-05-03 06:53:46,645 : INFO :    Acurácia do fold 10 na época 2: 0.50000000.
# 2022-05-03 06:53:46,651 : INFO :    Média perda(loss) do avaliação da época   : 0.70014114.
# 2022-05-03 06:53:46,653 : INFO :    Tempo de avaliação da época               : 0:01:24.
# 2022-05-03 06:53:46,658 : INFO :    Tempo parcial do processamento            : 1:40:20 (h:mm:ss)
# 2022-05-03 06:53:46,661 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/.
# 2022-05-03 06:53:49,865 : INFO : Criando arquivo classificação: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_f10_BERTimbau_large.csv.
# 2022-05-03 06:53:50,226 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/.
# 2022-05-03 06:53:50,234 : INFO : Criando arquivo resultado: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_f10_BERTimbau_large.csv.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>▁</td></tr><tr><td>do_lower_case</td><td>▁</td></tr><tr><td>fn</td><td>▁</td></tr><tr><td>fp</td><td>▁</td></tr><tr><td>max_seq_len</td><td>▁</td></tr><tr><td>media_test_epoca_loss</td><td>▁</td></tr><tr><td>media_train_epoca_loss</td><td>▁</td></tr><tr><td>output_hidden_states</td><td>▁</td></tr><tr><td>test_batch_loss</td><td>▃▄▆▄▄▄▆▃▁▄▄█▄▇▃▄▄▄▄▆▆▄▂▄▄▃▃▄▅▄█▄▃▄▄▄▄▁▄▅</td></tr><tr><td>train_batch_loss</td><td>▇▇▇▇▇█▇▇▇█▇▇▇▇▇▇▇▇▇▇▄▇▇▇▇▇▇▇▇▇▇▇▇▇▁▅▇▇▇▇</td></tr><tr><td>vn</td><td>▁</td></tr><tr><td>vp</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>0.5</td></tr><tr><td>do_lower_case</td><td>False</td></tr><tr><td>fn</td><td>0</td></tr><tr><td>fp</td><td>14190</td></tr><tr><td>max_seq_len</td><td>512</td></tr><tr><td>media_test_epoca_loss</td><td>0.70014</td></tr><tr><td>media_train_epoca_loss</td><td>0.69349</td></tr><tr><td>nome_execucao</td><td>AjusteFinoSquad2_P_C...</td></tr><tr><td>output_hidden_states</td><td>False</td></tr><tr><td>tempo_test</td><td>0:01:24</td></tr><tr><td>tempo_train</td><td>0:46:52</td></tr><tr><td>test_batch_loss</td><td>0.70014</td></tr><tr><td>train_batch_loss</td><td>0.77651</td></tr><tr><td>vn</td><td>0</td></tr><tr><td>vp</td><td>14190</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_f10</strong>: <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/7xkun32s" target="_blank">https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/7xkun32s</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220503_060403-7xkun32s/logs</code>
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220503_070948-26oxan45</code>
# Syncing run <strong><a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/26oxan45" target="_blank">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_f10</a></strong> to <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-05-03 07:09:56,018 : INFO : Realizando treinamento do fold 10 na época: 3.
# 2022-05-03 07:09:56,019 : INFO : Criando Lotes Inteligentes de 255,420 amostras com tamanho de lote 16...
# 2022-05-03 07:09:56,030 : INFO : Tokenizando 255,420 amostra...
# Documentos :   0%|          | 0/255420 [00:00<?, ?documento/s]
# 2022-05-03 07:11:13,671 : INFO :    255,420 amostras tokenizadas.
# 2022-05-03 07:11:14,363 : INFO :    255,420 amostras após classificação.
# 2022-05-03 07:11:14,364 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 07:11:14,709 : INFO :   FEITO - Selecionado 15,964 lotes.
# 2022-05-03 07:11:14,711 : INFO : Preenchendo sequências dentro de cada lote...
# Epoca 3:   0%|          | 0/15964 [00:00<?, ?lotes/s]
# 2022-05-03 07:58:40,153 : INFO :    Média perda(loss) do treinamento da época : 0.69365813.
# 2022-05-03 07:58:40,158 : INFO :    Tempo de treinamento da época             : 0:47:24.
# 2022-05-03 07:58:40,163 : INFO :    Tempo parcial processamento               : 2:45:14 (h:mm:ss)
# 2022-05-03 07:58:40,167 : INFO : Realizando avaliação do fold 10 na época: 3.
# 2022-05-03 07:58:40,169 : INFO : Criando Lotes Inteligentes de 28,380 amostras com tamanho de lote 16...
# 2022-05-03 07:58:40,172 : INFO : Tokenizando 28,380 amostra...
# Documentos :   0%|          | 0/28380 [00:00<?, ?documento/s]
# 2022-05-03 07:58:57,433 : INFO :     28,380 amostras tokenizadas.
# 2022-05-03 07:58:57,467 : INFO :     28,380 amostras após classificação.
# 2022-05-03 07:58:57,469 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 07:58:57,496 : INFO :   FEITO - Selecionado 1,774 lotes.
# 2022-05-03 07:58:57,498 : INFO : Preenchendo sequências dentro de cada lote...
# Lotes :   0%|          | 0/1774 [00:00<?, ?lotes/s]
# 2022-05-03 08:00:03,766 : INFO :    Avaliação loss: 0.69317775; Acc: 0.50000000; Rec: 0.00000000; Pre: 0.00000000, F1:0.00000000, vp:   0; vn: 14190; fp:   0; fn: 14190
# 2022-05-03 08:00:03,772 : INFO :    Acurácia do fold 10 na época 3: 0.50000000.
# 2022-05-03 08:00:03,777 : INFO :    Média perda(loss) do avaliação da época   : 0.69317775.
# 2022-05-03 08:00:03,781 : INFO :    Tempo de avaliação da época               : 0:01:24.
# 2022-05-03 08:00:03,785 : INFO :    Tempo parcial do processamento            : 2:46:38 (h:mm:ss)
# 2022-05-03 08:00:03,795 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/.
# 2022-05-03 08:00:07,014 : INFO : Criando arquivo classificação: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_f10_BERTimbau_large.csv.
# 2022-05-03 08:00:07,421 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/.
# 2022-05-03 08:00:07,430 : INFO : Criando arquivo resultado: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_f10_BERTimbau_large.csv.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>▁</td></tr><tr><td>do_lower_case</td><td>▁</td></tr><tr><td>fn</td><td>▁</td></tr><tr><td>fp</td><td>▁</td></tr><tr><td>max_seq_len</td><td>▁</td></tr><tr><td>media_test_epoca_loss</td><td>▁</td></tr><tr><td>media_train_epoca_loss</td><td>▁</td></tr><tr><td>output_hidden_states</td><td>▁</td></tr><tr><td>test_batch_loss</td><td>▇▄▄▄▆▄▄▄▅▄▇▅▄▄▄▃▄▇▄▁█▂▆▆▄▄▅▅▄▄▃▄▇▄▃▄▃▅▄▄</td></tr><tr><td>train_batch_loss</td><td>▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▂▃▃▁▃▁▃▃▆▃▃▃▄▄▄▄█</td></tr><tr><td>vn</td><td>▁</td></tr><tr><td>vp</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>0.5</td></tr><tr><td>do_lower_case</td><td>False</td></tr><tr><td>fn</td><td>14190</td></tr><tr><td>fp</td><td>0</td></tr><tr><td>max_seq_len</td><td>512</td></tr><tr><td>media_test_epoca_loss</td><td>0.69318</td></tr><tr><td>media_train_epoca_loss</td><td>0.69366</td></tr><tr><td>nome_execucao</td><td>AjusteFinoSquad2_P_C...</td></tr><tr><td>output_hidden_states</td><td>False</td></tr><tr><td>tempo_test</td><td>0:01:24</td></tr><tr><td>tempo_train</td><td>0:47:24</td></tr><tr><td>test_batch_loss</td><td>0.69318</td></tr><tr><td>train_batch_loss</td><td>0.69213</td></tr><tr><td>vn</td><td>14190</td></tr><tr><td>vp</td><td>0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_f10</strong>: <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/26oxan45" target="_blank">https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/26oxan45</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220503_070948-26oxan45/logs</code>
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220503_083851-2j1kyuzr</code>
# Syncing run <strong><a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/2j1kyuzr" target="_blank">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f10</a></strong> to <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-05-03 08:38:59,806 : INFO : Realizando treinamento do fold 10 na época: 4.
# 2022-05-03 08:38:59,808 : INFO : Criando Lotes Inteligentes de 255,420 amostras com tamanho de lote 16...
# 2022-05-03 08:38:59,810 : INFO : Tokenizando 255,420 amostra...
# Documentos :   0%|          | 0/255420 [00:00<?, ?documento/s]
# 2022-05-03 08:40:18,329 : INFO :    255,420 amostras tokenizadas.
# 2022-05-03 08:40:18,744 : INFO :    255,420 amostras após classificação.
# 2022-05-03 08:40:18,745 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 08:40:19,092 : INFO :   FEITO - Selecionado 15,964 lotes.
# 2022-05-03 08:40:19,093 : INFO : Preenchendo sequências dentro de cada lote...
# Epoca 4:   0%|          | 0/15964 [00:00<?, ?lotes/s]
# 2022-05-03 09:28:46,925 : INFO :    Média perda(loss) do treinamento da época : 0.69345846.
# 2022-05-03 09:28:46,929 : INFO :    Tempo de treinamento da época             : 0:48:25.
# 2022-05-03 09:28:46,932 : INFO :    Tempo parcial processamento               : 4:15:21 (h:mm:ss)
# 2022-05-03 09:28:46,934 : INFO : Realizando avaliação do fold 10 na época: 4.
# 2022-05-03 09:28:46,936 : INFO : Criando Lotes Inteligentes de 28,380 amostras com tamanho de lote 16...
# 2022-05-03 09:28:46,937 : INFO : Tokenizando 28,380 amostra...
# Documentos :   0%|          | 0/28380 [00:00<?, ?documento/s]
# 2022-05-03 09:29:04,692 : INFO :     28,380 amostras tokenizadas.
# 2022-05-03 09:29:04,727 : INFO :     28,380 amostras após classificação.
# 2022-05-03 09:29:04,731 : INFO : Criando lotes de tamanho 16...
# 2022-05-03 09:29:04,759 : INFO :   FEITO - Selecionado 1,774 lotes.
# 2022-05-03 09:29:04,765 : INFO : Preenchendo sequências dentro de cada lote...
# Lotes :   0%|          | 0/1774 [00:00<?, ?lotes/s]
# 2022-05-03 09:30:12,106 : INFO :    Avaliação loss: 0.69354616; Acc: 0.50000000; Rec: 0.00000000; Pre: 0.00000000, F1:0.00000000, vp:   0; vn: 14190; fp:   0; fn: 14190
# 2022-05-03 09:30:12,108 : INFO :    Acurácia do fold 10 na época 4: 0.50000000.
# 2022-05-03 09:30:12,114 : INFO :    Média perda(loss) do avaliação da época   : 0.69354616.
# 2022-05-03 09:30:12,118 : INFO :    Tempo de avaliação da época               : 0:01:25.
# 2022-05-03 09:30:12,124 : INFO :    Tempo parcial do processamento            : 4:16:46 (h:mm:ss)
# 2022-05-03 09:30:12,137 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/.
# 2022-05-03 09:30:15,553 : INFO : Criando arquivo classificação: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Classificacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f10_BERTimbau_large.csv.
# 2022-05-03 09:30:15,915 : INFO : Diretório já existe: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/.
# 2022-05-03 09:30:15,919 : INFO : Criando arquivo resultado: /content/drive/MyDrive/Colab Notebooks/Data/SQUAD2_P/validacao_classificacao_palavra/kfold/Avaliacao/P_100_K_100/AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f10_BERTimbau_large.csv.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>▁</td></tr><tr><td>do_lower_case</td><td>▁</td></tr><tr><td>fn</td><td>▁</td></tr><tr><td>fp</td><td>▁</td></tr><tr><td>max_seq_len</td><td>▁</td></tr><tr><td>media_test_epoca_loss</td><td>▁</td></tr><tr><td>media_train_epoca_loss</td><td>▁</td></tr><tr><td>output_hidden_states</td><td>▁</td></tr><tr><td>test_batch_loss</td><td>▅▅▅▅▅▅▅▃▂▁▅▅█▅▅▅▅▅▅▅█▄▅▅▄▅▄█▃▇▁▆▇▅▇▅▅▄▅▄</td></tr><tr><td>train_batch_loss</td><td>▅▅▅▅▅▅▅▇▅▅▅▃▄▅▅▅▁▅▅▅▅▅█▅▅▅▅▅▆▅▅▆▅▅▅▆▅▄▅▅</td></tr><tr><td>vn</td><td>▁</td></tr><tr><td>vp</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acuracia</td><td>0.5</td></tr><tr><td>do_lower_case</td><td>False</td></tr><tr><td>fn</td><td>14190</td></tr><tr><td>fp</td><td>0</td></tr><tr><td>max_seq_len</td><td>512</td></tr><tr><td>media_test_epoca_loss</td><td>0.69355</td></tr><tr><td>media_train_epoca_loss</td><td>0.69346</td></tr><tr><td>nome_execucao</td><td>AjusteFinoSquad2_P_C...</td></tr><tr><td>output_hidden_states</td><td>False</td></tr><tr><td>tempo_test</td><td>0:01:25</td></tr><tr><td>tempo_train</td><td>0:48:25</td></tr><tr><td>test_batch_loss</td><td>0.68883</td></tr><tr><td>train_batch_loss</td><td>0.69367</td></tr><tr><td>vn</td><td>14190</td></tr><tr><td>vp</td><td>0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f10</strong>: <a href="https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/2j1kyuzr" target="_blank">https://wandb.ai/osmar-braz/AjusteFinoSquad2_P_C_SB_KF_v1/runs/2j1kyuzr</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220503_083851-2j1kyuzr/logs</code>
# 2022-05-03 10:32:38,424 : INFO :   Média perda(loss) treinamento : 0.69471141.
# 2022-05-03 10:32:38,425 : INFO :   Média perda(loss) avaliação   : 0.69533577.
# 2022-05-03 10:32:38,442 : INFO :   Tempo total treinamento       : 5:19:12.
# 2022-05-03 10:32:38,455 : INFO :   Tempo processamento fold: 5:20:45 (h:mm:ss)
#
# 2022-05-03 10:32:38,652 : INFO :   Tempo processamento de todos os folds: 10:40:57 (h:mm:ss)

# %% [markdown]
# ## 5.3 Carregando a acurácia média das execuções

# %%
# Import das bibliotecas
from tqdm.notebook import tqdm as tqdm_notebook

TAXAS_DE_APRENDIZAGEM = [1e-5, 2e-5, 3e-5, 4e-5, 5e-5]

LISTA_EPOCAS = [*range(0,EPOCAS+1)]

# Guarda um resumo das execuções
lista_resultado_execucoes = []

# Barra de progresso modelos
modelo_bar = tqdm_notebook(enumerate(NOMES_MODELO), desc=f'Modelos ', unit=f'modelo', total=len(NOMES_MODELO))

# Percorre todos os modelos a serem avaliados
for modelo_i, modelo in modelo_bar:

  # Barra de progresso das taxas de aprendizagem
  taxa_de_aprendizagem_bar = tqdm_notebook(enumerate(TAXAS_DE_APRENDIZAGEM), desc=f'Taxas de aprendizagem ', unit=f'taxa', total=len(TAXAS_DE_APRENDIZAGEM))

  # Executa o treinamento e avaliação para diversas taxas de aprendizagem
  for taxas_de_aprendizagem_i, taxa_de_aprendizagem in taxa_de_aprendizagem_bar:

    # Barra de progresso épocas
    epoca_bar = tqdm_notebook(enumerate(LISTA_EPOCAS), desc=f'Épocas ', unit=f'época', total=len(LISTA_EPOCAS))

    # Percorre todos as épocas a serem avaliadas
    for epoca_i, epoca in epoca_bar:

      logging.info("\n")
      logging.info("Acurácia do modelo: {}".format(modelo))
      logging.info("   com época {} e taxa de treinamento {}.".format(epoca, taxa_de_aprendizagem))

      # Seta o parâmetro do modelo
      model_args.pretrained_model_name_or_path = modelo

      # Seta o parâmetro do modelo
      training_args.learning_rate = taxa_de_aprendizagem

      # Seta o parâmetro do modelo
      model_args.epoca = epoca
   
      # Monta o nome do arquivo de log
      NOME_ARQUIVO_AVALIACAO =  NOME_BASE_SAIDA + getSufixoNomeArquivoSaida(training_args, model_args)
      
      # Carrega o resultado
      carregaResultadoAvaliacao(NOME_ARQUIVO_AVALIACAO)
# Out:
# Modelos :   0%|          | 0/1 [00:00<?, ?modelo/s]
# Taxas de aprendizagem :   0%|          | 0/5 [00:00<?, ?taxa/s]
# Épocas :   0%|          | 0/4 [00:00<?, ?época/s]
# 2022-05-03 10:32:38,853 : INFO :
#
# 2022-05-03 10:32:38,860 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:32:38,861 : INFO :    com época 1 e taxa de treinamento 1e-05.
# 2022-05-03 10:32:38,862 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:32:39,431 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f1_BERTimbau_large, Data: 15/04/2022 21:41, Tempo: 0:58:31, QtdeTeste: 28380, Acc: 0.97836505, Rec: 0.99288231, Pre: 0.96486783, F1:0.97867463, vp: 14089; vn: 13677; fp:  513; fn:  101
# 2022-05-03 10:32:39,930 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f2_BERTimbau_large, Data: 16/04/2022 04:17, Tempo: 1:00:58, QtdeTeste: 28380, Acc: 0.98231149, Rec: 0.98625793, Pre: 0.97853447, F1:0.98238102, vp: 13995; vn: 13883; fp:  307; fn:  195
# 2022-05-03 10:32:40,661 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f3_BERTimbau_large, Data: 16/04/2022 20:25, Tempo: 0:50:10, QtdeTeste: 28380, Acc: 0.98234672, Rec: 0.99633545, Pre: 0.96921917, F1:0.98259026, vp: 14138; vn: 13741; fp:  449; fn:   52
# 2022-05-03 10:32:41,379 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f4_BERTimbau_large, Data: 17/04/2022 01:52, Tempo: 0:50:24, QtdeTeste: 28380, Acc: 0.98202960, Rec: 0.98661029, Pre: 0.97765363, F1:0.98211154, vp: 14000; vn: 13870; fp:  320; fn:  190
# 2022-05-03 10:32:42,076 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f5_BERTimbau_large, Data: 17/04/2022 07:21, Tempo: 0:50:45, QtdeTeste: 28380, Acc: 0.98139535, Rec: 0.99020437, Pre: 0.97306094, F1:0.98155781, vp: 14051; vn: 13801; fp:  389; fn:  139
# 2022-05-03 10:32:42,820 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f6_BERTimbau_large, Data: 18/04/2022 00:26, Tempo: 0:50:01, QtdeTeste: 28380, Acc: 0.98157153, Rec: 0.98978154, Pre: 0.97379186, F1:0.98172160, vp: 14045; vn: 13812; fp:  378; fn:  145
# 2022-05-03 10:32:43,501 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f7_BERTimbau_large, Data: 18/04/2022 05:54, Tempo: 0:50:25, QtdeTeste: 28380, Acc: 0.98389711, Rec: 0.99189570, Pre: 0.97627801, F1:0.98402489, vp: 14075; vn: 13848; fp:  342; fn:  115
# 2022-05-03 10:32:44,165 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f8_BERTimbau_large, Data: 18/04/2022 22:51, Tempo: 1:00:53, QtdeTeste: 28380, Acc: 0.98308668, Rec: 0.99337562, Pre: 0.97334622, F1:0.98325893, vp: 14096; vn: 13804; fp:  386; fn:   94
# 2022-05-03 10:32:44,696 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f9_BERTimbau_large, Data: 19/04/2022 21:04, Tempo: 0:49:42, QtdeTeste: 28380, Acc: 0.97854123, Rec: 0.98985201, Pre: 0.96795534, F1:0.97878123, vp: 14046; vn: 13725; fp:  465; fn:  144
# 2022-05-03 10:32:45,339 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_f10_BERTimbau_large, Data: 20/04/2022 09:22, Tempo: 0:49:56, QtdeTeste: 28380, Acc: 0.98199436, Rec: 0.99330514, Pre: 0.97133209, F1:0.98219574, vp: 14095; vn: 13774; fp:  416; fn:   95
# 2022-05-03 10:32:45,341 : INFO : Total acurácia                                       : 9.81553911.
# 2022-05-03 10:32:45,343 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:32:45,345 : INFO : A média da acurácia de 10 folds é                    : 0.98155391.
# 2022-05-03 10:32:45,346 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 08:51:45.
# 2022-05-03 10:32:45,351 : INFO : A média de tempo de execução de 10 folds é           : 00:53:10.
# 2022-05-03 10:32:45,354 : INFO :
#
# 2022-05-03 10:32:45,359 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:32:45,359 : INFO :    com época 2 e taxa de treinamento 1e-05.
# 2022-05-03 10:32:45,360 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:32:45,861 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f1_BERTimbau_large, Data: 15/04/2022 22:48, Tempo: 2:05:44, QtdeTeste: 28380, Acc: 0.98470754, Rec: 0.98139535, Pre: 0.98793984, F1:0.98465672, vp: 13926; vn: 14020; fp:  170; fn:  264
# 2022-05-03 10:32:46,646 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f2_BERTimbau_large, Data: 16/04/2022 05:28, Tempo: 2:12:25, QtdeTeste: 28380, Acc: 0.98833686, Rec: 0.99076815, Pre: 0.98597377, F1:0.98836514, vp: 14059; vn: 13990; fp:  200; fn:  131
# 2022-05-03 10:32:47,361 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f3_BERTimbau_large, Data: 16/04/2022 21:18, Tempo: 1:43:32, QtdeTeste: 28380, Acc: 0.98590557, Rec: 0.98386187, Pre: 0.98789980, F1:0.98587670, vp: 13961; vn: 14019; fp:  171; fn:  229
# 2022-05-03 10:32:48,036 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f4_BERTimbau_large, Data: 17/04/2022 02:46, Tempo: 1:44:16, QtdeTeste: 28380, Acc: 0.98611698, Rec: 0.98759690, Pre: 0.98468241, F1:0.98613750, vp: 14014; vn: 13972; fp:  218; fn:  176
# 2022-05-03 10:32:48,968 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f5_BERTimbau_large, Data: 17/04/2022 08:15, Tempo: 1:44:44, QtdeTeste: 28380, Acc: 0.98414376, Rec: 0.98210007, Pre: 0.98613077, F1:0.98411129, vp: 13936; vn: 13994; fp:  196; fn:  254
# 2022-05-03 10:32:49,615 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f6_BERTimbau_large, Data: 18/04/2022 01:19, Tempo: 1:43:12, QtdeTeste: 28380, Acc: 0.98202960, Rec: 0.97780127, Pre: 0.98614072, F1:0.98195329, vp: 13875; vn: 13995; fp:  195; fn:  315
# 2022-05-03 10:32:50,308 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f7_BERTimbau_large, Data: 18/04/2022 06:47, Tempo: 1:44:07, QtdeTeste: 28380, Acc: 0.98692741, Rec: 0.98470754, Pre: 0.98909889, F1:0.98689833, vp: 13973; vn: 14036; fp:  154; fn:  217
# 2022-05-03 10:32:50,960 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f8_BERTimbau_large, Data: 18/04/2022 23:59, Tempo: 2:09:03, QtdeTeste: 28380, Acc: 0.98798450, Rec: 0.98921776, Pre: 0.98678383, F1:0.98799930, vp: 14037; vn: 14002; fp:  188; fn:  153
# 2022-05-03 10:32:51,461 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f9_BERTimbau_large, Data: 19/04/2022 21:57, Tempo: 1:42:41, QtdeTeste: 28380, Acc: 0.98544750, Rec: 0.98386187, Pre: 0.98699187, F1:0.98542439, vp: 13961; vn: 14006; fp:  184; fn:  229
# 2022-05-03 10:32:52,125 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_f10_BERTimbau_large, Data: 20/04/2022 10:15, Tempo: 1:42:58, QtdeTeste: 28380, Acc: 0.98520085, Rec: 0.98703312, Pre: 0.98342929, F1:0.98522791, vp: 14006; vn: 13954; fp:  236; fn:  184
# 2022-05-03 10:32:52,126 : INFO : Total acurácia                                       : 9.85680056.
# 2022-05-03 10:32:52,127 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:32:52,128 : INFO : A média da acurácia de 10 folds é                    : 0.98568006.
# 2022-05-03 10:32:52,129 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 18:32:42.
# 2022-05-03 10:32:52,132 : INFO : A média de tempo de execução de 10 folds é           : 01:51:15.
# 2022-05-03 10:32:52,138 : INFO :
#
# 2022-05-03 10:32:52,140 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:32:52,142 : INFO :    com época 3 e taxa de treinamento 1e-05.
# 2022-05-03 10:32:52,143 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:32:52,664 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f1_BERTimbau_large, Data: 16/04/2022 00:12, Tempo: 3:30:12, QtdeTeste: 28380, Acc: 0.99076815, Rec: 0.99429175, Pre: 0.98733380, F1:0.99080056, vp: 14109; vn: 14009; fp:  181; fn:   81
# 2022-05-03 10:32:53,189 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f2_BERTimbau_large, Data: 16/04/2022 06:56, Tempo: 3:40:46, QtdeTeste: 28380, Acc: 0.99059197, Rec: 0.99196617, Pre: 0.98924731, F1:0.99060488, vp: 14076; vn: 14037; fp:  153; fn:  114
# 2022-05-03 10:32:53,911 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f3_BERTimbau_large, Data: 16/04/2022 22:26, Tempo: 2:51:06, QtdeTeste: 28380, Acc: 0.99031008, Rec: 0.99351656, Pre: 0.98718577, F1:0.99034105, vp: 14098; vn: 14007; fp:  183; fn:   92
# 2022-05-03 10:32:54,549 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f4_BERTimbau_large, Data: 17/04/2022 03:55, Tempo: 2:53:25, QtdeTeste: 28380, Acc: 0.98858351, Rec: 0.99020437, Pre: 0.98700478, F1:0.98860198, vp: 14051; vn: 14005; fp:  185; fn:  139
# 2022-05-03 10:32:55,222 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f5_BERTimbau_large, Data: 17/04/2022 09:25, Tempo: 2:54:24, QtdeTeste: 28380, Acc: 0.98583510, Rec: 0.98900634, Pre: 0.98277311, F1:0.98587987, vp: 14034; vn: 13944; fp:  246; fn:  156
# 2022-05-03 10:32:55,938 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f6_BERTimbau_large, Data: 18/04/2022 02:28, Tempo: 2:51:49, QtdeTeste: 28380, Acc: 0.98907681, Rec: 0.99133192, Pre: 0.98688088, F1:0.98910139, vp: 14067; vn: 14003; fp:  187; fn:  123
# 2022-05-03 10:32:56,644 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f7_BERTimbau_large, Data: 18/04/2022 07:56, Tempo: 2:52:46, QtdeTeste: 28380, Acc: 0.98932347, Rec: 0.98928823, Pre: 0.98935795, F1:0.98932309, vp: 14038; vn: 14039; fp:  151; fn:  152
# 2022-05-03 10:32:57,347 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f8_BERTimbau_large, Data: 19/04/2022 01:26, Tempo: 3:35:32, QtdeTeste: 28380, Acc: 0.98883016, Rec: 0.98893587, Pre: 0.98872684, F1:0.98883134, vp: 14033; vn: 14030; fp:  160; fn:  157
# 2022-05-03 10:32:57,857 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f9_BERTimbau_large, Data: 19/04/2022 23:05, Tempo: 2:50:18, QtdeTeste: 28380, Acc: 0.98840733, Rec: 0.98801973, Pre: 0.98878623, F1:0.98840283, vp: 14020; vn: 14031; fp:  159; fn:  170
# 2022-05-03 10:32:58,558 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_f10_BERTimbau_large, Data: 20/04/2022 11:22, Tempo: 2:50:05, QtdeTeste: 28380, Acc: 0.98844257, Rec: 0.98837209, Pre: 0.98851142, F1:0.98844175, vp: 14025; vn: 14027; fp:  163; fn:  165
# 2022-05-03 10:32:58,560 : INFO : Total acurácia                                       : 9.89016913.
# 2022-05-03 10:32:58,562 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:32:58,566 : INFO : A média da acurácia de 10 folds é                    : 0.98901691.
# 2022-05-03 10:32:58,569 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 30:50:23.
# 2022-05-03 10:32:58,571 : INFO : A média de tempo de execução de 10 folds é           : 03:05:00.
# 2022-05-03 10:32:58,577 : INFO :
#
# 2022-05-03 10:32:58,578 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:32:58,580 : INFO :    com época 4 e taxa de treinamento 1e-05.
# 2022-05-03 10:32:58,582 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:32:59,148 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f1_BERTimbau_large, Data: 16/04/2022 02:04, Tempo: 5:21:56, QtdeTeste: 28380, Acc: 0.99164905, Rec: 0.99457364, Pre: 0.98879002, F1:0.99167340, vp: 14113; vn: 14030; fp:  160; fn:   77
# 2022-05-03 10:32:59,672 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f2_BERTimbau_large, Data: 16/04/2022 08:50, Tempo: 5:34:41, QtdeTeste: 28380, Acc: 0.98851304, Rec: 0.98914729, Pre: 0.98789414, F1:0.98852032, vp: 14036; vn: 14018; fp:  172; fn:  154
# 2022-05-03 10:33:00,380 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f3_BERTimbau_large, Data: 16/04/2022 23:58, Tempo: 4:23:00, QtdeTeste: 28380, Acc: 0.99157858, Rec: 0.99760395, Pre: 0.98572523, F1:0.99162901, vp: 14156; vn: 13985; fp:  205; fn:   34
# 2022-05-03 10:33:01,083 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f4_BERTimbau_large, Data: 17/04/2022 05:27, Tempo: 4:25:38, QtdeTeste: 28380, Acc: 0.98840733, Rec: 0.98745595, Pre: 0.98933842, F1:0.98839629, vp: 14012; vn: 14039; fp:  151; fn:  178
# 2022-05-03 10:33:01,747 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f5_BERTimbau_large, Data: 17/04/2022 10:58, Tempo: 4:27:18, QtdeTeste: 28380, Acc: 0.98851304, Rec: 0.98935870, Pre: 0.98768819, F1:0.98852274, vp: 14039; vn: 14015; fp:  175; fn:  151
# 2022-05-03 10:33:02,447 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f6_BERTimbau_large, Data: 18/04/2022 03:59, Tempo: 4:23:01, QtdeTeste: 28380, Acc: 0.98615222, Rec: 0.99083862, Pre: 0.98163793, F1:0.98621681, vp: 14060; vn: 13927; fp:  263; fn:  130
# 2022-05-03 10:33:03,173 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f7_BERTimbau_large, Data: 18/04/2022 09:30, Tempo: 4:26:29, QtdeTeste: 28380, Acc: 0.98978154, Rec: 0.99182523, Pre: 0.98778776, F1:0.98980238, vp: 14074; vn: 14016; fp:  174; fn:  116
# 2022-05-03 10:33:03,824 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f8_BERTimbau_large, Data: 19/04/2022 03:16, Tempo: 5:25:59, QtdeTeste: 28380, Acc: 0.98858351, Rec: 0.98801973, Pre: 0.98913504, F1:0.98857707, vp: 14020; vn: 14036; fp:  154; fn:  170
# 2022-05-03 10:33:04,342 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f9_BERTimbau_large, Data: 20/04/2022 00:38, Tempo: 4:23:27, QtdeTeste: 28380, Acc: 0.98537703, Rec: 0.98343904, Pre: 0.98726565, F1:0.98534863, vp: 13955; vn: 14010; fp:  180; fn:  235
# 2022-05-03 10:33:04,952 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_f10_BERTimbau_large, Data: 20/04/2022 12:51, Tempo: 4:19:10, QtdeTeste: 28380, Acc: 0.98861875, Rec: 0.99140240, Pre: 0.98591352, F1:0.98865034, vp: 14068; vn: 13989; fp:  201; fn:  122
# 2022-05-03 10:33:04,954 : INFO : Total acurácia                                       : 9.88717407.
# 2022-05-03 10:33:04,956 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:04,957 : INFO : A média da acurácia de 10 folds é                    : 0.98871741.
# 2022-05-03 10:33:04,959 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 47:10:39.
# 2022-05-03 10:33:04,961 : INFO : A média de tempo de execução de 10 folds é           : 04:42:59.
# Épocas :   0%|          | 0/4 [00:00<?, ?época/s]
# 2022-05-03 10:33:05,021 : INFO :
#
# 2022-05-03 10:33:05,023 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:33:05,025 : INFO :    com época 1 e taxa de treinamento 2e-05.
# 2022-05-03 10:33:05,027 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:33:05,715 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f1_BERTimbau_large, Data: 21/04/2022 03:08, Tempo: 0:58:04, QtdeTeste: 28380, Acc: 0.96543340, Rec: 0.97455955, Pre: 0.95709046, F1:0.96574601, vp: 13829; vn: 13570; fp:  620; fn:  361
# 2022-05-03 10:33:06,370 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f2_BERTimbau_large, Data: 21/04/2022 09:41, Tempo: 0:59:23, QtdeTeste: 28380, Acc: 0.98111346, Rec: 0.98597604, Pre: 0.97647962, F1:0.98120485, vp: 13991; vn: 13853; fp:  337; fn:  199
# 2022-05-03 10:33:07,034 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f3_BERTimbau_large, Data: 21/04/2022 21:46, Tempo: 0:50:24, QtdeTeste: 28380, Acc: 0.97110641, Rec: 0.97632135, Pre: 0.96624355, F1:0.97125631, vp: 13854; vn: 13706; fp:  484; fn:  336
# 2022-05-03 10:33:07,686 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f4_BERTimbau_large, Data: 22/04/2022 03:17, Tempo: 0:50:47, QtdeTeste: 28380, Acc: 0.98023256, Rec: 0.97723749, Pre: 0.98312655, F1:0.98017318, vp: 13867; vn: 13952; fp:  238; fn:  323
# 2022-05-03 10:33:08,312 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f5_BERTimbau_large, Data: 22/04/2022 21:56, Tempo: 0:51:03, QtdeTeste: 28380, Acc: 0.97480620, Rec: 0.97279774, Pre: 0.97672115, F1:0.97475550, vp: 13804; vn: 13861; fp:  329; fn:  386
# 2022-05-03 10:33:08,940 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f6_BERTimbau_large, Data: 23/04/2022 03:17, Tempo: 0:50:00, QtdeTeste: 28380, Acc: 0.98195913, Rec: 0.98491896, Pre: 0.97912288, F1:0.98201237, vp: 13976; vn: 13892; fp:  298; fn:  214
# 2022-05-03 10:33:09,574 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f7_BERTimbau_large, Data: 23/04/2022 21:43, Tempo: 0:59:11, QtdeTeste: 28380, Acc: 0.97956307, Rec: 0.98710359, Pre: 0.97243821, F1:0.97971602, vp: 14007; vn: 13793; fp:  397; fn:  183
# 2022-05-03 10:33:10,230 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f8_BERTimbau_large, Data: 24/04/2022 04:28, Tempo: 1:03:47, QtdeTeste: 28380, Acc: 0.98132488, Rec: 0.98428471, Pre: 0.97849236, F1:0.98137999, vp: 13967; vn: 13883; fp:  307; fn:  223
# 2022-05-03 10:33:10,765 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f9_BERTimbau_large, Data: 24/04/2022 21:26, Tempo: 1:01:32, QtdeTeste: 28380, Acc: 0.97818887, Rec: 0.98146582, Pre: 0.97507526, F1:0.97826011, vp: 13927; vn: 13834; fp:  356; fn:  263
# 2022-05-03 10:33:11,358 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_f10_BERTimbau_large, Data: 25/04/2022 04:10, Tempo: 1:01:11, QtdeTeste: 28380, Acc: 0.97758985, Rec: 0.98301621, Pre: 0.97246235, F1:0.97771080, vp: 13949; vn: 13795; fp:  395; fn:  241
# 2022-05-03 10:33:11,360 : INFO : Total acurácia                                       : 9.77131783.
# 2022-05-03 10:33:11,361 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:11,362 : INFO : A média da acurácia de 10 folds é                    : 0.97713178.
# 2022-05-03 10:33:11,363 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 09:25:22.
# 2022-05-03 10:33:11,364 : INFO : A média de tempo de execução de 10 folds é           : 00:56:32.
# 2022-05-03 10:33:11,367 : INFO :
#
# 2022-05-03 10:33:11,368 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:33:11,369 : INFO :    com época 2 e taxa de treinamento 2e-05.
# 2022-05-03 10:33:11,370 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:33:12,060 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f1_BERTimbau_large, Data: 21/04/2022 04:16, Tempo: 2:05:49, QtdeTeste: 28380, Acc: 0.94076815, Rec: 0.90000000, Pre: 0.97989718, F1:0.93825074, vp: 12771; vn: 13928; fp:  262; fn: 1419
# 2022-05-03 10:33:12,768 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f2_BERTimbau_large, Data: 21/04/2022 10:49, Tempo: 2:07:16, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:13,460 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f3_BERTimbau_large, Data: 21/04/2022 22:39, Tempo: 1:43:46, QtdeTeste: 28380, Acc: 0.96472868, Rec: 0.95926709, Pre: 0.96986106, F1:0.96453499, vp: 13612; vn: 13767; fp:  423; fn:  578
# 2022-05-03 10:33:14,130 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f4_BERTimbau_large, Data: 22/04/2022 04:11, Tempo: 1:44:55, QtdeTeste: 28380, Acc: 0.97191684, Rec: 0.97195208, Pre: 0.97188359, F1:0.97191783, vp: 13792; vn: 13791; fp:  399; fn:  398
# 2022-05-03 10:33:14,774 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f5_BERTimbau_large, Data: 22/04/2022 22:49, Tempo: 1:44:16, QtdeTeste: 28380, Acc: 0.95355884, Rec: 0.92565187, Pre: 0.98037020, F1:0.95222561, vp: 13135; vn: 13927; fp:  263; fn: 1055
# 2022-05-03 10:33:15,448 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f6_BERTimbau_large, Data: 23/04/2022 04:11, Tempo: 1:43:17, QtdeTeste: 28380, Acc: 0.96134602, Rec: 0.95722340, Pre: 0.96518155, F1:0.96118600, vp: 13583; vn: 13700; fp:  490; fn:  607
# 2022-05-03 10:33:16,086 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f7_BERTimbau_large, Data: 23/04/2022 22:52, Tempo: 2:08:42, QtdeTeste: 28380, Acc: 0.96761804, Rec: 0.94918957, Pre: 0.98551255, F1:0.96701009, vp: 13469; vn: 13992; fp:  198; fn:  721
# 2022-05-03 10:33:16,729 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f8_BERTimbau_large, Data: 24/04/2022 05:41, Tempo: 2:17:10, QtdeTeste: 28380, Acc: 0.94510218, Rec: 0.90768147, Pre: 0.98110908, F1:0.94296801, vp: 12880; vn: 13942; fp:  248; fn: 1310
# 2022-05-03 10:33:17,415 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f9_BERTimbau_large, Data: 24/04/2022 22:36, Tempo: 2:11:44, QtdeTeste: 28380, Acc: 0.96458774, Rec: 0.95546159, Pre: 0.97322518, F1:0.96426158, vp: 13558; vn: 13817; fp:  373; fn:  632
# 2022-05-03 10:33:17,986 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_f10_BERTimbau_large, Data: 25/04/2022 05:21, Tempo: 2:12:14, QtdeTeste: 28380, Acc: 0.96691332, Rec: 0.95059901, Pre: 0.98266191, F1:0.96636458, vp: 13489; vn: 13952; fp:  238; fn:  701
# 2022-05-03 10:33:17,988 : INFO : Total acurácia                                       : 9.13653982.
# 2022-05-03 10:33:17,990 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:17,993 : INFO : A média da acurácia de 10 folds é                    : 0.91365398.
# 2022-05-03 10:33:17,994 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 19:59:09.
# 2022-05-03 10:33:17,995 : INFO : A média de tempo de execução de 10 folds é           : 01:59:55.
# 2022-05-03 10:33:17,998 : INFO :
#
# 2022-05-03 10:33:18,000 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:33:18,001 : INFO :    com época 3 e taxa de treinamento 2e-05.
# 2022-05-03 10:33:18,003 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:33:18,684 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f1_BERTimbau_large, Data: 21/04/2022 05:39, Tempo: 3:29:02, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:19,330 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f2_BERTimbau_large, Data: 21/04/2022 12:14, Tempo: 3:32:43, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:19,976 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f3_BERTimbau_large, Data: 21/04/2022 23:48, Tempo: 2:52:23, QtdeTeste: 28380, Acc: 0.92811839, Rec: 0.87385483, Pre: 0.98023715, F1:0.92399404, vp: 12400; vn: 13940; fp:  250; fn: 1790
# 2022-05-03 10:33:20,608 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f4_BERTimbau_large, Data: 22/04/2022 05:21, Tempo: 2:54:45, QtdeTeste: 28380, Acc: 0.94756871, Rec: 0.92156448, Pre: 0.97212310, F1:0.94616887, vp: 13077; vn: 13815; fp:  375; fn: 1113
# 2022-05-03 10:33:21,278 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f5_BERTimbau_large, Data: 22/04/2022 23:57, Tempo: 2:52:07, QtdeTeste: 28380, Acc: 0.90172657, Rec: 0.82882311, Pre: 0.97029948, F1:0.89399871, vp: 11761; vn: 13830; fp:  360; fn: 2429
# 2022-05-03 10:33:21,957 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f6_BERTimbau_large, Data: 23/04/2022 05:20, Tempo: 2:53:01, QtdeTeste: 28380, Acc: 0.96497533, Rec: 0.94679352, Pre: 0.98252157, F1:0.96432673, vp: 13435; vn: 13951; fp:  239; fn:  755
# 2022-05-03 10:33:22,590 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f7_BERTimbau_large, Data: 24/04/2022 00:18, Tempo: 3:35:02, QtdeTeste: 28380, Acc: 0.95870331, Rec: 0.93319239, Pre: 0.98336551, F1:0.95762222, vp: 13242; vn: 13966; fp:  224; fn:  948
# 2022-05-03 10:33:23,253 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f8_BERTimbau_large, Data: 24/04/2022 07:13, Tempo: 3:48:37, QtdeTeste: 28380, Acc: 0.89926004, Rec: 0.83664553, Pre: 0.95641666, F1:0.89253092, vp: 11872; vn: 13649; fp:  541; fn: 2318
# 2022-05-03 10:33:23,754 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f9_BERTimbau_large, Data: 25/04/2022 00:04, Tempo: 3:39:09, QtdeTeste: 28380, Acc: 0.96250881, Rec: 0.94940099, Pre: 0.97496020, F1:0.96201085, vp: 13472; vn: 13844; fp:  346; fn:  718
# 2022-05-03 10:33:24,259 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_f10_BERTimbau_large, Data: 25/04/2022 06:48, Tempo: 3:39:07, QtdeTeste: 28380, Acc: 0.95155039, Rec: 0.92522903, Pre: 0.97664212, F1:0.95024065, vp: 13129; vn: 13876; fp:  314; fn: 1061
# 2022-05-03 10:33:24,261 : INFO : Total acurácia                                       : 8.51441156.
# 2022-05-03 10:33:24,262 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:24,263 : INFO : A média da acurácia de 10 folds é                    : 0.85144116.
# 2022-05-03 10:33:24,264 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 33:15:56.
# 2022-05-03 10:33:24,266 : INFO : A média de tempo de execução de 10 folds é           : 03:19:36.
# 2022-05-03 10:33:24,268 : INFO :
#
# 2022-05-03 10:33:24,270 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:33:24,271 : INFO :    com época 4 e taxa de treinamento 2e-05.
# 2022-05-03 10:33:24,273 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:33:24,917 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f1_BERTimbau_large, Data: 21/04/2022 07:29, Tempo: 5:19:28, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:25,605 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f2_BERTimbau_large, Data: 21/04/2022 14:07, Tempo: 5:24:46, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:26,261 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f3_BERTimbau_large, Data: 22/04/2022 01:20, Tempo: 4:24:29, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:26,901 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f4_BERTimbau_large, Data: 22/04/2022 06:53, Tempo: 4:26:53, QtdeTeste: 28380, Acc: 0.93054968, Rec: 0.88238196, Pre: 0.97644857, F1:0.92703513, vp: 12521; vn: 13888; fp:  302; fn: 1669
# 2022-05-03 10:33:27,536 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f5_BERTimbau_large, Data: 23/04/2022 01:27, Tempo: 4:21:53, QtdeTeste: 28380, Acc: 0.87286822, Rec: 0.76899225, Pre: 0.97064579, F1:0.85813149, vp: 10912; vn: 13860; fp:  330; fn: 3278
# 2022-05-03 10:33:28,149 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f6_BERTimbau_large, Data: 23/04/2022 06:51, Tempo: 4:23:39, QtdeTeste: 28380, Acc: 0.94256519, Rec: 0.91789993, Pre: 0.96553002, F1:0.94111272, vp: 13025; vn: 13725; fp:  465; fn: 1165
# 2022-05-03 10:33:28,829 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f7_BERTimbau_large, Data: 24/04/2022 02:09, Tempo: 5:25:10, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:29,474 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f8_BERTimbau_large, Data: 24/04/2022 09:13, Tempo: 5:48:41, QtdeTeste: 28380, Acc: 0.93502467, Rec: 0.90197322, Pre: 0.96581648, F1:0.93280373, vp: 12799; vn: 13737; fp:  453; fn: 1391
# 2022-05-03 10:33:29,951 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f9_BERTimbau_large, Data: 25/04/2022 01:57, Tempo: 5:31:57, QtdeTeste: 28380, Acc: 0.94189570, Rec: 0.91205074, Pre: 0.96994679, F1:0.94010823, vp: 12942; vn: 13789; fp:  401; fn: 1248
# 2022-05-03 10:33:30,437 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_f10_BERTimbau_large, Data: 25/04/2022 08:42, Tempo: 5:33:15, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:30,439 : INFO : Total acurácia                                       : 7.12290345.
# 2022-05-03 10:33:30,440 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:30,441 : INFO : A média da acurácia de 10 folds é                    : 0.71229035.
# 2022-05-03 10:33:30,442 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 50:40:11.
# 2022-05-03 10:33:30,443 : INFO : A média de tempo de execução de 10 folds é           : 05:04:02.
# Épocas :   0%|          | 0/4 [00:00<?, ?época/s]
# 2022-05-03 10:33:30,506 : INFO :
#
# 2022-05-03 10:33:30,508 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:33:30,511 : INFO :    com época 1 e taxa de treinamento 3e-05.
# 2022-05-03 10:33:30,512 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:33:31,189 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f1_BERTimbau_large, Data: 25/04/2022 22:05, Tempo: 0:50:05, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:31,956 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f2_BERTimbau_large, Data: 26/04/2022 03:34, Tempo: 0:49:36, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:32,590 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f3_BERTimbau_large, Data: 26/04/2022 22:00, Tempo: 1:01:48, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:33,264 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f4_BERTimbau_large, Data: 27/04/2022 04:39, Tempo: 1:00:59, QtdeTeste: 28380, Acc: 0.97399577, Rec: 0.97610994, Pre: 0.97200000, F1:0.97405063, vp: 13851; vn: 13791; fp:  399; fn:  339
# 2022-05-03 10:33:33,928 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f5_BERTimbau_large, Data: 27/04/2022 22:57, Tempo: 1:03:11, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:34,569 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f6_BERTimbau_large, Data: 28/04/2022 21:45, Tempo: 0:49:36, QtdeTeste: 28380, Acc: 0.96885130, Rec: 0.97625088, Pre: 0.96201389, F1:0.96908010, vp: 13853; vn: 13643; fp:  547; fn:  337
# 2022-05-03 10:33:35,348 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f7_BERTimbau_large, Data: 29/04/2022 21:19, Tempo: 1:03:12, QtdeTeste: 28380, Acc: 0.95183228, Rec: 0.93305144, Pre: 0.96946621, F1:0.95091033, vp: 13240; vn: 13773; fp:  417; fn:  950
# 2022-05-03 10:33:36,064 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f8_BERTimbau_large, Data: 30/04/2022 04:26, Tempo: 1:04:48, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:36,860 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f9_BERTimbau_large, Data: 30/04/2022 22:55, Tempo: 0:48:42, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:37,654 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_f10_BERTimbau_large, Data: 01/05/2022 04:12, Tempo: 0:48:56, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:37,656 : INFO : Total acurácia                                       : 6.39467935.
# 2022-05-03 10:33:37,657 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:37,658 : INFO : A média da acurácia de 10 folds é                    : 0.63946794.
# 2022-05-03 10:33:37,659 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 09:20:53.
# 2022-05-03 10:33:37,660 : INFO : A média de tempo de execução de 10 folds é           : 00:56:05.
# 2022-05-03 10:33:37,666 : INFO :
#
# 2022-05-03 10:33:37,667 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:33:37,668 : INFO :    com época 2 e taxa de treinamento 3e-05.
# 2022-05-03 10:33:37,669 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:33:39,516 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f1_BERTimbau_large, Data: 25/04/2022 22:57, Tempo: 1:42:21, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:40,174 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f2_BERTimbau_large, Data: 26/04/2022 04:27, Tempo: 1:42:02, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:40,882 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f3_BERTimbau_large, Data: 26/04/2022 23:10, Tempo: 2:12:36, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:41,513 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f4_BERTimbau_large, Data: 27/04/2022 05:50, Tempo: 2:12:21, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:42,121 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f5_BERTimbau_large, Data: 28/04/2022 00:10, Tempo: 2:15:43, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:42,792 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f6_BERTimbau_large, Data: 28/04/2022 22:37, Tempo: 1:41:48, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:43,579 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f7_BERTimbau_large, Data: 29/04/2022 22:33, Tempo: 2:16:41, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:44,345 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f8_BERTimbau_large, Data: 30/04/2022 05:42, Tempo: 2:20:08, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:45,120 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f9_BERTimbau_large, Data: 30/04/2022 23:47, Tempo: 1:40:04, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:45,916 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_f10_BERTimbau_large, Data: 01/05/2022 05:04, Tempo: 1:40:36, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:45,917 : INFO : Total acurácia                                       : 5.00000000.
# 2022-05-03 10:33:45,919 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:45,920 : INFO : A média da acurácia de 10 folds é                    : 0.50000000.
# 2022-05-03 10:33:45,923 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 19:44:20.
# 2022-05-03 10:33:45,924 : INFO : A média de tempo de execução de 10 folds é           : 01:58:25.
# 2022-05-03 10:33:45,928 : INFO :
#
# 2022-05-03 10:33:45,930 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:33:45,931 : INFO :    com época 3 e taxa de treinamento 3e-05.
# 2022-05-03 10:33:45,933 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:33:46,583 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f1_BERTimbau_large, Data: 26/04/2022 00:06, Tempo: 2:50:48, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:47,220 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f2_BERTimbau_large, Data: 26/04/2022 05:36, Tempo: 2:50:52, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:47,835 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f3_BERTimbau_large, Data: 27/04/2022 00:36, Tempo: 3:38:06, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:48,455 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f4_BERTimbau_large, Data: 27/04/2022 07:16, Tempo: 3:38:13, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:49,117 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f5_BERTimbau_large, Data: 28/04/2022 01:37, Tempo: 3:42:54, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:49,743 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f6_BERTimbau_large, Data: 28/04/2022 23:43, Tempo: 2:47:47, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:50,501 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f7_BERTimbau_large, Data: 30/04/2022 00:06, Tempo: 3:49:20, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:51,272 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f8_BERTimbau_large, Data: 30/04/2022 07:14, Tempo: 3:52:38, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:52,047 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f9_BERTimbau_large, Data: 01/05/2022 00:53, Tempo: 2:46:12, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:52,804 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_f10_BERTimbau_large, Data: 01/05/2022 06:10, Tempo: 2:47:13, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:52,806 : INFO : Total acurácia                                       : 5.00000000.
# 2022-05-03 10:33:52,808 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:52,810 : INFO : A média da acurácia de 10 folds é                    : 0.50000000.
# 2022-05-03 10:33:52,815 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 32:44:03.
# 2022-05-03 10:33:52,817 : INFO : A média de tempo de execução de 10 folds é           : 03:16:24.
# 2022-05-03 10:33:52,821 : INFO :
#
# 2022-05-03 10:33:52,823 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:33:52,824 : INFO :    com época 4 e taxa de treinamento 3e-05.
# 2022-05-03 10:33:52,826 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:33:53,481 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f1_BERTimbau_large, Data: 26/04/2022 01:39, Tempo: 4:23:31, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:54,196 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f2_BERTimbau_large, Data: 26/04/2022 07:08, Tempo: 4:23:08, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:54,826 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f3_BERTimbau_large, Data: 27/04/2022 02:28, Tempo: 5:30:02, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:55,424 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f4_BERTimbau_large, Data: 27/04/2022 09:09, Tempo: 5:31:26, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:56,100 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f5_BERTimbau_large, Data: 28/04/2022 03:30, Tempo: 5:36:12, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:56,729 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f6_BERTimbau_large, Data: 29/04/2022 01:12, Tempo: 4:16:48, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:57,538 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f7_BERTimbau_large, Data: 30/04/2022 02:06, Tempo: 5:49:38, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:58,307 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f8_BERTimbau_large, Data: 30/04/2022 09:10, Tempo: 5:48:39, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:59,103 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f9_BERTimbau_large, Data: 01/05/2022 02:21, Tempo: 4:14:47, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:33:59,947 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_f10_BERTimbau_large, Data: 01/05/2022 07:40, Tempo: 4:16:48, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:33:59,949 : INFO : Total acurácia                                       : 5.00000000.
# 2022-05-03 10:33:59,950 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:33:59,951 : INFO : A média da acurácia de 10 folds é                    : 0.50000000.
# 2022-05-03 10:33:59,954 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 49:50:59.
# 2022-05-03 10:33:59,956 : INFO : A média de tempo de execução de 10 folds é           : 04:59:05.
# Épocas :   0%|          | 0/4 [00:00<?, ?época/s]
# 2022-05-03 10:34:00,006 : INFO :
#
# 2022-05-03 10:34:00,008 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:34:00,010 : INFO :    com época 1 e taxa de treinamento 4e-05.
# 2022-05-03 10:34:00,012 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:34:01,007 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f1_BERTimbau_large, Data: 01/05/2022 15:03, Tempo: 0:48:38, QtdeTeste: 28380, Acc: 0.81948555, Rec: 0.67477097, Pre: 0.94961817, F1:0.78894245, vp: 9575; vn: 13682; fp:  508; fn: 4615
# 2022-05-03 10:34:01,611 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f2_BERTimbau_large, Data: 02/05/2022 00:27, Tempo: 1:02:06, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:02,242 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f3_BERTimbau_large, Data: 02/05/2022 07:16, Tempo: 1:02:13, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:02,757 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f4_BERTimbau_large, Data: 03/05/2022 00:43, Tempo: 0:48:51, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:03,247 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f5_BERTimbau_large, Data: 03/05/2022 06:03, Tempo: 0:49:13, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:03,902 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f6_BERTimbau_large, Data: 01/05/2022 21:53, Tempo: 0:48:40, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:04,554 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f7_BERTimbau_large, Data: 02/05/2022 03:13, Tempo: 0:49:21, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:05,225 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f8_BERTimbau_large, Data: 02/05/2022 08:37, Tempo: 0:50:06, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:05,233 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_f9_BERTimbau_large, Data: 03/05/2022 00:43, Tempo: 0:48:49, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# ...
# 2022-05-03 10:34:20,607 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_f10_BERTimbau_large, Data: 03/05/2022 09:30, Tempo: 4:16:50, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:20,609 : INFO : Total acurácia                                       : 5.00000000.
# 2022-05-03 10:34:20,612 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:34:20,613 : INFO : A média da acurácia de 10 folds é                    : 0.50000000.
# 2022-05-03 10:34:20,614 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 45:41:58.
# 2022-05-03 10:34:20,615 : INFO : A média de tempo de execução de 10 folds é           : 04:34:01.
# Épocas :   0%|          | 0/4 [00:00<?, ?época/s]
# 2022-05-03 10:34:20,675 : INFO :
#
# 2022-05-03 10:34:20,677 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:34:20,679 : INFO :    com época 1 e taxa de treinamento 5e-05.
# 2022-05-03 10:34:20,681 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:34:21,336 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f1_BERTimbau_large, Data: 27/04/2022 02:43, Tempo: 0:49:11, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:22,000 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f2_BERTimbau_large, Data: 27/04/2022 08:11, Tempo: 0:49:24, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:22,490 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f3_BERTimbau_large, Data: 27/04/2022 22:42, Tempo: 0:49:00, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:23,003 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f4_BERTimbau_large, Data: 28/04/2022 04:03, Tempo: 0:49:10, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:23,671 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f5_BERTimbau_large, Data: 28/04/2022 21:45, Tempo: 0:50:04, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:24,294 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f6_BERTimbau_large, Data: 29/04/2022 21:04, Tempo: 0:49:00, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:24,892 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f7_BERTimbau_large, Data: 30/04/2022 02:25, Tempo: 0:49:44, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:25,527 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f8_BERTimbau_large, Data: 30/04/2022 22:23, Tempo: 0:50:22, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:26,137 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f9_BERTimbau_large, Data: 01/05/2022 03:45, Tempo: 0:49:20, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:26,781 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_f10_BERTimbau_large, Data: 01/05/2022 09:08, Tempo: 0:49:40, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:26,783 : INFO : Total acurácia                                       : 5.00000000.
# 2022-05-03 10:34:26,784 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:34:26,786 : INFO : A média da acurácia de 10 folds é                    : 0.50000000.
# 2022-05-03 10:34:26,787 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 08:14:55.
# 2022-05-03 10:34:26,788 : INFO : A média de tempo de execução de 10 folds é           : 00:49:29.
# 2022-05-03 10:34:26,791 : INFO :
#
# 2022-05-03 10:34:26,793 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:34:26,794 : INFO :    com época 2 e taxa de treinamento 5e-05.
# 2022-05-03 10:34:26,795 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:34:27,418 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f1_BERTimbau_large, Data: 27/04/2022 03:35, Tempo: 1:40:55, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:28,028 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f2_BERTimbau_large, Data: 27/04/2022 09:03, Tempo: 1:41:07, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:28,554 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f3_BERTimbau_large, Data: 27/04/2022 23:33, Tempo: 1:40:29, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:29,027 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f4_BERTimbau_large, Data: 28/04/2022 04:55, Tempo: 1:40:51, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:29,693 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f5_BERTimbau_large, Data: 28/04/2022 22:38, Tempo: 1:43:08, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:30,358 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f6_BERTimbau_large, Data: 29/04/2022 21:56, Tempo: 1:40:59, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:30,948 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f7_BERTimbau_large, Data: 30/04/2022 03:18, Tempo: 1:42:04, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:31,564 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f8_BERTimbau_large, Data: 30/04/2022 23:15, Tempo: 1:42:43, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:32,170 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f9_BERTimbau_large, Data: 01/05/2022 04:37, Tempo: 1:41:12, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:32,769 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_f10_BERTimbau_large, Data: 01/05/2022 10:00, Tempo: 1:41:53, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:32,771 : INFO : Total acurácia                                       : 5.00000000.
# 2022-05-03 10:34:32,772 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:34:32,773 : INFO : A média da acurácia de 10 folds é                    : 0.50000000.
# 2022-05-03 10:34:32,774 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 16:55:21.
# 2022-05-03 10:34:32,775 : INFO : A média de tempo de execução de 10 folds é           : 01:41:32.
# 2022-05-03 10:34:32,778 : INFO :
#
# 2022-05-03 10:34:32,779 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:34:32,780 : INFO :    com época 3 e taxa de treinamento 5e-05.
# 2022-05-03 10:34:32,781 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:34:33,498 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f1_BERTimbau_large, Data: 27/04/2022 04:43, Tempo: 2:49:01, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:34,091 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f2_BERTimbau_large, Data: 27/04/2022 10:10, Tempo: 2:48:05, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:34,590 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f3_BERTimbau_large, Data: 28/04/2022 00:40, Tempo: 2:47:11, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:35,091 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f4_BERTimbau_large, Data: 28/04/2022 06:02, Tempo: 2:47:58, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:35,740 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f5_BERTimbau_large, Data: 28/04/2022 23:53, Tempo: 2:57:42, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:36,361 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f6_BERTimbau_large, Data: 29/04/2022 23:04, Tempo: 2:49:20, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:36,980 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f7_BERTimbau_large, Data: 30/04/2022 04:26, Tempo: 2:50:16, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:37,869 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f8_BERTimbau_large, Data: 01/05/2022 00:23, Tempo: 2:50:57, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:38,479 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f9_BERTimbau_large, Data: 01/05/2022 05:44, Tempo: 2:48:24, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:39,134 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_f10_BERTimbau_large, Data: 01/05/2022 11:08, Tempo: 2:49:47, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:39,135 : INFO : Total acurácia                                       : 5.00000000.
# 2022-05-03 10:34:39,136 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:34:39,137 : INFO : A média da acurácia de 10 folds é                    : 0.50000000.
# 2022-05-03 10:34:39,138 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 28:18:41.
# 2022-05-03 10:34:39,140 : INFO : A média de tempo de execução de 10 folds é           : 02:49:52.
# 2022-05-03 10:34:39,146 : INFO :
#
# 2022-05-03 10:34:39,148 : INFO : Acurácia do modelo: neuralmind/bert-large-portuguese-cased
# 2022-05-03 10:34:39,151 : INFO :    com época 4 e taxa de treinamento 5e-05.
# 2022-05-03 10:34:39,153 : INFO : Média dos arquivos: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_fX_BERTimbau_large
# 2022-05-03 10:34:39,785 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f1_BERTimbau_large, Data: 27/04/2022 06:18, Tempo: 4:23:25, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:40,857 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f2_BERTimbau_large, Data: 27/04/2022 11:41, Tempo: 4:18:57, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:41,335 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f3_BERTimbau_large, Data: 28/04/2022 02:10, Tempo: 4:16:38, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:41,859 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f4_BERTimbau_large, Data: 28/04/2022 07:33, Tempo: 4:18:51, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:42,555 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f5_BERTimbau_large, Data: 29/04/2022 01:30, Tempo: 4:35:06, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:43,164 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f6_BERTimbau_large, Data: 30/04/2022 00:33, Tempo: 4:17:58, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:43,771 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f7_BERTimbau_large, Data: 30/04/2022 05:57, Tempo: 4:21:41, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:45,417 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f8_BERTimbau_large, Data: 01/05/2022 01:54, Tempo: 4:21:15, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:46,089 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f9_BERTimbau_large, Data: 01/05/2022 07:15, Tempo: 4:19:27, QtdeTeste: 28380, Acc: 0.50000000, Rec: 1.00000000, Pre: 0.50000000, F1:0.66666667, vp: 14190; vn:    0; fp: 14190; fn:    0
# 2022-05-03 10:34:46,810 : INFO : Arquivo: AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_f10_BERTimbau_large, Data: 01/05/2022 12:39, Tempo: 4:21:19, QtdeTeste: 28380, Acc: 0.50000000, Rec: 0.00000000, Pre: 0.00000000, F1:0.00000000, vp:    0; vn: 14190; fp:    0; fn: 14190
# 2022-05-03 10:34:46,812 : INFO : Total acurácia                                       : 5.00000000.
# 2022-05-03 10:34:46,813 : INFO : Quantidade de folds                                  : 10.
# 2022-05-03 10:34:46,814 : INFO : A média da acurácia de 10 folds é                    : 0.50000000.
# 2022-05-03 10:34:46,815 : INFO : O tempo gasto na execução do treinamentoa 10 folds é : 43:34:37.
# 2022-05-03 10:34:46,819 : INFO : A média de tempo de execução de 10 folds é           : 04:21:27.

# %% [markdown]
# Resumo da execução

# %% [markdown]
# Acurácia por época.

# %%
for i, linha in enumerate(lista_resultado_execucoes):  
  if "e_1" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_fX_BERTimbau_large;0.9815539112050742;08:51:45
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_fX_BERTimbau_large;0.9771317829457363;09:25:22
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_fX_BERTimbau_large;0.6394679351656096;09:20:53
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_fX_BERTimbau_large;0.5319485553206483;08:36:59
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_fX_BERTimbau_large;0.5;08:14:55

# %%
for i, linha in enumerate(lista_resultado_execucoes):
  if "_e_2" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_fX_BERTimbau_large;0.9856800563777309;18:32:42
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_fX_BERTimbau_large;0.9136539816772375;19:59:09
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_fX_BERTimbau_large;0.5;19:44:20
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_fX_BERTimbau_large;0.5;17:53:01
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_fX_BERTimbau_large;0.5;16:55:21

# %%
for i, linha in enumerate(lista_resultado_execucoes):
  if "_e_3" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_fX_BERTimbau_large;0.989016913319239;30:50:23
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_fX_BERTimbau_large;0.8514411557434813;33:15:56
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_fX_BERTimbau_large;0.5;32:44:03
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_fX_BERTimbau_large;0.5;29:48:58
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_fX_BERTimbau_large;0.5;28:18:41

# %%
for i, linha in enumerate(lista_resultado_execucoes):
  if "_e_4" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_fX_BERTimbau_large;0.9887174066243836;47:10:39
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_fX_BERTimbau_large;0.7122903453136011;50:40:11
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_fX_BERTimbau_large;0.5;49:50:59
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_fX_BERTimbau_large;0.5;45:41:58
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_fX_BERTimbau_large;0.5;43:34:37

# %% [markdown]
# Acurácia por taxa de aprendizagem.

# %%
for i, linha in enumerate(lista_resultado_execucoes):
  if "_lr_1" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_1_b_16_16_fX_BERTimbau_large;0.9815539112050742;08:51:45
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_1_b_16_16_fX_BERTimbau_large;0.9856800563777309;18:32:42
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_1_b_16_16_fX_BERTimbau_large;0.989016913319239;30:50:23
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_1_b_16_16_fX_BERTimbau_large;0.9887174066243836;47:10:39

# %%
for i, linha in enumerate(lista_resultado_execucoes):
  if "_lr_2" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_2_b_16_16_fX_BERTimbau_large;0.9771317829457363;09:25:22
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_2_b_16_16_fX_BERTimbau_large;0.9136539816772375;19:59:09
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_2_b_16_16_fX_BERTimbau_large;0.8514411557434813;33:15:56
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_2_b_16_16_fX_BERTimbau_large;0.7122903453136011;50:40:11

# %%
for i, linha in enumerate(lista_resultado_execucoes):
  if "_lr_3" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_3_b_16_16_fX_BERTimbau_large;0.6394679351656096;09:20:53
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_3_b_16_16_fX_BERTimbau_large;0.5;19:44:20
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_3_b_16_16_fX_BERTimbau_large;0.5;32:44:03
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_3_b_16_16_fX_BERTimbau_large;0.5;49:50:59

# %%
for i, linha in enumerate(lista_resultado_execucoes):
  if "_lr_4" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_4_b_16_16_fX_BERTimbau_large;0.5319485553206483;08:36:59
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_4_b_16_16_fX_BERTimbau_large;0.5;17:53:01
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_4_b_16_16_fX_BERTimbau_large;0.5;29:48:58
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_4_b_16_16_fX_BERTimbau_large;0.5;45:41:58

# %%
for i, linha in enumerate(lista_resultado_execucoes):
  if "_lr_5" in linha:
    print(linha)
# Out:
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_1_lr_5_b_16_16_fX_BERTimbau_large;0.5;08:14:55
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_2_lr_5_b_16_16_fX_BERTimbau_large;0.5;16:55:21
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_3_lr_5_b_16_16_fX_BERTimbau_large;0.5;28:18:41
# AjusteFinoSquad2_P_C_SB_KF_v1_P_100_K_100_E_4_e_4_lr_5_b_16_16_fX_BERTimbau_large;0.5;43:34:37

# %% [markdown]
# # 6 Finalização

# %% [markdown]
# ## 6.1 Tempo final de processamento

# %%
 # Pega o tempo atual menos o tempo do início do processamento.
final_processamento = time.time()
tempo_total_processamento = formataTempo(final_processamento - inicio_processamento)

print("")
print("  Tempo processamento:  {:} (h:mm:ss)".format(tempo_total_processamento))
# Out:
#   Tempo processamento: 10:44:07 (h:mm:ss)
