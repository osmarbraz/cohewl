# %% [markdown]
# # Análise de Correlação do Classificador e Cálculo coerência do conjunto de dados SQUAD 2 P(1,0%).
#
# Realiza a análise de correlação entre as classificações realizadas e o cálculo de medida de coerência utilizando BERT no SQUAD 2 P(1,0%).
#
# ----------------------------
#
# **Link biblioteca Transformers:**
# https://github.com/huggingface/transformers
#
# **Artigo original BERT:**
# https://arxiv.org/pdf/1506.06724.pdf
#
# **Artigo padding dinâmico:**
# https://towardsdatascience.com/divide-hugging-face-transformers-training-time-by-2-or-more-21bf7129db9q-21bf7129db9e

# %% [markdown]
# # 1 Preparação do ambiente
# Preparação do ambiente para execução do exemplo.

# %% [markdown]
# ## 1.1 Tempo inicial de processamento

# %%
# Import das bibliotecas
import time
import datetime

#marca o tempo de início do processamento.
inicio_processamento = time.time()

# %% [markdown]
# ## 1.2 Funções e classes auxiliares

# %% [markdown]
# Verifica se existe o diretório cohebert no diretório corrente.

# %%
# Import das bibliotecas.
import os # Biblioteca para manipular arquivos

# ============================  
def verificaDiretorioCoheBERT():
    """
      Verifica se existe o diretório cohebert no diretório corrente.    
    """
    
    # Verifica se o diretório existe
    if not os.path.exists(DIRETORIO_COHEBERT):  
        # Cria o diretório
        os.makedirs(DIRETORIO_COHEBERT)
        logging.info("Diretório Cohebert criado: {}".format(DIRETORIO_COHEBERT))
    
    return DIRETORIO_COHEBERT

# %% [markdown]
# Realiza o download e um arquivo

# %%
# Import das bibliotecas.
import requests # Biblioteca de download
from tqdm.notebook import tqdm as tqdm_notebook # Biblioteca para barra de progresso
import os # Biblioteca para manipular arquivos

def downloadArquivo(url_arquivo, nome_arquivo_destino):
    """    
      Realiza o download de um arquivo de uma url em salva em nome_arquivo_destino.
    
      Parâmetros:
        `url_arquivo` - URL do arquivo a ser feito download.      
        `nome_arquivo_destino` - Nome do arquivo a ser salvo.      
    """
    
    # Verifica se existe o diretório base
    DIRETORIO_COHEBERT = verificaDiretorioCoheBERT()
    
    # Realiza o download de um arquivo em uma url
    data = requests.get(url_arquivo, stream=True)
    
    # Verifica se o arquivo existe
    if data.status_code != 200:
        logging.info("Exceção ao tentar realizar download {}. Response {}.".format(url_arquivo, data.status_code))
        data.raise_for_status()
        return

    # Recupera o nome do arquivo a ser realizado o download    
    nome_arquivo = nome_arquivo_destino.split("/")[-1]  

    # Define o nome e caminho do arquivo temporário    
    nome_arquivo_temporario = DIRETORIO_COHEBERT + "/" + nome_arquivo + "_part"
    
    logging.info("Download do arquivo: {}.".format(nome_arquivo_destino))
    
    # Baixa o arquivo
    with open(nome_arquivo_temporario, "wb") as arquivo_binario:        
        tamanho_conteudo = data.headers.get("Content-Length")        
        total = int(tamanho_conteudo) if tamanho_conteudo is not None else None
        # Barra de progresso de download
        progresso_bar = tqdm_notebook(unit="B", total=total, unit_scale=True)                
        # Atualiza a barra de progresso
        for chunk in data.iter_content(chunk_size=1024):        
            if chunk:                
                progresso_bar.update(len(chunk))
                arquivo_binario.write(chunk)
    
    # Renomeia o arquivo temporário para o arquivo definitivo
    os.rename(nome_arquivo_temporario, nome_arquivo_destino)
    
    # Fecha a barra de progresso.
    progresso_bar.close()

# %% [markdown]
# Remove tags de um documento

# %%
def remove_tags(documento):
    """
      Remove tags de um documento
    """
    
    import re

    documento_limpo = re.compile("<.*?>")
    return re.sub(documento_limpo, "", documento)

# %% [markdown]
# Funções auxiliares de arquivos

# %%
def carregar(nome_arquivo, encoding="Windows-1252"):
    """
      Carrega um arquivo texto e retorna as linhas como um único parágrafo(texto).
    
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser carregado.  
    """

    # Abre o arquivo
    arquivo = open(nome_arquivo, "r", encoding= encoding)
    
    paragrafo = ""
    for linha in arquivo:
        linha = linha.splitlines()
        linha = " ".join(linha)
        # Remove as tags existentes no final das linhas
        linha = remove_tags(linha)
        if linha != "":
          paragrafo = paragrafo + linha.strip() + " "
    
    # Fecha o arquivo
    arquivo.close()

    # Remove os espaços em branco antes e depois do parágrafo
    return paragrafo.strip()

# %%
def carregarLista(nome_arquivo, encoding="Windows-1252"):
    """
      Carrega um arquivo texto e retorna as linhas como uma lista de sentenças(texto).
    
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser carregado.   
        `encoding` - Codificação dos caracteres do arquivo.
    """

    # Abre o arquivo
    arquivo = open(nome_arquivo, "r", encoding= encoding)
    
    sentencas = []
    for linha in arquivo:        
        linha = linha.splitlines()
        linha = " ".join(linha)
        linha = remove_tags(linha)
        if linha != "":
          sentencas.append(linha.strip())
    
    # Fecha o arquivo
    arquivo.close()

    return sentencas

# %%
def salvar(nome_arquivo,texto):                       
    """
      Salva um texto em arquivo.
     
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser salvo.
        `texto` - Texto a ser salvo.     
    """

    arquivo = open(nome_arquivo, "w")
    arquivo.write(str(texto))
    arquivo.close()

# %% [markdown]
# Função auxiliar para formatar o tempo como `hh: mm: ss`

# %%
# Import das bibliotecas.
import time
import datetime

def formataTempo(tempo):
    """
      Pega a tempo em segundos e retorna uma string hh:mm:ss
    """
    # Arredonda para o segundo mais próximo.
    tempo_arredondado = int(round((tempo)))
    
    # Formata como hh:mm:ss
    return str(datetime.timedelta(seconds=tempo_arredondado))

# %% [markdown]
# Calcula a média de uma lista tempo string no formato hh:mm:ss.

# %%
# Import das bibliotecas.
from cmath import rect, phase
from math import radians, degrees
  
def mediaAngulo(deg):
    return degrees(phase(sum(rect(1, radians(d)) for d in deg)/len(deg)))
 
def mediaTempo(tempos):
    '''
    Calcula a média de uma lista de tempo string no formato hh:mm:ss
    '''
    t = (tempo.split(':') for tempo in tempos)
    # Converte para segundos
    segundos = ((float(s) + int(m) * 60 + int(h) * 3600) for h, m, s in t)
    # Verifica se deu algum dia
    dia = 24 * 60 * 60
    # Converte para angulos
    para_angulos = [s * 360. / dia for s in segundos]
    # Calcula a média dos angulos
    media_como_angulo = mediaAngulo(para_angulos)
    media_segundos = media_como_angulo * dia / 360.
    if media_segundos < 0:
        media_segundos += dia
    # Recupera as horas e os minutos  
    h, m = divmod(media_segundos, 3600)
    # Recupera os minutos e os segundos
    m, s = divmod(m, 60)    
    return '{:02d}:{:02d}:{:02d}'.format(int(h), int(m), int(s))

# %% [markdown]
# Calcula a soma de uma lista de tempo string no formato hh:mm:ss

# %%
def somaTempo(tempos):
    '''
    Calcula a soma de uma lista de tempo string no formato hh:mm:ss
    '''
    t = (tempo.split(':') for tempo in tempos)
    # Converte para segundos
    segundos = ((float(s) + int(m) * 60 + int(h) * 3600) for h, m, s in t)
    # Soma os segundos
    soma_segundos = sum([s * 1. for s in segundos])
    # Recupera as horas e os minutos   
    h, m = divmod(soma_segundos, 3600)
    # Recupera os minutos e os segundos
    m, s = divmod(m, 60)    
    return '{:02d}:{:02d}:{:02d}'.format(int(h), int(m), int(s))

# %% [markdown]
# Classe(ModeloArgumentosMedida) de definição dos parâmetros do modelo para medida

# %%
# Import das bibliotecas.
from dataclasses import dataclass, field
from typing import Dict, Optional
from typing import List

@dataclass
class ModeloArgumentosMedida:
    max_seq_len: Optional[int] = field(
        default=None,
        metadata={'help': 'max seq len'},
    )    
    pretrained_model_name_or_path: str = field(
        default='neuralmind/bert-base-portuguese-cased',
        metadata={'help': 'nome do modelo pré-treinado do BERT.'},
    )
    modelo_spacy: str = field(
        default="pt_core_news_lg",
        metadata={"help": "nome do modelo do spaCy."},
    )
    versao_modelo_spacy: str = field(
        default="-3.2.0",
        metadata={"help": "versão do nome do modelo no spaCy."},
    )
    do_lower_case: bool = field(
        default=False,
        metadata={'help': 'define se o texto do modelo deve ser todo em minúsculo.'},
    )  
    output_attentions: bool = field(
        default=False,
        metadata={'help': 'habilita se o modelo retorna os pesos de atenção.'},
    )
    output_hidden_states: bool = field(
        default=False,
        metadata={'help': 'habilita gerar as camadas ocultas do modelo.'},
    )
    use_wandb : bool = field(
        default=True,
        metadata={'help': 'habilita o uso do wandb.'},
    )
    salvar_avaliacao : bool = field(
        default=True,
        metadata={'help': 'habilita o salvamento do resultado da avaliação.'},
    )     
    salvar_medicao : bool = field(
        default=False,
        metadata={'help': 'habilita o salvamento da medicao.'},
    )
    usar_mcl_ajustado : bool = field(
        default=False,
        metadata={'help': 'habilita o carragamento de mcl ajustado.'},
    )
    top_k_predicao: int = field(
        default="100",
        metadata={"help": "Quantidade de palavras a serem recuperadas mais próximas da máscara."},
    )
    numero_documentos_perturbados: int = field(
        default="1",
        metadata={"help": "Quantidade de documentos a serem perturbados a partir do original."},
    )
    estrategia_medida: int = field(
        default=0, # 0 - MEAN estratégia média / 1 - MAX  estratégia maior
        metadata={'help': 'Estratégia de cálculo da médida dos embeddings.'},
    )
    filtro_palavra: int = field(
        default=0, # 0 - Considera todas as palavras das sentenças / 1 - Desconsidera as stopwords / 2 - Considera somente as palavras substantivas
        metadata={'help': 'Define o filtro de palavras das sentenças para gerar os embeddings.'},
    )

# %% [markdown]
# Biblioteca de limpeza de tela

# %%
# Import das bibliotecas.
from IPython.display import clear_output

# %% [markdown]
# ## 1.3 Tratamento de logs

# %%
# Import das bibliotecas.
import logging # Biblioteca de logging

# Formatando a mensagem de logging
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s")

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ## 1.4  Identificando o ambiente Colab

# %%
# Se estiver executando no Google Colaboratory.
import sys

# Retorna true ou false se estiver no Google Colaboratory.
IN_COLAB = 'google.colab' in sys.modules

# %% [markdown]
# ## 1.5 Colaboratory

# %% [markdown]
# Usando Colab GPU para Treinamento

# %% [markdown]
# Uma GPU pode ser adicionada acessando o menu e selecionando:
#
# `Edit -> Notebook Settings -> Hardware accelerator -> (GPU)`
#
# Em seguida, execute a célula a seguir para confirmar que a GPU foi detectada.

# %%
# Import das bibliotecas.
import tensorflow as tf

# Recupera o nome do dispositido da GPU.
device_name = tf.test.gpu_device_name()

# O nome do dispositivo deve ser parecido com o seguinte:
if device_name == "/device:GPU:0":
    logging.info("Encontrei GPU em: {}".format(device_name))
else:
    logging.info("Dispositivo GPU não encontrado")
    #raise SystemError("Dispositivo GPU não encontrado")
# Out:
# 2022-03-18 12:45:40,206 : INFO : NumExpr defaulting to 2 threads.
# 2022-03-18 12:45:41,046 : INFO : Dispositivo GPU não encontrado

# %% [markdown]
# Nome da GPU
#
# Para que a torch use a GPU, precisamos identificar e especificar a GPU como o dispositivo. Posteriormente, em nosso ciclo de treinamento, carregaremos dados no dispositivo.
#
# Vale a pena observar qual GPU você recebeu. A GPU Tesla P100 é muito mais rápido que as outras GPUs, abaixo uma lista ordenada:
# - 1o Tesla P100
# - 2o Tesla T4
# - 3o Tesla P4 (Não tem memória para execução 4 x 8, somente 2 x 4)
# - 4o Tesla K80 (Não tem memória para execução 4 x 8, somente 2 x 4)

# %%
# Import das bibliotecas.
import torch

def getDeviceGPU():
    """
      Retorna um dispositivo de GPU se disponível ou CPU.
    
      Retorno:
        `device` - Um device de GPU ou CPU.       
    """
        
    # Se existe GPU disponível.
    if torch.cuda.is_available():
        
        # Diz ao PyTorch para usar GPU.    
        device = torch.device("cuda")
        
        logging.info("Existem {} GPU(s) disponíveis.".format(torch.cuda.device_count()))
        logging.info("Iremos usar a GPU: {}.".format(torch.cuda.get_device_name(0)))

    # Se não.
    else:        
        logging.info("Sem GPU disponível, usando CPU.")
        device = torch.device("cpu")
        
    return device

# %%
# Recupera o device com GPU ou CPU
device = getDeviceGPU()
# Out:
# 2022-03-18 12:45:47,893 : INFO : Sem GPU disponível, usando CPU.

# %% [markdown]
# Memória
#
# Memória disponível no ambiente

# %%
# Importando as bibliotecas.
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
logging.info("Seu ambiente de execução tem {: .1f} gigabytes de RAM disponível\n".format(ram_gb))

if ram_gb < 20:
  logging.info("Para habilitar um tempo de execução de RAM alta, selecione menu o ambiente de execução> \"Alterar tipo de tempo de execução\"")
  logging.info("e selecione High-RAM. Então, execute novamente está célula")
else:
  logging.info("Você está usando um ambiente de execução de memória RAM alta!")
# Out:
# 2022-03-18 12:45:47,938 : INFO : Seu ambiente de execução tem  13.6 gigabytes de RAM disponível
#
# 2022-03-18 12:45:47,946 : INFO : Para habilitar um tempo de execução de RAM alta, selecione menu o ambiente de execução> "Alterar tipo de tempo de execução"
# 2022-03-18 12:45:47,957 : INFO : e selecione High-RAM. Então, execute novamente está célula

# %% [markdown]
# ## 1.6 Monta uma pasta no google drive para carregar os arquivos de dados.

# %%
# import necessário
from google.colab import drive

# Monta o drive na pasta especificada
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2 Parametrização

# %% [markdown]
# ## Gerais

# %%
# Definição dos parâmetros a serem avaliados
#Quantidade de documentos a serem perturbados a partir do original.
NUMERO_DOCUMENTOS_PERTURBADOS = 1

#Quantidade de palavras a serem recuperadas mais próximas da máscara.
TOP_K_PREDICAO = 1

# %% [markdown]
# ## Específicos

# %% [markdown]
# Parâmetros do modelo

# %%
# Definição dos parâmetros do Modelo
model_args = ModeloArgumentosMedida(     
    max_seq_len = 512,    
    
    pretrained_model_name_or_path = "bert-large-uncased",
    #pretrained_model_name_or_path = "bert-base-uncased"
    #pretrained_model_name_or_path = "neuralmind/bert-large-portuguese-cased",
    #pretrained_model_name_or_path = "neuralmind/bert-base-portuguese-cased",    
    #pretrained_model_name_or_path = "bert-base-multilingual-cased",
    #pretrained_model_name_or_path = "bert-base-multilingual-uncased",

    modelo_spacy = "en_core_web_lg",
    #modelo_spacy = "en_core_web_md",
    #modelo_spacy = "en_core_web_sm",
    #modelo_spacy = "pt_core_news_lg",
    #modelo_spacy = "pt_core_news_md",
    #modelo_spacy = "pt_core_news_sm",
    versao_modelo_spacy = "3.2.0",
    do_lower_case = False,  # default True
    output_attentions = False,  # default False
    output_hidden_states = True, # default False
    use_wandb = True,    
    salvar_medicao = True, #Salva o resultado da medição
    salvar_avaliacao = True, # Salva o resultado da avaliação das medições
    usar_mcl_ajustado = False, # Especifica se deve ser carregado um MCL ajustado ou pré-treinado. Necessário especificar o tipo do modelo em pretrained_model_name_or_path. 
    numero_documentos_perturbados = NUMERO_DOCUMENTOS_PERTURBADOS, # Quantidade de documentos a serem perturbados a partir do original.
    top_k_predicao = TOP_K_PREDICAO, # Conjunto de valores: 1, 10, 100, 500 e 1000. Quantidade de palavras a serem recuperadas mais próximas da máscara. 
    estrategia_medida = 0, # Atributo usado para os logs do wandb. 0 - MEAN estratégia média / 1 - MAX  estratégia maior
    filtro_palavra = 0 # Atributo usado para os logs do wandb. 0 - Considera todas as palavras das sentenças / 1 - Desconsidera as stopwords / 2 - Considera somente as palavras substantivas
)

# %% [markdown]
# ## Nome do diretório dos arquivos de dados

# %%
# Diretório do cohebert
DIRETORIO_COHEBERT = "SQUAD2_P_EN"

# %% [markdown]
# ## Define o caminho para os arquivos de dados

# %%
# Diretório local para os arquivos pré-processados
DIRETORIO_LOCAL = "/content/" + DIRETORIO_COHEBERT + "/"

# Diretório no google drive com os arquivos pré-processados
DIRETORIO_DRIVE = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/"

# %% [markdown]
# # 3 Resultado do Classificador Binário usando o Método Kfold

# %%
# Nome base das saidas do projeto C = Cris, SB = SmartBatch, KF = KFold
NOME_BASE_SAIDA = "AjusteFinoSquad2_P_C_SB_KF_v1"

# %% [markdown]
# ## 3.1 Carrega o resultado e parâmetros da melhor classificação

# %% [markdown]
# ### 3.1.1 Função que encontra a melhor classificação

# %%
# Import das bibliotecas.
import os
import pandas as pd

def getResultadosClassificacaoKFold(DIRETORIO_COHEBERT, 
                                    _DOCUMENTOS_PERTURBADOS, 
                                    _TOP_K_PREDICAO):
  
  # Numero de Folds
  KFOLDS = 10

  # Quantidade de documentos a serem perturbados a partir do original.    
  DOCUMENTOS_PERTURBADOS = _DOCUMENTOS_PERTURBADOS

  # Quantidade de palavras a serem recuperadas mais próximas da máscara. 
  TOP_K_PREDICAO = _TOP_K_PREDICAO

  # MCL a serem avaliados
  #MODELO_BERT = ['_BERTimbau','_BERTmultilingual']
  MODELO_BERT = ['_BERTimbau']

  #TAMANHO_BERT = ['_base','_large']
  TAMANHO_BERT = ['_large']
  
  # Taxa de aprendizagem do nome do arquivo
  TAXAS_DE_APRENDIZAGEM = [1, 2, 3, 4, 5]

  # Tamanho dos lotes
  TAMANHO_LOTE = [16, 32]

  # Salva resultados intermediários
  EPOCA = [2, 3, 4]

  # Diretório para salvar o arquivo.
  DIRETORIO_AVALIACAO = "/content/drive/My Drive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_classificacao_palavra/kfold/Avaliacao/"  

  MELHOR_DOCUMENTOS_PERTURBADOS = 0
  MELHOR_TOP_K_PREDICAO = 0
  MELHOR_TAXAS_DE_APRENDIZAGEM = 0
  MELHOR_TAMANHO_LOTE = 0
  MELHOR_EPOCA_EXECUCA = 0
  MELHOR_ACURACIA = 0
  MELHOR_TEMPO = 0

  lista_resultados = []

  lista_tempo_total = []  
  
  # Verifica se o diretório dos resultados existe.
  if os.path.exists(DIRETORIO_AVALIACAO):    
    for modelo in MODELO_BERT:    
      for tamanho in TAMANHO_BERT:
        if modelo != '_BERTmultilingual' or tamanho != '_large':                  
          for documentos_perturbados in DOCUMENTOS_PERTURBADOS:
            for top_k_predicao in TOP_K_PREDICAO:              
              DIRETORIO_AVALIACAO_PK = DIRETORIO_AVALIACAO + "P_" + str(documentos_perturbados) + "_K_" + str(top_k_predicao) + "/"              
              # Verifica se o diretório dos resultados existe.
              if os.path.exists(DIRETORIO_AVALIACAO_PK):
                arquivos = os.listdir(DIRETORIO_AVALIACAO_PK)                 
                for lote in TAMANHO_LOTE:
                  for taxaaprendizagem in TAXAS_DE_APRENDIZAGEM:                      
                    for epoca in EPOCA:  
                        # Acumuladores.
                        soma_acuracia = 0
                        lista_tempo = []
                        conta_folds = 0 
                        conta_reg = 0
                        
                        for i in range(len(arquivos)):
                          for fold in range(1,11):
                            # Filtra o nome do arquivo a ser avaliado                                                     
                            if ((("_P_" + str(documentos_perturbados)+"_") in arquivos[i]) 
                                  and (("_K_" + str(top_k_predicao)+"_") in arquivos[i]) 
                                  and (("_b_" + str(lote)) in arquivos[i]) 
                                  and (modelo in arquivos[i]) 
                                  and (tamanho in arquivos[i]) 
                                  and (('_f' + str(fold) + '_') in arquivos[i]) 
                                  and (("e_" + str(epoca)) in arquivos[i]) 
                                  and (("lr_" + str(taxaaprendizagem)) in arquivos[i])):                           

                                NOME_ARQUIVO_AVALIACAO_COMPLETO = DIRETORIO_AVALIACAO_PK + arquivos[i]                              
                                # Verifica se o arquivo existe.
                                if os.path.isfile(NOME_ARQUIVO_AVALIACAO_COMPLETO):
                                  # Carrega os dados do arquivo  
                                  dados = pd.read_csv(NOME_ARQUIVO_AVALIACAO_COMPLETO, sep=';')
                      
                                  # Conta o número de folds.
                                  conta_folds = conta_folds + 1
                                  
                                  # Mostra os dados do teste do fold.
                                  for index, linha in dados.iterrows():        
                                    # Cálculo das estatísticas
                                    acc = (linha['vp']+linha['vn'])/(linha['vp']+linha['vn']+linha['fp']+linha['fn'])                         
                                    #print('{};{};{};{:.8f};{}'.format(fold, index, arquivos[i],acc,linha['tempo']))
                                    # Guarda o tempo.
                                    lista_tempo.append(str(linha['tempo']))
                                    # Conta o número de registros.
                                    conta_reg = conta_reg + 1
                                    
                                  # Realiza a soma da acurácia do arquivo.
                                  soma_acuracia = soma_acuracia + dados['acuracia'].sum()
                                        
                        if conta_folds != 0:
                          # Calcula a média.                          
                          media_acuracia = soma_acuracia/conta_reg

                          # Guarda os resultados de todos os folds  
                          lista_resultados.append([documentos_perturbados,top_k_predicao,taxaaprendizagem,lote,epoca, media_acuracia, somaTempo(lista_tempo)])
                          
                          if media_acuracia > MELHOR_ACURACIA:
                              MELHOR_DOCUMENTOS_PERTURBADOS = documentos_perturbados
                              MELHOR_TOP_K_PREDICAO = top_k_predicao
                              MELHOR_TAXAS_DE_APRENDIZAGEM = taxaaprendizagem
                              MELHOR_TAMANHO_LOTE = lote
                              MELHOR_EPOCA_EXECUCAO = epoca
                              MELHOR_ACURACIA = media_acuracia
                              MELHOR_TEMPO = somaTempo(lista_tempo)
                       
                        else:                          
                            print('Nenhum arquivo de avaliação encontrado')
                
              else:
                print('Diretório ' + 'P_' + str(documentos_perturbados) + '_K_' + str(top_k_predicao) + ' não encontrado')                        
    
    # Retorno do melhor valor
    lista_resultado_ordenado = sorted(lista_resultados, key=lambda x: x[5], reverse=True)
    return MELHOR_DOCUMENTOS_PERTURBADOS, MELHOR_TOP_K_PREDICAO, MELHOR_TAXAS_DE_APRENDIZAGEM, MELHOR_TAMANHO_LOTE, MELHOR_EPOCA_EXECUCAO, MELHOR_ACURACIA, MELHOR_TEMPO, lista_resultado_ordenado
  else:
    print('Diretório com os resultados não encontrado')

# %% [markdown]
# Recupera os melhores resultados

# %%
DOCUMENTOS_PERTURBADOS = [1, 20, 100]
TOP_K_PREDICAO = [1, 20, 100]

# Recupera os melhores parâmetros
MELHOR_DOCUMENTOS_PERTURBADOS, MELHOR_TOP_K_PREDICAO, MELHOR_TAXAS_DE_APRENDIZAGEM, MELHOR_TAMANHO_LOTE, MELHOR_EPOCA_EXECUCAO, MELHOR_ACURACIA, MELHOR_TEMPO, lista_resultados = getResultadosClassificacaoKFold(DIRETORIO_COHEBERT, DOCUMENTOS_PERTURBADOS, TOP_K_PREDICAO)

# %%
print("Parâmetros da melhor acurácia do classificador")
print("\n  Documentos Perturbados:", MELHOR_DOCUMENTOS_PERTURBADOS, 
      "\n  Top k predição        :", MELHOR_TOP_K_PREDICAO, 
      "\n  Taxa de aprendizagem  :", MELHOR_TAXAS_DE_APRENDIZAGEM, 
      "\n  Lote                  :", MELHOR_TAMANHO_LOTE, 
      "\n  Epoca execução        :", MELHOR_EPOCA_EXECUCAO, 
      "\n  Acurácia              :", MELHOR_ACURACIA, 
      "\n  Tempo execução        :", MELHOR_TEMPO)

print("\nLista das acurácias ranqueadas")
for i, linha in enumerate(lista_resultados):
    print((i+1),"=", linha)
# Out:
# Parâmetros da melhor acurácia do classificador
#
#   Documentos Perturbados: 20
#   Top k predição        : 100
#   Taxa de aprendizagem  : 4
#   Lote                  : 16
#   Epoca execução        : 4
#   Acurácia              : 0.9962500000000001
#   Tempo execução        : 00:09:33
#
# Lista das acurácias ranqueadas
# 1 = [20, 100, 4, 16, 4, 0.9962500000000001, '00:09:33']
# 2 = [20, 1000, 4, 16, 4, 0.9949999999999999, '00:12:00']
# 3 = [20, 1, 5, 32, 4, 0.9887499999999999, '00:10:19']
# 4 = [20, 1000, 2, 16, 4, 0.9862499999999998, '00:11:49']
# 5 = [20, 1, 5, 16, 4, 0.98375, '00:11:42']
# 6 = [20, 100, 3, 16, 4, 0.98125, '00:09:36']
# 7 = [20, 1000, 2, 16, 3, 0.98125, '00:08:44']
# 8 = [20, 1000, 3, 16, 3, 0.98125, '00:08:49']
# 9 = [20, 1000, 3, 16, 4, 0.98125, '00:12:02']
# 10 = [20, 1000, 4, 16, 3, 0.98125, '00:08:51']
# 11 = [20, 1000, 5, 16, 4, 0.98125, '00:12:02']
# 12 = [20, 100, 2, 16, 4, 0.97875, '00:09:27']
# 13 = [20, 100, 4, 32, 4, 0.9775, '00:10:05']
# 14 = [20, 1, 4, 16, 4, 0.975, '00:11:32']
# 15 = [20, 1, 3, 16, 4, 0.9737500000000001, '00:11:47']
# 16 = [20, 10, 3, 16, 4, 0.9725000000000001, '00:11:19']
# 17 = [20, 1, 4, 32, 4, 0.9724999999999999, '00:10:24']
# 18 = [20, 1, 2, 16, 4, 0.9712500000000001, '00:11:31']
# 19 = [20, 100, 5, 16, 4, 0.9700000000000001, '00:09:38']
# 20 = [20, 10, 4, 16, 4, 0.96875, '00:11:16']
# 21 = [20, 1000, 3, 32, 4, 0.96875, '00:10:10']
# 22 = [20, 1, 4, 16, 3, 0.9637500000000001, '00:08:30']
# 23 = [20, 1000, 5, 32, 4, 0.9637499999999999, '00:10:04']
# 24 = [20, 1000, 5, 16, 3, 0.96125, '00:08:51']
# 25 = [20, 1, 1, 16, 4, 0.96, '00:11:08']
# 26 = [20, 100, 3, 16, 3, 0.96, '00:07:04']
# 27 = [20, 10, 5, 16, 4, 0.9575000000000001, '00:11:30']
# 28 = [20, 100, 4, 16, 3, 0.9574999999999999, '00:07:06']
# 29 = [20, 1, 3, 32, 4, 0.95625, '00:10:37']
# 30 = [20, 1, 5, 16, 3, 0.9550000000000001, '00:08:34']
# 31 = [20, 1000, 2, 32, 4, 0.9549999999999997, '00:10:10']
# 32 = [20, 1000, 1, 16, 4, 0.9537500000000001, '00:11:29']
# 33 = [20, 100, 5, 16, 3, 0.95375, '00:07:08']
# 34 = [20, 1000, 4, 16, 2, 0.9524999999999999, '00:05:38']
# 35 = [20, 10, 2, 16, 4, 0.9512500000000002, '00:11:11']
# 36 = [20, 1, 2, 32, 4, 0.9512499999999999, '00:10:23']
# 37 = [20, 100, 5, 32, 4, 0.9512499999999999, '00:10:06']
# 38 = [20, 1000, 1, 16, 3, 0.9512499999999999, '00:08:26']
# 39 = [20, 10, 5, 32, 4, 0.95, '00:10:15']
# 40 = [20, 1000, 3, 16, 2, 0.95, '00:05:39']
# 41 = [20, 100, 4, 16, 2, 0.9487500000000001, '00:04:39']
# 42 = [20, 10, 3, 32, 4, 0.9475, '00:10:23']
# 43 = [20, 100, 2, 16, 3, 0.9474999999999998, '00:06:55']
# 44 = [20, 1000, 4, 32, 4, 0.9474999999999998, '00:10:12']
# 45 = [20, 1, 3, 16, 3, 0.9425000000000001, '00:08:39']
# 46 = [20, 10, 5, 16, 3, 0.9425000000000001, '00:08:25']
# 47 = [20, 100, 1, 16, 4, 0.9425000000000001, '00:09:00']
# 48 = [20, 100, 3, 32, 4, 0.9425000000000001, '00:10:07']
# 49 = [20, 1000, 5, 16, 2, 0.9400000000000001, '00:05:40']
# 50 = [20, 1000, 1, 32, 4, 0.9387500000000001, '00:09:57']
# 51 = [20, 1000, 5, 32, 3, 0.9387500000000001, '00:07:24']
# 52 = [20, 1, 2, 16, 3, 0.93625, '00:08:28']
# 53 = [20, 10, 1, 16, 4, 0.93625, '00:10:56']
# 54 = [20, 1000, 2, 16, 2, 0.9337500000000001, '00:05:35']
# 55 = [20, 100, 3, 16, 2, 0.93125, '00:04:36']
# 56 = [20, 10, 4, 16, 3, 0.9275, '00:08:17']
# 57 = [20, 10, 3, 32, 3, 0.9275, '00:07:38']
# 58 = [20, 10, 4, 32, 4, 0.9262499999999999, '00:10:16']
# 59 = [20, 1000, 4, 32, 3, 0.925, '00:07:28']
# 60 = [20, 1, 1, 16, 3, 0.9237499999999998, '00:08:10']
# 61 = [20, 10, 2, 16, 3, 0.9237499999999998, '00:08:12']
# 62 = [20, 1000, 3, 32, 3, 0.9212500000000002, '00:07:28']
# 63 = [20, 10, 3, 16, 2, 0.9199999999999999, '00:05:21']
# 64 = [20, 1, 3, 32, 3, 0.9187500000000002, '00:07:45']
# 65 = [20, 10, 3, 16, 3, 0.91875, '00:08:18']
# 66 = [20, 1, 4, 16, 2, 0.9175000000000001, '00:05:26']
# 67 = [20, 10, 2, 32, 4, 0.9174999999999999, '00:10:21']
# 68 = [20, 10, 1, 16, 3, 0.91625, '00:08:00']
# 69 = [20, 1, 5, 16, 2, 0.915, '00:05:27']
# 70 = [20, 100, 2, 32, 4, 0.915, '00:10:07']
# 71 = [20, 100, 5, 32, 3, 0.915, '00:07:25']
# 72 = [20, 1, 3, 16, 2, 0.9137500000000001, '00:05:35']
# 73 = [20, 1, 4, 32, 3, 0.9137500000000001, '00:07:36']
# 74 = [20, 1, 1, 32, 4, 0.91375, '00:09:02']
# 75 = [20, 10, 1, 32, 4, 0.91375, '00:10:10']
# 76 = [20, 1, 5, 32, 3, 0.9125, '00:07:37']
# 77 = [20, 1, 2, 32, 3, 0.9112500000000001, '00:07:36']
# 78 = [20, 100, 1, 32, 4, 0.9099999999999999, '00:09:52']
# 79 = [20, 100, 3, 32, 3, 0.9087499999999998, '00:07:28']
# 80 = [20, 1000, 2, 32, 3, 0.9075, '00:07:26']
# 81 = [20, 1, 2, 16, 2, 0.90625, '00:05:28']
# 82 = [20, 10, 5, 16, 2, 0.90625, '00:05:23']
# 83 = [20, 100, 4, 32, 3, 0.9049999999999999, '00:07:25']
# 84 = [20, 100, 5, 16, 2, 0.9037500000000002, '00:04:38']
# 85 = [20, 10, 2, 16, 2, 0.9037499999999999, '00:05:13']
# 86 = [20, 10, 2, 32, 3, 0.9037499999999999, '00:07:35']
# 87 = [20, 100, 1, 16, 3, 0.9037499999999999, '00:06:36']
# 88 = [20, 10, 4, 16, 2, 0.8987499999999999, '00:05:17']
# 89 = [20, 10, 4, 32, 3, 0.8949999999999999, '00:07:34']
# 90 = [20, 100, 2, 16, 2, 0.8924999999999998, '00:04:32']
# 91 = [20, 1000, 1, 32, 3, 0.8924999999999998, '00:07:17']
# 92 = [20, 10, 5, 32, 3, 0.89125, '00:07:31']
# 93 = [20, 1, 3, 32, 2, 0.8800000000000001, '00:04:55']
# 94 = [20, 1000, 5, 32, 2, 0.8799999999999999, '00:04:42']
# 95 = [20, 1, 1, 16, 2, 0.8787499999999999, '00:05:14']
# 96 = [20, 10, 4, 32, 2, 0.8775000000000001, '00:04:49']
# 97 = [20, 100, 2, 32, 3, 0.8775000000000001, '00:07:24']
# 98 = [20, 1000, 1, 16, 2, 0.8775000000000001, '00:05:25']
# 99 = [20, 10, 5, 32, 2, 0.87625, '00:04:47']
# 100 = [20, 1, 4, 32, 2, 0.87375, '00:04:50']
# 101 = [20, 10, 3, 32, 2, 0.8712499999999999, '00:04:52']
# 102 = [20, 1, 1, 32, 3, 0.8675, '00:06:34']
# 103 = [20, 10, 1, 16, 2, 0.865, '00:05:04']
# 104 = [20, 100, 4, 32, 2, 0.8624999999999998, '00:04:41']
# 105 = [20, 10, 1, 32, 3, 0.86, '00:07:25']
# 106 = [20, 100, 5, 32, 2, 0.8587499999999999, '00:04:43']
# 107 = [20, 100, 3, 32, 2, 0.85625, '00:04:44']
# 108 = [20, 1000, 4, 32, 2, 0.8537500000000001, '00:04:47']
# 109 = [20, 1, 5, 32, 2, 0.8525, '00:04:51']
# 110 = [20, 100, 1, 16, 2, 0.8399999999999999, '00:04:18']
# 111 = [20, 1, 2, 32, 2, 0.8375, '00:04:50']
# 112 = [20, 10, 2, 32, 2, 0.8250000000000002, '00:04:46']
# 113 = [20, 100, 1, 32, 3, 0.82, '00:07:09']
# 114 = [20, 1000, 3, 32, 2, 0.8150000000000002, '00:04:43']
# 115 = [1, 100, 5, 16, 4, 0.8, '00:09:03']
# 116 = [20, 1000, 2, 32, 2, 0.77875, '00:04:42']
# 117 = [20, 1000, 1, 32, 2, 0.7775, '00:04:39']
# 118 = [1, 1000, 5, 16, 4, 0.775, '00:08:49']
# 119 = [20, 1, 1, 32, 2, 0.7737499999999999, '00:04:13']
# 120 = [20, 100, 2, 32, 2, 0.755, '00:04:42']
# 121 = [1, 1000, 2, 16, 4, 0.75, '00:08:35']
# 122 = [1, 1000, 3, 32, 2, 0.75, '00:04:07']
# 123 = [1, 1, 1, 16, 4, 0.725, '00:08:12']
# 124 = [1, 100, 4, 16, 4, 0.725, '00:08:56']
# 125 = [1, 1000, 2, 16, 3, 0.725, '00:06:17']
# 126 = [20, 100, 1, 32, 2, 0.72375, '00:04:37']
# 127 = [1, 1, 1, 16, 2, 0.7, '00:03:45']
# 128 = [1, 1, 4, 16, 4, 0.7, '00:08:22']
# 129 = [1, 1, 4, 32, 4, 0.7, '00:07:31']
# 130 = [1, 1, 5, 32, 4, 0.7, '00:07:31']
# 131 = [1, 100, 3, 16, 3, 0.7, '00:06:34']
# 132 = [1, 100, 3, 16, 4, 0.7, '00:08:57']
# 133 = [1, 1000, 1, 16, 4, 0.7, '00:07:27']
# 134 = [1, 1000, 4, 16, 4, 0.7, '00:08:58']
# 135 = [1, 1000, 2, 32, 3, 0.7, '00:06:25']
# 136 = [1, 1000, 2, 32, 4, 0.7, '00:08:50']
# 137 = [20, 10, 1, 32, 2, 0.6925, '00:04:42']
# 138 = [1, 1, 1, 16, 3, 0.675, '00:05:57']
# 139 = [1, 1, 5, 32, 3, 0.675, '00:05:30']
# 140 = [1, 10, 3, 16, 4, 0.675, '00:08:18']
# 141 = [1, 100, 3, 32, 4, 0.675, '00:07:59']
# 142 = [1, 100, 4, 32, 4, 0.675, '00:07:57']
# 143 = [1, 1000, 1, 16, 3, 0.675, '00:05:26']
# 144 = [1, 1000, 3, 16, 4, 0.675, '00:09:05']
# 145 = [1, 1000, 5, 16, 3, 0.675, '00:06:24']
# 146 = [1, 1000, 1, 32, 3, 0.675, '00:06:14']
# 147 = [1, 1000, 3, 32, 3, 0.675, '00:06:32']
# 148 = [1, 1000, 3, 32, 4, 0.675, '00:08:59']
# 149 = [1, 1000, 4, 32, 3, 0.675, '00:06:22']
# 150 = [1, 1000, 4, 32, 4, 0.675, '00:08:44']
# 151 = [1, 1000, 5, 32, 3, 0.675, '00:06:26']
# 152 = [1, 1000, 5, 32, 4, 0.675, '00:08:43']
# 153 = [1, 1, 2, 16, 3, 0.65, '00:06:02']
# 154 = [1, 1, 3, 16, 4, 0.65, '00:08:18']
# 155 = [1, 1, 5, 16, 4, 0.65, '00:08:24']
# 156 = [1, 1, 2, 32, 4, 0.65, '00:06:44']
# 157 = [1, 1, 4, 32, 3, 0.65, '00:05:33']
# 158 = [1, 10, 2, 16, 4, 0.65, '00:08:17']
# 159 = [1, 10, 5, 16, 4, 0.65, '00:08:14']
# 160 = [1, 100, 2, 16, 4, 0.65, '00:08:50']
# 161 = [1, 100, 4, 16, 3, 0.65, '00:06:35']
# 162 = [1, 100, 5, 32, 4, 0.65, '00:07:58']
# 163 = [1, 1, 2, 32, 3, 0.625, '00:04:55']
# 164 = [1, 1, 3, 32, 4, 0.625, '00:07:30']
# 165 = [1, 10, 1, 16, 4, 0.625, '00:08:09']
# 166 = [1, 10, 2, 16, 3, 0.625, '00:06:02']
# 167 = [1, 10, 4, 16, 4, 0.625, '00:08:22']
# 168 = [1, 10, 4, 32, 4, 0.625, '00:07:35']
# 169 = [1, 10, 5, 32, 4, 0.625, '00:07:32']
# 170 = [1, 100, 1, 16, 4, 0.625, '00:08:33']
# 171 = [1, 100, 5, 16, 3, 0.625, '00:06:37']
# 172 = [1, 100, 1, 32, 4, 0.625, '00:07:56']
# 173 = [1, 100, 2, 32, 2, 0.625, '00:03:41']
# 174 = [1, 100, 3, 32, 2, 0.625, '00:03:40']
# 175 = [1, 100, 3, 32, 3, 0.625, '00:05:51']
# 176 = [1, 1000, 2, 16, 2, 0.625, '00:03:56']
# 177 = [1, 1000, 3, 16, 3, 0.625, '00:06:41']
# 178 = [1, 1000, 4, 16, 3, 0.625, '00:06:32']
# 179 = [1, 1000, 1, 32, 2, 0.625, '00:03:57']
# 180 = [1, 1000, 1, 32, 4, 0.625, '00:08:33']
# 181 = [1, 1, 2, 16, 2, 0.6, '00:03:50']
# 182 = [1, 1, 2, 16, 4, 0.6, '00:08:21']
# 183 = [1, 10, 2, 16, 2, 0.6, '00:03:47']
# 184 = [1, 10, 3, 16, 2, 0.6, '00:03:50']
# 185 = [1, 10, 3, 32, 4, 0.6, '00:07:30']
# 186 = [1, 100, 1, 16, 2, 0.6, '00:03:57']
# 187 = [1, 100, 2, 16, 3, 0.6, '00:06:26']
# 188 = [1, 100, 3, 16, 2, 0.6, '00:04:08']
# 189 = [1, 100, 5, 32, 3, 0.6, '00:05:53']
# 190 = [1, 1000, 1, 16, 2, 0.6, '00:03:24']
# 191 = [1, 1000, 2, 32, 2, 0.6, '00:04:02']
# 192 = [1, 1, 4, 16, 2, 0.575, '00:03:50']
# 193 = [1, 10, 1, 16, 3, 0.575, '00:05:54']
# 194 = [1, 10, 4, 16, 2, 0.575, '00:03:53']
# 195 = [1, 10, 3, 32, 2, 0.575, '00:03:30']
# 196 = [1, 10, 4, 32, 2, 0.575, '00:03:30']
# 197 = [1, 100, 5, 16, 2, 0.575, '00:04:09']
# 198 = [1, 100, 2, 32, 3, 0.575, '00:05:49']
# 199 = [1, 100, 2, 32, 4, 0.575, '00:07:59']
# 200 = [1, 100, 4, 32, 3, 0.575, '00:05:50']
# 201 = [1, 1000, 5, 16, 2, 0.575, '00:04:03']
# 202 = [1, 1000, 4, 32, 2, 0.575, '00:04:01']
# 203 = [1, 1, 3, 16, 2, 0.55, '00:03:51']
# 204 = [1, 1, 3, 16, 3, 0.55, '00:06:02']
# 205 = [1, 1, 5, 16, 2, 0.55, '00:03:51']
# 206 = [1, 1, 1, 32, 2, 0.55, '00:02:54']
# 207 = [1, 1, 1, 32, 4, 0.55, '00:05:57']
# 208 = [1, 1, 4, 32, 2, 0.55, '00:03:32']
# 209 = [1, 10, 3, 16, 3, 0.55, '00:06:04']
# 210 = [1, 10, 4, 16, 3, 0.55, '00:06:08']
# 211 = [1, 10, 5, 16, 3, 0.55, '00:06:01']
# 212 = [1, 10, 1, 32, 4, 0.55, '00:07:12']
# 213 = [1, 10, 2, 32, 2, 0.55, '00:03:32']
# 214 = [1, 10, 2, 32, 4, 0.55, '00:07:37']
# 215 = [1, 100, 1, 16, 3, 0.55, '00:06:15']
# 216 = [1, 100, 4, 16, 2, 0.55, '00:04:01']
# 217 = [1, 100, 1, 32, 3, 0.55, '00:05:50']
# 218 = [1, 1000, 3, 16, 2, 0.55, '00:04:13']
# 219 = [1, 1000, 4, 16, 2, 0.55, '00:04:09']
# 220 = [1, 1, 4, 16, 3, 0.525, '00:06:04']
# 221 = [1, 1, 5, 16, 3, 0.525, '00:06:05']
# 222 = [1, 1, 1, 32, 3, 0.525, '00:04:25']
# 223 = [1, 1, 2, 32, 2, 0.525, '00:03:06']
# 224 = [1, 1, 3, 32, 2, 0.525, '00:03:30']
# 225 = [1, 1, 3, 32, 3, 0.525, '00:05:30']
# 226 = [1, 1, 5, 32, 2, 0.525, '00:03:30']
# 227 = [1, 10, 5, 16, 2, 0.525, '00:03:49']
# 228 = [1, 10, 1, 32, 3, 0.525, '00:05:17']
# 229 = [1, 10, 2, 32, 3, 0.525, '00:05:35']
# 230 = [1, 10, 3, 32, 3, 0.525, '00:05:30']
# 231 = [1, 10, 4, 32, 3, 0.525, '00:05:31']
# 232 = [1, 10, 5, 32, 2, 0.525, '00:03:32']
# 233 = [1, 10, 5, 32, 3, 0.525, '00:05:32']
# 234 = [1, 100, 2, 16, 2, 0.525, '00:04:02']
# 235 = [1, 100, 1, 32, 2, 0.525, '00:03:43']
# 236 = [1, 100, 5, 32, 2, 0.525, '00:03:40']
# 237 = [1, 10, 1, 16, 2, 0.5, '00:03:44']
# 238 = [1, 1000, 5, 32, 2, 0.5, '00:04:05']
# 239 = [1, 10, 1, 32, 2, 0.475, '00:03:24']
# 240 = [1, 100, 4, 32, 2, 0.475, '00:03:41']

# %% [markdown]
# ### Escolhendo um resultado diferente do melhor

# %%
#MELHOR_DOCUMENTOS_PERTURBADOS = 20
#MELHOR_TOP_K_PREDICAO = 100
#MELHOR_TAXAS_DE_APRENDIZAGEM = 1
#MELHOR_TAMANHO_LOTE = 16
#MELHOR_EPOCA_EXECUCAO = 4
#MELHOR_ACURACIA = 0.9825555555555556
#MELHOR_TEMPO = '05:09:49'
#lista_resultados= []

# %% [markdown]
# ### 3.1.2 Função que carrega e calcula a média da acurácia dos folds

# %%
# Import das bibliotecas.
import os
import pandas as pd

def relatorioResultados(DIRETORIO_COHEBERT, 
                        TEXTO_PURO, 
                        _DOCUMENTOS_PERTURBADOS, 
                        _TOP_K_PREDICAO,
                        _TAXAS_DE_APRENDIZAGEM,
                        _TAMANHO_LOTE,
                        _EPOCA_EXECUCAO
                        ):
  
  # Numero de Folds
  KFOLDS = 10

  # Quantidade de documentos a serem perturbados a partir do original.    
  DOCUMENTOS_PERTURBADOS = _DOCUMENTOS_PERTURBADOS

  # Quantidade de palavras a serem recuperadas mais próximas da máscara. 
  TOP_K_PREDICAO = _TOP_K_PREDICAO

  # MCL a serem avaliados
  #MODELO_BERT = ['_BERTimbau','_BERTmultilingual']
  MODELO_BERT = ['_BERTimbau']

  #TAMANHO_BERT = ['_base','_large']
  TAMANHO_BERT = ['_large']

  # Taxa de aprendizagem do nome do arquivo
  TAXAS_DE_APRENDIZAGEM = _TAXAS_DE_APRENDIZAGEM

  # Tamanho dos lotes
  TAMANHO_LOTE = _TAMANHO_LOTE

  # Salva resultados intermediários
  EPOCA = _EPOCA_EXECUCAO
  
  # Diretório para salvar o arquivo.
  DIRETORIO_AVALIACAO = "/content/drive/My Drive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_classificacao_palavra/kfold/Avaliacao/"  

  lista_tempo_total = []  
  total_geral_folds = 0
  total_geral_registros = 0
  total_arquivos = (len(MODELO_BERT) * len(TAMANHO_BERT) *
                   len(DOCUMENTOS_PERTURBADOS) *  len(TOP_K_PREDICAO) * 
                   len(TAMANHO_LOTE) * len(EPOCA) * len(TAXAS_DE_APRENDIZAGEM) * KFOLDS)
  #total_arquivos = 400  
  if TEXTO_PURO == False:
    print("total_arquivos =", total_arquivos) 

  # Verifica se o diretório dos resultados existe.
  if os.path.exists(DIRETORIO_AVALIACAO):    
    for modelo in MODELO_BERT:
      for tamanho in TAMANHO_BERT:        
        if modelo != '_BERTmultilingual' or tamanho != '_large':  
          for documentos_perturbados in DOCUMENTOS_PERTURBADOS:
            for top_k_predicao in TOP_K_PREDICAO:        
              DIRETORIO_AVALIACAO_PK = DIRETORIO_AVALIACAO + "P_" + str(documentos_perturbados) + "_K_" + str(top_k_predicao) + "/"
        
              # Verifica se o diretório dos resultados existe.
              if os.path.exists(DIRETORIO_AVALIACAO_PK):
                arquivos = os.listdir(DIRETORIO_AVALIACAO_PK) 
                for lote in TAMANHO_LOTE:
                  for taxaaprendizagem in TAXAS_DE_APRENDIZAGEM:
                    for epoca in EPOCA:                    
                        # Acumuladores.
                        soma_acuracia = 0
                        lista_tempo = []
                        conta_folds = 0 
                        conta_reg = 0
                        if TEXTO_PURO == False:
                           print("\nModelo:", modelo, " Tamanho:", tamanho, " N Doc:",documentos_perturbados,
                                 " Top k:", top_k_predicao, " Lote:", lote, " Taxa Apred.:", taxaaprendizagem, " Época:", epoca)
       
                        for i in range(len(arquivos)):                                    
                          for fold in range(1,11):                                                         
                            if ((("_P_" + str(documentos_perturbados)+"_") in arquivos[i]) 
                                and (("_K_" + str(top_k_predicao)+"_") in arquivos[i]) 
                                and (("_b_" + str(lote)) in arquivos[i]) 
                                and (modelo in arquivos[i]) 
                                and (tamanho in arquivos[i]) 
                                and (("_b_" + str(lote)) in arquivos[i]) 
                                and (('_f' + str(fold) + '_') in arquivos[i]) 
                                and (("e_" + str(epoca)) in arquivos[i]) 
                                and (("lr_" + str(taxaaprendizagem)) in arquivos[i])):
                             
                                NOME_ARQUIVO_AVALIACAO_COMPLETO = DIRETORIO_AVALIACAO_PK + arquivos[i]                              
                                # Verifica se o arquivo existe.
                                if os.path.isfile(NOME_ARQUIVO_AVALIACAO_COMPLETO):
                                  # Carrega os dados do arquivo  
                                  dados = pd.read_csv(NOME_ARQUIVO_AVALIACAO_COMPLETO, sep=';')
                      
                                  # Conta o número de folds.
                                  conta_folds = conta_folds + 1
                                  # Conta o número geral de folds
                                  total_geral_folds = total_geral_folds + 1

                                  # Mostra os dados do teste do fold.
                                  for index, linha in dados.iterrows():        
                                    # Cálculo das estatísticas
                                    acc = (linha['vp']+linha['vn'])/(linha['vp']+linha['vn']+linha['fp']+linha['fn'])                         
                                    print('{};{};{};{};{}'.format(fold, index, arquivos[i],str(acc).replace(".", ","),linha['tempo']))
                                    #print('{};{};{};{:.8f};{}'.format(fold, index, arquivos[i],acc,linha['tempo']))
                                    # Guarda o tempo.
                                    lista_tempo.append(str(linha['tempo']))

                                    # Conta o número de registros.
                                    conta_reg = conta_reg + 1
                                    # Conta o número geral de registros.
                                    total_geral_registros = total_geral_registros + 1

                                  # Realiza a soma da acurácia do arquivo.
                                  soma_acuracia = soma_acuracia + dados['acuracia'].sum()

                        
                        if conta_folds != 0:
                            # Mostra a soma da acurácia . 
                            if TEXTO_PURO == False:
                              print('Total acurácia                                           : {:.8f}'.format(soma_acuracia))
                            # Mostra a quantidade de folds.
                            if TEXTO_PURO == False:
                              print('Quantidade de folds                                      : {}'.format(conta_folds))  
                            # Mostra a quantidade de registros.
                            if TEXTO_PURO == False:
                              print('Quantidade de registros                                  : {}'.format(conta_reg))  
                            # Calcula a média.
                            if TEXTO_PURO == False:
                              media_acuracia = soma_acuracia/conta_reg
                              print('A média da acurácia de {:2d} registros é                    : {:.8f}'.format(conta_reg, media_acuracia))
                              print('O tempo gasto na execução do treinamento {:2d} registros é  : {}'.format(conta_reg, somaTempo(lista_tempo)))
                              print('A média de tempo de execução de {:2d} registros é           : {}\n'.format(conta_reg, mediaTempo(lista_tempo)))
                            
                            if epoca == 4:
                              # Guarda o tempo total
                              lista_tempo_total.append(somaTempo(lista_tempo))
                        else:
                            if TEXTO_PURO == False:
                              print('Nenhum arquivo de avaliação encontrado')
                                    
              else:
                print('Diretório ' + 'P_' + str(documentos_perturbados) + '_K_' + str(top_k_predicao) + ' não encontrado')                        
    
  else:
      print('Diretório com os resultados não encontrado')

# %% [markdown]
# Recupera os dados dos melhores resultados

# %%
# Diretório do cohebert
DOCUMENTOS_PERTURBADOS = [MELHOR_DOCUMENTOS_PERTURBADOS]
TOP_K_PREDICAO = [MELHOR_TOP_K_PREDICAO]
TAXAS_DE_APRENDIZAGEM = [MELHOR_TAXAS_DE_APRENDIZAGEM]
TAMANHO_LOTE = [MELHOR_TAMANHO_LOTE]
EPOCA_EXECUCAO = [MELHOR_EPOCA_EXECUCAO]
TEXTO_PURO = False

relatorioResultados(DIRETORIO_COHEBERT, 
                    TEXTO_PURO, 
                    DOCUMENTOS_PERTURBADOS, 
                    TOP_K_PREDICAO, 
                    TAXAS_DE_APRENDIZAGEM, 
                    TAMANHO_LOTE, 
                    EPOCA_EXECUCAO)
# Out:
# totalArquivos = 10
#
# Modelo: _BERTimbau  Tamanho: _large  N Doc: 20  Top k: 100  Lote: 16  Taxa Apred.: 4  Época: 4
# 1;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f1_BERTimbau_large.csv;1,0;0:00:57
# 2;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f2_BERTimbau_large.csv;1,0;0:00:58
# 3;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f3_BERTimbau_large.csv;1,0;0:00:56
# 4;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f4_BERTimbau_large.csv;1,0;0:00:58
# 5;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f5_BERTimbau_large.csv;1,0;0:00:57
# 6;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f6_BERTimbau_large.csv;0,9625;0:00:57
# 7;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f7_BERTimbau_large.csv;1,0;0:00:58
# 8;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f8_BERTimbau_large.csv;1,0;0:00:57
# 9;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f9_BERTimbau_large.csv;1,0;0:00:58
# 10;0;AjusteFinoCohebert_v1_C_SB_KF_P_20_K_100_E_4_e_4_lr_4_b_16_16_f10_BERTimbau_large.csv;1,0;0:00:57
# Total acurácia                                           : 9.96250000
# Quantidade de folds                                      : 10
# Quantidade de registros                                  : 10
# A média da acurácia de 10 registros é                    : 0.99625000
# O tempo gasto na execução do treinamento 10 registros é  : 00:09:33
# A média de tempo de execução de 10 registros é           : 00:00:57

# %% [markdown]
# ## 3.2 Carregamento dos arquivos de dados originais e perturbados

# %% [markdown]
# ### 3.2.1 Especifica os nomes dos arquivos de dados

# %%
# Nome do arquivo
NOME_ARQUIVO_ORIGINAL = "original.csv"
NOME_ARQUIVO_ORIGINAL_COMPACTADO = "original.zip"
NOME_ARQUIVO_ORIGINAL_POS = "originalpos.csv"
NOME_ARQUIVO_ORIGINAL_POS_COMPACTADO = "originalpos.zip"

NOME_ARQUIVO_PERTURBADO = "perturbado_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".csv"
NOME_ARQUIVO_PERTURBADO_COMPACTADO = "perturbado_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".zip"
NOME_ARQUIVO_PERTURBADO_POS = "perturbadopos_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".csv"
NOME_ARQUIVO_PERTURBADO_POS_COMPACTADO = "perturbadopos_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".zip"

# %% [markdown]
# ### 3.2.2 Cria o diretório local para receber os dados

# %%
# Import das bibliotecas.
import os

# Cria o diretório para receber os arquivos Originais e Perturbados
# Diretório a ser criado
dirbase = DIRETORIO_LOCAL[:-1]

if not os.path.exists(dirbase):  
    # Cria o diretório
    os.makedirs(dirbase)    
    logging.info("Diretório criado: {}".format(dirbase))
else:    
    logging.info("Diretório já existe: {}".format(dirbase))
# Out:
# 2022-03-18 12:46:49,028 : INFO : Diretório criado: /content/COHEBERT

# %% [markdown]
# ### 3.2.3 Copia e descompacta os arquivos do Google Drive para o Colaboratory

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:

  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_ORIGINAL_COMPACTADO" "$DIRETORIO_LOCAL"
  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_ORIGINAL_POS_COMPACTADO" "$DIRETORIO_LOCAL"

  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_PERTURBADO_COMPACTADO" "$DIRETORIO_LOCAL"
  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_PERTURBADO_POS_COMPACTADO" "$DIRETORIO_LOCAL"

  logging.info("Terminei a cópia!")
# Out:
# 2022-03-18 12:46:50,077 : INFO : Terminei a cópia!

# %% [markdown]
# Descompacta os arquivos.
#
# Usa o unzip para descompactar:
# *   `-o` sobrescreve o arquivo se existir
# *   `-j` Não cria nenhum diretório
# *   `-q` Desliga as mensagens
# *   `-d` Diretório de destino

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_ORIGINAL_COMPACTADO" -d "$DIRETORIO_LOCAL"
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_ORIGINAL_POS_COMPACTADO" -d "$DIRETORIO_LOCAL"

  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_PERTURBADO_COMPACTADO" -d "$DIRETORIO_LOCAL"
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_PERTURBADO_POS_COMPACTADO" -d "$DIRETORIO_LOCAL"

  logging.info("Terminei a descompactação!")
# Out:
# 2022-03-18 12:46:50,633 : INFO : Terminei a descompactação!

# %% [markdown]
# ### 3.2.4 Carregamento das lista com os dados dos arquivos originais e perturbados

# %% [markdown]
# #### Carrega o arquivo dos dados originais e POS

# %%
#Biblioteca
import pandas as pd

# Abre o arquivo e retorna o DataFrame
lista_documentos_originais = pd.read_csv(DIRETORIO_LOCAL + NOME_ARQUIVO_ORIGINAL, sep=";", encoding="UTF-8")
lista_documentos_originais_pos = pd.read_csv(DIRETORIO_LOCAL + NOME_ARQUIVO_ORIGINAL_POS, sep=";", encoding="UTF-8")

logging.info("TERMINADO ORIGINAIS: {}.".format(len(lista_documentos_originais)))
logging.info("TERMINADO ORIGINAIS POS: {}.".format(len(lista_documentos_originais_pos)))
# Out:
# 2022-03-18 12:46:50,664 : INFO : TERMINADO ORIGINAIS: 20.
# 2022-03-18 12:46:50,668 : INFO : TERMINADO ORIGINAIS POS: 20.

# %%
lista_documentos_originais.sample(5)
# Out:
#     id                                          sentencas  \
# 15  16  ['O que é uma fila e como enfileirar e desenfi...
# 6    7       ['Como desempilhar elementos em uma pilha?']
# 11  12  ['O que é uma pilha e como desempilhar um elem...
# 10  11  ['O que é uma fila e como desenfileirar um ele...
# 19  20  ['Em uma fila a operação de enfileirar ocorre ...
#
#                                             documento
# 15  O que é uma fila e como enfileirar e desenfile...
# 6            Como desempilhar elementos em uma pilha?
# 11  O que é uma pilha e como desempilhar um elemen...
# 10  O que é uma fila e como desenfileirar um eleme...
# 19  Em uma fila a operação de enfileirar ocorre em...

# %%
lista_documentos_originais_pos.sample(5)
# Out:
#     id                                      pos_documento
# 6    7  [[['Como', 'desempilhar', 'elementos', 'em', '...
# 1    2  [[['Como', 'desenfileirar', 'elementos', 'em',...
# 10  11  [[['O', 'que', 'é', 'uma', 'fila', 'e', 'como'...
# 5    6  [[['Como', 'empilhar', 'e', 'desempilhar', 'el...
# 7    8  [[['Como', 'desempilhar', 'elementos', 'em', '...

# %% [markdown]
# #### Corrigir os tipos de colunas dos dados originais e POS
#
# Em dados originais:
# - coluna 1 - `sentenças` carregadas do arquivo vem como string e não como lista.
#
# Em dados originais pos:
# - coluna 1 - `pos_documento` carregadas do arquivo vem como string e não como lista.

# %%
# Import das bibliotecas.
import ast # Biblioteca para conversão de string em lista

# Verifica se o tipo da coluna não é list e converte
lista_documentos_originais["sentencas"] = lista_documentos_originais["sentencas"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

lista_documentos_originais_pos["pos_documento"] = lista_documentos_originais_pos["pos_documento"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

logging.info("TERMINADO CORREÇÃO ORIGINAIS: {}.".format(len(lista_documentos_originais)))
logging.info("TERMINADO CORREÇÃO ORIGINAIS POS: {}.".format(len(lista_documentos_originais_pos)))
# Out:
# 2022-03-18 12:46:50,735 : INFO : TERMINADO CORREÇÃO ORIGINAIS: 20.
# 2022-03-18 12:46:50,737 : INFO : TERMINADO CORREÇÃO ORIGINAIS POS: 20.

# %% [markdown]
# #### Carrega o arquivo dos dados perturbados e POS

# %%
# Abre o arquivo e retorna o DataFrame
lista_documentos_perturbados = pd.read_csv(DIRETORIO_LOCAL + NOME_ARQUIVO_PERTURBADO, sep=";", encoding="UTF-8")
lista_documentos_perturbados_pos = pd.read_csv(DIRETORIO_LOCAL + NOME_ARQUIVO_PERTURBADO_POS, sep=";", encoding="UTF-8")

logging.info("TERMINADO PERTURBADOS: {}.".format(len(lista_documentos_perturbados)))
logging.info("TERMINADO PERTURBADOS POS: {}.".format(len(lista_documentos_perturbados_pos)))
# Out:
# 2022-03-18 12:46:50,767 : INFO : TERMINADO PERTURBADOS: 400.
# 2022-03-18 12:46:50,770 : INFO : TERMINADO PERTURBADOS POS: 400.

# %%
lista_documentos_perturbados.sample(5)
# Out:
#              id                                         perturbado  \
# 193  10_pert_13  ['O que é uma fila e como caracteriza seu elem...
# 68     4_pert_8  ['Como empilhar e exibir elementos em uma pilh...
# 169    9_pert_9  ['O que é uma pilha e como substitui seu eleme...
# 224   12_pert_4  ['O que é uma pilha e como desempilhar um livr...
# 127    7_pert_7        ['Como desempilhar músicas em uma pilha ?']
#
#                                    documentoPerturbado  \
# 193  O que é uma fila e como caracteriza seu elemen...
# 68     Como empilhar e exibir elementos em uma pilha ?
# 169  O que é uma pilha e como substitui seu elemento ?
# 224  O que é uma pilha e como desempilhar um livro ...
# 127            Como desempilhar músicas em uma pilha ?
#
#                                              sentencas
# 193  [['O que é uma fila e como [MASK] seu elemento...
# 68   [['Como empilhar e [MASK] elementos em uma pil...
# 169  [['O que é uma pilha e como [MASK] seu element...
# 224  [['O que é uma pilha e como desempilhar um [MA...
# 127  [['Como desempilhar [MASK] em uma pilha ?', 'e...

# %%
lista_documentos_perturbados_pos.sample(5)
# Out:
#              id                                      pos_documento
# 81     5_pert_1  [[['Como', 'escolher', 'elementos', 'em', 'uma...
# 324   17_pert_4  [[['Como', 'são', 'implementadas', 'as', 'oper...
# 70    4_pert_10  [[['Como', 'empilhar', 'e', 'remover', 'elemen...
# 163    9_pert_3  [[['O', 'que', 'é', 'uma', 'pilha', 'e', 'como...
# 212  11_pert_12  [[['O', 'que', 'é', 'uma', 'fila', 'e', 'como'...

# %% [markdown]
# #### Corrigir os tipos de colunas dos dados perturbados e POS
#
# Em dados perturbados:
# - coluna 1 - `perturbado` carregadas do arquivo vem como string e não como lista.
# - coluna 3 - `sentencas` carregadas do arquivo vem como string e não como lista.
#
# Em dados perturbados pos:
# - coluna 1 - `pos_documento` carregadas do arquivo vem como string e não como lista.

# %%
# Import das bibliotecas.
import ast # Biblioteca para conversão de string em lista

# Verifica se o tipo da coluna não é list e converte
lista_documentos_perturbados["perturbado"] = lista_documentos_perturbados["perturbado"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)
lista_documentos_perturbados["sentencas"] = lista_documentos_perturbados["sentencas"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

lista_documentos_perturbados_pos["pos_documento"] = lista_documentos_perturbados_pos["pos_documento"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

logging.info("TERMINADO CORREÇÃO PERTURBADO: {}.".format(len(lista_documentos_perturbados)))
logging.info("TERMINADO CORREÇÃO PERTURBADO POS: {}.".format(len(lista_documentos_perturbados_pos)))
# Out:
# 2022-03-18 12:46:50,883 : INFO : TERMINADO CORREÇÃO PERTURBADO: 400.
# 2022-03-18 12:46:50,885 : INFO : TERMINADO CORREÇÃO PERTURBADO POS: 400.

# %% [markdown]
# ### 3.2.5 Agrupar os dados originais e perturbados

# %%
# Import das bibliotecas.
import ast
from tqdm.notebook import tqdm as tqdm_notebook

print("Processando",len(lista_documentos_originais),"documentos originais")

lista_documentos_agrupados = []

# Barra de progresso dos documentos
lista_documentos_originais_bar = tqdm_notebook(lista_documentos_originais.iterrows(), desc=f"Documentos", unit=f" documento", total=len(lista_documentos_originais))

# Percorre os documentos
for i, linha_documento in lista_documentos_originais_bar: 
  #if i < 2:
    #print("linha_documento:",linha_documento)
    # Recupera o id do documento
    id_documento = linha_documento[0]     
    #print("id_documento:",id_documento)     
 
    # Carrega a lista das sentenças do documento
    lista_sentenca_documento = linha_documento[1]    
    #print("\nlista_sentenca_documento:",lista_sentenca_documento)
    #print("len(lista_sentenca_documento):",len(lista_sentenca_documento)) 

    # Adiciona o original a lista dos dados agrupados, considerando como coerente(1)
    lista_documentos_agrupados.append([id_documento, lista_sentenca_documento, linha_documento[2], 1])
  
    # Percorre os documentos perturbados apartir do original
    for j in range(0, MELHOR_DOCUMENTOS_PERTURBADOS):

      # Id do documento perturbado
      id_perturbado = str(id_documento) + "_pert_" + str(j)

      # localiza o documento perturbado 
      documento_perturbado = lista_documentos_perturbados.loc[lista_documentos_perturbados['id']==id_perturbado].values[0]
      # Recupera a sentença do documento perturbado
      lista_perturbado = documento_perturbado[1]
          
      # Adiciona o perturbado a lista dos dados agrupados considerando como incoerente(0)
      lista_documentos_agrupados.append([id_perturbado, lista_perturbado, documento_perturbado[2], 0])    

logging.info("TERMINADO AGRUPAMENTO: {}.".format(len(lista_documentos_agrupados)))
# Out:
# Processando 20 documentos originais
# Documentos:   0%|          | 0/20 [00:00<?, ? documento/s]
# 2022-03-18 12:46:51,160 : INFO : TERMINADO AGRUPAMENTO: 420.

# %% [markdown]
# Converte em um dataframe

# %%
# Cria o dataframe da lista
dflista_documentos_agrupados = pd.DataFrame(lista_documentos_agrupados, columns = ["id","sentencas","documento","classe"])

# %%
# Corrige os tipos dos dados da lista agrupada
tipos = {"id": str, "sentencas": object, "documento": str, "classe": int}

dflista_documentos_agrupados = dflista_documentos_agrupados.astype(tipos)

# %%
dflista_documentos_agrupados.sample(5)
# Out:
#              id                                          sentencas  \
# 235   12_pert_3  [O que é uma pilha e como utilizar um elemento...
# 348  17_pert_11  [Como são tomadas as operações de empilhar e d...
# 398  19_pert_19  [Em uma pilha a operação de empilhar envolve e...
# 108    6_pert_2  [Como empilhar e organizar elementos em uma es...
# 132    7_pert_5         [Como concentrar elementos em uma pilha ?]
#
#                                              documento  classe
# 235  O que é uma pilha e como utilizar um elemento ...       0
# 348  Como são tomadas as operações de empilhar e de...       0
# 398  Em uma pilha a operação de empilhar envolve em...       0
# 108  Como empilhar e organizar elementos em uma est...       0
# 132           Como concentrar elementos em uma pilha ?       0

# %%
# Importa das bibliotecas
import pandas as pd

# Concatena as listas de documentos originais e perturbados
dflista_documentos_agrupados_pos = pd.concat([lista_documentos_originais_pos, lista_documentos_perturbados_pos])

logging.info("TERMINADO AGRUPAMENTO POS: {}.".format(len(dflista_documentos_agrupados_pos)))
# Out:
# 2022-03-18 12:46:51,264 : INFO : TERMINADO AGRUPAMENTO POS: 420.

# %%
# Corrige os tipos dos dados da lista agrupada
tipos = {"id": str}

dflista_documentos_agrupados_pos = dflista_documentos_agrupados_pos.astype(tipos)

# %%
dflista_documentos_agrupados_pos.sample(5)
# Out:
#             id                                      pos_documento
# 248  13_pert_8  [[[O, que, é, uma, fila, e, como, determinar, ...
# 66    4_pert_6  [[[Como, pôr, e, desempilhar, elementos, em, u...
# 364  19_pert_4  [[[Em, uma, pilha, a, operação, de, empilhar, ...
# 62    4_pert_2  [[[Como, empilhar, e, marcar, elementos, em, u...
# 265  14_pert_5  [[[O, que, é, uma, pilha, e, como, ficar, um, ...

# %% [markdown]
# ## 3.3 Carrega os dados da classificação

# %%
# Import das bibliotecas.
import os
import pandas as pd

def getDadosClassificacao(DIRETORIO_COHEBERT,                           
                          _DOCUMENTOS_PERTURBADOS, 
                          _TOP_K_PREDICAO,
                          _EPOCA,
                          _TAXAS_DE_APRENDIZAGEM,
                          _TAMANHO_LOTE,
                          _EPOCA_EXECUCAO
                          ):

  DIRETORIO_CLASSIFICACAO = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_classificacao_palavra/kfold/Classificacao/" + "P_" + str(_DOCUMENTOS_PERTURBADOS) + "_K_" + str(_TOP_K_PREDICAO) + "/"
    
  MODELO_BERT = '_BERTimbau'
  TAMANHO_BERT = '_large'

  # Dataframa que será retornado após o preenchimento
  dfDadosClassificacao = pd.DataFrame()

  # Verifica se o diretório dos resultados existem.
  if os.path.exists(DIRETORIO_CLASSIFICACAO):
    arquivos = os.listdir(DIRETORIO_CLASSIFICACAO)     
    print('\nModelo:', MODELO_BERT, 
          ' Tamanho:', TAMANHO_BERT, 
          ' Np:', str(_DOCUMENTOS_PERTURBADOS), 
          ' Topk:', str(_TOP_K_PREDICAO), 
          ' Lote:', str(_TAMANHO_LOTE), 
          ' Taxa Apr.: ', str(_TAXAS_DE_APRENDIZAGEM),
          ' Epoca:', str(_EPOCA_EXECUCAO))
    
    # Acumuladores.
    conta_folds = 0 
    conta_reg = 0
    for fold in range(1,11):    
      NOME_ARQUIVO_CLASSIFICAO = (NOME_BASE_SAIDA + "_P_" +  str(_DOCUMENTOS_PERTURBADOS) 
                                  + "_K_" + str(_TOP_K_PREDICAO) 
                                  + "_E_" + str(_EPOCA) 
                                  + "_e_" + str(_EPOCA_EXECUCAO) 
                                  + "_lr_" + str(_TAXAS_DE_APRENDIZAGEM) 
                                  + "_b_" +  str(_TAMANHO_LOTE)  
                                  + "_" +  str(_TAMANHO_LOTE)  
                                  + "_f" + str(fold) 
                                  + MODELO_BERT 
                                  + TAMANHO_BERT + ".csv")
      NOME_ARQUIVO_CLASSIFICACAO_COMPLETO = DIRETORIO_CLASSIFICACAO +  NOME_ARQUIVO_CLASSIFICAO

      # Verifica se o arquivo existe.
      if os.path.isfile(NOME_ARQUIVO_CLASSIFICACAO_COMPLETO):
          # Carrega os dados do arquivo  
          dados = pd.read_csv(NOME_ARQUIVO_CLASSIFICACAO_COMPLETO, sep=';')
          
          dfDadosClassificacao = pd.concat([dfDadosClassificacao, dados], ignore_index=True)
            
          # Conta o número de folds.
          conta_folds = conta_folds + 1

          conta_reg = conta_reg + len(dados)
      else:
          print('Arquivo não encontrado')
              
    print('Folds:', conta_folds, ' Regs:', conta_reg)
  else:
      print('Diretório com os resultados não encontrado')

  print('Registros:', len(dfDadosClassificacao))   

  return dfDadosClassificacao

# %%
DOCUMENTOS_PERTURBADOS = MELHOR_DOCUMENTOS_PERTURBADOS
TOP_K_PREDICAO = MELHOR_TOP_K_PREDICAO
EPOCA = 4
TAXAS_DE_APRENDIZAGEM = MELHOR_TAXAS_DE_APRENDIZAGEM
TAMANHO_LOTE = MELHOR_TAMANHO_LOTE
EPOCA_EXECUCAO = MELHOR_EPOCA_EXECUCAO

# Recupera os dados da melhor classificação
dfDadosClassificacao = getDadosClassificacao(DIRETORIO_COHEBERT, 
                                             DOCUMENTOS_PERTURBADOS, 
                                             TOP_K_PREDICAO,
                                             EPOCA,
                                             TAXAS_DE_APRENDIZAGEM,
                                             TAMANHO_LOTE,
                                             EPOCA_EXECUCAO)
# Out:
# Modelo: _BERTimbau  Tamanho: _large  Np: 20  Topk: 100  Lote: 16  Taxa Apr.:  4  Epoca: 4
# Folds: 10  Regs: 800
# Registros: 800

# %%
dfDadosClassificacao.sample(5)
# Out:
#                  data          id  classe  predicao
# 531  27/02/2022 05:47    2_pert_4       0         0
# 652  27/02/2022 05:50  10_pert_15       0         0
# 311  27/02/2022 05:43          15       1         1
# 692  27/02/2022 05:50   2_pert_10       0         0
# 580  27/02/2022 05:48   8_pert_11       0         0

# %% [markdown]
# ## 3.4 Analisa os dados das classificações

# %% [markdown]
# ### Acurácia

# %%
def calculoClassificacao(dfDadosClassificacao):
  vp_s = 0
  vn_s = 0
  fp_s = 0
  fn_s = 0
  for i, linha in dfDadosClassificacao.iterrows():
    #if i < 20:
    if linha['classe'] == 1 and linha['predicao'] == 1:
        vp_s = vp_s + 1
    if linha['classe'] == 0 and linha['predicao'] == 0:
        vn_s = vn_s + 1        
    if linha['classe'] == 1 and linha['predicao'] == 0:
        fp_s = fp_s + 1        
    if linha['classe'] == 0 and linha['predicao'] == 1:
        fn_s = fn_s + 1        

  # Acurácia indica uma performance geral do modelo. 
  # Dentre todas as classificações, quantas o modelo classificou corretamente(vp=1 e vn=0).
  if (vp_s+vn_s+fp_s+fn_s) != 0:
    acc = (vp_s+vn_s)/(vp_s+vn_s+fp_s+fn_s)
  else:
    acc  = 0
    
  # Recall(Revocação) avalia todas as situações da classe Positivo(vp=1) com o valor esperado e quantas estão corretas.
  if (vp_s+fn_s) != 0:
      rec = (vp_s)/(vp_s+fn_s)
  else:
      rec = 0
  
  # Precisão avalia as classificações da classe positivo(vp=1 e fp=0) que o modelo fez e quantas estão corretas.
  if (vp_s+fp_s) != 0:
      pre = (vp_s)/(vp_s+fp_s)
  else:
      pre = 0  

  # F1 é a média harmônica entre precisão e recall.
  if (pre + rec) != 0:  
    f1 = 2 * ((pre * rec)/(pre + rec))
  else:
    f1 = 0

  return acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s

# %%
acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s = calculoClassificacao(dfDadosClassificacao)

#dflistaParesDocumentosClassificados

print('Acurácia:', acc)
print('Recall  :', rec)
print('Precisão:', pre)
print('F1      :', f1)
print('vp      :', vp_s)
print('vn      :', vn_s)
print('fp      :', fp_s)
print('fn      :', fn_s)
total = vp_s + vn_s + fp_s + fn_s
print('Total   :', total)
# Out:
# Acurácia: 0.99625
# Recall  : 0.9925558312655087
# Precisão: 1.0
# F1      : 0.9962640099626401
# vp      : 400
# vn      : 397
# fp      : 0
# fn      : 3
# Total   : 800

# %% [markdown]
# #### Matriz de confusão

# %%
import matplotlib
import matplotlib.pyplot as plt

TAMANHO_FONTE = 38
matplotlib.rc('font', size=TAMANHO_FONTE)          # Controla o tamanho do do texto default
matplotlib.rc('axes', titlesize=TAMANHO_FONTE)     # Tamanho da fonte do eixo do título
matplotlib.rc('axes', labelsize=TAMANHO_FONTE)     # Tamanho da fonte dos rótulos do eixo x e y
matplotlib.rc('xtick', labelsize=TAMANHO_FONTE)    # Tamanho da fonte das marcações do eixo y
matplotlib.rc('ytick', labelsize=TAMANHO_FONTE)    # Tamanho da fonte dos marcações do eixo x
matplotlib.rc('legend', fontsize=TAMANHO_FONTE)    # Tamanho da fonte da legenda
matplotlib.rc('figure', titlesize=TAMANHO_FONTE+2)   # Tamanho da fonte do título da figura

# Aumenta o tamanho da plotagem e o tamanho da fonte.
plt.rcParams['figure.figsize'] = (15,8)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import numpy as np

X_alvo =     dfDadosClassificacao['classe'].tolist()
y_predicao = dfDadosClassificacao['predicao'].tolist()

print(classification_report(X_alvo, y_predicao))

# Insere os dados no gráfico
cf_matrix = confusion_matrix(X_alvo, y_predicao)
quantidade_grupos = ["{0:0.0f}".format(valor) for valor in cf_matrix.flatten()]
percentual_grupos = ["{0:.2%}".format(valor) for valor in cf_matrix.flatten()/np.sum(cf_matrix)]
rotulos = [f"{v1}\n{v2}" for v1, v2 in zip(quantidade_grupos,percentual_grupos)]
rotulos = np.asarray(rotulos).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=rotulos, fmt='', cmap='Blues_r')

# Texto do eixo x
ax.set_xlabel('Predicted labels')
# Texto do eixo y
ax.set_ylabel('True labels')
# Rótulos adicionais
ax.xaxis.set_ticklabels(['CDs','ODs'])
ax.yaxis.set_ticklabels(['CDs','ODs'])

# Mostra o gráfico
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       400
#            1       0.99      1.00      1.00       400
#
#     accuracy                           1.00       800
#    macro avg       1.00      1.00      1.00       800
# weighted avg       1.00      1.00      1.00       800

# %% [markdown]
# ### Listas em pares

# %% [markdown]
# #### Listas de pares de documentos originais e perturbados classificados corretamente

# %%
def listaClassificadoCorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    #if i < 20:    
    # 1 - Coerente
    if linha['classe'] == 1 and linha['predicao'] == 1:
        listaRetorno.append(linha['id'])
    # 0 - Incoerente        
    if linha['classe'] == 0 and linha['predicao'] == 0:
        listaRetorno.append(linha['id'])
  
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaRetornoClassificadoCorretamente = listaClassificadoCorretamente(dfDadosClassificacao)
print('listaRetornoClassificadoCorretamente:', len(listaRetornoClassificadoCorretamente))
# Out:
# listaRetornoClassificadoCorretamente: 797

# %% [markdown]
# #### Listas de pares de documentos originais e perturbados classificados incorretamente

# %%
def listaClassificadoIncorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    # 1 - Coerente
    if linha['classe'] == 1 and linha['predicao'] == 0:
        listaRetorno.append(linha['id'])
    # 0 - Incoerente
    if linha['classe'] == 0 and linha['predicao'] == 1:
        listaRetorno.append(linha['id'])
  
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])     
  return dflistaRetorno

# %%
listaRetornoClassificadoIncorretamente = listaClassificadoIncorretamente(dfDadosClassificacao)
print('listaRetornoClassificadoIncorretamente:', len(listaRetornoClassificadoIncorretamente))
# Out:
# listaRetornoClassificadoIncorretamente: 3

# %% [markdown]
# #### Acurácia das listas

# %%
total = len(listaRetornoClassificadoCorretamente) + len(listaRetornoClassificadoIncorretamente)
print("Total de documentos:", total)
print("Total de acertos   :", len(listaRetornoClassificadoCorretamente))
print("Total de erros     :", len(listaRetornoClassificadoIncorretamente))
print("Acurácia           :", len(listaRetornoClassificadoCorretamente)/total)
# Out:
# Total de documentos: 800
# Total de acertos   : 797
# Total de erros     : 3
# Acurácia           : 0.99625

# %% [markdown]
# #### Listas documentos originais e perturbados e suas classificações sem repetições

# %% [markdown]
# Remove as duplicidades dos dados originais.

# %%
print("Com repetição:",len(listaRetornoClassificadoCorretamente))
listaRetornoClassificadoCorretamenteSemRepeticao = listaRetornoClassificadoCorretamente.drop_duplicates(subset=['id'])
print("Sem repetição:", len(listaRetornoClassificadoCorretamenteSemRepeticao))
# Out:
# Com repetição: 797
# Sem repetição: 417

# %% [markdown]
# Remove as duplicidades dos dados perturbados.

# %%
print("Com repetição:",len(listaRetornoClassificadoIncorretamente))
listaRetornoClassificadoIncorretamenteSemRepeticao = listaRetornoClassificadoIncorretamente.drop_duplicates(subset=['id'])
print("Sem repetição:", len(listaRetornoClassificadoIncorretamenteSemRepeticao))
# Out:
# Com repetição: 3
# Sem repetição: 3

# %%
print("Documentos originais e perturados e suas classificações:", len(listaRetornoClassificadoCorretamente) + len(listaRetornoClassificadoIncorretamente))
print("  Classificados corretamente(classe=previsão):", len(listaRetornoClassificadoCorretamente))
print("  Classificados incorretamente(classe!=previsão):", len(listaRetornoClassificadoIncorretamente))

DOClasseIncorreta = 0

# Percorre a lista dos documentos originais
for i, linha in lista_documentos_originais.iterrows():
  
  # Limita a quantidade de dados a serem exibidas
  if i < 100:    
  # Procura um documento específico
  #if "Em uma fila a operação de enfileirar ocorre em qual extremidade" in linha['documento']:
    
    # Recupera as POS Tagging do documento original
    documentos_originais_pos = lista_documentos_originais_pos.loc[lista_documentos_originais_pos["id"] == linha['id']]
    #print("documentos_originais_pos[id]:", documentos_originais_pos["id"].values[0])
    
    # Recupera o id documento original se ele foi classificado corretamente    
    documento_id_original = listaRetornoClassificadoCorretamenteSemRepeticao.loc[listaRetornoClassificadoCorretamenteSemRepeticao["id"] == str(linha['id'])]
    #print("documento_id_original:", documento_id_original)

    # Recupera a classificação do original
    classe = ""
    # Se o documento original foi encontrado foi classificado corretamente
    if len(documento_id_original) != 0:
      #print("documento_id_original:",len(documento_id_original))          
      documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == str(documento_id_original['id'].values[0])]
      #print("documento:",documento)
      classe =  str(documento['classe'].values[0])
    else:
      classe = "0"
      DOClasseIncorreta = DOClasseIncorreta + 1

    # Mostra o documento original e sua classificação
    print("\nDO: " + linha["documento"] + " - " + classe)    
    # POSTagging da sentença
    print("    " + " ".join(documentos_originais_pos["pos_documento"].values[0][0][1]))
    
    # Lista com documentos perturbados e sua classificacao
    lista_perturbado_classificado_correto = []
    lista_perturbado_classificado_incorreto = []

    # Percorre os documentos perturbados e suas classificações a partir do original
    for j in range(0, MELHOR_DOCUMENTOS_PERTURBADOS):

        # Id do documento perturbado
        id_perturbado = str(linha['id']) + "_pert_" + str(j)
        #print("id_perturbado:",id_perturbado)

        # localiza os dados do documento perturbado 
        documento_perturbado = lista_documentos_perturbados.loc[lista_documentos_perturbados['id']==id_perturbado].values[0]        
        #print("registro_perturbado_1a_sentenca:", documento_perturbado[3][0][4])
        palavra_mascarada = documento_perturbado[3][0][1]
        token_predito = documento_perturbado[3][0][2]
        peso_predito = documento_perturbado[3][0][3]
        posicao_sorteio = documento_perturbado[3][0][4]

        # Recupera o id documento perturbado se ele foi classificado corretamente
        documento_id_perturbado_correto = listaRetornoClassificadoCorretamenteSemRepeticao.loc[listaRetornoClassificadoCorretamenteSemRepeticao["id"] == id_perturbado]        
        
        # Se foi encontrado foi classificado corretamente
        if len(documento_id_perturbado_correto) != 0:
          versaoPerturbadaClassificada = True
          #print("documento_id_perturbado_correto:",len(documento_id_perturbado_correto))          
          documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == str(documento_id_perturbado_correto['id'].values[0])]
          #print("documento:",documento)
          #saidaPerturbadoCorreto = saidaPerturbadoCorreto + "\n    pert_" + str(j) + ": " + str(documento['documento'].values[0]) + " - " + str(posicao_sorteio) + " - " + str(documento['classe'].values[0])
          lista_perturbado_classificado_correto.append(["pert_" + str(j), str(documento['documento'].values[0]), palavra_mascarada, token_predito, posicao_sorteio, 0 ])

        else:
          # Recupera o id documento perturbado se ele foi classificado incorretamente
          documento_id_perturbado_incorreto = listaRetornoClassificadoIncorretamenteSemRepeticao.loc[listaRetornoClassificadoIncorretamenteSemRepeticao["id"] == id_perturbado]

          # Se foi encontrado foi classificado incorretamente
          if len(documento_id_perturbado_incorreto) != 0:
            #print("documento_id_perturbado_correto:",len(documento_id_perturbado_correto))          
            documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == str(documento_id_perturbado_incorreto['id'].values[0])]
            #print("documento:",documento)
            #saidaPerturbadoIncorreto = saidaPerturbadoIncorreto + "\n    pert_" + str(j) + ": " + str(documento['documento'].values[0]) + " - " + str(posicao_sorteio) + " - 1"            
            lista_perturbado_classificado_incorreto.append(["pert_" + str(j), str(documento['documento'].values[0]), palavra_mascarada, token_predito, posicao_sorteio, 1 ])
                
    lista_perturbado_classificado_correto = sorted(lista_perturbado_classificado_correto, key=lambda x: x[4], reverse=False)
    lista_perturbado_classificado_incorreto = sorted(lista_perturbado_classificado_incorreto, key=lambda x: x[4], reverse=False)

    # Mostra a saída das classificações
    print("  Classificações corretas (classe = predição): " + str(len(lista_perturbado_classificado_correto)))
    if len(lista_perturbado_classificado_correto) != 0:           
      for i, x in enumerate(lista_perturbado_classificado_correto):
          print("  " , x[1]," [" + x[2] + " -> " + x[3] + "(" + str(x[4]) + ")] - ",x[5])
    
    print("  Classificações incorretas(classe != predição): " + str(len(lista_perturbado_classificado_incorreto)))
    if len(lista_perturbado_classificado_incorreto) != 0:           
      for i, x in enumerate(lista_perturbado_classificado_incorreto):
          print("  " ,  x[1]," [" + x[2] + " -> " + x[3] + "(" + str(x[4]) + ")] - ",x[5])

print("\nDocumentos originais classificados incorretamente:", DOClasseIncorreta)
# Out:
# Documentos originais e perturados e suas classificações: 800
#   Classificados corretamente(classe=previsão): 797
#   Classificados incorretamente(classe!=previsão): 3
#
# DO: Como enfileirar elementos em uma fila? - 1
#     SCONJ VERB NOUN ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como adicionar elementos em uma fila ?  [enfileirar -> adicionar(3)] -  0
#    Como conseguir elementos em uma fila ?  [enfileirar -> conseguir(7)] -  0
#    Como ver elementos em uma fila ?  [enfileirar -> ver(9)] -  0
#    Como separar elementos em uma fila ?  [enfileirar -> separar(11)] -  0
#    Como reconhecer elementos em uma fila ?  [enfileirar -> reconhecer(14)] -  0
#    Como obter elementos em uma fila ?  [enfileirar -> obter(17)] -  0
#    Como obter elementos em uma fila ?  [enfileirar -> obter(17)] -  0
#    Como introduzir elementos em uma fila ?  [enfileirar -> introduzir(21)] -  0
#    Como ter elementos em uma fila ?  [enfileirar -> ter(23)] -  0
#    Como desenhar elementos em uma fila ?  [enfileirar -> desenhar(32)] -  0
#    Como trocar elementos em uma fila ?  [enfileirar -> trocar(33)] -  0
#    Como criar elementos em uma fila ?  [enfileirar -> criar(36)] -  0
#    Como registrar elementos em uma fila ?  [enfileirar -> registrar(39)] -  0
#    Como usar elementos em uma fila ?  [enfileirar -> usar(43)] -  0
#    Como analisar elementos em uma fila ?  [enfileirar -> analisar(70)] -  0
#    Como se elementos em uma fila ?  [enfileirar -> se(72)] -  0
#    Como unir elementos em uma fila ?  [enfileirar -> unir(80)] -  0
#    Como eliminar elementos em uma fila ?  [enfileirar -> eliminar(81)] -  0
#    Como acomodar elementos em uma fila ?  [enfileirar -> acomodar(86)] -  0
#    Como encaix elementos em uma fila ?  [enfileirar -> encaix(90)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como desenfileirar elementos em uma fila? - 1
#     SCONJ VERB NOUN ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como classificar elementos em uma fila ?  [desenfileirar -> classificar(6)] -  0
#    Como conseguir elementos em uma fila ?  [desenfileirar -> conseguir(7)] -  0
#    Como juntar elementos em uma fila ?  [desenfileirar -> juntar(10)] -  0
#    Como procurar elementos em uma fila ?  [desenfileirar -> procurar(13)] -  0
#    Como deixar elementos em uma fila ?  [desenfileirar -> deixar(30)] -  0
#    Como comprar elementos em uma fila ?  [desenfileirar -> comprar(37)] -  0
#    Como esperar elementos em uma fila ?  [desenfileirar -> esperar(41)] -  0
#    Como marcar elementos em uma fila ?  [desenfileirar -> marcar(47)] -  0
#    Como descobrir elementos em uma fila ?  [desenfileirar -> descobrir(50)] -  0
#    Como coloca elementos em uma fila ?  [desenfileirar -> coloca(51)] -  0
#    Como estão elementos em uma fila ?  [desenfileirar -> estão(53)] -  0
#    Como inser elementos em uma fila ?  [desenfileirar -> inser(58)] -  0
#    Como substituir elementos em uma fila ?  [desenfileirar -> substituir(59)] -  0
#    Como transpor elementos em uma fila ?  [desenfileirar -> transpor(67)] -  0
#    Como integrar elementos em uma fila ?  [desenfileirar -> integrar(69)] -  0
#    Como analisar elementos em uma fila ?  [desenfileirar -> analisar(70)] -  0
#    Como unir elementos em uma fila ?  [desenfileirar -> unir(80)] -  0
#    Como eliminar elementos em uma fila ?  [desenfileirar -> eliminar(81)] -  0
#    Como concentrar elementos em uma fila ?  [desenfileirar -> concentrar(93)] -  0
#    Como destacar elementos em uma fila ?  [desenfileirar -> destacar(94)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como empilhar elementos em uma pilha? - 1
#     SCONJ VERB NOUN ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como ligar elementos em uma pilha ?  [empilhar -> ligar(6)] -  0
#    Como ligar elementos em uma pilha ?  [empilhar -> ligar(6)] -  0
#    Como ligar elementos em uma pilha ?  [empilhar -> ligar(6)] -  0
#    Como incluir elementos em uma pilha ?  [empilhar -> incluir(10)] -  0
#    Como procurar elementos em uma pilha ?  [empilhar -> procurar(12)] -  0
#    Como achar elementos em uma pilha ?  [empilhar -> achar(15)] -  0
#    Como usar elementos em uma pilha ?  [empilhar -> usar(21)] -  0
#    Como contar elementos em uma pilha ?  [empilhar -> contar(24)] -  0
#    Como ver elementos em uma pilha ?  [empilhar -> ver(27)] -  0
#    Como instalar elementos em uma pilha ?  [empilhar -> instalar(32)] -  0
#    Como criar elementos em uma pilha ?  [empilhar -> criar(34)] -  0
#    Como utilizar elementos em uma pilha ?  [empilhar -> utilizar(36)] -  0
#    Como retirar elementos em uma pilha ?  [empilhar -> retirar(42)] -  0
#    Como retirar elementos em uma pilha ?  [empilhar -> retirar(42)] -  0
#    Como comprar elementos em uma pilha ?  [empilhar -> comprar(44)] -  0
#    Como construir elementos em uma pilha ?  [empilhar -> construir(47)] -  0
#    Como mover elementos em uma pilha ?  [empilhar -> mover(54)] -  0
#    Como mudar elementos em uma pilha ?  [empilhar -> mudar(57)] -  0
#    Como destacar elementos em uma pilha ?  [empilhar -> destacar(67)] -  0
#    Como lançar elementos em uma pilha ?  [empilhar -> lançar(81)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como empilhar e desempilhar elementos em uma pilha? - 1
#     SCONJ VERB CCONJ VERB NOUN ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como juntar e desempilhar elementos em uma pilha ?  [empilhar -> juntar(3)] -  0
#    Como empilhar e manter elementos em uma pilha ?  [desempilhar -> manter(13)] -  0
#    Como empilhar e classificar elementos em uma pilha ?  [desempilhar -> classificar(15)] -  0
#    Como empilhar e acomodar elementos em uma pilha ?  [desempilhar -> acomodar(19)] -  0
#    Como empilhar e controlar elementos em uma pilha ?  [desempilhar -> controlar(30)] -  0
#    Como empilhar e representar elementos em uma pilha ?  [desempilhar -> representar(33)] -  0
#    Como empilhar e exibir elementos em uma pilha ?  [desempilhar -> exibir(38)] -  0
#    Como empilhar e conter elementos em uma pilha ?  [desempilhar -> conter(41)] -  0
#    Como pôr e desempilhar elementos em uma pilha ?  [empilhar -> pôr(41)] -  0
#    Como jogar e desempilhar elementos em uma pilha ?  [empilhar -> jogar(45)] -  0
#    Como empilhar e remover elementos em uma pilha ?  [desempilhar -> remover(47)] -  0
#    Como empilhar e remover elementos em uma pilha ?  [desempilhar -> remover(47)] -  0
#    Como gravar e desempilhar elementos em uma pilha ?  [empilhar -> gravar(53)] -  0
#    Como empilhar e marcar elementos em uma pilha ?  [desempilhar -> marcar(73)] -  0
#    Como empilhar e fechar elementos em uma pilha ?  [desempilhar -> fechar(74)] -  0
#    Como reconhecer e desempilhar elementos em uma pilha ?  [empilhar -> reconhecer(77)] -  0
#    Como contar e desempilhar elementos em uma pilha ?  [empilhar -> contar(82)] -  0
#    Como empilhar e destacar elementos em uma pilha ?  [desempilhar -> destacar(87)] -  0
#    Como empilhar e enviar elementos em uma pilha ?  [desempilhar -> enviar(88)] -  0
#    Como empilhar e reproduzir elementos em uma pilha ?  [desempilhar -> reproduzir(91)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como empilhar elementos em uma estrutura de dados pilha? - 1
#     SCONJ VERB NOUN ADP DET NOUN ADP NOUN NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como localizar elementos em uma estrutura de dados pilha ?  [empilhar -> localizar(6)] -  0
#    Como incluir elementos em uma estrutura de dados pilha ?  [empilhar -> incluir(8)] -  0
#    Como criar elementos em uma estrutura de dados pilha ?  [empilhar -> criar(10)] -  0
#    Como buscar elementos em uma estrutura de dados pilha ?  [empilhar -> buscar(14)] -  0
#    Como utilizar elementos em uma estrutura de dados pilha ?  [empilhar -> utilizar(19)] -  0
#    Como descobrir elementos em uma estrutura de dados pilha ?  [empilhar -> descobrir(21)] -  0
#    Como usar elementos em uma estrutura de dados pilha ?  [empilhar -> usar(27)] -  0
#    Como citar elementos em uma estrutura de dados pilha ?  [empilhar -> citar(28)] -  0
#    Como escolher elementos em uma estrutura de dados pilha ?  [empilhar -> escolher(35)] -  0
#    Como verificar elementos em uma estrutura de dados pilha ?  [empilhar -> verificar(51)] -  0
#    Como verificar elementos em uma estrutura de dados pilha ?  [empilhar -> verificar(51)] -  0
#    Como estudar elementos em uma estrutura de dados pilha ?  [empilhar -> estudar(53)] -  0
#    Como salvar elementos em uma estrutura de dados pilha ?  [empilhar -> salvar(61)] -  0
#    Como ligar elementos em uma estrutura de dados pilha ?  [empilhar -> ligar(64)] -  0
#    Como avaliar elementos em uma estrutura de dados pilha ?  [empilhar -> avaliar(65)] -  0
#    Como adquirir elementos em uma estrutura de dados pilha ?  [empilhar -> adquirir(71)] -  0
#    Como elaborar elementos em uma estrutura de dados pilha ?  [empilhar -> elaborar(77)] -  0
#    Como considerar elementos em uma estrutura de dados pilha ?  [empilhar -> considerar(80)] -  0
#    Como há elementos em uma estrutura de dados pilha ?  [empilhar -> há(83)] -  0
#    Como unir elementos em uma estrutura de dados pilha ?  [empilhar -> unir(88)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como empilhar e desempilhar elementos em uma estrutura de dados pilha? - 1
#     SCONJ VERB CCONJ VERB NOUN ADP DET NOUN ADP NOUN NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como empilhar e organizar elementos em uma estrutura de dados pilha ?  [desempilhar -> organizar(0)] -  0
#    Como organizar e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> organizar(7)] -  0
#    Como empilhar e carregar elementos em uma estrutura de dados pilha ?  [desempilhar -> carregar(18)] -  0
#    Como empilhar e utilizar elementos em uma estrutura de dados pilha ?  [desempilhar -> utilizar(28)] -  0
#    Como incorporar e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> incorporar(33)] -  0
#    Como empilhar e acomodar elementos em uma estrutura de dados pilha ?  [desempilhar -> acomodar(33)] -  0
#    Como parar e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> parar(34)] -  0
#    Como escrever e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> escrever(36)] -  0
#    Como buscar e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> buscar(38)] -  0
#    Como escolher e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> escolher(42)] -  0
#    Como empilhar e recuperar elementos em uma estrutura de dados pilha ?  [desempilhar -> recuperar(52)] -  0
#    Como estender e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> estender(53)] -  0
#    Como empilhar e cortar elementos em uma estrutura de dados pilha ?  [desempilhar -> cortar(54)] -  0
#    Como estabelecer e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> estabelecer(56)] -  0
#    Como empilhar e enviar elementos em uma estrutura de dados pilha ?  [desempilhar -> enviar(67)] -  0
#    Como empilhar e transmitir elementos em uma estrutura de dados pilha ?  [desempilhar -> transmitir(71)] -  0
#    Como desenvolver e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> desenvolver(79)] -  0
#    Como pôr e desempilhar elementos em uma estrutura de dados pilha ?  [empilhar -> pôr(81)] -  0
#    Como empilhar e conduzir elementos em uma estrutura de dados pilha ?  [desempilhar -> conduzir(89)] -  0
#    Como empilhar e informar elementos em uma estrutura de dados pilha ?  [desempilhar -> informar(95)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como desempilhar elementos em uma pilha? - 1
#     ADP NOUN NOUN ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como encontrar elementos em uma pilha ?  [desempilhar -> encontrar(4)] -  0
#    Como desempilhar dinheiro em uma pilha ?  [elementos -> dinheiro(8)] -  0
#    Como desempilhar elementos em uma estrutura ?  [pilha -> estrutura(10)] -  0
#    Como desempilhar frutas em uma pilha ?  [elementos -> frutas(28)] -  0
#    Como desempilhar elementos em uma frase ?  [pilha -> frase(33)] -  0
#    Como desempilhar espaço em uma pilha ?  [elementos -> espaço(41)] -  0
#    Como desempilhar músicas em uma pilha ?  [elementos -> músicas(49)] -  0
#    Como por elementos em uma pilha ?  [desempilhar -> por(52)] -  0
#    Como desempilhar elementos em uma pesquisa ?  [pilha -> pesquisa(57)] -  0
#    Como desempilhar medicamentos em uma pilha ?  [elementos -> medicamentos(57)] -  0
#    Como concentrar elementos em uma pilha ?  [desempilhar -> concentrar(63)] -  0
#    Como desempilhar sal em uma pilha ?  [elementos -> sal(67)] -  0
#    Como desempilhar gasolina em uma pilha ?  [elementos -> gasolina(72)] -  0
#    Como desempilhar notas em uma pilha ?  [elementos -> notas(75)] -  0
#    Como desempilhar elementos em uma escada ?  [pilha -> escada(80)] -  0
#    Como desempilhar elementos em uma prova ?  [pilha -> prova(84)] -  0
#    Como desempilhar brinquedos em uma pilha ?  [elementos -> brinquedos(85)] -  0
#    Como desempilhar cartões em uma pilha ?  [elementos -> cartões(88)] -  0
#    Como desempilhar elementos em uma campanha ?  [pilha -> campanha(92)] -  0
#    Como desempilhar elementos em uma rede ?  [pilha -> rede(97)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como desempilhar elementos em uma estrutura de dados pilha? - 1
#     ADP NOUN NOUN ADP DET NOUN ADP NOUN NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    Como desempilhar tabelas em uma estrutura de dados pilha ?  [elementos -> tabelas(7)] -  0
#    Como desempilhar elementos em uma memória de dados pilha ?  [estrutura -> memória(14)] -  0
#    Como desempilhar elementos em uma tela de dados pilha ?  [estrutura -> tela(25)] -  0
#    Como desempilhar classes em uma estrutura de dados pilha ?  [elementos -> classes(29)] -  0
#    Como desempilhar classes em uma estrutura de dados pilha ?  [elementos -> classes(29)] -  0
#    Como desempilhar transações em uma estrutura de dados pilha ?  [elementos -> transações(30)] -  0
#    Como desempilhar elementos em uma linha de dados pilha ?  [estrutura -> linha(42)] -  0
#    Como desempilhar aplicações em uma estrutura de dados pilha ?  [elementos -> aplicações(50)] -  0
#    Como estudar elementos em uma estrutura de dados pilha ?  [desempilhar -> estudar(53)] -  0
#    Como desempilhar elementos em uma estrutura de cor pilha ?  [dados -> cor(53)] -  0
#    Como remover elementos em uma estrutura de dados pilha ?  [desempilhar -> remover(56)] -  0
#    Como desempilhar elementos em uma estrutura de escala pilha ?  [dados -> escala(60)] -  0
#    Como desempilhar elementos em uma estrutura de dados pública ?  [pilha -> pública(68)] -  0
#    Como desempilhar elementos em uma estrutura de quatro pilha ?  [dados -> quatro(74)] -  0
#    Como instalar elementos em uma estrutura de dados pilha ?  [desempilhar -> instalar(75)] -  0
#    Como converter elementos em uma estrutura de dados pilha ?  [desempilhar -> converter(78)] -  0
#    Como desempilhar elementos em uma estrutura de mol pilha ?  [dados -> mol(79)] -  0
#    Como produzir elementos em uma estrutura de dados pilha ?  [desempilhar -> produzir(91)] -  0
#    Como fazer elementos em uma estrutura de dados pilha ?  [desempilhar -> fazer(94)] -  0
#   Classificações incorretas(classe != predição): 1
#    Como desempilhar elementos em uma estrutura de longa pilha ?  [dados -> longa(28)] -  1
#
# DO: O que é uma pilha e como empilhar seu elemento? - 1
#     PRON PRON AUX DET NOUN CCONJ ADV VERB DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    O que é uma pilha e como identificar seu elemento ?  [empilhar -> identificar(0)] -  0
#    O que é uma pilha e como substituir seu elemento ?  [empilhar -> substituir(12)] -  0
#    O que é uma pilha e como escolher seu elemento ?  [empilhar -> escolher(13)] -  0
#    O que é uma pilha e como organizar seu elemento ?  [empilhar -> organizar(18)] -  0
#    O que é uma pilha e como organizar seu elemento ?  [empilhar -> organizar(18)] -  0
#    O que é uma pilha e como fica seu elemento ?  [empilhar -> fica(22)] -  0
#    O que é uma pilha e como definir seu elemento ?  [empilhar -> definir(24)] -  0
#    O que é uma pilha e como conseguir seu elemento ?  [empilhar -> conseguir(31)] -  0
#    O que é uma pilha e como conseguir seu elemento ?  [empilhar -> conseguir(31)] -  0
#    O que é uma pilha e como conseguir seu elemento ?  [empilhar -> conseguir(31)] -  0
#    O que é uma pilha e como preservar seu elemento ?  [empilhar -> preservar(33)] -  0
#    O que é uma pilha e como preservar seu elemento ?  [empilhar -> preservar(33)] -  0
#    O que é uma pilha e como detectar seu elemento ?  [empilhar -> detectar(35)] -  0
#    O que é uma pilha e como detectar seu elemento ?  [empilhar -> detectar(35)] -  0
#    O que é uma pilha e como vem seu elemento ?  [empilhar -> vem(49)] -  0
#    O que é uma pilha e como o seu elemento ?  [empilhar -> o(53)] -  0
#    O que é uma pilha e como adquirir seu elemento ?  [empilhar -> adquirir(59)] -  0
#    O que é uma pilha e como explicar seu elemento ?  [empilhar -> explicar(77)] -  0
#    O que é uma pilha e como funcionar seu elemento ?  [empilhar -> funcionar(91)] -  0
#    O que é uma pilha e como substitui seu elemento ?  [empilhar -> substitui(92)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que é uma fila e como enfileirar seu elemento? - 1
#     PRON PRON AUX DET NOUN CCONJ ADV VERB DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    O que é uma fila e como é seu elemento ?  [enfileirar -> é(1)] -  0
#    O que é uma fila e como classificar seu elemento ?  [enfileirar -> classificar(5)] -  0
#    O que é uma fila e como funciona seu elemento ?  [enfileirar -> funciona(8)] -  0
#    O que é uma fila e como entender seu elemento ?  [enfileirar -> entender(23)] -  0
#    O que é uma fila e como interpretar seu elemento ?  [enfileirar -> interpretar(24)] -  0
#    O que é uma fila e como determina seu elemento ?  [enfileirar -> determina(26)] -  0
#    O que é uma fila e como designar seu elemento ?  [enfileirar -> designar(33)] -  0
#    O que é uma fila e como designar seu elemento ?  [enfileirar -> designar(33)] -  0
#    O que é uma fila e como representa seu elemento ?  [enfileirar -> representa(37)] -  0
#    O que é uma fila e como montar seu elemento ?  [enfileirar -> montar(50)] -  0
#    O que é uma fila e como controlar seu elemento ?  [enfileirar -> controlar(53)] -  0
#    O que é uma fila e como resolver seu elemento ?  [enfileirar -> resolver(58)] -  0
#    O que é uma fila e como aparece seu elemento ?  [enfileirar -> aparece(68)] -  0
#    O que é uma fila e como aparece seu elemento ?  [enfileirar -> aparece(68)] -  0
#    O que é uma fila e como usar seu elemento ?  [enfileirar -> usar(69)] -  0
#    O que é uma fila e como criar seu elemento ?  [enfileirar -> criar(77)] -  0
#    O que é uma fila e como distribuir seu elemento ?  [enfileirar -> distribuir(81)] -  0
#    O que é uma fila e como compor seu elemento ?  [enfileirar -> compor(84)] -  0
#    O que é uma fila e como alterar seu elemento ?  [enfileirar -> alterar(85)] -  0
#    O que é uma fila e como caracteriza seu elemento ?  [enfileirar -> caracteriza(95)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que é uma fila e como desenfileirar um elemento nela? - 1
#     PRON PRON AUX DET NOUN CCONJ ADV ADV DET NOUN PRON PUNCT
#   Classificações corretas (classe = predição): 20
#    O que é uma fila e como desenfileirar um cliente nela ?  [elemento -> cliente(2)] -  0
#    O que é uma fila e como desenfileirar um produto nela ?  [elemento -> produto(4)] -  0
#    O que é uma fila e como desenfileirar um cartão nela ?  [elemento -> cartão(8)] -  0
#    O que é uma caixa e como desenfileirar um elemento nela ?  [fila -> caixa(8)] -  0
#    O que é uma tabela e como desenfileirar um elemento nela ?  [fila -> tabela(10)] -  0
#    O que é uma fila e como desenfileirar um ingresso nela ?  [elemento -> ingresso(14)] -  0
#    O que é uma parede e como desenfileirar um elemento nela ?  [fila -> parede(16)] -  0
#    O que é uma fila e como desenfileirar um barco nela ?  [elemento -> barco(22)] -  0
#    O que é uma fila e como desenfileirar um bloco nela ?  [elemento -> bloco(27)] -  0
#    O que é uma classe e como desenfileirar um elemento nela ?  [fila -> classe(36)] -  0
#    O que é uma classe e como desenfileirar um elemento nela ?  [fila -> classe(36)] -  0
#    O que é uma linha e como desenfileirar um elemento nela ?  [fila -> linha(43)] -  0
#    O que é uma fila e como desenfileirar um evento nela ?  [elemento -> evento(45)] -  0
#    O que é uma fila e como desenfileirar um motor nela ?  [elemento -> motor(55)] -  0
#    O que é uma fila e como desenfileirar um corpo nela ?  [elemento -> corpo(66)] -  0
#    O que é uma fila e como desenfileirar um ambiente nela ?  [elemento -> ambiente(76)] -  0
#    O que é uma página e como desenfileirar um elemento nela ?  [fila -> página(79)] -  0
#    O que é uma ordem e como desenfileirar um elemento nela ?  [fila -> ordem(91)] -  0
#    O que é uma ordem e como desenfileirar um elemento nela ?  [fila -> ordem(91)] -  0
#    O que é uma fila e como desenfileirar um cartaz nela ?  [elemento -> cartaz(95)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que é uma pilha e como desempilhar um elemento nela? - 1
#     PRON PRON AUX DET NOUN CCONJ ADV NOUN DET NOUN PRON PUNCT
#   Classificações corretas (classe = predição): 20
#    O que é uma pilha e como desempilhar um livro nela ?  [elemento -> livro(2)] -  0
#    O que é uma pilha e como desempilhar um objeto nela ?  [elemento -> objeto(4)] -  0
#    O que é uma tabela e como desempilhar um elemento nela ?  [pilha -> tabela(8)] -  0
#    O que é uma pilha e como desempilhar um alimento nela ?  [elemento -> alimento(14)] -  0
#    O que é uma pilha e como identificar um elemento nela ?  [desempilhar -> identificar(19)] -  0
#    O que é uma pilha e como gravar um elemento nela ?  [desempilhar -> gravar(21)] -  0
#    O que é uma pilha e como desempilhar um espaço nela ?  [elemento -> espaço(28)] -  0
#    O que é uma pilha e como registrar um elemento nela ?  [desempilhar -> registrar(30)] -  0
#    O que é uma pilha e como utilizar um elemento nela ?  [desempilhar -> utilizar(36)] -  0
#    O que é uma pilha e como desempilhar um dispositivo nela ?  [elemento -> dispositivo(39)] -  0
#    O que é uma série e como desempilhar um elemento nela ?  [pilha -> série(43)] -  0
#    O que é uma pilha e como desempilhar um tubo nela ?  [elemento -> tubo(44)] -  0
#    O que é uma máscara e como desempilhar um elemento nela ?  [pilha -> máscara(52)] -  0
#    O que é uma pilha e como desempilhar um carvão nela ?  [elemento -> carvão(57)] -  0
#    O que é uma pilha e como esconder um elemento nela ?  [desempilhar -> esconder(58)] -  0
#    O que é uma fórmula e como desempilhar um elemento nela ?  [pilha -> fórmula(58)] -  0
#    O que é uma pilha e como desempilhar um composto nela ?  [elemento -> composto(64)] -  0
#    O que é uma área e como desempilhar um elemento nela ?  [pilha -> área(79)] -  0
#    O que é uma camisa e como desempilhar um elemento nela ?  [pilha -> camisa(88)] -  0
#    O que é uma pilha e como reproduzir um elemento nela ?  [desempilhar -> reproduzir(97)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que é uma fila e como enfileirar um elemento nela? - 1
#     PRON PRON AUX DET NOUN CCONJ ADV VERB DET NOUN PRON PUNCT
#   Classificações corretas (classe = predição): 20
#    O que é uma fila e como colocar um elemento nela ?  [enfileirar -> colocar(0)] -  0
#    O que é uma fila e como adicionar um elemento nela ?  [enfileirar -> adicionar(1)] -  0
#    O que é uma fila e como incluir um elemento nela ?  [enfileirar -> incluir(3)] -  0
#    O que é uma fila e como incluir um elemento nela ?  [enfileirar -> incluir(3)] -  0
#    O que é uma fila e como encontrar um elemento nela ?  [enfileirar -> encontrar(13)] -  0
#    O que é uma fila e como registrar um elemento nela ?  [enfileirar -> registrar(23)] -  0
#    O que é uma fila e como pôr um elemento nela ?  [enfileirar -> pôr(25)] -  0
#    O que é uma fila e como escolher um elemento nela ?  [enfileirar -> escolher(31)] -  0
#    O que é uma fila e como ligar um elemento nela ?  [enfileirar -> ligar(36)] -  0
#    O que é uma fila e como existe um elemento nela ?  [enfileirar -> existe(38)] -  0
#    O que é uma fila e como destacar um elemento nela ?  [enfileirar -> destacar(49)] -  0
#    O que é uma fila e como alterar um elemento nela ?  [enfileirar -> alterar(57)] -  0
#    O que é uma fila e como controlar um elemento nela ?  [enfileirar -> controlar(62)] -  0
#    O que é uma fila e como representa um elemento nela ?  [enfileirar -> representa(63)] -  0
#    O que é uma fila e como determinar um elemento nela ?  [enfileirar -> determinar(67)] -  0
#    O que é uma fila e como consiste um elemento nela ?  [enfileirar -> consiste(76)] -  0
#    O que é uma fila e como jogar um elemento nela ?  [enfileirar -> jogar(79)] -  0
#    O que é uma fila e como define um elemento nela ?  [enfileirar -> define(85)] -  0
#    O que é uma fila e como substitui um elemento nela ?  [enfileirar -> substitui(87)] -  0
#    O que é uma fila e como obter um elemento nela ?  [enfileirar -> obter(95)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que é uma pilha e como empilhar um elemento nela? - 1
#     PRON PRON AUX DET NOUN CCONJ ADV VERB DET NOUN PRON PUNCT
#   Classificações corretas (classe = predição): 20
#    O que é uma pilha e como ligar um elemento nela ?  [empilhar -> ligar(2)] -  0
#    O que é uma pilha e como incluir um elemento nela ?  [empilhar -> incluir(5)] -  0
#    O que é uma pilha e como prender um elemento nela ?  [empilhar -> prender(10)] -  0
#    O que é uma pilha e como carregar um elemento nela ?  [empilhar -> carregar(12)] -  0
#    O que é uma pilha e como transformar um elemento nela ?  [empilhar -> transformar(13)] -  0
#    O que é uma pilha e como manter um elemento nela ?  [empilhar -> manter(26)] -  0
#    O que é uma pilha e como jogar um elemento nela ?  [empilhar -> jogar(27)] -  0
#    O que é uma pilha e como registrar um elemento nela ?  [empilhar -> registrar(30)] -  0
#    O que é uma pilha e como registrar um elemento nela ?  [empilhar -> registrar(30)] -  0
#    O que é uma pilha e como medir um elemento nela ?  [empilhar -> medir(34)] -  0
#    O que é uma pilha e como medir um elemento nela ?  [empilhar -> medir(34)] -  0
#    O que é uma pilha e como formar um elemento nela ?  [empilhar -> formar(45)] -  0
#    O que é uma pilha e como calcular um elemento nela ?  [empilhar -> calcular(62)] -  0
#    O que é uma pilha e como ficar um elemento nela ?  [empilhar -> ficar(68)] -  0
#    O que é uma pilha e como entra um elemento nela ?  [empilhar -> entra(70)] -  0
#    O que é uma pilha e como ver um elemento nela ?  [empilhar -> ver(73)] -  0
#    O que é uma pilha e como ver um elemento nela ?  [empilhar -> ver(73)] -  0
#    O que é uma pilha e como dividir um elemento nela ?  [empilhar -> dividir(80)] -  0
#    O que é uma pilha e como reproduzir um elemento nela ?  [empilhar -> reproduzir(97)] -  0
#    O que é uma pilha e como falta um elemento nela ?  [empilhar -> falta(98)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que é uma pilha e como empilhar e desempilhar seus elementos? - 1
#     PRON PRON AUX DET NOUN CCONJ ADV VERB CCONJ NOUN DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    O que é uma pilha e como separar e desempilhar seus elementos ?  [empilhar -> separar(0)] -  0
#    O que é uma pilha e como preparar e desempilhar seus elementos ?  [empilhar -> preparar(4)] -  0
#    O que é uma pilha e como pegar e desempilhar seus elementos ?  [empilhar -> pegar(15)] -  0
#    O que é uma pilha e como acomodar e desempilhar seus elementos ?  [empilhar -> acomodar(17)] -  0
#    O que é uma pilha e como classificar e desempilhar seus elementos ?  [empilhar -> classificar(23)] -  0
#    O que é uma pilha e como capturar e desempilhar seus elementos ?  [empilhar -> capturar(26)] -  0
#    O que é uma pilha e como envolver e desempilhar seus elementos ?  [empilhar -> envolver(27)] -  0
#    O que é uma pilha e como transformar e desempilhar seus elementos ?  [empilhar -> transformar(28)] -  0
#    O que é uma pilha e como aproveitar e desempilhar seus elementos ?  [empilhar -> aproveitar(31)] -  0
#    O que é uma pilha e como manter e desempilhar seus elementos ?  [empilhar -> manter(42)] -  0
#    O que é uma pilha e como dividir e desempilhar seus elementos ?  [empilhar -> dividir(46)] -  0
#    O que é uma pilha e como chegar e desempilhar seus elementos ?  [empilhar -> chegar(62)] -  0
#    O que é uma pilha e como encerrar e desempilhar seus elementos ?  [empilhar -> encerrar(63)] -  0
#    O que é uma pilha e como instalar e desempilhar seus elementos ?  [empilhar -> instalar(64)] -  0
#    O que é uma pilha e como registrar e desempilhar seus elementos ?  [empilhar -> registrar(66)] -  0
#    O que é uma pilha e como estender e desempilhar seus elementos ?  [empilhar -> estender(74)] -  0
#    O que é uma pilha e como alimentar e desempilhar seus elementos ?  [empilhar -> alimentar(75)] -  0
#    O que é uma pilha e como esconder e desempilhar seus elementos ?  [empilhar -> esconder(78)] -  0
#    O que é uma pilha e como levar e desempilhar seus elementos ?  [empilhar -> levar(84)] -  0
#    O que é uma pilha e como incluir e desempilhar seus elementos ?  [empilhar -> incluir(88)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que é uma fila e como enfileirar e desenfileirar seus elementos? - 1
#     PRON PRON AUX DET NOUN CCONJ SCONJ VERB CCONJ ADV DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    O que é uma fila e como organizar e desenfileirar seus elementos ?  [enfileirar -> organizar(0)] -  0
#    O que é uma fila e como classificar e desenfileirar seus elementos ?  [enfileirar -> classificar(8)] -  0
#    O que é uma fila e como colocar e desenfileirar seus elementos ?  [enfileirar -> colocar(16)] -  0
#    O que é uma fila e como remover e desenfileirar seus elementos ?  [enfileirar -> remover(19)] -  0
#    O que é uma fila e como dividir e desenfileirar seus elementos ?  [enfileirar -> dividir(22)] -  0
#    O que é uma fila e como fechar e desenfileirar seus elementos ?  [enfileirar -> fechar(26)] -  0
#    O que é uma fila e como detectar e desenfileirar seus elementos ?  [enfileirar -> detectar(43)] -  0
#    O que é uma fila e como transferir e desenfileirar seus elementos ?  [enfileirar -> transferir(61)] -  0
#    O que é uma fila e como aproximar e desenfileirar seus elementos ?  [enfileirar -> aproximar(67)] -  0
#    O que é uma fila e como aproveitar e desenfileirar seus elementos ?  [enfileirar -> aproveitar(69)] -  0
#    O que é uma fila e como fixar e desenfileirar seus elementos ?  [enfileirar -> fixar(70)] -  0
#    O que é uma fila e como fixar e desenfileirar seus elementos ?  [enfileirar -> fixar(70)] -  0
#    O que é uma fila e como alcançar e desenfileirar seus elementos ?  [enfileirar -> alcançar(72)] -  0
#    O que é uma fila e como cobrir e desenfileirar seus elementos ?  [enfileirar -> cobrir(75)] -  0
#    O que é uma fila e como nomear e desenfileirar seus elementos ?  [enfileirar -> nomear(76)] -  0
#    O que é uma fila e como virar e desenfileirar seus elementos ?  [enfileirar -> virar(77)] -  0
#    O que é uma fila e como estabelecer e desenfileirar seus elementos ?  [enfileirar -> estabelecer(81)] -  0
#    O que é uma fila e como incluir e desenfileirar seus elementos ?  [enfileirar -> incluir(82)] -  0
#    O que é uma fila e como tratar e desenfileirar seus elementos ?  [enfileirar -> tratar(90)] -  0
#    O que é uma fila e como conhecer e desenfileirar seus elementos ?  [enfileirar -> conhecer(91)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? - 1
#     ADV AUX VERB DET NOUN SCONJ VERB CCONJ VERB NOUN ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como são conhecidas as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> conhecidas(3)] -  0
#    Como são implementadas as operações de juntar e desempilhar elementos em uma pilha ?  [empilhar -> juntar(3)] -  0
#    Como são implementadas as operações de empilhar e carregar elementos em uma pilha ?  [desempilhar -> carregar(5)] -  0
#    Como são realizados as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> realizados(15)] -  0
#    Como são tomadas as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> tomadas(27)] -  0
#    Como são diferentes as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> diferentes(30)] -  0
#    Como são implementadas as operações de empilhar e classificar elementos em uma pilha ?  [desempilhar -> classificar(33)] -  0
#    Como são relacionadas as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> relacionadas(33)] -  0
#    Como são escritas as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> escritas(52)] -  0
#    Como são implementadas as operações de identificar e desempilhar elementos em uma pilha ?  [empilhar -> identificar(57)] -  0
#    Como são implementadas as operações de produzir e desempilhar elementos em uma pilha ?  [empilhar -> produzir(59)] -  0
#    Como são implementadas as operações de empilhar e desenhar elementos em uma pilha ?  [desempilhar -> desenhar(68)] -  0
#    Como são implementadas as operações de empilhar e medir elementos em uma pilha ?  [desempilhar -> medir(73)] -  0
#    Como são implementadas as operações de reduzir e desempilhar elementos em uma pilha ?  [empilhar -> reduzir(76)] -  0
#    Como são implementadas as operações de entrar e desempilhar elementos em uma pilha ?  [empilhar -> entrar(77)] -  0
#    Como são disputadas as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> disputadas(83)] -  0
#    Como são implementadas as operações de confirmar e desempilhar elementos em uma pilha ?  [empilhar -> confirmar(84)] -  0
#    Como são distribuídas as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> distribuídas(84)] -  0
#    Como são distribuídas as operações de empilhar e desempilhar elementos em uma pilha ?  [implementadas -> distribuídas(84)] -  0
#    Como são implementadas as operações de empilhar e nomear elementos em uma pilha ?  [desempilhar -> nomear(98)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? - 1
#     ADV AUX VERB DET NOUN SCONJ VERB CCONJ DET NOUN ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como são realizadas as operações de enfileirar e desenfileirar elementos em uma fila ?  [implementadas -> realizadas(1)] -  0
#    Como são implementadas as operações de juntar e desenfileirar elementos em uma fila ?  [enfileirar -> juntar(1)] -  0
#    Como são descritas as operações de enfileirar e desenfileirar elementos em uma fila ?  [implementadas -> descritas(6)] -  0
#    Como são tomadas as operações de enfileirar e desenfileirar elementos em uma fila ?  [implementadas -> tomadas(12)] -  0
#    Como são implementadas as operações de incorporar e desenfileirar elementos em uma fila ?  [enfileirar -> incorporar(13)] -  0
#    Como são classificadas as operações de enfileirar e desenfileirar elementos em uma fila ?  [implementadas -> classificadas(16)] -  0
#    Como são implementadas as operações de carregar e desenfileirar elementos em uma fila ?  [enfileirar -> carregar(17)] -  0
#    Como são implementadas as operações de concentrar e desenfileirar elementos em uma fila ?  [enfileirar -> concentrar(26)] -  0
#    Como são construídas as operações de enfileirar e desenfileirar elementos em uma fila ?  [implementadas -> construídas(36)] -  0
#    Como são implementadas as operações de eliminar e desenfileirar elementos em uma fila ?  [enfileirar -> eliminar(38)] -  0
#    Como são implementadas as operações de mover e desenfileirar elementos em uma fila ?  [enfileirar -> mover(41)] -  0
#    Como são divididas as operações de enfileirar e desenfileirar elementos em uma fila ?  [implementadas -> divididas(42)] -  0
#    Como são implementadas as operações de introduzir e desenfileirar elementos em uma fila ?  [enfileirar -> introduzir(43)] -  0
#    Como são implementadas as operações de consolidar e desenfileirar elementos em uma fila ?  [enfileirar -> consolidar(46)] -  0
#    Como são implementadas as operações de registrar e desenfileirar elementos em uma fila ?  [enfileirar -> registrar(47)] -  0
#    Como são implementadas as operações de vender e desenfileirar elementos em uma fila ?  [enfileirar -> vender(77)] -  0
#    Como são implementadas as operações de escolher e desenfileirar elementos em uma fila ?  [enfileirar -> escolher(82)] -  0
#    Como são implementadas as operações de deter e desenfileirar elementos em uma fila ?  [enfileirar -> deter(87)] -  0
#    Como são típicas as operações de enfileirar e desenfileirar elementos em uma fila ?  [implementadas -> típicas(87)] -  0
#    Como são implementadas as operações de levar e desenfileirar elementos em uma fila ?  [enfileirar -> levar(91)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Em uma pilha a operação de empilhar ocorre em qual extremidade? - 1
#     ADP DET NOUN DET NOUN SCONJ VERB VERB ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    Em uma pilha a operação de montagem ocorre em qual extremidade ?  [empilhar -> montagem(3)] -  0
#    Em uma pilha a operação de empilhar será em qual extremidade ?  [ocorre -> será(8)] -  0
#    Em uma pilha a operação de tensão ocorre em qual extremidade ?  [empilhar -> tensão(11)] -  0
#    Em uma pilha a operação de condução ocorre em qual extremidade ?  [empilhar -> condução(15)] -  0
#    Em uma pilha a operação de empilhar faz em qual extremidade ?  [ocorre -> faz(28)] -  0
#    Em uma pilha a operação de troca ocorre em qual extremidade ?  [empilhar -> troca(32)] -  0
#    Em uma pilha a operação de produção ocorre em qual extremidade ?  [empilhar -> produção(40)] -  0
#    Em uma pilha a operação de empilhar segue em qual extremidade ?  [ocorre -> segue(40)] -  0
#    Em uma pilha a operação de contato ocorre em qual extremidade ?  [empilhar -> contato(41)] -  0
#    Em uma pilha a operação de separação ocorre em qual extremidade ?  [empilhar -> separação(43)] -  0
#    Em uma pilha a operação de empilhar esta em qual extremidade ?  [ocorre -> esta(45)] -  0
#    Em uma pilha a operação de empilhar significa em qual extremidade ?  [ocorre -> significa(47)] -  0
#    Em uma pilha a operação de empilhar acontecem em qual extremidade ?  [ocorre -> acontecem(56)] -  0
#    Em uma pilha a operação de eletricidade ocorre em qual extremidade ?  [empilhar -> eletricidade(59)] -  0
#    Em uma pilha a operação de empilhar envolve em qual extremidade ?  [ocorre -> envolve(63)] -  0
#    Em uma pilha a operação de empilhar parou em qual extremidade ?  [ocorre -> parou(77)] -  0
#    Em uma pilha a operação de empilhar requer em qual extremidade ?  [ocorre -> requer(83)] -  0
#    Em uma pilha a operação de circuito ocorre em qual extremidade ?  [empilhar -> circuito(84)] -  0
#    Em uma pilha a operação de teste ocorre em qual extremidade ?  [empilhar -> teste(98)] -  0
#   Classificações incorretas(classe != predição): 1
#    Em uma pilha a operação de empilhar termina em qual extremidade ?  [ocorre -> termina(4)] -  1
#
# DO: Em uma fila a operação de enfileirar ocorre em qual extremidade? - 1
#     ADP DET NOUN DET NOUN SCONJ VERB VERB ADP PRON NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    Em uma fila a operação de entrada ocorre em qual extremidade ?  [enfileirar -> entrada(0)] -  0
#    Em uma fila a operação de entrada ocorre em qual extremidade ?  [enfileirar -> entrada(0)] -  0
#    Em uma fila a operação de parada ocorre em qual extremidade ?  [enfileirar -> parada(8)] -  0
#    Em uma fila a operação de movimentação ocorre em qual extremidade ?  [enfileirar -> movimentação(9)] -  0
#    Em uma fila a operação de conexão ocorre em qual extremidade ?  [enfileirar -> conexão(18)] -  0
#    Em uma fila a operação de movimento ocorre em qual extremidade ?  [enfileirar -> movimento(20)] -  0
#    Em uma fila a operação de enfileirar existe em qual extremidade ?  [ocorre -> existe(23)] -  0
#    Em uma fila a operação de transporte ocorre em qual extremidade ?  [enfileirar -> transporte(32)] -  0
#    Em uma fila a operação de enfileirar age em qual extremidade ?  [ocorre -> age(34)] -  0
#    Em uma fila a operação de escoamento ocorre em qual extremidade ?  [enfileirar -> escoamento(36)] -  0
#    Em uma fila a operação de equilíbrio ocorre em qual extremidade ?  [enfileirar -> equilíbrio(42)] -  0
#    Em uma fila a operação de enfileirar opera em qual extremidade ?  [ocorre -> opera(47)] -  0
#    Em uma fila a operação de ingresso ocorre em qual extremidade ?  [enfileirar -> ingresso(77)] -  0
#    Em uma fila a operação de retirada ocorre em qual extremidade ?  [enfileirar -> retirada(78)] -  0
#    Em uma fila a operação de armazenamento ocorre em qual extremidade ?  [enfileirar -> armazenamento(84)] -  0
#    Em uma fila a operação de enfileirar decorre em qual extremidade ?  [ocorre -> decorre(94)] -  0
#    Em uma fila a operação de enfileirar difere em qual extremidade ?  [ocorre -> difere(95)] -  0
#    Em uma fila a operação de corrida ocorre em qual extremidade ?  [enfileirar -> corrida(98)] -  0
#    Em uma fila a operação de enfileirar irá em qual extremidade ?  [ocorre -> irá(99)] -  0
#   Classificações incorretas(classe != predição): 1
#    Em uma fila a operação de enfileirar parou em qual extremidade ?  [ocorre -> parou(68)] -  1
#
# Documentos originais classificados incorretamente: 0

# %% [markdown]
# #### Listas documentos originais e perturbados classificados corretamente

# %%
print("Documentos originais e perturbados classificados corretamente(classe=previsão):", len(listaRetornoClassificadoCorretamente))
conta = 0
for i, linha in listaRetornoClassificadoCorretamente.iterrows():
  conta = conta + 1
  if i < 2000:    
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == linha["id"]]       
    if len(documento)!= 0:    
      print("   ", conta, documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Documentos originais e perturbados classificados corretamente(classe=previsão): 797
#     1 Como desempilhar elementos em uma frase ? 0
#     2 Como enfileirar elementos em uma fila? 1
#     3 Como enfileirar elementos em uma fila? 1
#     4 Como enfileirar elementos em uma fila? 1
#     5 Como enfileirar elementos em uma fila? 1
#     6 Como desenfileirar elementos em uma fila? 1
#     7 Como empilhar e enviar elementos em uma pilha ? 0
#     8 O que é uma pilha e como substituir seu elemento ? 0
#     9 O que é uma pilha e como definir seu elemento ? 0
#     10 O que é uma pilha e como fica seu elemento ? 0
#     11 Como empilhar elementos em uma estrutura de dados pilha? 1
#     12 Como empilhar elementos em uma estrutura de dados pilha? 1
#     13 Como empilhar elementos em uma estrutura de dados pilha? 1
#     14 O que é uma fila e como criar seu elemento ? 0
#     15 O que é uma fila e como entender seu elemento ? 0
#     16 O que é uma pilha e como utilizar um elemento nela ? 0
#     17 O que é uma pilha e como esconder um elemento nela ? 0
#     18 O que é uma pilha e como manter um elemento nela ? 0
#     19 Em uma pilha a operação de eletricidade ocorre em qual extremidade ? 0
#     20 Em uma pilha a operação de contato ocorre em qual extremidade ? 0
#     21 O que é uma pilha e como empilhar seu elemento? 1
#     22 O que é uma pilha e como empilhar seu elemento? 1
#     23 O que é uma pilha e como empilhar seu elemento? 1
#     24 O que é uma fila e como destacar um elemento nela ? 0
#     25 Em uma fila a operação de conexão ocorre em qual extremidade ? 0
#     26 Como empilhar e desempilhar elementos em uma pilha? 1
#     27 Como empilhar e organizar elementos em uma estrutura de dados pilha ? 0
#     28 O que é uma pilha e como empilhar um elemento nela? 1
#     29 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     30 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     31 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     32 Em uma pilha a operação de empilhar significa em qual extremidade ? 0
#     33 Como desempilhar elementos em uma pilha? 1
#     34 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     35 Em uma pilha a operação de empilhar requer em qual extremidade ? 0
#     36 O que é uma fila e como enfileirar seu elemento? 1
#     37 O que é uma fila e como enfileirar seu elemento? 1
#     38 O que é uma classe e como desenfileirar um elemento nela ? 0
#     39 O que é uma pilha e como desempilhar um elemento nela? 1
#     40 O que é uma pilha e como desempilhar um elemento nela? 1
#     41 O que é uma fila e como desenfileirar um elemento nela? 1
#     42 O que é uma fila e como desenfileirar um elemento nela? 1
#     43 O que é uma fila e como desenfileirar um corpo nela ? 0
#     44 O que é uma fila e como desenfileirar um elemento nela? 1
#     45 O que é uma fila e como desenfileirar um barco nela ? 0
#     46 O que é uma fila e como enfileirar um elemento nela? 1
#     47 O que é uma pilha e como acomodar e desempilhar seus elementos ? 0
#     48 O que é uma pilha e como classificar e desempilhar seus elementos ? 0
#     49 Como eliminar elementos em uma fila ? 0
#     50 Como usar elementos em uma fila ? 0
#     51 Como unir elementos em uma fila ? 0
#     52 Como analisar elementos em uma fila ? 0
#     53 Como analisar elementos em uma fila ? 0
#     54 Como empilhar elementos em uma pilha? 1
#     55 Como localizar elementos em uma estrutura de dados pilha ? 0
#     56 Como escolher elementos em uma estrutura de dados pilha ? 0
#     57 Como criar elementos em uma estrutura de dados pilha ? 0
#     58 Como desempilhar elementos em uma pilha? 1
#     59 Como desempilhar elementos em uma escada ? 0
#     60 Como desempilhar elementos em uma pilha? 1
#     61 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     62 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     63 Em uma fila a operação de enfileirar opera em qual extremidade ? 0
#     64 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     65 Como comprar elementos em uma pilha ? 0
#     66 Como concentrar elementos em uma pilha ? 0
#     67 Em uma fila a operação de enfileirar existe em qual extremidade ? 0
#     68 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     69 Como são implementadas as operações de empilhar e carregar elementos em uma pilha ? 0
#     70 Como são implementadas as operações de empilhar e classificar elementos em uma pilha ? 0
#     71 Como são implementadas as operações de empilhar e nomear elementos em uma pilha ? 0
#     72 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     73 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     74 Como são distribuídas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     75 Como são implementadas as operações de carregar e desenfileirar elementos em uma fila ? 0
#     76 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     77 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     78 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     79 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     80 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     81 Como empilhar elementos em uma estrutura de dados pilha? 1
#     82 O que é uma fila e como aparece seu elemento ? 0
#     83 O que é uma pilha e como registrar um elemento nela ? 0
#     84 O que é uma pilha e como ligar um elemento nela ? 0
#     85 O que é uma pilha e como reproduzir um elemento nela ? 0
#     86 O que é uma pilha e como jogar um elemento nela ? 0
#     87 O que é uma pilha e como medir um elemento nela ? 0
#     88 O que é uma pilha e como empilhar seu elemento? 1
#     89 O que é uma fila e como registrar um elemento nela ? 0
#     90 O que é uma fila e como jogar um elemento nela ? 0
#     91 Em uma fila a operação de entrada ocorre em qual extremidade ? 0
#     92 Em uma fila a operação de parada ocorre em qual extremidade ? 0
#     93 Em uma fila a operação de retirada ocorre em qual extremidade ? 0
#     94 Como empilhar e desempilhar elementos em uma pilha? 1
#     95 Como empilhar e desempilhar elementos em uma pilha? 1
#     96 Como empilhar e desempilhar elementos em uma pilha? 1
#     97 Como empilhar e carregar elementos em uma estrutura de dados pilha ? 0
#     98 Como empilhar e transmitir elementos em uma estrutura de dados pilha ? 0
#     99 O que é uma pilha e como empilhar um elemento nela? 1
#     100 O que é uma pilha e como empilhar um elemento nela? 1
#     101 O que é uma pilha e como empilhar um elemento nela? 1
#     102 O que é uma pilha e como empilhar um elemento nela? 1
#     103 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     104 Em uma pilha a operação de empilhar esta em qual extremidade ? 0
#     105 Como organizar e desempilhar elementos em uma estrutura de dados pilha ? 0
#     106 O que é uma fila e como enfileirar seu elemento? 1
#     107 O que é uma ordem e como desenfileirar um elemento nela ? 0
#     108 O que é uma pilha e como desempilhar um elemento nela? 1
#     109 O que é uma pilha e como desempilhar um alimento nela ? 0
#     110 O que é uma pilha e como desempilhar um elemento nela? 1
#     111 O que é uma pilha e como desempilhar um livro nela ? 0
#     112 O que é uma pilha e como desempilhar um elemento nela? 1
#     113 Como empilhar elementos em uma estrutura de dados pilha? 1
#     114 O que é uma pilha e como desempilhar um carvão nela ? 0
#     115 O que é uma pilha e como desempilhar um elemento nela? 1
#     116 O que é uma fórmula e como desempilhar um elemento nela ? 0
#     117 O que é uma pilha e como desempilhar um elemento nela? 1
#     118 O que é uma fila e como desenfileirar um elemento nela? 1
#     119 O que é uma fila e como desenfileirar um elemento nela? 1
#     120 O que é uma fila e como desenfileirar um bloco nela ? 0
#     121 O que é uma fila e como enfileirar um elemento nela? 1
#     122 O que é uma fila e como enfileirar um elemento nela? 1
#     123 O que é uma pilha e como instalar e desempilhar seus elementos ? 0
#     124 O que é uma pilha e como esconder e desempilhar seus elementos ? 0
#     125 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     126 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     127 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     128 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     129 Como desenhar elementos em uma fila ? 0
#     130 Como empilhar elementos em uma pilha? 1
#     131 Como buscar elementos em uma estrutura de dados pilha ? 0
#     132 Como há elementos em uma estrutura de dados pilha ? 0
#     133 Como desempilhar elementos em uma pilha? 1
#     134 Como desempilhar gasolina em uma pilha ? 0
#     135 Como enfileirar elementos em uma fila? 1
#     136 Como enfileirar elementos em uma fila? 1
#     137 Como empilhar e marcar elementos em uma pilha ? 0
#     138 Como empilhar e acomodar elementos em uma pilha ? 0
#     139 O que é uma pilha e como preservar seu elemento ? 0
#     140 Como jogar e desempilhar elementos em uma pilha ? 0
#     141 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     142 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     143 O que é uma fila e como colocar e desenfileirar seus elementos ? 0
#     144 O que é uma fila e como transferir e desenfileirar seus elementos ? 0
#     145 Como mudar elementos em uma pilha ? 0
#     146 Como adicionar elementos em uma fila ? 0
#     147 O que é uma fila e como estabelecer e desenfileirar seus elementos ? 0
#     148 O que é uma fila e como organizar e desenfileirar seus elementos ? 0
#     149 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     150 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     151 Como são implementadas as operações de deter e desenfileirar elementos em uma fila ? 0
#     152 Como são implementadas as operações de vender e desenfileirar elementos em uma fila ? 0
#     153 Como são implementadas as operações de mover e desenfileirar elementos em uma fila ? 0
#     154 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     155 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     156 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     157 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     158 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     159 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     160 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     161 O que é uma pilha e como adquirir seu elemento ? 0
#     162 O que é uma pilha e como conseguir seu elemento ? 0
#     163 O que é uma pilha e como organizar seu elemento ? 0
#     164 Como gravar e desempilhar elementos em uma pilha ? 0
#     165 Como empilhar elementos em uma estrutura de dados pilha? 1
#     166 Como empilhar elementos em uma estrutura de dados pilha? 1
#     167 Como empilhar elementos em uma estrutura de dados pilha? 1
#     168 Como empilhar elementos em uma estrutura de dados pilha? 1
#     169 Como empilhar elementos em uma estrutura de dados pilha? 1
#     170 Como empilhar elementos em uma estrutura de dados pilha? 1
#     171 O que é uma fila e como designar seu elemento ? 0
#     172 O que é uma pilha e como registrar um elemento nela ? 0
#     173 O que é uma pilha e como formar um elemento nela ? 0
#     174 Em uma pilha a operação de troca ocorre em qual extremidade ? 0
#     175 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     176 Como desempilhar elementos em uma estrutura de escala pilha ? 0
#     177 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     178 Como desempilhar elementos em uma estrutura de cor pilha ? 0
#     179 O que é uma pilha e como empilhar seu elemento? 1
#     180 O que é uma pilha e como empilhar seu elemento? 1
#     181 O que é uma pilha e como empilhar seu elemento? 1
#     182 O que é uma fila e como define um elemento nela ? 0
#     183 O que é uma fila e como determinar um elemento nela ? 0
#     184 O que é uma fila e como consiste um elemento nela ? 0
#     185 Em uma fila a operação de movimento ocorre em qual extremidade ? 0
#     186 Em uma fila a operação de ingresso ocorre em qual extremidade ? 0
#     187 Como empilhar e desempilhar elementos em uma pilha? 1
#     188 Como empilhar e desempilhar elementos em uma pilha? 1
#     189 O que é uma pilha e como empilhar um elemento nela? 1
#     190 O que é uma pilha e como empilhar um elemento nela? 1
#     191 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     192 Em uma pilha a operação de empilhar faz em qual extremidade ? 0
#     193 Como empilhar e remover elementos em uma pilha ? 0
#     194 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     195 Como estabelecer e desempilhar elementos em uma estrutura de dados pilha ? 0
#     196 O que é uma fila e como enfileirar seu elemento? 1
#     197 O que é uma classe e como desenfileirar um elemento nela ? 0
#     198 O que é uma pilha e como desempilhar um elemento nela? 1
#     199 O que é uma pilha e como desempilhar um tubo nela ? 0
#     200 O que é uma fila e como desenfileirar um elemento nela? 1
#     201 O que é uma fila e como enfileirar um elemento nela? 1
#     202 O que é uma fila e como enfileirar um elemento nela? 1
#     203 O que é uma fila e como enfileirar um elemento nela? 1
#     204 O que é uma pilha e como chegar e desempilhar seus elementos ? 0
#     205 O que é uma pilha e como aproveitar e desempilhar seus elementos ? 0
#     206 O que é uma pilha e como dividir e desempilhar seus elementos ? 0
#     207 O que é uma pilha e como encerrar e desempilhar seus elementos ? 0
#     208 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     209 Como procurar elementos em uma fila ? 0
#     210 Como citar elementos em uma estrutura de dados pilha ? 0
#     211 Como elaborar elementos em uma estrutura de dados pilha ? 0
#     212 Como descobrir elementos em uma estrutura de dados pilha ? 0
#     213 Como verificar elementos em uma estrutura de dados pilha ? 0
#     214 Como considerar elementos em uma estrutura de dados pilha ? 0
#     215 Como unir elementos em uma estrutura de dados pilha ? 0
#     216 Como desempilhar elementos em uma pilha? 1
#     217 Como desempilhar músicas em uma pilha ? 0
#     218 Como enfileirar elementos em uma fila? 1
#     219 Como desenfileirar elementos em uma fila? 1
#     220 Como desenfileirar elementos em uma fila? 1
#     221 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     222 Em uma fila a operação de enfileirar irá em qual extremidade ? 0
#     223 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     224 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     225 Como registrar elementos em uma fila ? 0
#     226 Como juntar elementos em uma fila ? 0
#     227 O que é uma fila e como dividir e desenfileirar seus elementos ? 0
#     228 O que é uma fila e como cobrir e desenfileirar seus elementos ? 0
#     229 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     230 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     231 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     232 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     233 Como são conhecidas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     234 Como são realizados as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     235 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     236 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     237 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     238 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     239 Como são construídas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#     240 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     241 Como desempilhar elementos em uma pilha? 1
#     242 Como desempilhar brinquedos em uma pilha ? 0
#     243 Como desempilhar elementos em uma pilha? 1
#     244 Como desempilhar elementos em uma pesquisa ? 0
#     245 Como desempilhar elementos em uma pilha? 1
#     246 Como desempilhar elementos em uma pilha? 1
#     247 Como desempilhar elementos em uma rede ? 0
#     248 Como enfileirar elementos em uma fila? 1
#     249 Como enfileirar elementos em uma fila? 1
#     250 Como enfileirar elementos em uma fila? 1
#     251 Como enfileirar elementos em uma fila? 1
#     252 Como enfileirar elementos em uma fila? 1
#     253 Como desenfileirar elementos em uma fila? 1
#     254 Como desenfileirar elementos em uma fila? 1
#     255 Como empilhar e remover elementos em uma pilha ? 0
#     256 O que é uma pilha e como organizar seu elemento ? 0
#     257 O que é uma pilha e como conseguir seu elemento ? 0
#     258 Como empilhar elementos em uma estrutura de dados pilha? 1
#     259 O que é uma fila e como distribuir seu elemento ? 0
#     260 O que é uma fila e como é seu elemento ? 0
#     261 O que é uma pilha e como reproduzir um elemento nela ? 0
#     262 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     263 Como desempilhar classes em uma estrutura de dados pilha ? 0
#     264 O que é uma pilha e como empilhar seu elemento? 1
#     265 O que é uma pilha e como empilhar seu elemento? 1
#     266 Em uma fila a operação de movimentação ocorre em qual extremidade ? 0
#     267 Como empilhar e desempilhar elementos em uma pilha? 1
#     268 Como empilhar e cortar elementos em uma estrutura de dados pilha ? 0
#     269 Como empilhar e recuperar elementos em uma estrutura de dados pilha ? 0
#     270 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     271 Em uma pilha a operação de empilhar acontecem em qual extremidade ? 0
#     272 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     273 Como desempilhar cartões em uma pilha ? 0
#     274 Em uma pilha a operação de empilhar será em qual extremidade ? 0
#     275 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     276 Em uma pilha a operação de empilhar segue em qual extremidade ? 0
#     277 Como parar e desempilhar elementos em uma estrutura de dados pilha ? 0
#     278 O que é uma fila e como enfileirar seu elemento? 1
#     279 O que é uma fila e como enfileirar seu elemento? 1
#     280 O que é uma tabela e como desenfileirar um elemento nela ? 0
#     281 O que é uma pilha e como desempilhar um elemento nela? 1
#     282 O que é uma fila e como desenfileirar um elemento nela? 1
#     283 O que é uma fila e como desenfileirar um elemento nela? 1
#     284 O que é uma fila e como desenfileirar um cliente nela ? 0
#     285 O que é uma pilha e como transformar e desempilhar seus elementos ? 0
#     286 O que é uma pilha e como pegar e desempilhar seus elementos ? 0
#     287 O que é uma pilha e como estender e desempilhar seus elementos ? 0
#     288 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     289 Como encontrar elementos em uma pilha ? 0
#     290 Como introduzir elementos em uma fila ? 0
#     291 Como se elementos em uma fila ? 0
#     292 Como obter elementos em uma fila ? 0
#     293 Como ver elementos em uma fila ? 0
#     294 Como obter elementos em uma fila ? 0
#     295 Como destacar elementos em uma fila ? 0
#     296 Como comprar elementos em uma fila ? 0
#     297 Como empilhar elementos em uma pilha? 1
#     298 Como empilhar elementos em uma pilha? 1
#     299 Como adquirir elementos em uma estrutura de dados pilha ? 0
#     300 Como desempilhar elementos em uma pilha? 1
#     301 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     302 Em uma fila a operação de enfileirar decorre em qual extremidade ? 0
#     303 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     304 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     305 Como mover elementos em uma pilha ? 0
#     306 Como ligar elementos em uma pilha ? 0
#     307 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     308 O que é uma fila e como aproximar e desenfileirar seus elementos ? 0
#     309 Como são implementadas as operações de empilhar e desenhar elementos em uma pilha ? 0
#     310 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     311 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     312 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     313 Como são implementadas as operações de registrar e desenfileirar elementos em uma fila ? 0
#     314 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     315 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     316 Como são tomadas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#     317 Como são típicas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#     318 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     319 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     320 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     321 O que é uma pilha e como identificar seu elemento ? 0
#     322 O que é uma pilha e como escolher seu elemento ? 0
#     323 O que é uma pilha e como substitui seu elemento ? 0
#     324 O que é uma pilha e como funcionar seu elemento ? 0
#     325 Como empilhar elementos em uma estrutura de dados pilha? 1
#     326 O que é uma fila e como interpretar seu elemento ? 0
#     327 O que é uma fila e como usar seu elemento ? 0
#     328 O que é uma pilha e como prender um elemento nela ? 0
#     329 O que é uma pilha e como calcular um elemento nela ? 0
#     330 Em uma pilha a operação de condução ocorre em qual extremidade ? 0
#     331 Em uma pilha a operação de montagem ocorre em qual extremidade ? 0
#     332 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     333 Como desempilhar tabelas em uma estrutura de dados pilha ? 0
#     334 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     335 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     336 Como desempilhar aplicações em uma estrutura de dados pilha ? 0
#     337 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     338 Como desempilhar elementos em uma tela de dados pilha ? 0
#     339 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     340 Como desempilhar elementos em uma estrutura de mol pilha ? 0
#     341 O que é uma pilha e como empilhar seu elemento? 1
#     342 O que é uma pilha e como empilhar seu elemento? 1
#     343 O que é uma pilha e como empilhar seu elemento? 1
#     344 O que é uma pilha e como empilhar seu elemento? 1
#     345 O que é uma fila e como controlar um elemento nela ? 0
#     346 O que é uma fila e como escolher um elemento nela ? 0
#     347 O que é uma fila e como representa um elemento nela ? 0
#     348 O que é uma fila e como incluir um elemento nela ? 0
#     349 Em uma fila a operação de escoamento ocorre em qual extremidade ? 0
#     350 Como empilhar e desempilhar elementos em uma pilha? 1
#     351 Como empilhar e informar elementos em uma estrutura de dados pilha ? 0
#     352 O que é uma pilha e como empilhar um elemento nela? 1
#     353 Como empilhar e classificar elementos em uma pilha ? 0
#     354 O que é uma pilha e como empilhar um elemento nela? 1
#     355 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     356 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     357 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     358 Em uma pilha a operação de empilhar envolve em qual extremidade ? 0
#     359 Como buscar e desempilhar elementos em uma estrutura de dados pilha ? 0
#     360 Como estender e desempilhar elementos em uma estrutura de dados pilha ? 0
#     361 O que é uma fila e como enfileirar seu elemento? 1
#     362 O que é uma fila e como enfileirar seu elemento? 1
#     363 O que é uma pilha e como desempilhar um elemento nela? 1
#     364 O que é uma pilha e como desempilhar um objeto nela ? 0
#     365 O que é uma pilha e como desempilhar um elemento nela? 1
#     366 O que é uma pilha e como desempilhar um composto nela ? 0
#     367 O que é uma pilha e como desempilhar um elemento nela? 1
#     368 O que é uma pilha e como desempilhar um espaço nela ? 0
#     369 Como por elementos em uma pilha ? 0
#     370 Como reconhecer elementos em uma fila ? 0
#     371 Como encaix elementos em uma fila ? 0
#     372 Como eliminar elementos em uma fila ? 0
#     373 Como empilhar elementos em uma pilha? 1
#     374 Como empilhar elementos em uma pilha? 1
#     375 Como utilizar elementos em uma estrutura de dados pilha ? 0
#     376 Como desempilhar elementos em uma pilha? 1
#     377 Como estudar elementos em uma estrutura de dados pilha ? 0
#     378 Como enfileirar elementos em uma fila? 1
#     379 Como enfileirar elementos em uma fila? 1
#     380 Como desenfileirar elementos em uma fila? 1
#     381 O que é uma fila e como enfileirar um elemento nela? 1
#     382 O que é uma fila e como enfileirar um elemento nela? 1
#     383 O que é uma fila e como enfileirar um elemento nela? 1
#     384 O que é uma fila e como enfileirar um elemento nela? 1
#     385 Como contar elementos em uma pilha ? 0
#     386 Como retirar elementos em uma pilha ? 0
#     387 O que é uma pilha e como incluir e desempilhar seus elementos ? 0
#     388 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     389 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     390 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     391 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     392 O que é uma fila e como tratar e desenfileirar seus elementos ? 0
#     393 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     394 Como são relacionadas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     395 Como são implementadas as operações de escolher e desenfileirar elementos em uma fila ? 0
#     396 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     397 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     398 Como são divididas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#     399 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     400 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     401 Como salvar elementos em uma estrutura de dados pilha ? 0
#     402 Como desempilhar elementos em uma pilha? 1
#     403 Como desempilhar elementos em uma estrutura ? 0
#     404 Como desenfileirar elementos em uma fila? 1
#     405 Como desenfileirar elementos em uma fila? 1
#     406 Como desenfileirar elementos em uma fila? 1
#     407 Como desenfileirar elementos em uma fila? 1
#     408 Como desenfileirar elementos em uma fila? 1
#     409 O que é uma pilha e como preservar seu elemento ? 0
#     410 O que é uma pilha e como detectar seu elemento ? 0
#     411 Como juntar e desempilhar elementos em uma pilha ? 0
#     412 Como pôr e desempilhar elementos em uma pilha ? 0
#     413 Como empilhar elementos em uma estrutura de dados pilha? 1
#     414 O que é uma pilha e como identificar um elemento nela ? 0
#     415 O que é uma pilha e como dividir um elemento nela ? 0
#     416 O que é uma pilha e como transformar um elemento nela ? 0
#     417 O que é uma pilha e como entra um elemento nela ? 0
#     418 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     419 O que é uma pilha e como empilhar seu elemento? 1
#     420 O que é uma pilha e como empilhar seu elemento? 1
#     421 O que é uma fila e como obter um elemento nela ? 0
#     422 O que é uma fila e como incluir um elemento nela ? 0
#     423 Em uma fila a operação de armazenamento ocorre em qual extremidade ? 0
#     424 Como empilhar e desempilhar elementos em uma pilha? 1
#     425 Como empilhar e desempilhar elementos em uma pilha? 1
#     426 Como empilhar e utilizar elementos em uma estrutura de dados pilha ? 0
#     427 O que é uma pilha e como empilhar um elemento nela? 1
#     428 O que é uma pilha e como empilhar um elemento nela? 1
#     429 O que é uma pilha e como empilhar um elemento nela? 1
#     430 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     431 Como empilhar elementos em uma pilha? 1
#     432 O que é uma ordem e como desenfileirar um elemento nela ? 0
#     433 O que é uma pilha e como desempilhar um elemento nela? 1
#     434 O que é uma pilha e como desempilhar um elemento nela? 1
#     435 O que é uma série e como desempilhar um elemento nela ? 0
#     436 O que é uma fila e como desenfileirar um elemento nela? 1
#     437 O que é uma fila e como desenfileirar um elemento nela? 1
#     438 O que é uma fila e como desenfileirar um cartaz nela ? 0
#     439 O que é uma fila e como enfileirar um elemento nela? 1
#     440 O que é uma fila e como enfileirar um elemento nela? 1
#     441 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     442 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     443 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     444 O que é uma fila e como aproveitar e desenfileirar seus elementos ? 0
#     445 O que é uma fila e como virar e desenfileirar seus elementos ? 0
#     446 Como procurar elementos em uma pilha ? 0
#     447 Como criar elementos em uma pilha ? 0
#     448 Como ver elementos em uma pilha ? 0
#     449 Como coloca elementos em uma fila ? 0
#     450 Como substituir elementos em uma fila ? 0
#     451 Como descobrir elementos em uma fila ? 0
#     452 Como integrar elementos em uma fila ? 0
#     453 Como classificar elementos em uma fila ? 0
#     454 Como empilhar elementos em uma pilha? 1
#     455 Como empilhar elementos em uma pilha? 1
#     456 Como empilhar elementos em uma pilha? 1
#     457 Como empilhar elementos em uma pilha? 1
#     458 Como são implementadas as operações de empilhar e medir elementos em uma pilha ? 0
#     459 Como são implementadas as operações de confirmar e desempilhar elementos em uma pilha ? 0
#     460 Como são implementadas as operações de reduzir e desempilhar elementos em uma pilha ? 0
#     461 Como são implementadas as operações de produzir e desempilhar elementos em uma pilha ? 0
#     462 Como ligar elementos em uma pilha ? 0
#     463 Como usar elementos em uma pilha ? 0
#     464 Como são tomadas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     465 Como são implementadas as operações de incorporar e desenfileirar elementos em uma fila ? 0
#     466 Como são implementadas as operações de consolidar e desenfileirar elementos em uma fila ? 0
#     467 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     468 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     469 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     470 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     471 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     472 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     473 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     474 Como são descritas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#     475 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     476 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     477 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     478 Como desenfileirar elementos em uma fila? 1
#     479 Como desenfileirar elementos em uma fila? 1
#     480 Como empilhar e controlar elementos em uma pilha ? 0
#     481 O que é uma pilha e como conseguir seu elemento ? 0
#     482 O que é uma pilha e como vem seu elemento ? 0
#     483 O que é uma pilha e como explicar seu elemento ? 0
#     484 Como empilhar elementos em uma estrutura de dados pilha? 1
#     485 O que é uma fila e como controlar seu elemento ? 0
#     486 O que é uma fila e como alterar seu elemento ? 0
#     487 O que é uma fila e como funciona seu elemento ? 0
#     488 O que é uma fila e como aparece seu elemento ? 0
#     489 O que é uma fila e como resolver seu elemento ? 0
#     490 O que é uma fila e como designar seu elemento ? 0
#     491 O que é uma fila e como representa seu elemento ? 0
#     492 Em uma pilha a operação de separação ocorre em qual extremidade ? 0
#     493 O que é uma pilha e como empilhar seu elemento? 1
#     494 O que é uma pilha e como empilhar seu elemento? 1
#     495 O que é uma pilha e como empilhar seu elemento? 1
#     496 Em uma fila a operação de transporte ocorre em qual extremidade ? 0
#     497 Como empilhar e desempilhar elementos em uma pilha? 1
#     498 Como empilhar e conduzir elementos em uma estrutura de dados pilha ? 0
#     499 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     500 Como incorporar e desempilhar elementos em uma estrutura de dados pilha ? 0
#     501 Como desenvolver e desempilhar elementos em uma estrutura de dados pilha ? 0
#     502 Como pôr e desempilhar elementos em uma estrutura de dados pilha ? 0
#     503 O que é uma fila e como enfileirar seu elemento? 1
#     504 O que é uma fila e como enfileirar seu elemento? 1
#     505 O que é uma fila e como enfileirar seu elemento? 1
#     506 O que é uma fila e como enfileirar seu elemento? 1
#     507 O que é uma fila e como enfileirar seu elemento? 1
#     508 O que é uma fila e como enfileirar seu elemento? 1
#     509 O que é uma fila e como enfileirar seu elemento? 1
#     510 Como desempilhar espaço em uma pilha ? 0
#     511 O que é uma parede e como desenfileirar um elemento nela ? 0
#     512 O que é uma pilha e como desempilhar um elemento nela? 1
#     513 O que é uma máscara e como desempilhar um elemento nela ? 0
#     514 O que é uma fila e como desenfileirar um elemento nela? 1
#     515 O que é uma fila e como desenfileirar um elemento nela? 1
#     516 O que é uma fila e como desenfileirar um ambiente nela ? 0
#     517 O que é uma fila e como desenfileirar um elemento nela? 1
#     518 O que é uma fila e como desenfileirar um produto nela ? 0
#     519 O que é uma pilha e como manter e desempilhar seus elementos ? 0
#     520 O que é uma pilha e como envolver e desempilhar seus elementos ? 0
#     521 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     522 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     523 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     524 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     525 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     526 Como ligar elementos em uma pilha ? 0
#     527 Como retirar elementos em uma pilha ? 0
#     528 Como inser elementos em uma fila ? 0
#     529 Como conseguir elementos em uma fila ? 0
#     530 Como empilhar elementos em uma pilha? 1
#     531 Como empilhar elementos em uma pilha? 1
#     532 Como empilhar elementos em uma pilha? 1
#     533 Como empilhar elementos em uma pilha? 1
#     534 Como ligar elementos em uma estrutura de dados pilha ? 0
#     535 Como desempilhar elementos em uma pilha? 1
#     536 Como desempilhar notas em uma pilha ? 0
#     537 Como desempilhar elementos em uma pilha? 1
#     538 O que é uma fila e como remover e desenfileirar seus elementos ? 0
#     539 O que é uma fila e como classificar e desenfileirar seus elementos ? 0
#     540 O que é uma fila e como detectar e desenfileirar seus elementos ? 0
#     541 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     542 Como destacar elementos em uma pilha ? 0
#     543 Como incluir elementos em uma pilha ? 0
#     544 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     545 Como são implementadas as operações de identificar e desempilhar elementos em uma pilha ? 0
#     546 Como são diferentes as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     547 Como são distribuídas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     548 Como são implementadas as operações de levar e desenfileirar elementos em uma fila ? 0
#     549 Como são implementadas as operações de concentrar e desenfileirar elementos em uma fila ? 0
#     550 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     551 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     552 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     553 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     554 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     555 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     556 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     557 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     558 Como enfileirar elementos em uma fila? 1
#     559 Como desenfileirar elementos em uma fila? 1
#     560 Como desenfileirar elementos em uma fila? 1
#     561 Como empilhar e conter elementos em uma pilha ? 0
#     562 Como empilhar e fechar elementos em uma pilha ? 0
#     563 Como contar e desempilhar elementos em uma pilha ? 0
#     564 Como empilhar elementos em uma estrutura de dados pilha? 1
#     565 Como empilhar elementos em uma estrutura de dados pilha? 1
#     566 O que é uma fila e como montar seu elemento ? 0
#     567 O que é uma fila e como compor seu elemento ? 0
#     568 O que é uma fila e como caracteriza seu elemento ? 0
#     569 O que é uma pilha e como medir um elemento nela ? 0
#     570 O que é uma pilha e como falta um elemento nela ? 0
#     571 O que é uma pilha e como registrar um elemento nela ? 0
#     572 Em uma pilha a operação de produção ocorre em qual extremidade ? 0
#     573 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     574 Como desempilhar transações em uma estrutura de dados pilha ? 0
#     575 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     576 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     577 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     578 Como desempilhar elementos em uma memória de dados pilha ? 0
#     579 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     580 Como desempilhar elementos em uma estrutura de quatro pilha ? 0
#     581 O que é uma fila e como pôr um elemento nela ? 0
#     582 O que é uma fila e como colocar um elemento nela ? 0
#     583 O que é uma fila e como substitui um elemento nela ? 0
#     584 Em uma fila a operação de entrada ocorre em qual extremidade ? 0
#     585 Como empilhar e desempilhar elementos em uma pilha? 1
#     586 Como empilhar e desempilhar elementos em uma pilha? 1
#     587 Como empilhar e desempilhar elementos em uma pilha? 1
#     588 Como empilhar e enviar elementos em uma estrutura de dados pilha ? 0
#     589 O que é uma pilha e como empilhar um elemento nela? 1
#     590 Como enfileirar elementos em uma fila? 1
#     591 O que é uma pilha e como empilhar um elemento nela? 1
#     592 O que é uma pilha e como empilhar um elemento nela? 1
#     593 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     594 Em uma pilha a operação de empilhar parou em qual extremidade ? 0
#     595 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     596 O que é uma fila e como enfileirar seu elemento? 1
#     597 O que é uma fila e como enfileirar seu elemento? 1
#     598 O que é uma fila e como enfileirar seu elemento? 1
#     599 O que é uma linha e como desenfileirar um elemento nela ? 0
#     600 O que é uma caixa e como desenfileirar um elemento nela ? 0
#     601 O que é uma pilha e como desempilhar um elemento nela? 1
#     602 O que é uma camisa e como desempilhar um elemento nela ? 0
#     603 O que é uma fila e como desenfileirar um elemento nela? 1
#     604 O que é uma fila e como desenfileirar um elemento nela? 1
#     605 O que é uma fila e como desenfileirar um cartão nela ? 0
#     606 Como conseguir elementos em uma fila ? 0
#     607 Como trocar elementos em uma fila ? 0
#     608 Como estão elementos em uma fila ? 0
#     609 Como marcar elementos em uma fila ? 0
#     610 Como empilhar elementos em uma pilha? 1
#     611 Como empilhar elementos em uma pilha? 1
#     612 Como verificar elementos em uma estrutura de dados pilha ? 0
#     613 Como usar elementos em uma estrutura de dados pilha ? 0
#     614 Como desempilhar elementos em uma pilha? 1
#     615 Como desempilhar elementos em uma prova ? 0
#     616 Como remover elementos em uma estrutura de dados pilha ? 0
#     617 Como instalar elementos em uma estrutura de dados pilha ? 0
#     618 O que é uma fila e como desenfileirar um elemento nela? 1
#     619 O que é uma fila e como enfileirar um elemento nela? 1
#     620 O que é uma fila e como enfileirar um elemento nela? 1
#     621 O que é uma fila e como enfileirar um elemento nela? 1
#     622 Como utilizar elementos em uma pilha ? 0
#     623 Como instalar elementos em uma pilha ? 0
#     624 O que é uma pilha e como levar e desempilhar seus elementos ? 0
#     625 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     626 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     627 O que é uma fila e como fechar e desenfileirar seus elementos ? 0
#     628 O que é uma fila e como alcançar e desenfileirar seus elementos ? 0
#     629 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     630 Como são disputadas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     631 Como são implementadas as operações de introduzir e desenfileirar elementos em uma fila ? 0
#     632 Como são implementadas as operações de juntar e desenfileirar elementos em uma fila ? 0
#     633 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     634 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     635 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     636 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     637 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     638 Como converter elementos em uma estrutura de dados pilha ? 0
#     639 Como enfileirar elementos em uma fila? 1
#     640 Como enfileirar elementos em uma fila? 1
#     641 Como desenfileirar elementos em uma fila? 1
#     642 Como desenfileirar elementos em uma fila? 1
#     643 Como desenfileirar elementos em uma fila? 1
#     644 Como empilhar e reproduzir elementos em uma pilha ? 0
#     645 Como empilhar e representar elementos em uma pilha ? 0
#     646 O que é uma pilha e como detectar seu elemento ? 0
#     647 Como reconhecer e desempilhar elementos em uma pilha ? 0
#     648 Como empilhar elementos em uma estrutura de dados pilha? 1
#     649 Como empilhar elementos em uma estrutura de dados pilha? 1
#     650 O que é uma fila e como classificar seu elemento ? 0
#     651 O que é uma fila e como determina seu elemento ? 0
#     652 O que é uma pilha e como ficar um elemento nela ? 0
#     653 O que é uma pilha e como carregar um elemento nela ? 0
#     654 O que é uma pilha e como ver um elemento nela ? 0
#     655 Em uma pilha a operação de teste ocorre em qual extremidade ? 0
#     656 Em uma pilha a operação de tensão ocorre em qual extremidade ? 0
#     657 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     658 Como desempilhar elementos em uma estrutura de dados pública ? 0
#     659 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     660 Como desempilhar classes em uma estrutura de dados pilha ? 0
#     661 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     662 O que é uma pilha e como empilhar seu elemento? 1
#     663 O que é uma fila e como existe um elemento nela ? 0
#     664 Em uma fila a operação de corrida ocorre em qual extremidade ? 0
#     665 Como empilhar e desempilhar elementos em uma pilha? 1
#     666 Como empilhar e desempilhar elementos em uma pilha? 1
#     667 Como empilhar e desempilhar elementos em uma pilha? 1
#     668 O que é uma pilha e como empilhar um elemento nela? 1
#     669 O que é uma pilha e como empilhar um elemento nela? 1
#     670 Como desempilhar dinheiro em uma pilha ? 0
#     671 O que é uma pilha e como empilhar um elemento nela? 1
#     672 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     673 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     674 Como escolher e desempilhar elementos em uma estrutura de dados pilha ? 0
#     675 Como escrever e desempilhar elementos em uma estrutura de dados pilha ? 0
#     676 O que é uma fila e como enfileirar seu elemento? 1
#     677 O que é uma fila e como enfileirar seu elemento? 1
#     678 O que é uma pilha e como desempilhar um elemento nela? 1
#     679 O que é uma pilha e como desempilhar um dispositivo nela ? 0
#     680 O que é uma pilha e como desempilhar um elemento nela? 1
#     681 O que é uma área e como desempilhar um elemento nela ? 0
#     682 O que é uma fila e como enfileirar um elemento nela? 1
#     683 O que é uma pilha e como capturar e desempilhar seus elementos ? 0
#     684 O que é uma pilha e como registrar e desempilhar seus elementos ? 0
#     685 O que é uma pilha e como preparar e desempilhar seus elementos ? 0
#     686 Como criar elementos em uma fila ? 0
#     687 Como ter elementos em uma fila ? 0
#     688 Como esperar elementos em uma fila ? 0
#     689 Como transpor elementos em uma fila ? 0
#     690 Como unir elementos em uma fila ? 0
#     691 Como empilhar elementos em uma pilha? 1
#     692 Como empilhar elementos em uma pilha? 1
#     693 Como avaliar elementos em uma estrutura de dados pilha ? 0
#     694 Como incluir elementos em uma estrutura de dados pilha ? 0
#     695 Como desempilhar elementos em uma pilha? 1
#     696 Como desempilhar frutas em uma pilha ? 0
#     697 Como desempilhar elementos em uma pilha? 1
#     698 O que é uma pilha e como separar e desempilhar seus elementos ? 0
#     699 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     700 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     701 Em uma fila a operação de enfileirar age em qual extremidade ? 0
#     702 Como achar elementos em uma pilha ? 0
#     703 Como lançar elementos em uma pilha ? 0
#     704 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     705 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     706 O que é uma fila e como conhecer e desenfileirar seus elementos ? 0
#     707 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     708 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     709 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     710 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     711 Como são implementadas as operações de entrar e desempilhar elementos em uma pilha ? 0
#     712 Como são implementadas as operações de juntar e desempilhar elementos em uma pilha ? 0
#     713 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     714 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     715 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     716 Como são classificadas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#     717 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     718 Como enfileirar elementos em uma fila? 1
#     719 Como enfileirar elementos em uma fila? 1
#     720 Como desenfileirar elementos em uma fila? 1
#     721 Como desenfileirar elementos em uma fila? 1
#     722 Como empilhar e exibir elementos em uma pilha ? 0
#     723 Como empilhar e manter elementos em uma pilha ? 0
#     724 Como empilhar e destacar elementos em uma pilha ? 0
#     725 O que é uma pilha e como o seu elemento ? 0
#     726 Como empilhar elementos em uma estrutura de dados pilha? 1
#     727 O que é uma pilha e como gravar um elemento nela ? 0
#     728 O que é uma pilha e como incluir um elemento nela ? 0
#     729 O que é uma pilha e como ver um elemento nela ? 0
#     730 Em uma pilha a operação de circuito ocorre em qual extremidade ? 0
#     731 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     732 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     733 Como desempilhar elementos em uma linha de dados pilha ? 0
#     734 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     735 O que é uma pilha e como empilhar seu elemento? 1
#     736 O que é uma fila e como alterar um elemento nela ? 0
#     737 O que é uma fila e como encontrar um elemento nela ? 0
#     738 O que é uma fila e como adicionar um elemento nela ? 0
#     739 O que é uma fila e como ligar um elemento nela ? 0
#     740 Em uma fila a operação de equilíbrio ocorre em qual extremidade ? 0
#     741 Como empilhar e desempilhar elementos em uma pilha? 1
#     742 Como empilhar e desempilhar elementos em uma pilha? 1
#     743 Como empilhar e desempilhar elementos em uma pilha? 1
#     744 Como empilhar e acomodar elementos em uma estrutura de dados pilha ? 0
#     745 O que é uma pilha e como empilhar um elemento nela? 1
#     746 O que é uma pilha e como empilhar um elemento nela? 1
#     747 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     748 O que é uma página e como desenfileirar um elemento nela ? 0
#     749 O que é uma pilha e como desempilhar um elemento nela? 1
#     750 Como produzir elementos em uma estrutura de dados pilha ? 0
#     751 O que é uma pilha e como desempilhar um elemento nela? 1
#     752 O que é uma tabela e como desempilhar um elemento nela ? 0
#     753 O que é uma fila e como desenfileirar um elemento nela? 1
#     754 O que é uma fila e como desenfileirar um motor nela ? 0
#     755 O que é uma fila e como desenfileirar um elemento nela? 1
#     756 O que é uma fila e como desenfileirar um evento nela ? 0
#     757 O que é uma fila e como desenfileirar um elemento nela? 1
#     758 O que é uma fila e como desenfileirar um ingresso nela ? 0
#     759 O que é uma fila e como desenfileirar um elemento nela? 1
#     760 O que é uma fila e como enfileirar um elemento nela? 1
#     761 O que é uma fila e como enfileirar um elemento nela? 1
#     762 O que é uma fila e como enfileirar um elemento nela? 1
#     763 O que é uma fila e como enfileirar um elemento nela? 1
#     764 O que é uma pilha e como alimentar e desempilhar seus elementos ? 0
#     765 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     766 Como separar elementos em uma fila ? 0
#     767 Como deixar elementos em uma fila ? 0
#     768 Como concentrar elementos em uma fila ? 0
#     769 Como empilhar elementos em uma pilha? 1
#     770 Como estudar elementos em uma estrutura de dados pilha ? 0
#     771 Como desempilhar elementos em uma pilha? 1
#     772 Como desempilhar sal em uma pilha ? 0
#     773 Como desempilhar elementos em uma pilha? 1
#     774 Como desempilhar elementos em uma campanha ? 0
#     775 Como desempilhar elementos em uma pilha? 1
#     776 Como desempilhar medicamentos em uma pilha ? 0
#     777 Como fazer elementos em uma estrutura de dados pilha ? 0
#     778 Em uma fila a operação de enfileirar difere em qual extremidade ? 0
#     779 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     780 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     781 O que é uma fila e como incluir e desenfileirar seus elementos ? 0
#     782 Como construir elementos em uma pilha ? 0
#     783 Como acomodar elementos em uma fila ? 0
#     784 O que é uma fila e como fixar e desenfileirar seus elementos ? 0
#     785 O que é uma fila e como nomear e desenfileirar seus elementos ? 0
#     786 O que é uma fila e como fixar e desenfileirar seus elementos ? 0
#     787 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     788 Como são escritas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     789 Como são implementadas as operações de eliminar e desenfileirar elementos em uma fila ? 0
#     790 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     791 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     792 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     793 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     794 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     795 Como são realizadas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#     796 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     797 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1

# %% [markdown]
# #### Listas documentos originais e perturbados classificados incorretamente

# %%
print("Documentos originais e perturbados classificados incorretamente(classe!=previsão):", len(listaRetornoClassificadoIncorretamente))
conta = 0
for i, linha in listaRetornoClassificadoIncorretamente.iterrows():
  conta = conta + 1
  if i < 2000:    
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == linha["id"]]       
    if len(documento)!= 0:    
      print("   ", conta, documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Documentos originais e perturbados classificados incorretamente(classe!=previsão): 3
#     1 Como desempilhar elementos em uma estrutura de longa pilha ? 0
#     2 Em uma pilha a operação de empilhar termina em qual extremidade ? 0
#     3 Em uma fila a operação de enfileirar parou em qual extremidade ? 0

# %% [markdown]
# ### Listas

# %% [markdown]
# #### Lista de documentos originais(1) classificados corretamente(1)

# %%
def listaOriginalClassificadoCorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    if linha['classe'] == 1 and linha['predicao'] == 1:
        listaRetorno.append(linha['id'])

  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])        
  return dflistaRetorno

# %%
lista_documento_original_classificado_corretamente = listaOriginalClassificadoCorretamente(dfDadosClassificacao)
print('lista_documento_original_classificado_corretamente:', len(lista_documento_original_classificado_corretamente))
# Out:
# listaDocumentoOriginalClassificadoCorretamente: 400

# %%
print("Lista de documentos originais classificados corretamente(coerentes)(classe=1 & previsão=1):", len(lista_documento_original_classificado_corretamente))
for i, documento in lista_documento_original_classificado_corretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos originais classificados corretamente(coerentes)(classe=1 & previsão=1): 400
#    0 - Como enfileirar elementos em uma fila? 1
#    1 - Como enfileirar elementos em uma fila? 1
#    2 - Como enfileirar elementos em uma fila? 1
#    3 - Como enfileirar elementos em uma fila? 1
#    4 - Como desenfileirar elementos em uma fila? 1
#    5 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    6 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    7 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    8 - O que é uma pilha e como empilhar seu elemento? 1
#    9 - O que é uma pilha e como empilhar seu elemento? 1
#    10 - O que é uma pilha e como empilhar seu elemento? 1
#    11 - Como empilhar e desempilhar elementos em uma pilha? 1
#    12 - O que é uma pilha e como empilhar um elemento nela? 1
#    13 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    14 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    15 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    16 - Como desempilhar elementos em uma pilha? 1
#    17 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    18 - O que é uma fila e como enfileirar seu elemento? 1
#    19 - O que é uma fila e como enfileirar seu elemento? 1
#    20 - O que é uma pilha e como desempilhar um elemento nela? 1
#    21 - O que é uma pilha e como desempilhar um elemento nela? 1
#    22 - O que é uma fila e como desenfileirar um elemento nela? 1
#    23 - O que é uma fila e como desenfileirar um elemento nela? 1
#    24 - O que é uma fila e como desenfileirar um elemento nela? 1
#    25 - O que é uma fila e como enfileirar um elemento nela? 1
#    26 - Como empilhar elementos em uma pilha? 1
#    27 - Como desempilhar elementos em uma pilha? 1
#    28 - Como desempilhar elementos em uma pilha? 1
#    29 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    30 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    31 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    32 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    33 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    34 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    35 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    36 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    37 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    38 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    39 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    40 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    41 - O que é uma pilha e como empilhar seu elemento? 1
#    42 - Como empilhar e desempilhar elementos em uma pilha? 1
#    43 - Como empilhar e desempilhar elementos em uma pilha? 1
#    44 - Como empilhar e desempilhar elementos em uma pilha? 1
#    45 - O que é uma pilha e como empilhar um elemento nela? 1
#    46 - O que é uma pilha e como empilhar um elemento nela? 1
#    47 - O que é uma pilha e como empilhar um elemento nela? 1
#    48 - O que é uma pilha e como empilhar um elemento nela? 1
#    49 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    50 - O que é uma fila e como enfileirar seu elemento? 1
#    51 - O que é uma pilha e como desempilhar um elemento nela? 1
#    52 - O que é uma pilha e como desempilhar um elemento nela? 1
#    53 - O que é uma pilha e como desempilhar um elemento nela? 1
#    54 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    55 - O que é uma pilha e como desempilhar um elemento nela? 1
#    56 - O que é uma pilha e como desempilhar um elemento nela? 1
#    57 - O que é uma fila e como desenfileirar um elemento nela? 1
#    58 - O que é uma fila e como desenfileirar um elemento nela? 1
#    59 - O que é uma fila e como enfileirar um elemento nela? 1
#    60 - O que é uma fila e como enfileirar um elemento nela? 1
#    61 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    62 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    63 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    64 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    65 - Como empilhar elementos em uma pilha? 1
#    66 - Como desempilhar elementos em uma pilha? 1
#    67 - Como enfileirar elementos em uma fila? 1
#    68 - Como enfileirar elementos em uma fila? 1
#    69 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    70 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    71 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    72 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    73 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    74 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    75 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    76 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    77 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    78 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    79 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    80 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    81 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    82 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    83 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    84 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    85 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    86 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    87 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    88 - O que é uma pilha e como empilhar seu elemento? 1
#    89 - O que é uma pilha e como empilhar seu elemento? 1
#    90 - O que é uma pilha e como empilhar seu elemento? 1
#    91 - Como empilhar e desempilhar elementos em uma pilha? 1
#    92 - Como empilhar e desempilhar elementos em uma pilha? 1
#    93 - O que é uma pilha e como empilhar um elemento nela? 1
#    94 - O que é uma pilha e como empilhar um elemento nela? 1
#    95 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    96 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    97 - O que é uma fila e como enfileirar seu elemento? 1
#    98 - O que é uma pilha e como desempilhar um elemento nela? 1
#    99 - O que é uma fila e como desenfileirar um elemento nela? 1
#    100 - O que é uma fila e como enfileirar um elemento nela? 1
#    101 - O que é uma fila e como enfileirar um elemento nela? 1
#    102 - O que é uma fila e como enfileirar um elemento nela? 1
#    103 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    104 - Como desempilhar elementos em uma pilha? 1
#    105 - Como enfileirar elementos em uma fila? 1
#    106 - Como desenfileirar elementos em uma fila? 1
#    107 - Como desenfileirar elementos em uma fila? 1
#    108 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    109 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    110 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    111 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    112 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    113 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    114 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    115 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    116 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    117 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    118 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    119 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    120 - Como desempilhar elementos em uma pilha? 1
#    121 - Como desempilhar elementos em uma pilha? 1
#    122 - Como desempilhar elementos em uma pilha? 1
#    123 - Como desempilhar elementos em uma pilha? 1
#    124 - Como enfileirar elementos em uma fila? 1
#    125 - Como enfileirar elementos em uma fila? 1
#    126 - Como enfileirar elementos em uma fila? 1
#    127 - Como enfileirar elementos em uma fila? 1
#    128 - Como enfileirar elementos em uma fila? 1
#    129 - Como desenfileirar elementos em uma fila? 1
#    130 - Como desenfileirar elementos em uma fila? 1
#    131 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    132 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    133 - O que é uma pilha e como empilhar seu elemento? 1
#    134 - O que é uma pilha e como empilhar seu elemento? 1
#    135 - Como empilhar e desempilhar elementos em uma pilha? 1
#    136 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    137 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    138 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    139 - O que é uma fila e como enfileirar seu elemento? 1
#    140 - O que é uma fila e como enfileirar seu elemento? 1
#    141 - O que é uma pilha e como desempilhar um elemento nela? 1
#    142 - O que é uma fila e como desenfileirar um elemento nela? 1
#    143 - O que é uma fila e como desenfileirar um elemento nela? 1
#    144 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    145 - Como empilhar elementos em uma pilha? 1
#    146 - Como empilhar elementos em uma pilha? 1
#    147 - Como desempilhar elementos em uma pilha? 1
#    148 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    149 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    150 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    151 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    152 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    153 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    154 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    155 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    156 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    157 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    158 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    159 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    160 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    161 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    162 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    163 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    164 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    165 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    166 - O que é uma pilha e como empilhar seu elemento? 1
#    167 - O que é uma pilha e como empilhar seu elemento? 1
#    168 - O que é uma pilha e como empilhar seu elemento? 1
#    169 - O que é uma pilha e como empilhar seu elemento? 1
#    170 - Como empilhar e desempilhar elementos em uma pilha? 1
#    171 - O que é uma pilha e como empilhar um elemento nela? 1
#    172 - O que é uma pilha e como empilhar um elemento nela? 1
#    173 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    174 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    175 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    176 - O que é uma fila e como enfileirar seu elemento? 1
#    177 - O que é uma fila e como enfileirar seu elemento? 1
#    178 - O que é uma pilha e como desempilhar um elemento nela? 1
#    179 - O que é uma pilha e como desempilhar um elemento nela? 1
#    180 - O que é uma pilha e como desempilhar um elemento nela? 1
#    181 - Como empilhar elementos em uma pilha? 1
#    182 - Como empilhar elementos em uma pilha? 1
#    183 - Como desempilhar elementos em uma pilha? 1
#    184 - Como enfileirar elementos em uma fila? 1
#    185 - Como enfileirar elementos em uma fila? 1
#    186 - Como desenfileirar elementos em uma fila? 1
#    187 - O que é uma fila e como enfileirar um elemento nela? 1
#    188 - O que é uma fila e como enfileirar um elemento nela? 1
#    189 - O que é uma fila e como enfileirar um elemento nela? 1
#    190 - O que é uma fila e como enfileirar um elemento nela? 1
#    191 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    192 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    193 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    194 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    195 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    196 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    197 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    198 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    199 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    200 - Como desempilhar elementos em uma pilha? 1
#    201 - Como desenfileirar elementos em uma fila? 1
#    202 - Como desenfileirar elementos em uma fila? 1
#    203 - Como desenfileirar elementos em uma fila? 1
#    204 - Como desenfileirar elementos em uma fila? 1
#    205 - Como desenfileirar elementos em uma fila? 1
#    206 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    207 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    208 - O que é uma pilha e como empilhar seu elemento? 1
#    209 - O que é uma pilha e como empilhar seu elemento? 1
#    210 - Como empilhar e desempilhar elementos em uma pilha? 1
#    211 - Como empilhar e desempilhar elementos em uma pilha? 1
#    212 - O que é uma pilha e como empilhar um elemento nela? 1
#    213 - O que é uma pilha e como empilhar um elemento nela? 1
#    214 - O que é uma pilha e como empilhar um elemento nela? 1
#    215 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    216 - Como empilhar elementos em uma pilha? 1
#    217 - O que é uma pilha e como desempilhar um elemento nela? 1
#    218 - O que é uma pilha e como desempilhar um elemento nela? 1
#    219 - O que é uma fila e como desenfileirar um elemento nela? 1
#    220 - O que é uma fila e como desenfileirar um elemento nela? 1
#    221 - O que é uma fila e como enfileirar um elemento nela? 1
#    222 - O que é uma fila e como enfileirar um elemento nela? 1
#    223 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    224 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    225 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    226 - Como empilhar elementos em uma pilha? 1
#    227 - Como empilhar elementos em uma pilha? 1
#    228 - Como empilhar elementos em uma pilha? 1
#    229 - Como empilhar elementos em uma pilha? 1
#    230 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    231 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    232 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    233 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    234 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    235 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    236 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    237 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    238 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    239 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    240 - Como desenfileirar elementos em uma fila? 1
#    241 - Como desenfileirar elementos em uma fila? 1
#    242 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    243 - O que é uma pilha e como empilhar seu elemento? 1
#    244 - O que é uma pilha e como empilhar seu elemento? 1
#    245 - O que é uma pilha e como empilhar seu elemento? 1
#    246 - Como empilhar e desempilhar elementos em uma pilha? 1
#    247 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    248 - O que é uma fila e como enfileirar seu elemento? 1
#    249 - O que é uma fila e como enfileirar seu elemento? 1
#    250 - O que é uma fila e como enfileirar seu elemento? 1
#    251 - O que é uma fila e como enfileirar seu elemento? 1
#    252 - O que é uma fila e como enfileirar seu elemento? 1
#    253 - O que é uma fila e como enfileirar seu elemento? 1
#    254 - O que é uma fila e como enfileirar seu elemento? 1
#    255 - O que é uma pilha e como desempilhar um elemento nela? 1
#    256 - O que é uma fila e como desenfileirar um elemento nela? 1
#    257 - O que é uma fila e como desenfileirar um elemento nela? 1
#    258 - O que é uma fila e como desenfileirar um elemento nela? 1
#    259 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    260 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    261 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    262 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    263 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    264 - Como empilhar elementos em uma pilha? 1
#    265 - Como empilhar elementos em uma pilha? 1
#    266 - Como empilhar elementos em uma pilha? 1
#    267 - Como empilhar elementos em uma pilha? 1
#    268 - Como desempilhar elementos em uma pilha? 1
#    269 - Como desempilhar elementos em uma pilha? 1
#    270 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    271 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    272 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    273 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    274 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    275 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    276 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    277 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    278 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    279 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    280 - Como enfileirar elementos em uma fila? 1
#    281 - Como desenfileirar elementos em uma fila? 1
#    282 - Como desenfileirar elementos em uma fila? 1
#    283 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    284 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    285 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    286 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    287 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    288 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    289 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    290 - Como empilhar e desempilhar elementos em uma pilha? 1
#    291 - Como empilhar e desempilhar elementos em uma pilha? 1
#    292 - Como empilhar e desempilhar elementos em uma pilha? 1
#    293 - O que é uma pilha e como empilhar um elemento nela? 1
#    294 - Como enfileirar elementos em uma fila? 1
#    295 - O que é uma pilha e como empilhar um elemento nela? 1
#    296 - O que é uma pilha e como empilhar um elemento nela? 1
#    297 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    298 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    299 - O que é uma fila e como enfileirar seu elemento? 1
#    300 - O que é uma fila e como enfileirar seu elemento? 1
#    301 - O que é uma fila e como enfileirar seu elemento? 1
#    302 - O que é uma pilha e como desempilhar um elemento nela? 1
#    303 - O que é uma fila e como desenfileirar um elemento nela? 1
#    304 - O que é uma fila e como desenfileirar um elemento nela? 1
#    305 - Como empilhar elementos em uma pilha? 1
#    306 - Como empilhar elementos em uma pilha? 1
#    307 - Como desempilhar elementos em uma pilha? 1
#    308 - O que é uma fila e como desenfileirar um elemento nela? 1
#    309 - O que é uma fila e como enfileirar um elemento nela? 1
#    310 - O que é uma fila e como enfileirar um elemento nela? 1
#    311 - O que é uma fila e como enfileirar um elemento nela? 1
#    312 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    313 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    314 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    315 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    316 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    317 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    318 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    319 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    320 - Como enfileirar elementos em uma fila? 1
#    321 - Como enfileirar elementos em uma fila? 1
#    322 - Como desenfileirar elementos em uma fila? 1
#    323 - Como desenfileirar elementos em uma fila? 1
#    324 - Como desenfileirar elementos em uma fila? 1
#    325 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    326 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    327 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    328 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    329 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    330 - O que é uma pilha e como empilhar seu elemento? 1
#    331 - Como empilhar e desempilhar elementos em uma pilha? 1
#    332 - Como empilhar e desempilhar elementos em uma pilha? 1
#    333 - Como empilhar e desempilhar elementos em uma pilha? 1
#    334 - O que é uma pilha e como empilhar um elemento nela? 1
#    335 - O que é uma pilha e como empilhar um elemento nela? 1
#    336 - O que é uma pilha e como empilhar um elemento nela? 1
#    337 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    338 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    339 - O que é uma fila e como enfileirar seu elemento? 1
#    340 - O que é uma fila e como enfileirar seu elemento? 1
#    341 - O que é uma pilha e como desempilhar um elemento nela? 1
#    342 - O que é uma pilha e como desempilhar um elemento nela? 1
#    343 - O que é uma fila e como enfileirar um elemento nela? 1
#    344 - Como empilhar elementos em uma pilha? 1
#    345 - Como empilhar elementos em uma pilha? 1
#    346 - Como desempilhar elementos em uma pilha? 1
#    347 - Como desempilhar elementos em uma pilha? 1
#    348 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    349 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    350 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    351 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    352 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    353 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    354 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    355 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    356 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    357 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    358 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    359 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    360 - Como enfileirar elementos em uma fila? 1
#    361 - Como enfileirar elementos em uma fila? 1
#    362 - Como desenfileirar elementos em uma fila? 1
#    363 - Como desenfileirar elementos em uma fila? 1
#    364 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    365 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    366 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    367 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    368 - O que é uma pilha e como empilhar seu elemento? 1
#    369 - Como empilhar e desempilhar elementos em uma pilha? 1
#    370 - Como empilhar e desempilhar elementos em uma pilha? 1
#    371 - Como empilhar e desempilhar elementos em uma pilha? 1
#    372 - O que é uma pilha e como empilhar um elemento nela? 1
#    373 - O que é uma pilha e como empilhar um elemento nela? 1
#    374 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    375 - O que é uma pilha e como desempilhar um elemento nela? 1
#    376 - O que é uma pilha e como desempilhar um elemento nela? 1
#    377 - O que é uma fila e como desenfileirar um elemento nela? 1
#    378 - O que é uma fila e como desenfileirar um elemento nela? 1
#    379 - O que é uma fila e como desenfileirar um elemento nela? 1
#    380 - O que é uma fila e como desenfileirar um elemento nela? 1
#    381 - O que é uma fila e como enfileirar um elemento nela? 1
#    382 - O que é uma fila e como enfileirar um elemento nela? 1
#    383 - O que é uma fila e como enfileirar um elemento nela? 1
#    384 - O que é uma fila e como enfileirar um elemento nela? 1
#    385 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    386 - Como empilhar elementos em uma pilha? 1
#    387 - Como desempilhar elementos em uma pilha? 1
#    388 - Como desempilhar elementos em uma pilha? 1
#    389 - Como desempilhar elementos em uma pilha? 1
#    390 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#    391 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    392 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    393 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    394 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    395 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    396 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    397 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    398 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#    399 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1

# %% [markdown]
# #### Lista de documento originais(1) classificados incorretamente(0)

# %%
def listaOriginalClassificadoIncorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    if linha['classe'] == 1 and linha['predicao'] == 0:
        listaRetorno.append(linha['id'])
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
lista_documento_original_classificado_incorretamente = listaOriginalClassificadoIncorretamente(dfDadosClassificacao)

print("Lista de documentos originais classificados incorretamente:",len(lista_documento_original_classificado_incorretamente))
# Out:
# Lista de documentos originais classificados incorretamente: 0

# %%
print("Lista de documentos originais classificados incorretamente(incoerentes)(classe=1 & previsão=0):", len(lista_documento_original_classificado_incorretamente))
for i, documento in lista_documento_original_classificado_incorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos originais classificados incorretamente(incoerentes)(classe=1 & previsão=0): 0

# %% [markdown]
# #### Lista Documentos Perturbados(0) Classificados corretamente(0)

# %%
def listaPerturbadoClassificadoCorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    if linha['classe'] == 0 and linha['predicao'] == 0:
        listaRetorno.append(linha['id'])
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
lista_documento_perturbado_classificado_corretamente = listaPerturbadoClassificadoCorretamente(dfDadosClassificacao)
print('lista_documento_perturbado_classificado_corretamente:', len(lista_documento_perturbado_classificado_corretamente))
# Out:
# listaDocumentoPerturbadoClassificadoCorretamente: 397

# %%
print("Lista de documentos perturbados classificados corretamente(incoerentes)(classe=0 & previsão=0):", len(lista_documento_perturbado_classificado_corretamente))
for i, documento in lista_documento_perturbado_classificado_corretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos perturbados classificados corretamente(incoerentes)(classe=0 & previsão=0): 397
#    0 - Como desempilhar elementos em uma frase ? 0
#    1 - Como empilhar e enviar elementos em uma pilha ? 0
#    2 - O que é uma pilha e como substituir seu elemento ? 0
#    3 - O que é uma pilha e como definir seu elemento ? 0
#    4 - O que é uma pilha e como fica seu elemento ? 0
#    5 - O que é uma fila e como criar seu elemento ? 0
#    6 - O que é uma fila e como entender seu elemento ? 0
#    7 - O que é uma pilha e como utilizar um elemento nela ? 0
#    8 - O que é uma pilha e como esconder um elemento nela ? 0
#    9 - O que é uma pilha e como manter um elemento nela ? 0
#    10 - Em uma pilha a operação de eletricidade ocorre em qual extremidade ? 0
#    11 - Em uma pilha a operação de contato ocorre em qual extremidade ? 0
#    12 - O que é uma fila e como destacar um elemento nela ? 0
#    13 - Em uma fila a operação de conexão ocorre em qual extremidade ? 0
#    14 - Como empilhar e organizar elementos em uma estrutura de dados pilha ? 0
#    15 - Em uma pilha a operação de empilhar significa em qual extremidade ? 0
#    16 - Em uma pilha a operação de empilhar requer em qual extremidade ? 0
#    17 - O que é uma classe e como desenfileirar um elemento nela ? 0
#    18 - O que é uma fila e como desenfileirar um corpo nela ? 0
#    19 - O que é uma fila e como desenfileirar um barco nela ? 0
#    20 - O que é uma pilha e como acomodar e desempilhar seus elementos ? 0
#    21 - O que é uma pilha e como classificar e desempilhar seus elementos ? 0
#    22 - Como eliminar elementos em uma fila ? 0
#    23 - Como usar elementos em uma fila ? 0
#    24 - Como unir elementos em uma fila ? 0
#    25 - Como analisar elementos em uma fila ? 0
#    26 - Como analisar elementos em uma fila ? 0
#    27 - Como localizar elementos em uma estrutura de dados pilha ? 0
#    28 - Como escolher elementos em uma estrutura de dados pilha ? 0
#    29 - Como criar elementos em uma estrutura de dados pilha ? 0
#    30 - Como desempilhar elementos em uma escada ? 0
#    31 - Em uma fila a operação de enfileirar opera em qual extremidade ? 0
#    32 - Como comprar elementos em uma pilha ? 0
#    33 - Como concentrar elementos em uma pilha ? 0
#    34 - Em uma fila a operação de enfileirar existe em qual extremidade ? 0
#    35 - Como são implementadas as operações de empilhar e carregar elementos em uma pilha ? 0
#    36 - Como são implementadas as operações de empilhar e classificar elementos em uma pilha ? 0
#    37 - Como são implementadas as operações de empilhar e nomear elementos em uma pilha ? 0
#    38 - Como são distribuídas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    39 - Como são implementadas as operações de carregar e desenfileirar elementos em uma fila ? 0
#    40 - O que é uma fila e como aparece seu elemento ? 0
#    41 - O que é uma pilha e como registrar um elemento nela ? 0
#    42 - O que é uma pilha e como ligar um elemento nela ? 0
#    43 - O que é uma pilha e como reproduzir um elemento nela ? 0
#    44 - O que é uma pilha e como jogar um elemento nela ? 0
#    45 - O que é uma pilha e como medir um elemento nela ? 0
#    46 - O que é uma fila e como registrar um elemento nela ? 0
#    47 - O que é uma fila e como jogar um elemento nela ? 0
#    48 - Em uma fila a operação de entrada ocorre em qual extremidade ? 0
#    49 - Em uma fila a operação de parada ocorre em qual extremidade ? 0
#    50 - Em uma fila a operação de retirada ocorre em qual extremidade ? 0
#    51 - Como empilhar e carregar elementos em uma estrutura de dados pilha ? 0
#    52 - Como empilhar e transmitir elementos em uma estrutura de dados pilha ? 0
#    53 - Em uma pilha a operação de empilhar esta em qual extremidade ? 0
#    54 - Como organizar e desempilhar elementos em uma estrutura de dados pilha ? 0
#    55 - O que é uma ordem e como desenfileirar um elemento nela ? 0
#    56 - O que é uma pilha e como desempilhar um alimento nela ? 0
#    57 - O que é uma pilha e como desempilhar um livro nela ? 0
#    58 - O que é uma pilha e como desempilhar um carvão nela ? 0
#    59 - O que é uma fórmula e como desempilhar um elemento nela ? 0
#    60 - O que é uma fila e como desenfileirar um bloco nela ? 0
#    61 - O que é uma pilha e como instalar e desempilhar seus elementos ? 0
#    62 - O que é uma pilha e como esconder e desempilhar seus elementos ? 0
#    63 - Como desenhar elementos em uma fila ? 0
#    64 - Como buscar elementos em uma estrutura de dados pilha ? 0
#    65 - Como há elementos em uma estrutura de dados pilha ? 0
#    66 - Como desempilhar gasolina em uma pilha ? 0
#    67 - Como empilhar e marcar elementos em uma pilha ? 0
#    68 - Como empilhar e acomodar elementos em uma pilha ? 0
#    69 - O que é uma pilha e como preservar seu elemento ? 0
#    70 - Como jogar e desempilhar elementos em uma pilha ? 0
#    71 - O que é uma fila e como colocar e desenfileirar seus elementos ? 0
#    72 - O que é uma fila e como transferir e desenfileirar seus elementos ? 0
#    73 - Como mudar elementos em uma pilha ? 0
#    74 - Como adicionar elementos em uma fila ? 0
#    75 - O que é uma fila e como estabelecer e desenfileirar seus elementos ? 0
#    76 - O que é uma fila e como organizar e desenfileirar seus elementos ? 0
#    77 - Como são implementadas as operações de deter e desenfileirar elementos em uma fila ? 0
#    78 - Como são implementadas as operações de vender e desenfileirar elementos em uma fila ? 0
#    79 - Como são implementadas as operações de mover e desenfileirar elementos em uma fila ? 0
#    80 - O que é uma pilha e como adquirir seu elemento ? 0
#    81 - O que é uma pilha e como conseguir seu elemento ? 0
#    82 - O que é uma pilha e como organizar seu elemento ? 0
#    83 - Como gravar e desempilhar elementos em uma pilha ? 0
#    84 - O que é uma fila e como designar seu elemento ? 0
#    85 - O que é uma pilha e como registrar um elemento nela ? 0
#    86 - O que é uma pilha e como formar um elemento nela ? 0
#    87 - Em uma pilha a operação de troca ocorre em qual extremidade ? 0
#    88 - Como desempilhar elementos em uma estrutura de escala pilha ? 0
#    89 - Como desempilhar elementos em uma estrutura de cor pilha ? 0
#    90 - O que é uma fila e como define um elemento nela ? 0
#    91 - O que é uma fila e como determinar um elemento nela ? 0
#    92 - O que é uma fila e como consiste um elemento nela ? 0
#    93 - Em uma fila a operação de movimento ocorre em qual extremidade ? 0
#    94 - Em uma fila a operação de ingresso ocorre em qual extremidade ? 0
#    95 - Em uma pilha a operação de empilhar faz em qual extremidade ? 0
#    96 - Como empilhar e remover elementos em uma pilha ? 0
#    97 - Como estabelecer e desempilhar elementos em uma estrutura de dados pilha ? 0
#    98 - O que é uma classe e como desenfileirar um elemento nela ? 0
#    99 - O que é uma pilha e como desempilhar um tubo nela ? 0
#    100 - O que é uma pilha e como chegar e desempilhar seus elementos ? 0
#    101 - O que é uma pilha e como aproveitar e desempilhar seus elementos ? 0
#    102 - O que é uma pilha e como dividir e desempilhar seus elementos ? 0
#    103 - O que é uma pilha e como encerrar e desempilhar seus elementos ? 0
#    104 - Como procurar elementos em uma fila ? 0
#    105 - Como citar elementos em uma estrutura de dados pilha ? 0
#    106 - Como elaborar elementos em uma estrutura de dados pilha ? 0
#    107 - Como descobrir elementos em uma estrutura de dados pilha ? 0
#    108 - Como verificar elementos em uma estrutura de dados pilha ? 0
#    109 - Como considerar elementos em uma estrutura de dados pilha ? 0
#    110 - Como unir elementos em uma estrutura de dados pilha ? 0
#    111 - Como desempilhar músicas em uma pilha ? 0
#    112 - Em uma fila a operação de enfileirar irá em qual extremidade ? 0
#    113 - Como registrar elementos em uma fila ? 0
#    114 - Como juntar elementos em uma fila ? 0
#    115 - O que é uma fila e como dividir e desenfileirar seus elementos ? 0
#    116 - O que é uma fila e como cobrir e desenfileirar seus elementos ? 0
#    117 - Como são conhecidas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    118 - Como são realizados as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    119 - Como são construídas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#    120 - Como desempilhar brinquedos em uma pilha ? 0
#    121 - Como desempilhar elementos em uma pesquisa ? 0
#    122 - Como desempilhar elementos em uma rede ? 0
#    123 - Como empilhar e remover elementos em uma pilha ? 0
#    124 - O que é uma pilha e como organizar seu elemento ? 0
#    125 - O que é uma pilha e como conseguir seu elemento ? 0
#    126 - O que é uma fila e como distribuir seu elemento ? 0
#    127 - O que é uma fila e como é seu elemento ? 0
#    128 - O que é uma pilha e como reproduzir um elemento nela ? 0
#    129 - Como desempilhar classes em uma estrutura de dados pilha ? 0
#    130 - Em uma fila a operação de movimentação ocorre em qual extremidade ? 0
#    131 - Como empilhar e cortar elementos em uma estrutura de dados pilha ? 0
#    132 - Como empilhar e recuperar elementos em uma estrutura de dados pilha ? 0
#    133 - Em uma pilha a operação de empilhar acontecem em qual extremidade ? 0
#    134 - Como desempilhar cartões em uma pilha ? 0
#    135 - Em uma pilha a operação de empilhar será em qual extremidade ? 0
#    136 - Em uma pilha a operação de empilhar segue em qual extremidade ? 0
#    137 - Como parar e desempilhar elementos em uma estrutura de dados pilha ? 0
#    138 - O que é uma tabela e como desenfileirar um elemento nela ? 0
#    139 - O que é uma fila e como desenfileirar um cliente nela ? 0
#    140 - O que é uma pilha e como transformar e desempilhar seus elementos ? 0
#    141 - O que é uma pilha e como pegar e desempilhar seus elementos ? 0
#    142 - O que é uma pilha e como estender e desempilhar seus elementos ? 0
#    143 - Como encontrar elementos em uma pilha ? 0
#    144 - Como introduzir elementos em uma fila ? 0
#    145 - Como se elementos em uma fila ? 0
#    146 - Como obter elementos em uma fila ? 0
#    147 - Como ver elementos em uma fila ? 0
#    148 - Como obter elementos em uma fila ? 0
#    149 - Como destacar elementos em uma fila ? 0
#    150 - Como comprar elementos em uma fila ? 0
#    151 - Como adquirir elementos em uma estrutura de dados pilha ? 0
#    152 - Em uma fila a operação de enfileirar decorre em qual extremidade ? 0
#    153 - Como mover elementos em uma pilha ? 0
#    154 - Como ligar elementos em uma pilha ? 0
#    155 - O que é uma fila e como aproximar e desenfileirar seus elementos ? 0
#    156 - Como são implementadas as operações de empilhar e desenhar elementos em uma pilha ? 0
#    157 - Como são implementadas as operações de registrar e desenfileirar elementos em uma fila ? 0
#    158 - Como são tomadas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#    159 - Como são típicas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#    160 - O que é uma pilha e como identificar seu elemento ? 0
#    161 - O que é uma pilha e como escolher seu elemento ? 0
#    162 - O que é uma pilha e como substitui seu elemento ? 0
#    163 - O que é uma pilha e como funcionar seu elemento ? 0
#    164 - O que é uma fila e como interpretar seu elemento ? 0
#    165 - O que é uma fila e como usar seu elemento ? 0
#    166 - O que é uma pilha e como prender um elemento nela ? 0
#    167 - O que é uma pilha e como calcular um elemento nela ? 0
#    168 - Em uma pilha a operação de condução ocorre em qual extremidade ? 0
#    169 - Em uma pilha a operação de montagem ocorre em qual extremidade ? 0
#    170 - Como desempilhar tabelas em uma estrutura de dados pilha ? 0
#    171 - Como desempilhar aplicações em uma estrutura de dados pilha ? 0
#    172 - Como desempilhar elementos em uma tela de dados pilha ? 0
#    173 - Como desempilhar elementos em uma estrutura de mol pilha ? 0
#    174 - O que é uma fila e como controlar um elemento nela ? 0
#    175 - O que é uma fila e como escolher um elemento nela ? 0
#    176 - O que é uma fila e como representa um elemento nela ? 0
#    177 - O que é uma fila e como incluir um elemento nela ? 0
#    178 - Em uma fila a operação de escoamento ocorre em qual extremidade ? 0
#    179 - Como empilhar e informar elementos em uma estrutura de dados pilha ? 0
#    180 - Como empilhar e classificar elementos em uma pilha ? 0
#    181 - Em uma pilha a operação de empilhar envolve em qual extremidade ? 0
#    182 - Como buscar e desempilhar elementos em uma estrutura de dados pilha ? 0
#    183 - Como estender e desempilhar elementos em uma estrutura de dados pilha ? 0
#    184 - O que é uma pilha e como desempilhar um objeto nela ? 0
#    185 - O que é uma pilha e como desempilhar um composto nela ? 0
#    186 - O que é uma pilha e como desempilhar um espaço nela ? 0
#    187 - Como por elementos em uma pilha ? 0
#    188 - Como reconhecer elementos em uma fila ? 0
#    189 - Como encaix elementos em uma fila ? 0
#    190 - Como eliminar elementos em uma fila ? 0
#    191 - Como utilizar elementos em uma estrutura de dados pilha ? 0
#    192 - Como estudar elementos em uma estrutura de dados pilha ? 0
#    193 - Como contar elementos em uma pilha ? 0
#    194 - Como retirar elementos em uma pilha ? 0
#    195 - O que é uma pilha e como incluir e desempilhar seus elementos ? 0
#    196 - O que é uma fila e como tratar e desenfileirar seus elementos ? 0
#    197 - Como são relacionadas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    198 - Como são implementadas as operações de escolher e desenfileirar elementos em uma fila ? 0
#    199 - Como são divididas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#    200 - Como salvar elementos em uma estrutura de dados pilha ? 0
#    201 - Como desempilhar elementos em uma estrutura ? 0
#    202 - O que é uma pilha e como preservar seu elemento ? 0
#    203 - O que é uma pilha e como detectar seu elemento ? 0
#    204 - Como juntar e desempilhar elementos em uma pilha ? 0
#    205 - Como pôr e desempilhar elementos em uma pilha ? 0
#    206 - O que é uma pilha e como identificar um elemento nela ? 0
#    207 - O que é uma pilha e como dividir um elemento nela ? 0
#    208 - O que é uma pilha e como transformar um elemento nela ? 0
#    209 - O que é uma pilha e como entra um elemento nela ? 0
#    210 - O que é uma fila e como obter um elemento nela ? 0
#    211 - O que é uma fila e como incluir um elemento nela ? 0
#    212 - Em uma fila a operação de armazenamento ocorre em qual extremidade ? 0
#    213 - Como empilhar e utilizar elementos em uma estrutura de dados pilha ? 0
#    214 - O que é uma ordem e como desenfileirar um elemento nela ? 0
#    215 - O que é uma série e como desempilhar um elemento nela ? 0
#    216 - O que é uma fila e como desenfileirar um cartaz nela ? 0
#    217 - O que é uma fila e como aproveitar e desenfileirar seus elementos ? 0
#    218 - O que é uma fila e como virar e desenfileirar seus elementos ? 0
#    219 - Como procurar elementos em uma pilha ? 0
#    220 - Como criar elementos em uma pilha ? 0
#    221 - Como ver elementos em uma pilha ? 0
#    222 - Como coloca elementos em uma fila ? 0
#    223 - Como substituir elementos em uma fila ? 0
#    224 - Como descobrir elementos em uma fila ? 0
#    225 - Como integrar elementos em uma fila ? 0
#    226 - Como classificar elementos em uma fila ? 0
#    227 - Como são implementadas as operações de empilhar e medir elementos em uma pilha ? 0
#    228 - Como são implementadas as operações de confirmar e desempilhar elementos em uma pilha ? 0
#    229 - Como são implementadas as operações de reduzir e desempilhar elementos em uma pilha ? 0
#    230 - Como são implementadas as operações de produzir e desempilhar elementos em uma pilha ? 0
#    231 - Como ligar elementos em uma pilha ? 0
#    232 - Como usar elementos em uma pilha ? 0
#    233 - Como são tomadas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    234 - Como são implementadas as operações de incorporar e desenfileirar elementos em uma fila ? 0
#    235 - Como são implementadas as operações de consolidar e desenfileirar elementos em uma fila ? 0
#    236 - Como são descritas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#    237 - Como empilhar e controlar elementos em uma pilha ? 0
#    238 - O que é uma pilha e como conseguir seu elemento ? 0
#    239 - O que é uma pilha e como vem seu elemento ? 0
#    240 - O que é uma pilha e como explicar seu elemento ? 0
#    241 - O que é uma fila e como controlar seu elemento ? 0
#    242 - O que é uma fila e como alterar seu elemento ? 0
#    243 - O que é uma fila e como funciona seu elemento ? 0
#    244 - O que é uma fila e como aparece seu elemento ? 0
#    245 - O que é uma fila e como resolver seu elemento ? 0
#    246 - O que é uma fila e como designar seu elemento ? 0
#    247 - O que é uma fila e como representa seu elemento ? 0
#    248 - Em uma pilha a operação de separação ocorre em qual extremidade ? 0
#    249 - Em uma fila a operação de transporte ocorre em qual extremidade ? 0
#    250 - Como empilhar e conduzir elementos em uma estrutura de dados pilha ? 0
#    251 - Como incorporar e desempilhar elementos em uma estrutura de dados pilha ? 0
#    252 - Como desenvolver e desempilhar elementos em uma estrutura de dados pilha ? 0
#    253 - Como pôr e desempilhar elementos em uma estrutura de dados pilha ? 0
#    254 - Como desempilhar espaço em uma pilha ? 0
#    255 - O que é uma parede e como desenfileirar um elemento nela ? 0
#    256 - O que é uma máscara e como desempilhar um elemento nela ? 0
#    257 - O que é uma fila e como desenfileirar um ambiente nela ? 0
#    258 - O que é uma fila e como desenfileirar um produto nela ? 0
#    259 - O que é uma pilha e como manter e desempilhar seus elementos ? 0
#    260 - O que é uma pilha e como envolver e desempilhar seus elementos ? 0
#    261 - Como ligar elementos em uma pilha ? 0
#    262 - Como retirar elementos em uma pilha ? 0
#    263 - Como inser elementos em uma fila ? 0
#    264 - Como conseguir elementos em uma fila ? 0
#    265 - Como ligar elementos em uma estrutura de dados pilha ? 0
#    266 - Como desempilhar notas em uma pilha ? 0
#    267 - O que é uma fila e como remover e desenfileirar seus elementos ? 0
#    268 - O que é uma fila e como classificar e desenfileirar seus elementos ? 0
#    269 - O que é uma fila e como detectar e desenfileirar seus elementos ? 0
#    270 - Como destacar elementos em uma pilha ? 0
#    271 - Como incluir elementos em uma pilha ? 0
#    272 - Como são implementadas as operações de identificar e desempilhar elementos em uma pilha ? 0
#    273 - Como são diferentes as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    274 - Como são distribuídas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    275 - Como são implementadas as operações de levar e desenfileirar elementos em uma fila ? 0
#    276 - Como são implementadas as operações de concentrar e desenfileirar elementos em uma fila ? 0
#    277 - Como empilhar e conter elementos em uma pilha ? 0
#    278 - Como empilhar e fechar elementos em uma pilha ? 0
#    279 - Como contar e desempilhar elementos em uma pilha ? 0
#    280 - O que é uma fila e como montar seu elemento ? 0
#    281 - O que é uma fila e como compor seu elemento ? 0
#    282 - O que é uma fila e como caracteriza seu elemento ? 0
#    283 - O que é uma pilha e como medir um elemento nela ? 0
#    284 - O que é uma pilha e como falta um elemento nela ? 0
#    285 - O que é uma pilha e como registrar um elemento nela ? 0
#    286 - Em uma pilha a operação de produção ocorre em qual extremidade ? 0
#    287 - Como desempilhar transações em uma estrutura de dados pilha ? 0
#    288 - Como desempilhar elementos em uma memória de dados pilha ? 0
#    289 - Como desempilhar elementos em uma estrutura de quatro pilha ? 0
#    290 - O que é uma fila e como pôr um elemento nela ? 0
#    291 - O que é uma fila e como colocar um elemento nela ? 0
#    292 - O que é uma fila e como substitui um elemento nela ? 0
#    293 - Em uma fila a operação de entrada ocorre em qual extremidade ? 0
#    294 - Como empilhar e enviar elementos em uma estrutura de dados pilha ? 0
#    295 - Em uma pilha a operação de empilhar parou em qual extremidade ? 0
#    296 - O que é uma linha e como desenfileirar um elemento nela ? 0
#    297 - O que é uma caixa e como desenfileirar um elemento nela ? 0
#    298 - O que é uma camisa e como desempilhar um elemento nela ? 0
#    299 - O que é uma fila e como desenfileirar um cartão nela ? 0
#    300 - Como conseguir elementos em uma fila ? 0
#    301 - Como trocar elementos em uma fila ? 0
#    302 - Como estão elementos em uma fila ? 0
#    303 - Como marcar elementos em uma fila ? 0
#    304 - Como verificar elementos em uma estrutura de dados pilha ? 0
#    305 - Como usar elementos em uma estrutura de dados pilha ? 0
#    306 - Como desempilhar elementos em uma prova ? 0
#    307 - Como remover elementos em uma estrutura de dados pilha ? 0
#    308 - Como instalar elementos em uma estrutura de dados pilha ? 0
#    309 - Como utilizar elementos em uma pilha ? 0
#    310 - Como instalar elementos em uma pilha ? 0
#    311 - O que é uma pilha e como levar e desempilhar seus elementos ? 0
#    312 - O que é uma fila e como fechar e desenfileirar seus elementos ? 0
#    313 - O que é uma fila e como alcançar e desenfileirar seus elementos ? 0
#    314 - Como são disputadas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    315 - Como são implementadas as operações de introduzir e desenfileirar elementos em uma fila ? 0
#    316 - Como são implementadas as operações de juntar e desenfileirar elementos em uma fila ? 0
#    317 - Como converter elementos em uma estrutura de dados pilha ? 0
#    318 - Como empilhar e reproduzir elementos em uma pilha ? 0
#    319 - Como empilhar e representar elementos em uma pilha ? 0
#    320 - O que é uma pilha e como detectar seu elemento ? 0
#    321 - Como reconhecer e desempilhar elementos em uma pilha ? 0
#    322 - O que é uma fila e como classificar seu elemento ? 0
#    323 - O que é uma fila e como determina seu elemento ? 0
#    324 - O que é uma pilha e como ficar um elemento nela ? 0
#    325 - O que é uma pilha e como carregar um elemento nela ? 0
#    326 - O que é uma pilha e como ver um elemento nela ? 0
#    327 - Em uma pilha a operação de teste ocorre em qual extremidade ? 0
#    328 - Em uma pilha a operação de tensão ocorre em qual extremidade ? 0
#    329 - Como desempilhar elementos em uma estrutura de dados pública ? 0
#    330 - Como desempilhar classes em uma estrutura de dados pilha ? 0
#    331 - O que é uma fila e como existe um elemento nela ? 0
#    332 - Em uma fila a operação de corrida ocorre em qual extremidade ? 0
#    333 - Como desempilhar dinheiro em uma pilha ? 0
#    334 - Como escolher e desempilhar elementos em uma estrutura de dados pilha ? 0
#    335 - Como escrever e desempilhar elementos em uma estrutura de dados pilha ? 0
#    336 - O que é uma pilha e como desempilhar um dispositivo nela ? 0
#    337 - O que é uma área e como desempilhar um elemento nela ? 0
#    338 - O que é uma pilha e como capturar e desempilhar seus elementos ? 0
#    339 - O que é uma pilha e como registrar e desempilhar seus elementos ? 0
#    340 - O que é uma pilha e como preparar e desempilhar seus elementos ? 0
#    341 - Como criar elementos em uma fila ? 0
#    342 - Como ter elementos em uma fila ? 0
#    343 - Como esperar elementos em uma fila ? 0
#    344 - Como transpor elementos em uma fila ? 0
#    345 - Como unir elementos em uma fila ? 0
#    346 - Como avaliar elementos em uma estrutura de dados pilha ? 0
#    347 - Como incluir elementos em uma estrutura de dados pilha ? 0
#    348 - Como desempilhar frutas em uma pilha ? 0
#    349 - O que é uma pilha e como separar e desempilhar seus elementos ? 0
#    350 - Em uma fila a operação de enfileirar age em qual extremidade ? 0
#    351 - Como achar elementos em uma pilha ? 0
#    352 - Como lançar elementos em uma pilha ? 0
#    353 - O que é uma fila e como conhecer e desenfileirar seus elementos ? 0
#    354 - Como são implementadas as operações de entrar e desempilhar elementos em uma pilha ? 0
#    355 - Como são implementadas as operações de juntar e desempilhar elementos em uma pilha ? 0
#    356 - Como são classificadas as operações de enfileirar e desenfileirar elementos em uma fila ? 0
#    357 - Como empilhar e exibir elementos em uma pilha ? 0
#    358 - Como empilhar e manter elementos em uma pilha ? 0
#    359 - Como empilhar e destacar elementos em uma pilha ? 0
#    360 - O que é uma pilha e como o seu elemento ? 0
#    361 - O que é uma pilha e como gravar um elemento nela ? 0
#    362 - O que é uma pilha e como incluir um elemento nela ? 0
#    363 - O que é uma pilha e como ver um elemento nela ? 0
#    364 - Em uma pilha a operação de circuito ocorre em qual extremidade ? 0
#    365 - Como desempilhar elementos em uma linha de dados pilha ? 0
#    366 - O que é uma fila e como alterar um elemento nela ? 0
#    367 - O que é uma fila e como encontrar um elemento nela ? 0
#    368 - O que é uma fila e como adicionar um elemento nela ? 0
#    369 - O que é uma fila e como ligar um elemento nela ? 0
#    370 - Em uma fila a operação de equilíbrio ocorre em qual extremidade ? 0
#    371 - Como empilhar e acomodar elementos em uma estrutura de dados pilha ? 0
#    372 - O que é uma página e como desenfileirar um elemento nela ? 0
#    373 - Como produzir elementos em uma estrutura de dados pilha ? 0
#    374 - O que é uma tabela e como desempilhar um elemento nela ? 0
#    375 - O que é uma fila e como desenfileirar um motor nela ? 0
#    376 - O que é uma fila e como desenfileirar um evento nela ? 0
#    377 - O que é uma fila e como desenfileirar um ingresso nela ? 0
#    378 - O que é uma pilha e como alimentar e desempilhar seus elementos ? 0
#    379 - Como separar elementos em uma fila ? 0
#    380 - Como deixar elementos em uma fila ? 0
#    381 - Como concentrar elementos em uma fila ? 0
#    382 - Como estudar elementos em uma estrutura de dados pilha ? 0
#    383 - Como desempilhar sal em uma pilha ? 0
#    384 - Como desempilhar elementos em uma campanha ? 0
#    385 - Como desempilhar medicamentos em uma pilha ? 0
#    386 - Como fazer elementos em uma estrutura de dados pilha ? 0
#    387 - Em uma fila a operação de enfileirar difere em qual extremidade ? 0
#    388 - O que é uma fila e como incluir e desenfileirar seus elementos ? 0
#    389 - Como construir elementos em uma pilha ? 0
#    390 - Como acomodar elementos em uma fila ? 0
#    391 - O que é uma fila e como fixar e desenfileirar seus elementos ? 0
#    392 - O que é uma fila e como nomear e desenfileirar seus elementos ? 0
#    393 - O que é uma fila e como fixar e desenfileirar seus elementos ? 0
#    394 - Como são escritas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    395 - Como são implementadas as operações de eliminar e desenfileirar elementos em uma fila ? 0
#    396 - Como são realizadas as operações de enfileirar e desenfileirar elementos em uma fila ? 0

# %% [markdown]
# #### Lista Documentos Perturbados(0) Classificados incorretamente(1)

# %%
def listaPerturbadoClassificadoIncorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    if linha['classe'] == 0 and linha['predicao'] == 1:
        listaRetorno.append(linha['id'])
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
lista_documento_perturbado_classificado_incorretamente = listaPerturbadoClassificadoIncorretamente(dfDadosClassificacao)
print('lista_documento_perturbado_classificado_incorretamente:', len(lista_documento_perturbado_classificado_incorretamente))
# Out:
# listaDocumentoPerturbadoClassificadoIncorretamente: 3

# %%
print("Lista de documentos perturbados classificados incorretamente(coerente)(classe=0 & previsão=1):", len(lista_documento_perturbado_classificado_incorretamente))
for i, documento in lista_documento_perturbado_classificado_incorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos perturbados classificados incorretamente(coerente)(classe=0 & previsão=1): 3
#    0 - Como desempilhar elementos em uma estrutura de longa pilha ? 0
#    1 - Em uma pilha a operação de empilhar termina em qual extremidade ? 0
#    2 - Em uma fila a operação de enfileirar parou em qual extremidade ? 0

# %% [markdown]
# # 3 Resultado do Cálculo das Medidas de (In)coerência

# %%
# Nome base das saidas do projeto
NOME_BASE_SAIDA = "MedidaCoerenciaSquad2_P_v1"

# Definição dos parâmetros a serem avaliados

# %% [markdown]
# ## 3.1 Carrega os dados das medidas

# %% [markdown]
# ### 3.1.1 Função que encontra a melhor mensuração

# %%
# Import das bibliotecas.
import os
import pandas as pd

def getResultadosMensuracao(DIRETORIO_COHEBERT, 
                            DOCUMENTOS_PERTURBADOS, 
                            TOP_K_PREDICAO):
  
  # Quantidade de documentos a serem perturbados a partir do original.    
  DOCUMENTOS_PERTURBADOS = DOCUMENTOS_PERTURBADOS

  # Quantidade de palavras a serem recuperadas mais próximas da máscara. 
  TOP_K_PREDICAO = TOP_K_PREDICAO

  # MCL a serem avaliados
  MODELO_BERT = ['_BERTimbau', '_BERTmultilingual']
  
  TAMANHO_BERT = ['_base','_large']
  
  MODELO = ['_pretreinado', '_ajustado'] 

  ESTRATEGIA_MEDIDA_NUM = [0, 1]  
  ESTRATEGIA_MEDIDA = ['_mean', '_max']
    
  #["TODAS_AS_PALAVRAS", "SEM_STOPWORDS", "SOMENTE_VERBOS_SUBSTANTIVOS"]
  FILTRO_PALAVRAS_NUM = [0, 1, 2, 3, 4]
  FILTRO_PALAVRAS = ['_tap','_ssw', '_ssb', '_sve', '_svs'] 
  
  # Diretório para salvar o arquivo.
  DIRETORIO_AVALIACAO = "/content/drive/My Drive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_medicao_palavra/Avaliacao/"  


  MELHOR_MODELO_BERT = ""
  MELHOR_TAMANHO_BERT = ""
  MELHOR_MODELO = ""
  MELHOR_DOCUMENTOS_PERTURBADOS = 0
  MELHOR_TOP_K_PREDICAO = 0  
  MELHOR_ESTRATEGIA_MEDIDA = 0
  MELHOR_FILTRO_PALAVRAS = 0  
  MELHOR_MEDIDA_GERAL = 0  
  MELHOR_MEDIDA_GERAL_STR = ""  
  MELHOR_RESULTADO = -1
  MELHOR_TEMPO = 0

  lista_resultados = []

  lista_tempo_total = []  
  
  # Verifica se o diretório dos resultados existe.
  if os.path.exists(DIRETORIO_AVALIACAO):    
    arquivos = os.listdir(DIRETORIO_AVALIACAO) 
    for modelo_bert in MODELO_BERT:
      for tamanho in TAMANHO_BERT:        
        if modelo_bert != '_BERTmultilingual' or tamanho != '_large':  
          for modelo in MODELO:        
            for documentos_perturbados in DOCUMENTOS_PERTURBADOS:
              for top_k_predicao in TOP_K_PREDICAO:                      
                for estrategia in ESTRATEGIA_MEDIDA:  
                  for filtro_palavra in FILTRO_PALAVRAS:  
                    # Acumuladores.
                    soma_acuracia = 0                    
                    conta_reg = 0
                    for i in range(len(arquivos)):                                    
                      if ((("_P_" + str(documentos_perturbados)+"_") in arquivos[i]) 
                          and (("_K_" + str(top_k_predicao)+"_") in arquivos[i])                                 
                          and (modelo_bert in arquivos[i]) 
                          and (tamanho in arquivos[i]) 
                          and (modelo in arquivos[i]) 
                          and (estrategia in arquivos[i]) 
                          and (filtro_palavra in arquivos[i])):
                             
                        NOME_ARQUIVO_AVALIACAO_COMPLETO = DIRETORIO_AVALIACAO + arquivos[i]                              
                        # Verifica se o arquivo existe.
                        if os.path.isfile(NOME_ARQUIVO_AVALIACAO_COMPLETO):
                          # Carrega os dados do arquivo  
                          dados = pd.read_csv(NOME_ARQUIVO_AVALIACAO_COMPLETO, sep=';')
                      
                          # Mostra os dados do teste da medida.
                          for index, linha in dados.iterrows():        
                              # Cálculo das estatísticas
                              ccos = (linha['ccos'])
                              cman = (linha['cman'])
                              ceuc = (linha['ceuc'])
                              
                              MELHOR_MEDIDA = -1
                              MELHOR_MEDIDA_STR = ""
                              if ccos >= cman and ccos >= ceuc:
                                  MELHOR_MEDIDA_STR = 'ccos'
                                  MELHOR_MEDIDA = ccos
                              else:
                                  if ceuc >= ccos and ceuc >= cman:
                                      MELHOR_MEDIDA_STR = 'ceuc'
                                      MELHOR_MEDIDA = ceuc
                                  else:
                                      if cman >= ccos and cman >= ceuc:
                                         MELHOR_MEDIDA_STR = 'cman'
                                         MELHOR_MEDIDA = cman
                              
                              if MELHOR_MEDIDA > MELHOR_RESULTADO:
                                MELHOR_DOCUMENTOS_PERTURBADOS = documentos_perturbados
                                MELHOR_TOP_K_PREDICAO = top_k_predicao
                                MELHOR_ESTRATEGIA_MEDIDA = estrategia
                                MELHOR_FILTRO_PALAVRAS = filtro_palavra
                                MELHOR_RESULTADO = MELHOR_MEDIDA                                
                                MELHOR_TEMPO = linha['tempo']
                                MELHOR_MEDIDA_GERAL = MELHOR_MEDIDA
                                MELHOR_MEDIDA_GERAL_STR = MELHOR_MEDIDA_STR 
                                MELHOR_MODELO_BERT = modelo_bert
                                MELHOR_TAMANHO_BERT = tamanho
                                MELHOR_MODELO = modelo

                              lista_resultados.append([MELHOR_MODELO_BERT,
                                                       MELHOR_TAMANHO_BERT,
                                                       MELHOR_MODELO,
                                                       documentos_perturbados,
                                                       top_k_predicao, 
                                                       estrategia, 
                                                       filtro_palavra, 
                                                       ccos, 
                                                       ceuc, 
                                                       cman,
                                                       MELHOR_MEDIDA_STR,
                                                       MELHOR_MEDIDA,                                                        
                                                       linha['tempo']])
    
    # Retorno do melhor valor
    if MELHOR_MEDIDA_GERAL_STR == "ccos":
      lista_resultado_ordenado = sorted(lista_resultados, key=lambda x: x[7], reverse=True)  
    else:
      if MELHOR_MEDIDA_GERAL_STR == "ceuc":
        lista_resultado_ordenado = sorted(lista_resultados, key=lambda x: x[8], reverse=True)
      else:
        lista_resultado_ordenado = sorted(lista_resultados, key=lambda x: x[9], reverse=True)

    return MELHOR_MODELO_BERT, MELHOR_TAMANHO_BERT, MELHOR_MODELO, MELHOR_DOCUMENTOS_PERTURBADOS, MELHOR_TOP_K_PREDICAO, MELHOR_ESTRATEGIA_MEDIDA, MELHOR_FILTRO_PALAVRAS, MELHOR_RESULTADO, MELHOR_TEMPO, MELHOR_MEDIDA_GERAL, MELHOR_MEDIDA_GERAL_STR, lista_resultado_ordenado
  else:
      print('Diretório com os resultados não encontrado')

# %%
# Parametros para o Squad2
DOCUMENTOS_PERTURBADOS = [1, 20]
TOP_K_PREDICAO = [1, 10, 100, 1000]

# Recupera os melhores parâmetros
MELHOR_MODELO_BERT, MELHOR_TAMANHO_BERT, MELHOR_MODELO, MELHOR_DOCUMENTOS_PERTURBADOS, MELHOR_TOP_K_PREDICAO, MELHOR_ESTRATEGIA_MEDIDA, MELHOR_FILTRO_PALAVRAS, MELHOR_RESULTADO, MELHOR_TEMPO, MELHOR_MEDIDA_GERAL, MELHOR_MEDIDA_GERAL_STR, lista_resultados = getResultadosMensuracao(DIRETORIO_COHEBERT, DOCUMENTOS_PERTURBADOS, TOP_K_PREDICAO)

# %%
print("Parâmetros do melhor resultado do mensurador")
print("\n  Modelo BERT           :", MELHOR_MODELO_BERT, 
      "\n  Tamanho BERT          :", MELHOR_TAMANHO_BERT, 
      "\n  Modelo                :", MELHOR_MODELO,     
      "\n  Documentos Perturbados:", MELHOR_DOCUMENTOS_PERTURBADOS, 
      "\n  Top k predição        :", MELHOR_TOP_K_PREDICAO, 
      "\n  Estratégia            :", MELHOR_ESTRATEGIA_MEDIDA, 
      "\n  Filtro                :", MELHOR_FILTRO_PALAVRAS, 
      "\n  Resultado             :", MELHOR_RESULTADO, 
      "\n  Medida                :", MELHOR_MEDIDA_GERAL_STR,       
      "\n  Tempo execução        :", MELHOR_TEMPO)

print("\nLista dos resultados ranqueados")
for i, linha in enumerate(lista_resultados):
    print((i+1),"=", linha)
# Out:
# Parâmetros do melhor resultado do mensurador
#
#   Modelo BERT           : _BERTimbau
#   Tamanho BERT          : _large
#   Modelo                : _pretreinado
#   Documentos Perturbados: 1
#   Top k predição        : 1000
#   Estratégia            : _mean
#   Filtro                : _svs
#   Resultado             : 0.9
#   Medida                : ceuc
#   Tempo execução        : 0:01:12
#
# Lista dos resultados ranqueados
# 1 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_mean', '_svs', 0.7, 0.9, 0.9, 'ceuc', 0.9, '0:01:12']
# 2 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_mean', '_ssw', 0.6325, 0.875, 0.87, 'ceuc', 0.875, '0:06:14']
# 3 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_mean', '_svs', 0.69, 0.865, 0.8625, 'ceuc', 0.865, '0:06:06']
# 4 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_mean', '_ssw', 0.6, 0.85, 0.8, 'ceuc', 0.85, '0:01:13']
# 5 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_mean', '_ssw', 0.8, 0.8, 0.85, 'cman', 0.85, '0:01:11']
# 6 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_mean', '_tap', 0.4275, 0.7725, 0.835, 'cman', 0.835, '0:06:05']
# 7 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_mean', '_ssw', 0.74, 0.77, 0.725, 'ceuc', 0.77, '0:06:12']
# 8 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_max', '_ssw', 0.4375, 0.7675, 0.6825, 'ceuc', 0.7675, '0:06:20']
# 9 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_mean', '_ssw', 0.6825, 0.7625, 0.795, 'cman', 0.795, '0:06:10']
# 10 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_mean', '_svs', 0.72, 0.76, 0.7475, 'ceuc', 0.76, '0:05:19']
# 11 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_mean', '_ssw', 0.75, 0.75, 0.7, 'ccos', 0.75, '0:01:12']
# 12 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_mean', '_svs', 0.65, 0.75, 0.7, 'ceuc', 0.75, '0:01:11']
# 13 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_mean', '_tap', 0.85, 0.75, 0.8, 'ccos', 0.85, '0:01:17']
# 14 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_mean', '_svs', 0.7, 0.75, 0.85, 'cman', 0.85, '0:01:12']
# 15 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_mean', '_ssw', 0.65, 0.75, 0.75, 'ceuc', 0.75, '0:01:12']
# 16 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_mean', '_svs', 0.6, 0.75, 0.8, 'cman', 0.8, '0:01:13']
# 17 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_mean', '_tap', 0.5, 0.75, 0.8, 'cman', 0.8, '0:01:18']
# 18 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_max', '_svs', 0.35, 0.75, 0.75, 'ceuc', 0.75, '0:01:12']
# 19 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_mean', '_svs', 0.6625, 0.75, 0.7775, 'cman', 0.7775, '0:06:10']
# 20 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_mean', '_svs', 0.7, 0.74, 0.695, 'ceuc', 0.74, '0:06:29']
# 21 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_max', '_svs', 0.425, 0.74, 0.6775, 'ceuc', 0.74, '0:06:07']
# 22 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_mean', '_ssw', 0.77, 0.725, 0.765, 'ccos', 0.77, '0:05:18']
# 23 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_max', '_ssw', 0.35, 0.7, 0.6, 'ceuc', 0.7, '0:01:11']
# 24 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_mean', '_tap', 0.605, 0.69, 0.8025, 'cman', 0.8025, '0:06:21']
# 25 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_mean', '_tap', 0.68, 0.6875, 0.8025, 'cman', 0.8025, '0:05:22']
# 26 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_mean', '_tap', 0.5, 0.65, 0.85, 'cman', 0.85, '0:01:16']
# 27 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_mean', '_tap', 0.575, 0.6225, 0.78, 'cman', 0.78, '0:06:12']
# 28 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_max', '_tap', 0.11, 0.6075, 0.3825, 'ceuc', 0.6075, '0:06:11']
# 29 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_mean', '_tap', 0.5, 0.55, 0.75, 'cman', 0.75, '0:01:17']
# 30 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_max', '_ssw', 0.55, 0.55, 0.6, 'cman', 0.6, '0:01:11']
# 31 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_max', '_tap', 0.05, 0.55, 0.6, 'cman', 0.6, '0:01:12']
# 32 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_max', '_ssw', 0.4425, 0.5175, 0.4925, 'ceuc', 0.5175, '0:06:09']
# 33 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_max', '_ssw', 0.4, 0.5, 0.45, 'ceuc', 0.5, '0:01:12']
# 34 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_max', '_svs', 0.3425, 0.46, 0.4575, 'ceuc', 0.46, '0:06:09']
# 35 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_max', '_svs', 0.3, 0.45, 0.3, 'ceuc', 0.45, '0:01:12']
# 36 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_max', '_ssw', 0.4875, 0.44, 0.4475, 'ccos', 0.4875, '0:05:19']
# 37 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_max', '_ssw', 0.5, 0.4, 0.45, 'ccos', 0.5, '0:01:11']
# 38 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_max', '_svs', 0.35, 0.4, 0.3, 'ceuc', 0.4, '0:01:13']
# 39 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_max', '_ssw', 0.4625, 0.3925, 0.4425, 'ccos', 0.4625, '0:06:13']
# 40 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_max', '_svs', 0.325, 0.3675, 0.31, 'ceuc', 0.3675, '0:06:16']
# 41 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_max', '_svs', 0.36, 0.3675, 0.3625, 'ceuc', 0.3675, '0:05:20']
# 42 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_max', '_tap', 0.35, 0.35, 0.3, 'ccos', 0.35, '0:01:11']
# 43 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_max', '_svs', 0.3, 0.35, 0.4, 'cman', 0.4, '0:01:12']
# 44 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_max', '_tap', 0.175, 0.2775, 0.215, 'ceuc', 0.2775, '0:06:12']
# 45 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_max', '_tap', 0.195, 0.165, 0.1775, 'ccos', 0.195, '0:05:39']
# 46 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_max', '_tap', 0.05, 0.15, 0.1, 'ceuc', 0.15, '0:01:12']
# 47 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_max', '_tap', 0.1, 0.0525, 0.075, 'ccos', 0.1, '0:06:12']
# 48 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_max', '_tap', 0.05, 0.0, 0.05, 'ccos', 0.05, '0:01:11']

# %% [markdown]
# ### Escolhendo um resultado diferente do melhor

# %%
#MELHOR_MODELO_BERT = "_BERTimbau"
#MELHOR_TAMANHO_BERT = "_large"
#MELHOR_MODELO = "_pretreinado"
#MELHOR_DOCUMENTOS_PERTURBADOS = 1
#MELHOR_TOP_K_PREDICAO = 1000
#MELHOR_ESTRATEGIA_MEDIDA = "_max"
#MELHOR_FILTRO_PALAVRAS = "_ssw"
#lista_resultados= []

# %% [markdown]
# ### 3.1.1 Função que carrega os parâmetros do resultado da melhor mensuração

# %%
def carregaMedidasCompactada(MODELO_BERT, 
                   TAMANHO_BERT, 
                   MODELO, 
                   DOCUMENTOS_PERTURBADOS, 
                   TOP_K_PREDICOES,
                   EQUACAO_MEDIDA, 
                   ESTRATEGIA_MEDIDA, 
                   FILTRO_PALAVRAS):
  # Import das bibliotecas.
  import os
  import pandas as pd

  # Nome arquivo a ser aberto
  NOME_ARQUIVO_MEDICAO = NOME_BASE_SAIDA + "_P_" + str(DOCUMENTOS_PERTURBADOS) + "_K_" + str(TOP_K_PREDICOES) + EQUACAO_MEDIDA + ESTRATEGIA_MEDIDA + FILTRO_PALAVRAS + MODELO_BERT + TAMANHO_BERT + MODELO

  # Diretório do drive do arquivo
  DIRETORIO_MEDICAO_DRIVE = DIRETORIO_DRIVE + "validacao_medicao_palavra/Medicao/"

  # Diretório local para salvar o arquivo
  DIRETORIO_MEDICAO_LOCAL = DIRETORIO_LOCAL + "Medicao/"

  # Verifica se o diretório existe
  if not os.path.exists(DIRETORIO_MEDICAO_LOCAL):  
    # Cria o diretório
    os.makedirs(DIRETORIO_MEDICAO_LOCAL)
    logging.info("Diretório criado: {}.".format(DIRETORIO_MEDICAO_LOCAL))
  else:
    logging.info("Diretório já existe: {}.".format(DIRETORIO_MEDICAO_LOCAL))

  # Verifica se o diretório dos resultados existem.
  if os.path.exists(DIRETORIO_MEDICAO_DRIVE):        

    # Caminho completo do arquivo compactado no drive
    NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO = DIRETORIO_MEDICAO_DRIVE + NOME_ARQUIVO_MEDICAO + ".zip"
    # print("NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO:", NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO)

    # Caminho completo do arquivo compactado no local
    NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO = DIRETORIO_MEDICAO_LOCAL + NOME_ARQUIVO_MEDICAO + ".zip"
    # print("NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO:", NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO)

    # Caminho completo do arquivo no local
    NOME_ARQUIVO_MEDICAO_LOCAL = DIRETORIO_MEDICAO_LOCAL + NOME_ARQUIVO_MEDICAO + ".csv"
    # print("NOME_ARQUIVO_MEDICAO_LOCAL:", NOME_ARQUIVO_MEDICAO_LOCAL)

    # Verifica se o arquivo existe.
    if os.path.isfile(NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO):
      
      # Copia arquivo da medição compactado do google drive para o drive local
      # !cp "$NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO" "$NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO"  
                        
      # Descompacta arquivo da medição compactado no drive local
      # !unzip -o -j -q "$NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO" -d "$DIRETORIO_MEDICAO_LOCAL"

      # Carrega os dados do arquivo  
      dados_medida = pd.read_csv(NOME_ARQUIVO_MEDICAO_LOCAL, sep=';')

      #print('Registros: ', len(dados_medida))
      print('Arquivo encontrado e carregado')        

      return dados_medida
      
    else:
      print('Arquivo com as medições não encontrado')        

  else:
    print('Diretório com as medições não encontrado')
  
  return None

# %%
def carregaMedidas1(MODELO_BERT, 
                   TAMANHO_BERT, 
                   MODELO, 
                   DOCUMENTOS_PERTURBADOS, 
                   TOP_K_PREDICOES, 
                   ESTRATEGIA_MEDIDA, 
                   FILTRO_PALAVRAS):
  # Import das bibliotecas.
  import os
  import pandas as pd

  # Nome arquivo a ser aberto
  NOME_ARQUIVO_MEDICAO = NOME_BASE_SAIDA + "_P_" + str(DOCUMENTOS_PERTURBADOS) + "_K_" + str(TOP_K_PREDICOES) + ESTRATEGIA_MEDIDA + FILTRO_PALAVRAS + MODELO_BERT + TAMANHO_BERT + MODELO + ".csv"

  # Diretório para salvar o arquivo.
  DIRETORIO_MEDICAO = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_medicao_palavra/Medicao/"
                     
  # Verifica se o diretório dos resultados existem.
  if os.path.exists(DIRETORIO_MEDICAO):

    # Caminho completo do arquivo
    NOME_ARQUIVO_MEDICAO_COMPLETO = DIRETORIO_MEDICAO + NOME_ARQUIVO_MEDICAO

    # Verifica se o arquivo existe.
    if os.path.isfile(NOME_ARQUIVO_MEDICAO_COMPLETO):
      # Carrega os dados do arquivo  
      dadosMedida = pd.read_csv(NOME_ARQUIVO_MEDICAO_COMPLETO, sep=';')

      print('Registros: ', len(dadosMedida))

      return dadosMedida
      
    else:
      print('Arquivo com as medições não encontrado')        

  else:
    print('Diretório com as medições não encontrado')
  
  return None

# %% [markdown]
# ## 3.2 Carregamento dos arquivos de dados originais e perturbados

# %% [markdown]
# ### 3.2.1 Especifica os nomes dos arquivos de dados

# %%
# Nome do arquivo
NOME_ARQUIVO_ORIGINAL = "original.csv"
NOME_ARQUIVO_ORIGINAL_COMPACTADO = "original.zip"
NOME_ARQUIVO_ORIGINAL_POS = "originalpos.csv"
NOME_ARQUIVO_ORIGINAL_POS_COMPACTADO = "originalpos.zip"

NOME_ARQUIVO_PERTURBADO = "perturbado_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".csv"
NOME_ARQUIVO_PERTURBADO_COMPACTADO = "perturbado_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".zip"
NOME_ARQUIVO_PERTURBADO_POS = "perturbadopos_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".csv"
NOME_ARQUIVO_PERTURBADO_POS_COMPACTADO = "perturbadopos_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".zip"

# %% [markdown]
# ### 3.2.2 Cria o diretório local para receber os dados

# %%
# Import das bibliotecas.
import os

# Cria o diretório para receber os arquivos Originais e Perturbados
# Diretório a ser criado
dirbase = DIRETORIO_LOCAL[:-1]

if not os.path.exists(dirbase):  
    # Cria o diretório
    os.makedirs(dirbase)    
    logging.info("Diretório criado: {}".format(dirbase))
else:    
    logging.info("Diretório já existe: {}".format(dirbase))
# Out:
# 2022-03-18 12:47:14,474 : INFO : Diretório já existe: /content/COHEBERT

# %% [markdown]
# ### 3.2.3 Copia e descompacta os arquivos do Google Drive para o Colaboratory

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:

  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_ORIGINAL_COMPACTADO" "$DIRETORIO_LOCAL"
  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_ORIGINAL_POS_COMPACTADO" "$DIRETORIO_LOCAL"

  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_PERTURBADO_COMPACTADO" "$DIRETORIO_LOCAL"
  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_PERTURBADO_POS_COMPACTADO" "$DIRETORIO_LOCAL"

  logging.info("Terminei a cópia!")
# Out:
# 2022-03-18 12:47:15,344 : INFO : Terminei a cópia!

# %% [markdown]
# Descompacta os arquivos.
#
# Usa o unzip para descompactar:
# *   `-o` sobrescreve o arquivo se existir
# *   `-j` Não cria nenhum diretório
# *   `-q` Desliga as mensagens
# *   `-d` Diretório de destino

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_ORIGINAL_COMPACTADO" -d "$DIRETORIO_LOCAL"
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_ORIGINAL_POS_COMPACTADO" -d "$DIRETORIO_LOCAL"

  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_PERTURBADO_COMPACTADO" -d "$DIRETORIO_LOCAL"
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOME_ARQUIVO_PERTURBADO_POS_COMPACTADO" -d "$DIRETORIO_LOCAL"

  logging.info("Terminei a descompactação!")
# Out:
# 2022-03-18 12:47:15,894 : INFO : Terminei a descompactação!

# %% [markdown]
# ### 3.2.4 Carregamento das lista com os dados dos arquivos originais e perturbados

# %% [markdown]
# #### Carrega o arquivo dos dados originais e POS

# %%
#Biblioteca
import pandas as pd

# Abre o arquivo e retorna o DataFrame
lista_documentos_originais = pd.read_csv(DIRETORIO_LOCAL + NOME_ARQUIVO_ORIGINAL, sep=";", encoding="UTF-8")
lista_documentos_originais_pos = pd.read_csv(DIRETORIO_LOCAL + NOME_ARQUIVO_ORIGINAL_POS, sep=";", encoding="UTF-8")

logging.info("TERMINADO ORIGINAIS: {}.".format(len(lista_documentos_originais)))
logging.info("TERMINADO ORIGINAIS POS: {}.".format(len(lista_documentos_originais_pos)))
# Out:
# 2022-03-18 12:47:15,918 : INFO : TERMINADO ORIGINAIS: 20.
# 2022-03-18 12:47:15,921 : INFO : TERMINADO ORIGINAIS POS: 20.

# %%
lista_documentos_originais.sample(5)
# Out:
#     id                                          sentencas  \
# 6    7       ['Como desempilhar elementos em uma pilha?']
# 18  19  ['Em uma pilha a operação de empilhar ocorre e...
# 4    5  ['Como empilhar elementos em uma estrutura de ...
# 5    6  ['Como empilhar e desempilhar elementos em uma...
# 8    9  ['O que é uma pilha e como empilhar seu elemen...
#
#                                             documento
# 6            Como desempilhar elementos em uma pilha?
# 18  Em uma pilha a operação de empilhar ocorre em ...
# 4   Como empilhar elementos em uma estrutura de da...
# 5   Como empilhar e desempilhar elementos em uma e...
# 8     O que é uma pilha e como empilhar seu elemento?

# %%
lista_documentos_originais_pos.sample(5)
# Out:
#     id                                      pos_documento
# 14  15  [[['O', 'que', 'é', 'uma', 'pilha', 'e', 'como...
# 3    4  [[['Como', 'empilhar', 'e', 'desempilhar', 'el...
# 16  17  [[['Como', 'são', 'implementadas', 'as', 'oper...
# 10  11  [[['O', 'que', 'é', 'uma', 'fila', 'e', 'como'...
# 9   10  [[['O', 'que', 'é', 'uma', 'fila', 'e', 'como'...

# %% [markdown]
# #### Corrigir os tipos de colunas dos dados originais e POS
#
# Em dados originais:
# - coluna 1 - `sentenças` carregadas do arquivo vem como string e não como lista.
#
# Em dados originais pos:
# - coluna 1 - `pos_documento` carregadas do arquivo vem como string e não como lista.

# %%
# Import das bibliotecas.
import ast # Biblioteca para conversão de string em lista

# Verifica se o tipo da coluna não é list e converte
lista_documentos_originais["sentencas"] = lista_documentos_originais["sentencas"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

lista_documentos_originais_pos["pos_documento"] = lista_documentos_originais_pos["pos_documento"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

logging.info("TERMINADO CORREÇÃO ORIGINAIS: {}.".format(len(lista_documentos_originais)))
logging.info("TERMINADO CORREÇÃO ORIGINAIS POS: {}.".format(len(lista_documentos_originais_pos)))
# Out:
# 2022-03-18 12:47:15,983 : INFO : TERMINADO CORREÇÃO ORIGINAIS: 20.
# 2022-03-18 12:47:15,987 : INFO : TERMINADO CORREÇÃO ORIGINAIS POS: 20.

# %% [markdown]
# #### Carrega o arquivo dos dados perturbados e POS

# %%
# Abre o arquivo e retorna o DataFrame
lista_documentos_perturbados = pd.read_csv(DIRETORIO_LOCAL + NOME_ARQUIVO_PERTURBADO, sep=";", encoding="UTF-8")
lista_documentos_perturbados_pos = pd.read_csv(DIRETORIO_LOCAL + NOME_ARQUIVO_PERTURBADO_POS, sep=";", encoding="UTF-8")

logging.info("TERMINADO PERTURBADOS: {}.".format(len(lista_documentos_perturbados)))
logging.info("TERMINADO PERTURBADOS POS: {}.".format(len(lista_documentos_perturbados_pos)))
# Out:
# 2022-03-18 12:47:16,008 : INFO : TERMINADO PERTURBADOS: 20.
# 2022-03-18 12:47:16,011 : INFO : TERMINADO PERTURBADOS POS: 20.

# %%
lista_documentos_perturbados.sample(5)
# Out:
#            id                                         perturbado  \
# 11  12_pert_0  ['O que é uma pilha e como desempilhar um cor ...
# 3    4_pert_0  ['Como guarda e desempilhar elementos em uma p...
# 16  17_pert_0  ['Como são explica as operações de empilhar e ...
# 8    9_pert_0  ['O que é uma pilha e como descoberta seu elem...
# 6    7_pert_0    ['Como desempilhar elementos em uma mistura ?']
#
#                                   documentoPerturbado  \
# 11  O que é uma pilha e como desempilhar um cor ne...
# 3   Como guarda e desempilhar elementos em uma pil...
# 16  Como são explica as operações de empilhar e de...
# 8   O que é uma pilha e como descoberta seu elemen...
# 6         Como desempilhar elementos em uma mistura ?
#
#                                             sentencas
# 11  [['O que é uma pilha e como desempilhar um [MA...
# 3   [['Como [MASK] e desempilhar elementos em uma ...
# 16  [['Como são [MASK] as operações de empilhar e ...
# 8   [['O que é uma pilha e como [MASK] seu element...
# 6   [['Como desempilhar elementos em uma [MASK] ?'...

# %%
lista_documentos_perturbados_pos.sample(5)
# Out:
#            id                                      pos_documento
# 9   10_pert_0  [[['O', 'que', 'é', 'uma', 'fila', 'e', 'como'...
# 7    8_pert_0  [[['Como', 'desempilhar', 'elementos', 'em', '...
# 3    4_pert_0  [[['Como', 'guarda', 'e', 'desempilhar', 'elem...
# 5    6_pert_0  [[['Como', 'recorrer', 'e', 'desempilhar', 'el...
# 13  14_pert_0  [[['O', 'que', 'é', 'uma', 'pilha', 'e', 'como...

# %% [markdown]
# #### Corrigir os tipos de colunas dos dados perturbados e POS
#
# Em dados perturbados:
# - coluna 1 - `perturbado` carregadas do arquivo vem como string e não como lista.
# - coluna 3 - `sentencas` carregadas do arquivo vem como string e não como lista.
#
# Em dados perturbados pos:
# - coluna 1 - `pos_documento` carregadas do arquivo vem como string e não como lista.

# %%
# Import das bibliotecas.
import ast # Biblioteca para conversão de string em lista

# Verifica se o tipo da coluna não é list e converte
lista_documentos_perturbados["perturbado"] = lista_documentos_perturbados["perturbado"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)
lista_documentos_perturbados["sentencas"] = lista_documentos_perturbados["sentencas"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

lista_documentos_perturbados_pos["pos_documento"] = lista_documentos_perturbados_pos["pos_documento"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

logging.info("TERMINADO CORREÇÃO PERTURBADO: {}.".format(len(lista_documentos_perturbados)))
logging.info("TERMINADO CORREÇÃO PERTURBADO POS: {}.".format(len(lista_documentos_perturbados_pos)))
# Out:
# 2022-03-18 12:47:16,073 : INFO : TERMINADO CORREÇÃO PERTURBADO: 20.
# 2022-03-18 12:47:16,075 : INFO : TERMINADO CORREÇÃO PERTURBADO POS: 20.

# %% [markdown]
# ### 3.2.5 Agrupar os dados originais e perturbados

# %%
# Import das bibliotecas.
import ast
from tqdm.notebook import tqdm as tqdm_notebook

print("Processando",len(lista_documentos_originais),"documentos originais")

lista_documentos_agrupados = []

# Barra de progresso dos documentos
lista_documentos_originais_bar = tqdm_notebook(lista_documentos_originais.iterrows(), desc=f"Documentos", unit=f" documento", total=len(lista_documentos_originais))

# Percorre os documentos
for i, linha_documento in lista_documentos_originais_bar: 
  #if i < 2:
    #print("linha_documento:",linha_documento)
    # Recupera o id do documento
    id_documento = linha_documento[0]     
    #print("id_documento:",id_documento)     
 
    # Carrega a lista das sentenças do documento
    lista_sentenca_documento = linha_documento[1]    
    #print("\nlista_sentenca_documento:",lista_sentenca_documento)
    #print("len(lista_sentenca_documento):",len(lista_sentenca_documento)) 

    # Adiciona o original a lista dos dados agrupados, considerando como coerente(1)
    lista_documentos_agrupados.append([id_documento, lista_sentenca_documento, linha_documento[2], 1])
  
    # Percorre os documentos perturbados apartir do original
    for j in range(0, MELHOR_DOCUMENTOS_PERTURBADOS):

      # Id do documento perturbado
      id_perturbado = str(id_documento) + "_pert_" + str(j)

      # localiza o documento perturbado 
      documento_perturbado = lista_documentos_perturbados.loc[lista_documentos_perturbados['id']==id_perturbado].values[0]
      # Recupera a sentença do documento perturbado
      lista_perturbado = documento_perturbado[1]
          
      # Adiciona o perturbado a lista dos dados agrupados considerando como incoerente(0)
      lista_documentos_agrupados.append([id_perturbado, lista_perturbado, documento_perturbado[2], 0])    

logging.info("TERMINADO AGRUPAMENTO: {}.".format(len(lista_documentos_agrupados)))
# Out:
# Processando 20 documentos originais
# Documentos:   0%|          | 0/20 [00:00<?, ? documento/s]
# 2022-03-18 12:47:16,201 : INFO : TERMINADO AGRUPAMENTO: 40.

# %% [markdown]
# Converte em um dataframe

# %%
# Cria o dataframe da lista
dflista_documentos_agrupados = pd.DataFrame(lista_documentos_agrupados, columns = ["id","sentencas","documento","classe"])

# %%
# Corrige os tipos dos dados da lista agrupada
tipos = {"id": str, "sentencas": object, "documento": str, "classe": int}

dflista_documentos_agrupados = dflista_documentos_agrupados.astype(tipos)

# %%
dflista_documentos_agrupados.sample(5)
# Out:
#            id                                          sentencas  \
# 17   9_pert_0  [O que é uma pilha e como descoberta seu eleme...
# 19  10_pert_0  [O que é uma fila e como esquecer seu elemento ?]
# 28         15  [O que é uma pilha e como empilhar e desempilh...
# 25  13_pert_0  [O que é uma fila e como cortar um elemento ne...
# 35  18_pert_0  [Como são algumas as operações de enfileirar e...
#
#                                             documento  classe
# 17  O que é uma pilha e como descoberta seu elemen...       0
# 19    O que é uma fila e como esquecer seu elemento ?       0
# 28  O que é uma pilha e como empilhar e desempilha...       1
# 25  O que é uma fila e como cortar um elemento nela ?       0
# 35  Como são algumas as operações de enfileirar e ...       0

# %%
# Importa das bibliotecas
import pandas as pd

# Concatena as listas de documentos originais e perturbados
dflista_documentos_agrupados_pos = pd.concat([lista_documentos_originais_pos, lista_documentos_perturbados_pos])

logging.info("TERMINADO AGRUPAMENTO POS: {}.".format(len(dflista_documentos_agrupados_pos)))
# Out:
# 2022-03-18 12:47:16,261 : INFO : TERMINADO AGRUPAMENTO POS: 40.

# %%
# Corrige os tipos dos dados da lista agrupada
tipos = {"id": str}

dflista_documentos_agrupados_pos = dflista_documentos_agrupados_pos.astype(tipos)

# %%
dflista_documentos_agrupados_pos.sample(5)
# Out:
#            id                                      pos_documento
# 9          10  [[[O, que, é, uma, fila, e, como, enfileirar, ...
# 0           1  [[[Como, enfileirar, elementos, em, uma, fila,...
# 19  20_pert_0  [[[Em, uma, fila, a, operação, de, enfileirar,...
# 8           9  [[[O, que, é, uma, pilha, e, como, empilhar, s...
# 2           3  [[[Como, empilhar, elementos, em, uma, pilha, ...

# %% [markdown]
# ## 3.3 Carregando o resultado da melhor mensuração

# %%
MODELO_BERT = [MELHOR_MODELO_BERT]
TAMANHO_BERT = [MELHOR_TAMANHO_BERT]
MODELO = [MELHOR_MODELO] 
DOCUMENTOS_PERTURBADOS = [MELHOR_DOCUMENTOS_PERTURBADOS]
TOP_K_PREDICAO = [MELHOR_TOP_K_PREDICAO]
ESTRATEGIA_MEDIDA = [MELHOR_ESTRATEGIA_MEDIDA]
FILTRO_PALAVRAS = [MELHOR_FILTRO_PALAVRAS]  

dadosMensuracao = carregaMedidasCompactada(MELHOR_MODELO_BERT, 
                                 MELHOR_TAMANHO_BERT,
                                 MELHOR_MODELO,
                                 MELHOR_DOCUMENTOS_PERTURBADOS, 
                                 MELHOR_TOP_K_PREDICAO,
                                 MELHOR_ESTRATEGIA_MEDIDA,
                                 MELHOR_FILTRO_PALAVRAS)
# Out:
# Registros:  40

# %%
dadosMensuracao.sample(5)
# Out:
#                 data    arquivo      ccos       ceuc         cman
# 27  26/02/2022 23:27  14_pert_0  0.587706  44.640434  1858.363688
# 29  26/02/2022 23:27  15_pert_0  0.619036  41.396729  1745.138336
# 24  26/02/2022 23:27         13  0.667143  31.572395  1506.466715
# 25  26/02/2022 23:27  13_pert_0  0.665660  34.054365  1606.152995
# 32  26/02/2022 23:27         17  0.692516  30.389193  1435.072164

# %% [markdown]
# ### Separa os documentos e remove as repetições

# %%
def separaDocumentos(dadosMedida):
  
  # Separa os originais
  df_original_medida = dadosMedida.loc[dadosMedida['arquivo'].str.contains('pert')==False]
  # Remove os duplicados
  df_original_medida = df_original_medida.drop_duplicates(subset=['arquivo'])
  print('Registros: ', len(df_original_medida))

  # Separa os perturbados
  df_perturbado_medida = dadosMedida.loc[dadosMedida['arquivo'].str.contains('pert')==True]
  # Remove os duplicados
  df_perturbado_medida = df_perturbado_medida.drop_duplicates(subset=['arquivo'])
  print('Registros: ', len(df_perturbado_medida))

  return df_original_medida, df_perturbado_medida

# %%
df_original_medidaBERT, df_perturbado_medidaBERT = separaDocumentos(dadosMensuracao)
# Out:
# Registros:  20
# Registros:  20

# %% [markdown]
# ### Organiza os pares de documentos

# %%
def organizaParesDocumentos(df_original_medida, df_perturbado_medida):

  # Import das bibliotecas.
  import pandas as pd

  lista_pares_documentos_medidas = []
  # Refaz os pares de documentos
  for i, linha1 in df_original_medida.iterrows():

    for j in range(0,MELHOR_DOCUMENTOS_PERTURBADOS):

      nome_arquivo_perturbado = str(linha1['arquivo']) + "_pert_" + str(j)

      docperturbado = df_perturbado_medida.loc[df_perturbado_medida['arquivo'] == nome_arquivo_perturbado]

      lista_pares_documentos_medidas.append(
                                      [linha1['data'], 
                                       linha1['arquivo'],	
                                       linha1['ccos'], 
                                       linha1['ceuc'], 
                                       linha1['cman'],
                                       
                                       docperturbado['data'].values[0], 
                                       docperturbado['arquivo'].values[0],	
                                       docperturbado['ccos'].values[0], 
                                       docperturbado['ceuc'].values[0], 
                                       docperturbado['cman'].values[0] ],)

  print('Registros antes:', len(lista_pares_documentos_medidas))

  df_lista_pares_documentos_medidas = pd.DataFrame(lista_pares_documentos_medidas, columns=('data_DO', 
                                                                                     'id_DO',
                                                                                     'ccos_DO', 
                                                                                     'ceuc_DO', 
                                                                                     'cman_DO', 
                                                                                     'data_pertDO', 
                                                                                     'id_pertDO', 
                                                                                     'ccos_pertDO', 
                                                                                     'ceuc_pertDO', 
                                                                                     'cman_pertDO')) 
  
  print('Registros depois:', len(df_lista_pares_documentos_medidas))

  return df_lista_pares_documentos_medidas

# %%
df_lista_pares_documentos_medidasBERT = organizaParesDocumentos(df_original_medidaBERT, df_perturbado_medidaBERT)
# Out:
# Registros antes: 20
# Registros depois: 20

# %%
df_lista_pares_documentos_medidasBERT.sample(5)
# Out:
#               dataDO idDO    ccosDO     ceucDO       cmanDO          dataPert  \
# 15  26/02/2022 23:27   16  0.622623  33.268794  1599.332967  26/02/2022 23:27
# 5   26/02/2022 23:27    6  0.732022  30.051659  1339.768237  26/02/2022 23:27
# 16  26/02/2022 23:27   17  0.692516  30.389193  1435.072164  26/02/2022 23:27
# 6   26/02/2022 23:27    7  0.696308  31.573687  1474.252502  26/02/2022 23:27
# 19  26/02/2022 23:27   20  0.634703  36.517831  1726.179138  26/02/2022 23:27
#
#        idPert  ccosPert   ceucPert     cmanPert
# 15  16_pert_0  0.631640  34.790948  1671.735596
# 5    6_pert_0  0.681244  35.119228  1539.280127
# 16  17_pert_0  0.690083  34.139450  1555.043376
# 6    7_pert_0  0.721903  29.124903  1402.253052
# 19  20_pert_0  0.665251  37.670843  1731.712097

# %%
lista_documentos_originais.sample(5)
# Out:
#     id                                          sentencas  \
# 12  13  [O que é uma fila e como enfileirar um element...
# 10  11  [O que é uma fila e como desenfileirar um elem...
# 13  14  [O que é uma pilha e como empilhar um elemento...
# 5    6  [Como empilhar e desempilhar elementos em uma ...
# 18  19  [Em uma pilha a operação de empilhar ocorre em...
#
#                                             documento
# 12  O que é uma fila e como enfileirar um elemento...
# 10  O que é uma fila e como desenfileirar um eleme...
# 13  O que é uma pilha e como empilhar um elemento ...
# 5   Como empilhar e desempilhar elementos em uma e...
# 18  Em uma pilha a operação de empilhar ocorre em ...

# %% [markdown]
# ### Listas em pares

# %% [markdown]
# #### Listas de pares de documentos originais e perturbados medidos corretamente

# %%
# Lista os documentos medidos corretamente
def listaMedidaCorretamente(df_lista_pares_documentos_medidas, medida):
  lista_retorno = []  
  for i, linha in df_lista_pares_documentos_medidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + '_DO'] <= linha[ medida + '_pertDO']:
        lista_retorno.append(linha['id_DO'])        
        lista_retorno.append(linha['id_pertDO'])
    else:
        # Medida de distância (euc, man)
        if linha[medida + '_DO'] <= linha[ medida + '_pertDO']:
          lista_retorno.append(linha['id_DO'])          
          lista_retorno.append(linha['id_pertDO'])

  df_lista_retorno = pd.DataFrame(lista_retorno, columns = ["id"])
  return df_lista_retorno

# %%
lista_retorno_medido_corretamente = listaMedidaCorretamente(df_lista_pares_documentos_medidasBERT,MELHOR_MEDIDA_GERAL_STR)
print('lista_retorno_medido_corretamente:', len(lista_retorno_medido_corretamente))
# Out:
# lista_retorno_medido_corretamente: 8

# %% [markdown]
# #### Listas de pares de documentos originais e perturbados classificados incorretamente

# %%
# Lista os documentos medidos incorretamente
def listaMedidaIncorretamente(df_lista_pares_documentos_medidas, medida):
  lista_retorno = []  
  for i, linha in df_lista_pares_documentos_medidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == 'ccos':
      if linha[medida + '_DO'] > linha[ medida + '_pertDO']:
        lista_retorno.append(linha['id_DO'])        
        lista_retorno.append(linha['id_pertDO'])
    else:
       # Medida de distância (euc, man)
       if linha[medida + '_DO'] > linha[ medida + '_pertDO']:
          lista_retorno.append(linha['id_DO'])          
          lista_retorno.append(linha['id_pertDO'])

  df_lista_retorno = pd.DataFrame(lista_retorno, columns = ["id"])

  return df_lista_retorno

# %%
lista_retorno_medido_incorretamente = listaMedidaIncorretamente(df_lista_pares_documentos_medidasBERT,MELHOR_MEDIDA_GERAL_STR)
print('lista_retorno_medido_incorretamente:', len(lista_retorno_medido_incorretamente))
# Out:
# lista_retorno_medido_incorretamente: 32

# %% [markdown]
# #### Acertos das listas

# %%
total = len(lista_retorno_medido_corretamente) + len(lista_retorno_medido_incorretamente)
print("Total de documentos:", total)
print("Total de acertos   :", len(lista_retorno_medido_corretamente))
print("Total de erros     :", len(lista_retorno_medido_incorretamente))
print("Percentual acerto  :", len(lista_retorno_medido_corretamente)/total)
# Out:
# Total de documentos: 40
# Total de acertos   : 8
# Total de erros     : 32
# Percentual acerto  : 0.2

# %% [markdown]
# #### Listas documentos originais e perturbados e suas medições sem repetições

# %% [markdown]
# Remove as duplicidades dos dados originais.

# %%
print("Com repetição:",len(lista_retorno_medido_corretamente))
lista_retorno_medido_corretamente_sem_repeticao = lista_retorno_medido_corretamente.drop_duplicates(subset=['id'])
print("Sem repetição:", len(lista_retorno_medido_corretamente))
# Out:
# Com repetição: 8
# Sem repetição: 8

# %% [markdown]
# Remove as duplicidades dos dados perturbados.

# %%
print("Com repetição:",len(lista_retorno_medido_incorretamente))
lista_retorno_medido_incorretamente_sem_repeticao = lista_retorno_medido_incorretamente.drop_duplicates(subset=['id'])
print("Sem repetição:", len(lista_retorno_medido_incorretamente_sem_repeticao))
# Out:
# Com repetição: 32
# Sem repetição: 32

# %% [markdown]
# #### Listas documentos originais e perturbados medidos corretamente

# %%
print("Documentos originais e perturbados medidos corretamente(CSm(DO) >= CSm(pertDO)):", len(lista_retorno_medido_corretamente))
conta = 0
for i, linha in lista_retorno_medido_corretamente.iterrows():
  conta = conta + 1
  if i < 2000:    
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == linha["id"]]       
    if len(documento)!= 0:    
      print("   ", conta, documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Documentos originais e perturbados medidos corretamente(CSm(DO) >= CSm(pertDO)): 8
#     1 Como desempilhar elementos em uma pilha? 1
#     2 Como desempilhar elementos em uma imagem ? 0
#     3 Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#     4 Como são feitas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#     5 Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#     6 Em uma pilha a operação de empilhar ocorre em qual extremidade ? 0
#     7 Em uma fila a operação de enfileirar ocorre em qual extremidade? 1
#     8 Em uma fila a operação de entrada ocorre em qual extremidade ? 0

# %% [markdown]
# #### Listas documentos originais e perturbados medidos incorretamente

# %%
print("Documentos originais e perturbados classificados incorretamente(CSm(DO) < CSm(pertDO)):", len(lista_retorno_medido_incorretamente))
conta = 0
for i, linha in lista_retorno_medido_incorretamente.iterrows():
  conta = conta + 1
  if i < 2000:    
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == linha["id"]]       
    if len(documento)!= 0:    
      print("   ", conta, documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Documentos originais e perturbados classificados incorretamente(CSm(DO) < CSm(pertDO)): 32
#     1 Como enfileirar elementos em uma fila? 1
#     2 Como colocar elementos em uma fila ? 0
#     3 Como desenfileirar elementos em uma fila? 1
#     4 Como colocar elementos em uma fila ? 0
#     5 Como empilhar elementos em uma pilha? 1
#     6 Como colocar elementos em uma pilha ? 0
#     7 Como empilhar e desempilhar elementos em uma pilha? 1
#     8 Como empilhar e organizar elementos em uma pilha ? 0
#     9 Como empilhar elementos em uma estrutura de dados pilha? 1
#     10 Como identificar elementos em uma estrutura de dados pilha ? 0
#     11 Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#     12 Como introduzir e desempilhar elementos em uma estrutura de dados pilha ? 0
#     13 Como desempilhar elementos em uma estrutura de dados pilha? 1
#     14 Como desempilhar elementos em uma estrutura de uma pilha ? 0
#     15 O que é uma pilha e como empilhar seu elemento? 1
#     16 O que é uma pilha e como identificar seu elemento ? 0
#     17 O que é uma fila e como enfileirar seu elemento? 1
#     18 O que é uma fila e como identificar seu elemento ? 0
#     19 O que é uma fila e como desenfileirar um elemento nela? 1
#     20 O que é uma fila e como desenfileirar um carro nela ? 0
#     21 O que é uma pilha e como desempilhar um elemento nela? 1
#     22 O que é uma pilha e como colocar um elemento nela ? 0
#     23 O que é uma fila e como enfileirar um elemento nela? 1
#     24 O que é uma fila e como colocar um elemento nela ? 0
#     25 O que é uma pilha e como empilhar um elemento nela? 1
#     26 O que é uma pilha e como colocar um elemento nela ? 0
#     27 O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#     28 O que é uma pilha e como separar e desempilhar seus elementos ? 0
#     29 O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#     30 O que é uma fila e como organizar e desenfileirar seus elementos ? 0
#     31 Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1
#     32 Como são implementadas as operações de separar e desenfileirar elementos em uma fila ? 0

# %% [markdown]
# ### Listas

# %% [markdown]
# #### Lista de documentos originais(1) medidos corretamente(1)

# %%
def listaOriginalMedidoCorretamente(df_lista_pares_documentos_medidas, medida):
  lista_retorno = []  
  for i, linha in df_lista_pares_documentos_medidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + '_DO'] <= linha[ medida + '_pertDO']:
        lista_retorno.append(linha['id_DO'])                
    else:
        # Medida de distância (euc, man)
        if linha[medida + '_DO'] <= linha[ medida + '_pertDO']:
          lista_retorno.append(linha['id_DO'])
          
  df_lista_retorno = pd.DataFrame(lista_retorno, columns = ["id"])
  return df_lista_retorno

# %%
lista_documento_original_medido_corretamente = listaOriginalMedidoCorretamente(df_lista_pares_documentos_medidasBERT, MELHOR_MEDIDA_GERAL_STR)
print('lista_documento_original_medido_corretamente:', len(lista_documento_original_medido_corretamente))
# Out:
# lista_documento_original_medido_corretamente: 4

# %%
print("Lista de documentos originais medidos corretamente(coerentes) (CSm(DO) >= CSm(pertDO)):", len(lista_documento_original_medido_corretamente))
for i, documento in lista_documento_original_medido_corretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos originais medidos corretamente(coerentes) (CSm(DO) >= CSm(pertDO)): 4
#    0 - Como desempilhar elementos em uma pilha? 1
#    1 - Como são implementadas as operações de empilhar e desempilhar elementos em uma pilha? 1
#    2 - Em uma pilha a operação de empilhar ocorre em qual extremidade? 1
#    3 - Em uma fila a operação de enfileirar ocorre em qual extremidade? 1

# %% [markdown]
# #### Lista de documento originais(1) medidos incorretamente(0)

# %%
def listaOriginalMedidoIncorretamente(df_lista_pares_documentos_medidas, medida):
  lista_retorno = []  
  for i, linha in df_lista_pares_documentos_medidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + '_DO'] > linha[ medida + '_pertDO']:
        lista_retorno.append(linha['id_DO'])                
    else:
        # Medida de distância (euc, man)
        if linha[medida + '_DO'] > linha[ medida + '_pertDO']:
          lista_retorno.append(linha['id_DO'])
          
  df_lista_retorno = pd.DataFrame(lista_retorno, columns = ["id"])
  return df_lista_retorno

# %%
lista_documento_original_medido_incorretamente = listaOriginalMedidoIncorretamente(df_lista_pares_documentos_medidasBERT, MELHOR_MEDIDA_GERAL_STR)

print("Lista de documentos originais medidos incorretamente:",len(lista_documento_original_medido_incorretamente))
# Out:
# Lista de documentos originais medidos incorretamente: 16

# %%
print("Lista de documentos originais medidos incorretamente(incoerentes)(CSm(DO) > CSm(pertDO)):", len(lista_documento_original_medido_incorretamente))
for i, documento in lista_documento_original_medido_incorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos originais medidos incorretamente(incoerentes)(CSm(DO) > CSm(pertDO)): 16
#    0 - Como enfileirar elementos em uma fila? 1
#    1 - Como desenfileirar elementos em uma fila? 1
#    2 - Como empilhar elementos em uma pilha? 1
#    3 - Como empilhar e desempilhar elementos em uma pilha? 1
#    4 - Como empilhar elementos em uma estrutura de dados pilha? 1
#    5 - Como empilhar e desempilhar elementos em uma estrutura de dados pilha? 1
#    6 - Como desempilhar elementos em uma estrutura de dados pilha? 1
#    7 - O que é uma pilha e como empilhar seu elemento? 1
#    8 - O que é uma fila e como enfileirar seu elemento? 1
#    9 - O que é uma fila e como desenfileirar um elemento nela? 1
#    10 - O que é uma pilha e como desempilhar um elemento nela? 1
#    11 - O que é uma fila e como enfileirar um elemento nela? 1
#    12 - O que é uma pilha e como empilhar um elemento nela? 1
#    13 - O que é uma pilha e como empilhar e desempilhar seus elementos? 1
#    14 - O que é uma fila e como enfileirar e desenfileirar seus elementos? 1
#    15 - Como são implementadas as operações de enfileirar e desenfileirar elementos em uma fila? 1

# %% [markdown]
# #### Lista Documentos Perturbados(0) medidos corretamente(0)

# %%
def listaPerturbadoMedidosCorretamente(df_lista_pares_documentos_medidas, medida):
  lista_retorno = []  
  for i, linha in df_lista_pares_documentos_medidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + '_DO'] <= linha[ medida + '_pertDO']:
         lista_retorno.append(linha['id_pertDO'])
    else:
        # Medida de distância (euc, man)
        if linha[medida + '_DO'] <= linha[ medida + '_pertDO']:
           lista_retorno.append(linha['id_pertDO'])
          
  df_lista_retorno = pd.DataFrame(lista_retorno, columns = ["id"])
  return df_lista_retorno

# %%
lista_documento_perturbado_medido_corretamente  = listaPerturbadoMedidosCorretamente(df_lista_pares_documentos_medidasBERT, MELHOR_MEDIDA_GERAL_STR)

print("Lista de documentos perturbados medidos corretamente:",len(lista_documento_perturbado_medido_corretamente ))
# Out:
# Lista de documentos perturbados medidos corretamente: 4

# %%
print("Lista de documentos perturbados medidos corretamente(incoerentes)(CSm(DO) >= CSm(pertDO)):", len(lista_documento_perturbado_medido_corretamente ))
for i, documento in lista_documento_perturbado_medido_corretamente .iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos perturbados medidos corretamente(incoerentes)(CSm(DO) >= CSm(pertDO)): 4
#    0 - Como desempilhar elementos em uma imagem ? 0
#    1 - Como são feitas as operações de empilhar e desempilhar elementos em uma pilha ? 0
#    2 - Em uma pilha a operação de empilhar ocorre em qual extremidade ? 0
#    3 - Em uma fila a operação de entrada ocorre em qual extremidade ? 0

# %% [markdown]
# #### Lista Documentos Perturbados(0) medidos  incorretamente(1)

# %%
def listaPerturbadoMedidosIncorretamente(df_lista_pares_documentos_medidas, medida):
  lista_retorno = []  
  for i, linha in df_lista_pares_documentos_medidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + '_DO'] > linha[ medida + '_pertDO']:
         lista_retorno.append(linha['id_pertDO'])
    else:
        # Medida de distância (euc, man)
        if linha[medida + '_DO'] > linha[ medida + '_pertDO']:
           lista_retorno.append(linha['id_pertDO'])
          
  df_lista_retorno = pd.DataFrame(lista_retorno, columns = ["id"])
  return df_lista_retorno

# %%
lista_documento_perturbado_medido_incorretamente = listaPerturbadoMedidosIncorretamente(df_lista_pares_documentos_medidasBERT, MELHOR_MEDIDA_GERAL_STR)

print("Lista de documentos perturbados medidos incorretamente:",len(lista_documento_perturbado_medido_incorretamente))
# Out:
# Lista de documentos perturbados medidos incorretamente: 16

# %%
print("Lista de documentos perturbados medidos incorretamente(coerentes)(CSm(DO) < CSm(pertDO)):", len(lista_documento_perturbado_medido_incorretamente))
for i, documento in lista_documento_perturbado_medido_incorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos perturbados medidos incorretamente(coerentes)(CSm(DO) < CSm(pertDO)): 16
#    0 - Como colocar elementos em uma fila ? 0
#    1 - Como colocar elementos em uma fila ? 0
#    2 - Como colocar elementos em uma pilha ? 0
#    3 - Como empilhar e organizar elementos em uma pilha ? 0
#    4 - Como identificar elementos em uma estrutura de dados pilha ? 0
#    5 - Como introduzir e desempilhar elementos em uma estrutura de dados pilha ? 0
#    6 - Como desempilhar elementos em uma estrutura de uma pilha ? 0
#    7 - O que é uma pilha e como identificar seu elemento ? 0
#    8 - O que é uma fila e como identificar seu elemento ? 0
#    9 - O que é uma fila e como desenfileirar um carro nela ? 0
#    10 - O que é uma pilha e como colocar um elemento nela ? 0
#    11 - O que é uma fila e como colocar um elemento nela ? 0
#    12 - O que é uma pilha e como colocar um elemento nela ? 0
#    13 - O que é uma pilha e como separar e desempilhar seus elementos ? 0
#    14 - O que é uma fila e como organizar e desenfileirar seus elementos ? 0
#    15 - Como são implementadas as operações de separar e desenfileirar elementos em uma fila ? 0

# %% [markdown]
# ## 3.4 Estatísticas das Medidas

# %% [markdown]
# # 5 Compara os resultados
#
# Listas das classificações
# * lista_documento_original_classificado_corretamente
# * lista_documento_original_classificado_incorretamente
# * lista_documento_perturbado_classificado_corretamente
# * lista_documento_perturbado_classificado_incorretamente
#
#
# Lista das medições
# * lista_documento_original_medido_corretamente 12
# * lista_documento_original_medido_incorretamente 8
# * lista_documento_perturbado_medido_corretamente 12
# * lista_documento_perturbado_medido_incorretamente 8

# %%
total_classificacao = (len(lista_documento_original_classificado_corretamente) + 
                       len(lista_documento_original_classificado_incorretamente) + 
                       len(lista_documento_perturbado_classificado_corretamente) + 
                       len(lista_documento_perturbado_classificado_incorretamente))
print("total_classificacao:", total_classificacao)

print("DO classificados corretamente:", 
      len(lista_documento_original_classificado_corretamente), 
      " / {0:.2%} do total".format(len(lista_documento_original_classificado_corretamente)/total_classificacao))
print("DO classificados incorretamente:", 
      len(lista_documento_original_classificado_incorretamente), 
      " / {0:.2%} do total".format(len(lista_documento_original_classificado_incorretamente)/total_classificacao))
print("pertDO classificados corretamente:", 
      len(lista_documento_perturbado_classificado_corretamente), 
      " / {0:.2%} do total".format(len(lista_documento_perturbado_classificado_corretamente)/total_classificacao))
print("pertDO classificados incorretamente:", 
      len(lista_documento_perturbado_classificado_incorretamente), 
      " / {0:.2%} do total".format(len(lista_documento_perturbado_classificado_incorretamente)/total_classificacao))

total_medicao = (len(lista_documento_original_medido_corretamente) +
                 len(lista_documento_original_medido_incorretamente) + 
                 len(lista_documento_perturbado_medido_corretamente) + 
                 len(lista_documento_perturbado_medido_incorretamente))

print()
print("total_medicao:",total_medicao)

print("DO medidos corretamente:", 
      len(lista_documento_original_medido_corretamente), 
      " / {0:.2%} do total".format(len(lista_documento_original_medido_corretamente)/total_medicao))
print("DO medidos incorretamente:", 
      len(lista_documento_original_medido_incorretamente), 
      " / {0:.2%} do total".format(len(lista_documento_original_medido_incorretamente)/total_medicao))
print("pertDO medidos corretamente:", 
      len(lista_documento_perturbado_medido_corretamente), 
      " / {0:.2%} do total".format(len(lista_documento_perturbado_medido_corretamente)/total_medicao))
print("pertDO medidos incorretamente:", 
      len(lista_documento_perturbado_medido_incorretamente), 
      " / {0:.2%} do total".format(len(lista_documento_perturbado_medido_incorretamente)/total_medicao))
# Out:
# total_classificacao: 800
# DO classificados corretamente: 400  / 50.00% do total
# DO classificados incorretamente: 0  / 0.00% do total
# pertDO classificados corretamente: 397  / 49.62% do total
# pertDO classificados incorretamente: 3  / 0.38% do total
#
# total_medicao: 40
# DO medidos corretamente: 18  / 45.00% do total
# DO medidos incorretamente: 2  / 5.00% do total
# pertDO medidos corretamente: 18  / 45.00% do total
# pertDO medidos incorretamente: 2  / 5.00% do total

# %% [markdown]
# ## Documentos originais classificados e medidos corretamente

# %%
lista_intersecao = []
for i, documento1 in lista_documento_original_classificado_corretamente.iterrows():
  procura = documento1["id"]
  documento2 = lista_documento_original_medido_corretamente.loc[lista_documento_original_medido_corretamente["id"] == procura]
  if len(documento2) != 0:        
      lista_intersecao.append(documento1["id"])

# %%
if len(lista_intersecao) != 0:    
  percentual = len(lista_intersecao)/total_classificacao
  print ("Lista de documentos originais que foram classificados e medidos corretamente: ", len(lista_intersecao), " / {0:.2%} do total".format( percentual))
  for i, x in enumerate(lista_intersecao):
    if i < 100:
      print(x)
else:
  print("Não existe documentos originais que foram classificados e medidos corretamente ")
# Out:
# Lista de documentos originais que foram classificados e medidos corretamente:  360  / 45.00% do total
# 1
# 1
# 1
# 1
# 2
# 5
# 5
# 5
# 9
# 9
# 9
# 4
# 14
# 19
# 19
# 19
# 19
# 10
# 10
# 12
# 12
# 11
# 11
# 11
# 13
# 3
# 20
# 20
# 20
# 6
# 15
# 15
# 17
# 17
# 17
# 17
# 18
# 5
# 9
# 4
# 4
# 4
# 14
# 14
# 14
# 14
# 19
# 10
# 12
# 12
# 12
# 5
# 12
# 12
# 11
# 11
# 13
# 13
# 20
# 20
# 20
# 6
# 3
# 1
# 1
# 6
# 6
# 15
# 15
# 16
# 16
# 16
# 16
# 18
# 18
# 18
# 5
# 5
# 5
# 5
# 5
# 5
# 9
# 9
# 9
# 4
# 4
# 14
# 14
# 19
# 19
# 10
# 12
# 11
# 13
# 13
# 13
# 20
# 1
# 2

# %% [markdown]
# ## Documentos originais classificados e medidos incorretamente

# %%
lista_intersecao = []
for i, documento1 in lista_documento_original_classificado_incorretamente.iterrows():
  procura = documento1["id"]
  documento2 = lista_documento_original_medido_incorretamente.loc[lista_documento_original_medido_incorretamente["id"] == procura]
  if len(documento2) != 0:        
      lista_intersecao.append(documento1["id"])

# %%
if len(lista_intersecao) != 0:    
  percentual = len(lista_intersecao)/total_classificacao
  print ("Lista de documentos originais que foram classificados e medidos incorretamente: ", len(lista_intersecao), " / {0:.2%} do total".format( percentual))
  for i, x in enumerate(lista_intersecao):
    if i < 100:
      print(x)
else:
  print("Não existe documentos originais que foram classificados e medidos incorretamente ")
# Out:
# Não existe documentos originais que foram classificados e medidos incorretamente

# %% [markdown]
# ## Documentos perturbados classificados e medidos corretamente

# %%
lista_intersecao = []
for i, documento1 in lista_documento_perturbado_classificado_corretamente.iterrows():
  procura = documento1["id"]
  documento2 = lista_documento_perturbado_medido_corretamente.loc[lista_documento_perturbado_medido_corretamente["id"] == procura]
  if len(documento2) != 0:        
      lista_intersecao.append(documento1["id"])

# %%
if len(lista_intersecao) != 0:    
  percentual = len(lista_intersecao)/total_classificacao
  print ("Lista de documentos perturbados que foram classificados e medidos corretamente: ", len(lista_intersecao), " / {0:.2%} do total".format( percentual))
  for i, x in enumerate(lista_intersecao):
    if i < 100:
      print(x)
else:
  print("Não existe documentos perturbados que foram classificados e medidos corretamente ")
# Out:
# Lista de documentos perturbados que foram classificados e medidos corretamente:  18  / 2.25% do total
# 5_pert_0
# 10_pert_0
# 19_pert_0
# 14_pert_0
# 16_pert_0
# 1_pert_0
# 18_pert_0
# 9_pert_0
# 6_pert_0
# 20_pert_0
# 17_pert_0
# 3_pert_0
# 4_pert_0
# 13_pert_0
# 11_pert_0
# 12_pert_0
# 2_pert_0
# 15_pert_0

# %% [markdown]
# ## Documentos perturbados classificados e medidos incorretamente

# %%
lista_intersecao = []
for i, documento1 in lista_documento_perturbado_classificado_incorretamente.iterrows():
  procura = documento1["id"]
  documento2 = lista_documento_perturbado_medido_incorretamente.loc[lista_documento_perturbado_medido_incorretamente["id"] == procura]
  if len(documento2) != 0:        
      lista_intersecao.append(documento1["id"])

# %%
if len(lista_intersecao) != 0:    
  percentual = len(lista_intersecao)/total_classificacao
  print ("Lista de documentos perturbados que foram classificados e medidos incorretamente: ", len(lista_intersecao), " / {0:.2%} do total".format( percentual))
  for i, x in enumerate(lista_intersecao):
    if i < 20:
      print(x)
else:
  print("Não existe documentos perturbados que foram classificados e medidos incorretamente ")
# Out:
# Não existe documentos perturbados que foram classificados e medidos incorretamente

# %% [markdown]
# # 6 Finalização

# %% [markdown]
# ## 6.3 Tempo final de processamento
#
# Tempo processamento:  1:34:52 (h:mm:ss)

# %%
 # Pega o tempo atual menos o tempo do início do processamento.
final_processamento = time.time()
tempo_total_processamento = formataTempo(final_processamento - inicio_processamento)

print('')
print('  Tempo processamento:  {:} (h:mm:ss)'.format(tempo_total_processamento))
# Out:
#   Tempo processamento:  0:01:41 (h:mm:ss)
