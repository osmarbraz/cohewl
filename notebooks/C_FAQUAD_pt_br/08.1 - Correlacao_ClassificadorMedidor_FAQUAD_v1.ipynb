# %% [markdown]
# # Análise de Correlação do Classificador e Cálculo coerência do conjunto de dados FAQUAD.
#
# Realiza a análise de correlação entre as classificações realizadas e o cálculo de medida de coerência utilizando BERT no FAQUAD.
#
# ----------------------------
#
# **Link biblioteca Transformers:**
# https://github.com/huggingface/transformers
#
# **Artigo original BERT:**
# https://arxiv.org/pdf/1506.06724.pdf
#
# **Artigo padding dinâmico:**
# https://towardsdatascience.com/divide-hugging-face-transformers-training-time-by-2-or-more-21bf7129db9q-21bf7129db9e

# %% [markdown]
# # 1 Preparação do ambiente
# Preparação do ambiente para execução do exemplo.

# %% [markdown]
# ## 1.1 Tempo inicial de processamento

# %%
# Import das bibliotecas
import time
import datetime

#marca o tempo de início do processamento.
inicioProcessamento = time.time()

# %% [markdown]
# ## 1.2 Funções e classes auxiliares

# %% [markdown]
# Verifica se existe o diretório cohebert no diretório corrente.

# %%
# Import das bibliotecas.
import os # Biblioteca para manipular arquivos

# ============================  
def verificaDiretorioCoheBERT():
    """
      Verifica se existe o diretório cohebert no diretório corrente.    
    """
    
    # Verifica se o diretório existe
    if not os.path.exists(DIRETORIO_COHEBERT):  
        # Cria o diretório
        os.makedirs(DIRETORIO_COHEBERT)
        logging.info("Diretório Cohebert criado: {}".format(DIRETORIO_COHEBERT))
    
    return DIRETORIO_COHEBERT

# %% [markdown]
# Realiza o download e um arquivo

# %%
# Import das bibliotecas.
import requests # Biblioteca de download
from tqdm.notebook import tqdm as tqdm_notebook # Biblioteca para barra de progresso
import os # Biblioteca para manipular arquivos

def downloadArquivo(url_arquivo, nome_arquivo_destino):
    """    
      Realiza o download de um arquivo de uma url em salva em nome_arquivo_destino.
    
      Parâmetros:
        `url_arquivo` - URL do arquivo a ser feito download.      
        `nome_arquivo_destino` - Nome do arquivo a ser salvo.      
    """
    
    # Verifica se existe o diretório base
    DIRETORIO_COHEBERT = verificaDiretorioCoheBERT()
    
    # Realiza o download de um arquivo em uma url
    data = requests.get(url_arquivo, stream=True)
    
    # Verifica se o arquivo existe
    if data.status_code != 200:
        logging.info("Exceção ao tentar realizar download {}. Response {}.".format(url_arquivo, data.status_code))
        data.raise_for_status()
        return

    # Recupera o nome do arquivo a ser realizado o download    
    nome_arquivo = nome_arquivo_destino.split("/")[-1]  

    # Define o nome e caminho do arquivo temporário    
    nome_arquivo_temporario = DIRETORIO_COHEBERT + "/" + nome_arquivo + "_part"
    
    logging.info("Download do arquivo: {}.".format(nome_arquivo_destino))
    
    # Baixa o arquivo
    with open(nome_arquivo_temporario, "wb") as arquivo_binario:        
        tamanho_conteudo = data.headers.get("Content-Length")        
        total = int(tamanho_conteudo) if tamanho_conteudo is not None else None
        # Barra de progresso de download
        progresso_bar = tqdm_notebook(unit="B", total=total, unit_scale=True)                
        # Atualiza a barra de progresso
        for chunk in data.iter_content(chunk_size=1024):        
            if chunk:                
                progresso_bar.update(len(chunk))
                arquivo_binario.write(chunk)
    
    # Renomeia o arquivo temporário para o arquivo definitivo
    os.rename(nome_arquivo_temporario, nome_arquivo_destino)
    
    # Fecha a barra de progresso.
    progresso_bar.close()

# %% [markdown]
# Remove tags de um documento

# %%
def remove_tags(documento):
    """
      Remove tags de um documento
    """
    
    import re

    documentoLimpo = re.compile("<.*?>")
    return re.sub(documentoLimpo, "", documento)

# %% [markdown]
# Funções auxiliares de arquivos

# %%
def carregar(nomeArquivo, encoding="Windows-1252"):
    """
      Carrega um arquivo texto e retorna as linhas como um único parágrafo(texto).
    
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser carregado.  
    """

    # Abre o arquivo
    arquivo = open(nomeArquivo, "r", encoding= encoding)
    
    paragrafo = ""
    for linha in arquivo:
        linha = linha.splitlines()
        linha = " ".join(linha)
        # Remove as tags existentes no final das linhas
        linha = remove_tags(linha)
        if linha != "":
          paragrafo = paragrafo + linha.strip() + " "
    
    # Fecha o arquivo
    arquivo.close()

    # Remove os espaços em branco antes e depois do parágrafo
    return paragrafo.strip()

# %%
def carregarLista(nomeArquivo, encoding="Windows-1252"):
    """
      Carrega um arquivo texto e retorna as linhas como uma lista de sentenças(texto).
    
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser carregado.   
        `encoding` - Codificação dos caracteres do arquivo.
    """

    # Abre o arquivo
    arquivo = open(nomeArquivo, "r", encoding= encoding)
    
    sentencas = []
    for linha in arquivo:        
        linha = linha.splitlines()
        linha = " ".join(linha)
        linha = remove_tags(linha)
        if linha != "":
          sentencas.append(linha.strip())
    
    # Fecha o arquivo
    arquivo.close()

    return sentencas

# %%
def salvar(nomeArquivo,texto):                       
    """
      Salva um texto em arquivo.
     
      Parâmetros:
        `nome_arquivo` - Nome do arquivo a ser salvo.
        `texto` - Texto a ser salvo.     
    """

    arquivo = open(nomeArquivo, "w")
    arquivo.write(str(texto))
    arquivo.close()

# %% [markdown]
# Função auxiliar para formatar o tempo como `hh: mm: ss`

# %%
# Import das bibliotecas.
import time
import datetime

def formataTempo(tempo):
    """
      Pega a tempo em segundos e retorna uma string hh:mm:ss
    """
    # Arredonda para o segundo mais próximo.
    tempoArredondado = int(round((tempo)))
    
    # Formata como hh:mm:ss
    return str(datetime.timedelta(seconds=tempoArredondado))

# %% [markdown]
# Calcula a média de uma lista tempo string no formato hh:mm:ss.

# %%
# Import das bibliotecas.
from cmath import rect, phase
from math import radians, degrees
  
def mediaAngulo(deg):
    return degrees(phase(sum(rect(1, radians(d)) for d in deg)/len(deg)))
 
def mediaTempo(tempos):
    '''
    Calcula a média de uma lista de tempo string no formato hh:mm:ss
    '''
    t = (tempo.split(':') for tempo in tempos)
    # Converte para segundos
    segundos = ((float(s) + int(m) * 60 + int(h) * 3600) for h, m, s in t)
    # Verifica se deu algum dia
    dia = 24 * 60 * 60
    # Converte para angulos
    paraAngulos = [s * 360. / dia for s in segundos]
    # Calcula a média dos angulos
    mediaComoAngulo = mediaAngulo(paraAngulos)
    media_segundos = mediaComoAngulo * dia / 360.
    if media_segundos < 0:
        media_segundos += dia
    # Recupera as horas e os minutos  
    h, m = divmod(media_segundos, 3600)
    # Recupera os minutos e os segundos
    m, s = divmod(m, 60)    
    return '{:02d}:{:02d}:{:02d}'.format(int(h), int(m), int(s))

# %% [markdown]
# Calcula a soma de uma lista de tempo string no formato hh:mm:ss

# %%
def somaTempo(tempos):
    '''
    Calcula a soma de uma lista de tempo string no formato hh:mm:ss
    '''
    t = (tempo.split(':') for tempo in tempos)
    # Converte para segundos
    segundos = ((float(s) + int(m) * 60 + int(h) * 3600) for h, m, s in t)
    # Soma os segundos
    soma_segundos = sum([s * 1. for s in segundos])
    # Recupera as horas e os minutos   
    h, m = divmod(soma_segundos, 3600)
    # Recupera os minutos e os segundos
    m, s = divmod(m, 60)    
    return '{:02d}:{:02d}:{:02d}'.format(int(h), int(m), int(s))

# %% [markdown]
# Classe(ModeloArgumentosMedida) de definição dos parâmetros do modelo para medida

# %%
# Import das bibliotecas.
from dataclasses import dataclass, field
from typing import Dict, Optional
from typing import List

@dataclass
class ModeloArgumentosMedida:
    max_seq_len: Optional[int] = field(
        default=None,
        metadata={'help': 'max seq len'},
    )    
    pretrained_model_name_or_path: str = field(
        default='neuralmind/bert-base-portuguese-cased',
        metadata={'help': 'nome do modelo pré-treinado do BERT.'},
    )
    modelo_spacy: str = field(
        default="pt_core_news_lg",
        metadata={"help": "nome do modelo do spaCy."},
    )
    versao_modelo_spacy: str = field(
        default="-3.2.0",
        metadata={"help": "versão do nome do modelo no spaCy."},
    )
    do_lower_case: bool = field(
        default=False,
        metadata={'help': 'define se o texto do modelo deve ser todo em minúsculo.'},
    )  
    output_attentions: bool = field(
        default=False,
        metadata={'help': 'habilita se o modelo retorna os pesos de atenção.'},
    )
    output_hidden_states: bool = field(
        default=False,
        metadata={'help': 'habilita gerar as camadas ocultas do modelo.'},
    )
    use_wandb : bool = field(
        default=True,
        metadata={'help': 'habilita o uso do wandb.'},
    )
    salvar_avaliacao : bool = field(
        default=True,
        metadata={'help': 'habilita o salvamento do resultado da avaliação.'},
    )     
    salvar_medicao : bool = field(
        default=False,
        metadata={'help': 'habilita o salvamento da medicao.'},
    )
    usar_mcl_ajustado : bool = field(
        default=False,
        metadata={'help': 'habilita o carragamento de mcl ajustado.'},
    )
    top_k_predicao: int = field(
        default="100",
        metadata={"help": "Quantidade de palavras a serem recuperadas mais próximas da máscara."},
    )
    numero_documentos_perturbados: int = field(
        default="1",
        metadata={"help": "Quantidade de documentos a serem perturbados a partir do original."},
    )
    estrategia_medida: int = field(
        default=0, # 0 - MEAN estratégia média / 1 - MAX  estratégia maior
        metadata={'help': 'Estratégia de cálculo da médida dos embeddings.'},
    )
    filtro_palavra: int = field(
        default=0, # 0 - Considera todas as palavras das sentenças / 1 - Desconsidera as stopwords / 2 - Considera somente as palavras substantivas
        metadata={'help': 'Define o filtro de palavras das sentenças para gerar os embeddings.'},
    )

# %% [markdown]
# Biblioteca de limpeza de tela

# %%
# Import das bibliotecas.
from IPython.display import clear_output

# %% [markdown]
# ## 1.3 Tratamento de logs

# %%
# Import das bibliotecas.
import logging # Biblioteca de logging

# Formatando a mensagem de logging
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s")

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ## 1.4  Identificando o ambiente Colab

# %%
# Se estiver executando no Google Colaboratory.
import sys

# Retorna true ou false se estiver no Google Colaboratory.
IN_COLAB = 'google.colab' in sys.modules

# %% [markdown]
# ## 1.5 Colaboratory

# %% [markdown]
# Usando Colab GPU para Treinamento

# %% [markdown]
# Uma GPU pode ser adicionada acessando o menu e selecionando:
#
# `Edit -> Notebook Settings -> Hardware accelerator -> (GPU)`
#
# Em seguida, execute a célula a seguir para confirmar que a GPU foi detectada.

# %%
# Import das bibliotecas.
import tensorflow as tf

# Recupera o nome do dispositido da GPU.
device_name = tf.test.gpu_device_name()

# O nome do dispositivo deve ser parecido com o seguinte:
if device_name == "/device:GPU:0":
    logging.info("Encontrei GPU em: {}".format(device_name))
else:
    logging.info("Dispositivo GPU não encontrado")
    #raise SystemError("Dispositivo GPU não encontrado")
# Out:
# 2022-03-18 12:45:09,822 : INFO : NumExpr defaulting to 2 threads.
# 2022-03-18 12:45:10,323 : INFO : Dispositivo GPU não encontrado

# %% [markdown]
# Nome da GPU
#
# Para que a torch use a GPU, precisamos identificar e especificar a GPU como o dispositivo. Posteriormente, em nosso ciclo de treinamento, carregaremos dados no dispositivo.
#
# Vale a pena observar qual GPU você recebeu. A GPU Tesla P100 é muito mais rápido que as outras GPUs, abaixo uma lista ordenada:
# - 1o Tesla P100
# - 2o Tesla T4
# - 3o Tesla P4 (Não tem memória para execução 4 x 8, somente 2 x 4)
# - 4o Tesla K80 (Não tem memória para execução 4 x 8, somente 2 x 4)

# %%
# Import das bibliotecas.
import torch

def getDeviceGPU():
    """
      Retorna um dispositivo de GPU se disponível ou CPU.
    
      Retorno:
        `device` - Um device de GPU ou CPU.       
    """
        
    # Se existe GPU disponível.
    if torch.cuda.is_available():
        
        # Diz ao PyTorch para usar GPU.    
        device = torch.device("cuda")
        
        logging.info("Existem {} GPU(s) disponíveis.".format(torch.cuda.device_count()))
        logging.info("Iremos usar a GPU: {}.".format(torch.cuda.get_device_name(0)))

    # Se não.
    else:        
        logging.info("Sem GPU disponível, usando CPU.")
        device = torch.device("cpu")
        
    return device

# %%
# Recupera o device com GPU ou CPU
device = getDeviceGPU()
# Out:
# 2022-03-18 12:45:16,267 : INFO : Sem GPU disponível, usando CPU.

# %% [markdown]
# Memória
#
# Memória disponível no ambiente

# %%
# Importando as bibliotecas.
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
logging.info("Seu ambiente de execução tem {: .1f} gigabytes de RAM disponível\n".format(ram_gb))

if ram_gb < 20:
  logging.info("Para habilitar um tempo de execução de RAM alta, selecione menu o ambiente de execução> \"Alterar tipo de tempo de execução\"")
  logging.info("e selecione High-RAM. Então, execute novamente está célula")
else:
  logging.info("Você está usando um ambiente de execução de memória RAM alta!")
# Out:
# 2022-03-18 12:45:16,300 : INFO : Seu ambiente de execução tem  13.6 gigabytes de RAM disponível
#
# 2022-03-18 12:45:16,304 : INFO : Para habilitar um tempo de execução de RAM alta, selecione menu o ambiente de execução> "Alterar tipo de tempo de execução"
# 2022-03-18 12:45:16,308 : INFO : e selecione High-RAM. Então, execute novamente está célula

# %% [markdown]
# ## 1.6 Monta uma pasta no google drive para carregar os arquivos de dados.

# %%
# import necessário
from google.colab import drive

# Monta o drive na pasta especificada
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2 Parametrização

# %% [markdown]
# ## Gerais

# %%
# Nome base das saidas do projeto
NOMEBASESAIDA = "MedidaCoerenciaFaquad_v1"

# Definição dos parâmetros a serem avaliados
#Quantidade de documentos a serem perturbados a partir do original.
NUMERO_DOCUMENTOS_PERTURBADOS = 20

#Quantidade de palavras a serem recuperadas mais próximas da máscara.
TOP_K_PREDICAO = 20

# %% [markdown]
# ## Específicos

# %% [markdown]
# Parâmetros do modelo

# %%
# Definição dos parâmetros do Modelo
model_args = ModeloArgumentosMedida(     
    max_seq_len = 512,    
    pretrained_model_name_or_path = "https://neuralmind-ai.s3.us-east-2.amazonaws.com/nlp/bert-large-portuguese-cased/bert-large-portuguese-cased_pytorch_checkpoint.zip",
    #pretrained_model_name_or_path = "https://neuralmind-ai.s3.us-east-2.amazonaws.com/nlp/bert-base-portuguese-cased/bert-base-portuguese-cased_pytorch_checkpoint.zip",
    #pretrained_model_name_or_path = "neuralmind/bert-large-portuguese-cased",
    #pretrained_model_name_or_path = "neuralmind/bert-base-portuguese-cased",    
    #pretrained_model_name_or_path = "bert-base-multilingual-cased",
    #pretrained_model_name_or_path = "bert-base-multilingual-uncased",
    modelo_spacy = "pt_core_news_lg",
    #modelo_spacy = "pt_core_news_md",
    #modelo_spacy = "pt_core_news_sm",
    versao_modelo_spacy = "3.2.0",
    do_lower_case = False,  # default True
    output_attentions = False,  # default False
    output_hidden_states = True, # default False
    use_wandb = True,    
    salvar_medicao = True, #Salva o resultado da medição
    salvar_avaliacao = True, # Salva o resultado da avaliação das medições
    usar_mcl_ajustado = False, # Especifica se deve ser carregado um MCL ajustado ou pré-treinado. Necessário especificar o tipo do modelo em pretrained_model_name_or_path. 
    numero_documentos_perturbados = NUMERO_DOCUMENTOS_PERTURBADOS, # Quantidade de documentos a serem perturbados a partir do original.
    top_k_predicao = TOP_K_PREDICAO, # Conjunto de valores: 1, 10, 100, 500 e 1000. Quantidade de palavras a serem recuperadas mais próximas da máscara. 
    estrategia_medida = 0, # Atributo usado para os logs do wandb. 0 - MEAN estratégia média / 1 - MAX  estratégia maior
    filtro_palavra = 0 # Atributo usado para os logs do wandb. 0 - Considera todas as palavras das sentenças / 1 - Desconsidera as stopwords / 2 - Considera somente as palavras substantivas
)

# %% [markdown]
# ## Nome do diretório dos arquivos de dados

# %%
# Diretório do cohebert
DIRETORIO_COHEBERT = "FAQUAD"

# %% [markdown]
# ## Define o caminho para os arquivos de dados

# %%
# Diretório local para os arquivos pré-processados
DIRETORIO_LOCAL = "/content/" + DIRETORIO_COHEBERT + "/"

# Diretório no google drive com os arquivos pré-processados
DIRETORIO_DRIVE = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/"

# %% [markdown]
# # 3 Resultado do Classificador Binário usando o Método Kfold

# %%
# Nome base das saidas do projeto C = Cris, SB = SmartBatch, KF = KFold
NOMEBASESAIDA = "AjusteFinoFaquad_C_SB_KF_v1"

# %% [markdown]
# ## 3.1 Carrega o resultado e parâmetros da melhor classificação

# %% [markdown]
# ### 3.1.1 Função que encontra a melhor classificação

# %%
# Import das bibliotecas.
import os
import pandas as pd

def getResultadosClassificacaoKFold(DIRETORIO_COHEBERT, 
                                         _DOCUMENTOS_PERTURBADOS, 
                                         _TOP_K_PREDICAO):
  
  # Numero de Folds
  KFOLDS = 10

  # Quantidade de documentos a serem perturbados a partir do original.    
  DOCUMENTOS_PERTURBADOS = _DOCUMENTOS_PERTURBADOS

  # Quantidade de palavras a serem recuperadas mais próximas da máscara. 
  TOP_K_PREDICAO = _TOP_K_PREDICAO

  # MCL a serem avaliados
  #MODELO_BERT = ['_BERTimbau','_BERTmultilingual']
  MODELO_BERT = ['_BERTimbau']

  #TAMANHO_BERT = ['_base','_large']
  TAMANHO_BERT = ['_large']
  
  # Taxa de aprendizagem do nome do arquivo
  TAXAS_DE_APRENDIZAGEM = [1, 2, 3, 4, 5]

  # Tamanho dos lotes
  TAMANHO_LOTE = [16, 32]

  # Salva resultados intermediários
  EPOCA = [2, 3, 4]

  # Diretório para salvar o arquivo.
  DIRETORIO_AVALIACAO = "/content/drive/My Drive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_classificacao_palavra/kfold/Avaliacao/"  

  MELHOR_DOCUMENTOS_PERTURBADOS = 0
  MELHOR_TOP_K_PREDICAO = 0
  MELHOR_TAXAS_DE_APRENDIZAGEM = 0
  MELHOR_TAMANHO_LOTE = 0
  MELHOR_EPOCA_EXECUCA = 0
  MELHOR_ACURACIA = 0
  MELHOR_TEMPO = 0

  lista_resultados = []

  listaTempoTotal = []  
  
  # Verifica se o diretório dos resultados existe.
  if os.path.exists(DIRETORIO_AVALIACAO):    
    for modelo in MODELO_BERT:    
      for tamanho in TAMANHO_BERT:
        if modelo != '_BERTmultilingual' or tamanho != '_large':                  
          for documentos_perturbados in DOCUMENTOS_PERTURBADOS:
            for top_k_predicao in TOP_K_PREDICAO:              
              DIRETORIO_AVALIACAO_PK = DIRETORIO_AVALIACAO + "P_" + str(documentos_perturbados) + "_K_" + str(top_k_predicao) + "/"              
              # Verifica se o diretório dos resultados existe.
              if os.path.exists(DIRETORIO_AVALIACAO_PK):
                arquivos = os.listdir(DIRETORIO_AVALIACAO_PK) 
                contaRegR = 0
                for lote in TAMANHO_LOTE:
                  for taxaaprendizagem in TAXAS_DE_APRENDIZAGEM:                      
                    for epoca in EPOCA:  
                        # Acumuladores.
                        somaAcuracia = 0
                        listaTempo = []
                        contaFolds = 0 
                        contaReg = 0
                        
                        for i in range(len(arquivos)):
                          for fold in range(1,11):
                            # Filtra o nome do arquivo a ser avaliado                                                     
                            if ((("_P_" + str(documentos_perturbados)+"_") in arquivos[i]) 
                                  and (("_K_" + str(top_k_predicao)+"_") in arquivos[i]) 
                                  and (("_b_" + str(lote)) in arquivos[i]) 
                                  and (modelo in arquivos[i]) 
                                  and (tamanho in arquivos[i]) 
                                  and (('_f' + str(fold) + '_') in arquivos[i]) 
                                  and (("e_" + str(epoca)) in arquivos[i]) 
                                  and (("lr_" + str(taxaaprendizagem)) in arquivos[i])):                           

                                NOME_ARQUIVO_AVALIACAO_COMPLETO = DIRETORIO_AVALIACAO_PK + arquivos[i]                              
                                # Verifica se o arquivo existe.
                                if os.path.isfile(NOME_ARQUIVO_AVALIACAO_COMPLETO):
                                  # Carrega os dados do arquivo  
                                  dados = pd.read_csv(NOME_ARQUIVO_AVALIACAO_COMPLETO, sep=';')
                      
                                  # Conta o número de folds.
                                  contaFolds = contaFolds + 1
                                  
                                  # Mostra os dados do teste do fold.
                                  for index, linha in dados.iterrows():        
                                    # Cálculo das estatísticas
                                    acc = (linha['vp']+linha['vn'])/(linha['vp']+linha['vn']+linha['fp']+linha['fn'])                         
                                    #print('{};{};{};{:.8f};{}'.format(fold, index, arquivos[i],acc,linha['tempo']))
                                    # Guarda o tempo.
                                    listaTempo.append(str(linha['tempo']))
                                    # Conta o número de registros.
                                    contaReg = contaReg + 1
                                    
                                  # Realiza a soma da acurácia do arquivo.
                                  somaAcuracia = somaAcuracia + dados['acuracia'].sum()
                                        
                        if contaFolds != 0:
                          # Calcula a média.                          
                          mediaAcuracia = somaAcuracia/contaReg

                          # Guarda os resultados de todos os folds  
                          lista_resultados.append([documentos_perturbados,top_k_predicao,taxaaprendizagem,lote,epoca, mediaAcuracia, somaTempo(listaTempo)])
                          
                          if mediaAcuracia > MELHOR_ACURACIA:
                              MELHOR_DOCUMENTOS_PERTURBADOS = documentos_perturbados
                              MELHOR_TOP_K_PREDICAO = top_k_predicao
                              MELHOR_TAXAS_DE_APRENDIZAGEM = taxaaprendizagem
                              MELHOR_TAMANHO_LOTE = lote
                              MELHOR_EPOCA_EXECUCAO = epoca
                              MELHOR_ACURACIA = mediaAcuracia
                              MELHOR_TEMPO = somaTempo(listaTempo)
                       
                        else:                          
                            print('Nenhum arquivo de avaliação encontrado')
                
              else:
                print('Diretório ' + 'P_' + str(documentos_perturbados) + '_K_' + str(top_k_predicao) + ' não encontrado')                        
    
    # Retorno do melhor valor
    lista_resultado_ordenado = sorted(lista_resultados, key=lambda x: x[5], reverse=True)
    return MELHOR_DOCUMENTOS_PERTURBADOS, MELHOR_TOP_K_PREDICAO, MELHOR_TAXAS_DE_APRENDIZAGEM, MELHOR_TAMANHO_LOTE, MELHOR_EPOCA_EXECUCAO, MELHOR_ACURACIA, MELHOR_TEMPO, lista_resultado_ordenado
  else:
    print('Diretório com os resultados não encontrado')

# %% [markdown]
# Recupera os melhores resultados

# %%
DOCUMENTOS_PERTURBADOS = [1, 20]
TOP_K_PREDICAO = [1, 10, 100, 1000]

# Recupera os melhores parâmetros
MELHOR_DOCUMENTOS_PERTURBADOS, MELHOR_TOP_K_PREDICAO, MELHOR_TAXAS_DE_APRENDIZAGEM, MELHOR_TAMANHO_LOTE, MELHOR_EPOCA_EXECUCAO, MELHOR_ACURACIA, MELHOR_TEMPO, lista_resultados = getResultadosClassificacaoKFold(DIRETORIO_COHEBERT, DOCUMENTOS_PERTURBADOS, TOP_K_PREDICAO)

# %%
print("Parâmetros da melhor acurácia do classificador")
print("\n  Documentos Perturbados:", MELHOR_DOCUMENTOS_PERTURBADOS, 
      "\n  Top k predição        :", MELHOR_TOP_K_PREDICAO, 
      "\n  Taxa de aprendizagem  :", MELHOR_TAXAS_DE_APRENDIZAGEM, 
      "\n  Lote                  :", MELHOR_TAMANHO_LOTE, 
      "\n  Epoca execução        :", MELHOR_EPOCA_EXECUCAO, 
      "\n  Acurácia              :", MELHOR_ACURACIA, 
      "\n  Tempo execução        :", MELHOR_TEMPO)

print("\nLista das acurácias ranqueadas")
for i, linha in enumerate(lista_resultados):
    print((i+1),"=", linha)
# Out:
# Parâmetros da melhor acurácia do classificador
#
#   Documentos Perturbados: 20
#   Top k predição        : 1000
#   Taxa de aprendizagem  : 1
#   Lote                  : 16
#   Epoca execução        : 4
#   Acurácia              : 0.9880000000000001
#   Tempo execução        : 04:30:09
#
# Lista das acurácias ranqueadas
# 1 = [20, 1000, 1, 16, 4, 0.9880000000000001, '04:30:09']
# 2 = [20, 1000, 1, 32, 4, 0.9872222222222222, '03:13:19']
# 3 = [20, 1000, 1, 16, 3, 0.9854722222222222, '03:21:10']
# 4 = [20, 1000, 1, 16, 2, 0.9853888888888889, '02:12:39']
# 5 = [20, 1000, 1, 32, 3, 0.9844166666666666, '02:21:55']
# 6 = [20, 1000, 2, 32, 4, 0.9827499999999999, '03:14:09']
# 7 = [20, 100, 1, 16, 4, 0.9825555555555556, '05:09:49']
# 8 = [20, 1000, 2, 16, 3, 0.9803333333333333, '03:31:40']
# 9 = [20, 1000, 2, 16, 4, 0.9800833333333333, '04:44:18']
# 10 = [20, 1, 1, 16, 4, 0.9798611111111111, '05:10:13']
# 11 = [20, 1000, 1, 32, 2, 0.979638888888889, '01:32:44']
# 12 = [20, 1000, 2, 32, 3, 0.9793333333333333, '02:22:42']
# 13 = [20, 100, 1, 32, 4, 0.9783888888888888, '03:12:41']
# 14 = [20, 1000, 3, 32, 4, 0.9776944444444444, '03:12:14']
# 15 = [20, 1000, 2, 16, 2, 0.9774166666666668, '02:19:39']
# 16 = [20, 1000, 3, 32, 3, 0.9755, '02:21:18']
# 17 = [20, 100, 1, 16, 3, 0.9753055555555555, '03:32:48']
# 18 = [20, 100, 2, 16, 4, 0.97325, '05:41:26']
# 19 = [20, 10, 1, 16, 4, 0.9726111111111109, '06:19:34']
# 20 = [20, 100, 2, 32, 4, 0.9720833333333332, '03:16:08']
# 21 = [20, 100, 1, 32, 3, 0.9711666666666667, '02:21:46']
# 22 = [20, 1000, 2, 32, 2, 0.9704722222222222, '01:33:25']
# 23 = [20, 1000, 3, 16, 3, 0.9683611111111109, '03:40:15']
# 24 = [20, 100, 1, 16, 2, 0.9674722222222222, '02:13:48']
# 25 = [20, 10, 1, 16, 3, 0.9668333333333333, '04:20:36']
# 26 = [20, 1, 1, 16, 3, 0.9668055555555556, '03:33:35']
# 27 = [20, 100, 2, 16, 3, 0.9642222222222223, '03:54:41']
# 28 = [20, 10, 1, 32, 4, 0.9636111111111111, '03:09:46']
# 29 = [20, 1000, 3, 32, 2, 0.9635277777777779, '01:32:28']
# 30 = [20, 1, 1, 32, 4, 0.9629166666666666, '03:12:56']
# 31 = [20, 1000, 3, 16, 2, 0.9621666666666668, '02:25:16']
# 32 = [20, 1000, 3, 16, 4, 0.962111111111111, '04:55:50']
# 33 = [20, 100, 2, 32, 3, 0.9603611111111112, '02:24:10']
# 34 = [20, 100, 2, 16, 2, 0.9577222222222221, '02:27:08']
# 35 = [20, 1000, 4, 32, 2, 0.954111111111111, '01:34:37']
# 36 = [20, 100, 1, 32, 2, 0.9496944444444445, '01:32:46']
# 37 = [20, 10, 1, 32, 3, 0.9468888888888889, '02:19:40']
# 38 = [20, 1, 1, 32, 3, 0.9452222222222224, '02:22:02']
# 39 = [20, 100, 2, 32, 2, 0.9420833333333334, '01:34:27']
# 40 = [20, 10, 3, 32, 4, 0.9383055555555556, '03:15:59']
# 41 = [20, 10, 1, 16, 2, 0.9365555555555554, '02:43:22']
# 42 = [20, 1, 1, 16, 2, 0.9364444444444444, '02:14:26']
# 43 = [20, 100, 3, 16, 2, 0.9255277777777777, '02:14:48']
# 44 = [20, 10, 3, 32, 3, 0.9176666666666667, '02:24:09']
# 45 = [20, 1000, 4, 32, 3, 0.9135833333333331, '02:24:39']
# 46 = [20, 1, 2, 32, 4, 0.9117499999999998, '03:17:56']
# 47 = [20, 10, 1, 32, 2, 0.9065833333333334, '01:31:31']
# 48 = [20, 1, 1, 32, 2, 0.9027222222222223, '01:32:58']
# 49 = [1, 1000, 5, 32, 4, 0.8966666666666668, '00:17:35']
# 50 = [20, 1, 3, 32, 4, 0.8963055555555555, '03:25:01']
# 51 = [1, 1000, 4, 32, 4, 0.8961111111111112, '00:17:34']
# 52 = [20, 1, 2, 32, 3, 0.8934444444444445, '02:25:31']
# 53 = [1, 1000, 2, 16, 3, 0.8927777777777777, '00:15:52']
# 54 = [1, 1000, 2, 32, 3, 0.8927777777777777, '00:13:02']
# 55 = [1, 1000, 2, 32, 4, 0.8922222222222222, '00:17:32']
# 56 = [1, 1000, 2, 16, 4, 0.8916666666666666, '00:21:18']
# 57 = [1, 1000, 3, 16, 4, 0.8911111111111112, '00:21:14']
# 58 = [20, 100, 4, 32, 3, 0.8891944444444444, '02:25:26']
# 59 = [1, 1000, 4, 32, 3, 0.8872222222222221, '00:13:05']
# 60 = [1, 1000, 3, 16, 3, 0.8866666666666667, '00:15:51']
# 61 = [20, 100, 4, 32, 2, 0.8861666666666667, '01:35:15']
# 62 = [1, 1000, 1, 16, 3, 0.8861111111111111, '00:15:18']
# 63 = [1, 1000, 3, 32, 2, 0.8855555555555558, '00:08:32']
# 64 = [1, 1000, 3, 32, 4, 0.8855555555555557, '00:17:39']
# 65 = [1, 1000, 5, 16, 4, 0.8849999999999998, '00:21:33']
# 66 = [1, 1000, 2, 16, 2, 0.8844444444444444, '00:10:27']
# 67 = [1, 1000, 1, 16, 4, 0.8833333333333334, '00:20:32']
# 68 = [1, 1000, 4, 16, 2, 0.8827777777777778, '00:10:30']
# 69 = [1, 1000, 2, 32, 2, 0.8827777777777778, '00:08:30']
# 70 = [1, 1000, 4, 16, 3, 0.8822222222222222, '00:15:52']
# 71 = [1, 1000, 4, 16, 4, 0.8822222222222222, '00:21:17']
# 72 = [1, 1000, 5, 32, 3, 0.8822222222222222, '00:13:02']
# 73 = [1, 1000, 3, 32, 3, 0.881111111111111, '00:13:07']
# 74 = [20, 1, 3, 32, 3, 0.8788055555555555, '02:30:31']
# 75 = [1, 1000, 5, 16, 3, 0.8783333333333335, '00:16:06']
# 76 = [1, 1000, 1, 16, 2, 0.8783333333333333, '00:10:03']
# 77 = [20, 10, 3, 32, 2, 0.8770277777777779, '01:34:28']
# 78 = [20, 1000, 4, 16, 2, 0.876972222222222, '02:30:06']
# 79 = [20, 10, 2, 16, 4, 0.8741666666666668, '05:58:00']
# 80 = [1, 1000, 5, 32, 2, 0.8738888888888889, '00:08:31']
# 81 = [1, 1000, 4, 32, 2, 0.8722222222222223, '00:08:32']
# 82 = [1, 1000, 3, 16, 2, 0.8716666666666667, '00:10:27']
# 83 = [1, 1000, 1, 32, 4, 0.8716666666666667, '00:17:11']
# 84 = [20, 1000, 4, 32, 4, 0.8713611111111111, '03:16:43']
# 85 = [1, 1000, 5, 16, 2, 0.8705555555555555, '00:10:33']
# 86 = [1, 1000, 1, 32, 3, 0.8694444444444445, '00:12:46']
# 87 = [20, 1000, 4, 16, 3, 0.8646111111111111, '03:47:15']
# 88 = [20, 10, 2, 32, 4, 0.8645833333333333, '03:11:59']
# 89 = [20, 10, 2, 16, 3, 0.8637777777777778, '04:06:58']
# 90 = [20, 100, 3, 32, 4, 0.8624722222222223, '03:12:09']
# 91 = [20, 100, 3, 16, 3, 0.8618055555555554, '03:35:08']
# 92 = [1, 1000, 1, 32, 2, 0.8616666666666667, '00:08:17']
# 93 = [20, 100, 4, 32, 4, 0.8610833333333332, '03:17:54']
# 94 = [20, 100, 3, 16, 4, 0.8564722222222223, '05:12:56']
# 95 = [20, 100, 3, 32, 3, 0.8560277777777777, '02:21:21']
# 96 = [20, 1, 2, 32, 2, 0.855111111111111, '01:35:13']
# 97 = [20, 10, 2, 32, 3, 0.8491944444444444, '02:21:17']
# 98 = [20, 10, 2, 16, 2, 0.8418055555555556, '02:35:11']
# 99 = [20, 1, 3, 32, 2, 0.8408888888888889, '01:38:20']
# 100 = [20, 100, 3, 32, 2, 0.8373611111111112, '01:32:31']
# 101 = [20, 1, 2, 16, 4, 0.8289722222222222, '05:25:04']
# 102 = [20, 1000, 5, 32, 2, 0.8215277777777776, '01:36:09']
# 103 = [20, 10, 2, 32, 2, 0.8213888888888891, '01:32:37']
# 104 = [20, 1, 2, 16, 3, 0.8201666666666668, '03:43:58']
# 105 = [1, 100, 1, 16, 4, 0.7933333333333332, '00:20:09']
# 106 = [1, 100, 2, 32, 4, 0.7899999999999999, '00:17:32']
# 107 = [20, 1, 2, 16, 2, 0.7863271604938271, '02:06:20']
# 108 = [1, 100, 2, 16, 4, 0.7838888888888887, '00:20:44']
# 109 = [1, 100, 2, 16, 2, 0.7827777777777778, '00:10:08']
# 110 = [1, 100, 2, 16, 3, 0.7822222222222222, '00:15:26']
# 111 = [20, 10, 4, 32, 2, 0.7818611111111111, '01:38:20']
# 112 = [1, 100, 3, 32, 3, 0.7794444444444444, '00:13:06']
# 113 = [1, 100, 2, 32, 3, 0.7755555555555554, '00:13:01']
# 114 = [1, 100, 4, 32, 4, 0.775, '00:17:34']
# 115 = [1, 100, 5, 32, 4, 0.7744444444444445, '00:17:36']
# 116 = [1, 100, 3, 16, 3, 0.7733333333333332, '00:15:46']
# 117 = [1, 100, 1, 16, 3, 0.7727777777777777, '00:15:00']
# 118 = [1, 100, 4, 32, 3, 0.7711111111111111, '00:13:03']
# 119 = [1, 100, 5, 32, 2, 0.7694444444444444, '00:08:30']
# 120 = [1, 100, 1, 16, 2, 0.7672222222222221, '00:09:52']
# 121 = [1, 100, 4, 16, 3, 0.7661111111111111, '00:15:58']
# 122 = [1, 100, 3, 32, 4, 0.7661111111111111, '00:17:38']
# 123 = [1, 100, 3, 16, 4, 0.7655555555555555, '00:21:05']
# 124 = [1, 100, 3, 16, 2, 0.7644444444444444, '00:10:22']
# 125 = [1, 100, 3, 32, 2, 0.7644444444444444, '00:08:34']
# 126 = [1, 100, 4, 32, 2, 0.7633333333333333, '00:08:31']
# 127 = [1, 100, 4, 16, 2, 0.7627777777777778, '00:10:24']
# 128 = [1, 100, 5, 16, 3, 0.7627777777777778, '00:16:10']
# 129 = [1, 100, 1, 32, 4, 0.7622222222222221, '00:16:44']
# 130 = [1, 100, 4, 16, 4, 0.7605555555555555, '00:21:27']
# 131 = [1, 100, 1, 32, 3, 0.7605555555555555, '00:12:27']
# 132 = [1, 100, 2, 32, 2, 0.7605555555555555, '00:08:29']
# 133 = [1, 100, 5, 32, 3, 0.7605555555555555, '00:13:03']
# 134 = [1, 100, 5, 16, 4, 0.7577777777777778, '00:21:38']
# 135 = [20, 10, 3, 16, 3, 0.7573888888888888, '03:34:19']
# 136 = [1, 100, 5, 16, 2, 0.7483333333333333, '00:10:34']
# 137 = [20, 10, 3, 16, 2, 0.7385277777777778, '02:14:22']
# 138 = [20, 10, 4, 32, 4, 0.7371944444444445, '03:26:09']
# 139 = [20, 10, 4, 32, 3, 0.7361666666666667, '02:31:04']
# 140 = [20, 1000, 5, 32, 3, 0.734, '02:27:13']
# 141 = [1, 100, 1, 32, 2, 0.7222222222222222, '00:08:10']
# 142 = [20, 10, 3, 16, 4, 0.7130555555555554, '05:10:49']
# 143 = [20, 1000, 5, 16, 2, 0.6704444444444445, '02:22:44']
# 144 = [20, 1000, 5, 32, 4, 0.6704444444444444, '03:20:21']
# 145 = [1, 10, 3, 16, 4, 0.668888888888889, '00:21:07']
# 146 = [1, 1, 2, 16, 4, 0.6666666666666667, '00:20:18']
# 147 = [1, 10, 4, 32, 4, 0.6666666666666667, '00:17:42']
# 148 = [1, 1, 2, 32, 4, 0.665, '00:17:55']
# 149 = [1, 10, 3, 32, 3, 0.6644444444444446, '00:13:07']
# 150 = [1, 10, 3, 32, 4, 0.6633333333333334, '00:17:40']
# 151 = [1, 1, 1, 16, 4, 0.6627777777777779, '00:18:55']
# 152 = [20, 100, 5, 32, 2, 0.6624444444444444, '01:37:08']
# 153 = [1, 10, 2, 32, 4, 0.6611111111111112, '00:17:38']
# 154 = [1, 1, 2, 16, 3, 0.6605555555555556, '00:15:06']
# 155 = [1, 1, 4, 32, 4, 0.66, '00:18:03']
# 156 = [1, 1, 4, 32, 3, 0.6544444444444446, '00:13:24']
# 157 = [1, 10, 4, 32, 2, 0.6544444444444445, '00:08:34']
# 158 = [1, 10, 4, 32, 3, 0.653888888888889, '00:13:11']
# 159 = [20, 100, 5, 32, 3, 0.6533888888888889, '02:29:07']
# 160 = [1, 10, 5, 32, 3, 0.6533333333333335, '00:13:03']
# 161 = [1, 10, 2, 16, 4, 0.6533333333333334, '00:20:48']
# 162 = [1, 1, 2, 32, 3, 0.6527777777777778, '00:13:20']
# 163 = [1, 10, 1, 16, 4, 0.6522222222222223, '00:20:14']
# 164 = [1, 1, 3, 16, 4, 0.6516666666666667, '00:21:08']
# 165 = [1, 10, 3, 16, 3, 0.6511111111111113, '00:15:45']
# 166 = [1, 10, 2, 32, 3, 0.6500000000000001, '00:13:06']
# 167 = [1, 1, 1, 16, 3, 0.6494444444444445, '00:14:06']
# 168 = [1, 10, 2, 16, 3, 0.6483333333333333, '00:15:32']
# 169 = [1, 1, 1, 32, 4, 0.6477777777777778, '00:17:08']
# 170 = [1, 1, 1, 16, 2, 0.6472222222222223, '00:09:17']
# 171 = [1, 1, 3, 16, 3, 0.6455555555555555, '00:15:46']
# 172 = [1, 1, 2, 32, 2, 0.6433333333333333, '00:08:40']
# 173 = [1, 1, 3, 32, 3, 0.6433333333333333, '00:13:23']
# 174 = [1, 1, 2, 16, 2, 0.6422222222222222, '00:09:55']
# 175 = [1, 1, 4, 32, 2, 0.6422222222222222, '00:08:46']
# 176 = [1, 10, 3, 16, 2, 0.6416666666666667, '00:10:21']
# 177 = [1, 10, 1, 16, 3, 0.6411111111111112, '00:15:03']
# 178 = [1, 10, 5, 16, 3, 0.6411111111111112, '00:16:06']
# 179 = [1, 10, 5, 32, 4, 0.6411111111111112, '00:17:34']
# 180 = [1, 1, 1, 32, 3, 0.6405555555555555, '00:12:49']
# 181 = [1, 1, 3, 32, 4, 0.64, '00:18:09']
# 182 = [1, 10, 3, 32, 2, 0.6394444444444445, '00:08:31']
# 183 = [1, 1, 4, 16, 4, 0.6383333333333333, '00:21:18']
# 184 = [1, 10, 5, 32, 2, 0.6383333333333333, '00:08:30']
# 185 = [1, 1, 3, 32, 2, 0.6372222222222221, '00:08:35']
# 186 = [1, 1, 3, 16, 2, 0.6355555555555557, '00:10:18']
# 187 = [1, 1, 4, 16, 3, 0.635, '00:15:55']
# 188 = [1, 1, 5, 32, 4, 0.635, '00:17:39']
# 189 = [1, 10, 1, 32, 4, 0.633888888888889, '00:17:20']
# 190 = [1, 10, 2, 16, 2, 0.6327777777777778, '00:10:12']
# 191 = [1, 10, 5, 16, 4, 0.6316666666666666, '00:21:40']
# 192 = [1, 10, 4, 16, 4, 0.6311111111111111, '00:21:26']
# 193 = [20, 100, 4, 16, 2, 0.6306666666666667, '03:21:35']
# 194 = [1, 10, 4, 16, 3, 0.6305555555555556, '00:15:58']
# 195 = [1, 10, 4, 16, 2, 0.6294444444444445, '00:10:25']
# 196 = [1, 10, 2, 32, 2, 0.6288888888888888, '00:08:30']
# 197 = [1, 1, 5, 32, 3, 0.6277777777777779, '00:13:06']
# 198 = [1, 10, 5, 16, 2, 0.6266666666666667, '00:10:34']
# 199 = [1, 10, 1, 32, 3, 0.6211111111111112, '00:12:53']
# 200 = [1, 1, 4, 16, 2, 0.6205555555555554, '00:10:27']
# 201 = [1, 10, 1, 16, 2, 0.6200000000000001, '00:09:52']
# 202 = [20, 100, 4, 16, 3, 0.6097777777777778, '05:31:48']
# 203 = [1, 1, 1, 32, 2, 0.6061111111111112, '00:08:23']
# 204 = [1, 1, 5, 32, 2, 0.6044444444444445, '00:08:35']
# 205 = [1, 10, 1, 32, 2, 0.6022222222222221, '00:08:19']
# 206 = [20, 10, 5, 32, 2, 0.6003333333333334, '01:44:41']
# 207 = [1, 1, 5, 16, 4, 0.5966666666666667, '00:21:29']
# 208 = [20, 1, 3, 16, 4, 0.5901111111111111, '05:11:46']
# 209 = [1, 1, 5, 16, 3, 0.5900000000000001, '00:16:01']
# 210 = [20, 1, 3, 16, 3, 0.5878611111111111, '03:34:25']
# 211 = [20, 100, 5, 32, 4, 0.5870555555555556, '03:23:33']
# 212 = [20, 1, 4, 32, 4, 0.5855277777777778, '03:37:43']
# 213 = [20, 1, 3, 16, 2, 0.5832777777777778, '02:13:40']
# 214 = [20, 1000, 5, 16, 3, 0.5827777777777777, '03:41:54']
# 215 = [1, 1, 5, 16, 2, 0.58, '00:10:29']
# 216 = [20, 1, 4, 32, 3, 0.5799166666666666, '02:39:46']
# 217 = [20, 10, 5, 32, 3, 0.5723055555555556, '02:40:24']
# 218 = [20, 1, 4, 32, 2, 0.5685277777777777, '01:44:17']
# 219 = [20, 10, 4, 16, 2, 0.5665833333333333, '02:22:22']
# 220 = [20, 1000, 4, 16, 4, 0.5445555555555556, '05:05:22']
# 221 = [20, 100, 4, 16, 4, 0.5428333333333333, '07:56:35']
# 222 = [20, 10, 4, 16, 3, 0.5380277777777778, '03:48:54']
# 223 = [20, 10, 4, 16, 4, 0.5374444444444444, '05:32:17']
# 224 = [20, 100, 5, 16, 2, 0.5283333333333333, '03:11:14']
# 225 = [20, 1, 5, 32, 2, 0.5194166666666666, '01:48:41']
# 226 = [20, 1, 4, 16, 2, 0.5, '02:17:34']
# 227 = [20, 1, 4, 16, 3, 0.5, '03:40:39']
# 228 = [20, 1, 4, 16, 4, 0.5, '05:21:15']
# 229 = [20, 1, 5, 16, 3, 0.5, '03:32:41']
# 230 = [20, 1, 5, 16, 4, 0.5, '05:10:12']
# 231 = [20, 1, 5, 32, 3, 0.5, '02:46:53']
# 232 = [20, 1, 5, 32, 4, 0.5, '03:47:22']
# 233 = [20, 10, 5, 16, 2, 0.5, '02:16:05']
# 234 = [20, 10, 5, 16, 3, 0.5, '03:39:41']
# 235 = [20, 10, 5, 16, 4, 0.5, '05:20:25']
# 236 = [20, 10, 5, 32, 4, 0.5, '03:38:51']
# 237 = [20, 100, 5, 16, 3, 0.5, '05:12:45']
# 238 = [20, 100, 5, 16, 4, 0.5, '07:26:55']
# 239 = [20, 1000, 5, 16, 4, 0.5, '05:10:40']
# 240 = [20, 1, 5, 16, 2, 0.4999166666666667, '02:12:07']

# %% [markdown]
# ### Escolhendo um resultado diferente do melhor

# %%
#MELHOR_DOCUMENTOS_PERTURBADOS = 20
#MELHOR_TOP_K_PREDICAO = 100
#MELHOR_TAXAS_DE_APRENDIZAGEM = 1
#MELHOR_TAMANHO_LOTE = 16
#MELHOR_EPOCA_EXECUCAO = 4
#MELHOR_ACURACIA = 0.9825555555555556
#MELHOR_TEMPO = '05:09:49'
#lista_resultados= []

# %% [markdown]
# ### 3.1.2 Função que carrega e calcula a média da acurácia dos folds

# %%
# Import das bibliotecas.
import os
import pandas as pd

def relatorioResultados(DIRETORIO_COHEBERT, 
                        TEXTO_PURO, 
                        _DOCUMENTOS_PERTURBADOS, 
                        _TOP_K_PREDICAO,
                        _TAXAS_DE_APRENDIZAGEM,
                        _TAMANHO_LOTE,
                        _EPOCA_EXECUCAO
                        ):
  
  # Numero de Folds
  KFOLDS = 10

  # Quantidade de documentos a serem perturbados a partir do original.    
  DOCUMENTOS_PERTURBADOS = _DOCUMENTOS_PERTURBADOS

  # Quantidade de palavras a serem recuperadas mais próximas da máscara. 
  TOP_K_PREDICAO = _TOP_K_PREDICAO

  # MCL a serem avaliados
  #MODELO_BERT = ['_BERTimbau','_BERTmultilingual']
  MODELO_BERT = ['_BERTimbau']

  #TAMANHO_BERT = ['_base','_large']
  TAMANHO_BERT = ['_large']

  # Taxa de aprendizagem do nome do arquivo
  TAXAS_DE_APRENDIZAGEM = _TAXAS_DE_APRENDIZAGEM

  # Tamanho dos lotes
  TAMANHO_LOTE = _TAMANHO_LOTE

  # Salva resultados intermediários
  EPOCA = _EPOCA_EXECUCAO
  
  # Diretório para salvar o arquivo.
  DIRETORIO_AVALIACAO = "/content/drive/My Drive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_classificacao_palavra/kfold/Avaliacao/"  

  listaTempoTotal = []  
  totalGeralFolds = 0
  totalGeralRegistros = 0
  totalArquivos = (len(MODELO_BERT) * len(TAMANHO_BERT) *
                   len(DOCUMENTOS_PERTURBADOS) *  len(TOP_K_PREDICAO) * 
                   len(TAMANHO_LOTE) * len(EPOCA) * len(TAXAS_DE_APRENDIZAGEM) * KFOLDS)
  #totalArquivos = 400  
  if TEXTO_PURO == False:
    print("totalArquivos =", totalArquivos) 

  # Verifica se o diretório dos resultados existe.
  if os.path.exists(DIRETORIO_AVALIACAO):    
    for modelo in MODELO_BERT:
      for tamanho in TAMANHO_BERT:        
        if modelo != '_BERTmultilingual' or tamanho != '_large':  
          for documentos_perturbados in DOCUMENTOS_PERTURBADOS:
            for top_k_predicao in TOP_K_PREDICAO:        
              DIRETORIO_AVALIACAO_PK = DIRETORIO_AVALIACAO + "P_" + str(documentos_perturbados) + "_K_" + str(top_k_predicao) + "/"
        
              # Verifica se o diretório dos resultados existe.
              if os.path.exists(DIRETORIO_AVALIACAO_PK):
                arquivos = os.listdir(DIRETORIO_AVALIACAO_PK) 
                for lote in TAMANHO_LOTE:
                  for taxaaprendizagem in TAXAS_DE_APRENDIZAGEM:
                    for epoca in EPOCA:                    
                        # Acumuladores.
                        somaAcuracia = 0
                        listaTempo = []
                        contaFolds = 0 
                        contaReg = 0
                        if TEXTO_PURO == False:
                           print("\nModelo:", modelo, " Tamanho:", tamanho, " N Doc:",documentos_perturbados,
                                 " Top k:", top_k_predicao, " Lote:", lote, " Taxa Apred.:", taxaaprendizagem, " Época:", epoca)
       
                        for i in range(len(arquivos)):                                    
                          for fold in range(1,11):                                                         
                            if ((("_P_" + str(documentos_perturbados)+"_") in arquivos[i]) 
                                and (("_K_" + str(top_k_predicao)+"_") in arquivos[i]) 
                                and (("_b_" + str(lote)) in arquivos[i]) 
                                and (modelo in arquivos[i]) 
                                and (tamanho in arquivos[i]) 
                                and (("_b_" + str(lote)) in arquivos[i]) 
                                and (('_f' + str(fold) + '_') in arquivos[i]) 
                                and (("e_" + str(epoca)) in arquivos[i]) 
                                and (("lr_" + str(taxaaprendizagem)) in arquivos[i])):
                             
                                NOME_ARQUIVO_AVALIACAO_COMPLETO = DIRETORIO_AVALIACAO_PK + arquivos[i]                              
                                # Verifica se o arquivo existe.
                                if os.path.isfile(NOME_ARQUIVO_AVALIACAO_COMPLETO):
                                  # Carrega os dados do arquivo  
                                  dados = pd.read_csv(NOME_ARQUIVO_AVALIACAO_COMPLETO, sep=';')
                      
                                  # Conta o número de folds.
                                  contaFolds = contaFolds + 1
                                  # Conta o número geral de folds
                                  totalGeralFolds = totalGeralFolds + 1

                                  # Mostra os dados do teste do fold.
                                  for index, linha in dados.iterrows():        
                                    # Cálculo das estatísticas
                                    acc = (linha['vp']+linha['vn'])/(linha['vp']+linha['vn']+linha['fp']+linha['fn'])                         
                                    print('{};{};{};{};{}'.format(fold, index, arquivos[i],str(acc).replace(".", ","),linha['tempo']))
                                    #print('{};{};{};{:.8f};{}'.format(fold, index, arquivos[i],acc,linha['tempo']))
                                    # Guarda o tempo.
                                    listaTempo.append(str(linha['tempo']))

                                    # Conta o número de registros.
                                    contaReg = contaReg + 1
                                    # Conta o número geral de registros.
                                    totalGeralRegistros = totalGeralRegistros + 1

                                  # Realiza a soma da acurácia do arquivo.
                                  somaAcuracia = somaAcuracia + dados['acuracia'].sum()

                        
                        if contaFolds != 0:
                            # Mostra a soma da acurácia . 
                            if TEXTO_PURO == False:
                              print('Total acurácia                                           : {:.8f}'.format(somaAcuracia))
                            # Mostra a quantidade de folds.
                            if TEXTO_PURO == False:
                              print('Quantidade de folds                                      : {}'.format(contaFolds))  
                            # Mostra a quantidade de registros.
                            if TEXTO_PURO == False:
                              print('Quantidade de registros                                  : {}'.format(contaReg))  
                            # Calcula a média.
                            if TEXTO_PURO == False:
                              mediaAcuracia = somaAcuracia/contaReg
                              print('A média da acurácia de {:2d} registros é                    : {:.8f}'.format(contaReg, mediaAcuracia))
                              print('O tempo gasto na execução do treinamento {:2d} registros é  : {}'.format(contaReg, somaTempo(listaTempo)))
                              print('A média de tempo de execução de {:2d} registros é           : {}\n'.format(contaReg, mediaTempo(listaTempo)))
                            
                            if epoca == 4:
                              # Guarda o tempo total
                              listaTempoTotal.append(somaTempo(listaTempo))
                        else:
                            if TEXTO_PURO == False:
                              print('Nenhum arquivo de avaliação encontrado')
                                    
              else:
                print('Diretório ' + 'P_' + str(documentos_perturbados) + '_K_' + str(top_k_predicao) + ' não encontrado')                        
    
  else:
      print('Diretório com os resultados não encontrado')

# %% [markdown]
# Recupera os dados dos melhores resultados

# %%
# Diretório do cohebert
DOCUMENTOS_PERTURBADOS = [MELHOR_DOCUMENTOS_PERTURBADOS]
TOP_K_PREDICAO = [MELHOR_TOP_K_PREDICAO]
TAXAS_DE_APRENDIZAGEM = [MELHOR_TAXAS_DE_APRENDIZAGEM]
TAMANHO_LOTE = [MELHOR_TAMANHO_LOTE]
EPOCA_EXECUCAO = [MELHOR_EPOCA_EXECUCAO]
TEXTO_PURO = False

relatorioResultados(DIRETORIO_COHEBERT, 
                    TEXTO_PURO, 
                    DOCUMENTOS_PERTURBADOS, 
                    TOP_K_PREDICAO, 
                    TAXAS_DE_APRENDIZAGEM, 
                    TAMANHO_LOTE, 
                    EPOCA_EXECUCAO)
# Out:
# totalArquivos = 10
#
# Modelo: _BERTimbau  Tamanho: _large  N Doc: 20  Top k: 1000  Lote: 16  Taxa Apred.: 1  Época: 4
# 1;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f1_BERTimbau_large.csv;0,9808333333333333;0:26:16
# 2;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f2_BERTimbau_large.csv;0,9880555555555556;0:26:18
# 3;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f3_BERTimbau_large.csv;0,9891666666666666;0:26:27
# 4;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f4_BERTimbau_large.csv;0,9866666666666667;0:26:36
# 5;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f5_BERTimbau_large.csv;0,9877777777777778;0:26:52
# 6;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f6_BERTimbau_large.csv;0,9911111111111112;0:27:12
# 7;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f7_BERTimbau_large.csv;0,9872222222222222;0:27:24
# 8;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f8_BERTimbau_large.csv;0,9883333333333333;0:27:32
# 9;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f9_BERTimbau_large.csv;0,9886111111111111;0:27:47
# 10;0;AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f10_BERTimbau_large.csv;0,9922222222222222;0:27:45
# Total acurácia                                           : 9.88000000
# Quantidade de folds                                      : 10
# Quantidade de registros                                  : 10
# A média da acurácia de 10 registros é                    : 0.98800000
# O tempo gasto na execução do treinamento 10 registros é  : 04:30:09
# A média de tempo de execução de 10 registros é           : 00:27:00

# %% [markdown]
# ## 3.2 Carregamento dos arquivos de dados originais e perturbados

# %% [markdown]
# ### 3.2.1 Especifica os nomes dos arquivos de dados

# %%
# Nome do arquivo
NOMEARQUIVOORIGINAL = "original.csv"
NOMEARQUIVOORIGINALCOMPACTADO = "original.zip"
NOMEARQUIVOORIGINALPOS = "originalpos.csv"
NOMEARQUIVOORIGINALPOSCOMPACTADO = "originalpos.zip"

NOMEARQUIVOPERTURBADO = "perturbado_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".csv"
NOMEARQUIVOPERTURBADOCOMPACTADO = "perturbado_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".zip"
NOMEARQUIVOPERTURBADOPOS = "perturbadopos_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".csv"
NOMEARQUIVOPERTURBADOPOSCOMPACTADO = "perturbadopos_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".zip"

# %% [markdown]
# ### 3.2.2 Cria o diretório local para receber os dados

# %%
# Import das bibliotecas.
import os

# Cria o diretório para receber os arquivos Originais e Perturbados
# Diretório a ser criado
dirbase = DIRETORIO_LOCAL[:-1]

if not os.path.exists(dirbase):  
    # Cria o diretório
    os.makedirs(dirbase)    
    logging.info("Diretório criado: {}".format(dirbase))
else:    
    logging.info("Diretório já existe: {}".format(dirbase))
# Out:
# 2022-03-18 12:46:57,434 : INFO : Diretório criado: /content/FAQUAD

# %% [markdown]
# ### 3.2.3 Copia e descompacta os arquivos do Google Drive para o Colaboratory

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:

  # !cp "$DIRETORIO_DRIVE$NOMEARQUIVOORIGINALCOMPACTADO" "$DIRETORIO_LOCAL"
  # !cp "$DIRETORIO_DRIVE$NOMEARQUIVOORIGINALPOSCOMPACTADO" "$DIRETORIO_LOCAL"

  # !cp "$DIRETORIO_DRIVE$NOMEARQUIVOPERTURBADOCOMPACTADO" "$DIRETORIO_LOCAL"
  # !cp "$DIRETORIO_DRIVE$NOMEARQUIVOPERTURBADOPOSCOMPACTADO" "$DIRETORIO_LOCAL"

  logging.info("Terminei a cópia!")
# Out:
# 2022-03-18 12:46:59,579 : INFO : Terminei a cópia!

# %% [markdown]
# Descompacta os arquivos.
#
# Usa o unzip para descompactar:
# *   `-o` sobrescreve o arquivo se existir
# *   `-j` Não cria nenhum diretório
# *   `-q` Desliga as mensagens
# *   `-d` Diretório de destino

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOMEARQUIVOORIGINALCOMPACTADO" -d "$DIRETORIO_LOCAL"
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOMEARQUIVOORIGINALPOSCOMPACTADO" -d "$DIRETORIO_LOCAL"

  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOMEARQUIVOPERTURBADOCOMPACTADO" -d "$DIRETORIO_LOCAL"
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOMEARQUIVOPERTURBADOPOSCOMPACTADO" -d "$DIRETORIO_LOCAL"

  logging.info("Terminei a descompactação!")
# Out:
# 2022-03-18 12:47:00,115 : INFO : Terminei a descompactação!

# %% [markdown]
# ### 3.2.4 Carregamento das lista com os dados dos arquivos originais e perturbados

# %% [markdown]
# #### Carrega o arquivo dos dados originais e POS

# %%
#Biblioteca
import pandas as pd

# Abre o arquivo e retorna o DataFrame
lista_documentos_originais = pd.read_csv(DIRETORIO_LOCAL + NOMEARQUIVOORIGINAL, sep=";", encoding="UTF-8")
lista_documentos_originais_pos = pd.read_csv(DIRETORIO_LOCAL + NOMEARQUIVOORIGINALPOS, sep=";", encoding="UTF-8")

logging.info("TERMINADO ORIGINAIS: {}.".format(len(lista_documentos_originais)))
logging.info("TERMINADO ORIGINAIS POS: {}.".format(len(lista_documentos_originais_pos)))
# Out:
# 2022-03-18 12:47:00,161 : INFO : TERMINADO ORIGINAIS: 900.
# 2022-03-18 12:47:00,163 : INFO : TERMINADO ORIGINAIS POS: 900.

# %%
lista_documentos_originais.sample(5)
# Out:
#                                    id  \
# 287  ab221182bdf242d98e9b5f6bb9a34a52
# 442  f1146e1e59e648a8b095e7d6d7e39f7f
# 525  a9814c246dee46b59b733c3a473b595e
# 109  95cea743eb4c4328958d41f7e445d950
# 251  7e00d87ee5c5462686e4c5ce506a673f
#
#                                              sentencas  \
# 287  ['Qual termo é controverso nas ciências em ger...
# 442  ['O que acontece caso o aluno se ausente da re...
# 525  ['O que a máquina de turing utilizava para ope...
# 109  ['Em que a maioria dos cientistas da computaçã...
# 251  ['Qual era o objetivo do curso de engenharia d...
#
#                                              documento
# 287    Qual termo é controverso nas ciências em geral?
# 442  O que acontece caso o aluno se ausente da reno...
# 525  O que a máquina de turing utilizava para opera...
# 109  Em que a maioria dos cientistas da computação ...
# 251  Qual era o objetivo do curso de engenharia de ...

# %%
lista_documentos_originais_pos.sample(5)
# Out:
#                                    id  \
# 843  84b0eef8870841c5bf638cd3e54b0284
# 718  f71500e2feec42198524d833bc76cd14
# 441  ba930d3c69b445fe95787bee95481a69
# 604  73fc0c9b75344150be634b3d1d31dd1f
# 423  859b15a179714620906bf10f0b284e95
#
#                                          pos_documento
# 843  [[['quem', 'dá', 'a', 'nota', 'final', 'ao', '...
# 718  [[['O', 'que', 'o', 'desenvolvimento', 'cada',...
# 441  [[['O', 'que', 'acontece', 'caso', 'o', 'acadê...
# 604  [[['Quem', 'deve', 'corrigir', 'e', 'previnir'...
# 423  [[['Qual', 'a', 'condição', 'para', 'matrícula...

# %% [markdown]
# #### Corrigir os tipos de colunas dos dados originais e POS
#
# Em dados originais:
# - coluna 1 - `sentenças` carregadas do arquivo vem como string e não como lista.
#
# Em dados originais pos:
# - coluna 1 - `pos_documento` carregadas do arquivo vem como string e não como lista.

# %%
# Import das bibliotecas.
import ast # Biblioteca para conversão de string em lista

# Verifica se o tipo da coluna não é list e converte
lista_documentos_originais["sentencas"] = lista_documentos_originais["sentencas"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

lista_documentos_originais_pos["pos_documento"] = lista_documentos_originais_pos["pos_documento"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

logging.info("TERMINADO CORREÇÃO ORIGINAIS: {}.".format(len(lista_documentos_originais)))
logging.info("TERMINADO CORREÇÃO ORIGINAIS POS: {}.".format(len(lista_documentos_originais_pos)))
# Out:
# 2022-03-18 12:47:00,304 : INFO : TERMINADO CORREÇÃO ORIGINAIS: 900.
# 2022-03-18 12:47:00,306 : INFO : TERMINADO CORREÇÃO ORIGINAIS POS: 900.

# %% [markdown]
# #### Carrega o arquivo dos dados perturbados e POS

# %%
# Abre o arquivo e retorna o DataFrame
lista_documentos_perturbados = pd.read_csv(DIRETORIO_LOCAL + NOMEARQUIVOPERTURBADO, sep=";", encoding="UTF-8")
lista_documentos_perturbados_pos = pd.read_csv(DIRETORIO_LOCAL + NOMEARQUIVOPERTURBADOPOS, sep=";", encoding="UTF-8")

logging.info("TERMINADO PERTURBADOS: {}.".format(len(lista_documentos_perturbados)))
logging.info("TERMINADO PERTURBADOS POS: {}.".format(len(lista_documentos_perturbados_pos)))
# Out:
# 2022-03-18 12:47:00,523 : INFO : TERMINADO PERTURBADOS: 18000.
# 2022-03-18 12:47:00,525 : INFO : TERMINADO PERTURBADOS POS: 18000.

# %%
lista_documentos_perturbados.sample(5)
# Out:
#                                              id  \
# 3676   536fd8c1b1a943ecb74a79aa72ff8a48_pert_16
# 15308   3b95690d7e9b4074b87c2c1476e2ec0b_pert_8
# 14373  f71500e2feec42198524d833bc76cd14_pert_13
# 10547   29f13da0db884441a2e7dc9e34f62d4d_pert_7
# 16349   69ac001c690c4a02a2151758743f6db3_pert_9
#
#                                               perturbado  \
# 3676   ['Por que o Z1 foi permitido pelo governo alem...
# 15308                    ['O que é Tecnologia da Lar ?']
# 14373  ['O que o desenvolvimento cada vez mais rápido...
# 10547  ['Qual era o número de cadeira acadêmicos no B...
# 16349  ['Como ficou Praga a primeira universidade mod...
#
#                                      documentoPerturbado  \
# 3676    Por que o Z1 foi permitido pelo governo alemão ?
# 15308                        O que é Tecnologia da Lar ?
# 14373  O que o desenvolvimento cada vez mais rápido d...
# 10547  Qual era o número de cadeira acadêmicos no Bra...
# 16349  Como ficou Praga a primeira universidade moder...
#
#                                                sentencas
# 3676   [['Por que o Z1 foi [MASK] pelo governo alemão...
# 15308  [['O que é Tecnologia da [MASK] ?', 'Informaçã...
# 14373  [['O que o desenvolvimento cada vez mais rápid...
# 10547  [['Qual era o número de [MASK] acadêmicos no B...
# 16349  [['Como ficou [MASK] a primeira universidade m...

# %%
lista_documentos_perturbados_pos.sample(5)
# Out:
#                                              id  \
# 4841    9345e1a73aee4ea191ff28df49a56c5b_pert_1
# 13067   51b282c3346b461c8006f338ed5c0bd6_pert_7
# 2715   992c12a7782a470ea48a1438c5ae7a0e_pert_15
# 5282    b5874b7d124c42b284e1c0799ec8efe4_pert_2
# 11100   f2ccd205ac284d239c3da37353f84196_pert_0
#
#                                            pos_documento
# 4841   [[['Quando', 'os', 'primeiros', 'docentes', 'd...
# 13067  [[['Qual', 'o', 'número', 'mínimo', 'de', 'cré...
# 2715   [[['Quantos', 'números', 'um', 'byte', 'possa'...
# 5282   [[['Qual', 'um', 'exemplo', 'recente', 'de', '...
# 11100  [[['Os', 'modelos', '2006', 'são', 'equivalent...

# %% [markdown]
# #### Corrigir os tipos de colunas dos dados perturbados e POS
#
# Em dados perturbados:
# - coluna 1 - `perturbado` carregadas do arquivo vem como string e não como lista.
# - coluna 3 - `sentencas` carregadas do arquivo vem como string e não como lista.
#
# Em dados perturbados pos:
# - coluna 1 - `pos_documento` carregadas do arquivo vem como string e não como lista.

# %%
# Import das bibliotecas.
import ast # Biblioteca para conversão de string em lista

# Verifica se o tipo da coluna não é list e converte
lista_documentos_perturbados["perturbado"] = lista_documentos_perturbados["perturbado"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)
lista_documentos_perturbados["sentencas"] = lista_documentos_perturbados["sentencas"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

lista_documentos_perturbados_pos["pos_documento"] = lista_documentos_perturbados_pos["pos_documento"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

logging.info("TERMINADO CORREÇÃO PERTURBADO: {}.".format(len(lista_documentos_perturbados)))
logging.info("TERMINADO CORREÇÃO PERTURBADO POS: {}.".format(len(lista_documentos_perturbados_pos)))
# Out:
# 2022-03-18 12:47:02,533 : INFO : TERMINADO CORREÇÃO PERTURBADO: 18000.
# 2022-03-18 12:47:02,534 : INFO : TERMINADO CORREÇÃO PERTURBADO POS: 18000.

# %% [markdown]
# ### 3.2.5 Agrupar os dados originais e perturbados

# %%
# Import das bibliotecas.
import ast
from tqdm.notebook import tqdm as tqdm_notebook

print("Processando",len(lista_documentos_originais),"documentos originais")

lista_documentos_agrupados = []

# Barra de progresso dos documentos
lista_documentos_originais_bar = tqdm_notebook(lista_documentos_originais.iterrows(), desc=f"Documentos", unit=f" documento", total=len(lista_documentos_originais))

# Percorre os documentos
for i, linha_documento in lista_documentos_originais_bar: 
  #if i < 2:
    #print("linha_documento:",linha_documento)
    # Recupera o id do documento
    id_documento = linha_documento[0]     
    #print("id_documento:",id_documento)     
 
    # Carrega a lista das sentenças do documento
    lista_sentenca_documento = linha_documento[1]    
    #print("\nlista_sentenca_documento:",lista_sentenca_documento)
    #print("len(lista_sentenca_documento):",len(lista_sentenca_documento)) 

    # Adiciona o original a lista dos dados agrupados, considerando como coerente(1)
    lista_documentos_agrupados.append([id_documento, lista_sentenca_documento, linha_documento[2], 1])
  
    # Percorre os documentos perturbados apartir do original
    for j in range(0, MELHOR_DOCUMENTOS_PERTURBADOS):

      # Id do documento perturbado
      id_perturbado = str(id_documento) + "_pert_" + str(j)

      # localiza o documento perturbado 
      documento_perturbado = lista_documentos_perturbados.loc[lista_documentos_perturbados['id']==id_perturbado].values[0]
      # Recupera a sentença do documento perturbado
      lista_perturbado = documento_perturbado[1]
          
      # Adiciona o perturbado a lista dos dados agrupados considerando como incoerente(0)
      lista_documentos_agrupados.append([id_perturbado, lista_perturbado, documento_perturbado[2], 0])    

logging.info("TERMINADO AGRUPAMENTO: {}.".format(len(lista_documentos_agrupados)))
# Out:
# Processando 900 documentos originais
# Documentos:   0%|          | 0/900 [00:00<?, ? documento/s]
# 2022-03-18 12:47:31,430 : INFO : TERMINADO AGRUPAMENTO: 18900.

# %% [markdown]
# Converte em um dataframe

# %%
# Cria o dataframe da lista
dflista_documentos_agrupados = pd.DataFrame(lista_documentos_agrupados, columns = ["id","sentencas","documento","classe"])

# %%
# Corrige os tipos dos dados da lista agrupada
tipos = {"id": str, "sentencas": object, "documento": str, "classe": int}

dflista_documentos_agrupados = dflista_documentos_agrupados.astype(tipos)

# %%
dflista_documentos_agrupados.sample(5)
# Out:
#                                              id  \
# 10857          f20ebd2a1baa435e8458af51f6397bea
# 11046          7a50b2ccd7b9424f87bf312e60fc9a44
# 12681  2f91caf3322742e190beae0fd37262d3_pert_17
# 800     ecefc6cb3cc44bef8c606567e8ae756b_pert_1
# 9182    4ac2a64c1af245c5b712fd7078d25628_pert_4
#
#                                                sentencas  \
# 10857  [Quem listou os maiores desafios no campo da m...
# 11046  [Qual modelo computacional propôs a construção...
# 12681  [Qual deve ser a frequência do acadêmico para ...
# 800    [O que é necessário publicar para comprovar a ...
# 9182   [O que o discente envia fazer na seleção de di...
#
#                                                documento  classe
# 10857  Quem listou os maiores desafios no campo da ma...       1
# 11046  Qual modelo computacional propôs a construção ...       1
# 12681  Qual deve ser a frequência do acadêmico para q...       0
# 800    O que é necessário publicar para comprovar a p...       0
# 9182   O que o discente envia fazer na seleção de dis...       0

# %%
# Importa das bibliotecas
import pandas as pd

# Concatena as listas de documentos originais e perturbados
dflista_documentos_agrupados_pos = pd.concat([lista_documentos_originais_pos, lista_documentos_perturbados_pos])

logging.info("TERMINADO AGRUPAMENTO POS: {}.".format(len(dflista_documentos_agrupados_pos)))
# Out:
# 2022-03-18 12:47:31,503 : INFO : TERMINADO AGRUPAMENTO POS: 18900.

# %%
# Corrige os tipos dos dados da lista agrupada
tipos = {"id": str}

dflista_documentos_agrupados_pos = dflista_documentos_agrupados_pos.astype(tipos)

# %%
dflista_documentos_agrupados_pos.sample(5)
# Out:
#                                              id  \
# 167            5c91b3d0d6f54872b84b68e61cca84ca
# 8048    8392f85c85024a878d983f7692fa98ab_pert_8
# 17475  39fd8cfbb7e54ca280c4fc09bdc91a1a_pert_15
# 2940    6d29de5b8a674d7685457daba539eb0b_pert_0
# 12348   c308a5365bea44458a70619f4b131df0_pert_8
#
#                                            pos_documento
# 167    [[[Quem, construiu, a, primeira, máquina, de, ...
# 8048   [[[O, que, era, dizer, Total, de, Alunos, Equi...
# 17475  [[[como, falou, a, componente, curricular, não...
# 2940   [[[Onde, geralmente, pegou, a, próxima, instru...
# 12348  [[[O, que, _, ser, respeitado, na, inscrição, ...

# %% [markdown]
# ## 3.3 Carrega os dados da classificação

# %%
# Import das bibliotecas.
import os
import pandas as pd

def getDadosClassificacaoCompactado(DIRETORIO_COHEBERT,                           
                          _DOCUMENTOS_PERTURBADOS, 
                          _TOP_K_PREDICAO,
                          _EPOCA,
                          _TAXAS_DE_APRENDIZAGEM,
                          _TAMANHO_LOTE,
                          _EPOCA_EXECUCAO,
                          _MODELO_BERT = '_BERTimbau',
                          _TAMANHO_BERT = '_large'
                          ):

  # Diretório para carregar o arquivo.
  DIRETORIO_CLASSIFICACAO_DRIVE = DIRETORIO_DRIVE + "validacao_classificacao_palavra/kfold/Classificacao/" + "P_" + str(_DOCUMENTOS_PERTURBADOS) + "_K_" + str(_TOP_K_PREDICAO) + "/"

  # Diretório local para carregar o arquivo
  DIRETORIO_CLASSIFICACAO_LOCAL = DIRETORIO_LOCAL + "Classificacao/"

  # Verifica se o diretório existe
  if not os.path.exists(DIRETORIO_CLASSIFICACAO_LOCAL):  
    # Cria o diretório
    os.makedirs(DIRETORIO_CLASSIFICACAO_LOCAL)
    logging.info("Diretório criado: {}.".format(DIRETORIO_CLASSIFICACAO_LOCAL))
  else:
    logging.info("Diretório já existe: {}.".format(DIRETORIO_CLASSIFICACAO_LOCAL))
    
  # Dataframe que será retornado após o preenchimento
  df_dados_classificacao = pd.DataFrame()

  # Verifica se o diretório das classificações existem.
  if os.path.exists(DIRETORIO_CLASSIFICACAO_DRIVE):
    
    # Carrega o nome dos arquivos do drive
    arquivos = os.listdir(DIRETORIO_CLASSIFICACAO_DRIVE)     

    print('\nModelo:', _MODELO_BERT, 
          ' Tamanho:', _TAMANHO_BERT, 
          ' Np:', str(_DOCUMENTOS_PERTURBADOS), 
          ' Topk:', str(_TOP_K_PREDICAO), 
          ' Lote:', str(_TAMANHO_LOTE), 
          ' Taxa Apr.: ', str(_TAXAS_DE_APRENDIZAGEM),
          ' Epoca:', str(_EPOCA_EXECUCAO))
    
    # Acumuladores.
    conta_folds = 0 
    conta_reg = 0

    # Percorre os folds 
    for fold in range(1,11): 
      # Nome do arquivo
      NOME_ARQUIVO_CLASSIFICACAO = (NOME_BASE_SAIDA + "_P_" +  str(_DOCUMENTOS_PERTURBADOS) 
                                  + "_K_" + str(_TOP_K_PREDICAO) 
                                  + "_E_" + str(_EPOCA) 
                                  + "_e_" + str(_EPOCA_EXECUCAO) 
                                  + "_lr_" + str(_TAXAS_DE_APRENDIZAGEM) 
                                  + "_b_" +  str(_TAMANHO_LOTE)  
                                  + "_" +  str(_TAMANHO_LOTE)  
                                  + "_f" + str(fold) 
                                  + _MODELO_BERT 
                                  + _TAMANHO_BERT)
      
      # Caminho completo do arquivo compactado no drive
      NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO = DIRETORIO_CLASSIFICACAO_DRIVE + NOME_ARQUIVO_CLASSIFICACAO + ".zip"
      # print("NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO:", NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO)

      # Caminho completo do arquivo compactado no local
      NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO = DIRETORIO_CLASSIFICACAO_LOCAL + NOME_ARQUIVO_CLASSIFICACAO + ".zip"
      # print("NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO:", NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO)

      # Caminho completo do arquivo no local
      NOME_ARQUIVO_CLASSIFICACAO_LOCAL = DIRETORIO_CLASSIFICACAO_LOCAL + NOME_ARQUIVO_CLASSIFICACAO + ".csv"
      # print("NOME_ARQUIVO_CLASSIFICACAO_LOCAL:", NOME_ARQUIVO_CLASSIFICACAO_LOCAL)

      # Verifica se o arquivo existe.
      if os.path.isfile(NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO):

          # Copia arquivo da classificação compactado do google drive para o drive local
          # !cp "$NOME_ARQUIVO_CLASSIFICACAO_DRIVE_COMPACTADO" "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO"  
                        
          # Descompacta arquivo da classificação compactado no drive local
          # !unzip -o -j -q "$NOME_ARQUIVO_CLASSIFICACAO_LOCAL_COMPACTADO" -d "$DIRETORIO_CLASSIFICACAO_LOCAL"

          # Carrega os dados do arquivo  
          dados = pd.read_csv(NOME_ARQUIVO_CLASSIFICACAO_LOCAL, sep=';')
          
          # Concatena com os dados lidos anteriormente
          df_dados_classificacao = pd.concat([df_dados_classificacao, dados], ignore_index=True)
            
          # Conta o número de folds.
          conta_folds = conta_folds + 1

          conta_reg = conta_reg + len(dados)
      else:
          print('Arquivo não encontrado')
              
    print('Folds:', conta_folds, ' Regs:', conta_reg)
  else:
      print('Diretório com os resultados não encontrado')

  # Corrige os tipos dos dados 
  tipos = {"id": str}
  df_dados_classificacao = df_dados_classificacao.astype(tipos)      

  print('Registros:', len(df_dados_classificacao))   

  return df_dados_classificacao

# %%
DOCUMENTOS_PERTURBADOS = MELHOR_DOCUMENTOS_PERTURBADOS
TOP_K_PREDICAO = MELHOR_TOP_K_PREDICAO
EPOCA = 4
TAXAS_DE_APRENDIZAGEM = MELHOR_TAXAS_DE_APRENDIZAGEM
TAMANHO_LOTE = MELHOR_TAMANHO_LOTE
EPOCA_EXECUCAO = MELHOR_EPOCA_EXECUCAO

# Recupera os dados da melhor classificação
dfDadosClassificacao = getDadosClassificacaoCompactado(DIRETORIO_COHEBERT, 
                                             DOCUMENTOS_PERTURBADOS, 
                                             TOP_K_PREDICAO,
                                             EPOCA,
                                             TAXAS_DE_APRENDIZAGEM,
                                             TAMANHO_LOTE,
                                             EPOCA_EXECUCAO)
# Out:
# Modelo: _BERTimbau  Tamanho: _large  Np: 20  Topk: 1000  Lote: 16  Taxa Apr.:  1  Epoca: 4
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f1_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f2_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f3_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f4_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f5_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f6_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f7_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f8_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f9_BERTimbau_large.csv
# /content/drive/MyDrive/Colab Notebooks/Data/FAQUAD/validacao_classificacao_palavra/kfold/Classificacao/P_20_K_1000/AjusteFinoFaquad_v1_C_SB_KF_P_20_K_1000_E_4_e_4_lr_1_b_16_16_f10_BERTimbau_large.csv
# Folds: 10  Regs: 36000
# Registros: 36000

# %%
dfDadosClassificacao.sample(5)
# Out:
#                    data                                        id  classe  \
# 17711  01/03/2022 13:24          fb1dd28864324e9a9d6d657f7bb6a5f9       1
# 32115  01/03/2022 15:20          f1866ef29f9a4b2bb069b897168cc3ea       1
# 30508  01/03/2022 15:20          0b70044075784d24ae6743c4ebb9c0e9       1
# 22925  01/03/2022 14:22          445387abf59e43cbbf3b58f7a224c6c0       1
# 54     01/03/2022 11:32  5d670b9c1fa442129c2c4cd6348c4392_pert_11       0
#
#        predicao
# 17711         1
# 32115         1
# 30508         1
# 22925         0
# 54            1

# %% [markdown]
# ## 3.4 Analisa os dados das classificações

# %% [markdown]
# ### Acurácia

# %%
def calculoClassificacao(dfDadosClassificacao):
  vp_s = 0
  vn_s = 0
  fp_s = 0
  fn_s = 0
  for i, linha in dfDadosClassificacao.iterrows():
    #if i < 20:
    if linha['classe'] == 1 and linha['predicao'] == 1:
        vp_s = vp_s + 1
    if linha['classe'] == 0 and linha['predicao'] == 0:
        vn_s = vn_s + 1        
    if linha['classe'] == 1 and linha['predicao'] == 0:
        fp_s = fp_s + 1        
    if linha['classe'] == 0 and linha['predicao'] == 1:
        fn_s = fn_s + 1        

  # Acurácia indica uma performance geral do modelo. 
  # Dentre todas as classificações, quantas o modelo classificou corretamente(vp=1 e vn=0).
  if (vp_s+vn_s+fp_s+fn_s) != 0:
    acc = (vp_s+vn_s)/(vp_s+vn_s+fp_s+fn_s)
  else:
    acc  = 0
    
  # Recall(Revocação) avalia todas as situações da classe Positivo(vp=1) com o valor esperado e quantas estão corretas.
  if (vp_s+fn_s) != 0:
      rec = (vp_s)/(vp_s+fn_s)
  else:
      rec = 0
  
  # Precisão avalia as classificações da classe positivo(vp=1 e fp=0) que o modelo fez e quantas estão corretas.
  if (vp_s+fp_s) != 0:
      pre = (vp_s)/(vp_s+fp_s)
  else:
      pre = 0  

  # F1 é a média harmônica entre precisão e recall.
  if (pre + rec) != 0:  
    f1 = 2 * ((pre * rec)/(pre + rec))
  else:
    f1 = 0

  return acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s

# %%
acc, rec, pre, f1, vp_s, vn_s, fp_s, fn_s = calculoClassificacao(dfDadosClassificacao)

#dflistaParesDocumentosClassificados

print('Acurácia:', acc)
print('Recall  :', rec)
print('Precisão:', pre)
print('F1      :', f1)
print('vp      :', vp_s)
print('vn      :', vn_s)
print('fp      :', fp_s)
print('fn      :', fn_s)
total = vp_s + vn_s + fp_s + fn_s
print('Total   :', total)
# Out:
# Acurácia: 0.988
# Recall  : 0.9857869704678686
# Precisão: 0.9902777777777778
# F1      : 0.9880272712155646
# vp      : 17825
# vn      : 17743
# fp      : 175
# fn      : 257
# Total   : 36000

# %% [markdown]
# #### Matriz de confusão

# %%
import matplotlib
import matplotlib.pyplot as plt

TAMANHO_FONTE = 38
matplotlib.rc('font', size=TAMANHO_FONTE)          # Controla o tamanho do do texto default
matplotlib.rc('axes', titlesize=TAMANHO_FONTE)     # Tamanho da fonte do eixo do título
matplotlib.rc('axes', labelsize=TAMANHO_FONTE)     # Tamanho da fonte dos rótulos do eixo x e y
matplotlib.rc('xtick', labelsize=TAMANHO_FONTE)    # Tamanho da fonte das marcações do eixo y
matplotlib.rc('ytick', labelsize=TAMANHO_FONTE)    # Tamanho da fonte dos marcações do eixo x
matplotlib.rc('legend', fontsize=TAMANHO_FONTE)    # Tamanho da fonte da legenda
matplotlib.rc('figure', titlesize=TAMANHO_FONTE+2)   # Tamanho da fonte do título da figura

# Aumenta o tamanho da plotagem e o tamanho da fonte.
plt.rcParams['figure.figsize'] = (15,8)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import numpy as np

X_alvo =     dfDadosClassificacao['classe'].tolist()
y_predicao = dfDadosClassificacao['predicao'].tolist()

print(classification_report(X_alvo, y_predicao))

# Insere os dados no gráfico
cf_matrix = confusion_matrix(X_alvo, y_predicao)
quantidade_grupos = ["{0:0.0f}".format(valor) for valor in cf_matrix.flatten()]
percentual_grupos = ["{0:.2%}".format(valor) for valor in cf_matrix.flatten()/np.sum(cf_matrix)]
rotulos = [f"{v1}\n{v2}" for v1, v2 in zip(quantidade_grupos,percentual_grupos)]
rotulos = np.asarray(rotulos).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=rotulos, fmt='', cmap='Blues_r')

# Texto do eixo x
ax.set_xlabel('Rótulos preditos')
# Texto do eixo y
ax.set_ylabel('Rótulos verdadeiros')
# Rótulos adicionais
ax.xaxis.set_ticklabels(['pertDOs','DOs'])
ax.yaxis.set_ticklabels(['pertDOs','DOs'])

# Mostra o gráfico
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     18000
#            1       0.99      0.99      0.99     18000
#
#     accuracy                           0.99     36000
#    macro avg       0.99      0.99      0.99     36000
# weighted avg       0.99      0.99      0.99     36000

# %% [markdown]
# ### Listas em pares

# %% [markdown]
# #### Listas de pares de documentos originais e perturbados classificados corretamente

# %%
def listaClassificadoCorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    #if i < 20:    
    # 1 - Coerente
    if linha['classe'] == 1 and linha['predicao'] == 1:
        listaRetorno.append(linha['id'])
    # 0 - Incoerente        
    if linha['classe'] == 0 and linha['predicao'] == 0:
        listaRetorno.append(linha['id'])
  
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaRetornoClassificadoCorretamente = listaClassificadoCorretamente(dfDadosClassificacao)
print('listaRetornoClassificadoCorretamente:', len(listaRetornoClassificadoCorretamente))
# Out:
# listaRetornoClassificadoCorretamente: 35568

# %% [markdown]
# #### Listas de pares de documentos originais e perturbados classificados incorretamente

# %%
def listaClassificadoIncorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    # 1 - Coerente
    if linha['classe'] == 1 and linha['predicao'] == 0:
        listaRetorno.append(linha['id'])
    # 0 - Incoerente
    if linha['classe'] == 0 and linha['predicao'] == 1:
        listaRetorno.append(linha['id'])
  
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])     
  return dflistaRetorno

# %%
listaRetornoClassificadoIncorretamente = listaClassificadoIncorretamente(dfDadosClassificacao)
print('listaRetornoClassificadoIncorretamente:', len(listaRetornoClassificadoIncorretamente))
# Out:
# listaRetornoClassificadoIncorretamente: 432

# %% [markdown]
# #### Acurácia das listas

# %%
total = len(listaRetornoClassificadoCorretamente) + len(listaRetornoClassificadoIncorretamente)
print("Total de documentos:", total)
print("Total de acertos   :", len(listaRetornoClassificadoCorretamente))
print("Total de erros     :", len(listaRetornoClassificadoIncorretamente))
print("Acurácia           :", len(listaRetornoClassificadoCorretamente)/total)
# Out:
# Total de documentos: 36000
# Total de acertos   : 35568
# Total de erros     : 432
# Acurácia           : 0.988

# %% [markdown]
# #### Listas documentos originais e perturbados e suas classificações sem repetições

# %% [markdown]
# Remove as duplicidades dos dados originais.

# %%
print("Com repetição:",len(listaRetornoClassificadoCorretamente))
listaRetornoClassificadoCorretamenteSemRepeticao = listaRetornoClassificadoCorretamente.drop_duplicates(subset=['id'])
print("Sem repetição:", len(listaRetornoClassificadoCorretamenteSemRepeticao))
# Out:
# Com repetição: 35568
# Sem repetição: 18643

# %% [markdown]
# Remove as duplicidades dos dados perturbados.

# %%
print("Com repetição:",len(listaRetornoClassificadoIncorretamente))
listaRetornoClassificadoIncorretamenteSemRepeticao = listaRetornoClassificadoIncorretamente.drop_duplicates(subset=['id'])
print("Sem repetição:", len(listaRetornoClassificadoIncorretamenteSemRepeticao))
# Out:
# Com repetição: 432
# Sem repetição: 319

# %%
print("Documentos originais e perturados e suas classificações:", len(listaRetornoClassificadoCorretamente) + len(listaRetornoClassificadoIncorretamente))
print("  Classificados corretamente(classe=previsão):", len(listaRetornoClassificadoCorretamente))
print("  Classificados incorretamente(classe!=previsão):", len(listaRetornoClassificadoIncorretamente))

DOClasseIncorreta = 0

# Percorre a lista dos documentos originais
for i, linha in lista_documentos_originais.iterrows():
  
  # Limita a quantidade de dados a serem exibidas
  if i < 100:    
  # Procura um documento específico
  #if "Em uma fila a operação de enfileirar ocorre em qual extremidade" in linha['documento']:
    
    # Recupera as POS Tagging do documento original
    documentos_originais_pos = lista_documentos_originais_pos.loc[lista_documentos_originais_pos["id"] == linha['id']]
    #print("documentos_originais_pos[id]:", documentos_originais_pos["id"].values[0])
    
    # Recupera o id documento original se ele foi classificado corretamente    
    documento_id_original = listaRetornoClassificadoCorretamenteSemRepeticao.loc[listaRetornoClassificadoCorretamenteSemRepeticao["id"] == str(linha['id'])]
    #print("documento_id_original:", documento_id_original)

    # Recupera a classificação do original
    classe = ""
    # Se o documento original foi encontrado foi classificado corretamente
    if len(documento_id_original) != 0:
      #print("documento_id_original:",len(documento_id_original))          
      documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == str(documento_id_original['id'].values[0])]
      #print("documento:",documento)
      classe =  str(documento['classe'].values[0])
    else:
      classe = "0"
      DOClasseIncorreta = DOClasseIncorreta + 1

    # Mostra o documento original e sua classificação
    print("\nDO: " + linha["documento"] + " - " + classe)    
    # POSTagging da sentença
    print("    " + " ".join(documentos_originais_pos["pos_documento"].values[0][0][1]))
    
    # Lista com documentos perturbados e sua classificacao
    lista_perturbado_classificado_correto = []
    lista_perturbado_classificado_incorreto = []

    # Percorre os documentos perturbados e suas classificações a partir do original
    for j in range(0, MELHOR_DOCUMENTOS_PERTURBADOS):

        # Id do documento perturbado
        id_perturbado = str(linha['id']) + "_pert_" + str(j)
        #print("id_perturbado:",id_perturbado)

        # localiza os dados do documento perturbado 
        documento_perturbado = lista_documentos_perturbados.loc[lista_documentos_perturbados['id']==id_perturbado].values[0]        
        #print("registro_perturbado_1a_sentenca:", documento_perturbado[3][0][4])
        palavra_mascarada = documento_perturbado[3][0][1]
        token_predito = documento_perturbado[3][0][2]
        peso_predito = documento_perturbado[3][0][3]
        posicao_sorteio = documento_perturbado[3][0][4]

        # Recupera o id documento perturbado se ele foi classificado corretamente
        documento_id_perturbado_correto = listaRetornoClassificadoCorretamenteSemRepeticao.loc[listaRetornoClassificadoCorretamenteSemRepeticao["id"] == id_perturbado]        
        
        # Se foi encontrado foi classificado corretamente
        if len(documento_id_perturbado_correto) != 0:
          versaoPerturbadaClassificada = True
          #print("documento_id_perturbado_correto:",len(documento_id_perturbado_correto))          
          documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == str(documento_id_perturbado_correto['id'].values[0])]
          #print("documento:",documento)
          #saidaPerturbadoCorreto = saidaPerturbadoCorreto + "\n    pert_" + str(j) + ": " + str(documento['documento'].values[0]) + " - " + str(posicao_sorteio) + " - " + str(documento['classe'].values[0])
          lista_perturbado_classificado_correto.append(["pert_" + str(j), str(documento['documento'].values[0]), palavra_mascarada, token_predito, posicao_sorteio, 0 ])

        else:
          # Recupera o id documento perturbado se ele foi classificado incorretamente
          documento_id_perturbado_incorreto = listaRetornoClassificadoIncorretamenteSemRepeticao.loc[listaRetornoClassificadoIncorretamenteSemRepeticao["id"] == id_perturbado]

          # Se foi encontrado foi classificado incorretamente
          if len(documento_id_perturbado_incorreto) != 0:
            #print("documento_id_perturbado_correto:",len(documento_id_perturbado_correto))          
            documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == str(documento_id_perturbado_incorreto['id'].values[0])]
            #print("documento:",documento)
            #saidaPerturbadoIncorreto = saidaPerturbadoIncorreto + "\n    pert_" + str(j) + ": " + str(documento['documento'].values[0]) + " - " + str(posicao_sorteio) + " - 1"            
            lista_perturbado_classificado_incorreto.append(["pert_" + str(j), str(documento['documento'].values[0]), palavra_mascarada, token_predito, posicao_sorteio, 1 ])
                
    lista_perturbado_classificado_correto = sorted(lista_perturbado_classificado_correto, key=lambda x: x[4], reverse=False)
    lista_perturbado_classificado_incorreto = sorted(lista_perturbado_classificado_incorreto, key=lambda x: x[4], reverse=False)

    # Mostra a saída das classificações
    print("  Classificações corretas (classe = predição): " + str(len(lista_perturbado_classificado_correto)))
    if len(lista_perturbado_classificado_correto) != 0:           
      for i, x in enumerate(lista_perturbado_classificado_correto):
          print("  " , x[1]," [" + x[2] + " -> " + x[3] + "(" + str(x[4]) + ")] - ",x[5])
    
    print("  Classificações incorretas(classe != predição): " + str(len(lista_perturbado_classificado_incorreto)))
    if len(lista_perturbado_classificado_incorreto) != 0:           
      for i, x in enumerate(lista_perturbado_classificado_incorreto):
          print("  " ,  x[1]," [" + x[2] + " -> " + x[3] + "(" + str(x[4]) + ")] - ",x[5])

print("\nDocumentos originais classificados incorretamente:", DOClasseIncorreta)
# Out:
# Documentos originais e perturados e suas classificações: 36000
#   Classificados corretamente(classe=previsão): 35568
#   Classificados incorretamente(classe!=previsão): 432
#
# DO: Como pode ser definido um sistema de informação? - 1
#     ADV VERB AUX VERB DET NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Como devem ser definido um sistema de informação ?  [pode -> devem(21)] -  0
#    Como pode ser controlado um sistema de informação ?  [definido -> controlado(25)] -  0
#    Como define ser definido um sistema de informação ?  [pode -> define(43)] -  0
#    Como pode ser atingido um sistema de informação ?  [definido -> atingido(114)] -  0
#    Como geralmente ser definido um sistema de informação ?  [pode -> geralmente(171)] -  0
#    Como pode ser adaptado um sistema de informação ?  [definido -> adaptado(190)] -  0
#    Como age ser definido um sistema de informação ?  [pode -> age(197)] -  0
#    Como ciência ser definido um sistema de informação ?  [pode -> ciência(362)] -  0
#    Como pode ser parte um sistema de informação ?  [definido -> parte(447)] -  0
#    Como precisão ser definido um sistema de informação ?  [pode -> precisão(475)] -  0
#    Como essencial ser definido um sistema de informação ?  [pode -> essencial(509)] -  0
#    Como rede ser definido um sistema de informação ?  [pode -> rede(537)] -  0
#    Como pode ser coberto um sistema de informação ?  [definido -> coberto(541)] -  0
#    Como pode ser essa um sistema de informação ?  [definido -> essa(638)] -  0
#    Como expressa ser definido um sistema de informação ?  [pode -> expressa(655)] -  0
#    Como evoluiu ser definido um sistema de informação ?  [pode -> evoluiu(656)] -  0
#    Como pode ser futuro um sistema de informação ?  [definido -> futuro(761)] -  0
#    Como significado ser definido um sistema de informação ?  [pode -> significado(879)] -  0
#    Como iria ser definido um sistema de informação ?  [pode -> iria(942)] -  0
#    Como pode ser emprestado um sistema de informação ?  [definido -> emprestado(988)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que as soluções tecnológicas automatizam? - 1
#     PRON PRON DET NOUN ADJ VERB PUNCT
#   Classificações corretas (classe = predição): 20
#    O que as soluções tecnológicas encontram ?  [automatizam -> encontram(78)] -  0
#    O que as soluções tecnológicas tomaram ?  [automatizam -> tomaram(191)] -  0
#    O que as soluções tecnológicas tomaram ?  [automatizam -> tomaram(191)] -  0
#    O que as soluções tecnológicas acabaram ?  [automatizam -> acabaram(210)] -  0
#    O que as soluções tecnológicas fornecer ?  [automatizam -> fornecer(275)] -  0
#    O que as soluções tecnológicas serviram ?  [automatizam -> serviram(303)] -  0
#    O que as soluções tecnológicas ainda ?  [automatizam -> ainda(327)] -  0
#    O que as soluções tecnológicas fará ?  [automatizam -> fará(361)] -  0
#    O que as soluções tecnológicas tocaram ?  [automatizam -> tocaram(380)] -  0
#    O que as soluções tecnológicas incluíam ?  [automatizam -> incluíam(436)] -  0
#    O que as soluções tecnológicas derrotaram ?  [automatizam -> derrotaram(452)] -  0
#    O que as soluções tecnológicas derrotaram ?  [automatizam -> derrotaram(452)] -  0
#    O que as soluções tecnológicas só ?  [automatizam -> só(467)] -  0
#    O que as soluções tecnológicas permaneceram ?  [automatizam -> permaneceram(502)] -  0
#    O que as soluções tecnológicas recomenda ?  [automatizam -> recomenda(622)] -  0
#    O que as soluções tecnológicas alcançar ?  [automatizam -> alcançar(787)] -  0
#    O que as soluções tecnológicas das ?  [automatizam -> das(890)] -  0
#    O que as soluções tecnológicas adicionais ?  [automatizam -> adicionais(931)] -  0
#    O que as soluções tecnológicas Melhor ?  [automatizam -> Melhor(971)] -  0
#    O que as soluções tecnológicas atrás ?  [automatizam -> atrás(994)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? - 1
#     ADP SCONJ DET NOUN ADP DET NOUN PUNCT NOUN PUNCT NOUN CCONJ NOUN ADP NOUN VERB PUNCT
#   Classificações corretas (classe = predição): 20
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação chegou ?  [cresce -> chegou(149)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação apresentada ?  [cresce -> apresentada(274)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação apresentada ?  [cresce -> apresentada(274)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação sonora ?  [cresce -> sonora(325)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação perigosa ?  [cresce -> perigosa(404)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação há ?  [cresce -> há(482)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação restrita ?  [cresce -> restrita(493)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação integrada ?  [cresce -> integrada(513)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação pesquisa ?  [cresce -> pesquisa(521)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação alta ?  [cresce -> alta(577)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação aguda ?  [cresce -> aguda(689)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação substancial ?  [cresce -> substancial(734)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação aliada ?  [cresce -> aliada(742)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação iniciada ?  [cresce -> iniciada(747)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação relevantes ?  [cresce -> relevantes(755)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação compreende ?  [cresce -> compreende(763)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação alimenta ?  [cresce -> alimenta(764)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação publicado ?  [cresce -> publicado(828)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação travada ?  [cresce -> travada(888)] -  0
#    Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação Antiga ?  [cresce -> Antiga(919)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Qual um componente indispensável nas organizações? - 1
#     DET DET NOUN ADJ ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Qual um time indispensável nas organizações ?  [componente -> time(88)] -  0
#    Qual um componente indispensável nas sementes ?  [organizações -> sementes(109)] -  0
#    Qual um componente indispensável nas instituições ?  [organizações -> instituições(173)] -  0
#    Qual um componente indispensável nas fontes ?  [organizações -> fontes(303)] -  0
#    Qual um futuro indispensável nas organizações ?  [componente -> futuro(507)] -  0
#    Qual um componente indispensável nas clientes ?  [organizações -> clientes(558)] -  0
#    Qual um componente indispensável nas água ?  [organizações -> água(561)] -  0
#    Qual um exemplar indispensável nas organizações ?  [componente -> exemplar(606)] -  0
#    Qual um adolescente indispensável nas organizações ?  [componente -> adolescente(638)] -  0
#    Qual um componente indispensável nas nucleares ?  [organizações -> nucleares(641)] -  0
#    Qual um componente indispensável nas nucleares ?  [organizações -> nucleares(641)] -  0
#    Qual um constante indispensável nas organizações ?  [componente -> constante(732)] -  0
#    Qual um sexto indispensável nas organizações ?  [componente -> sexto(778)] -  0
#    Qual um componente indispensável nas poesia ?  [organizações -> poesia(790)] -  0
#    Qual um judeu indispensável nas organizações ?  [componente -> judeu(794)] -  0
#    Qual um componente indispensável nas sistemas ?  [organizações -> sistemas(824)] -  0
#    Qual um componente indispensável nas seguintes ?  [organizações -> seguintes(825)] -  0
#    Qual um cronista indispensável nas organizações ?  [componente -> cronista(868)] -  0
#    Qual um dia indispensável nas organizações ?  [componente -> dia(944)] -  0
#    Qual um Estado indispensável nas organizações ?  [componente -> Estado(949)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Em que se concentram as responsabilidades do analista de sistemas? - 1
#     ADP PRON PRON VERB DET NOUN ADP NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Em que se revelam as responsabilidades do analista de sistemas ?  [concentram -> revelam(29)] -  0
#    Em que se afirmam as responsabilidades do analista de sistemas ?  [concentram -> afirmam(86)] -  0
#    Em que se baseado as responsabilidades do analista de sistemas ?  [concentram -> baseado(93)] -  0
#    Em que se estão as responsabilidades do analista de sistemas ?  [concentram -> estão(94)] -  0
#    Em que se determina as responsabilidades do analista de sistemas ?  [concentram -> determina(98)] -  0
#    Em que se sugerem as responsabilidades do analista de sistemas ?  [concentram -> sugerem(156)] -  0
#    Em que se incluíram as responsabilidades do analista de sistemas ?  [concentram -> incluíram(167)] -  0
#    Em que se expressar as responsabilidades do analista de sistemas ?  [concentram -> expressar(226)] -  0
#    Em que se existem as responsabilidades do analista de sistemas ?  [concentram -> existem(260)] -  0
#    Em que se suporta as responsabilidades do analista de sistemas ?  [concentram -> suporta(295)] -  0
#    Em que se destacou as responsabilidades do analista de sistemas ?  [concentram -> destacou(334)] -  0
#    Em que se localizadas as responsabilidades do analista de sistemas ?  [concentram -> localizadas(390)] -  0
#    Em que se organizadas as responsabilidades do analista de sistemas ?  [concentram -> organizadas(409)] -  0
#    Em que se lugar as responsabilidades do analista de sistemas ?  [concentram -> lugar(662)] -  0
#    Em que se descreveu as responsabilidades do analista de sistemas ?  [concentram -> descreveu(716)] -  0
#    Em que se na as responsabilidades do analista de sistemas ?  [concentram -> na(724)] -  0
#    Em que se joga as responsabilidades do analista de sistemas ?  [concentram -> joga(733)] -  0
#    Em que se vis as responsabilidades do analista de sistemas ?  [concentram -> vis(861)] -  0
#    Em que se vem as responsabilidades do analista de sistemas ?  [concentram -> vem(900)] -  0
#    Em que se substitui as responsabilidades do analista de sistemas ?  [concentram -> substitui(946)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que os profissionais da área geram? - 1
#     PRON PRON DET NOUN ADP NOUN VERB PUNCT
#   Classificações corretas (classe = predição): 20
#    O que os profissionais da área passam ?  [geram -> passam(43)] -  0
#    O que os profissionais da área afirmaram ?  [geram -> afirmaram(73)] -  0
#    O que os profissionais da área entende ?  [geram -> entende(161)] -  0
#    O que os profissionais da área de ?  [geram -> de(166)] -  0
#    O que os profissionais da área pretende ?  [geram -> pretende(173)] -  0
#    O que os profissionais da área construíram ?  [geram -> construíram(236)] -  0
#    O que os profissionais da área levaram ?  [geram -> levaram(238)] -  0
#    O que os profissionais da área observa ?  [geram -> observa(245)] -  0
#    O que os profissionais da área mesmos ?  [geram -> mesmos(426)] -  0
#    O que os profissionais da área garante ?  [geram -> garante(461)] -  0
#    O que os profissionais da área mulheres ?  [geram -> mulheres(495)] -  0
#    O que os profissionais da área cita ?  [geram -> cita(514)] -  0
#    O que os profissionais da área digital ?  [geram -> digital(531)] -  0
#    O que os profissionais da área prioridade ?  [geram -> prioridade(647)] -  0
#    O que os profissionais da área viriam ?  [geram -> viriam(752)] -  0
#    O que os profissionais da área dois ?  [geram -> dois(772)] -  0
#    O que os profissionais da área acabaram ?  [geram -> acabaram(786)] -  0
#    O que os profissionais da área anunciaram ?  [geram -> anunciaram(787)] -  0
#    O que os profissionais da área fantasia ?  [geram -> fantasia(924)] -  0
#    O que os profissionais da área cionistas ?  [geram -> cionistas(935)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que é análise de sistemas? - 1
#     PRON PRON AUX NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 18
#    O que é análise de custos ?  [sistemas -> custos(26)] -  0
#    O que é análise de preço ?  [sistemas -> preço(32)] -  0
#    O que é placa de sistemas ?  [análise -> placa(136)] -  0
#    O que é análise de culpa ?  [sistemas -> culpa(224)] -  0
#    O que é análise de doenças ?  [sistemas -> doenças(402)] -  0
#    O que é defensor de sistemas ?  [análise -> defensor(402)] -  0
#    O que é análise de prestígio ?  [sistemas -> prestígio(480)] -  0
#    O que é análise de observação ?  [sistemas -> observação(625)] -  0
#    O que é dados de sistemas ?  [análise -> dados(644)] -  0
#    O que é análise de assuntos ?  [sistemas -> assuntos(748)] -  0
#    O que é análise de paradigma ?  [sistemas -> paradigma(765)] -  0
#    O que é técnicas de sistemas ?  [análise -> técnicas(828)] -  0
#    O que é análise de agentes ?  [sistemas -> agentes(863)] -  0
#    O que é regulamento de sistemas ?  [análise -> regulamento(871)] -  0
#    O que é análise de cor ?  [sistemas -> cor(917)] -  0
#    O que é recursos de sistemas ?  [análise -> recursos(946)] -  0
#    O que é robus de sistemas ?  [análise -> robus(967)] -  0
#    O que é análise de agenda ?  [sistemas -> agenda(980)] -  0
#   Classificações incorretas(classe != predição): 2
#    O que é integração de sistemas ?  [análise -> integração(4)] -  1
#    O que é teoria de sistemas ?  [análise -> teoria(210)] -  1
#
# DO: Onde são executados os softwares gerados pelos profissionais da área? - 1
#     PRON AUX VERB DET NOUN VERB ADP NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Onde são de os softwares gerados pelos profissionais da área ?  [executados -> de(222)] -  0
#    Onde são executados os softwares financeiros pelos profissionais da área ?  [gerados -> financeiros(246)] -  0
#    Onde são executados os softwares pesquisa pelos profissionais da área ?  [gerados -> pesquisa(319)] -  0
#    Onde são executados os softwares comandos pelos profissionais da área ?  [gerados -> comandos(321)] -  0
#    Onde são salvo os softwares gerados pelos profissionais da área ?  [executados -> salvo(337)] -  0
#    Onde são executados os softwares inclusive pelos profissionais da área ?  [gerados -> inclusive(345)] -  0
#    Onde são editores os softwares gerados pelos profissionais da área ?  [executados -> editores(352)] -  0
#    Onde são executados os softwares em pelos profissionais da área ?  [gerados -> em(378)] -  0
#    Onde são móveis os softwares gerados pelos profissionais da área ?  [executados -> móveis(533)] -  0
#    Onde são utilizar os softwares gerados pelos profissionais da área ?  [executados -> utilizar(559)] -  0
#    Onde são os os softwares gerados pelos profissionais da área ?  [executados -> os(564)] -  0
#    Onde são paralelos os softwares gerados pelos profissionais da área ?  [executados -> paralelos(612)] -  0
#    Onde são executados os softwares literários pelos profissionais da área ?  [gerados -> literários(615)] -  0
#    Onde são milhares os softwares gerados pelos profissionais da área ?  [executados -> milhares(627)] -  0
#    Onde são executados os softwares permanentes pelos profissionais da área ?  [gerados -> permanentes(774)] -  0
#    Onde são incluem os softwares gerados pelos profissionais da área ?  [executados -> incluem(781)] -  0
#    Onde são menos os softwares gerados pelos profissionais da área ?  [executados -> menos(782)] -  0
#    Onde são localiza os softwares gerados pelos profissionais da área ?  [executados -> localiza(859)] -  0
#    Onde são engenheiros os softwares gerados pelos profissionais da área ?  [executados -> engenheiros(874)] -  0
#    Onde são executados os softwares X pelos profissionais da área ?  [gerados -> X(1067)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Onde são utilizadas as informações levantadas sobre uma empresa? - 1
#     PRON AUX VERB DET NOUN VERB ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Onde são utilizadas as informações positivas sobre uma empresa ?  [levantadas -> positivas(78)] -  0
#    Onde são utilizadas as informações próprias sobre uma empresa ?  [levantadas -> próprias(98)] -  0
#    Onde são presentes as informações levantadas sobre uma empresa ?  [utilizadas -> presentes(136)] -  0
#    Onde são aproximadamente as informações levantadas sobre uma empresa ?  [utilizadas -> aproximadamente(242)] -  0
#    Onde são utilizadas as informações pessoal sobre uma empresa ?  [levantadas -> pessoal(306)] -  0
#    Onde são quentes as informações levantadas sobre uma empresa ?  [utilizadas -> quentes(356)] -  0
#    Onde são utilizadas as informações para sobre uma empresa ?  [levantadas -> para(403)] -  0
#    Onde são utilizadas as informações através sobre uma empresa ?  [levantadas -> através(408)] -  0
#    Onde são utilizadas as informações já sobre uma empresa ?  [levantadas -> já(426)] -  0
#    Onde são pedidos as informações levantadas sobre uma empresa ?  [utilizadas -> pedidos(440)] -  0
#    Onde são acesso as informações levantadas sobre uma empresa ?  [utilizadas -> acesso(505)] -  0
#    Onde são utilizadas as informações bônus sobre uma empresa ?  [levantadas -> bônus(551)] -  0
#    Onde são inimigas as informações levantadas sobre uma empresa ?  [utilizadas -> inimigas(589)] -  0
#    Onde são utilizadas as informações correndo sobre uma empresa ?  [levantadas -> correndo(672)] -  0
#    Onde são espaciais as informações levantadas sobre uma empresa ?  [utilizadas -> espaciais(709)] -  0
#    Onde são utilizadas as informações segredos sobre uma empresa ?  [levantadas -> segredos(720)] -  0
#    Onde são utilizadas as informações rituais sobre uma empresa ?  [levantadas -> rituais(796)] -  0
#    Onde são utilizadas as informações descrições sobre uma empresa ?  [levantadas -> descrições(797)] -  0
#    Onde são locais as informações levantadas sobre uma empresa ?  [utilizadas -> locais(798)] -  0
#    Onde são utilizadas as informações 1 sobre uma empresa ?  [levantadas -> 1(872)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Por quem são operados os softwares gerados pelos profissionais da área? - 1
#     ADP PRON AUX VERB DET NOUN VERB ADP NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Por quem são relacionados os softwares gerados pelos profissionais da área ?  [operados -> relacionados(110)] -  0
#    Por quem são dispostos os softwares gerados pelos profissionais da área ?  [operados -> dispostos(180)] -  0
#    Por quem são próprios os softwares gerados pelos profissionais da área ?  [operados -> próprios(216)] -  0
#    Por quem são operados os softwares móveis pelos profissionais da área ?  [gerados -> móveis(254)] -  0
#    Por quem são operados os softwares " pelos profissionais da área ?  [gerados -> "(324)] -  0
#    Por quem são equipamentos os softwares gerados pelos profissionais da área ?  [operados -> equipamentos(381)] -  0
#    Por quem são operados os softwares ou pelos profissionais da área ?  [gerados -> ou(397)] -  0
#    Por quem são especialistas os softwares gerados pelos profissionais da área ?  [operados -> especialistas(412)] -  0
#    Por quem são operados os softwares acima pelos profissionais da área ?  [gerados -> acima(424)] -  0
#    Por quem são operados os softwares utilização pelos profissionais da área ?  [gerados -> utilização(449)] -  0
#    Por quem são operados os softwares individualmente pelos profissionais da área ?  [gerados -> individualmente(469)] -  0
#    Por quem são fãs os softwares gerados pelos profissionais da área ?  [operados -> fãs(556)] -  0
#    Por quem são operados os softwares consideradas pelos profissionais da área ?  [gerados -> consideradas(612)] -  0
#    Por quem são demandas os softwares gerados pelos profissionais da área ?  [operados -> demandas(735)] -  0
#    Por quem são operados os softwares coordenadas pelos profissionais da área ?  [gerados -> coordenadas(825)] -  0
#    Por quem são senão os softwares gerados pelos profissionais da área ?  [operados -> senão(927)] -  0
#    Por quem são operados os softwares práticas pelos profissionais da área ?  [gerados -> práticas(945)] -  0
#    Por quem são operados os softwares observado pelos profissionais da área ?  [gerados -> observado(947)] -  0
#    Por quem são operados os softwares conforme pelos profissionais da área ?  [gerados -> conforme(990)] -  0
#    Por quem são operados os softwares conforme pelos profissionais da área ?  [gerados -> conforme(990)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Quem é o responsável pelo levantamento de informações sobre uma empresa? - 1
#     PRON AUX DET NOUN ADP NOUN ADP NOUN ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Quem é o órgão pelo levantamento de informações sobre uma empresa ?  [responsável -> órgão(33)] -  0
#    Quem é o colaborador pelo levantamento de informações sobre uma empresa ?  [responsável -> colaborador(118)] -  0
#    Quem é o responsável pelo levantamento de informações sobre uma filial ?  [empresa -> filial(148)] -  0
#    Quem é o detido pelo levantamento de informações sobre uma empresa ?  [responsável -> detido(151)] -  0
#    Quem é o responsável pelo levantamento de informações sobre uma entrevista ?  [empresa -> entrevista(168)] -  0
#    Quem é o profissional pelo levantamento de informações sobre uma empresa ?  [responsável -> profissional(174)] -  0
#    Quem é o responsável pelo levantamento de informações sobre uma língua ?  [empresa -> língua(224)] -  0
#    Quem é o responsável pelo cumprimento de informações sobre uma empresa ?  [levantamento -> cumprimento(247)] -  0
#    Quem é o aplicado pelo levantamento de informações sobre uma empresa ?  [responsável -> aplicado(263)] -  0
#    Quem é o responsável pelo levantamento de luz sobre uma empresa ?  [informações -> luz(396)] -  0
#    Quem é o impacto pelo levantamento de informações sobre uma empresa ?  [responsável -> impacto(520)] -  0
#    Quem é o responsável pelo levantamento de conflitos sobre uma empresa ?  [informações -> conflitos(540)] -  0
#    Quem é o responsável pelo declínio de informações sobre uma empresa ?  [levantamento -> declínio(541)] -  0
#    Quem é o responsável pelo levantamento de informações sobre uma fatura ?  [empresa -> fatura(545)] -  0
#    Quem é o responsável pelo levantamento de aparência sobre uma empresa ?  [informações -> aparência(651)] -  0
#    Quem é o responsável pelo levantamento de informações sobre uma quadra ?  [empresa -> quadra(718)] -  0
#    Quem é o responsável pelo levantamento de informações sobre uma cozinha ?  [empresa -> cozinha(804)] -  0
#    Quem é o responsável pelo combustível de informações sobre uma empresa ?  [levantamento -> combustível(819)] -  0
#    Quem é o responsável pelo levantamento de estado sobre uma empresa ?  [informações -> estado(845)] -  0
#    Quem é o e pelo levantamento de informações sobre uma empresa ?  [responsável -> e(1049)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? - 1
#     PRON PRON VERB SCONJ SCONJ NOUN PRON ADV VERB NOUN ADJ VERB DET NOUN ADP NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    O que mais com que profissionais que não possuem educação superior compram o papel de analista de sistemas ?  [permite -> mais(40)] -  0
#    O que permite com que profissionais que não sofreram educação superior compram o papel de analista de sistemas ?  [possuem -> sofreram(139)] -  0
#    O que permite com que profissionais que não possuem educação superior corte o papel de analista de sistemas ?  [compram -> corte(189)] -  0
#    O que permite com que profissionais que não essa educação superior compram o papel de analista de sistemas ?  [possuem -> essa(286)] -  0
#    O que permite com que profissionais que não possuem educação superior começam o papel de analista de sistemas ?  [compram -> começam(306)] -  0
#    O que permite com que profissionais que não mesma educação superior compram o papel de analista de sistemas ?  [possuem -> mesma(403)] -  0
#    O que parar com que profissionais que não possuem educação superior compram o papel de analista de sistemas ?  [permite -> parar(411)] -  0
#    O que possível com que profissionais que não possuem educação superior compram o papel de analista de sistemas ?  [permite -> possível(417)] -  0
#    O que permite com que profissionais que não termina educação superior compram o papel de analista de sistemas ?  [possuem -> termina(439)] -  0
#    O que permite com que profissionais que não possuem educação superior prestar o papel de analista de sistemas ?  [compram -> prestar(455)] -  0
#    O que perde com que profissionais que não possuem educação superior compram o papel de analista de sistemas ?  [permite -> perde(573)] -  0
#    O que permite com que profissionais que não possuem educação superior performa o papel de analista de sistemas ?  [compram -> performa(653)] -  0
#    O que sofreu com que profissionais que não possuem educação superior compram o papel de analista de sistemas ?  [permite -> sofreu(733)] -  0
#    O que bastidores com que profissionais que não possuem educação superior compram o papel de analista de sistemas ?  [permite -> bastidores(765)] -  0
#    O que permite com que profissionais que não possuem educação superior conquista o papel de analista de sistemas ?  [compram -> conquista(792)] -  0
#    O que permite com que profissionais que não issem educação superior compram o papel de analista de sistemas ?  [possuem -> issem(800)] -  0
#    O que habilidade com que profissionais que não possuem educação superior compram o papel de analista de sistemas ?  [permite -> habilidade(831)] -  0
#    O que permite com que profissionais que não teve educação superior compram o papel de analista de sistemas ?  [possuem -> teve(901)] -  0
#    O que permite com que profissionais que não possuem educação superior empreendimento o papel de analista de sistemas ?  [compram -> empreendimento(916)] -  0
#   Classificações incorretas(classe != predição): 1
#    O que permite com que profissionais que não tenham educação superior compram o papel de analista de sistemas ?  [possuem -> tenham(3)] -  1
#
# DO: Para o que o analista de sistemas deve servir? - 1
#     ADP PRON PRON DET NOUN ADP NOUN VERB VERB PUNCT
#   Classificações corretas (classe = predição): 19
#    Para o que o analista de sistemas deve chamar ?  [servir -> chamar(131)] -  0
#    Para o que o analista de sistemas do servir ?  [deve -> do(165)] -  0
#    Para o que o analista de sistemas deve competir ?  [servir -> competir(170)] -  0
#    Para o que o analista de sistemas aqui servir ?  [deve -> aqui(261)] -  0
#    Para o que o analista de sistemas deve aponta ?  [servir -> aponta(306)] -  0
#    Para o que o analista de sistemas deve renunciar ?  [servir -> renunciar(314)] -  0
#    Para o que o analista de sistemas sua servir ?  [deve -> sua(393)] -  0
#    Para o que o analista de sistemas segue servir ?  [deve -> segue(549)] -  0
#    Para o que o analista de sistemas professor servir ?  [deve -> professor(578)] -  0
#    Para o que o analista de sistemas deve falta ?  [servir -> falta(679)] -  0
#    Para o que o analista de sistemas deve tar ?  [servir -> tar(710)] -  0
#    Para o que o analista de sistemas deve consciência ?  [servir -> consciência(717)] -  0
#    Para o que o analista de sistemas ologia servir ?  [deve -> ologia(768)] -  0
#    Para o que o analista de sistemas m servir ?  [deve -> m(787)] -  0
#    Para o que o analista de sistemas deve general ?  [servir -> general(793)] -  0
#    Para o que o analista de sistemas deve compet ?  [servir -> compet(928)] -  0
#    Para o que o analista de sistemas deve facilidade ?  [servir -> facilidade(964)] -  0
#    Para o que o analista de sistemas regula servir ?  [deve -> regula(980)] -  0
#    Para o que o analista de sistemas deve exclusivamente ?  [servir -> exclusivamente(981)] -  0
#   Classificações incorretas(classe != predição): 1
#    Para o que o analista de sistemas deve ter ?  [servir -> ter(808)] -  1
#
# DO: Por que o analista de sistemas deve traduzir a necessidade do usuário? - 1
#     ADP SCONJ DET NOUN ADP NOUN VERB VERB DET NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    Por que o analista de sistemas faz traduzir a necessidade do usuário ?  [deve -> faz(41)] -  0
#    Por que o analista de sistemas deve destacar a necessidade do usuário ?  [traduzir -> destacar(74)] -  0
#    Por que o analista de sistemas deve adaptar a necessidade do usuário ?  [traduzir -> adaptar(86)] -  0
#    Por que o analista de sistemas possibilita traduzir a necessidade do usuário ?  [deve -> possibilita(163)] -  0
#    Por que o analista de sistemas deve pedir a necessidade do usuário ?  [traduzir -> pedir(252)] -  0
#    Por que o analista de sistemas identifica traduzir a necessidade do usuário ?  [deve -> identifica(308)] -  0
#    Por que o analista de sistemas deve recorrer a necessidade do usuário ?  [traduzir -> recorrer(369)] -  0
#    Por que o analista de sistemas deve cada a necessidade do usuário ?  [traduzir -> cada(579)] -  0
#    Por que o analista de sistemas deve ir a necessidade do usuário ?  [traduzir -> ir(672)] -  0
#    Por que o analista de sistemas deve tizar a necessidade do usuário ?  [traduzir -> tizar(697)] -  0
#    Por que o analista de sistemas deve relevante a necessidade do usuário ?  [traduzir -> relevante(698)] -  0
#    Por que o analista de sistemas deve conhecido a necessidade do usuário ?  [traduzir -> conhecido(712)] -  0
#    Por que o analista de sistemas vo traduzir a necessidade do usuário ?  [deve -> vo(725)] -  0
#    Por que o analista de sistemas reduz traduzir a necessidade do usuário ?  [deve -> reduz(761)] -  0
#    Por que o analista de sistemas partilha traduzir a necessidade do usuário ?  [deve -> partilha(792)] -  0
#    Por que o analista de sistemas desde traduzir a necessidade do usuário ?  [deve -> desde(851)] -  0
#    Por que o analista de sistemas deve e a necessidade do usuário ?  [traduzir -> e(944)] -  0
#    Por que o analista de sistemas deve detecção a necessidade do usuário ?  [traduzir -> detecção(975)] -  0
#    Por que o analista de sistemas deve diferencial a necessidade do usuário ?  [traduzir -> diferencial(980)] -  0
#   Classificações incorretas(classe != predição): 1
#    Por que o analista de sistemas poderia traduzir a necessidade do usuário ?  [deve -> poderia(17)] -  1
#
# DO: Quem desenvolve o programa traduzido da necessidade do usuário pelo analista de sistemas? - 1
#     PRON VERB DET NOUN VERB ADP NOUN ADP NOUN ADP NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    Quem administra o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> administra(83)] -  0
#    Quem desenvolve o programa saindo da necessidade do usuário pelo analista de sistemas ?  [traduzido -> saindo(118)] -  0
#    Quem importa o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> importa(131)] -  0
#    Quem desenvolve o programa responsável da necessidade do usuário pelo analista de sistemas ?  [traduzido -> responsável(139)] -  0
#    Quem nomeou o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> nomeou(246)] -  0
#    Quem desenvolve o programa enviado da necessidade do usuário pelo analista de sistemas ?  [traduzido -> enviado(248)] -  0
#    Quem defende o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> defende(328)] -  0
#    Quem consulta o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> consulta(379)] -  0
#    Quem perguntou o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> perguntou(490)] -  0
#    Quem desenvolve o programa seguro da necessidade do usuário pelo analista de sistemas ?  [traduzido -> seguro(505)] -  0
#    Quem desenvolve o programa seguro da necessidade do usuário pelo analista de sistemas ?  [traduzido -> seguro(505)] -  0
#    Quem rejeita o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> rejeita(525)] -  0
#    Quem monte o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> monte(533)] -  0
#    Quem protege o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> protege(581)] -  0
#    Quem atual o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> atual(709)] -  0
#    Quem desenvolve o programa manual da necessidade do usuário pelo analista de sistemas ?  [traduzido -> manual(735)] -  0
#    Quem compara o programa traduzido da necessidade do usuário pelo analista de sistemas ?  [desenvolve -> compara(798)] -  0
#    Quem desenvolve o programa manifestação da necessidade do usuário pelo analista de sistemas ?  [traduzido -> manifestação(979)] -  0
#    Quem desenvolve o programa surgimento da necessidade do usuário pelo analista de sistemas ?  [traduzido -> surgimento(988)] -  0
#   Classificações incorretas(classe != predição): 1
#    Quem desenvolve o programa criado da necessidade do usuário pelo analista de sistemas ?  [traduzido -> criado(285)] -  1
#
# DO: Em que deve ser formado um profissional em análise e desenvolvimento de sistemas? - 1
#     ADP PRON VERB AUX VERB DET NOUN ADP NOUN CCONJ NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    Em que deve ser avançado um profissional em análise e desenvolvimento de sistemas ?  [formado -> avançado(118)] -  0
#    Em que deve ser para um profissional em análise e desenvolvimento de sistemas ?  [formado -> para(150)] -  0
#    Em que motivo ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> motivo(251)] -  0
#    Em que deve ser exemplo um profissional em análise e desenvolvimento de sistemas ?  [formado -> exemplo(384)] -  0
#    Em que especialista ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> especialista(415)] -  0
#    Em que deve ser subordinado um profissional em análise e desenvolvimento de sistemas ?  [formado -> subordinado(457)] -  0
#    Em que países ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> países(587)] -  0
#    Em que uma ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> uma(596)] -  0
#    Em que teria ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> teria(614)] -  0
#    Em que deve ser desenhista um profissional em análise e desenvolvimento de sistemas ?  [formado -> desenhista(674)] -  0
#    Em que obrigações ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> obrigações(737)] -  0
#    Em que grupo ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> grupo(743)] -  0
#    Em que deve ser demanda um profissional em análise e desenvolvimento de sistemas ?  [formado -> demanda(782)] -  0
#    Em que pré ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> pré(858)] -  0
#    Em que deve ser talentos um profissional em análise e desenvolvimento de sistemas ?  [formado -> talentos(898)] -  0
#    Em que deve ser paixão um profissional em análise e desenvolvimento de sistemas ?  [formado -> paixão(926)] -  0
#    Em que esporte ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> esporte(995)] -  0
#    Em que conseguir ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> conseguir(999)] -  0
#    Em que arquitetura ser formado um profissional em análise e desenvolvimento de sistemas ?  [deve -> arquitetura(1047)] -  0
#   Classificações incorretas(classe != predição): 1
#    Em que deve ser contratado um profissional em análise e desenvolvimento de sistemas ?  [formado -> contratado(15)] -  1
#
# DO: O que curso superior em análise e desenvolvimento de sistemas visa? - 1
#     PRON PRON NOUN ADJ ADP NOUN CCONJ NOUN ADP NOUN VERB PUNCT
#   Classificações corretas (classe = predição): 20
#    O que curso superior em análise e desenvolvimento de sistemas FA ?  [visa -> FA(188)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas reconhece ?  [visa -> reconhece(251)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas estrutura ?  [visa -> estrutura(285)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas 3 ?  [visa -> 3(317)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas ocorre ?  [visa -> ocorre(520)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas A ?  [visa -> A(521)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas interessado ?  [visa -> interessado(636)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas estudos ?  [visa -> estudos(684)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas simples ?  [visa -> simples(773)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas exata ?  [visa -> exata(797)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas ocupam ?  [visa -> ocupam(824)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas seguro ?  [visa -> seguro(833)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas sustenta ?  [visa -> sustenta(881)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas sites ?  [visa -> sites(942)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas cons ?  [visa -> cons(950)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas Letras ?  [visa -> Letras(964)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas Letras ?  [visa -> Letras(964)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas lê ?  [visa -> lê(974)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas Faze ?  [visa -> Faze(1074)] -  0
#    O que curso superior em análise e desenvolvimento de sistemas Direito ?  [visa -> Direito(1099)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Por quem foi designada a profissão de tecnólogo em análise e desenvolvimento de sistemas? - 1
#     ADP PRON AUX VERB DET NOUN ADP NOUN ADP NOUN CCONJ NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Por quem foi tentar a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> tentar(245)] -  0
#    Por quem foi mesmo a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> mesmo(260)] -  0
#    Por quem foi extinto a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> extinto(279)] -  0
#    Por quem foi exerc a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> exerc(308)] -  0
#    Por quem foi estimada a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> estimada(387)] -  0
#    Por quem foi instalado a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> instalado(443)] -  0
#    Por quem foi minha a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> minha(482)] -  0
#    Por quem foi conseguir a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> conseguir(521)] -  0
#    Por quem foi tido a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> tido(614)] -  0
#    Por quem foi especifica a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> especifica(643)] -  0
#    Por quem foi oferecidos a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> oferecidos(680)] -  0
#    Por quem foi formou a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> formou(740)] -  0
#    Por quem foi tocado a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> tocado(795)] -  0
#    Por quem foi provocado a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> provocado(805)] -  0
#    Por quem foi agregado a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> agregado(842)] -  0
#    Por quem foi agregado a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> agregado(842)] -  0
#    Por quem foi tem a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> tem(843)] -  0
#    Por quem foi conheceram a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> conheceram(942)] -  0
#    Por quem foi marcado a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> marcado(957)] -  0
#    Por quem foi cercado a profissão de tecnólogo em análise e desenvolvimento de sistemas ?  [designada -> cercado(959)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Qual deve ser a ênfase do curso universitário dos analistas de sistemas? - 1
#     NOUN VERB AUX DET NOUN ADP NOUN ADJ ADP NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    Qual costumava ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> costumava(28)] -  0
#    Qual podia ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> podia(40)] -  0
#    Qual procura ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> procura(55)] -  0
#    Qual ideal ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> ideal(66)] -  0
#    Qual , ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> ,(117)] -  0
#    Qual se ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> se(135)] -  0
#    Qual dita ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> dita(150)] -  0
#    Qual diferencial ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> diferencial(208)] -  0
#    Qual programa ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> programa(263)] -  0
#    Qual opção ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> opção(311)] -  0
#    Qual desafio ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> desafio(377)] -  0
#    Qual solução ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> solução(428)] -  0
#    Qual identifica ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> identifica(525)] -  0
#    Qual seguir ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> seguir(548)] -  0
#    Qual teor ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> teor(553)] -  0
#    Qual raça ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> raça(758)] -  0
#    Qual proposto ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> proposto(799)] -  0
#    Qual aí ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> aí(881)] -  0
#    Qual unidade ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> unidade(975)] -  0
#   Classificações incorretas(classe != predição): 1
#    Qual parece ser a ênfase do curso universitário dos analistas de sistemas ?  [deve -> parece(11)] -  1
#
# DO: Quem emite a carteira profissional dos analistas de sistemas? - 1
#     PRON VERB DET NOUN ADJ ADP NOUN ADP NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Quem regula a carteira profissional dos analistas de sistemas ?  [emite -> regula(18)] -  0
#    Quem pagou a carteira profissional dos analistas de sistemas ?  [emite -> pagou(58)] -  0
#    Quem sustenta a carteira profissional dos analistas de sistemas ?  [emite -> sustenta(61)] -  0
#    Quem concedeu a carteira profissional dos analistas de sistemas ?  [emite -> concedeu(110)] -  0
#    Quem trabalha a carteira profissional dos analistas de sistemas ?  [emite -> trabalha(114)] -  0
#    Quem nega a carteira profissional dos analistas de sistemas ?  [emite -> nega(201)] -  0
#    Quem alterou a carteira profissional dos analistas de sistemas ?  [emite -> alterou(202)] -  0
#    Quem fundou a carteira profissional dos analistas de sistemas ?  [emite -> fundou(261)] -  0
#    Quem concluiu a carteira profissional dos analistas de sistemas ?  [emite -> concluiu(302)] -  0
#    Quem melhora a carteira profissional dos analistas de sistemas ?  [emite -> melhora(362)] -  0
#    Quem encerra a carteira profissional dos analistas de sistemas ?  [emite -> encerra(367)] -  0
#    Quem ama a carteira profissional dos analistas de sistemas ?  [emite -> ama(548)] -  0
#    Quem for a carteira profissional dos analistas de sistemas ?  [emite -> for(643)] -  0
#    Quem pedia a carteira profissional dos analistas de sistemas ?  [emite -> pedia(673)] -  0
#    Quem compara a carteira profissional dos analistas de sistemas ?  [emite -> compara(679)] -  0
#    Quem efetiva a carteira profissional dos analistas de sistemas ?  [emite -> efetiva(696)] -  0
#    Quem caça a carteira profissional dos analistas de sistemas ?  [emite -> caça(856)] -  0
#    Quem criam a carteira profissional dos analistas de sistemas ?  [emite -> criam(870)] -  0
#    Quem enviar a carteira profissional dos analistas de sistemas ?  [emite -> enviar(889)] -  0
#    Quem faze a carteira profissional dos analistas de sistemas ?  [emite -> faze(921)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: O que aumenta a procura por profissionais com conhecimento para desenvolver sistemas? - 1
#     PRON PRON VERB DET NOUN ADP NOUN ADP NOUN SCONJ VERB NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    O que provoca a procura por profissionais com conhecimento para desenvolver sistemas ?  [aumenta -> provoca(16)] -  0
#    O que aumenta a procura por profissionais com conhecimento para adaptar sistemas ?  [desenvolver -> adaptar(58)] -  0
#    O que estuda a procura por profissionais com conhecimento para desenvolver sistemas ?  [aumenta -> estuda(215)] -  0
#    O que aumenta a procura por profissionais com conhecimento para complexo sistemas ?  [desenvolver -> complexo(259)] -  0
#    O que aumenta a procura por profissionais com conhecimento para ntar sistemas ?  [desenvolver -> ntar(286)] -  0
#    O que fizeram a procura por profissionais com conhecimento para desenvolver sistemas ?  [aumenta -> fizeram(370)] -  0
#    O que aumenta a procura por profissionais com conhecimento para aproximar sistemas ?  [desenvolver -> aproximar(387)] -  0
#    O que grande a procura por profissionais com conhecimento para desenvolver sistemas ?  [aumenta -> grande(408)] -  0
#    O que aumenta a procura por profissionais com conhecimento para plataforma sistemas ?  [desenvolver -> plataforma(523)] -  0
#    O que aumenta a procura por profissionais com conhecimento para comer sistemas ?  [desenvolver -> comer(580)] -  0
#    O que viria a procura por profissionais com conhecimento para desenvolver sistemas ?  [aumenta -> viria(640)] -  0
#    O que aumenta a procura por profissionais com conhecimento para infer sistemas ?  [desenvolver -> infer(702)] -  0
# ...
#    Por que o dispositivo de Babbage se critica de outros dispositivos ?  [diferenciava -> critica(971)] -  0
#   Classificações incorretas(classe != predição): 1
#    Por que o dispositivo de Babbage se distingue de outros dispositivos ?  [diferenciava -> distingue(2)] -  1
#
# DO: Quando o computador foi originalmente descrito? - 1
#     SCONJ DET NOUN AUX ADV VERB PUNCT
#   Classificações corretas (classe = predição): 19
#    Quando o computador foi originalmente pensando ?  [descrito -> pensando(58)] -  0
#    Quando o computador foi originalmente armado ?  [descrito -> armado(89)] -  0
#    Quando o computador foi originalmente cunhado ?  [descrito -> cunhado(119)] -  0
#    Quando o computador foi originalmente escravo ?  [descrito -> escravo(333)] -  0
#    Quando o computador foi originalmente especial ?  [descrito -> especial(340)] -  0
#    Quando o computador foi originalmente confirmado ?  [descrito -> confirmado(348)] -  0
#    Quando o computador foi originalmente japonês ?  [descrito -> japonês(378)] -  0
#    Quando o computador foi originalmente doméstico ?  [descrito -> doméstico(399)] -  0
#    Quando o computador foi originalmente mentado ?  [descrito -> mentado(528)] -  0
#    Quando o computador foi originalmente navegador ?  [descrito -> navegador(652)] -  0
#    Quando o computador foi originalmente Intel ?  [descrito -> Intel(681)] -  0
#    Quando o computador foi originalmente bonito ?  [descrito -> bonito(683)] -  0
#    Quando o computador foi originalmente acusado ?  [descrito -> acusado(760)] -  0
#    Quando o computador foi originalmente teclado ?  [descrito -> teclado(821)] -  0
#    Quando o computador foi originalmente lançando ?  [descrito -> lançando(882)] -  0
#    Quando o computador foi originalmente net ?  [descrito -> net(893)] -  0
#    Quando o computador foi originalmente Pro ?  [descrito -> Pro(969)] -  0
#    Quando o computador foi originalmente h ?  [descrito -> h(984)] -  0
#    Quando o computador foi originalmente alimentar ?  [descrito -> alimentar(988)] -  0
#   Classificações incorretas(classe != predição): 1
#    Quando o computador foi originalmente transformado ?  [descrito -> transformado(146)] -  1
#
# DO: Quem é considerada a primeira programadora? - 1
#     PRON AUX VERB DET ADJ NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Quem é apenas a primeira programadora ?  [considerada -> apenas(32)] -  0
#    Quem é certamente a primeira programadora ?  [considerada -> certamente(46)] -  0
#    Quem é pessoalmente a primeira programadora ?  [considerada -> pessoalmente(118)] -  0
#    Quem é então a primeira programadora ?  [considerada -> então(150)] -  0
#    Quem é . a primeira programadora ?  [considerada -> .(171)] -  0
#    Quem é / a primeira programadora ?  [considerada -> /(255)] -  0
#    Quem é não a primeira programadora ?  [considerada -> não(329)] -  0
#    Quem é diretamente a primeira programadora ?  [considerada -> diretamente(458)] -  0
#    Quem é amigo a primeira programadora ?  [considerada -> amigo(567)] -  0
#    Quem é caso a primeira programadora ?  [considerada -> caso(640)] -  0
#    Quem é estabelecida a primeira programadora ?  [considerada -> estabelecida(653)] -  0
#    Quem é peculiar a primeira programadora ?  [considerada -> peculiar(655)] -  0
#    Quem é santa a primeira programadora ?  [considerada -> santa(678)] -  0
#    Quem é Freud a primeira programadora ?  [considerada -> Freud(713)] -  0
#    Quem é patrono a primeira programadora ?  [considerada -> patrono(798)] -  0
#    Quem é aluno a primeira programadora ?  [considerada -> aluno(810)] -  0
#    Quem é próximo a primeira programadora ?  [considerada -> próximo(861)] -  0
#    Quem é figura a primeira programadora ?  [considerada -> figura(864)] -  0
#    Quem é modificada a primeira programadora ?  [considerada -> modificada(887)] -  0
#    Quem é cultural a primeira programadora ?  [considerada -> cultural(978)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Qual o termo utilizado para definir sequências de passos para completar uma tarefa? - 1
#     DET DET NOUN VERB SCONJ VERB NOUN ADP NOUN SCONJ VERB DET NOUN PUNCT
#   Classificações corretas (classe = predição): 19
#    Qual o termo disponível para definir sequências de passos para completar uma tarefa ?  [utilizado -> disponível(18)] -  0
#    Qual o termo utilizado para significar sequências de passos para completar uma tarefa ?  [definir -> significar(27)] -  0
#    Qual o termo utilizado para termo sequências de passos para completar uma tarefa ?  [definir -> termo(81)] -  0
#    Qual o termo utilizado para reduzir sequências de passos para completar uma tarefa ?  [definir -> reduzir(111)] -  0
#    Qual o termo conveniente para definir sequências de passos para completar uma tarefa ?  [utilizado -> conveniente(134)] -  0
#    Qual o termo utilizado para provocar sequências de passos para completar uma tarefa ?  [definir -> provocar(156)] -  0
#    Qual o termo utilizado para definir sequências de passos para fixar uma tarefa ?  [completar -> fixar(295)] -  0
#    Qual o termo mecânico para definir sequências de passos para completar uma tarefa ?  [utilizado -> mecânico(390)] -  0
#    Qual o termo delegado para definir sequências de passos para completar uma tarefa ?  [utilizado -> delegado(469)] -  0
#    Qual o termo utilizado para trás sequências de passos para completar uma tarefa ?  [definir -> trás(477)] -  0
#    Qual o termo utilizado para definir sequências de passos para percorre uma tarefa ?  [completar -> percorre(480)] -  0
#    Qual o termo utilizado para definir sequências de passos para conduz uma tarefa ?  [completar -> conduz(561)] -  0
#    Qual o termo web para definir sequências de passos para completar uma tarefa ?  [utilizado -> web(642)] -  0
#    Qual o termo judeu para definir sequências de passos para completar uma tarefa ?  [utilizado -> judeu(692)] -  0
#    Qual o termo utilizado para definir sequências de passos para engloba uma tarefa ?  [completar -> engloba(761)] -  0
#    Qual o termo utilizado para definir sequências de passos para eita uma tarefa ?  [completar -> eita(804)] -  0
#    Qual o termo utilizado para ir sequências de passos para completar uma tarefa ?  [definir -> ir(815)] -  0
#    Qual o termo óp para definir sequências de passos para completar uma tarefa ?  [utilizado -> óp(824)] -  0
#    Qual o termo frequentemente para definir sequências de passos para completar uma tarefa ?  [utilizado -> frequentemente(863)] -  0
#   Classificações incorretas(classe != predição): 1
#    Qual o termo utilizado para calcular sequências de passos para completar uma tarefa ?  [definir -> calcular(84)] -  1
#
# DO: Quando o livro Calculando com numerais hindus foi traduzido para o latim? - 1
#     SCONJ DET NOUN VERB ADP NOUN ADJ AUX VERB ADP DET NOUN PUNCT
#   Classificações corretas (classe = predição): 20
#    Quando o livro budista com numerais hindus foi traduzido para o latim ?  [Calculando -> budista(60)] -  0
#    Quando o livro nascido com numerais hindus foi traduzido para o latim ?  [Calculando -> nascido(194)] -  0
#    Quando o livro fundamental com numerais hindus foi traduzido para o latim ?  [Calculando -> fundamental(231)] -  0
#    Quando o livro Calculando com numerais hindus foi material para o latim ?  [traduzido -> material(238)] -  0
#    Quando o livro Calculando com numerais hindus foi para para o latim ?  [traduzido -> para(240)] -  0
#    Quando o livro nove com numerais hindus foi traduzido para o latim ?  [Calculando -> nove(287)] -  0
#    Quando o livro Daniel com numerais hindus foi traduzido para o latim ?  [Calculando -> Daniel(313)] -  0
#    Quando o livro dela com numerais hindus foi traduzido para o latim ?  [Calculando -> dela(349)] -  0
#    Quando o livro fixo com numerais hindus foi traduzido para o latim ?  [Calculando -> fixo(405)] -  0
#    Quando o livro vem com numerais hindus foi traduzido para o latim ?  [Calculando -> vem(472)] -  0
#    Quando o livro distribuído com numerais hindus foi traduzido para o latim ?  [Calculando -> distribuído(495)] -  0
#    Quando o livro lida com numerais hindus foi traduzido para o latim ?  [Calculando -> lida(548)] -  0
#    Quando o livro incrível com numerais hindus foi traduzido para o latim ?  [Calculando -> incrível(699)] -  0
#    Quando o livro ia com numerais hindus foi traduzido para o latim ?  [Calculando -> ia(770)] -  0
#    Quando o livro Calculando com numerais hindus foi referência para o latim ?  [traduzido -> referência(808)] -  0
#    Quando o livro usual com numerais hindus foi traduzido para o latim ?  [Calculando -> usual(834)] -  0
#    Quando o livro 95 com numerais hindus foi traduzido para o latim ?  [Calculando -> 95(838)] -  0
#    Quando o livro Calculando com numerais hindus foi saída para o latim ?  [traduzido -> saída(868)] -  0
#    Quando o livro Calculando com numerais hindus foi forma para o latim ?  [traduzido -> forma(879)] -  0
#    Quando o livro publicados com numerais hindus foi traduzido para o latim ?  [Calculando -> publicados(935)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Quem foi o primeiro a explicar o sistema de numeração hindu-arábico? - 1
#     PRON AUX DET ADJ SCONJ VERB DET NOUN ADP NOUN ADJ PUNCT
#   Classificações corretas (classe = predição): 20
#    Quem foi o primeiro a formar o sistema de numeração hindu-arábico ?  [explicar -> formar(77)] -  0
#    Quem foi o primeiro a manter o sistema de numeração hindu-arábico ?  [explicar -> manter(80)] -  0
#    Quem foi o primeiro a tornar o sistema de numeração hindu-arábico ?  [explicar -> tornar(192)] -  0
#    Quem foi o primeiro a ouvir o sistema de numeração hindu-arábico ?  [explicar -> ouvir(194)] -  0
#    Quem foi o primeiro a roubar o sistema de numeração hindu-arábico ?  [explicar -> roubar(217)] -  0
#    Quem foi o primeiro a invent o sistema de numeração hindu-arábico ?  [explicar -> invent(232)] -  0
#    Quem foi o primeiro a incentivar o sistema de numeração hindu-arábico ?  [explicar -> incentivar(272)] -  0
#    Quem foi o primeiro a sair o sistema de numeração hindu-arábico ?  [explicar -> sair(320)] -  0
#    Quem foi o primeiro a descobri o sistema de numeração hindu-arábico ?  [explicar -> descobri(373)] -  0
#    Quem foi o primeiro a considerado o sistema de numeração hindu-arábico ?  [explicar -> considerado(415)] -  0
#    Quem foi o primeiro a continuar o sistema de numeração hindu-arábico ?  [explicar -> continuar(421)] -  0
#    Quem foi o primeiro a público o sistema de numeração hindu-arábico ?  [explicar -> público(432)] -  0
#    Quem foi o primeiro a consulta o sistema de numeração hindu-arábico ?  [explicar -> consulta(612)] -  0
#    Quem foi o primeiro a racional o sistema de numeração hindu-arábico ?  [explicar -> racional(628)] -  0
#    Quem foi o primeiro a fez o sistema de numeração hindu-arábico ?  [explicar -> fez(713)] -  0
#    Quem foi o primeiro a tentaram o sistema de numeração hindu-arábico ?  [explicar -> tentaram(743)] -  0
#    Quem foi o primeiro a aceitação o sistema de numeração hindu-arábico ?  [explicar -> aceitação(811)] -  0
#    Quem foi o primeiro a toda o sistema de numeração hindu-arábico ?  [explicar -> toda(814)] -  0
#    Quem foi o primeiro a explicou o sistema de numeração hindu-arábico ?  [explicar -> explicou(882)] -  0
#    Quem foi o primeiro a ( o sistema de numeração hindu-arábico ?  [explicar -> ((940)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Quem foi o primeiro a explicar o uso do 0? - 1
#     PRON AUX DET ADJ SCONJ VERB DET NOUN ADP NUM PUNCT
#   Classificações corretas (classe = predição): 20
#    Quem foi o primeiro a identificar o uso do 0 ?  [explicar -> identificar(40)] -  0
#    Quem foi o primeiro a promover o uso do 0 ?  [explicar -> promover(51)] -  0
#    Quem foi o primeiro a parar o uso do 0 ?  [explicar -> parar(157)] -  0
#    Quem foi o primeiro a negociar o uso do 0 ?  [explicar -> negociar(191)] -  0
#    Quem foi o primeiro a ser o uso do 0 ?  [explicar -> ser(220)] -  0
#    Quem foi o primeiro a cobrir o uso do 0 ?  [explicar -> cobrir(290)] -  0
#    Quem foi o primeiro a afetar o uso do 0 ?  [explicar -> afetar(349)] -  0
#    Quem foi o primeiro a vir o uso do 0 ?  [explicar -> vir(376)] -  0
#    Quem foi o primeiro a racional o uso do 0 ?  [explicar -> racional(400)] -  0
#    Quem foi o primeiro a criou o uso do 0 ?  [explicar -> criou(434)] -  0
#    Quem foi o primeiro a , o uso do 0 ?  [explicar -> ,(448)] -  0
#    Quem foi o primeiro a crescer o uso do 0 ?  [explicar -> crescer(478)] -  0
#    Quem foi o primeiro a polêmica o uso do 0 ?  [explicar -> polêmica(575)] -  0
#    Quem foi o primeiro a Note o uso do 0 ?  [explicar -> Note(689)] -  0
#    Quem foi o primeiro a iniciado o uso do 0 ?  [explicar -> iniciado(726)] -  0
#    Quem foi o primeiro a utilizado o uso do 0 ?  [explicar -> utilizado(851)] -  0
#    Quem foi o primeiro a revelou o uso do 0 ?  [explicar -> revelou(862)] -  0
#    Quem foi o primeiro a diferencia o uso do 0 ?  [explicar -> diferencia(884)] -  0
#    Quem foi o primeiro a a o uso do 0 ?  [explicar -> a(952)] -  0
#    Quem foi o primeiro a embora o uso do 0 ?  [explicar -> embora(962)] -  0
#   Classificações incorretas(classe != predição): 0
#
# DO: Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? - 1
#     PRON AUX ADJ ADP NOUN ADP NOUN ADP NOUN ADJ ADP PROPN PROPN PUNCT
#   Classificações corretas (classe = predição): 20
#    Quem foi responsável pela difusão do formato de numeração hindu-arábico no Oriente Médio ?  [sistema -> formato(16)] -  0
#    Quem foi responsável pela difusão do registro de numeração hindu-arábico no Oriente Médio ?  [sistema -> registro(25)] -  0
#    Quem foi responsável pela introduziu do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> introduziu(129)] -  0
#    Quem foi responsável pela difusão do consenso de numeração hindu-arábico no Oriente Médio ?  [sistema -> consenso(211)] -  0
#    Quem foi responsável pela experiência do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> experiência(341)] -  0
#    Quem foi responsável pela difusão do sistema de arte hindu-arábico no Oriente Médio ?  [numeração -> arte(349)] -  0
#    Quem foi responsável pela instrução do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> instrução(459)] -  0
#    Quem foi responsável pela difusão do combinado de numeração hindu-arábico no Oriente Médio ?  [sistema -> combinado(488)] -  0
#    Quem foi responsável pela difusão do tetra de numeração hindu-arábico no Oriente Médio ?  [sistema -> tetra(552)] -  0
#    Quem foi responsável pela difusão do cristianismo de numeração hindu-arábico no Oriente Médio ?  [sistema -> cristianismo(613)] -  0
#    Quem foi responsável pela concorrência do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> concorrência(615)] -  0
#    Quem foi responsável pela firma do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> firma(669)] -  0
#    Quem foi responsável pela consequência do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> consequência(750)] -  0
#    Quem foi responsável pela difusão do branco de numeração hindu-arábico no Oriente Médio ?  [sistema -> branco(763)] -  0
#    Quem foi responsável pela paródia do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> paródia(810)] -  0
#    Quem foi responsável pela difusão do criador de numeração hindu-arábico no Oriente Médio ?  [sistema -> criador(887)] -  0
#    Quem foi responsável pela trama do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> trama(906)] -  0
#    Quem foi responsável pela difusão do artificial de numeração hindu-arábico no Oriente Médio ?  [sistema -> artificial(939)] -  0
#    Quem foi responsável pela difusão do sistema de química hindu-arábico no Oriente Médio ?  [numeração -> química(990)] -  0
#    Quem foi responsável pela corte do sistema de numeração hindu-arábico no Oriente Médio ?  [difusão -> corte(1033)] -  0
#   Classificações incorretas(classe != predição): 0
#
# Documentos originais classificados incorretamente: 0

# %% [markdown]
# #### Listas documentos originais e perturbados classificados corretamente

# %%
print("Documentos originais e perturbados classificados corretamente(classe=previsão):", len(listaRetornoClassificadoCorretamente))
conta = 0
for i, linha in listaRetornoClassificadoCorretamente.iterrows():
  conta = conta + 1
  if i < 2000:    
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == linha["id"]]       
    if len(documento)!= 0:    
      print("   ", conta, documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Documentos originais e perturbados classificados corretamente(classe=previsão): 35568
#     1 Qual é o nome dado à máquina que alcançou polinômios por meio de diferenças ? 0
#     2 Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#     3 Em quantos segundos o Mark I X multiplicar dois números de dez dígitos ? 0
#     4 Quando o curso de Engenharia de Sistemas e Computação da UERJ começou a funcionar? 1
#     5 Quando o curso de Engenharia de Sistemas e Computação da UERJ começou a 1978 ? 0
#     6 Quando o curso de Engenharia de Sistemas e Computação da UERJ começou a funcionar? 1
#     7 Quando o curso de Engenharia de Sistemas e Computação da UERJ iniciando a funcionar ? 0
#     8 O que os modelos usados pelos fundamentos científicos da engenharia de software devem permitir ao engenheiro? 1
#     9 O que os modelos os pelos fundamentos científicos da engenharia de software devem permitir ao engenheiro ? 0
#     10 O que os modelos usados pelos fundamentos científicos da engenharia de software devem permitir ao engenheiro? 1
#     11 O que os modelos armados pelos fundamentos científicos da engenharia de software devem permitir ao engenheiro ? 0
#     12 Pelo que a instituição de ensino gostaria com a interveniência da celebração do contrato ? 0
#     13 Pelo que a instituição de ensino soube com a interveniência da celebração do contrato ? 0
#     14 O que a gestante deve fazer para requisitar o regime de exercícios domiciliares? 1
#     15 O que a gestante deve fazer para requisitar o regime de exercícios domiciliares? 1
#     16 O que a gestante federal fazer para requisitar o regime de exercícios domiciliares ? 0
#     17 Como o aluno pode adquirir conhecimento sem o acompanhamento de um professor? 1
#     18 Como o aluno pode comer conhecimento sem o acompanhamento de um professor ? 0
#     19 Para que engenheiros eletricistas contruiam circuitos eletrônicos? 1
#     20 Para que pescadores eletricistas contruiam circuitos eletrônicos ? 0
#     21 Para que engenheiros eletricistas contruiam circuitos eletrônicos? 1
#     22 Para que engenheiros eletricistas contruiam compostos eletrônicos ? 0
#     23 Quais áreas são fundamentadas no conteúdo da teoria da informação? 1
#     24 Os estudos da ciência da computação podem ser aplicadas em quais áreas? 1
#     25 Os estudos da ciência da computação podem ser parceiros em quais áreas ? 0
#     26 Os estudos da ciência da computação podem ser aplicadas em quais áreas? 1
#     27 Os estudos da ciência da computação podem ser mesmos em quais áreas ? 0
#     28 Com o que estão relacionados as inovações e aspectos teóricos da computação? 1
#     29 Com o que estão relacionados as formações e aspectos teóricos da computação ? 0
#     30 Com o que estão relacionados as inovações e aspectos teóricos da computação? 1
#     31 Com o que estão relacionados as inovações e aspectos teóricos da média ? 0
#     32 O que foi confirmado pelo tear controlado por cartão perfurado ? 0
#     33 Quem tá o cálculo ? 0
#     34 Quem tirou o cálculo ? 0
#     35 O que é IBM? 1
#     36 O que pre IBM ? 0
#     37 O que é IBM? 1
#     38 O que distingue IBM ? 0
#     39 O que são programas? 1
#     40 O que são hotéis ? 0
#     41 O que são programas? 1
#     42 O que são anéis ? 0
#     43 O que são programas? 1
#     44 O que são contribuições ? 0
#     45 O que são programas? 1
#     46 O que são prémios ? 0
#     47 O que são programas? 1
#     48 O que são comandos ? 0
#     49 A quem a coordenação de curso deve solicitar o oferecimento das turmas? 1
#     50 A quem a coordenação de curso anda solicitar o oferecimento das turmas ? 0
#     51 Quais disciplinas possuem tratamento diferenciado quanto ao processo de verificação de aprendizagem? 1
#     52 Quais disciplinas aplicar tratamento diferenciado quanto ao processo de verificação de aprendizagem ? 0
#     53 Quais disciplinas possuem tratamento diferenciado quanto ao processo de verificação de aprendizagem? 1
#     54 Quais disciplinas possuem tratamento diferenciado quanto ao processo de verificação de aprendizagem? 1
#     55 Quais disciplinas possuem tratamento diferenciado quanto ao processo de verificação de aprendizagem? 1
#     56 Quais disciplinas sofrem tratamento diferenciado quanto ao processo de verificação de aprendizagem ? 0
#     57 Quais os resultados finais que devem ser registrados para trabalho de conclusão de curso? 1
#     58 Quais os resultados finais que devem ser registrados para trabalho de conclusão de curso? 1
#     59 Quais os resultados finais que devem ser documentação para trabalho de conclusão de curso ? 0
#     60 Quais os resultados finais que devem ser registrados para trabalho de conclusão de curso? 1
#     61 Quais os resultados finais que através ser registrados para trabalho de conclusão de curso ? 0
#     62 Quais os resultados finais que devem ser registrados para trabalho de conclusão de curso? 1
#     63 Quais números um byte definiu ? 0
#     64 Quais números um byte representa? 1
#     65 Quais números um byte monta ? 0
#     66 Quantos números um byte representa? 1
#     67 Quantos números um byte medida ? 0
#     68 Quantos números um byte representa? 1
#     69 Quantos números um byte inteiro ? 0
#     70 O que era o dizer analítico ? 0
#     71 Quem inventou o tear mecânico? 1
#     72 A quem foi aplicado o termo computador? 1
#     73 A quem foi designado o termo computador ? 0
#     74 A quem foi aplicado o termo computador? 1
#     75 A quem foi saber o termo computador ? 0
#     76 A quem foi aplicado o termo computador? 1
#     77 A quem foi endere o termo computador ? 0
#     78 A quem foi aplicado o termo computador? 1
#     79 Como será verificado o rendimento do acadêmico? 1
#     80 Estudos realizados no exterior podem ser aproveitados? 1
#     81 O que o professor deve não ao acadêmico ? 0
#     82 Onde são desenvolvidos os conteúdos de uma disciplina? 1
#     83 Onde são métodos os conteúdos de uma disciplina ? 0
#     84 Onde são desenvolvidos os conteúdos de uma disciplina? 1
#     85 Onde são exercícios os conteúdos de uma disciplina ? 0
#     86 Para que serve a modalidade de graduação licenciatura? 1
#     87 Para que via a modalidade de graduação licenciatura ? 0
#     88 Para que serve a modalidade de graduação licenciatura? 1
#     89 Para que relevante a modalidade de graduação licenciatura ? 0
#     90 Quem testemunha a validação da matrícula ? 0
#     91 Quem cabe a validação da matrícula ? 0
#     92 Quando são oferecidos os períodos letivos especiais? 1
#     93 Quando são passados os períodos letivos especiais ? 0
#     94 O que modificou as bibliotecas e os centros de documentação? 1
#     95 Do que os gestores esquecem com tantos recursos disponíveis? 1
#     96 Desde quando existem as tecnologias de classificação e organização de informações? 1
#     97 Desde quando mundo as tecnologias de classificação e organização de informações ? 0
#     98 Com o que os computadores eram incompartíveis até 1960? 1
#     99 Com o que os portos eram incompartíveis até 1960 ? 0
#     100 Com o que os computadores eram incompartíveis até 1960? 1
#     101 Com o que os vencedores eram incompartíveis até 1960 ? 0
#     102 Pelo que os avanços da informática eram puxados em 1960? 1
#     103 O que a flexibilização do terminal permitiu ao computador? 1
#     104 O que a flexibilização do terminal diminuiu ao computador ? 0
#     105 Qual elemento de TI é indispensável em uma organização? 1
#     106 Qual elemento de TI é indispensável em uma classificação ? 0
#     107 Qual elemento de TI é indispensável em uma organização? 1
#     108 Qual questão de TI é indispensável em uma organização ? 0
#     109 Qual elemento de TI é indispensável em uma organização? 1
#     110 O que acontece se houver mais de uma turma ofertada para uma mesma disciplina? 1
#     111 O que fazer caso o aluno perca o prazo de seleção de disciplinas online? 1
#     112 O que fazer caso o aluno perca o prazo de seleção de disciplinas online? 1
#     113 Qual a condição para incluir disciplinas durante a etapa de ajustes de matrícula? 1
#     114 Qual a condição para conhecer disciplinas durante a etapa de ajustes de matrícula ? 0
#     115 Quais outros critérios para seleção dos canditados que os programas podem utilizar? 1
#     116 Quais outros critérios para seleção dos canditados que os programas - utilizar ? 0
#     117 Qual a carga horária máxima dos cursos de aperfeiçoamento lato sensu? 1
#     118 Qual a carga horária máxima dos mineiros de aperfeiçoamento lato sensu ? 0
#     119 Qual a carga horária máxima dos cursos de aperfeiçoamento lato sensu? 1
#     120 Qual a carga horária máxima dos não de aperfeiçoamento lato sensu ? 0
#     121 Qual a carga horária máxima dos cursos de aperfeiçoamento lato sensu? 1
#     122 Qual a gravação horária máxima dos cursos de aperfeiçoamento lato sensu ? 0
#     123 Qual a carga horária máxima dos cursos de aperfeiçoamento lato sensu? 1
#     124 Qual a carga horária máxima dos relatórios de aperfeiçoamento lato sensu ? 0
#     125 Qual a carga horária máxima dos cursos de aperfeiçoamento lato sensu? 1
#     126 Qual tipo de estudo é geralmente lembrado em uma monografia ? 0
#     127 Qual tipo de estudo é geralmente feito em uma monografia? 1
#     128 Qual tipo de estudo é geralmente provocado em uma monografia ? 0
#     129 Qual tipo de estudo é geralmente feito em uma monografia? 1
#     130 Qual tipo de estudo é geralmente assunto em uma monografia ? 0
#     131 Quais as condições para a instância em disciplinas obrigatórias ? 0
#     132 Qual a condição para matrícula em disciplinas optativas? 1
#     133 Qual a condição para matrícula em paredes optativas ? 0
#     134 Onde o aluno deve preencher o formulário eletrônico? 1
#     135 Onde o aluno quem preencher o formulário eletrônico ? 0
#     136 Onde o aluno deve preencher o formulário eletrônico? 1
#     137 Onde o aluno indo preencher o formulário eletrônico ? 0
#     138 Onde o aluno deve preencher o formulário eletrônico? 1
#     139 Onde o aluno assume preencher o formulário eletrônico ? 0
#     140 Onde o aluno deve preencher o formulário eletrônico? 1
#     141 Onde o aluno deve preencher o formulário eletrônico? 1
#     142 Quantos consultores ad hoc elaboração os projetos ? 0
#     143 Quantos consultores ad hoc trata os projetos ? 0
#     144 Quem foram os pioneiros da ciência da computação na poeira ? 0
#     145 Qual a prioridade do curso de Análise de Sistemas? 1
#     146 Qual a Fama do curso de Análise de Sistemas ? 0
#     147 Qual a prioridade do curso de Análise de Sistemas? 1
#     148 Qual a indicação do curso de Análise de Sistemas ? 0
#     149 Quando a área de computação foi CR na UFMS ? 0
#     150 Quando a área de computação foi desenvolvido na UFMS ? 0
#     151 Quando a área de computação foi introduzir na UFMS ? 0
#     152 Quando foi criado o curso de Análise de Sistemas? 1
#     153 Quando foi fechar o curso de Análise de Sistemas ? 0
#     154 Quando foi criado o curso de Análise de Sistemas? 1
#     155 Quando foi fechado o curso de Análise de Sistemas ? 0
#     156 Quando foi criado o curso de Análise de Sistemas? 1
#     157 Quando foi efetiva o curso de Análise de Sistemas ? 0
#     158 O que acontece se o acadêmico não entregar as atividades na data estipulada? 1
#     159 O que foi implantado no distrito federal em cumprimento a lei número 347? 1
#     160 O que foi criado com a subdivisão do Departamento de Matemática da UFMS? 1
#     161 O que foi reduzido com a subdivisão do Departamento de Matemática da UFMS ? 0
#     162 Quem aprovou a criação do Doutorado em Ciência da Computação da UFMS? 1
#     163 Quem assinatura a criação do Doutorado em Ciência da Computação da UFMS ? 0
#     164 O que acontece se houver mais de uma turma ofertada para uma mesma disciplina? 1
#     165 Qual a carga horária máxima dos gastos de aperfeiçoamento lato sensu ? 0
#     166 Por que é necessário que um professor tenha qualificações acadêmicas e pedagógicas? 1
#     167 Por que é necessário que um professor excepcional qualificações acadêmicas e pedagógicas ? 0
#     168 Qual obra alertava para a importância do papel do professor na formação do cidadão? 1
#     169 Qual obra alertava para a importância do papel do professor na formação do cidadão? 1
#     170 Qual obra alertava para a importância do papel do professor na formação do cidadão? 1
#     171 Qual obra alertava para a importância do papel do professor na formação do cidadão? 1
#     172 A quem a coordenação de curso deve solicitar o oferecimento das turmas? 1
#     173 A quem a coordenação de curso II solicitar o oferecimento das turmas ? 0
#     174 Como era controlada a máquina de tecer números de Babbage? 1
#     175 Como era controlada a máquina de tecer números de Babbage? 1
#     176 O que inspirou Babbage a desenvolver a máquina de apresenta números ? 0
#     177 Onde a unidade de controle busca a informação que a ULA precisa? 1
#     178 Onde a unidade de controle busca a informação que a ULA descobriu ? 0
#     179 Onde a unidade de controle busca a informação que a ULA precisa? 1
#     180 Onde a unidade de controle leu a informação que a ULA precisa ? 0
#     181 Onde a unidade de controle busca a informação que a ULA precisa? 1
#     182 Onde a unidade de controle busca a informação que a ULA recebida ? 0
#     183 Onde a unidade de controle busca a informação que a ULA precisa? 1
#     184 Onde a unidade de controle busca a informação que a ULA produziu ? 0
#     185 Como eram gravadas as tabelas de multiplicação de John Napier? 1
#     186 Como eram os as tabelas de multiplicação de John Napier ? 0
#     187 Como eram gravadas as tabelas de multiplicação de John Napier? 1
#     188 Como eram interpretar as tabelas de multiplicação de John Napier ? 0
#     189 Qual metodologia vem sendo aplicada a cursos de engenharia de computação no Brasil? 1
#     190 Quantas instruções dos programas de computador possuem? 1
#     191 Quantas instruções dos programas de computador acompanha ? 0
#     192 Qual o principal objetivo da PBL? 1
#     193 Qual o principal apoio da PBL ? 0
#     194 Qual o principal objetivo da PBL? 1
#     195 Qual o principal orçamento da PBL ? 0
#     196 Quem é considerado engenheiro de computação no Brasil? 1
#     197 Quem é mito engenheiro de computação no Brasil ? 0
#     198 Quem é considerado engenheiro de computação no Brasil? 1
#     199 Quem é diferente engenheiro de computação no Brasil ? 0
#     200 Quem é considerado engenheiro de computação no Brasil? 1
#     201 Quem é Um engenheiro de computação no Brasil ? 0
#     202 Em que a engenharia de software se concentra? 1
#     203 Em que a engenharia de software se utilizada ? 0
#     204 O que os fundamentos científicos envolvem o uso? 1
#     205 O que os fundamentos científicos defini o uso ? 0
#     206 Em que tem exercido os avanços recentes na ciência da computação ? 0
#     207 Em que tem apoio os avanços recentes na ciência da computação ? 0
#     208 Quais as áreas que tem mais instalado a sociedade contemporânea ? 0
#     209 Por que existem várias definições alternativas para a ciência da computação? 1
#     210 Por que eleger várias definições alternativas para a ciência da computação ? 0
#     211 Em que é utilizado o sistema de numeração binário? 1
#     212 Em que é habitual o sistema de numeração binário ? 0
#     213 Quais informações podem ser representadas por uns e zeros? 1
#     214 Quais informações podem ser indicados por uns e zeros ? 0
#     215 Quais informações podem ser representadas por uns e zeros? 1
#     216 Quais informações complementares ser representadas por uns e zeros ? 0
#     217 Quais informações podem ser representadas por uns e zeros? 1
#     218 Quais informações podem ser usada por uns e zeros ? 0
#     219 Quais informações podem ser representadas por uns e zeros? 1
#     220 Quais informações h ser representadas por uns e zeros ? 0
#     221 Quais informações podem ser representadas por uns e zeros? 1
#     222 O que começou a escrever novas opções para a transformação de dados em informação ? 0
#     223 O que começou a abrir novas opções para a transformação de dados em informação? 1
#     224 O que começou a cantar novas opções para a transformação de dados em informação ? 0
#     225 Qual o conceito da federal segundo a avaliação do Índice Geral de Cursos ? 0
#     226 Quando foi criado o Instituto Superior de Pedagogia em Corumbá? 1
#     227 Quando foi anunciar o Instituto Superior de Pedagogia em Corumbá ? 0
#     228 Quando foi criado o Instituto Superior de Pedagogia em Corumbá? 1
#     229 Quando foi cá o Instituto Superior de Pedagogia em Corumbá ? 0
#     230 Quando foi criado o Instituto Superior de Pedagogia em Corumbá? 1
#     231 Quando foi nós o Instituto Superior de Pedagogia em Corumbá ? 0
#     232 A UFMS abrange uma área geográfico-educacional de quantos km? 1
#     233 A UFMS explorar uma área geográfico-educacional de quantos km ? 0
#     234 A UFMS abrange uma área geográfico-educacional de quantos km? 1
#     235 A UFMS capturou uma área geográfico-educacional de quantos km ? 0
#     236 A UFMS abrange uma área geográfico-educacional de quantos km? 1
#     237 A UFMS pega uma área geográfico-educacional de quantos km ? 0
#     238 O que Hollerith inventou? 1
#     239 Para que serve a fonte de energia? 1
#     240 Para que determina a fonte de energia ? 0
#     241 Para que serve a fonte de energia? 1
#     242 Para que utilizam a fonte de energia ? 0
#     243 Para que serve a fonte de energia? 1
#     244 Para que frente a fonte de energia ? 0
#     245 Quem escreve as instruções para o computador? 1
#     246 Quem divide as instruções para o computador ? 0
#     247 Quem escreve as instruções para o computador? 1
#     248 Quem instala as instruções para o computador ? 0
#     249 Quem escreve as instruções para o computador? 1
#     250 Quem quebrou as instruções para o computador ? 0
#     251 Qual o sistema de computação mais conhecido? 1
#     252 Qual o estágio de computação mais conhecido ? 0
#     253 O que é UNIVASF? 1
#     254 Quantas instruções dos programas de computador possuem? 1
#     255 Quantas instruções dos programas de computador apresentaram ? 0
#     256 O que os fundamentos científicos envolvem o uso? 1
#     257 O que os fundamentos científicos totalmente o uso ? 0
#     258 Por quem geralmente é prestado o estágio? 1
#     259 O que deve ser convertido ao requerimento ? 0
#     260 Onde será arquivado o Laudo Médico? 1
#     261 Onde será arquivado o Laudo Médico? 1
#     262 Onde será arquivado o Laudo Médico? 1
#     263 Onde será arquivado o Laudo Médico? 1
#     264 Onde será arquivado o Laudo Médico? 1
#     265 Quando a FAPDF foi implementada? 1
#     266 Quando a FAPDF foi implementada? 1
#     267 O que ocorreu com a implantação do curso? 1
#     268 O que objetivo com a implantação do curso ? 0
#     269 De quando é a resolução nº 342? 1
#     270 Quando foi criado o curso de Análise de Sistemas? 1
#     271 Quando foi abertos o curso de Análise de Sistemas ? 0
#     272 Quando foi criado o curso de Análise de Sistemas? 1
#     273 Quando foi sar o curso de Análise de Sistemas ? 0
#     274 Quando a primeira turma de Engenharia da Computação entrou? 1
#     275 Quando a primeira turma de Engenharia da Computação cobra ? 0
#     276 A resolução nº 342 torna claro o quê ? 0
#     277 A resolução nº 342 torna democrático o quê ? 0
#     278 A resolução nº 342 torna simples o quê ? 0
#     279 O programa de monitoria é recurso para qual finalidade? 1
#     280 O que carrega ser anexado no SigProj ? 0
#     281 O que os professors no Reino Unido geralmente apareceram ? 0
#     282 O que os professors no Reino Unido geralmente cam ? 0
#     283 O que os professors no Reino Unido geralmente College ? 0
#     284 Quantas avaliações obrigatórias devem haver em cada disciplina? 1
#     285 A matrícula em disciplinas isoladas depende de quê? 1
#     286 A matrícula em disciplinas isoladas esta de quê ? 0
#     287 A matrícula em disciplinas isoladas depende de quê? 1
#     288 Em quais matérias o aluno especial não pode se tocar ? 0
#     289 Em quais matérias o aluno especial não pode se matar ? 0
#     290 O que o professor deve consignar ao acadêmico? 1
#     291 Qual a modalidade de curso de graduação que forma profissionais? 1
#     292 Qual a modalidade de curso de graduação que consta profissionais ? 0
#     293 Qual a modalidade de curso de graduação que forma profissionais? 1
#     294 Quais informações podem ser representadas por uns e zeros? 1
#     295 Quais informações desconhecidas ser representadas por uns e zeros ? 0
#     296 O que a unidade de controle icia à ULA ? 0
#     297 Quais tipos de dispositivos os sistemas embarcados controlam? 1
#     298 Quais tipos de dispositivos os sistemas embarcados controlam? 1
#     299 Quais tipos de dispositivos os sistemas embarcados controlam? 1
#     300 Quais tipos de dispositivos os sistemas embarcados controlam? 1
#     301 Qual linguagem de programação é parecida com a linguagem de máquina? 1
#     302 Qual linguagem de programação é parecida com a IA de máquina ? 0
#     303 Qual linguagem de programação é parecida com a linguagem de máquina? 1
#     304 Qual tip de programação é parecida com a linguagem de máquina ? 0
#     305 Qual linguagem de programação é parecida com a linguagem de máquina? 1
#     306 Qual linguagem de entrevista é parecida com a linguagem de máquina ? 0
#     307 Até quando o ENIAC foi mantido em segredo? 1
#     308 Até quando o ENIAC foi o em segredo ? 0
#     309 Como é conhecida a empresa fundada por Hollerith atualmente? 1
#     310 O que é uma universidade de múltiplos cultos ? 0
#     311 O que é uma universidade de múltiplos números ? 0
#     312 Quais níveis de educação uma universidade fornece? 1
#     313 Quais níveis de educação uma universidade sobre ? 0
#     314 quais incisos os acadêmicos deve cumprir? 1
#     315 quais incisos os acadêmicos três cumprir ? 0
#     316 quais incisos os acadêmicos deve cumprir? 1
#     317 quais incisos os acadêmicos deve compreende ? 0
#     318 quais os critérios de constituição do nde? 1
#     319 quais os critérios de agência do nde ? 0
#     320 quais os critérios de constituição do nde? 1
#     321 quais os remanescentes de constituição do nde ? 0
#     322 como deve ser elaborado o projeto pedagógico? 1
#     323 como objeto ser elaborado o projeto pedagógico ? 0
#     324 como deve ser elaborado o projeto pedagógico? 1
#     325 como emprega ser elaborado o projeto pedagógico ? 0
#     326 Qual o tipo de abordagem que afirma a complexidade da realidade social ? 0
#     327 O POSCOMP dispensou a necessidade de quê? 1
#     328 O POSCOMP dispensou a necessidade de quê? 1
#     329 O POSCOMP dispensou a necessidade de quê? 1
#     330 O POSCOMP dispensou a necessidade de quê? 1
#     331 Onde são chave as instruções sobre a inscrição e processo seletivo ? 0
#     332 Qual é a utilidade dos cursos de ares profissionais para a sociedade ? 0
#     333 Quem conheceram os maiores desafios no campo da matemática no século XX ? 0
#     334 Quem desafio os maiores desafios no campo da matemática no século XX ? 0
#     335 Quem ofereceu os maiores desafios no campo da matemática no século XX ? 0
#     336 Quem classificou os maiores desafios no campo da matemática no século XX ? 0
#     337 Qual era o número de mestrados acadêmicos no Brasil em 2017? 1
#     338 Quando o doutorado passou a admitir a modalidade profissional no Brasil? 1
#     339 Quando o doutorado passou a admitir a modalidade profissional no Brasil? 1
#     340 Quando o doutorado passou a admitir a modalidade profissional no Brasil? 1
#     341 Quando o doutorado avalia a admitir a modalidade profissional no Brasil ? 0
#     342 Como a ciência da computação se distinguir enquanto ciência ? 0
#     343 Como a ciência da computação se classifica enquanto ciência? 1
#     344 Como a ciência da computação se dedicou enquanto ciência ? 0
#     345 Com quem o computador moderno começou a ganhar forma? 1
#     346 Com quem o computador moderno começou a prima forma ? 0
#     347 Com quem o computador moderno começou a ganhar forma? 1
#     348 Com quem o computador moderno vol a ganhar forma ? 0
#     349 O que mostra o teorema da incompletude? 1
#     350 O que teve o teorema da incompletude ? 0
#     351 O que mostra o teorema da incompletude? 1
#     352 O que formou o teorema da incompletude ? 0
#     353 Para que várias pessoas estudam ciência da computação? 1
#     354 Para que várias pessoas estudam ciência da computação? 1
#     355 Quando foi publicada a álgebra booleana? 1
#     356 Quando foi promovida a álgebra booleana ? 0
#     357 Quem usava o sistema de numeração binário ? 0
#     358 O que curso superior em análise e desenvolvimento de sistemas visa? 1
#     359 O que curso superior em análise e desenvolvimento de sistemas Faze ? 0
#     360 O que curso superior em análise e desenvolvimento de sistemas visa? 1
#     361 O que curso superior em análise e desenvolvimento de sistemas Direito ? 0
#     362 O que curso superior em análise e desenvolvimento de sistemas visa? 1
#     363 O que curso superior em análise e desenvolvimento de sistemas ocupam ? 0
#     364 Quem caça a carteira profissional dos analistas de sistemas ? 0
#     365 Quem efetiva a carteira profissional dos analistas de sistemas ? 0
#     366 Quem concedeu a carteira profissional dos analistas de sistemas ? 0
#     367 Real diferentes formas de pesquisa nos ajudam com o quê ? 0
#     368 O que a oportunidade de estudo cta a uma pessoa ? 0
#     369 Em que eram empregados os computadores antes da década de 1920? 1
#     370 Em que eram empregados os nazistas antes da década de 1920 ? 0
#     371 Em que eram empregados os computadores antes da década de 1920? 1
#     372 Em que eram empregados os limites antes da década de 1920 ? 0
#     373 Quando o termo máquina computacional perdeu espaço para o termo computador? 1
#     374 Onde será previsto o Laudo Médico ? 0
#     375 Onde será pedidos o Laudo Médico ? 0
#     376 Onde será adotado o Laudo Médico ? 0
#     377 Onde será vindo o Laudo Médico ? 0
#     378 Onde será fundamental o Laudo Médico ? 0
#     379 Quando a FAPDF foi medida ? 0
#     380 Quando a FAPDF foi composto ? 0
#     381 O que a FAPDF visa? 1
#     382 O que a FAPDF poderia ? 0
#     383 O que é a FAPDF? 1
#     384 O que é a FAPDF? 1
#     385 O que é a FAPDF? 1
#     386 Qual a finalidade da FAPDF? 1
#     387 Qual a substância da FAPDF ? 0
#     388 Quando foi constituída a FAPDF? 1
#     389 Quando foi afiliada a FAPDF ? 0
#     390 Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#     391 como é itada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas ? 0
#     392 o que acontece com o acadêmico com vínculo trancado em caso de não renovação de sua matrícula no semestre seguinte? 1
#     393 o que perda com o acadêmico com vínculo trancado em caso de não renovação de sua matrícula no semestre seguinte ? 0
#     394 o que acontece com o acadêmico com vínculo trancado em caso de não renovação de sua matrícula no semestre seguinte? 1
#     395 o que MS com o acadêmico com vínculo trancado em caso de não renovação de sua matrícula no semestre seguinte ? 0
#     396 Qual foi a necessidade que fez a lei da criação da FAPDF ser alterada pela lei nº 3.652? 1
#     397 Qual foi a necessidade que hoje a lei da criação da FAPDF ser alterada pela lei nº 3.652 ? 0
#     398 Qual foi a necessidade que fez a lei da criação da FAPDF ser alterada pela lei nº 3.652? 1
#     399 Qual foi a necessidade que compõe a lei da criação da FAPDF ser alterada pela lei nº 3.652 ? 0
#     400 Quem noticiou que o DF passou a ser um novo exemplo de como a sociedade deve valorizar a atividade científica? 1
#     401 Quem noticiou que o DF reduziu a ser um novo exemplo de como a sociedade deve valorizar a atividade científica ? 0
#     402 O Ministério da Instrução Pública passou a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto? 1
#     403 O Ministério da Instrução Pública [ a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto ? 0
#     404 Quem encaminha o nome dos membros da Comissão do Processo Seletivo à Diap/CDA/Prograd? 1
#     405 Quem encaminha o nome dos membros da Comissão do Processo Seletivo à Diap/CDA/Prograd? 1
#     406 O que ergue a Tese de Church-Turing ? 0
#     407 Em que a maioria dos cientistas da computação estão interessados? 1
#     408 Em que a maioria dos cientistas da tradução estão interessados ? 0
#     409 Quem inventou o sistema de numeração binário? 1
#     410 O que a unidade de controle informa à ULA? 1
#     411 O que a unidade de controle informa à ULA? 1
#     412 O que a unidade de controle envia à ULA ? 0
#     413 Quais as formas mais comuns de computador em uso? 1
#     414 Quais as discos mais comuns de computador em uso ? 0
#     415 Quais as formas mais comuns de computador em uso? 1
#     416 Quais as formas mais comuns de computador em apresentações ? 0
#     417 Quais tipos de dispositivos os sistemas sócios controlam ? 0
#     418 Quais tipos de dispositivos os sistemas embarcados argumentam ? 0
#     419 Quais tipos de dispositivos os sistemas Google controlam ? 0
#     420 Quais tipos de dispositivos os sistemas embarcados extras ? 0
#     421 Por quem foi proposta a arquitetura de von Neumann? 1
#     422 Qual o principal verbo de texto científico ? 0
#     423 Quando ocorre a renovação de matrícula? 1
#     424 Quando pediu a renovação de matrícula ? 0
#     425 Quando ocorre a renovação de matrícula? 1
#     426 Quando obrigado a renovação de matrícula ? 0
#     427 Como é calculado o rendimento acadêmico? 1
#     428 Como é calculado o rendimento acadêmico? 1
#     429 Como é calculado o rendimento acadêmico? 1
#     430 A atividade universitária possui quantos pilares? 1
#     431 A atividade universitária aborda quantos pilares ? 0
#     432 Por quem é poderosa a pesquisa acadêmica ? 0
#     433 Por quem é sujeita a pesquisa acadêmica ? 0
#     434 Qual o objetivo da pesquisa bibliográfica? 1
#     435 Qual o objetivo da demanda bibliográfica ? 0
#     436 Qual o objetivo da pesquisa bibliográfica? 1
#     437 Qual o consenso da pesquisa bibliográfica ? 0
#     438 Como a linguagem de programação é traduzida para a linguagem de máquina? 1
#     439 Como a linguagem de programação é temática para a linguagem de máquina ? 0
#     440 Por que o Z1 foi desprezado pelo governo alemão? 1
#     441 Por que o Z1 foi desprezado pelo governo alemão? 1
#     442 Por que o Z1 foi desprezado pelo governo alemão? 1
#     443 Por que o Z1 foi desprezado pelo governo alemão? 1
#     444 Desde quando os processadores vêm sendo construídos em um único circuito C ? 0
#     445 Desde quando os processadores vêm sendo envolvido em um único circuito integrado ? 0
#     446 Qual o foco de desenvolvimento do curso de Engenharia de Computação? 1
#     447 Qual o foco de final do curso de Engenharia de Computação ? 0
#     448 Qual o foco de desenvolvimento do curso de Engenharia de Computação? 1
#     449 Qual o foco de mudança do curso de Engenharia de Computação ? 0
#     450 Qual o foco de desenvolvimento do curso de Engenharia de Computação? 1
#     451 Qual o sede de desenvolvimento do curso de Engenharia de Computação ? 0
#     452 Como muitas empresas desenvolvedoras são caso ? 0
#     453 Como muitas empresas desenvolvedoras são organizadas? 1
#     454 Como muitas empresas desenvolvedoras são contratada ? 0
#     455 Qual o objetivo do contrato de estágio? 1
#     456 Qual o financiamento do contrato de estágio ? 0
#     457 Qual o objetivo do contrato de estágio? 1
#     458 Qual o objetivo do ministro de estágio ? 0
#     459 Qual o objetivo do contrato de estágio? 1
#     460 Qual o objetivo do caminho de estágio ? 0
#     461 Onde o estágio pode ser prestado? 1
#     462 Por quem geralmente é ordenado o estágio ? 0
#     463 Quando foi constituída a FAPDF? 1
#     464 Quando foi ativa a FAPDF ? 0
#     465 Quando foi constituída a FAPDF? 1
#     466 Quando foi batizada a FAPDF ? 0
#     467 Quando foi constituída a FAPDF? 1
#     468 O que é necessário contratar para comprovar a participação em um evento ? 0
#     469 Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#     470 Compreender diferentes formas de pesquisa nos funcionou com o quê ? 0
#     471 Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#     472 O que considerar as metodologias e técnicas ligadas à implementação de software ? 0
#     473 Por que o dispositivo de Babbage se pensava de outros dispositivos ? 0
#     474 Por que o dispositivo de Babbage se portas de outros dispositivos ? 0
#     475 Qual o termo utilizado para definir sequências de passos para completar uma tarefa? 1
#     476 Qual o termo conveniente para definir sequências de passos para completar uma tarefa ? 0
#     477 Qual o termo utilizado para definir sequências de passos para completar uma tarefa? 1
#     478 Qual o termo utilizado para definir sequências de passos para conduz uma tarefa ? 0
#     479 Em que tem impactado os avanços recentes na ciência da computação? 1
#     480 Em que tem impactado os avanços recentes na ciência da computação? 1
#     481 Em que tem impactado os avanços recentes na ciência da computação? 1
#     482 Quais as áreas que tem mais impactado a sociedade contemporânea? 1
#     483 Quais as áreas que possu mais impactado a sociedade contemporânea ? 0
#     484 Quando destruir o ensino superior no Brasil ? 0
#     485 Quando começou o ensino superior no Brasil? 1
#     486 Quando estabelece o ensino superior no Brasil ? 0
#     487 Quando começou o ensino superior no Brasil? 1
#     488 Quando pega o ensino superior no Brasil ? 0
#     489 o que o acadêmico deve preencher? 1
#     490 quem dá a nota final ao acadêmico? 1
#     491 quem fixa a nota final ao acadêmico ? 0
#     492 quem dá a nota final ao acadêmico? 1
#     493 quem garantiu a nota final ao acadêmico ? 0
#     494 a aprovação nas disciplinas depende do que? 1
#     495 a aprovação nas disciplinas exemplo do que ? 0
#     496 a aprovação nas disciplinas depende do que? 1
#     497 a aprovação nas disciplinas posteriores do que ? 0
#     498 a aprovação nas disciplinas depende do que? 1
#     499 a aprovação nas disciplinas feitas do que ? 0
#     500 Onde são desenvolvido os prazos para elaboração dos horários das aulas ? 0
#     501 Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#     502 Quem a coordenação de curso consulta para refere o horário das aulas ? 0
#     503 O que o Siscad controla, acompanha e divulga? 1
#     504 O que o Siscad atividade , acompanha e divulga ? 0
#     505 O que o Siscad controla, acompanha e divulga? 1
#     506 A partir de qual momento o tempo cursado será contabilizado? 1
#     507 A partir de qual momento o tempo cursado será contabilizado? 1
#     508 Qual a carga horária em hora-aula para disciplinas diretas ? 0
#     509 Qual a carga horária em hora-aula para disciplinas isolada ? 0
#     510 Qual a carga horária em hora-aula para disciplinas determinado ? 0
#     511 Qual a carga horária em hora-aula para disciplinas estudantes ? 0
#     512 Qual a carga horária em hora-aula para disciplinas 02 ? 0
#     513 O que deve ser previamente ao pedido de aproveitamento das atividades complementares ? 0
#     514 Quando devem ser encaminhados os pedidos de aproveitamento de atividades complementares? 1
#     515 Quando complementares ser encaminhados os pedidos de aproveitamento de atividades complementares ? 0
#     516 Quais os possíveis resultados finais para as atividades complementares? 1
#     517 Quais os possíveis resultados finais para as definições complementares ? 0
#     518 Quais os possíveis resultados finais para as atividades complementares? 1
#     519 Quais os possíveis resultados finais para as juntas complementares ? 0
#     520 Quais os possíveis resultados finais para as atividades complementares? 1
#     521 Quais os possíveis resultados finais para as aventuras complementares ? 0
#     522 Como deve ser comprovada a monitoria de ensino? 1
#     523 Como cobra ser comprovada a monitoria de ensino ? 0
#     524 Como deve ser comprovada a monitoria de ensino? 1
#     525 Quem emite a declaração de realização de monitoria? 1
#     526 Quem emite a declaração de realização de monitoria? 1
#     527 Quem emite a declaração de realização de monitoria? 1
#     528 Quem emite a declaração de realização de monitoria? 1
#     529 Quantos professores compõem a banca examinadora? 1
#     530 Quantos professores concorrentes a banca examinadora ? 0
#     531 Quanto tempo o aluno passará escrevendo o TCC? 1
#     532 até quando o acadêmico deverá frequentar regularmente as disciplinas após solicitar dispensa por abreviação de curso? 1
#     533 na solicitação de abreviação de curso, quais disciplinas o acadêmico não pode solicitar dispensa? 1
#     534 na solicitação de abreviação de curso , quais disciplinas o acadêmico não devem solicitar dispensa ? 0
#     535 como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#     536 como é observando a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#     537 como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#     538 como é referente a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#     539 em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#     540 em quantas discplinas o acadêmico devem inscrever-se durante o período letivo especial ? 0
#     541 em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#     542 O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? 1
#     543 O que mais com que profissionais que não possuem educação superior compram o papel de analista de sistemas ? 0
#     544 O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? 1
#     545 O que possível com que profissionais que não possuem educação superior compram o papel de analista de sistemas ? 0
#     546 O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? 1
#     547 O que permite com que profissionais que não teve educação superior compram o papel de analista de sistemas ? 0
#     548 o que os membros do nde devem prender ? 0
#     549 o que os membros do nde devem assegurar? 1
#     550 o que os membros do nde devem tentar ? 0
#     551 o que os membros do nde devem exercer? 1
#     552 o que os membros do nde devem por ? 0
#     553 o que os membros do nde devem exercer? 1
#     554 o que os membros do nde sim exercer ? 0
#     555 quais são as atribuições acadêmicas do nde? 1
#     556 quais são as pouco acadêmicas do nde ? 0
#     557 quais são as atribuições acadêmicas do nde? 1
#     558 quais são as políticas acadêmicas do nde ? 0
#     559 quantas vezes posso solicitar aproveitamento de estudos? 1
#     560 quantas vezes aceito solicitar aproveitamento de estudos ? 0
#     561 quantas vezes posso solicitar aproveitamento de estudos? 1
#     562 quantas vezes pra solicitar aproveitamento de estudos ? 0
#     563 quantas vezes posso solicitar aproveitamento de estudos? 1
#     564 Quantos bytes em sequência geralmente são utilizados para armazenar números maiores? 1
#     565 Quantos bytes em sequência geralmente são utilizados para armazenar números maiores? 1
#     566 O que inspirou Babbage a desenvolver a máquina de tecer números? 1
#     567 O que inspirou Babbage a desenvolver a máquina de tecer números? 1
#     568 O que inspirou Babbage a caça a máquina de tecer números ? 0
#     569 O que inspirou Babbage a desenvolver a máquina de tecer números? 1
#     570 O que inspirou Babbage a indicar a máquina de tecer números ? 0
#     571 Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#     572 Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#     573 Quantas fases o processamento de dados de um sistema de computadores digital cuida ? 0
#     574 Por que grande parte dos eletroeletrônicos são sistemas de computação? 1
#     575 Por que grande ponto dos eletroeletrônicos são sistemas de computação ? 0
#     576 Por que grande parte dos eletroeletrônicos são sistemas de computação? 1
#     577 Por que grande funcionamento dos eletroeletrônicos são sistemas de computação ? 0
#     578 Por que grande parte dos eletroeletrônicos são sistemas de computação? 1
#     579 Por que grande parte dos eletroeletrônicos são opções de computação ? 0
#     580 o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é escola pelo orgão competente ? 0
#     581 O trancamento de matrícula deve ser feito caso o regime de exercícios domicilares for superior a quantos semestres? 1
#     582 O trancamento de matrícula deve ser acontecido caso o regime de exercícios domicilares for superior a quantos semestres ? 0
#     583 O trancamento de matrícula deve ser feito caso o regime de exercícios domicilares for superior a quantos semestres? 1
#     584 O trancamento de matrícula deve ser periódico caso o regime de exercícios domicilares for superior a quantos semestres ? 0
#     585 O trancamento de matrícula deve ser feito caso o regime de exercícios domicilares for superior a quantos semestres? 1
#     586 O trancamento de matrícula normalmente ser feito caso o regime de exercícios domicilares for superior a quantos semestres ? 0
#     587 O trancamento de matrícula deve ser feito caso o regime de exercícios domicilares for superior a quantos semestres? 1
#     588 O trancamento de matrícula banc ser feito caso o regime de exercícios domicilares for superior a quantos semestres ? 0
#     589 O trancamento de matrícula deve ser feito caso o regime de exercícios domicilares for superior a quantos semestres? 1
#     590 O trancamento de matrícula deve ser livre caso o regime de exercícios domicilares for superior a quantos semestres ? 0
#     591 O que acontece caso o Aluno Especial não requeira o aproveitamento das duas disciplinas cursadas até a data de matrícula? 1
#     592 O que nasce caso o Aluno Especial não requeira o aproveitamento das duas disciplinas cursadas até a data de matrícula ? 0
#     593 Em qual ano os alunos de colação de grau poderão ser matriculados em disciplinas sem que tenham denominado todos os pré-requisitos ? 0
#     594 Em qual ano os alunos de colação de grau poderão ser matriculados em disciplinas sem que tenham cumprido todos os pré-requisitos? 1
#     595 Como deve ser diária a carga horária faltante em caso de falta de cargha horária para integralização curricular ? 0
#     596 Quando Eduba foi criada? 1
#     597 Quando Eduba foi incorporada ? 0
#     598 Quando Eduba foi criada? 1
#     599 Quando Eduba foi definida ? 0
#     600 Quando Eduba foi criada? 1
#     601 Quando Eduba foi pago ? 0
#     602 o que é nde? 1
#     603 onde correu o requerimento ? 0
#     604 onde reduzir o requerimento ? 0
#     605 onde colocou o requerimento ? 0
#     606 o que levava ao reitor ? 0
#     607 o que queriam ao reitor ? 0
#     608 O que é técnicas de sistemas ? 0
#     609 Qual o objetivo das C complementares ? 0
#     610 Quem fiscaliza o ensino superior? 1
#     611 o que compete ao reitor? 1
#     612 o que compete ao reitor? 1
#     613 O que as soluções tecnológicas recomenda ? 0
#     614 O que as soluções tecnológicas alcançar ? 0
#     615 O que as soluções tecnológicas fornecer ? 0
#     616 O que as soluções tecnológicas tocaram ? 0
#     617 O que as soluções tecnológicas tomaram ? 0
#     618 Qual um componente indispensável nas organizações? 1
#     619 Qual um componente indispensável nas nucleares ? 0
#     620 Qual um componente indispensável nas organizações? 1
#     621 Qual um componente indispensável nas nucleares ? 0
#     622 O que os profissionais da área cita ? 0
#     623 O que os profissionais da área dois ? 0
#     624 O que os profissionais da área pretende ? 0
#     625 O que os profissionais da área acabaram ? 0
#     626 Qual a principal vantagem das atividades complementares? 1
#     627 Ao que a realização do exame não está vinculada? 1
#     628 Ao que a gravidez do exame não está vinculada ? 0
#     629 Ao que a realização do exame não está vinculada? 1
#     630 Ao que a formulação do exame não está vinculada ? 0
#     631 Como o mestrado acadêmico é caracterizado segundo a portaria? 1
#     632 Como o mestrado acadêmico é enterrado segundo a portaria ? 0
#     633 Como o mestrado acadêmico é caracterizado segundo a portaria? 1
#     634 Como o mestrado acadêmico é operacional segundo a portaria ? 0
#     635 Qual o trabalho acadêmico para obtenção do título de mestre? 1
#     636 Qual o rito acadêmico para obtenção do título de mestre ? 0
#     637 Qual o trabalho acadêmico para obtenção do título de mestre? 1
#     638 Qual o trabalho acadêmico para obtenção do vale de mestre ? 0
#     639 Qual o trabalho acadêmico para obtenção do título de mestre? 1
#     640 Qual o trabalho acadêmico para obtenção do título de plena ? 0
#     641 Qual o trabalho acadêmico para obtenção do título de mestre? 1
#     642 O que a ciência da computação é basicamente a mais do que teórica ? 0
#     643 O que a ciência da computação é considerada a mais do que teórica? 1
#     644 O que a ciência da computação é Mas a mais do que teórica ? 0
#     645 O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#     646 O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#     647 O que foi ilustrado pelo tear roubado por cartão perfurado ? 0
#     648 Quantos bytes em sequência geralmente são utilizados para suas números maiores ? 0
#     649 Quantos bytes em sequência geralmente são utilizados para 100 números maiores ? 0
#     650 Qual metodologia rural sendo aplicada a cursos de engenharia de computação no Brasil ? 0
#     651 Qual metodologia vem sendo aplicada a cursos de engenharia de computação no Brasil? 1
#     652 Qual metodologia vem sendo atribuição a cursos de engenharia de computação no Brasil ? 0
#     653 Qual metodologia vem sendo aplicada a cursos de engenharia de computação no Brasil? 1
#     654 Qual metodologia vem sendo convidada a cursos de engenharia de computação no Brasil ? 0
#     655 Quanto dos sistemas de computação são conhecidos como “sistemas embarcados”? 1
#     656 Quanto dos sistemas de computação são sérios como “ sistemas embarcados ” ? 0
#     657 Quanto dos sistemas de computação são conhecidos como “sistemas embarcados”? 1
#     658 Qual a Parte da pesquisa descritiva ? 0
#     659 Qual o princípio da pesquisa descritiva? 1
#     660 Qual o se da pesquisa descritiva ? 0
#     661 Como a computação pode ser definida formalmente? 1
#     662 Como a computação pode ser alterada formalmente ? 0
#     663 Como a computação pode ser definida formalmente? 1
#     664 Como a computação pode ser científica formalmente ? 0
#     665 Qual a finalidade da teoria da computação? 1
#     666 Qual a finalidade da teoria da identificação ? 0
#     667 Qual a finalidade da teoria da computação? 1
#     668 Qual a finalidade da teoria da computação? 1
#     669 Qual a finalidade da teoria da Turner ? 0
#     670 Qual a duração média de um doutorado? 1
#     671 Qual a duração média de um docente ? 0
#     672 Qual a duração média de um doutorado? 1
#     673 Qual a duração média de um set ? 0
#     674 Quando a área de computação foi solidificada na UFMS? 1
#     675 Quando a área de computação foi solidificada na UFMS? 1
#     676 Quando a área de computação foi solidificada na UFMS? 1
#     677 Quais eram as atividades do Ministério da Educação e Saúde? 1
#     678 Quais eram as intervenção do Ministério da Educação e Saúde ? 0
#     679 Quais eram as atividades do Ministério da Educação e Saúde? 1
#     680 Professor voluntário pode requerer monitor para sua disciplina? 1
#     681 Professor voluntário pode requerer monitor para sua disciplina? 1
#     682 Professor voluntário pode requerer monitor para sua disciplina? 1
#     683 Professor voluntário justifica requerer monitor para sua disciplina ? 0
#     684 Quantas bolsas serão históricas para o edital nº 163 ? 0
#     685 O processo seletivo dos monitores será feita por quem? 1
#     686 O processo seletivo dos monitores será vez por quem ? 0
#     687 O processo seletivo dos monitores será feita por quem? 1
#     688 O processo seletivo dos monitores será movido por quem ? 0
#     689 Qual tipo de estudo é geralmente feito em uma monografia? 1
#     690 Como são utilizadas as versões mais modernas do ábaco? 1
#     691 Como são termos as versões mais modernas do ábaco ? 0
# ...
#     1790 Por quem é conduzida a pesquisa acadêmica? 1
#     1791 Quem buscou o pedido de regime de exercícios domiciliares ? 0
#     1792 Quem poderia o pedido de regime de exercícios domiciliares ? 0
#     1793 Quem denuncia o pedido de regime de exercícios domiciliares ? 0
#     1794 Quando o professor deve devolver as provas aos alunos? 1
#     1795 Quando o professor falou devolver as provas aos alunos ? 0
#     1796 Onde os acadêmicos devem retirar e devolver as atividades? 1
#     1797 O que assistirá os portadores de traumatismos? 1
#     1798 O que assistirá os portadores de traumatismos? 1
#     1799 Qual foi o primeiro projeto a receber apoio da instituição? 1
#     1800 Qual foi o primeiro projeto a conhecer apoio da instituição ? 0
#     1801 Qual foi o primeiro projeto a receber apoio da instituição? 1
#     1802 Qual foi o primeiro projeto a alguns apoio da instituição ? 0
#     1803 Quantos consultores ad hoc mostraram os projetos ? 0
#     1804 Quantos consultores ad hoc viviam os projetos ? 0
#     1805 Ao que o docente responsável pelo monitor deve pertencer? 1
#     1806 Ao que o docente responsável pelo monitor deve elaborar ? 0
#     1807 Quais disciplinas o acadêmico passo preencher no formulário eletrônico ? 0
#     1808 Quais disciplinas o acadêmico deve preencher no formulário eletrônico? 1
#     1809 Quais disciplinas o acadêmico favor preencher no formulário eletrônico ? 0
#     1810 O que acontece caso o aluno se ausente da renovação de matrícula? 1
#     1811 O que lançar caso o aluno se ausente da renovação de matrícula ? 0
#     1812 O que acontece caso o aluno se ausente da renovação de matrícula? 1
#     1813 Qual o tipo de abordagem que ignora a complexidade da realidade social? 1
#     1814 Qual o tipo de abordagem que ignora a complexidade da realidade social? 1
#     1815 Qual o tipo de abordagem que ignora a complexidade da realidade social? 1
#     1816 Desde quando o POSCOMP passou a ser equipado no Peru ? 0
#     1817 Desde quando o POSCOMP passou a ser determinado no Peru ? 0
#     1818 Desde quando o POSCOMP passou a ser tomado no Peru ? 0
#     1819 Como os programas podem, por exemplo, utilizar os resultados dos exames? 1
#     1820 Quantas modalidades do curso de Ciência da Computação a UFSC possuia? 1
#     1821 Quantas modalidades do curso de Ciência da Computação a UFSC possuia? 1
#     1822 Quantos dias remunerados o estagiário possui de recesso? 1
#     1823 Quantos dias remunerados o estagiário possui de recesso? 1
#     1824 Quantos dias remunerados o estagiário verifica de recesso ? 0
#     1825 Quantos dias remunerados o estagiário possui de recesso? 1
#     1826 Quantos dias remunerados o estagiário também de recesso ? 0
#     1827 Quantos dias remunerados o estagiário possui de recesso? 1
#     1828 Quantos dias remunerados o estagiário possui de recesso? 1
#     1829 O que a gestante deve fazer para recomenda o regime de exercícios domiciliares ? 0
#     1830 O que a gestante deve fazer para controlar o regime de exercícios domiciliares ? 0
#     1831 Ao que deve ser protocolizada a solicitação do regime de exercícios domiciliares? 1
#     1832 Quais os resultados finais que devem ser utiliza para trabalho de conclusão de curso ? 0
#     1833 Quantos alunos no mínimo as turmas devem ter nos períodos letivos regulares? 1
#     1834 Quantos alunos no mínimo as turmas tais ter nos períodos letivos regulares ? 0
#     1835 O que deve ser incluído no plano de estudos referente ao curso na UFMS? 1
#     1836 Qual é a segunda universidade mais antiga do mundo? 1
#     1837 Qual é a segunda cobertura mais antiga do mundo ? 0
#     1838 Quais áreas a universidade de Nalanda mudou ? 0
#     1839 Quando as universidades se tornaram bastante comuns nos EUA? 1
#     1840 Quando as universidades se incluíam bastante comuns nos EUA ? 0
#     1841 Quando as universidades se tornaram bastante comuns nos EUA? 1
#     1842 Quando as universidades se sinais bastante comuns nos EUA ? 0
#     1843 O que é uma universidade de múltiplos campi? 1
#     1844 O que é uma universidade de múltiplos campi? 1
#     1845 O que é uma universidade de múltiplos campi? 1
#     1846 O que é uma contratação de múltiplos campi ? 0
#     1847 O que é uma universidade de múltiplos campi? 1
#     1848 O que é uma certificação de múltiplos campi ? 0
#     1849 quem deve fazer o registro no siscad? 1
#     1850 quem programa fazer o registro no siscad ? 0
#     1851 quem deve fazer o registro no siscad? 1
#     1852 Qual a tropa mais antiga do Brasil ? 0
#     1853 Quando começou o ensino superior no Brasil? 1
#     1854 Quando deixaram o ensino superior no Brasil ? 0
#     1855 Quando começou o ensino superior no Brasil? 1
#     1856 Como pode ser definido um sistema de informação? 1
#     1857 Como pode ser futuro um sistema de informação ? 0
#     1858 Como pode ser definido um sistema de informação? 1
#     1859 Como pode ser emprestado um sistema de informação ? 0
#     1860 O que os profissionais da área geram? 1
#     1861 O que os profissionais da área geram? 1
#     1862 O que os profissionais da área geram? 1
#     1863 O que os profissionais da área geram? 1
#     1864 Qual ferramenta é fundamental em qualquer atividade empresarial? 1
#     1865 Qual palestra é fundamental em qualquer atividade empresarial ? 0
#     1866 Quais alguns exemplos de atividades de extensão? 1
#     1867 Quais alguns disponíveis de atividades de extensão ? 0
#     1868 Os cursos de pós-graduação podem quais cursos ? 0
#     1869 Os cursos de pós-graduação exigia quais cursos ? 0
#     1870 Por quem é exercido o cargo de Reitor? 1
#     1871 Por quem é exerceu o cargo de Reitor ? 0
#     1872 Quem é responsável por aproximar a Universidade da comunidade? 1
#     1873 Quem é responsável por novo a Universidade da comunidade ? 0
#     1874 Quem é responsável por aproximar a Universidade da comunidade? 1
#     1875 Quem é responsável por apropri a Universidade da comunidade ? 0
#     1876 O Pergamum é acessível por quais computadores? 1
#     1877 O Pergamum é acessível por quais computadores? 1
#     1878 O Pergamum é acessível por quais obras ? 0
#     1879 O Pergamum é acessível por quais computadores? 1
#     1880 O Pergamum é acessível por quais computadores? 1
#     1881 O Pergamum é acessível por quais computadores? 1
#     1882 O Pergamum é acessível por quais esportes ? 0
#     1883 Aproximadamente quantos municípios a UFMS atinge? 1
#     1884 Como o curso de engenharia de sistemas e computação passará a se combater ? 0
#     1885 Como o curso de engenharia de sistemas e computação passará a se chamar? 1
#     1886 Como o curso de engenharia de sistemas e computação passará a se estabeleceu ? 0
#     1887 Por que países mais deficiência em ciência hoje colem bons frutos nessa área ? 0
#     1888 Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#     1889 Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#     1890 Por que países mais viviam em ciência hoje colem bons frutos nessa área ? 0
#     1891 Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#     1892 Por que países mais reais em ciência hoje colem bons frutos nessa área ? 0
#     1893 Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#     1894 O que foi recebido no distrito federal em cumprimento a lei número 347 ? 0
#     1895 Quando foi implantado o curso de Ciência da Computação na UFMS? 1
#     1896 Quando foi implantado o curso de Ciência da Computação na UFMS? 1
#     1897 Quando foi implantado o curso de Ciência da Computação na UFMS? 1
#     1898 O que quer dizer Total de Alunos Equivalentes da Graduação? 1
#     1899 O tempo além das 360 horas da especialização é contrato para o quê ? 0
#     1900 Quem é excluído por jubilação forma o vínculo acadêmico com quem ? 0
#     1901 Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#     1902 Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#     1903 Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#     1904 Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#     1905 Quem deve expor o formulário de inscrição na confirmação de matrícula ? 0
#     1906 Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#     1907 Quem á apresentar o formulário de inscrição na confirmação de matrícula ? 0
#     1908 O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#     1909 O Colegiado de Curso poderá rever alterações na matriz curricular ? 0
#     1910 O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#     1911 O Colegiado de Curso nega propor alterações na matriz curricular ? 0
#     1912 O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#     1913 O Colegiado de Curso deu propor alterações na matriz curricular ? 0
#     1914 O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#     1915 O Colegiado de Curso mínimo propor alterações na matriz curricular ? 0
#     1916 Com o que as atividades complementares contribuem? 1
#     1917 Com o que as atividades complementares vistas ? 0
#     1918 Com o que as atividades complementares contribuem? 1
#     1919 Com o que as atividades complementares adicionados ? 0
#     1920 Com o que as atividades complementares contribuem? 1
#     1921 Qual o objetivo das ativdades complementares? 1
#     1922 Qual o objetivo das ativdades complementares? 1
#     1923 Qual o professor das ativdades complementares ? 0
#     1924 Qual a ideia da metodologia de direito ? 0
#     1925 Qual a ideia da metodologia de respostas ? 0
#     1926 Qual era o uso original do circo ? 0
#     1927 Quem segundo o logaritmo ? 0
#     1928 Quem encerra o logaritmo ? 0
#     1929 Quem argumenta o logaritmo ? 0
#     1930 Quem propõe o logaritmo ? 0
#     1931 Ao que a ciência da computação contribuiu? 1
#     1932 qual o limite de dias para o acadêmico que requisitou abreviação de curso ser informado do conteúdo? 1
#     1933 qual o limite de dias para o acadêmico que requisitou abreviação de curso ser utilizado do conteúdo ? 0
#     1934 Em que a rápida mudança promovida pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação? 1
#     1935 Em que a rápida mudança fabricados pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação ? 0
#     1936 Quando os primeiros docentes do curso de Engenharia de Computação da UNIVASF iniciaram suas atividades? 1
#     1937 Como o Ministério dos Negócios da Educação e Saúde Pública passou a se chamar em 15 de janeiro de 1937? 1
#     1938 Como o Ministério dos Negócios da Educação e Saúde Pública destinado a se chamar em 15 de janeiro de 1937 ? 0
#     1939 Como o Ministério dos Negócios da Educação e Saúde Pública passou a se chamar em 15 de janeiro de 1937? 1
#     1940 Como o Ministério dos Negócios da Educação e Saúde Pública trabalhava a se chamar em 15 de janeiro de 1937 ? 0
#     1941 Como o Ministério dos Negócios da Educação e Saúde Pública passou a se chamar em 15 de janeiro de 1937? 1
#     1942 Como o Ministério dos Negócios da Educação e Saúde Pública passou a se componente em 15 de janeiro de 1937 ? 0
#     1943 Qual um dos modelos de pós-graduação do Brasil que se aproximam com o do norte-americano? 1
#     1944 Qual um dos modelos de pós-graduação do Brasil que se aproximam com o do norte-americano? 1
#     1945 Qual um dos modelos de pós-graduação do Brasil que se aproximam com o do norte-americano? 1
#     1946 Qual um dos modelos de pós-graduação do Brasil que se aproximam com o do norte-americano? 1
#     1947 Qual um dos modelos de pós-graduação do Brasil que se aproximam com o do norte-americano? 1
#     1948 Como a pesquisa empírica ocorre? 1
#     1949 Como a pesquisa empírica determina ? 0
#     1950 Como a pesquisa empírica ocorre? 1
#     1951 Como a pesquisa empírica previa ? 0
#     1952 O que significa R & D? 1
#     1953 O que representar R & D ? 0
#     1954 O que significa R & D? 1
#     1955 O que Design R & D ? 0
#     1956 O que significa R & D? 1
#     1957 O que prefere R & D ? 0
#     1958 O que a pesquisa constrói? 1
#     1959 Ao que os candidatos têm acesso? 1
#     1960 Ao que os candidatos aqueles acesso ? 0
#     1961 Ao que o mestrado é voltado? 1
#     1962 Ao que o mestrado é presente ? 0
#     1963 Ao que o mestrado é voltado? 1
#     1964 Ao que os impasses e problemas dado pela difusão das novas tecnologias estão relacionados ? 0
#     1965 Ao que os impasses e problemas trazidos pela difusão das novas tecnologias estão relacionados? 1
#     1966 Ao que os impasses e problemas avançados pela difusão das novas tecnologias estão relacionados ? 0
#     1967 Ao que os impasses e problemas trazidos pela difusão das novas tecnologias estão relacionados? 1
#     1968 Ao que os impasses e problemas posteriores pela difusão das novas tecnologias estão relacionados ? 0
#     1969 Qual um exemplo de tecnologias intelectuais ndidas para lidar com o ciclo da informação ? 0
#     1970 O que a transformação das telecomunicações em uma base tecnológica levou as empresas a processo ? 0
#     1971 O que a transformação das telecomunicações em uma base tecnológica levou as empresas a r ? 0
#     1972 O que a transformação das telecomunicações em uma base tecnológica levou as empresas a descobriram ? 0
#     1973 Em que os CPDs se encaix com o surgimento dos SGBDs ? 0
#     1974 Em que os CPDs se chegaram com o surgimento dos SGBDs ? 0
#     1975 Em que os CPDs se disseram com o surgimento dos SGBDs ? 0
#     1976 Em que lugar ficou a UFMS na edição de 2014 do Guia do Estudante? 1
#     1977 Em que lugar confirmou a UFMS na edição de 2014 do Guia do Estudante ? 0
#     1978 De que forma a Reitora responde por todos os atos no âmbito da Instituição? 1
#     1979 De que forma a Reitora combate por todos os atos no âmbito da Instituição ? 0
#     1980 Qual o prazo mínimo para a divulgação das notas de todas as avaliações que comporão a média de aproveitamento? 1
#     1981 Qual o prazo mínimo para a divulgação das notas de todas as avaliações que comporão a média de aproveitamento? 1
#     1982 Como ficaram conhecidas a série de inovações orientada pelos pacotes de software combinados com a flexibilidade dos terminais ? 0
#     1983 como é realizada a seleção de alunos para uma disciplina cujo número de inscritos compatível o número de vagas ? 0
#     1984 como é realizada a seleção de alunos para uma disciplina cujo número de inscritos impacto o número de vagas ? 0
#     1985 quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de gradução? 1
#     1986 quais são as componentes curriculares não disciplinares no projeto pedagógico de um disco de gradução ? 0
#     1987 O que quer dizer quando um professor e por avaliar a sua matéria através de seminários ao invés de provas ? 0
#     1988 Por que estudos diversas metodologias , sistemas e análise e outros meios de guiar um estudo é tão importante ? 0
#     1989 Por que comandar diversas metodologias , sistemas e análise e outros meios de guiar um estudo é tão importante ? 0
#     1990 Quando os primeiros docentes do curso de Engenharia de Computação da UNIVASF viam suas atividades ? 0
#     1991 Quantos membros haviam no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008? 1
#     1992 Quantos membros permanece no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008 ? 0
#     1993 Como o Ministério da Educação e Saúde passou a se chamar depois que o governo federal criou o Ministério da Saúde? 1
#     1994 Como é maior o iniciante na carreira acadêmica nas universidades britânicas ? 0
#     1995 Como são chamados os professores de ensino fundamental ou médio nos EUA? 1
#     1996 Como são nascidos os professores de ensino fundamental ou médio nos EUA ? 0
#     1997 Como são chamados os professores de ensino fundamental ou médio nos EUA? 1
#     1998 Como são e os professores de ensino fundamental ou médio nos EUA ? 0
#     1999 Como são chamados os professores de ensino fundamental ou médio nos EUA? 1
#     2000 Como são nomeou os professores de ensino fundamental ou médio nos EUA ? 0

# %% [markdown]
# #### Listas documentos originais e perturbados classificados incorretamente

# %%
print("Documentos originais e perturbados classificados incorretamente(classe!=previsão):", len(listaRetornoClassificadoIncorretamente))
conta = 0
for i, linha in listaRetornoClassificadoIncorretamente.iterrows():
  conta = conta + 1
  if i < 2000:    
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == linha["id"]]       
    if len(documento)!= 0:    
      print("   ", conta, documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Documentos originais e perturbados classificados incorretamente(classe!=previsão): 432
#     1 Quais disciplinas tem tratamento diferenciado quanto ao processo de verificação de aprendizagem ? 0
#     2 Quais os resultados finais que devem ser considerados para trabalho de conclusão de curso ? 0
#     3 Estudos realizados no exterior vão ser aproveitados ? 0
#     4 A resolução nº 342 torna recorre o quê? 1
#     5 A resolução nº 342 torna recorre o quê? 1
#     6 A resolução nº 342 torna recorre o quê? 1
#     7 O que deve ser anexado no SigProj? 1
#     8 O que deve ser anexado no SigProj? 1
#     9 O que os professors no Reino Unido geralmente são? 1
#     10 O que os professors no Reino Unido geralmente são? 1
#     11 O que os professors no Reino Unido geralmente são? 1
#     12 Desde quando os processadores vêm sendo construídos em um único circuito integrado? 1
#     13 Desde quando os processadores vêm sendo construídos em um único circuito integrado? 1
#     14 O que é análise de sistemas? 1
#     15 Qual um termo matematicamente equivalente às expressões regulares ? 0
#     16 Onde vai ser feita a matrícula em disciplinas optativas ? 0
#     17 Quem será responsável por alterar a nota do aluno no Siscad? 1
#     18 Quem será responsável por alterar a nota do aluno no Siscad? 1
#     19 Por quem foi desenvolvido o Pergamum? 1
#     20 Por quem foi desenvolvido o Pergamum? 1
#     21 Quais órgãos centrais são comuns em universidades? 1
#     22 Como são chamadas as instruções no computador ? 0
#     23 Em quais áreas a ciência é uma grande força ? 0
#     24 Quem autorizou o curso de Engenharia de Computação da UNIVASF? 1
#     25 Quem autorizou o curso de Engenharia de Computação da UNIVASF? 1
#     26 Quem controla e registra a frequência das atividades acadêmicas? 1
#     27 Quem controla e registra a frequência das atividades acadêmicas? 1
#     28 Quem controla e registra a frequência das atividades acadêmicas? 1
#     29 Há quantas vagas anualmente para cursos de graduação na Facom? 1
#     30 quem define o semestre de posicionamento? 1
#     31 quem define o semestre de posicionamento? 1
#     32 quem define o semestre de posicionamento? 1
#     33 quem define o semestre de posicionamento? 1
#     34 quem define o semestre de posicionamento? 1
#     35 Desde quando o POSCOMP passou a ser realizado no Peru? 1
#     36 Desde quando o POSCOMP passou a ser realizado no Peru? 1
#     37 Desde quando o POSCOMP passou a ser realizado no Peru? 1
#     38 Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#     39 Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#     40 O que envolve o TCC em cursos voltados à ciências ? 0
#     41 Desde quando o curso de engenharia de computação tem sido associado às universidades ? 0
#     42 O que os professors no Reino Unido geralmente são? 1
#     43 O que os professors no Reino Unido geralmente são? 1
#     44 O que os professors no Reino Unido geralmente são? 1
#     45 O que os professors no Reino Unido geralmente são? 1
#     46 O que os professors no Reino Unido geralmente são? 1
#     47 O que os professors no Reino Unido geralmente são? 1
#     48 O que os professors no Reino Unido geralmente são? 1
#     49 Quem listou os maiores desafios no campo da matemática no século XX? 1
#     50 Quem listou os maiores desafios no campo da matemática no século XX? 1
#     51 Quem listou os maiores desafios no campo da matemática no século XX? 1
#     52 Quem listou os maiores desafios no campo da matemática no século XX? 1
#     53 O que os professors no Reino Unido geralmente são? 1
#     54 O que deve ser anexado ao pedido de aproveitamento das atividades complementares? 1
#     55 O que deve ser anexado ao pedido de aproveitamento das atividades complementares? 1
#     56 O que abordam as metodologias e técnicas ligadas à implementação de software? 1
#     57 O que abordam as metodologias e técnicas ligadas à implementação de software? 1
#     58 O que abordam as metodologias e técnicas ligadas à implementação de software? 1
#     59 Quais os modos de abordagem da pesquisa de campo ? 0
#     60 Quem dominava a área de ensino de computação na época? 1
#     61 Quem dominava a área de ensino de computação na época? 1
#     62 Qual a formação pioneira no brasil em engenharia de software ? 0
#     63 Qual lei inclui o estágio de estudantes na lei brasileira ? 0
#     64 A monografia é produzida a partir do quê ? 0
#     65 O que a integração tecnológica flexibilizou? 1
#     66 O que a integração tecnológica flexibilizou? 1
#     67 Qual o objetivo do reitor ? 0
#     68 Qual o funcionamento do Redecomep ? 0
#     69 Do que decorre a validação de matrículas ? 0
#     70 Quem identifica e registra a frequência das atividades acadêmicas ? 0
#     71 Quantos bytes em sequência geralmente são divididos para armazenar números maiores ? 0
#     72 o que verifica com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente ? 0
#     73 O que e PBL ? 0
#     74 Qual curso foi criada através da parceria entre a Escola de Engenharia de São Carlos e o Instituto de Ciências Matemáticas e de Computação da Universidade de São Paulo ? 0
#     75 Qual geralmente é a base de uma monografia? 1
#     76 Qual geralmente é a base de uma monografia? 1
#     77 Qual geralmente é a base de uma monografia? 1
#     78 Qual geralmente é a base de uma monografia? 1
#     79 Quais são os aspectos da ULA ? 0
#     80 O que o trabalho de conclusão de curso aborda ? 0
#     81 Qual deve ser a frequência do acadêmico para que seja suficiente em uma disciplina ? 0
#     82 Por que grande parte dos eletroeletrônicos são acessórios de computação ? 0
#     83 Quais são as instituições orgânicas de ensino de uma universidade ? 0
#     84 Quais matérias Al-Azhar representa ? 0
#     85 Quais são os integrantes da CPU ? 0
#     86 Quais são os efeitos da ULA ? 0
#     87 Ao que os candidatos tem acesso ? 0
#     88 O que permite com que profissionais que não tenham educação superior compram o papel de analista de sistemas ? 0
#     89 quem possui a solicitação de regime de exercícios domiciliares ? 0
#     90 Como é a forma mais adequada de dizer o que é uma metodologia? 1
#     91 Como é a forma mais adequada de dizer o que é uma metodologia? 1
#     92 Como é a forma mais adequada de dizer o que é uma metodologia? 1
#     93 Qual as tarefas do processador? 1
#     94 Qual as tarefas do processador? 1
#     95 Qual as tarefas do processador? 1
#     96 Quais são os órgãos acadêmicos superiores da UFMS ? 0
#     97 Quais as formas mais comuns de computador em uso? 1
#     98 Quais as formas mais comuns de computador em uso? 1
#     99 O que deverá ser anexado no SigProj ? 0
#     100 Qual era o objetivo do curso de engenharia de arquitetura e computação ? 0
#     101 Quando os alunos especiais podem fazer matrícula em disciplinas equivalentes ? 0
#     102 Onde está calculado o número máximo para integralização curricular ? 0
#     103 Qual o objetivo do curso ? 0
#     104 Como é a forma mais adequada de dizer o que é uma metodologia? 1
#     105 Como é a forma mais adequada de dizer o que é uma metodologia? 1
#     106 Como é a forma mais adequada de dizer o que é uma metodologia? 1
#     107 Quem foi o primeiro presidente da República ? 0
#     108 Quando os alunos especiais podem fazer matrícula em disciplinas somente ? 0
#     109 como é construída a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#     110 Qual era o dever do Ministério da Educação anteriormente ? 0
#     111 O que sabe dizer quando um professor opta por avaliar a sua matéria através de seminários ao invés de provas ? 0
#     112 Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto testar quais problemas matemáticos poderiam ser resolvidos por um método efetivo ? 0
#     113 Por quem é administrado o POP da RNP em Mato Grosso do Sul? 1
#     114 O que a Secretaria Acadêmica avalia durante a etapa de validação de matrículas ? 0
#     115 Como era caracterizada a máquina de tecer números de Babbage ? 0
#     116 Para que a triagem pode contribuir eventualmente ? 0
#     117 O Ministério da Instrução Pública passou a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto? 1
#     118 O Ministério da Instrução Pública passou a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto? 1
#     119 O Ministério da Instrução Pública passou a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto? 1
#     120 Em quais áreas a TI é uma grande alternativa ? 0
#     121 Quanto dos sistemas de computação são vistos como “ sistemas embarcados ” ? 0
#     122 O que é caracterizado pelas gramáticas livres de contexto ? 0
#     123 Quantas horas haverá cada reunião de participação em órgãos colegiados ? 0
#     124 Através de qual sistema o teclado da biblioteca da UFMS está disponível para consulta na internet ? 0
#     125 Quem são os atores da investigação empírica ? 0
#     126 O que veio a abrir novas opções para a transformação de dados em informação ? 0
#     127 A UFMS construiu uma área geográfico-educacional de quantos km ? 0
#     128 Qual modelo computacional mostra a construção de uma máquina universal capaz de operar com uma sequência de instruções ? 0
#     129 Como os programas podem , por exemplo , realizar os resultados dos exames ? 0
#     130 O que pode realizar caso uma empresa possua mais uma porta para o mundo aberta ? 0
#     131 Para o que o analista de sistemas deve ter ? 0
#     132 Por que o dispositivo de Babbage se distingue de outros dispositivos ? 0
#     133 Quem é o núcleo da universidade de brasília ? 0
#     134 O que os modelos dados pelos fundamentos científicos da engenharia de software devem permitir ao engenheiro ? 0
#     135 Quais órgãos centrais são comuns em computador ? 0
#     136 Em que a máquina de Hollerith foi dividida ? 0
#     137 Qual um forte papel dado pelo POSCOMP ? 0
#     138 Em que tem inicio os avanços recentes na ciência da computação ? 0
#     139 O que a flexibilização do terminal fez ao computador ? 0
#     140 A resolução nº 342 age recorre o quê ? 0
#     141 quem é responsável pela apuração de conduta inadequadas de alunos e aplicação de medidas corretivas ? 0
#     142 Como a pesquisa empírica ocorre? 1
#     143 Como a pesquisa empírica ocorre? 1
#     144 Como a pesquisa empírica ocorre? 1
#     145 Por que em 2019 o ENEM conquistou um número bastante considerável de inscritos ? 0
#     146 Quem informa as instruções para o computador ? 0
#     147 O que a ciência da computação sofre ? 0
#     148 Quem define a universidade de Nalanda ? 0
#     149 Qual ferramenta é utilizada pela análise individual e análise essencial para modelar o funcionamento do sistema ? 0
#     150 De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#     151 De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#     152 Quem cria os programas ? 0
#     153 Por que uma máquina que possui uma fita de tamanho infinito não pode ser criada ? 0
#     154 Por que uma máquina que possui uma fita de tamanho infinito não pode ser descrita ? 0
#     155 Em que é baseada o sistema de numeração binário ? 0
#     156 Como é conhecida a empresa tocada por Hollerith atualmente ? 0
#     157 Quem orienta e prepara os alunos no ajuste de matrícula ? 0
#     158 Em que o prolog é especializado ? 0
#     159 Ao que a realização do exame não está vinculada? 1
#     160 Qual o estímulo acadêmico para obtenção do título de mestre ? 0
#     161 Desde quando os processadores vêm sendo construídos em um único circuito ffer ? 0
#     162 Qual a exigência para a promoção ao nível de trabalho na Alemanha ? 0
#     163 onde o acadêmico deve requisitar graduação por extraordinário rendimento acadêmico ? 0
#     164 O que a área de ciência da computação sofre? 1
#     165 O que a área de ciência da computação sofre? 1
#     166 Para que os alunos tenham atividades complementares ? 0
#     167 Onde o professor irá passar as provas ? 0
#     168 Para que cada profissional exerce um papel nas organizações ? 0
#     169 Como a Universidade do Paraná é construída hoje em dia ? 0
#     170 O que o discente deve realizar na seleção de disciplinas on-line ? 0
#     171 quantos dos membros do nde devem possuir titulação acadêmica recebida em programas de pósgraduação ? 0
#     172 A quem deve ser solicitado o aproveitamento das disciplinas AD em outro curso de graduação ? 0
#     173 O que o plano de ensino deve permitir ? 0
#     174 Qual a função do governador ? 0
#     175 O que a área visa ? 0
#     176 Como a pesquisa empírica ocorreu ? 0
#     177 Por que a matemática de sistemas é uma área ampla ? 0
#     178 o que os membros do nde devem formar ? 0
#     179 Onde uma pessoa deve ministrar aula para ser contratada professor nos Estados Unidos ? 0
#     180 Onde uma pessoa deve ministrar aula para ser a professor nos Estados Unidos ? 0
#     181 Para que seria a fonte de energia ? 0
#     182 Qual parece ser a ênfase do curso universitário dos analistas de sistemas ? 0
#     183 O que o desenvolvimento cada vez mais rápido de novas tecnologias melhorou ? 0
#     184 Quantos dias complementares o estagiário possui de recesso ? 0
#     185 como deve ser distribuidas as disciplinas que o acadêmico está apto a obter ? 0
#     186 Por que a contagem do tempo mensal é feita a partir do ingresso do acadêmico na UFMS ? 0
#     187 quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de políticas corretivas ? 0
#     188 Quem desenvolve o programa criado da necessidade do usuário pelo analista de sistemas ? 0
#     189 O que o desenvolvimento cada vez mais rápido de novas tecnologias mudou ? 0
#     190 Para onde deve ser enviado o material científico nas pesquisas ? 0
#     191 O que os Programas de Pós-Graduação obtiveram em seu processo seletivo ? 0
#     192 Qual um órgão brasileiro que usa pesquisas descritivas ? 0
#     193 Qual o principal setor da PBL ? 0
#     194 O que é Educação ? 0
#     195 Onde são apresentados os conteúdos de uma disciplina ? 0
#     196 Qual a limitação de um período letivo especial ? 0
#     197 A quem é usada a frase " Ciência é para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos " ? 0
#     198 De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#     199 De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#     200 Qual o prazo para o acadêmico fazer revisão da avaliação acadêmica ? 0
#     201 como ficou a componente curricular não disciplinar no siscad ? 0
#     202 O que a FAPDF criou ? 0
#     203 Quais as exigências da pesquisa de ponta ? 0
#     204 Como os primeiros processadores eram construídos? 1
#     205 Como os primeiros processadores eram construídos? 1
#     206 qual a designação do núcleo docente estruturante ( nde ) ? 0
#     207 O que o regime de exercícios domiciliares garante ao acadêmico? 1
#     208 O que o regime de exercícios domiciliares garante ao acadêmico? 1
#     209 O que o regime de exercícios domiciliares garante ao acadêmico? 1
#     210 O que o regime de exercícios domiciliares garante ao acadêmico? 1
#     211 Qual era o objetivo do curso de ciências de sistemas e computação ? 0
#     212 Como deve ser considerado o pedido de aproveitamento das atividades complementares ? 0
#     213 O que envolve o TCC em cursos ligados à ciências? 1
#     214 O que envolve o TCC em cursos ligados à ciências? 1
#     215 O que envolve o TCC em cursos ligados à ciências? 1
#     216 O que envolve o TCC em cursos ligados à ciências? 1
#     217 O que envolve o TCC em cursos ligados à ciências? 1
#     218 Ao que o trabalho de Mestrado em Engenharia de Computação está associado ? 0
#     219 Quais as áreas que há mais impactado a sociedade contemporânea ? 0
#     220 O que quer dizer quando um professor opta por avaliar a sua matéria através de seminários ao invés de provas? 1
#     221 Quantas pessoas geralmente fazem a monografia ? 0
#     222 As especializações são destinadas ao quê ? 0
#     223 O que é Secac ? 0
#     224 O que é integração de sistemas ? 0
#     225 O que foram WebApps ? 0
#     226 Quanto dos sistemas de computação são conhecidos como “sistemas embarcados”? 1
#     227 Quem é responsável por criar e produzir novas tecnologias ? 0
#     228 O que o profissional de computação precisa utilizar ? 0
#     229 Como o trabalho de conclusão de curso é obrigatório ? 0
#     230 Em quais áreas a mídia é uma grande força ? 0
#     231 Qual o termo utilizado para calcular sequências de passos para completar uma tarefa ? 0
#     232 Ao que a exigência do exame não está vinculada ? 0
#     233 O que envolve o TCC em cursos ligados à ciências? 1
#     234 Qual tipo de estudo é geralmente baseado em uma monografia ? 0
#     235 Como os primeiros processadores eram construídos? 1
#     236 Como os primeiros processadores eram construídos? 1
#     237 A quem o coordenador de curso poderia consultar se necessário ? 0
#     238 Com o que estão relacionados as inovações e aspectos teóricos da economia ? 0
#     239 Qual a finalidade da aplicação empírica ? 0
#     240 Qual um órgão brasileiro que executa pesquisas descritivas ? 0
#     241 Quem possui a primeira máquina de verdade ? 0
#     242 Qual fase é fundamental em qualquer atividade empresarial ? 0
#     243 Por quem é utilizado a pesquisa acadêmica ? 0
#     244 O que foi iniciado com a subdivisão do Departamento de Matemática da UFMS ? 0
#     245 Em que deve ser contratado um profissional em análise e desenvolvimento de sistemas ? 0
#     246 O que a difusão das novas tecnologias de informação trouxe além das facilidades? 1
#     247 O que a difusão das novas tecnologias de informação trouxe além das facilidades? 1
#     248 O que a difusão das novas tecnologias de informação trouxe além das facilidades? 1
#     249 Onde está prevista a tabela horária dos componentes curriculares ? 0
#     250 Quando o acadêmico em regime de exercícios domiciliares pode prestar as provas que foram aplicadas durante o afastamento ? 0
#     251 O que é teoria de sistemas ? 0
#     252 quais são as tarefas da renovação de matrícula ? 0
#     253 Onde está o MIT ? 0
#     254 Qual a exigência para a promoção ao nível de professor na Alemanha? 1
#     255 Qual a exigência para a promoção ao nível de professor na Alemanha? 1
#     256 Qual a exigência para a promoção ao nível de professor na Alemanha? 1
#     257 Qual a finalidade da criação do plano de estudos ? 0
#     258 Quem deve identificar e indicar o motivo da ausência de renovação de matrícula sem justificativa ? 0
#     259 Pelo que é responsável o Estado da educação em Portugal ? 0
#     260 Desde quando os processadores vêm sendo construídos em um único circuito avançado ? 0
#     261 Onde geralmente entra a próxima instrução ? 0
#     262 Para que servem os sistemas modernos ? 0
#     263 Qual a carga horária para publicação de pesquisadores ? 0
#     264 O que as tecnologias da informação incluem além dos componentes de máquina? 1
#     265 Por quem é regido o sistema de bibliotecas da UFMS? 1
#     266 A partir de qual momento o tempo sempre será contabilizado ? 0
#     267 Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#     268 Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#     269 Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#     270 Como o TCC é desenvolvido em instituições ? 0
#     271 Quando o termo máquina computacional perdeu espaço para o termo computador? 1
#     272 Quando o termo máquina computacional perdeu espaço para o termo computador? 1
#     273 Após quantos anos de estágio o estagiário tem direito a recesso virtual ? 0
#     274 A teoria da engenharia é um subcampo de quais áreas ? 0
#     275 o que consta com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente ? 0
#     276 O que envolve o TCC em cursos ligados à ciências? 1
#     277 O que envolve o TCC em cursos ligados à ciências? 1
#     278 como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#     279 como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#     280 como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#     281 Por que é importante descobrir os problemas que a tecnologia traz para as empresas ? 0
#     282 Qual geralmente é a base de uma máquina ? 0
#     283 Por quem é responsável o sistema de bibliotecas da UFMS ? 0
#     284 Em que os sistemas de informação de computador são de extrema importância ? 0
#     285 Onde pode ser aprovada a matrícula em disciplinas optativas ? 0
#     286 Por que o analista de sistemas poderia traduzir a necessidade do usuário ? 0
#     287 Onde deverão ser executadas os sistemas de software complexo ? 0
#     288 O que atende os portadores de traumatismos ? 0
#     289 Por que uma máquina que rete uma fita de tamanho infinito não pode ser construída ? 0
#     290 por meio de quem as instituições de ensino superior devem desenvolver as atribuições e os critérios de constituição do nde ? 0
#     291 Como o tema deve ser inserido ? 0
#     292 Onde poderá ser lançadas as notas e as frequências ? 0
#     293 O tempo além das 360 horas da especialização é destinado para o quê? 1
#     294 O tempo além das 360 horas da especialização é destinado para o quê? 1
#     295 Qual foi a necessidade que permitiu a lei da criação da FAPDF ser alterada pela lei nº 3.652 ? 0
#     296 O que é a academia? 1
#     297 O que é a academia? 1
#     298 O tempo além das 360 horas da especialização é destinado para o quê? 1
#     299 A quem era aplicada o termo computador ? 0
#     300 quais são as partes curriculares não disciplinares no projeto pedagógico de um curso de gradução ? 0
#     301 O que envolve o TCC em cursos ligados à ciências? 1
#     302 O que envolve o TCC em cursos ligados à ciências? 1
#     303 O que envolve o TCC em cursos ligados à ciências? 1
#     304 Qual o prazo de aprovação do plano de absorção das disciplinas ? 0
#     305 O que acontece com os alunos que não conseguiram vaga na turma comum ? 0
#     306 O que acontece com os alunos que não conseguiram vaga na turma docente ? 0
#     307 Quando o computador foi originalmente descrito? 1
#     308 Quando o computador foi originalmente descrito? 1
#     309 Em qual semestre o acadêmico deve ser inserido de preferência ? 0
#     310 O que é necessário para um engenheiro de computação definir a profissão ? 0
#     311 Em que eram empregados os funcionários antes da década de 1920 ? 0
#     312 Quais as formas mais comuns de programa em uso ? 0
#     313 Quais disciplinas estão inclusas nas atividades complementares ? 0
#     314 Qual é o aproveitamento da bolsa de monitoria ? 0
#     315 Qual a duração de um programa letivo especial ? 0
#     316 Quando o acadêmico em regime de exercícios domiciliares poderá livrar as provas que foram aplicadas durante o afastamento ? 0
#     317 em quantas discplinas o acadêmico poderá ter durante o período letivo especial ? 0
#     318 Em que os profissionais atuando em cursos de graduação tecnológicos ou superiores de tecnologias são especializados ? 0
#     319 Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#     320 Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#     321 Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#     322 O que é rapidamente modificado com as transformações contínuas conhecidas pela área da computação ? 0
#     323 Em que ano foi reconhecido o mestrado profissional no Brasil? 1
#     324 Em que ano foi reconhecido o mestrado profissional no Brasil? 1
#     325 Em que ano foi reconhecido o mestrado profissional no Brasil? 1
#     326 Em que ano foi reconhecido o mestrado profissional no Brasil? 1
#     327 Com qual intuito foi destinado o curso de Análise de Sistemas ? 0
#     328 o que a resolução no 401 contem ? 0
#     329 qual etapa a distribuição das vagas disponíveis deve seguir ? 0
#     330 Onde foi constituída a conferência internacional de engenharia de requisitos em 2013 ? 0
#     331 Qual a área que atua e avalia os processos da engenharia de software ? 0
#     332 O que acontece caso o Aluno Especial não requeira o aproveitamento das duas disciplinas anualmente até a data de matrícula ? 0
#     333 Qual é a utilidade dos cursos de pós-graduação profissionais para a instituição ? 0
#     334 Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#     335 Qual o número mínimo de créditos para uma turma de período letivo especial ? 0
#     336 Quando o computador foi originalmente transformado ? 0
#     337 O que acontece caso o aluno se ausente da renovação de matrícula? 1
#     338 O que acontece caso o aluno se ausente da renovação de matrícula? 1
#     339 O que acontece caso o aluno se ausente da renovação de matrícula? 1
#     340 Qual a carga horária para publicação de currículo ? 0
#     341 Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#     342 Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#     343 Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#     344 quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de educação ? 0
#     345 Como os programas podem, por exemplo, utilizar os resultados dos exames? 1
#     346 Como os programas podem, por exemplo, utilizar os resultados dos exames? 1
#     347 Qual precisa ser a frequência do acadêmico para que seja aprovado em uma disciplina ? 0
#     348 Quem é excluído por jubilação obstante o vínculo acadêmico com quem ? 0
#     349 Quem é excluído por jubilação tirar o vínculo acadêmico com quem ? 0
#     350 Quem é excluído por jubilação alimentar o vínculo acadêmico com quem ? 0
#     351 Qual o número mínimo de componentes para uma turma de período letivo especial ? 0
#     352 O que o plano de ensino visa conter ? 0
#     353 Qual o valor de um especialista na maioria das universidades ? 0
#     354 Em que ano o ENEM atingiu 9,2 milhões de escritos ? 0
#     355 O que o compartilhamento de tempo da CPU atende ? 0
#     356 Quem deve incluir e registrar o motivo da ausência de renovação de matrícula sem justificativa ? 0
#     357 Em que o prolog é baseado? 1
#     358 Em que o prolog é baseado? 1
#     359 por quem será executado o plano de estudos ? 0
#     360 por quem será aplicado o plano de estudos ? 0
#     361 O que o professor deve proporcionar ao acadêmico ? 0
#     362 O que é estágio ? 0
#     363 O que eram os portadores de traumatismos ? 0
#     364 Quando foi sediado o Instituto Superior de Pedagogia em Corumbá ? 0
#     365 O que a metodologia da auto-aprendizagem proporciona ao aluno? 1
#     366 O que a metodologia da auto-aprendizagem proporciona ao aluno? 1
#     367 O que a metodologia da auto-aprendizagem proporciona ao aluno? 1
#     368 quais os critérios de constituição do nde? 1
#     369 quais os critérios de constituição do nde? 1
#     370 O que a oportunidade de estudo proporciona a uma pessoa? 1
#     371 Quem foi o primeiro associado da instituição ? 0
#     372 O que põe a enfatização de uma universidade ao sistema ? 0
#     373 Quando a avaliação do coordenador de curso é indispensável ? 0
#     374 Quais os conceitos trazidos pelo significado de engenharia de software? 1
#     375 Quais os conceitos trazidos pelo significado de engenharia de software? 1
#     376 Como são denominadas as versões mais modernas do ábaco ? 0
#     377 como o aluno deverá solicitar a revisão de sua frequência em uma disciplina ? 0
#     378 Quais eram as unidades do Ministério da Educação e Saúde ? 0
#     379 Quando é feito o cálculo do período de posicionamento do discente no curso ? 0
#     380 Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#     381 Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#     382 Em quais áreas a TI é uma grande força? 1
#     383 Em quais áreas a TI é uma grande força? 1
#     384 Em quais áreas a TI é uma grande força? 1
#     385 o que é regime de atividades domiciliares ? 0
#     386 o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é realizada pelo orgão competente ? 0
#     387 O que são dispositivos de entradas e saída ? 0
#     388 Quem irá elaborar as atividades que deverão ser cumpridas durante o regime de exercícios domiciliares ? 0
#     389 O que é rapidamente modificado com as transformações contínuas sofridas pela área da computação? 1
#     390 Qual o objetivo da atuação de campo para a Ciência ? 0
#     391 Qual o currículo acadêmico para obtenção do título de mestre ? 0
#     392 O que é função da computação ? 0
#     393 Qual era o embrião do ensino superior público no Noroeste do Mato Grosso ? 0
#     394 Quando a primeira turma de Engenharia da Computação entrou? 1
#     395 Desde quando o curso de engenharia de computação tem sido adicionado às universidades? 1
#     396 Desde quando o curso de engenharia de computação tem sido adicionado às universidades? 1
#     397 O que é rapidamente modificado com as transformações contínuas sofridas pela área da computação? 1
#     398 O que é rapidamente modificado com as transformações contínuas sofridas pela área da computação? 1
#     399 A quem Zuse decidiu vender o Z1 ? 0
#     400 Por quem eram criadas as tabelas logarítmicas ? 0
#     401 Quem é responsável por criar e desenvolver novas tecnologias? 1
#     402 Para que servem os sistemas utilizados ? 0
#     403 Qual o prazo para a issão de frequência ? 0
#     404 O que deve ser usada no SigProj ? 0
#     405 Quantas regras Pānini utilizou para escrever a gramática de Sânscrito ? 0
#     406 Qual a base da teoria da computação ? 0
#     407 O que o regime de exercícios domiciliares permite ao acadêmico ? 0
#     408 Qual o intuito do POSCOMP ? 0
#     409 Qual a metragem horária para publicação de trabalhos ? 0
#     410 O que garante o uso da TI nas empresas do mundo todo ? 0
#     411 Há quantas vagas anualmente para cursos de graduação na Facom? 1
#     412 Há quantas vagas anualmente para cursos de graduação na Facom? 1
#     413 Há quantas vagas anualmente para cursos de graduação na Facom? 1
#     414 Há quantas vagas anualmente para cursos de graduação na Facom? 1
#     415 A bolsa será entregue para quem ? 0
#     416 Qual o objeto da revisão do curso de engenharia de sistemas e computação ? 0
#     417 Do que surgiu a aplicação da gestão do conhecimento ? 0
#     418 O que fazer com os alunos que não conseguiram vaga na turma pretendida ? 0
#     419 Qual geralmente é a grafia de uma monografia ? 0
#     420 A resolução nº 342 torna recorre o quê? 1
#     421 Quais eram as atividades do Ministério da Educação e Saúde? 1
#     422 Quais eram as atividades do Ministério da Educação e Saúde? 1
#     423 O que o plano de ensino deve apresentar ? 0
#     424 Quem foi o primeiro presidente da instituição? 1
#     425 Quem foi o primeiro presidente da instituição? 1
#     426 Quem também utiliza a sigla inglesa ? 0
#     427 Quando as vagas nas disciplinas estão no período de posicionamento do discente não são garantidas ? 0
#     428 Onde foi chamada oficialmente o termo engenharia de software ? 0
#     429 O Pergamum é acessível por quais computadores? 1
#     430 O Pergamum é acessível por quais computadores? 1
#     431 Como é feito a memória da CPU ? 0
#     432 Como o TCC é classificado em instituições ? 0

# %% [markdown]
# ### Listas

# %% [markdown]
# #### Lista de documentos originais(1-coerente) classificados corretamente(1-coerente)

# %%
def listaOriginalClassificadoCorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    if linha['classe'] == 1 and linha['predicao'] == 1:
        listaRetorno.append(linha['id'])

  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])        
  return dflistaRetorno

# %%
listaDocumentoOriginalClassificadoCorretamente = listaOriginalClassificadoCorretamente(dfDadosClassificacao)
print('listaDocumentoOriginalClassificadoCorretamente:', len(listaDocumentoOriginalClassificadoCorretamente))
# Out:
# listaDocumentoOriginalClassificadoCorretamente: 17825

# %%
print("Lista de documentos originais classificados corretamente(coerentes)(classe=1 & previsão=1):", len(listaDocumentoOriginalClassificadoCorretamente))
for i, documento in listaDocumentoOriginalClassificadoCorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#    12825 - O que é uma universidade de múltiplos campi? 1
#    12826 - O que é uma universidade de múltiplos campi? 1
#    12827 - o que os membros do nde devem exercer? 1
#    12828 - Como é feito o cálculo do posicionamento do discente no curso? 1
#    12829 - Como é feito o cálculo do posicionamento do discente no curso? 1
#    12830 - Como é feito o cálculo do posicionamento do discente no curso? 1
#    12831 - Como é feito o cálculo do posicionamento do discente no curso? 1
#    12832 - Como é feito o cálculo do posicionamento do discente no curso? 1
#    12833 - Qual programa do governo oferece bolsas integrais e parciais através da nota do Enem? 1
#    12834 - O que evidencia a capacidade de redação de textos científicos do aluno nos trabalhos autônomos? 1
#    12835 - Quem é profissional que ministra aulas ou cursos em todos os níveis educacionais no Brasil? 1
#    12836 - O coordenador de curso deve elaborar o plano de estudos após a análise de quê? 1
#    12837 - O coordenador de curso deve elaborar o plano de estudos após a análise de quê? 1
#    12838 - O coordenador de curso deve elaborar o plano de estudos após a análise de quê? 1
#    12839 - Por que a difusão das novas tecnologias trouxe problemas relativos ao direito de informação dos indivíduos? 1
#    12840 - Quando o professor deve devolver as provas aos alunos? 1
#    12841 - Onde os acadêmicos devem retirar e devolver as atividades? 1
#    12842 - O que assistirá os portadores de traumatismos? 1
#    12843 - O que assistirá os portadores de traumatismos? 1
#    12844 - Qual foi o primeiro projeto a receber apoio da instituição? 1
#    12845 - Qual a prioridade do curso de Análise de Sistemas? 1
#    12846 - Qual a prioridade do curso de Análise de Sistemas? 1
#    12847 - Qual curso foi criado através da parceria entre a Escola de Engenharia de São Carlos e o Instituto de Ciências Matemáticas e de Computação da Universidade de São Paulo? 1
#    12848 - Quanto do questionário deve ser respondido para que a carga horária de resposta ao questionário do estudante da Comissão Própria de Avaliação da UFMS seja válida? 1
#    12849 - Quanto do questionário deve ser respondido para que a carga horária de resposta ao questionário do estudante da Comissão Própria de Avaliação da UFMS seja válida? 1
#    12850 - Quanto do questionário deve ser respondido para que a carga horária de resposta ao questionário do estudante da Comissão Própria de Avaliação da UFMS seja válida? 1
#    12851 - Quanto do questionário deve ser respondido para que a carga horária de resposta ao questionário do estudante da Comissão Própria de Avaliação da UFMS seja válida? 1
#    12852 - De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#    12853 - De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#    12854 - De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#    12855 - Qual o fundamento do pedido de regime de exercícios domiciliares? 1
#    12856 - Qual o fundamento do pedido de regime de exercícios domiciliares? 1
#    12857 - Qual o fundamento do pedido de regime de exercícios domiciliares? 1
#    12858 - Qual o fundamento do pedido de regime de exercícios domiciliares? 1
#    12859 - Para quem o professor deve entregar as atividades devolvidas pelo acadêmico? 1
#    12860 - Para quem o professor deve entregar as atividades devolvidas pelo acadêmico? 1
#    12861 - Em que ano o Estatuto Social da FAPDF foi aprovado? 1
#    12862 - Em que ano o Estatuto Social da FAPDF foi aprovado? 1
#    12863 - Qual lei alterou a lei da criação da fundação? 1
#    12864 - Qual lei alterou a lei da criação da fundação? 1
#    12865 - Qual lei alterou a lei da criação da fundação? 1
#    12866 - Qual lei alterou a lei da criação da fundação? 1
#    12867 - Quando o DCT da UFMS foi criado? 1
#    12868 - Qual a ênfase do mestrado profissional em computação aplicada? 1
#    12869 - Qual a ênfase do mestrado profissional em computação aplicada? 1
#    12870 - Quando foi criado o Instituto Superior de Pedagogia em Corumbá? 1
#    12871 - A UFMS abrange uma área geográfico-educacional de quantos km? 1
#    12872 - A UFMS abrange uma área geográfico-educacional de quantos km? 1
#    12873 - Onde foi criada a Real Academia de Artilharia, Fortificação e Desenho? 1
#    12874 - Onde foi criada a Real Academia de Artilharia, Fortificação e Desenho? 1
#    12875 - o que o acadêmico pode solicitar caso este apresente extraordinário rendimento acadêmico? 1
#    12876 - Onde deve ser entregue o pedido de aproveitamento das atividades complementares? 1
#    12877 - O que acontece se o aluno reprovar no TCC? 1
#    12878 - O que acontece se o aluno reprovar no TCC? 1
#    12879 - O que acontece se o aluno reprovar no TCC? 1
#    12880 - Do que os gestores esquecem com tantos recursos disponíveis? 1
#    12881 - Do que os gestores esquecem com tantos recursos disponíveis? 1
#    12882 - Do que os gestores esquecem com tantos recursos disponíveis? 1
#    12883 - Desde quando existem as tecnologias de classificação e organização de informações? 1
#    12884 - Desde quando existem as tecnologias de classificação e organização de informações? 1
#    12885 - Desde quando existem as tecnologias de classificação e organização de informações? 1
#    12886 - Quem foi o primeiro a explicar o uso do 0? 1
#    12887 - O que diz a Tese de Church-Turing? 1
#    12888 - O que diz a Tese de Church-Turing? 1
#    12889 - O que diz a Tese de Church-Turing? 1
#    12890 - Em que a maioria dos cientistas da computação estão interessados? 1
#    12891 - Em que a maioria dos cientistas da computação estão interessados? 1
#    12892 - Quem inventou o sistema de numeração binário? 1
#    12893 - Qual a principal característica dos computadores de hoje em dia? 1
#    12894 - Qual a principal característica dos computadores de hoje em dia? 1
#    12895 - O que as tecnologias e práticas da engenharia de software englobam? 1
#    12896 - Quais palavras são tratadas como sinônimas pelos autores? 1
#    12897 - Quais palavras são tratadas como sinônimas pelos autores? 1
#    12898 - Onde foi sediada a conferência internacional de engenharia de requisitos em 2013? 1
#    12899 - Onde foi sediada a conferência internacional de engenharia de requisitos em 2013? 1
#    12900 - Onde foi sediada a conferência internacional de engenharia de requisitos em 2013? 1
#    12901 - Onde foi sediada a conferência internacional de engenharia de requisitos em 2013? 1
#    12902 - Onde foi sediada a conferência internacional de engenharia de requisitos em 2013? 1
#    12903 - Para que a engenharia de software aplica técnicas de otimização matemática? 1
#    12904 - Para que a engenharia de software aplica técnicas de otimização matemática? 1
#    12905 - Quem saqueou a universidade de Nalanda? 1
#    12906 - Quais níveis de educação uma universidade fornece? 1
#    12907 - Quais níveis de educação uma universidade fornece? 1
#    12908 - quais incisos os acadêmicos deve cumprir? 1
#    12909 - O que é CPDs? 1
#    12910 - O que é CPDs? 1
#    12911 - O que é CPDs? 1
#    12912 - O que é Tecnologia da Informação? 1
#    12913 - O que é Tecnologia da Informação? 1
#    12914 - Onde se localiza a CBC? 1
#    12915 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    12916 - O que o trancamento de matrícula permite ao acadêmico? 1
#    12917 - O que o trancamento de matrícula permite ao acadêmico? 1
#    12918 - O que o trancamento de matrícula permite ao acadêmico? 1
#    12919 - Quem elabora o plano de estudos do aluno que está aproveitando os estudos? 1
#    12920 - Quem elabora o plano de estudos do aluno que está aproveitando os estudos? 1
#    12921 - Quem foram os pioneiros da ciência da computação na UFMS? 1
#    12922 - Quando a área de computação foi solidificada na UFMS? 1
#    12923 - Quais eram as atividades do Ministério da Educação e Saúde? 1
#    12924 - Quais eram as atividades do Ministério da Educação e Saúde? 1
#    12925 - Quais eram as atividades do Ministério da Educação e Saúde? 1
#    12926 - Professor voluntário pode requerer monitor para sua disciplina? 1
#    12927 - Professor voluntário pode requerer monitor para sua disciplina? 1
#    12928 - O processo seletivo dos monitores será feita por quem? 1
#    12929 - O que cabe ao presidente da Comissão do Processo Seletivo? 1
#    12930 - Como a instituição presta serviço à comunidade? 1
#    12931 - Como a instituição presta serviço à comunidade? 1
#    12932 - Em qual canal é transmitido a TVU? 1
#    12933 - Em qual canal é transmitido a TVU? 1
#    12934 - Em qual canal é transmitido a TVU? 1
#    12935 - Em qual canal é transmitido a TVU? 1
#    12936 - Em qual canal é transmitido a TVU? 1
#    12937 - Por quem foi desenvolvido o Pergamum? 1
#    12938 - Em quais áreas as universidades públicas possuem autonomia? 1
#    12939 - O que é UERJ? 1
#    12940 - O que é CREA? 1
#    12941 - O que é CREA? 1
#    12942 - O que é CREA? 1
#    12943 - O que é UFSC? 1
#    12944 - O que o estágio possibilita? 1
#    12945 - O que o estágio possibilita? 1
#    12946 - Qual o objetivo do estágio? 1
#    12947 - Qual o objetivo do estágio? 1
#    12948 - Quando foi implantado o curso de Ciência da Computação na UFMS? 1
#    12949 - O que quer dizer Total de Alunos Equivalentes da Graduação? 1
#    12950 - O que quer dizer Total de Alunos Equivalentes da Graduação? 1
#    12951 - O que acontece com os alunos que não conseguiram vaga na turma pretendida? 1
#    12952 - O que acontece com os alunos que não conseguiram vaga na turma pretendida? 1
#    12953 - O que acontece com os alunos que não conseguiram vaga na turma pretendida? 1
#    12954 - O que acontece com os alunos que não conseguiram vaga na turma pretendida? 1
#    12955 - Qual o princípio da pesquisa descritiva? 1
#    12956 - Qual o princípio da pesquisa descritiva? 1
#    12957 - Qual o princípio da pesquisa descritiva? 1
#    12958 - Como a computação pode ser definida formalmente? 1
#    12959 - Como a computação pode ser definida formalmente? 1
#    12960 - Onde os esquemas podem ser incluídos? 1
#    12961 - Onde os esquemas podem ser incluídos? 1
#    12962 - Como a linguagem de programação é traduzida para a linguagem de máquina? 1
#    12963 - Por que o Z1 foi desprezado pelo governo alemão? 1
#    12964 - Por que o Z1 foi desprezado pelo governo alemão? 1
#    12965 - Por que o Z1 foi desprezado pelo governo alemão? 1
#    12966 - Por que o Z1 foi desprezado pelo governo alemão? 1
#    12967 - Por que o Z1 foi desprezado pelo governo alemão? 1
#    12968 - Desde quando os processadores vêm sendo construídos em um único circuito integrado? 1
#    12969 - Desde quando os processadores vêm sendo construídos em um único circuito integrado? 1
#    12970 - Desde quando os processadores vêm sendo construídos em um único circuito integrado? 1
#    12971 - Qual o foco de desenvolvimento do curso de Engenharia de Computação? 1
#    12972 - Qual a área que estuda e avalia os processos da engenharia de software? 1
#    12973 - Qual a área que estuda e avalia os processos da engenharia de software? 1
#    12974 - Como é denominada a área de otimização matemática na engenharia de software? 1
#    12975 - Quantas horas semanais são garantidas para estudantes do ensino superior? 1
#    12976 - Quantas horas semanais são garantidas para estudantes do ensino superior? 1
#    12977 - Quantas horas semanais são garantidas para estudantes do ensino superior? 1
#    12978 - Quantas horas semanais são garantidas para estudantes do ensino superior? 1
#    12979 - quais as condições para solicitar dispensa para fins de abreviação de curso? 1
#    12980 - quais as condições para solicitar dispensa para fins de abreviação de curso? 1
#    12981 - O que é rapidamente modificado com as transformações contínuas sofridas pela área da computação? 1
#    12982 - O que é rapidamente modificado com as transformações contínuas sofridas pela área da computação? 1
#    12983 - Quando o livro Calculando com numerais hindus foi traduzido para o latim? 1
#    12984 - Quando o livro Calculando com numerais hindus foi traduzido para o latim? 1
#    12985 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    12986 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    12987 - Quando o curso de Engenharia de Sistemas e Computação da UERJ começou a funcionar? 1
#    12988 - O que Hollerith inventou? 1
#    12989 - Para que serve a fonte de energia? 1
#    12990 - Quem escreve as instruções para o computador? 1
#    12991 - Qual o sistema de computação mais conhecido? 1
#    12992 - O que é UNIVASF? 1
#    12993 - Quem também utiliza a sigla WebE? 1
#    12994 - Quem também utiliza a sigla WebE? 1
#    12995 - Quem também utiliza a sigla WebE? 1
#    12996 - O que era o calculador analítico? 1
#    12997 - O que era o calculador analítico? 1
#    12998 - O que era o calculador analítico? 1
#    12999 - O que era o calculador analítico? 1
#    13000 - O que distingue o computador de outras máquinas? 1
#    13001 - Como é chamada a memória da CPU? 1
#    13002 - Como é chamada a memória da CPU? 1
#    13003 - Quem são os ícones da era da informação? 1
#    13004 - Quem são os ícones da era da informação? 1
#    13005 - Qual era o sonho de Gottfried? 1
#    13006 - A quem é destinado a pós-graduação? 1
#    13007 - Qual a principal característica do trabalho autônomo? 1
#    13008 - Junior professor é equivalente ao que nos EUA? 1
#    13009 - Qual era o número de mestrados acadêmicos no Brasil em 2017? 1
#    13010 - Quando o doutorado passou a admitir a modalidade profissional no Brasil? 1
#    13011 - O mestrado em administração de negócios é considerado o que no Brasil? 1
#    13012 - O que é esperado do aluno finalizante do curso de mestrado? 1
#    13013 - Ao que são direcionados os cursos lato sensu? 1
#    13014 - Ao que são direcionados os cursos lato sensu? 1
#    13015 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    13016 - O que o Siscad controla, acompanha e divulga? 1
#    13017 - O que o Siscad controla, acompanha e divulga? 1
#    13018 - A partir de qual momento o tempo cursado será contabilizado? 1
#    13019 - O que o desenvolvimento cada vez mais rápido de novas tecnologias reduziu? 1
#    13020 - O que o desenvolvimento cada vez mais rápido de novas tecnologias reduziu? 1
#    13021 - Com quem a Facom possui parceria para atender à necessidade regional de formação de recursos humanos na área de computação aplicada? 1
#    13022 - Com quem a Facom possui parceria para atender à necessidade regional de formação de recursos humanos na área de computação aplicada? 1
#    13023 - Por que aspectos fundamentais do comportamento humano nunca devem ser estudados e/ou reproduzidos no ambiente controlado do laboratório? 1
#    13024 - Por que aspectos fundamentais do comportamento humano nunca devem ser estudados e/ou reproduzidos no ambiente controlado do laboratório? 1
#    13025 - Por que aspectos fundamentais do comportamento humano nunca devem ser estudados e/ou reproduzidos no ambiente controlado do laboratório? 1
#    13026 - O que é necessário para que um indivíduo se qualifique para obter a habilitação de professor nos países europeus? 1
#    13027 - O que a UFPE criou numa parceria com o Centro de Informática e o Departamento de Eletrônica e Sistemas? 1
#    13028 - O que a UFPE criou numa parceria com o Centro de Informática e o Departamento de Eletrônica e Sistemas? 1
#    13029 - O que é SGBDs? 1
#    13030 - Como ficou conhecida a primeira universidade moderna? 1
#    13031 - Como ficou conhecida a primeira universidade moderna? 1
#    13032 - Como ficou conhecida a primeira universidade moderna? 1
#    13033 - Como ficou conhecida a primeira universidade moderna? 1
#    13034 - Qual uma semelhança entre o ensino médio e faculdade? 1
#    13035 - Em que as atividades complementares incentivam o aluno? 1
#    13036 - Em que as atividades complementares incentivam o aluno? 1
#    13037 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    13038 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    13039 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    13040 - O que a área de ciência da computação sofre? 1
#    13041 - O que é CPDs? 1
#    13042 - O que é CPDs? 1
#    13043 - Onde se localiza a CBC? 1
#    13044 - Onde se localiza a CBC? 1
#    13045 - O que Eduba ensinava? 1
#    13046 - O que Eduba ensinava? 1
#    13047 - Onde surgiu a primeira universidade moderna? 1
#    13048 - quem define o semestre de posicionamento? 1
#    13049 - quais são as atividades para o regime de exercícios domiciliares? 1
#    13050 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    13051 - Quantas horas de atividade complementar os estudantes de licenciatura precisam realizar? 1
#    13052 - Quantas horas de atividade complementar os estudantes de licenciatura precisam realizar? 1
#    13053 - Quantas horas de atividade complementar os estudantes de licenciatura precisam realizar? 1
#    13054 - Quantas horas de atividade complementar os estudantes de licenciatura precisam realizar? 1
#    13055 - Quantas horas de atividade complementar os estudantes de licenciatura precisam realizar? 1
#    13056 - Qual um órgão brasileiro que realiza pesquisas descritivas? 1
#    13057 - Qual um órgão brasileiro que realiza pesquisas descritivas? 1
#    13058 - Qual um órgão brasileiro que realiza pesquisas descritivas? 1
#    13059 - Qual um órgão brasileiro que realiza pesquisas descritivas? 1
#    13060 - Para que o POSCOMP foi concebido? 1
#    13061 - Para que o POSCOMP foi concebido? 1
#    13062 - Para que o POSCOMP foi concebido? 1
#    13063 - Ao que os candidatos têm acesso além do resultado? 1
#    13064 - A quem é reservado o título de professor no Estados Unidos? 1
#    13065 - Quantas avaliações optativas devem haver em cada disciplina? 1
#    13066 - Quantas avaliações optativas devem haver em cada disciplina? 1
#    13067 - Quantas avaliações optativas devem haver em cada disciplina? 1
#    13068 - Em quais matérias o aluno especial não pode se matricular? 1
#    13069 - Quando os alunos especiais podem fazer matrícula em disciplinas isoladas? 1
#    13070 - Quando os alunos especiais podem fazer matrícula em disciplinas isoladas? 1
#    13071 - Quando os alunos especiais podem fazer matrícula em disciplinas isoladas? 1
#    13072 - Qual linguagens de programação empregam as expressões regulares? 1
#    13073 - Qual linguagens de programação empregam as expressões regulares? 1
#    13074 - Qual linguagens de programação empregam as expressões regulares? 1
#    13075 - As especializações são submetidas ao quê? 1
#    13076 - Os modelos propostos são equivalentes ao quê? 1
#    13077 - Os modelos propostos são equivalentes ao quê? 1
#    13078 - Os modelos propostos são equivalentes ao quê? 1
#    13079 - Os modelos propostos são equivalentes ao quê? 1
#    13080 - Quais são os graduados no nível superior? 1
#    13081 - O que um professor precisa para exercer a profissão? 1
#    13082 - O que um professor precisa para exercer a profissão? 1
#    13083 - Onde devem ser lançadas as notas e as frequências? 1
#    13084 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    13085 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    13086 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    13087 - Qual a carga horária em hora-aula para disciplinas dispensadas? 1
#    13088 - Qual a carga horária em hora-aula para disciplinas dispensadas? 1
#    13089 - Qual a carga horária em hora-aula para disciplinas dispensadas? 1
#    13090 - Quantas horas conta cada reunião de participação em órgãos colegiados? 1
#    13091 - O que deve ser anexado ao pedido de aproveitamento das atividades complementares? 1
#    13092 - O que ocorreu em 1970 que tornou as telecomunicações uma base tecnológica? 1
#    13093 - Por quem geralmente é prestado o estágio? 1
#    13094 - Por quem geralmente é prestado o estágio? 1
#    13095 - O que é regime de exercícios domiciliares? 1
#    13096 - O que é regime de exercícios domiciliares? 1
#    13097 - O que é regime de exercícios domiciliares? 1
#    13098 - Quando a FAPDF foi implementada? 1
#    13099 - O que ocorreu com a implantação do curso? 1
#    13100 - Qual um motivo para fazer um curso de gradução? 1
#    13101 - A quem é atribuida a invenção do ábaco? 1
#    13102 - A quem é atribuida a invenção do ábaco? 1
#    13103 - Como são utilizadas as versões mais modernas do ábaco? 1
#    13104 - Por quem eram produzidas as tabelas logarítmicas? 1
#    13105 - A expressão máquina computacional se referia à quê? 1
#    13106 - Quem foi o primeiro a explicar o uso do 0? 1
#    13107 - O que a unidade de controle informa à ULA? 1
#    13108 - Qual é a utilidade dos cursos de pós-graduação profissionais para a sociedade? 1
#    13109 - Qual é a utilidade dos cursos de pós-graduação profissionais para a sociedade? 1
#    13110 - Qual é a utilidade dos cursos de pós-graduação profissionais para a sociedade? 1
#    13111 - Qual fundação do estado de São Paulo concedem bolsas de doutorado no exterior? 1
#    13112 - Quem concluiu que o Brasil já conta com cursos de doutorado de qualidade suficiente? 1
#    13113 - Quem concluiu que o Brasil já conta com cursos de doutorado de qualidade suficiente? 1
#    13114 - Quem concluiu que o Brasil já conta com cursos de doutorado de qualidade suficiente? 1
#    13115 - O tempo além das 360 horas da especialização é destinado para o quê? 1
#    13116 - O tempo além das 360 horas da especialização é destinado para o quê? 1
#    13117 - Quais eram as operações que a máquina construída por Wilhelm Schickard era capaz de fazer? 1
#    13118 - Onde a grade do curso de Engenharia da Computação da UFRG pode ser consultada? 1
#    13119 - Após quantos anos de estágio o estagiário tem direito a recesso remunerado? 1
#    13120 - Após quantos anos de estágio o estagiário tem direito a recesso remunerado? 1
#    13121 - Gestantes poderão ser ajudadas pelo regime de exercícios a partir de qual mês de gestação? 1
#    13122 - Quem deverá informar aos professores a relação dos acadêmicos que estiverem em regime de exercícios domiciliares? 1
#    13123 - Quem deverá informar aos professores a relação dos acadêmicos que estiverem em regime de exercícios domiciliares? 1
#    13124 - Quem deverá informar aos professores a relação dos acadêmicos que estiverem em regime de exercícios domiciliares? 1
#    13125 - Quem deverá informar aos professores a relação dos acadêmicos que estiverem em regime de exercícios domiciliares? 1
#    13126 - Quem irá definir as atividades que deverão ser cumpridas durante o regime de exercícios domiciliares? 1
#    13127 - O que pode tornar a tecnologia da informação um risco? 1
#    13128 - O que pode tornar a tecnologia da informação um risco? 1
#    13129 - Por que as aplicações eram construídas do zero em 1960? 1
#    13130 - Por que as aplicações eram construídas do zero em 1960? 1
#    13131 - Os cursos de pós-graduação englobam quais cursos? 1
#    13132 - Por quem se dá a administração central da UFMS? 1
#    13133 - Por quem se dá a administração central da UFMS? 1
#    13134 - Por quem se dá a administração central da UFMS? 1
#    13135 - Quem emite a declaração de realização de monitoria? 1
#    13136 - Quantos professores compõem a banca examinadora? 1
#    13137 - Quantos professores compõem a banca examinadora? 1
#    13138 - Quanto tempo o aluno passará escrevendo o TCC? 1
#    13139 - Quanto tempo o aluno passará escrevendo o TCC? 1
#    13140 - Quanto tempo o aluno passará escrevendo o TCC? 1
#    13141 - Quanto tempo o aluno passará escrevendo o TCC? 1
#    13142 - O que o trabalho de conclusão de curso contempla? 1
#    13143 - O que o trabalho de conclusão de curso contempla? 1
#    13144 - Em quais áreas a TI é uma grande força? 1
#    13145 - Em que ano o ENEM registrou 9,2 milhões de escritos? 1
#    13146 - Em que ano o ENEM registrou 9,2 milhões de escritos? 1
#    13147 - Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#    13148 - Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#    13149 - Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#    13150 - Por que grande parte dos eletroeletrônicos são sistemas de computação? 1
#    13151 - Ao que o curso de Mestrado em Engenharia de Computação está associado? 1
#    13152 - Ao que o curso de Mestrado em Engenharia de Computação está associado? 1
#    13153 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    13154 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    13155 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    13156 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    13157 - Em que os sistemas de informação de saúde são de extrema importância? 1
#    13158 - O que as tecnologias da informação incluem além dos componentes de máquina? 1
#    13159 - O que as tecnologias da informação incluem além dos componentes de máquina? 1
#    13160 - O que as tecnologias da informação incluem além dos componentes de máquina? 1
#    13161 - O que as tecnologias da informação incluem além dos componentes de máquina? 1
#    13162 - Em que os profissionais formados em cursos de graduação tecnológicos ou superiores de tecnologias são especializados? 1
#    13163 - O que deve ser feito para que a carga horária das atividades complementares sejam computadas? 1
#    13164 - O que deve ser feito para que a carga horária das atividades complementares sejam computadas? 1
#    13165 - O que deve ser feito para que a carga horária das atividades complementares sejam computadas? 1
#    13166 - O que a transformação das telecomunicações em uma base tecnológica levou as empresas a fazerem? 1
#    13167 - Em que os CPDs se transformaram com o surgimento dos SGBDs? 1
#    13168 - Em que os CPDs se transformaram com o surgimento dos SGBDs? 1
#    13169 - Em que os CPDs se transformaram com o surgimento dos SGBDs? 1
#    13170 - Em que os CPDs se transformaram com o surgimento dos SGBDs? 1
#    13171 - Através de qual sistema o acervo da biblioteca da UFMS está disponível para consulta na internet? 1
#    13172 - Através de qual sistema o acervo da biblioteca da UFMS está disponível para consulta na internet? 1
#    13173 - Através de qual sistema o acervo da biblioteca da UFMS está disponível para consulta na internet? 1
#    13174 - O que o discente deve fazer na seleção de disciplinas on-line? 1
#    13175 - Quando o período de posicionamento do discente é definido pelo coordenador de curso? 1
#    13176 - Quando o período de posicionamento do discente é definido pelo coordenador de curso? 1
#    13177 - Quando é iniciado o cálculo do período de posicionamento do discente no curso? 1
#    13178 - A hora-aula deve ser de quantos minutos caso o histórico escolar não a indicar explicitamente? 1
#    13179 - A hora-aula deve ser de quantos minutos caso o histórico escolar não a indicar explicitamente? 1
#    13180 - A hora-aula deve ser de quantos minutos caso o histórico escolar não a indicar explicitamente? 1
#    13181 - A hora-aula deve ser de quantos minutos caso o histórico escolar não a indicar explicitamente? 1
#    13182 - A hora-aula deve ser de quantos minutos caso o histórico escolar não a indicar explicitamente? 1
#    13183 - Qual quesito da gestão da tecnologia da informação não acompanha o mesmo ritmo das políticas de segurança? 1
#    13184 - Qual quesito da gestão da tecnologia da informação não acompanha o mesmo ritmo das políticas de segurança? 1
#    13185 - Em que os gestores devem se atentar para as empresas que fornecem os recursos tecnológicos? 1
#    13186 - Quantos membros haviam no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008? 1
#    13187 - Quantos membros haviam no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008? 1
#    13188 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    13189 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    13190 - O que quer dizer quando um professor opta por avaliar a sua matéria através de seminários ao invés de provas? 1
#    13191 - Em que ano a comunidade científica do distrito federal iniciou a criação de uma instituição dedicada ao incentivo da ciência e tecnologia? 1
#    13192 - Qual foi uma das primeiras escolas superiores especializadas do Brasil? 1
#    13193 - onde deve constar o conteúdo a ser avaliado? 1
#    13194 - onde deve constar o conteúdo a ser avaliado? 1
#    13195 - onde deve constar o conteúdo a ser avaliado? 1
#    13196 - onde deve constar o conteúdo a ser avaliado? 1
#    13197 - onde é realizada a matrícula em disciplinas obrigatórias? 1
#    13198 - onde é realizada a matrícula em disciplinas obrigatórias? 1
#    13199 - onde é realizada a matrícula em disciplinas obrigatórias? 1
#    13200 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    13201 - O que a integração tecnológica flexibilizou? 1
#    13202 - O que a integração tecnológica flexibilizou? 1
#    13203 - Em que a tecnologia da informação pode contribuir? 1
#    13204 - Em quais áreas as universidades públicas possuem autonomia? 1
#    13205 - Para que os pensadores fundavam escolas? 1
#    13206 - Para que os pensadores fundavam escolas? 1
#    13207 - quais os critérios de constituição do nde? 1
#    13208 - quais os critérios de constituição do nde? 1
#    13209 - quais os critérios de constituição do nde? 1
#    13210 - O que o acadêmico deve fazer em casos de atividades práticas em regime de exercícios domiciliares? 1
#    13211 - O que o acadêmico deve fazer em casos de atividades práticas em regime de exercícios domiciliares? 1
#    13212 - O que o acadêmico deve fazer em casos de atividades práticas em regime de exercícios domiciliares? 1
#    13213 - O processo seletivo do programa de monitoria da resolução nº 342 tem qual finalidade? 1
#    13214 - Como pode ser requisitada a inclusão de disciplinas que não estão na estrutura curricular? 1
#    13215 - Como pode ser requisitada a inclusão de disciplinas que não estão na estrutura curricular? 1
#    13216 - Quem deve identificar e registrar o motivo da ausência de renovação de matrícula sem justificativa? 1
#    13217 - Por que a ciência da computação é criticada? 1
#    13218 - Por que a ciência da computação é criticada? 1
#    13219 - Em que é utilizado o nome de Turing? 1
#    13220 - Como podemos armazenar números maiores na memória? 1
#    13221 - Como podemos armazenar números maiores na memória? 1
#    13222 - Onde é feita parte da memória do computador? 1
#    13223 - Onde é feita parte da memória do computador? 1
#    13224 - Onde é feita parte da memória do computador? 1
#    13225 - Qual era o sonho de Gottfried? 1
#    13226 - Por onde a pesquisa de campo se inicia? 1
#    13227 - Por onde a pesquisa de campo se inicia? 1
#    13228 - Quais as exigências da pesquisa de campo? 1
#    13229 - Quais as exigências da pesquisa de campo? 1
#    13230 - Qual a definição de pesquisa como atividade regular? 1
#    13231 - Qual a definição de pesquisa como atividade regular? 1
#    13232 - Onde o POSCOMP é aplicado? 1
#    13233 - Onde o POSCOMP é aplicado? 1
#    13234 - Junior professor é equivalente ao que nos EUA? 1
#    13235 - Junior professor é equivalente ao que nos EUA? 1
#    13236 - Qual a maior federação sindical docente de Portugal? 1
#    13237 - Qual a maior federação sindical docente de Portugal? 1
#    13238 - Qual a principal atividade dos professores nos EUA? 1
#    13239 - Qual a principal atividade dos professores nos EUA? 1
#    13240 - Qual professores possuem uma cátedra pessoal? 1
#    13241 - Como será verificado o rendimento do acadêmico? 1
#    13242 - Que tipo de trabalho é desenvolvido nos cursos de mestrado? 1
#    13243 - Que tipo de trabalho é desenvolvido nos cursos de mestrado? 1
#    13244 - Que tipo de trabalho é desenvolvido nos cursos de mestrado? 1
#    13245 - Pelo que é responsável o ministério da educação em Portugal? 1
#    13246 - Lecturers são equivalentes ao que nos EUA? 1
#    13247 - Quantas avaliações obrigatórias devem haver em cada disciplina? 1
#    13248 - Quantas avaliações obrigatórias devem haver em cada disciplina? 1
#    13249 - O que o concluinte de cursos tecnológicos recebem? 1
#    13250 - O que o trabalho de conclusão de curso vincula? 1
#    13251 - O que determina o semestre de enquadramento do aluno? 1
#    13252 - O que determina o semestre de enquadramento do aluno? 1
#    13253 - Quais os possíveis resultados finais para as atividades complementares? 1
#    13254 - Quais os possíveis resultados finais para as atividades complementares? 1
#    13255 - O que são dispositivos de entrada e saída? 1
#    13256 - Por quem as instruções escritas podem ser utilizadas? 1
#    13257 - Por quem as instruções escritas podem ser utilizadas? 1
#    13258 - Quantas instruções dos programas de computador possuem? 1
#    13259 - Quantas instruções dos programas de computador possuem? 1
#    13260 - Quantas instruções dos programas de computador possuem? 1
#    13261 - Em que a engenharia de software se concentra? 1
#    13262 - A pesquisa básica faz oposição ao quê? 1
#    13263 - O que as tecnologias e práticas da engenharia de software englobam? 1
#    13264 - O que as tecnologias e práticas da engenharia de software englobam? 1
#    13265 - Como foi distribuída as bolsas para cada unidade de administração setorial? 1
#    13266 - Como foi distribuída as bolsas para cada unidade de administração setorial? 1
#    13267 - Quantas bolsas serão concedidas para o edital nº 163? 1
#    13268 - Quantas bolsas serão concedidas para o edital nº 163? 1
#    13269 - Quantas bolsas serão concedidas para o edital nº 163? 1
#    13270 - O que é a monografia segundo o dicionário Aurélio? 1
#    13271 - Onde pode ser feita a matrícula em disciplinas optativas? 1
#    13272 - Quantos membros haviam no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008? 1
#    13273 - Quantos membros haviam no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008? 1
#    13274 - Em que ano a comunidade científica do distrito federal iniciou a criação de uma instituição dedicada ao incentivo da ciência e tecnologia? 1
#    13275 - Em que ano a comunidade científica do distrito federal iniciou a criação de uma instituição dedicada ao incentivo da ciência e tecnologia? 1
#    13276 - Qual a base da análise e interpretação dos dados coletados a partir da observação de fatos e fenômenos exatamente como ocorem realmente? 1
#    13277 - Qual a base da análise e interpretação dos dados coletados a partir da observação de fatos e fenômenos exatamente como ocorem realmente? 1
#    13278 - Qual a base da análise e interpretação dos dados coletados a partir da observação de fatos e fenômenos exatamente como ocorem realmente? 1
#    13279 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    13280 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    13281 - Qual um componente indispensável nas organizações? 1
#    13282 - Qual a principal vantagem das atividades complementares? 1
#    13283 - Com o que as atividades complementares contribuem? 1
#    13284 - Com o que as atividades complementares contribuem? 1
#    13285 - Com o que as atividades complementares contribuem? 1
#    13286 - Com o que as atividades complementares contribuem? 1
#    13287 - O que é monografia? 1
#    13288 - O que é monografia? 1
#    13289 - O que é monografia? 1
#    13290 - O que é a academia? 1
#    13291 - O que é a academia? 1
#    13292 - O que significa R & D? 1
#    13293 - O que a pesquisa constrói? 1
#    13294 - O que a pesquisa constrói? 1
#    13295 - Ao que os candidatos têm acesso? 1
#    13296 - Ao que os candidatos têm acesso? 1
#    13297 - Ao que o mestrado é voltado? 1
#    13298 - Ao que o mestrado é voltado? 1
#    13299 - Quais são os níveis educacionais? 1
#    13300 - Quais são os níveis educacionais? 1
#    13301 - Qual o número mínimo de alunos para uma turma de período letivo especial? 1
#    13302 - Qual o número mínimo de alunos para uma turma de período letivo especial? 1
#    13303 - Qual o número mínimo de alunos para uma turma de período letivo especial? 1
#    13304 - Quem atribui o código DS nas disciplinas dispensadas no histórico escolar do aluno? 1
#    13305 - Quem atribui o código DS nas disciplinas dispensadas no histórico escolar do aluno? 1
#    13306 - Como o acadêmico pode autenticar a fotocópia na Secretaria Acadêmica? 1
#    13307 - Atividades complementares não previstas no edital podem ser computadas? 1
#    13308 - Atividades complementares não previstas no edital podem ser computadas? 1
#    13309 - Atividades complementares não previstas no edital podem ser computadas? 1
#    13310 - É necessário que a cópia dos documentos comprobatórios seja autenticada? 1
#    13311 - O que liberou o uso da TI nas empresas do mundo todo? 1
#    13312 - O que é linguagem de programação? 1
#    13313 - O que é ciência da computação? 1
#    13314 - O que é ciência da computação? 1
#    13315 - O que é ciência da computação? 1
#    13316 - Quando o computador foi originalmente descrito? 1
#    13317 - Quando o computador foi originalmente descrito? 1
#    13318 - Quando o computador foi originalmente descrito? 1
#    13319 - Onde geralmente fica a próxima instrução? 1
#    13320 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    13321 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    13322 - Quais eram as operações que a máquina construída por Wilhelm Schickard era capaz de fazer? 1
#    13323 - Quais eram as operações que a máquina construída por Wilhelm Schickard era capaz de fazer? 1
#    13324 - Quem irá definir as atividades que deverão ser cumpridas durante o regime de exercícios domiciliares? 1
#    13325 - A FAPDF tem finalidade de estimular, apoiar e promover o desenvolvimento científico de qual âmbito? 1
#    13326 - Em que ano foi criado o Ministério da Instrução Pública, Correios e Telégrafos? 1
#    13327 - Em que ano foi criado o Ministério da Instrução Pública, Correios e Telégrafos? 1
#    13328 - Pelo que o MIT optou? 1
#    13329 - Pelo que o MIT optou? 1
#    13330 - Pelo que o MIT optou? 1
#    13331 - O que são WebApps? 1
#    13332 - O que são WebApps? 1
#    13333 - Quem criou o Ministério da Saúde? 1
#    13334 - Qual a arquitetura geralmente adotada no desenvolvimento de WebApps? 1
#    13335 - Qual a arquitetura geralmente adotada no desenvolvimento de WebApps? 1
#    13336 - Quais os conceitos trazidos pelo significado de engenharia de software? 1
#    13337 - Quais os conceitos trazidos pelo significado de engenharia de software? 1
#    13338 - Quando foi publicado o primeiro edital da FAPDF? 1
#    13339 - Quando foi publicado o primeiro edital da FAPDF? 1
#    13340 - Quem autorizou o curso de Engenharia de Computação da UNIVASF? 1
#    13341 - Quem autorizou o curso de Engenharia de Computação da UNIVASF? 1
#    13342 - Como o curso de engenharia de sistemas e computação passará a se chamar? 1
#    13343 - Como o curso de engenharia de sistemas e computação passará a se chamar? 1
#    13344 - Como o curso de engenharia de sistemas e computação passará a se chamar? 1
#    13345 - Como o curso de engenharia de sistemas e computação passará a se chamar? 1
#    13346 - Como o curso de engenharia de sistemas e computação passará a se chamar? 1
#    13347 - Em que o tratamento de engenharia tornaria o desenvolvimento de sistemas de software complexos? 1
#    13348 - Quantas horas diárias de estágio são garantidas para estudantes de educação especial? 1
#    13349 - Qual o objetivo do estágio? 1
#    13350 - Qual o objetivo do estágio? 1
#    13351 - O que é Secac? 1
#    13352 - O que é um pesquisador? 1
#    13353 - Qual a finalidade do mestrado? 1
#    13354 - Qual a finalidade do mestrado? 1
#    13355 - Qual a finalidade do mestrado? 1
#    13356 - O que é a unidade lógica e aritmética? 1
#    13357 - Quais são os parâmetros da ULA? 1
#    13358 - O que são dispositivos de entrada e saída? 1
#    13359 - O que são dispositivos de entrada e saída? 1
#    13360 - O que são dispositivos de entrada e saída? 1
#    13361 - A pesquisa básica faz oposição ao quê? 1
#    13362 - Em que a máquina de Hollerith foi pioneira? 1
#    13363 - Em que a máquina de Hollerith foi pioneira? 1
#    13364 - Em que a máquina de Hollerith foi pioneira? 1
#    13365 - Em que a máquina de Hollerith foi utilizada? 1
#    13366 - Como os dispositivos da placa-mãe são conectados? 1
#    13367 - Quais tipos de interface o barramento pode utilizar? 1
#    13368 - Onde deverão ser executados os sistemas de software complexo? 1
#    13369 - Quantos projetos foram apresentados no primeiro edital da FAPDF? 1
#    13370 - Quais disciplinas o acadêmico deve preencher no formulário eletrônico? 1
#    13371 - Quais disciplinas o acadêmico deve preencher no formulário eletrônico? 1
#    13372 - Qual o tipo de abordagem que ignora a complexidade da realidade social? 1
#    13373 - como fica a componente curricular não disciplinar no siscad? 1
#    13374 - como fica a componente curricular não disciplinar no siscad? 1
#    13375 - como fica a componente curricular não disciplinar no siscad? 1
#    13376 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    13377 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    13378 - Por quem foi designada a profissão de tecnólogo em análise e desenvolvimento de sistemas? 1
#    13379 - Por quem foi designada a profissão de tecnólogo em análise e desenvolvimento de sistemas? 1
#    13380 - Quais atividades foram integradas ao MEC em 8 de novembro de 1990? 1
#    13381 - Quais atividades foram integradas ao MEC em 8 de novembro de 1990? 1
#    13382 - Qual a carga horária para publicação de trabalhos? 1
#    13383 - Em qual semestre as atividades complementares podem ser feitas? 1
#    13384 - Quais atividades estão inclusas nas atividades complementares? 1
#    13385 - Como o TCC é compreendida em instituições? 1
#    13386 - Como o TCC é compreendida em instituições? 1
#    13387 - Como o TCC é compreendida em instituições? 1
#    13388 - Como o TCC é compreendida em instituições? 1
#    13389 - O que o tema do TCC deve atender? 1
#    13390 - a aprovação nas disciplinas depende do que? 1
#    13391 - Como pode ser definido um sistema de informação? 1
#    13392 - Quais alguns exemplos de atividades de extensão? 1
#    13393 - Quais alguns exemplos de atividades de extensão? 1
#    13394 - Do que se tratam as atividades complementares? 1
#    13395 - Do que se tratam as atividades complementares? 1
#    13396 - O ensino superior é composto por quais cursos? 1
#    13397 - Qual era o uso original do ábaco? 1
#    13398 - Qual o prazo para a recontagem de frequência? 1
#    13399 - Quando os professores podem lançar no Siscad? 1
#    13400 - Quando os professores podem lançar no Siscad? 1
#    13401 - Quando os professores podem lançar no Siscad? 1
#    13402 - Para que o dia letivo deve ser considerado? 1
#    13403 - Para que o dia letivo deve ser considerado? 1
#    13404 - Para que o dia letivo deve ser considerado? 1
#    13405 - Qual a duração de um período letivo especial? 1
#    13406 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    13407 - Quantas horas diárias de estágio são garantidas para estudantes de educação especial? 1
#    13408 - Quantas horas diárias de estágio são garantidas para estudantes de educação especial? 1
#    13409 - Quantas horas diárias de estágio são garantidas para estudantes de educação especial? 1
#    13410 - Quando haverá transmutação da espécie para a de vínculo empregatício? 1
#    13411 - Quando haverá transmutação da espécie para a de vínculo empregatício? 1
#    13412 - Quando é iniciado o cálculo do período de posicionamento do discente no curso? 1
#    13413 - Onde os cursos designados como MBA são equiparáveis aos mestrados? 1
#    13414 - Onde os cursos designados como MBA são equiparáveis aos mestrados? 1
#    13415 - O doutorado possui duração média de quatro anos para a realização de quê? 1
#    13416 - Onde uma pessoa deve ministrar aula para ser considerada professor nos Estados Unidos? 1
#    13417 - Onde uma pessoa deve ministrar aula para ser considerada professor nos Estados Unidos? 1
#    13418 - Onde uma pessoa deve ministrar aula para ser considerada professor nos Estados Unidos? 1
#    13419 - Como é dividida a memória do computador? 1
#    13420 - Quais números um byte representa? 1
#    13421 - Quais números um byte representa? 1
#    13422 - A quem foi aplicado o termo computador? 1
#    13423 - A quem foi aplicado o termo computador? 1
#    13424 - A quem foi aplicado o termo computador? 1
#    13425 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos? 1
#    13426 - qual o limite de dias para o acadêmico que requisitou abreviação de curso ser informado do conteúdo? 1
#    13427 - qual o limite de dias para o acadêmico que requisitou abreviação de curso ser informado do conteúdo? 1
#    13428 - até quando o acadêmico deverá frequentar regularmente as disciplinas após solicitar dispensa por abreviação de curso? 1
#    13429 - na solicitação de abreviação de curso, quais disciplinas o acadêmico não pode solicitar dispensa? 1
#    13430 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    13431 - O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? 1
#    13432 - O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? 1
#    13433 - Quais são os níveis educacionais? 1
#    13434 - O que pode ensinar um professor? 1
#    13435 - O que pode ensinar um professor? 1
#    13436 - O que pode ensinar um professor? 1
#    13437 - Qual o dia mundial dos professores? 1
#    13438 - Qual o dia mundial dos professores? 1
#    13439 - Qual o dia mundial dos professores? 1
#    13440 - Quem elabora os horários das aulas? 1
#    13441 - Por quem é administrado o POP da RNP em Mato Grosso do Sul? 1
#    13442 - Por quem é administrado o POP da RNP em Mato Grosso do Sul? 1
#    13443 - O que os Programas de Pós-Graduação utilizam em seu processo seletivo? 1
#    13444 - Não há qualquer interferência de quem nas instruções sobre inscrição e sobre o processo seletivo? 1
#    13445 - Qual o critério de desempate caso o número de inscritos em uma turma seja maior que o de vagas? 1
#    13446 - Qual um dos modelos de pós-graduação do Brasil que se aproximam com o do norte-americano? 1
#    13447 - O candidato deve ter um vinculo efetivo com quem para se matricular sem passar pelo exame de seleção? 1
#    13448 - O candidato deve ter um vinculo efetivo com quem para se matricular sem passar pelo exame de seleção? 1
#    13449 - Qual nível dos cursos de pós-graduação são regulados pela resolução CNE/CES nº 1? 1
#    13450 - Qual nível dos cursos de pós-graduação são regulados pela resolução CNE/CES nº 1? 1
#    13451 - Qual teoria investiga as questões relativas à possibilidade de realizar certos tipos de computação em determinados tipos de máquina? 1
#    13452 - Qual o prazo mínimo para a divulgação das notas de todas as avaliações que comporão a média de aproveitamento? 1
#    13453 - Qual o prazo mínimo para a divulgação das notas de todas as avaliações que comporão a média de aproveitamento? 1
#    13454 - quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de gradução? 1
# ...
#    17606 - Quais tipos de eventos científicos podem ser utilizados para integralização da carga horária das atividades complementares? 1
#    17607 - Quais tipos de eventos científicos podem ser utilizados para integralização da carga horária das atividades complementares? 1
#    17608 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos? 1
#    17609 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos? 1
#    17610 - Como o aluno pode adquirir conhecimento sem o acompanhamento de um professor? 1
#    17611 - Como o aluno pode adquirir conhecimento sem o acompanhamento de um professor? 1
#    17612 - Em que tem impactado os avanços recentes na ciência da computação? 1
#    17613 - Por que é necessário que um professor tenha qualificações acadêmicas e pedagógicas? 1
#    17614 - A quem a coordenação de curso deve solicitar o oferecimento das turmas? 1
#    17615 - A quem a coordenação de curso deve solicitar o oferecimento das turmas? 1
#    17616 - A quem a coordenação de curso deve solicitar o oferecimento das turmas? 1
#    17617 - Quem é profissional que ministra aulas ou cursos em todos os níveis educacionais no Brasil? 1
#    17618 - o que deverá conter o plano de estudos? 1
#    17619 - por quem será aprovado o plano de estudos? 1
#    17620 - por quem será aprovado o plano de estudos? 1
#    17621 - O que as soluções tecnológicas automatizam? 1
#    17622 - O que as soluções tecnológicas automatizam? 1
#    17623 - O que as soluções tecnológicas automatizam? 1
#    17624 - O que as soluções tecnológicas automatizam? 1
#    17625 - Onde os profissionais em sistemas de informação devem atuar? 1
#    17626 - Do que consiste a validação de matrículas? 1
#    17627 - A quais fases da pesquisa bibliográfica dá suporte? 1
#    17628 - A quais fases da pesquisa bibliográfica dá suporte? 1
#    17629 - A quais fases da pesquisa bibliográfica dá suporte? 1
#    17630 - Qual a finalidade da triagem em uma pesquisa? 1
#    17631 - Para que a Ciência usa a pesquisa de campo? 1
#    17632 - Para que a Ciência usa a pesquisa de campo? 1
#    17633 - Para que a Ciência usa a pesquisa de campo? 1
#    17634 - Como Zuse construiu o Z1? 1
#    17635 - Em que foi baseado o Mark I? 1
#    17636 - Em que foi baseado o Mark I? 1
#    17637 - Qual o sistema de computação mais conhecido? 1
#    17638 - Qual o sistema de computação mais conhecido? 1
#    17639 - O que é UNIVASF? 1
#    17640 - Qual o valor de um crédito na maioria das universidades? 1
#    17641 - Qual o valor de um crédito na maioria das universidades? 1
#    17642 - O que aprendemos de forma teórica em um curso? 1
#    17643 - O que aprendemos de forma teórica em um curso? 1
#    17644 - Quando se iniciou a primeira turma de engenheiros de computação? 1
#    17645 - Quando se iniciou a primeira turma de engenheiros de computação? 1
#    17646 - Quais os tipos de abordagem da pesquisa de campo? 1
#    17647 - Qual o interesse do investigador nas pesquisas descritivas? 1
#    17648 - Em qual decreto foi fundado o ministério da educação? 1
#    17649 - Com o que pesquisa laboratorial é confundido? 1
#    17650 - Com o que pesquisa laboratorial é confundido? 1
#    17651 - Com o que pesquisa laboratorial é confundido? 1
#    17652 - Com o que pesquisa laboratorial é confundido? 1
#    17653 - O que é indispensável para pesquisas laboratoriais? 1
#    17654 - O que é indispensável para pesquisas laboratoriais? 1
#    17655 - O que é indispensável para pesquisas laboratoriais? 1
#    17656 - O que é indispensável para pesquisas laboratoriais? 1
#    17657 - Para que o POSCOMP foi concebido? 1
#    17658 - Os modelos propostos são equivalentes ao quê? 1
#    17659 - Quem é responsável por criar e desenvolver novas tecnologias? 1
#    17660 - Quais definições conseguem determinar a expressão TI? 1
#    17661 - quais são as atribuições acadêmicas do nde? 1
#    17662 - Ao que as cotas do estágio devem ser destinadas? 1
#    17663 - Ao que as cotas do estágio devem ser destinadas? 1
#    17664 - Professor voluntário pode requerer monitor para sua disciplina? 1
#    17665 - O processo seletivo dos monitores será feita por quem? 1
#    17666 - Qual tipo de estudo é geralmente feito em uma monografia? 1
#    17667 - O que os cursos tecnológicos conferem ao diplomado? 1
#    17668 - O que os cursos tecnológicos conferem ao diplomado? 1
#    17669 - O que os cursos tecnológicos conferem ao diplomado? 1
#    17670 - Quantas vezes o aproveitamento de estudos pode ser solicitado? 1
#    17671 - O coordenador de curso deve elaborar o plano de estudos após a análise de quê? 1
#    17672 - As especializações são submetidas ao quê? 1
#    17673 - As especializações são submetidas ao quê? 1
#    17674 - Os modelos propostos são equivalentes ao quê? 1
#    17675 - Quais algumas opções para preencher carga horária? 1
#    17676 - Quais algumas opções para preencher carga horária? 1
#    17677 - Quais algumas opções para preencher carga horária? 1
#    17678 - Quais algumas opções para preencher carga horária? 1
#    17679 - Por quantos docentes deve ser composta a comissão? 1
#    17680 - O que o trabalho de conclusão de curso contempla? 1
#    17681 - O que o trabalho de conclusão de curso contempla? 1
#    17682 - Em quais áreas a TI é uma grande força? 1
#    17683 - O que nem sempre são pequenos na área de tecnologia? 1
#    17684 - Quem celebra o contrato do estágio? 1
#    17685 - Onde é sediada a UFMS? 1
#    17686 - Quais números um byte representa? 1
#    17687 - Quais números um byte representa? 1
#    17688 - Para que servem os sistemas embarcados? 1
#    17689 - Para que servem os sistemas embarcados? 1
#    17690 - Para que servem os sistemas embarcados? 1
#    17691 - Como são representadas as instruções no computador? 1
#    17692 - Como são representadas as instruções no computador? 1
#    17693 - quais incisos os acadêmicos deve cumprir? 1
#    17694 - quais os critérios de constituição do nde? 1
#    17695 - quais os critérios de constituição do nde? 1
#    17696 - como deve ser elaborado o projeto pedagógico? 1
#    17697 - como deve ser elaborado o projeto pedagógico? 1
#    17698 - o que é regime de exercícios domiciliares? 1
#    17699 - o que deverá conter o plano de estudos? 1
#    17700 - Como ficou conhecida a primeira universidade moderna? 1
#    17701 - O ensino superior é composto por quais cursos? 1
#    17702 - O ensino superior é composto por quais cursos? 1
#    17703 - O ensino superior é composto por quais cursos? 1
#    17704 - O ensino superior é composto por quais cursos? 1
#    17705 - O que distingue o computador de outras máquinas? 1
#    17706 - O que distingue o computador de outras máquinas? 1
#    17707 - Qual a finalidade da pesquisa descritiva? 1
#    17708 - O calendário acadêmico é aprovado por quem? 1
#    17709 - Como é chamada a memória da CPU? 1
#    17710 - Quem são os ícones da era da informação? 1
#    17711 - A pesquisa básica faz oposição ao quê? 1
#    17712 - Qual a definição de pesquisa como atividade regular? 1
#    17713 - Qual a definição de pesquisa como atividade regular? 1
#    17714 - Onde o POSCOMP é aplicado? 1
#    17715 - Para quem é informado o resultado do exame? 1
#    17716 - O que deve ser feito para que a carga horária das atividades complementares sejam computadas? 1
#    17717 - O que a transformação das telecomunicações em uma base tecnológica levou as empresas a fazerem? 1
#    17718 - A hora-aula deve ser de quantos minutos caso o histórico escolar não a indicar explicitamente? 1
#    17719 - O que a UFMS visa participando do ensino e da preservação dos recursos naturais do meio ambiente? 1
#    17720 - Pelo que passam os membros do corpo docente antes de serem designados Maître de conférences? 1
#    17721 - Quando o acadêmico em regime de exercícios domiciliares poderá prestar as provas que foram aplicadas durante o afastamento? 1
#    17722 - Como será verificado o rendimento do acadêmico? 1
#    17723 - Estudos realizados no exterior podem ser aproveitados? 1
#    17724 - Onde são desenvolvidos os conteúdos de uma disciplina? 1
#    17725 - Qual a carga horária das atividades complementares? 1
#    17726 - Qual a carga horária das atividades complementares? 1
#    17727 - Qual a carga horária das atividades complementares? 1
#    17728 - quais incisos os acadêmicos deve cumprir? 1
#    17729 - Por que a contratação de estágio tem sofrido críticas? 1
#    17730 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos? 1
#    17731 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos? 1
#    17732 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos? 1
#    17733 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos? 1
#    17734 - qual o limite de dias para o acadêmico que requisitou abreviação de curso ser informado do conteúdo? 1
#    17735 - qual o limite de dias para o acadêmico que requisitou abreviação de curso ser informado do conteúdo? 1
#    17736 - qual o limite de dias para o acadêmico que requisitou abreviação de curso ser informado do conteúdo? 1
#    17737 - Qual um dos modelos de pós-graduação do Brasil que se aproximam com o do norte-americano? 1
#    17738 - Qual um dos modelos de pós-graduação do Brasil que se aproximam com o do norte-americano? 1
#    17739 - O candidato deve ter um vinculo efetivo com quem para se matricular sem passar pelo exame de seleção? 1
#    17740 - O que é um pesquisador? 1
#    17741 - O que é um pesquisador? 1
#    17742 - Quem celebra o contrato do estágio? 1
#    17743 - Quem celebra o contrato do estágio? 1
#    17744 - Quantas sessões principais o computador possui? 1
#    17745 - Como Zuse construiu o Z1? 1
#    17746 - O que é UNIVASF? 1
#    17747 - Onde o professor irá lançar as provas? 1
#    17748 - O que é um pesquisador? 1
#    17749 - O que é um pesquisador? 1
#    17750 - O que a FAPDF visa? 1
#    17751 - O que é a FAPDF? 1
#    17752 - O que é a FAPDF? 1
#    17753 - Qual a finalidade da FAPDF? 1
#    17754 - Qual a finalidade da FAPDF? 1
#    17755 - Qual a finalidade da FAPDF? 1
#    17756 - Como é chamada a lei 11.788/2008? 1
#    17757 - Como é chamada a lei 11.788/2008? 1
#    17758 - Quem é o ex-reitor da universidade de brasília? 1
#    17759 - O coordenador de curso deve elaborar o plano de estudos após a análise de quê? 1
#    17760 - Ao que os impasses e problemas trazidos pela difusão das novas tecnologias estão relacionados? 1
#    17761 - Ao que os impasses e problemas trazidos pela difusão das novas tecnologias estão relacionados? 1
#    17762 - Ao que os impasses e problemas trazidos pela difusão das novas tecnologias estão relacionados? 1
#    17763 - como deve ser distribuidas as disciplinas que o acadêmico está apto a cursar? 1
#    17764 - O que é a Redecomep? 1
#    17765 - O que é a Redecomep? 1
#    17766 - Onde é feito a inscrição das disciplinas? 1
#    17767 - Onde é feito a inscrição das disciplinas? 1
#    17768 - Qual o principal tipo de texto científico? 1
#    17769 - Qual a finalidade da pesquisa empírica? 1
#    17770 - Para quem é informado o resultado do exame? 1
#    17771 - Qual a ênfase do mestrado profissional em computação aplicada? 1
#    17772 - Em qual decreto foi fundado o ministério da educação? 1
#    17773 - Ao que os candidatos têm acesso além do resultado? 1
#    17774 - O que nem sempre são pequenos na área de tecnologia? 1
#    17775 - O que nem sempre são pequenos na área de tecnologia? 1
#    17776 - Com quantos alunos a universidade de Nalanda contava? 1
#    17777 - O que o compartilhamento de tempo da CPU gera? 1
#    17778 - O que o compartilhamento de tempo da CPU gera? 1
#    17779 - Junior professor é equivalente ao que nos EUA? 1
#    17780 - Junior professor é equivalente ao que nos EUA? 1
#    17781 - Qual professores possuem uma cátedra pessoal? 1
#    17782 - Como será verificado o rendimento do acadêmico? 1
#    17783 - Por que a contratação de estágio tem sofrido críticas? 1
#    17784 - Por que a contratação de estágio tem sofrido críticas? 1
#    17785 - O que deve ser anexado ao requerimento? 1
#    17786 - Quando Turing cometeu suicídio? 1
#    17787 - À que Turing contribuiu? 1
#    17788 - À que Turing contribuiu? 1
#    17789 - À que Turing contribuiu? 1
#    17790 - O que é computador? 1
#    17791 - Qual a pontuação disponibilizada pela SBC? 1
#    17792 - Qual a pontuação disponibilizada pela SBC? 1
#    17793 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    17794 - O que deve ser feito para que a carga horária das atividades complementares sejam computadas? 1
#    17795 - Quando o acadêmico em regime de exercícios domiciliares poderá prestar as provas que foram aplicadas durante o afastamento? 1
#    17796 - Como o Ministério da Educação e Saúde passou a se chamar depois que o governo federal criou o Ministério da Saúde? 1
#    17797 - Como o Ministério da Educação e Saúde passou a se chamar depois que o governo federal criou o Ministério da Saúde? 1
#    17798 - Quem noticiou que o DF passou a ser um novo exemplo de como a sociedade deve valorizar a atividade científica? 1
#    17799 - O Ministério da Instrução Pública passou a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto? 1
#    17800 - O trancamento de matrícula deve ser feito caso o regime de exercícios domicilares for superior a quantos semestres? 1
#    17801 - O trancamento de matrícula deve ser feito caso o regime de exercícios domicilares for superior a quantos semestres? 1
#    17802 - O que acontece caso o Aluno Especial não requeira o aproveitamento das duas disciplinas cursadas até a data de matrícula? 1
#    17803 - Qual é o nome dado à máquina que calcula polinômios por meio de diferenças? 1
#    17804 - Qual é o nome dado à máquina que calcula polinômios por meio de diferenças? 1
#    17805 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    17806 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    17807 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    17808 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    17809 - Qual a principal característica do trabalho autônomo? 1
#    17810 - O que deve ser anexado ao requerimento? 1
#    17811 - O que deve ser anexado ao requerimento? 1
#    17812 - O que deve ser anexado ao requerimento? 1
#    17813 - Qual a universidade pioneira no brasil em engenharia de software? 1
#    17814 - Quantas regras Pānini utilizou para formular a gramática de Sânscrito? 1
#    17815 - Quantas regras Pānini utilizou para formular a gramática de Sânscrito? 1
#    17816 - Quando Turing cometeu suicídio? 1
#    17817 - O que indicavam as áreas não furadas no tear controlado por cartão perfurado? 1
#    17818 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#    17819 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#    17820 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#    17821 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#    17822 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#    17823 - Quem é considerado o autor da frase ”Ciência da Computação tem tanto a ver com o computador como a astronomia com o telescópio […]"? 1
#    17824 - Em qual semestre o acadêmico deve ser enquadrado no caso de existir pré-requisitos que o impeçam de se matricular no semestre mais próximo ao inicial em que apresentar maior carga horária de disciplinas a serem cursadas? 1

# %% [markdown]
# #### Lista de documento originais(1-coerente) classificados incorretamente(0-incoerente)

# %%
def listaOriginalClassificadoIncorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    if linha['classe'] == 1 and linha['predicao'] == 0:
        listaRetorno.append(linha['id'])
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaDocumentoOriginalClassificadoIncorretamente = listaOriginalClassificadoIncorretamente(dfDadosClassificacao)

print("Lista de documentos originais classificados incorretamente:",len(listaDocumentoOriginalClassificadoIncorretamente))
# Out:
# Lista de documentos originais classificados incorretamente: 175

# %%
print("Lista de documentos originais classificados incorretamente(incoerentes)(classe=1 & previsão=0):", len(listaDocumentoOriginalClassificadoIncorretamente))
for i, documento in listaDocumentoOriginalClassificadoIncorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos originais classificados incorretamente(incoerentes)(classe=1 & previsão=0): 175
#    0 - A resolução nº 342 torna recorre o quê? 1
#    1 - A resolução nº 342 torna recorre o quê? 1
#    2 - A resolução nº 342 torna recorre o quê? 1
#    3 - O que deve ser anexado no SigProj? 1
#    4 - O que deve ser anexado no SigProj? 1
#    5 - O que os professors no Reino Unido geralmente são? 1
#    6 - O que os professors no Reino Unido geralmente são? 1
#    7 - O que os professors no Reino Unido geralmente são? 1
#    8 - Desde quando os processadores vêm sendo construídos em um único circuito integrado? 1
#    9 - Desde quando os processadores vêm sendo construídos em um único circuito integrado? 1
#    10 - O que é análise de sistemas? 1
#    11 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    12 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    13 - Por quem foi desenvolvido o Pergamum? 1
#    14 - Por quem foi desenvolvido o Pergamum? 1
#    15 - Quais órgãos centrais são comuns em universidades? 1
#    16 - Quem autorizou o curso de Engenharia de Computação da UNIVASF? 1
#    17 - Quem autorizou o curso de Engenharia de Computação da UNIVASF? 1
#    18 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    19 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    20 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    21 - Há quantas vagas anualmente para cursos de graduação na Facom? 1
#    22 - quem define o semestre de posicionamento? 1
#    23 - quem define o semestre de posicionamento? 1
#    24 - quem define o semestre de posicionamento? 1
#    25 - quem define o semestre de posicionamento? 1
#    26 - quem define o semestre de posicionamento? 1
#    27 - Desde quando o POSCOMP passou a ser realizado no Peru? 1
#    28 - Desde quando o POSCOMP passou a ser realizado no Peru? 1
#    29 - Desde quando o POSCOMP passou a ser realizado no Peru? 1
#    30 - Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#    31 - Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#    32 - O que os professors no Reino Unido geralmente são? 1
#    33 - O que os professors no Reino Unido geralmente são? 1
#    34 - O que os professors no Reino Unido geralmente são? 1
#    35 - O que os professors no Reino Unido geralmente são? 1
#    36 - O que os professors no Reino Unido geralmente são? 1
#    37 - O que os professors no Reino Unido geralmente são? 1
#    38 - O que os professors no Reino Unido geralmente são? 1
#    39 - Quem listou os maiores desafios no campo da matemática no século XX? 1
#    40 - Quem listou os maiores desafios no campo da matemática no século XX? 1
#    41 - Quem listou os maiores desafios no campo da matemática no século XX? 1
#    42 - Quem listou os maiores desafios no campo da matemática no século XX? 1
#    43 - O que os professors no Reino Unido geralmente são? 1
#    44 - O que deve ser anexado ao pedido de aproveitamento das atividades complementares? 1
#    45 - O que deve ser anexado ao pedido de aproveitamento das atividades complementares? 1
#    46 - O que abordam as metodologias e técnicas ligadas à implementação de software? 1
#    47 - O que abordam as metodologias e técnicas ligadas à implementação de software? 1
#    48 - O que abordam as metodologias e técnicas ligadas à implementação de software? 1
#    49 - Quem dominava a área de ensino de computação na época? 1
#    50 - Quem dominava a área de ensino de computação na época? 1
#    51 - O que a integração tecnológica flexibilizou? 1
#    52 - O que a integração tecnológica flexibilizou? 1
#    53 - Qual geralmente é a base de uma monografia? 1
#    54 - Qual geralmente é a base de uma monografia? 1
#    55 - Qual geralmente é a base de uma monografia? 1
#    56 - Qual geralmente é a base de uma monografia? 1
#    57 - Como é a forma mais adequada de dizer o que é uma metodologia? 1
#    58 - Como é a forma mais adequada de dizer o que é uma metodologia? 1
#    59 - Como é a forma mais adequada de dizer o que é uma metodologia? 1
#    60 - Qual as tarefas do processador? 1
#    61 - Qual as tarefas do processador? 1
#    62 - Qual as tarefas do processador? 1
#    63 - Quais as formas mais comuns de computador em uso? 1
#    64 - Quais as formas mais comuns de computador em uso? 1
#    65 - Como é a forma mais adequada de dizer o que é uma metodologia? 1
#    66 - Como é a forma mais adequada de dizer o que é uma metodologia? 1
#    67 - Como é a forma mais adequada de dizer o que é uma metodologia? 1
#    68 - Por quem é administrado o POP da RNP em Mato Grosso do Sul? 1
#    69 - O Ministério da Instrução Pública passou a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto? 1
#    70 - O Ministério da Instrução Pública passou a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto? 1
#    71 - O Ministério da Instrução Pública passou a ser uma diretoria de onde após sua extinção durante o governo de Floriano Peixoto? 1
#    72 - Como a pesquisa empírica ocorre? 1
#    73 - Como a pesquisa empírica ocorre? 1
#    74 - Como a pesquisa empírica ocorre? 1
#    75 - De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#    76 - De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#    77 - Ao que a realização do exame não está vinculada? 1
#    78 - O que a área de ciência da computação sofre? 1
#    79 - O que a área de ciência da computação sofre? 1
#    80 - De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#    81 - De quem foram as palavras “Há pouco tempo não passava de um sonho de idealistas, hoje é uma realidade irreversível. Mais do que isto é uma garantia de um futuro mais promissor, quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília”? 1
#    82 - Como os primeiros processadores eram construídos? 1
#    83 - Como os primeiros processadores eram construídos? 1
#    84 - O que o regime de exercícios domiciliares garante ao acadêmico? 1
#    85 - O que o regime de exercícios domiciliares garante ao acadêmico? 1
#    86 - O que o regime de exercícios domiciliares garante ao acadêmico? 1
#    87 - O que o regime de exercícios domiciliares garante ao acadêmico? 1
#    88 - O que envolve o TCC em cursos ligados à ciências? 1
#    89 - O que envolve o TCC em cursos ligados à ciências? 1
#    90 - O que envolve o TCC em cursos ligados à ciências? 1
#    91 - O que envolve o TCC em cursos ligados à ciências? 1
#    92 - O que envolve o TCC em cursos ligados à ciências? 1
#    93 - O que quer dizer quando um professor opta por avaliar a sua matéria através de seminários ao invés de provas? 1
#    94 - Quanto dos sistemas de computação são conhecidos como “sistemas embarcados”? 1
#    95 - O que envolve o TCC em cursos ligados à ciências? 1
#    96 - Como os primeiros processadores eram construídos? 1
#    97 - Como os primeiros processadores eram construídos? 1
#    98 - O que a difusão das novas tecnologias de informação trouxe além das facilidades? 1
#    99 - O que a difusão das novas tecnologias de informação trouxe além das facilidades? 1
#    100 - O que a difusão das novas tecnologias de informação trouxe além das facilidades? 1
#    101 - Qual a exigência para a promoção ao nível de professor na Alemanha? 1
#    102 - Qual a exigência para a promoção ao nível de professor na Alemanha? 1
#    103 - Qual a exigência para a promoção ao nível de professor na Alemanha? 1
#    104 - O que as tecnologias da informação incluem além dos componentes de máquina? 1
#    105 - Por quem é regido o sistema de bibliotecas da UFMS? 1
#    106 - Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#    107 - Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#    108 - Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#    109 - Quando o termo máquina computacional perdeu espaço para o termo computador? 1
#    110 - Quando o termo máquina computacional perdeu espaço para o termo computador? 1
#    111 - O que envolve o TCC em cursos ligados à ciências? 1
#    112 - O que envolve o TCC em cursos ligados à ciências? 1
#    113 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    114 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    115 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    116 - O tempo além das 360 horas da especialização é destinado para o quê? 1
#    117 - O tempo além das 360 horas da especialização é destinado para o quê? 1
#    118 - O que é a academia? 1
#    119 - O que é a academia? 1
#    120 - O tempo além das 360 horas da especialização é destinado para o quê? 1
#    121 - O que envolve o TCC em cursos ligados à ciências? 1
#    122 - O que envolve o TCC em cursos ligados à ciências? 1
#    123 - O que envolve o TCC em cursos ligados à ciências? 1
#    124 - Quando o computador foi originalmente descrito? 1
#    125 - Quando o computador foi originalmente descrito? 1
#    126 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#    127 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#    128 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo? 1
#    129 - Em que ano foi reconhecido o mestrado profissional no Brasil? 1
#    130 - Em que ano foi reconhecido o mestrado profissional no Brasil? 1
#    131 - Em que ano foi reconhecido o mestrado profissional no Brasil? 1
#    132 - Em que ano foi reconhecido o mestrado profissional no Brasil? 1
#    133 - Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#    134 - O que acontece caso o aluno se ausente da renovação de matrícula? 1
#    135 - O que acontece caso o aluno se ausente da renovação de matrícula? 1
#    136 - O que acontece caso o aluno se ausente da renovação de matrícula? 1
#    137 - Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#    138 - Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#    139 - Por que países mais avançados em ciência hoje colem bons frutos nessa área? 1
#    140 - Como os programas podem, por exemplo, utilizar os resultados dos exames? 1
#    141 - Como os programas podem, por exemplo, utilizar os resultados dos exames? 1
#    142 - Em que o prolog é baseado? 1
#    143 - Em que o prolog é baseado? 1
#    144 - O que a metodologia da auto-aprendizagem proporciona ao aluno? 1
#    145 - O que a metodologia da auto-aprendizagem proporciona ao aluno? 1
#    146 - O que a metodologia da auto-aprendizagem proporciona ao aluno? 1
#    147 - quais os critérios de constituição do nde? 1
#    148 - quais os critérios de constituição do nde? 1
#    149 - O que a oportunidade de estudo proporciona a uma pessoa? 1
#    150 - Quais os conceitos trazidos pelo significado de engenharia de software? 1
#    151 - Quais os conceitos trazidos pelo significado de engenharia de software? 1
#    152 - Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#    153 - Quem é excluído por jubilação perde o vínculo acadêmico com quem? 1
#    154 - Em quais áreas a TI é uma grande força? 1
#    155 - Em quais áreas a TI é uma grande força? 1
#    156 - Em quais áreas a TI é uma grande força? 1
#    157 - O que é rapidamente modificado com as transformações contínuas sofridas pela área da computação? 1
#    158 - Quando a primeira turma de Engenharia da Computação entrou? 1
#    159 - Desde quando o curso de engenharia de computação tem sido adicionado às universidades? 1
#    160 - Desde quando o curso de engenharia de computação tem sido adicionado às universidades? 1
#    161 - O que é rapidamente modificado com as transformações contínuas sofridas pela área da computação? 1
#    162 - O que é rapidamente modificado com as transformações contínuas sofridas pela área da computação? 1
#    163 - Quem é responsável por criar e desenvolver novas tecnologias? 1
#    164 - Há quantas vagas anualmente para cursos de graduação na Facom? 1
#    165 - Há quantas vagas anualmente para cursos de graduação na Facom? 1
#    166 - Há quantas vagas anualmente para cursos de graduação na Facom? 1
#    167 - Há quantas vagas anualmente para cursos de graduação na Facom? 1
#    168 - A resolução nº 342 torna recorre o quê? 1
#    169 - Quais eram as atividades do Ministério da Educação e Saúde? 1
#    170 - Quais eram as atividades do Ministério da Educação e Saúde? 1
#    171 - Quem foi o primeiro presidente da instituição? 1
#    172 - Quem foi o primeiro presidente da instituição? 1
#    173 - O Pergamum é acessível por quais computadores? 1
#    174 - O Pergamum é acessível por quais computadores? 1

# %% [markdown]
# #### Lista Documentos Perturbados(0-incoerente) Classificados corretamente(0-incoerente)

# %%
def listaPerturbadoClassificadoCorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    if linha['classe'] == 0 and linha['predicao'] == 0:
        listaRetorno.append(linha['id'])
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaDocumentoPerturbadoClassificadoCorretamente = listaPerturbadoClassificadoCorretamente(dfDadosClassificacao)
print('listaDocumentoPerturbadoClassificadoCorretamente:', len(listaDocumentoPerturbadoClassificadoCorretamente))
# Out:
# listaDocumentoPerturbadoClassificadoCorretamente: 17743

# %%
print("Lista de documentos perturbados classificados corretamente(incoerentes)(classe=0 & previsão=0):", len(listaDocumentoPerturbadoClassificadoCorretamente))
for i, documento in listaDocumentoPerturbadoClassificadoCorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#    12743 - Do que a aprovação nas disciplinas consideradas ? 0
#    12744 - Do que a aprovação nas disciplinas necessária ? 0
#    12745 - Do que a aprovação nas disciplinas equivalentes ? 0
#    12746 - Estudos realizados no exterior podem ser procedimentos ? 0
#    12747 - Qual tema de TCC é elevado ? 0
#    12748 - Qual tema de TCC é sempre ? 0
#    12749 - Qual tema de TCC é futuro ? 0
#    12750 - Quais palavras são pensar como sinônimas pelos autores ? 0
#    12751 - Quais palavras são ente como sinônimas pelos autores ? 0
#    12752 - Qual a universidade pioneira no brasil em alfabetização de software ? 0
#    12753 - Qual a instituições pioneira no brasil em engenharia de software ? 0
#    12754 - Qual o decidido do pedido de regime de exercícios domiciliares ? 0
#    12755 - Qual o n do pedido de regime de exercícios domiciliares ? 0
#    12756 - Qual o mistério do pedido de regime de exercícios domiciliares ? 0
#    12757 - Quando uma universidade pode incentivar uma federação de escolas ? 0
#    12758 - Quando uma universidade pode o uma federação de escolas ? 0
#    12759 - Quais áreas a universidade de Nalanda destacou ? 0
#    12760 - Quais áreas a universidade de Nalanda utilizava ? 0
#    12761 - Quando as universidades se classes bastante comuns nos EUA ? 0
#    12762 - Quando as universidades se artes bastante comuns nos EUA ? 0
#    12763 - Onde se compõe as médias de aproveitamento das disciplinas cursadas ? 0
#    12764 - Como é , o cálculo do posicionamento do discente no curso ? 0
#    12765 - Como é encontrado o cálculo do posicionamento do discente no curso ? 0
#    12766 - Como é fabricado o cálculo do posicionamento do discente no curso ? 0
#    12767 - Como é afeta o cálculo do posicionamento do discente no curso ? 0
#    12768 - Como é norte o cálculo do posicionamento do discente no curso ? 0
#    12769 - Qual o tipo de abordagem que reduziu a complexidade da realidade social ? 0
#    12770 - Qual o tipo de abordagem que substitui a complexidade da realidade social ? 0
#    12771 - Qual o tipo de abordagem que precisa a complexidade da realidade social ? 0
#    12772 - Onde são ir as instruções sobre a inscrição e processo seletivo ? 0
#    12773 - Onde são espalhadas as instruções sobre a inscrição e processo seletivo ? 0
#    12774 - Qual programa do governo identificou bolsas integrais e parciais através da nota do Enem ? 0
#    12775 - O que utilizar a capacidade de redação de textos científicos do aluno nos trabalhos autônomos ? 0
#    12776 - Em quais casos o acadêmico pode imediata a matrícula nos dois primeiros períodos letivos ? 0
#    12777 - Em quais casos o acadêmico pode atender a matrícula nos dois primeiros períodos letivos ? 0
#    12778 - O coordenador de curso prevê elaborar o plano de estudos após a análise de quê ? 0
#    12779 - O coordenador de curso estaria elaborar o plano de estudos após a análise de quê ? 0
#    12780 - O coordenador de curso dispõe elaborar o plano de estudos após a análise de quê ? 0
#    12781 - O que deve ser feito para que a carga horária das atividades complementares sejam em ? 0
#    12782 - O que deve ser feito para que a carga horária das atividades complementares sejam supera ? 0
#    12783 - Quem firma o pedido de regime de exercícios domiciliares ? 0
#    12784 - Onde os acadêmicos devem abrir e devolver as atividades ? 0
#    12785 - Qual foi o primeiro projeto a tenham apoio da instituição ? 0
#    12786 - Quantos consultores ad hoc assinar os projetos ? 0
#    12787 - Quantos consultores ad hoc escreveram os projetos ? 0
#    12788 - Quantos consultores ad hoc permitiram os projetos ? 0
#    12789 - Quem foram os pioneiros da ciência da computação na tortura ? 0
#    12790 - Qual a Escola do curso de Análise de Sistemas ? 0
#    12791 - Qual a prioridade do óleo de Análise de Sistemas ? 0
#    12792 - Qual curso foi andamento através da parceria entre a Escola de Engenharia de São Carlos e o Instituto de Ciências Matemáticas e de Computação da Universidade de São Paulo ? 0
#    12793 - Quanto do questionário deve ser 6 para que a carga horária de resposta ao questionário do estudante da Comissão Própria de Avaliação da UFMS seja válida ? 0
#    12794 - Quanto do questionário deve ser concluído para que a carga horária de resposta ao questionário do estudante da Comissão Própria de Avaliação da UFMS seja válida ? 0
#    12795 - Quanto do questionário realiza ser respondido para que a carga horária de resposta ao questionário do estudante da Comissão Própria de Avaliação da UFMS seja válida ? 0
#    12796 - Quanto do questionário como ser respondido para que a carga horária de resposta ao questionário do estudante da Comissão Própria de Avaliação da UFMS seja válida ? 0
#    12797 - De quem foram as palavras “ Há pouco tempo não passava de um sonho de idealistas , hoje é uma realidade irreversível . Mais do que isto é uma garantia de um futuro mais promissor , quando os resultados das pesquisas financiadas se constituírem-se em fatos que serem os moradores de Brasília ” ? 0
#    12798 - De quem foram as palavras “ Há pouco tempo não passava de um sonho de idealistas , hoje é uma realidade irreversível . Mais do que isto é uma garantia de um futuro mais promissor , quando os resultados das pesquisas residentes se constituírem-se em fatos que beneficiarão os moradores de Brasília ” ? 0
#    12799 - De quem foram as palavras “ Há pouco tempo não começou de um sonho de idealistas , hoje é uma realidade irreversível . Mais do que isto é uma garantia de um futuro mais promissor , quando os resultados das pesquisas financiadas se constituírem-se em fatos que beneficiarão os moradores de Brasília ” ? 0
#    12800 - Quantas horas semanais são o para estudantes do ensino superior ? 0
#    12801 - Quantas horas semanais são jurídicas para estudantes do ensino superior ? 0
#    12802 - Quantas horas semanais são liberdade para estudantes do ensino superior ? 0
#    12803 - Qual o fundamento do movimento de regime de exercícios domiciliares ? 0
#    12804 - Quem irá ará o regime de exercícios domiciliares do acadêmico ? 0
#    12805 - Para quem o professor escrever entregar as atividades devolvidas pelo acadêmico ? 0
#    12806 - Para quem o professor deve ceder as atividades devolvidas pelo acadêmico ? 0
#    12807 - Em que ano o Estatuto Social da FAPDF foi início ? 0
#    12808 - Quem é o ensino da universidade de brasília ? 0
#    12809 - Quem é o dinheiro da universidade de brasília ? 0
#    12810 - Qual lei limite a lei da criação da fundação ? 0
#    12811 - Qual lei compôs a lei da criação da fundação ? 0
#    12812 - Qual lei integrou a lei da criação da fundação ? 0
#    12813 - Qual lei comentou a lei da criação da fundação ? 0
#    12814 - Quando o DCT da UFMS foi surgindo ? 0
#    12815 - Qual a ênfase do mestrado profissional em computação disciplina ? 0
#    12816 - Qual a ênfase do mestrado profissional em computação paulista ? 0
#    12817 - O que começou a fontes novas opções para a transformação de dados em informação ? 0
#    12818 - Qual o conceito da Vila segundo a avaliação do Índice Geral de Cursos ? 0
#    12819 - Quando foi armado o Instituto Superior de Pedagogia em Corumbá ? 0
#    12820 - A UFMS nacional uma área geográfico-educacional de quantos km ? 0
#    12821 - A UFMS governou uma área geográfico-educacional de quantos km ? 0
#    12822 - Onde foi baseado a Real Academia de Artilharia , Fortificação e Desenho ? 0
#    12823 - Onde foi inauguração a Real Academia de Artilharia , Fortificação e Desenho ? 0
#    12824 - quais as condições para recorrente dispensa para fins de abreviação de curso ? 0
#    12825 - quais as condições para decorrência dispensa para fins de abreviação de curso ? 0
#    12826 - quais as condições para indicada dispensa para fins de abreviação de curso ? 0
#    12827 - Onde deve ser line o pedido de aproveitamento das atividades complementares ? 0
#    12828 - O que acho se o aluno reprovar no TCC ? 0
#    12829 - O que mede se o aluno reprovar no TCC ? 0
#    12830 - Desde quando ler as tecnologias de classificação e organização de informações ? 0
#    12831 - Desde quando úteis as tecnologias de classificação e organização de informações ? 0
#    12832 - Desde quando suporta as tecnologias de classificação e organização de informações ? 0
#    12833 - Quem foi o primeiro a , o uso do 0 ? 0
#    12834 - O que estuda a Tese de Church-Turing ? 0
#    12835 - O que aumentou a Tese de Church-Turing ? 0
#    12836 - O que surge a Tese de Church-Turing ? 0
#    12837 - Em que a maioria dos cientistas da Prefeitura estão interessados ? 0
#    12838 - Em que a maioria dos segurança da computação estão interessados ? 0
#    12839 - Qual a principal estação dos computadores de hoje em dia ? 0
#    12840 - Onde foi expor a conferência internacional de engenharia de requisitos em 2013 ? 0
#    12841 - Onde foi resgatar a conferência internacional de engenharia de requisitos em 2013 ? 0
#    12842 - Onde foi complementar a conferência internacional de engenharia de requisitos em 2013 ? 0
#    12843 - Onde foi chegada a conferência internacional de engenharia de requisitos em 2013 ? 0
#    12844 - Para que a engenharia de software operar técnicas de otimização matemática ? 0
#    12845 - Onde partiu o desenvolvimento da primeira universidade árabe ? 0
#    12846 - Onde promoveu o desenvolvimento da primeira universidade árabe ? 0
#    12847 - O que é uma universidade de múltiplos ares ? 0
#    12848 - O que é uma universidade de múltiplos relatórios ? 0
#    12849 - Quais níveis de educação uma universidade implica ? 0
#    12850 - Quais níveis de educação uma universidade ouve ? 0
#    12851 - por quem o pedido de avaliação é transmitido ? 0
#    12852 - por quem o pedido de avaliação é referente ? 0
#    12853 - por quem o pedido de avaliação é originalmente ? 0
#    12854 - por quem o pedido de avaliação é orientado ? 0
#    12855 - por quem o pedido de avaliação é válida ? 0
#    12856 - quais incisos os acadêmicos deve têm ? 0
#    12857 - O que 50 CPDs ? 0
#    12858 - O que escolheu CPDs ? 0
#    12859 - O que conheceu CPDs ? 0
#    12860 - O que a integração tecnológica acarre ? 0
#    12861 - O que a integração tecnológica mente ? 0
#    12862 - O que a integração tecnológica acima ? 0
#    12863 - O que a integração tecnológica possa ? 0
#    12864 - O que a integração tecnológica revela ? 0
#    12865 - O que é Tecnologia da Estrada ? 0
#    12866 - O que é Tecnologia da Internet ? 0
#    12867 - Quem será responsável por principal a nota do aluno no Siscad ? 0
#    12868 - Quem será responsável por entender a nota do aluno no Siscad ? 0
#    12869 - Onde está mencionada a documentação que deve ser teste pelo candidato ingressante ? 0
#    12870 - O que o trancamento de matrícula consiste ao acadêmico ? 0
#    12871 - O que o trancamento de matrícula efetivo ao acadêmico ? 0
#    12872 - O que o trancamento de matrícula cobre ao acadêmico ? 0
#    12873 - Quem atribui o código DS nas disciplinas produzida no histórico escolar do aluno ? 0
#    12874 - Quem atribui o código DS nas disciplinas gerado no histórico escolar do aluno ? 0
#    12875 - Quem interessa o plano de estudos do aluno que está aproveitando os estudos ? 0
#    12876 - Quem conduz o plano de estudos do aluno que está aproveitando os estudos ? 0
#    12877 - Quais eram as interesse do Ministério da Educação e Saúde ? 0
#    12878 - Quais eram as Pessoas do Ministério da Educação e Saúde ? 0
#    12879 - Quantas bolsas serão somente para o edital nº 163 ? 0
#    12880 - Quantas bolsas serão alterações para o edital nº 163 ? 0
#    12881 - Quantas bolsas serão com para o edital nº 163 ? 0
#    12882 - O processo seletivo dos monitores será começado por quem ? 0
#    12883 - O que responde ao presidente da Comissão do Processo Seletivo ? 0
#    12884 - Em que a tecnologia da informação pode perfeitamente ? 0
#    12885 - Em qual canal é adotada a TVU ? 0
#    12886 - Em qual canal é exclusivamente a TVU ? 0
#    12887 - Em qual canal é encontra a TVU ? 0
#    12888 - Em qual canal é áudio a TVU ? 0
#    12889 - Em qual canal é gravados a TVU ? 0
#    12890 - Por quem foi Black o Pergamum ? 0
#    12891 - O que censura CREA ? 0
#    12892 - O que aprender CREA ? 0
#    12893 - O que Acordo CREA ? 0
#    12894 - O que visita UFSC ? 0
#    12895 - O que o estágio utiliza ? 0
#    12896 - O que o estágio espera ? 0
#    12897 - Qual o objetivo do presente ? 0
#    12898 - O que foi dita no distrito federal em cumprimento a lei número 347 ? 0
#    12899 - O que foi devido no distrito federal em cumprimento a lei número 347 ? 0
#    12900 - Quais atividades foram juntos ao MEC em 8 de novembro de 1990 ? 0
#    12901 - Quais atividades foram permitido ao MEC em 8 de novembro de 1990 ? 0
#    12902 - Quais atividades foram introduzidas ao MEC em 8 de novembro de 1990 ? 0
#    12903 - Quais atividades foram expor ao MEC em 8 de novembro de 1990 ? 0
#    12904 - Quais atividades foram consulta ao MEC em 8 de novembro de 1990 ? 0
#    12905 - O que quer mos Total de Alunos Equivalentes da Graduação ? 0
#    12906 - O que parar com os alunos que não conseguiram vaga na turma pretendida ? 0
#    12907 - Qual o princípio da introdução descritiva ? 0
#    12908 - Qual o princípio da aceitação descritiva ? 0
#    12909 - Qual o princípio da expectativa descritiva ? 0
#    12910 - Qual a pontuação dominada pela SBC ? 0
#    12911 - Qual a pontuação procura pela SBC ? 0
#    12912 - Como a computação via ser definida formalmente ? 0
#    12913 - Qual tema de TCC é câncer ? 0
#    12914 - Onde os esquemas podem ser direto ? 0
#    12915 - Onde os esquemas podem ser solos ? 0
#    12916 - Como a linguagem de programação é diferente para a linguagem de máquina ? 0
#    12917 - Como a linguagem de programação é necessário para a linguagem de máquina ? 0
#    12918 - Desde quando os processadores vêm sendo construídos em um único circuito este ? 0
#    12919 - Desde quando os processadores unidos sendo construídos em um único circuito integrado ? 0
#    12920 - Desde quando os processadores vêm sendo veículos em um único circuito integrado ? 0
#    12921 - Qual o foco de desenvolvimento do presente de Engenharia de Computação ? 0
#    12922 - Qual a área que disse e avalia os processos da engenharia de software ? 0
#    12923 - Qual a área que cliente e avalia os processos da engenharia de software ? 0
#    12924 - Como é praticamente a área de otimização matemática na engenharia de software ? 0
#    12925 - Quantas horas diárias de estágio são distantes para estudantes de educação especial ? 0
#    12926 - Quantas horas diárias de estágio são exemplos para estudantes de educação especial ? 0
#    12927 - Quantas horas diárias de estágio são vindas para estudantes de educação especial ? 0
#    12928 - Quantas horas diárias de estágio são distantes para estudantes de educação especial ? 0
#    12929 - Quantos dias Domingos o estagiário possui de recesso ? 0
#    12930 - qual a nota mínima para o acadêmico que identifica abreviação de curso ser aprovado ? 0
#    12931 - qual a nota mínima para o acadêmico que faculdade abreviação de curso ser aprovado ? 0
#    12932 - O que é rapidamente estranho com as transformações contínuas sofridas pela área da computação ? 0
#    12933 - O que indicavam as áreas não intelectuais no tear controlado por cartão perfurado ? 0
#    12934 - Qual é o nome dado à máquina que diferenci polinômios por meio de diferenças ? 0
#    12935 - Em quantos segundos o Mark I deveriam multiplicar dois números de dez dígitos ? 0
#    12936 - Quando o curso de Engenharia de Sistemas e Computação da UERJ os a funcionar ? 0
#    12937 - Para que chama a fonte de energia ? 0
#    12938 - Quem publicou as instruções para o computador ? 0
#    12939 - O que a engenharia de computação Fez ? 0
#    12940 - O que a engenharia de computação contratou ? 0
#    12941 - Qual o sistema de dissolução mais conhecido ? 0
#    12942 - O que # UNIVASF ? 0
#    12943 - Quem também apontou a sigla WebE ? 0
#    12944 - Quem também concordou a sigla WebE ? 0
#    12945 - O que reti o computador de outras máquinas ? 0
#    12946 - Como é considerável a memória da CPU ? 0
#    12947 - Como é enterrado a memória da CPU ? 0
#    12948 - Quem são os ícones da era da pop ? 0
#    12949 - Quem são os ícones da era da venda ? 0
#    12950 - Qual era o doce de Gottfried ? 0
#    12951 - Qual linguagens de programação obter as expressões regulares ? 0
#    12952 - Qual linguagens de programação acha as expressões regulares ? 0
#    12953 - As especializações são marcantes ao quê ? 0
#    12954 - A quem é prover a pós-graduação ? 0
#    12955 - Quais os tipos de cursos de livros ? 0
#    12956 - Quais os tipos de cursos de horas ? 0
#    12957 - Qual a principal interface do trabalho autônomo ? 0
#    12958 - Os modelos SM são equivalentes ao quê ? 0
#    12959 - Os modelos contemporâneos são equivalentes ao quê ? 0
#    12960 - Os modelos chineses são equivalentes ao quê ? 0
#    12961 - Os modelos 2009 são equivalentes ao quê ? 0
#    12962 - Quais são os torneios no nível superior ? 0
#    12963 - Junior proporção é equivalente ao que nos EUA ? 0
#    12964 - Quem encerrou os maiores desafios no campo da matemática no século XX ? 0
#    12965 - Quem pôs os maiores desafios no campo da matemática no século XX ? 0
#    12966 - Quem destaca os maiores desafios no campo da matemática no século XX ? 0
#    12967 - Qual era o status de mestrados acadêmicos no Brasil em 2017 ? 0
#    12968 - O mestrado em administração de negócios é relativo o que no Brasil ? 0
#    12969 - O que é ensino do aluno finalizante do curso de mestrado ? 0
#    12970 - Que tipo de trabalho é izado nos cursos de mestrado ? 0
#    12971 - Qual o grau acadêmico relativo para o ingresso na carreira de professor ? 0
#    12972 - Qual o grau acadêmico estudantil para o ingresso na carreira de professor ? 0
#    12973 - Qual o grau acadêmico aluno para o ingresso na carreira de professor ? 0
#    12974 - Quem a coordenação de curso envolvem para elaborar o horário das aulas ? 0
#    12975 - O que o Siscad controla , reforma e divulga ? 0
#    12976 - O que o Siscad controla , divide e divulga ? 0
#    12977 - Qual a carga horária em hora-aula para disciplinas Extra ? 0
#    12978 - Qual a carga horária em hora-aula para disciplinas sempre ? 0
#    12979 - Qual a carga horária em hora-aula para disciplinas distância ? 0
#    12980 - É necessário que a cópia dos documentos comprobatórios seja esta ? 0
#    12981 - É necessário que a cópia dos documentos comprobatórios seja visual ? 0
#    12982 - É necessário que a cópia dos documentos comprobatórios seja fatura ? 0
#    12983 - O que o desenvolvimento cada vez mais rápido de novas tecnologias recomenda ? 0
#    12984 - Quem concorda que o DF passou a ser um novo exemplo de como a sociedade deve valorizar a atividade científica ? 0
#    12985 - Com quem a Facom reduziu parceria para atender à necessidade regional de formação de recursos humanos na área de computação aplicada ? 0
#    12986 - Com quem a Facom possui parceria para atender à necessidade regional de formação de recursos humanos na área de computação agrícola ? 0
#    12987 - Por que aspectos fundamentais do comportamento humano nunca incluíram ser estudados e/ou reproduzidos no ambiente controlado do laboratório ? 0
#    12988 - Por que aspectos fundamentais do comportamento humano nunca necessário ser estudados e/ou reproduzidos no ambiente controlado do laboratório ? 0
#    12989 - O que é necessário para que um indivíduo se qualifique para Portugal a habilitação de professor nos países europeus ? 0
#    12990 - O que a UFPE age numa parceria com o Centro de Informática e o Departamento de Eletrônica e Sistemas ? 0
#    12991 - O que grava SGBDs ? 0
#    12992 - Como a instituição prevê serviço à comunidade ? 0
#    12993 - Como a instituição comunica serviço à comunidade ? 0
#    12994 - O Q é acessível por quais computadores ? 0
#    12995 - O confronto é acessível por quais computadores ? 0
#    12996 - Para que os pensadores oferecem escolas ? 0
#    12997 - Para que os pensadores mantiveram escolas ? 0
#    12998 - Como ficou interna a primeira universidade moderna ? 0
#    12999 - Como seriam conhecida a primeira universidade moderna ? 0
#    13000 - Como cham conhecida a primeira universidade moderna ? 0
#    13001 - Como ficou [ a primeira universidade moderna ? 0
#    13002 - Qual uma aposta entre o ensino médio e faculdade ? 0
#    13003 - Qual uma semelhança entre o senso médio e faculdade ? 0
#    13004 - A quem é clara a invenção do ábaco ? 0
#    13005 - A quem é ` a invenção do ábaco ? 0
#    13006 - Qual foi a primeira ferramenta ideia para a computação ? 0
#    13007 - Qual foi a primeira ferramenta nascente para a computação ? 0
#    13008 - Qual foi a primeira ferramenta funda para a computação ? 0
#    13009 - A expressão máquina computacional se empregada à quê ? 0
#    13010 - O que a área de ciência da computação assumiu ? 0
#    13011 - O que tão CPDs ? 0
#    13012 - O que desenvolve CPDs ? 0
#    13013 - Onde se trabalhava a CBC ? 0
#    13014 - Onde se pesca a CBC ? 0
#    13015 - Onde se falta a CBC ? 0
#    13016 - Onde acaso a primeira universidade moderna ? 0
#    13017 - o que o acadêmico deve comportamento ? 0
#    13018 - o que o acadêmico deve lista ? 0
#    13019 - quais são as doutrinas para o regime de exercícios domiciliares ? 0
#    13020 - Quantas horas de atividade complementar os estudantes de licenciatura dizem realizar ? 0
#    13021 - Quantas horas de atividade complementar os estudantes de licenciatura precisam tenha ? 0
#    13022 - Quantas horas de atividade complementar os estudantes de licenciatura desta realizar ? 0
#    13023 - Quantas horas de atividade complementar os estudantes de licenciatura dois realizar ? 0
#    13024 - Quantas horas de atividade complementar os estudantes de licenciatura precisa realizar ? 0
#    13025 - O que é necessário apresentar para eleger a participação em um evento ? 0
#    13026 - O que é necessário apresentar para reserva a participação em um evento ? 0
#    13027 - O que é necessário apresentar para pedidos a participação em um evento ? 0
#    13028 - Qual o interesse do movimento nas pesquisas descritivas ? 0
#    13029 - Qual um órgão brasileiro que frequente pesquisas descritivas ? 0
#    13030 - Qual um órgão brasileiro que preocupa pesquisas descritivas ? 0
#    13031 - Qual um órgão brasileiro que eficiente pesquisas descritivas ? 0
#    13032 - Qual um órgão brasileiro que falha pesquisas descritivas ? 0
#    13033 - Para que o POSCOMP foi povoado ? 0
#    13034 - Para que o POSCOMP foi libertado ? 0
#    13035 - Para que o POSCOMP foi apelidado ? 0
#    13036 - A quem é desconhecido o título de professor no Estados Unidos ? 0
#    13037 - A quem é ouro o título de professor no Estados Unidos ? 0
#    13038 - Quantas avaliações optativas devem 2012 em cada disciplina ? 0
#    13039 - Quantas avaliações optativas exigem haver em cada disciplina ? 0
#    13040 - Quantas avaliações optativas entram haver em cada disciplina ? 0
#    13041 - Em quais matérias o aluno especial não lucra se matricular ? 0
#    13042 - Quando os alunos especiais podem roubar matrícula em disciplinas isoladas ? 0
#    13043 - Quando os alunos especiais vai fazer matrícula em disciplinas isoladas ? 0
#    13044 - Junior TO é equivalente ao que nos EUA ? 0
#    13045 - O que um professor alega para exercer a profissão ? 0
#    13046 - O que um professor precisa para explicar a profissão ? 0
#    13047 - Onde envolvem ser lançadas as notas e as frequências ? 0
#    13048 - Quem será responsável por concluir a nota do aluno no Siscad ? 0
#    13049 - Quem será responsável por registra a nota do aluno no Siscad ? 0
#    13050 - Como o acadêmico pode Consegu a fotocópia na Secretaria Acadêmica ? 0
#    13051 - Quantas horas pede cada reunião de participação em órgãos colegiados ? 0
#    13052 - Atividades complementares não destas no edital podem ser computadas ? 0
#    13053 - Atividades complementares não previstas no edital podem ser designados ? 0
#    13054 - O que rá ser anexado ao pedido de aproveitamento das atividades complementares ? 0
#    13055 - Em que a engenharia de software se introduz ? 0
#    13056 - O que deve ser acessível ao requerimento ? 0
#    13057 - O que deve ser multa à Secac ? 0
#    13058 - O que é módulo de exercícios domiciliares ? 0
#    13059 - O que é parte de exercícios domiciliares ? 0
#    13060 - O que é pasta de exercícios domiciliares ? 0
#    13061 - O que retornou com a implantação do curso ? 0
#    13062 - Qual a finalidade da orquestra em uma pesquisa ? 0
#    13063 - Qual a finalidade da quantidade em uma pesquisa ? 0
#    13064 - Qual um motivo para fato um curso de gradução ? 0
#    13065 - Qual um motivo para ia um curso de gradução ? 0
#    13066 - Como são apresentada as versões mais modernas do ábaco ? 0
#    13067 - Por quem eram rodada as tabelas logarítmicas ? 0
#    13068 - Como a ciência da computação se mou enquanto ciência ? 0
#    13069 - Quem foi o primeiro a identificar o uso do 0 ? 0
#    13070 - Qual a principal característica dos parentes de hoje em dia ? 0
#    13071 - O que a unidade de controle dar à ULA ? 0
#    13072 - Qual é a página dos cursos de pós-graduação profissionais para a sociedade ? 0
#    13073 - Qual é a certificação dos cursos de pós-graduação profissionais para a sociedade ? 0
#    13074 - Quem concluiu que o Brasil já fale com cursos de doutorado de qualidade suficiente ? 0
#    13075 - Quem time que o Brasil já conta com cursos de doutorado de qualidade suficiente ? 0
#    13076 - Quem concluiu que o Brasil já existe com cursos de doutorado de qualidade suficiente ? 0
#    13077 - O tempo além das 360 horas da especialização é excelente para o quê ? 0
#    13078 - Quais eram as operações que a máquina ferramenta por Wilhelm Schickard era capaz de fazer ? 0
#    13079 - Para quantos anos a máquina de Hollerith põe o tempo de processamento de dados ? 0
#    13080 - Onde a grade do curso de Engenharia da Computação da UFRG tenha ser consultada ? 0
#    13081 - Gestantes como ser ajudadas pelo regime de exercícios a partir de qual mês de gestação ? 0
#    13082 - Quem vinha informar aos professores a relação dos acadêmicos que estiverem em regime de exercícios domiciliares ? 0
#    13083 - Quem reclama informar aos professores a relação dos acadêmicos que estiverem em regime de exercícios domiciliares ? 0
#    13084 - O que leve tornar a tecnologia da informação um risco ? 0
#    13085 - O que pode fixar a tecnologia da informação um risco ? 0
#    13086 - O que pode met a tecnologia da informação um risco ? 0
#    13087 - Por que as aplicações eram quaisquer do zero em 1960 ? 0
#    13088 - Por que as aplicações eram aumentaram do zero em 1960 ? 0
#    13089 - Por quem se escolheu a administração central da UFMS ? 0
#    13090 - Por quem se aproveita a administração central da UFMS ? 0
#    13091 - Por quem se propõe a administração central da UFMS ? 0
#    13092 - O que acontece se o aluno publicar no TCC ? 0
#    13093 - Quantos professores disputaram a banca examinadora ? 0
#    13094 - Quantos professores leu a banca examinadora ? 0
#    13095 - Quanto tempo o aluno passará , o TCC ? 0
#    13096 - Do que os gestores alimentam com tantos recursos disponíveis ? 0
#    13097 - Do que os gestores contribuir com tantos recursos disponíveis ? 0
#    13098 - Em que ano o ENEM alcançando 9,2 milhões de escritos ? 0
#    13099 - Quantas fases o processamento de dados de um sistema de computadores digital são ? 0
#    13100 - Quantas fases o processamento de dados de um sistema de computadores digital prevê ? 0
#    13101 - Quantas fases o processamento de dados de um sistema de computadores digital compree ? 0
#    13102 - Por que grande parte dos eletroeletrônicos são negativos de computação ? 0
#    13103 - Ao que o Tribunal de Mestrado em Engenharia de Computação está associado ? 0
#    13104 - Ao que o Acadêm de Mestrado em Engenharia de Computação está associado ? 0
#    13105 - Onde são marco os prazos para elaboração dos horários das aulas ? 0
#    13106 - Onde são respectivos os prazos para elaboração dos horários das aulas ? 0
#    13107 - Quem a coordenação de curso declarou para elaborar o horário das aulas ? 0
#    13108 - O que o desenvolvimento cada vez mais rápido de novas tecnologias surge ? 0
#    13109 - Em que os sistemas de informação de pressão são de extrema importância ? 0
#    13110 - O que as tecnologias da informação usa além dos componentes de máquina ? 0
#    13111 - O que as tecnologias da informação economia além dos componentes de máquina ? 0
#    13112 - O que as tecnologias da informação mantêm além dos componentes de máquina ? 0
#    13113 - Em que os profissionais formados em cursos de graduação tecnológicos ou superiores de tecnologias são convencionais ? 0
#    13114 - Em que os profissionais eletrônicos em cursos de graduação tecnológicos ou superiores de tecnologias são especializados ? 0
#    13115 - O que ria ser feito para que a carga horária das atividades complementares sejam computadas ? 0
#    13116 - Em que os gestores devem se retornando para as empresas que fornecem os recursos tecnológicos ? 0
#    13117 - Por que países mais métodos em ciência hoje colem bons frutos nessa área ? 0
#    13118 - O que foi buscar no distrito federal em cumprimento a lei número 347 ? 0
#    13119 - O que foi marco no distrito federal em cumprimento a lei número 347 ? 0
#    13120 - O que foi Revolta no distrito federal em cumprimento a lei número 347 ? 0
#    13121 - O que caso com os alunos que não conseguiram vaga na turma pretendida ? 0
#    13122 - O que fazer caso o aluno cai o prazo de seleção de disciplinas online ? 0
#    13123 - O que fazer caso o aluno esse o prazo de seleção de disciplinas online ? 0
#    13124 - O que o discente deve pensava na seleção de disciplinas on-line ? 0
#    13125 - Quando o período de posicionamento do discente é interino pelo coordenador de curso ? 0
#    13126 - Quando o período de posicionamento do discente é incluída pelo coordenador de curso ? 0
#    13127 - Quando é matemático o cálculo do período de posicionamento do discente no curso ? 0
#    13128 - O que ameaça caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    13129 - A hora-aula deve ser de quantos minutos caso o histórico escolar não a revela explicitamente ? 0
#    13130 - A hora-aula deve ser de quantos minutos caso o histórico escolar não a evo explicitamente ? 0
#    13131 - A hora-aula deve especial de quantos minutos caso o histórico escolar não a indicar explicitamente ? 0
#    13132 - A hora-aula deve igualmente de quantos minutos caso o histórico escolar não a indicar explicitamente ? 0
#    13133 - A hora-aula deve voltar de quantos minutos caso o histórico escolar não a indicar explicitamente ? 0
#    13134 - Qual quesito da gestão da tecnologia da informação não surgiu o mesmo ritmo das políticas de segurança ? 0
#    13135 - Qual quesito da gestão da tecnologia da informação não inclui o mesmo ritmo das políticas de segurança ? 0
#    13136 - Quantos membros e no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008 ? 0
#    13137 - Quantos membros significativos no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008 ? 0
#    13138 - Quantos membros homossexuais no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008 ? 0
#    13139 - Por que aspectos fundamentais do comportamento humano nunca devem ser estudados e/ou destacado no ambiente controlado do laboratório ? 0
#    13140 - Com o que será vital a carga horária se for constatada a falta para integralização curricular ? 0
#    13141 - como é institucional a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas ? 0
#    13142 - como é deixada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas ? 0
#    13143 - o que acontece com o acadêmico com vínculo var em caso de não renovação de sua matrícula no semestre seguinte ? 0
#    13144 - O que quer escrever quando um professor opta por avaliar a sua matéria através de seminários ao invés de provas ? 0
#    13145 - Em que ano a comunidade científica do distrito federal brasileira a criação de uma instituição dedicada ao incentivo da ciência e tecnologia ? 0
#    13146 - Qual foi uma das primeiras escolas superiores militantes do Brasil ? 0
#    13147 - O que as universidades públicas lançaram em comum nos EUA ? 0
#    13148 - onde instruções constar o conteúdo a ser avaliado ? 0
#    13149 - quem esta a proposta para projeto pedagógico de curso ? 0
#    13150 - onde é ilegal a matrícula em disciplinas obrigatórias ? 0
#    13151 - onde é melhor a matrícula em disciplinas obrigatórias ? 0
#    13152 - onde é alta a matrícula em disciplinas obrigatórias ? 0
#    13153 - Em quais áreas as universidades públicas mesmo autonomia ? 0
#    13154 - Em quais áreas as universidades públicas entidades autonomia ? 0
#    13155 - Quais matérias Al-Azhar guarda ? 0
#    13156 - Onde escreveu o desenvolvimento da primeira universidade árabe ? 0
#    13157 - quais os possíveis de constituição do nde ? 0
#    13158 - quais os critérios de ranking do nde ? 0
#    13159 - quais os critérios de deposição do nde ? 0
#    13160 - Quem deverá informar aos professores a relação dos acadêmicos que estabeleceu em regime de exercícios domiciliares ? 0
#    13161 - O que o acadêmico dita fazer em casos de atividades práticas em regime de exercícios domiciliares ? 0
#    13162 - O que o acadêmico ente fazer em casos de atividades práticas em regime de exercícios domiciliares ? 0
#    13163 - O que o acadêmico declarar fazer em casos de atividades práticas em regime de exercícios domiciliares ? 0
#    13164 - Quem irá definir as atividades que Vai ser cumpridas durante o regime de exercícios domiciliares ? 0
#    13165 - O processo seletivo do programa de monitoria da resolução nº 342 confirmou qual finalidade ? 0
#    13166 - Quanto é o montante do edital nº 163 para seleção de disciplinas que promover monitores ? 0
#    13167 - Quanto é o montante do edital nº 163 para seleção de disciplinas que categorias monitores ? 0
#    13168 - O que acontece caso o acadêmico não ataque a matrícula e estiver impedido de trancar ? 0
#    13169 - Por que a ciência da computação é típica ? 0
#    13170 - Por que a ciência da computação é poderosa ? 0
#    13171 - Em que é definido o nome de Turing ? 0
#    13172 - Onde é ira parte da memória do computador ? 0
#    13173 - Onde é levado parte da memória do computador ? 0
#    13174 - Onde é sempre parte da memória do computador ? 0
#    13175 - Qual era o cor de Gottfried ? 0
#    13176 - Por onde a pesquisa de campo se reserva ? 0
#    13177 - Por onde a pesquisa de campo se apresentou ? 0
#    13178 - Quais as exigências da pesquisa de público ? 0
#    13179 - Quais as complementares da pesquisa de campo ? 0
#    13180 - Qual a definição de pesquisa como lugar regular ? 0
#    13181 - Qual a contribuição de pesquisa como atividade regular ? 0
#    13182 - Onde o POSCOMP é previsto ? 0
#    13183 - Onde o POSCOMP é lixo ? 0
#    13184 - Junior categoria é equivalente ao que nos EUA ? 0
#    13185 - Junior Iraque é equivalente ao que nos EUA ? 0
#    13186 - Junior cidade é equivalente ao que nos EUA ? 0
#    13187 - Qual a maior câmara sindical docente de Portugal ? 0
#    13188 - Qual a maior dirigentes sindical docente de Portugal ? 0
#    13189 - Qual a principal aproximação dos professores nos EUA ? 0
#    13190 - Qual a principal ideologia dos professores nos EUA ? 0
#    13191 - Qual professores terminou uma cátedra pessoal ? 0
#    13192 - Que tipo de trabalho é claro nos cursos de mestrado ? 0
#    13193 - Que tipo de trabalho é bem nos cursos de mestrado ? 0
#    13194 - Que tipo de trabalho é autorizado nos cursos de mestrado ? 0
#    13195 - Ao que são receptores os cursos lato sensu ? 0
#    13196 - Ao que são propriamente os cursos lato sensu ? 0
#    13197 - Ao que são selecionados os cursos lato sensu ? 0
#    13198 - Pelo que é responsável o tanto da educação em Portugal ? 0
#    13199 - Lecturers nomes equivalentes ao que nos EUA ? 0
#    13200 - Quantas avaliações obrigatórias devem trabalhar em cada disciplina ? 0
#    13201 - O que o concluinte de cursos tecnológicos desistiu ? 0
#    13202 - O que os cursos tecnológicos dividem ao diplomado ? 0
#    13203 - O que os cursos tecnológicos direc ao diplomado ? 0
#    13204 - A quem o coordenador de curso deve secreta se necessário ? 0
#    13205 - A quem o coordenador de curso deve escapar se necessário ? 0
#    13206 - Em qual semestre o acadêmico deve ser ouvidos de preferência ? 0
#    13207 - O que gravou o semestre de enquadramento do aluno ? 0
#    13208 - O que qual o semestre de enquadramento do aluno ? 0
#    13209 - Quais os possíveis resultados finais para as eleições complementares ? 0
#    13210 - Quais os possíveis resultados finais para as idades complementares ? 0
#    13211 - O que são dispositivos de entrada e diretamente ? 0
#    13212 - O que são dispositivos de entrada e usados ? 0
#    13213 - Por quem as instruções escritas podem ser textos ? 0
#    13214 - Por quem as instruções escritas fo ser utilizadas ? 0
#    13215 - Quantas instruções dos programas de computador perguntou ? 0
#    13216 - Quantas instruções dos programas de computador figura ? 0
#    13217 - Quantas instruções dos programas de computador trouxe ? 0
#    13218 - Qual a finalidade da palestra em uma pesquisa ? 0
#    13219 - Para que a engenharia de software nessas técnicas de otimização matemática ? 0
#    13220 - Quantas horas semanais são abertos para estudantes do ensino superior ? 0
#    13221 - houver quantas vagas anualmente para cursos de graduação na Facom ? 0
#    13222 - Quais eram as ências do Ministério da Educação e Saúde ? 0
#    13223 - Como foi promovido as bolsas para cada unidade de administração setorial ? 0
#    13224 - Como foi atribuído as bolsas para cada unidade de administração setorial ? 0
#    13225 - Onde utiliza ser feita a matrícula em disciplinas optativas ? 0
#    13226 - Quantos membros liderou no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008 ? 0
#    13227 - Quantos membros continuam no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008 ? 0
#    13228 - Em que ano a comunidade científica do distrito federal iniciou a criação de uma instituição capaz ao incentivo da ciência e tecnologia ? 0
#    13229 - Em que ano a comunidade científica do distrito federal celebr a criação de uma instituição dedicada ao incentivo da ciência e tecnologia ? 0
#    13230 - O que a UFPE trocou numa parceria com o Centro de Informática e o Departamento de Eletrônica e Sistemas ? 0
#    13231 - Qual a base da análise e interpretação dos dados coletados a acontecer da observação de fatos e fenômenos exatamente como ocorem realmente ? 0
#    13232 - O que acontece caso o Aluno Especial não publicar o aproveitamento das duas disciplinas cursadas até a data de matrícula ? 0
#    13233 - Qual um judeu indispensável nas organizações ? 0
#    13234 - Qual a principal entrada das atividades complementares ? 0
#    13235 - Com o que as atividades complementares empregados ? 0
#    13236 - Com o que as atividades complementares termina ? 0
#    13237 - Com o que as atividades complementares estão ? 0
#    13238 - Com o que as atividades complementares sugerem ? 0
#    13239 - Do que se enfrentaram as atividades complementares ? 0
#    13240 - O que consideram a era da informação ? 0
#    13241 - O que os cientistas da computação escreve ? 0
#    13242 - O que os cientistas da computação estuda ? 0
#    13243 - O que i Secac ? 0
#    13244 - O que é a viagem ? 0
#    13245 - O que é a qual ? 0
#    13246 - O que é a atenção ? 0
#    13247 - Qual a finalidade da arte ? 0
#    13248 - Qual a finalidade da aeronave ? 0
#    13249 - O que a Amazônia visa ? 0
#    13250 - O que a Luz visa ? 0
#    13251 - O que é a pena ? 0
#    13252 - O que é a escalada ? 0
#    13253 - O que é a alma ? 0
#    13254 - O que promete R & D ? 0
#    13255 - Ao que os candidatos fazem acesso ? 0
#    13256 - Ao que os candidatos tê acesso ? 0
#    13257 - Ao que o mestrado é particularmente ? 0
#    13258 - Ao que o mestrado é dependência ? 0
#    13259 - Quais são os competências educacionais ? 0
#    13260 - Quais são os terroristas educacionais ? 0
#    13261 - Qual o desfile mínimo de alunos para uma turma de período letivo especial ? 0
#    13262 - Qual o valores mínimo de alunos para uma turma de período letivo especial ? 0
#    13263 - Como é traduzida a carga horária de participação em órgãos colegiados ? 0
#    13264 - Atividades complementares não previstas no edital contemp ser computadas ? 0
#    13265 - O que é processamento de programação ? 0
#    13266 - O que é arte da computação ? 0
#    13267 - O que é ciência da torcida ? 0
#    13268 - O que é pesquisador da computação ? 0
#    13269 - Quando o computador foi originalmente Pro ? 0
#    13270 - Quando o computador foi originalmente especial ? 0
#    13271 - Onde geralmente encerrar a próxima instrução ? 0
#    13272 - Quem foi responsável pela difusão do cristianismo de numeração hindu-arábico no Oriente Médio ? 0
#    13273 - Quem foi responsável pela introduziu do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    13274 - Quais eram as operações que a máquina construída por Wilhelm Schickard era capaz de simplicidade ? 0
#    13275 - Quais eram as operações que a máquina construída por Wilhelm Schickard era capaz de suporte ? 0
#    13276 - Quem irá assinar as atividades que deverão ser cumpridas durante o regime de exercícios domiciliares ? 0
#    13277 - A FAPDF preserva finalidade de estimular , apoiar e promover o desenvolvimento científico de qual âmbito ? 0
#    13278 - Em que ano foi encontrar o Ministério da Instrução Pública , Correios e Telégrafos ? 0
#    13279 - Em que ano foi incluídos o Ministério da Instrução Pública , Correios e Telégrafos ? 0
#    13280 - O que Serra UFRG ? 0
#    13281 - Pelo que o MIT sei ? 0
#    13282 - Pelo que o MIT provou ? 0
#    13283 - Pelo que o MIT gerou ? 0
#    13284 - O que afirma WebApps ? 0
#    13285 - O que fonte WebApps ? 0
#    13286 - Quem também utiliza a sigla 51 ? 0
#    13287 - Quem também utiliza a sigla 2000 ? 0
#    13288 - Onde o estágio pode ser participar ? 0
#    13289 - Onde o estágio pode ser brilhante ? 0
#    13290 - Qual a arquitetura geralmente indicado no desenvolvimento de WebApps ? 0
#    13291 - Qual a arquitetura geralmente encontrados no desenvolvimento de WebApps ? 0
#    13292 - O que as tecnologias e práticas da engenharia de software independentes ? 0
#    13293 - O que as tecnologias e práticas da engenharia de software diferem ? 0
#    13294 - O que as tecnologias e práticas da engenharia de software aspira ? 0
#    13295 - O que as tecnologias e práticas da engenharia de software humana ? 0
#    13296 - Quais os conceitos dita pelo significado de engenharia de software ? 0
#    13297 - Quais os conceitos trabalham pelo significado de engenharia de software ? 0
#    13298 - Quando foi utilizado o primeiro edital da FAPDF ? 0
#    13299 - Quando foi apresentar o primeiro edital da FAPDF ? 0
#    13300 - Quem declarou o curso de Engenharia de Computação da UNIVASF ? 0
#    13301 - Como o curso de engenharia de sistemas e computação passará a se provar ? 0
#    13302 - Como o curso de engenharia de sistemas e computação passará a se organizou ? 0
#    13303 - Como o curso de engenharia de sistemas e computação passará a se função ? 0
#    13304 - Quantas modalidades do curso de Ciência da Computação a UFSC toma ? 0
#    13305 - Quantas modalidades do curso de Ciência da Computação a UFSC visita ? 0
#    13306 - Em que o tratamento de engenharia caracteriza o desenvolvimento de sistemas de software complexos ? 0
#    13307 - Qual o objetivo do monumento ? 0
#    13308 - Qual o objetivo do eixo ? 0
#    13309 - Qual o ritual do estágio ? 0
#    13310 - O que a pesquisa estabelece ? 0
#    13311 - O que a pesquisa estatística ? 0
#    13312 - O que é um candidato ? 0
#    13313 - Qual a finalidade do censo ? 0
#    13314 - Qual a saúde do mestrado ? 0
#    13315 - Qual a finalidade do estádio ? 0
#    13316 - O que é a letra lógica e aritmética ? 0
#    13317 - O que é a preocupação lógica e aritmética ? 0
#    13318 - Quais são os desenvolvimento da ULA ? 0
#    13319 - O que são dispositivos de ligações e saída ? 0
#    13320 - O que são momentos de entrada e saída ? 0
#    13321 - A pesquisa básica declarar oposição ao quê ? 0
#    13322 - A pesquisa básica ) oposição ao quê ? 0
#    13323 - Com o que pesquisa laboratorial é identificado ? 0
#    13324 - Com o que pesquisa laboratorial é literatura ? 0
#    13325 - Com o que pesquisa laboratorial é envolvimento ? 0
#    13326 - Por que o Z1 foi importante pelo governo alemão ? 0
#    13327 - Por que o Z1 foi errado pelo governo alemão ? 0
#    13328 - Por que o Z1 foi destaque pelo governo alemão ? 0
#    13329 - Por que o Z1 foi senador pelo governo alemão ? 0
#    13330 - Em que a máquina de Hollerith demonstrou pioneira ? 0
#    13331 - Em que a máquina de Hollerith consideram pioneira ? 0
#    13332 - Em que a máquina de Hollerith foca pioneira ? 0
#    13333 - Em que a máquina de Hollerith foi Pensa ? 0
#    13334 - Onde deverão ser dos os sistemas de software complexo ? 0
#    13335 - Quantos projetos foram dois no primeiro edital da FAPDF ? 0
#    13336 - Por que países mais avançados em ciência hoje na bons frutos nessa área ? 0
#    13337 - Por que países mais avançados em ciência hoje na bons frutos nessa área ? 0
#    13338 - Quando foi defendida o curso de Ciência da Computação na UFMS ? 0
#    13339 - O que acontece com os alunos que não conseguiram vaga na turma essencial ? 0
#    13340 - Quais disciplinas o acadêmico aposta preencher no formulário eletrônico ? 0
#    13341 - O que acompanha caso o aluno se ausente da renovação de matrícula ? 0
#    13342 - O que mudar caso o aluno se ausente da renovação de matrícula ? 0
#    13343 - O que acontece caso o aluno se apoia da renovação de matrícula ? 0
#    13344 - como convencer a componente curricular não disciplinar no siscad ? 0
#    13345 - como falou a componente curricular não disciplinar no siscad ? 0
#    13346 - como percebeu a componente curricular não disciplinar no siscad ? 0
#    13347 - como o aluno informou solicitar a revisão de sua frequência em uma disciplina ? 0
#    13348 - Por quem foi tido a profissão de tecnólogo em análise e desenvolvimento de sistemas ? 0
#    13349 - O que quer ncia Total de Alunos Equivalentes da Graduação ? 0
#    13350 - O que acontece com os alunos que não raram vaga na turma pretendida ? 0
#    13351 - Qual a carga horária para publicação de mandatos ? 0
#    13352 - Como deve ser local a monitoria de ensino ? 0
#    13353 - Quem acredita a declaração de realização de monitoria ? 0
#    13354 - Quem conduz a declaração de realização de monitoria ? 0
#    13355 - Em qual plataforma as atividades complementares podem ser feitas ? 0
#    13356 - Quais algas estão inclusas nas atividades complementares ? 0
#    13357 - O que o tema do TCC deve 2 ? 0
#    13358 - a aprovação nas disciplinas ficou do que ? 0
#    13359 - a aprovação nas disciplinas aquelas do que ? 0
#    13360 - Quais alguns exemplos de vida de extensão ? 0
#    13361 - Quais alguns exemplos de programação de extensão ? 0
#    13362 - Quais alguns exemplos de atividades de agência ? 0
#    13363 - Em que as atividades complementares fizeram o aluno ? 0
#    13364 - Em que as atividades complementares realiza o aluno ? 0
#    13365 - O ensino superior é professor por quais cursos ? 0
#    13366 - Qual o prazo para a recontagem de familiares ? 0
#    13367 - Por quanto tempo a matrícula pode ser post ? 0
#    13368 - Quando os professores passaria lançar no Siscad ? 0
#    13369 - Quando os professores podem presença no Siscad ? 0
#    13370 - Para que o dia letivo tudo ser considerado ? 0
#    13371 - Para que o dia letivo tende ser considerado ? 0
#    13372 - Para que o dia letivo visita ser considerado ? 0
#    13373 - Qual a duração de um junho letivo especial ? 0
#    13374 - O que o curso de Engenharia da Computação da UFRG tomou ? 0
#    13375 - O que o curso de Engenharia da Computação da UFRG tema ? 0
#    13376 - Quando exigia transmutação da espécie para a de vínculo empregatício ? 0
#    13377 - Quando máxima transmutação da espécie para a de vínculo empregatício ? 0
#    13378 - Ao que deve ser dependência a solicitação do regime de exercícios domiciliares ? 0
#    13379 - Por que países mais avançados em ciência hoje omem bons frutos nessa área ? 0
#    13380 - Onde os cursos quentes como MBA são equiparáveis aos mestrados ? 0
# ...
#    17528 - Quais tipos de eventos científicos podem ser complementar para integralização da carga horária das atividades complementares ? 0
#    17529 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a Seleção do Índice Geral de Cursos ? 0
#    17530 - Qual a segunda melhor experiência de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos ? 0
#    17531 - A partir de qual momento o tempo professor será contabilizado ? 0
#    17532 - Como o aluno optou adquirir conhecimento sem o acompanhamento de um professor ? 0
#    17533 - Como o aluno deles adquirir conhecimento sem o acompanhamento de um professor ? 0
#    17534 - Qual o termo web para definir sequências de passos para completar uma tarefa ? 0
#    17535 - Por que é necessário que um professor satisfa qualificações acadêmicas e pedagógicas ? 0
#    17536 - A quem a coordenação de curso referência solicitar o oferecimento das turmas ? 0
#    17537 - A quem deve ser solicitado o aproveitamento das disciplinas governamentais em outro curso de graduação ? 0
#    17538 - Em quais casos o acadêmico pode considerada a matrícula nos dois primeiros períodos letivos ? 0
#    17539 - o que conseguem conter o plano de estudos ? 0
#    17540 - por quem será destacado o plano de estudos ? 0
#    17541 - por quem será roubado o plano de estudos ? 0
#    17542 - tens lei sobre a transferência compulsória ? 0
#    17543 - Onde são utilizadas as informações rituais sobre uma empresa ? 0
#    17544 - Onde são utilizadas as informações correndo sobre uma empresa ? 0
#    17545 - Onde os profissionais em sistemas de informação vis atuar ? 0
#    17546 - Em qual decreto foi erguido o ministério da educação ? 0
#    17547 - O que as inúmeras regras da monografia buscam ? 0
#    17548 - Do que retirar a validação de matrículas ? 0
#    17549 - A quais fases da pesquisa bibliográfica mantém suporte ? 0
#    17550 - A quais fases da pesquisa bibliográfica colabora suporte ? 0
#    17551 - A quais fases da pesquisa bibliográfica ajudam suporte ? 0
#    17552 - Para que a Ciência viola a pesquisa de campo ? 0
#    17553 - Para que a Ciência criou a pesquisa de campo ? 0
#    17554 - Como Zuse viver o Z1 ? 0
#    17555 - Em que foi lançado o Mark I ? 0
#    17556 - Em que foi passado o Mark I ? 0
#    17557 - O que a engenharia de computação herdou ? 0
#    17558 - O que a engenharia de computação caça ? 0
#    17559 - O que a engenharia de computação sentiu ? 0
#    17560 - O que a engenharia de computação descobriram ? 0
#    17561 - Qual o instituto de computação mais conhecido ? 0
#    17562 - Qual o sistema de salvação mais conhecido ? 0
#    17563 - O que nomeou UNIVASF ? 0
#    17564 - Qual o conhecimento de um crédito na maioria das universidades ? 0
#    17565 - Qual o valor de um crédito na maioria das ponta ? 0
#    17566 - Onde a primeira turma de engenheiros de computação se instalado ? 0
#    17567 - Quando se encerrou a primeira turma de engenheiros de computação ? 0
#    17568 - Quando se jogou a primeira turma de engenheiros de computação ? 0
#    17569 - Onde deverão ser resultados os sistemas de software complexo ? 0
#    17570 - Quais os tipos de prova da pesquisa de campo ? 0
#    17571 - Por quantos docentes deve ser presidido a comissão ? 0
#    17572 - Em qual decreto foi implantação o ministério da educação ? 0
#    17573 - Para que a Ciência tão a pesquisa de campo ? 0
#    17574 - O que é indispensável para ferramentas laboratoriais ? 0
#    17575 - O que é indispensável para universidades laboratoriais ? 0
#    17576 - O que é indispensável para jardins laboratoriais ? 0
#    17577 - O que é indispensável para conferência laboratoriais ? 0
#    17578 - Quem recusa a declaração de realização de monitoria ? 0
#    17579 - O que o trabalho de conclusão de curso retira ? 0
#    17580 - Quem é responsável por há e desenvolver novas tecnologias ? 0
#    17581 - Os cursos de pós-graduação normalmente quais cursos ? 0
#    17582 - O Pergamum é acessível por quais alianças ? 0
#    17583 - quais são as profundidade acadêmicas do nde ? 0
#    17584 - Ao que as cotas do estágio devem ser estendendo ? 0
#    17585 - Ao que as cotas do estágio passa ser destinadas ? 0
#    17586 - Professor voluntário Rede requerer monitor para sua disciplina ? 0
#    17587 - Quantas bolsas serão descritas para o edital nº 163 ? 0
#    17588 - Qual tipo de estudo é geralmente consistente em uma monografia ? 0
#    17589 - Qual tipo de estudo é geralmente evidente em uma monografia ? 0
#    17590 - O que o Siscad controla , acompanha e induz ? 0
#    17591 - O que o Siscad controla , acompanha e forma ? 0
#    17592 - O que o Siscad controla , acompanha e aponta ? 0
#    17593 - O coordenador de curso deve Or o plano de estudos após a análise de quê ? 0
#    17594 - Ao que as cotas do estágio devem ser observar ? 0
#    17595 - Em quais áreas a TI é uma grande investir ? 0
#    17596 - O que visita as bibliotecas e os centros de documentação ? 0
#    17597 - O que nem sempre são pequenos na área de análise ? 0
#    17598 - Quem observar o contrato do estágio ? 0
#    17599 - Onde é Aqui a UFMS ? 0
#    17600 - Como é testar a memória do computador ? 0
#    17601 - Quais números um byte representam ? 0
#    17602 - Para que render os sistemas embarcados ? 0
#    17603 - Para que permanecem os sistemas embarcados ? 0
#    17604 - Como são altas as instruções no computador ? 0
#    17605 - quais incisos os acadêmicos sempre cumprir ? 0
#    17606 - quais são as fases da renovação de espaço ? 0
#    17607 - quais os significados de constituição do nde ? 0
#    17608 - como deve ser escritos o projeto pedagógico ? 0
#    17609 - como ara ser elaborado o projeto pedagógico ? 0
#    17610 - o que é tabu de exercícios domiciliares ? 0
#    17611 - quantas vezes posso multa aproveitamento de estudos ? 0
#    17612 - quantas vezes posso haverá aproveitamento de estudos ? 0
#    17613 - quantas vezes posso libertar aproveitamento de estudos ? 0
#    17614 - O calendário acadêmico é selecionado por quem ? 0
#    17615 - Como ficou científica a primeira universidade moderna ? 0
#    17616 - Como ficou basicamente a primeira universidade moderna ? 0
#    17617 - O ensino superior é total por quais cursos ? 0
#    17618 - O ensino superior é ocupando por quais cursos ? 0
#    17619 - O ensino superior é vindo por quais cursos ? 0
#    17620 - Onde é ¿ parte da memória do computador ? 0
#    17621 - O que há o computador de outras máquinas ? 0
#    17622 - O que tira o computador de outras máquinas ? 0
#    17623 - Qual a finalidade da navegação empírica ? 0
#    17624 - Quem são os ícones da venda da informação ? 0
#    17625 - Quais as exigências da pesquisa de Prince ? 0
#    17626 - Qual a definição de pesquisa como regularmente regular ? 0
#    17627 - Qual a menção de pesquisa como atividade regular ? 0
#    17628 - Onde o POSCOMP é visível ? 0
#    17629 - O que varia ser feito para que a carga horária das atividades complementares sejam computadas ? 0
#    17630 - O que a transformação das telecomunicações em uma base tecnológica incluía as empresas a fazerem ? 0
#    17631 - quem é responsável pela reputação de atitudes inadequadas de alunos e aplicação de medidas corretivas ? 0
#    17632 - quem é responsável pela procura de atitudes inadequadas de alunos e aplicação de medidas corretivas ? 0
#    17633 - A hora-aula deve invés de quantos minutos caso o histórico escolar não a indicar explicitamente ? 0
#    17634 - Pelo que passam os membros do corpo docente antes de serem que Maître de conférences ? 0
#    17635 - Qual o prazo mínimo para a divulgação das notas de todas as avaliações que fixa a média de aproveitamento ? 0
#    17636 - Qual o prazo mínimo para a divulgação das notas de todas as avaliações que incluiu a média de aproveitamento ? 0
#    17637 - Qual o prazo mínimo para a divulgação das notas de todas as avaliações que estabelecer a média de aproveitamento ? 0
#    17638 - Qual o prazo mínimo para a divulgação das notas de todas as avaliações que medida a média de aproveitamento ? 0
#    17639 - O que o professor deve ceder ao acadêmico ? 0
#    17640 - Qual a pilha horária das atividades complementares ? 0
#    17641 - Qual a campanha horária das atividades complementares ? 0
#    17642 - Qual a designação horária das atividades complementares ? 0
#    17643 - Como o TCC é básico em instituições ? 0
#    17644 - quais incisos os acadêmicos deve investigar ? 0
#    17645 - o que deverá nela o plano de estudos ? 0
#    17646 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a Confederação do Índice Geral de Cursos ? 0
#    17647 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a vinda do Índice Geral de Cursos ? 0
#    17648 - Qual a segunda melhor universidade de Mato Grosso do Sul segundo a audiência do Índice Geral de Cursos ? 0
#    17649 - Qual a segunda melhor FI de Mato Grosso do Sul segundo a avaliação do Índice Geral de Cursos ? 0
#    17650 - qual o limite de dias para o acadêmico que requisitou abreviação de curso ser ause do conteúdo ? 0
#    17651 - qual o limite de dias para o acadêmico que requisitou abreviação de curso ser manutenção do conteúdo ? 0
#    17652 - O que é um contexto ? 0
#    17653 - O que é um pacto ? 0
#    17654 - Quem estabeleceu o contrato do estágio ? 0
#    17655 - O que verifica os setores do computador ? 0
#    17656 - Quantas sessões principais o computador ganhou ? 0
#    17657 - Como Zuse em o Z1 ? 0
#    17658 - O que senão UNIVASF ? 0
#    17659 - Onde o professor irá dormir as provas ? 0
#    17660 - O que a pesquisa preparou ? 0
#    17661 - O que a pesquisa varia ? 0
#    17662 - O que é um negócio ? 0
#    17663 - Onde o professor irá colaborar as provas ? 0
#    17664 - Onde será derivado o Laudo Médico ? 0
#    17665 - Quando a FAPDF foi tal ? 0
#    17666 - O que a FAPDF Representa ? 0
#    17667 - Qual a discriminação da FAPDF ? 0
#    17668 - Como é complementar a lei 11.788/2008 ? 0
#    17669 - O coordenador de curso deve dá o plano de estudos após a análise de quê ? 0
#    17670 - O que deve ser feito para que a carga horária das atividades complementares sejam organizados ? 0
#    17671 - Ao que os impasses e problemas dominantes pela difusão das novas tecnologias estão relacionados ? 0
#    17672 - Ao que os impasses e problemas retratado pela difusão das novas tecnologias estão relacionados ? 0
#    17673 - Ao que os impasses e problemas fundadores pela difusão das novas tecnologias estão relacionados ? 0
#    17674 - qual a nota mínima para o acadêmico que requisitou abreviação de curso ser reserva ? 0
#    17675 - em quantas discplinas o acadêmico poderá agenda durante o período letivo especial ? 0
#    17676 - O que é a evolução ? 0
#    17677 - O que a pesquisa apoia ? 0
#    17678 - O que entre a Redecomep ? 0
#    17679 - O que pensou a Redecomep ? 0
#    17680 - Onde é descrita a inscrição das disciplinas ? 0
#    17681 - Onde é registrar a inscrição das disciplinas ? 0
#    17682 - Qual o principal tipo de câncer científico ? 0
#    17683 - Qual a finalidade da escola empírica ? 0
#    17684 - Para quem é leva o resultado do exame ? 0
#    17685 - Quando o professor deve for as provas aos alunos ? 0
#    17686 - Onde os acadêmicos devem retirar e contribuir as atividades ? 0
#    17687 - Qual a ênfase do mestrado profissional em computação leve ? 0
#    17688 - Para que o POSCOMP foi restrito ? 0
#    17689 - Ao que os candidatos envolvem acesso além do resultado ? 0
#    17690 - O que nem sempre são pequenos na incorporação de tecnologia ? 0
#    17691 - Com quantos alunos a universidade de Nalanda segura ? 0
#    17692 - O que o compartilhamento de tempo da CPU tirou ? 0
#    17693 - Os modelos USA são equivalentes ao quê ? 0
#    17694 - Quais são os jogos no nível superior ? 0
#    17695 - Quais são os veteranos no nível superior ? 0
#    17696 - Junior corrida é equivalente ao que nos EUA ? 0
#    17697 - Junior total é equivalente ao que nos EUA ? 0
#    17698 - Qual professores pergunta uma cátedra pessoal ? 0
#    17699 - Por que a contratação de estágio tem realizado críticas ? 0
#    17700 - Por que a contratação de estágio tem críticas críticas ? 0
#    17701 - Por que a contratação de estágio tem possíveis críticas ? 0
#    17702 - Quando Turing parece suicídio ? 0
#    17703 - À que Turing obrigada ? 0
#    17704 - À que Turing respostas ? 0
#    17705 - À que Turing acima ? 0
#    17706 - O que é consciência ? 0
#    17707 - Quem revista o cálculo ? 0
#    17708 - O que é a corrupção ? 0
#    17709 - Para quem é impresso o resultado do exame ? 0
#    17710 - Qual a principal característica do residente autônomo ? 0
#    17711 - Em quais casos o acadêmico obriga trancar a matrícula nos dois primeiros períodos letivos ? 0
#    17712 - Quando o acadêmico em regime de exercícios domiciliares poderá prestar as provas que foram acompanhando durante o afastamento ? 0
#    17713 - Como o Ministério da Educação e Saúde promoveu a se chamar depois que o governo federal criou o Ministério da Saúde ? 0
#    17714 - Quem noticiou que o DF passou a ser um novo exemplo de como a sociedade denuncia valorizar a atividade científica ? 0
#    17715 - O trancamento de matrícula essa ser feito caso o regime de exercícios domicilares for superior a quantos semestres ? 0
#    17716 - O trancamento de matrícula deve ser definido caso o regime de exercícios domicilares for superior a quantos semestres ? 0
#    17717 - Qual é o nome criado à máquina que calcula polinômios por meio de diferenças ? 0
#    17718 - Em quantos segundos o Mark I ie multiplicar dois números de dez dígitos ? 0
#    17719 - Para quantos anos a máquina de Hollerith conter o tempo de processamento de dados ? 0
#    17720 - Para quantos anos a máquina de Hollerith informou o tempo de processamento de dados ? 0
#    17721 - Onde a grade do curso de Engenharia da Computação da UFRG pode ser Encont ? 0
#    17722 - Após quantos anos de estágio o estagiário tem direito a recesso portanto ? 0
#    17723 - O que acontece caso o candidato não retorn no prazo estabelecido em edital para matrícula ? 0
#    17724 - Em quais casos o acadêmico obrigação trancar a matrícula nos dois primeiros períodos letivos ? 0
#    17725 - Qual o problema de Hilbert que fez os matemáticos se familiar tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo ? 0
#    17726 - Qual o problema de Hilbert que fez os matemáticos se quem tentanto descobrir quais problemas matemáticos poderiam ser resolvidos por um método efetivo ? 0
#    17727 - Quando Turing nesse suicídio ? 0
#    17728 - Qual a principal derrota do trabalho autônomo ? 0
#    17729 - Os modelos amadores são equivalentes ao quê ? 0
#    17730 - O que acorda ser anexado ao requerimento ? 0
#    17731 - O que roda ser anexado ao requerimento ? 0
#    17732 - O que ? ser anexado ao requerimento ? 0
#    17733 - O que o compartilhamento de tempo da CPU verifica ? 0
#    17734 - Qual a universidade pioneira no brasil em especialidade de software ? 0
#    17735 - Por que o estágio é a mais executada forma dentre as opções de atividade complementar de extensão ? 0
#    17736 - Quantas regras Pānini gravou para formular a gramática de Sânscrito ? 0
#    17737 - O que indicavam as áreas não furadas no tear falso por cartão perfurado ? 0
#    17738 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto descobrir quais problemas matemáticos significativas ser resolvidos por um método efetivo ? 0
#    17739 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto ensinar quais problemas matemáticos poderiam ser resolvidos por um método efetivo ? 0
#    17740 - Quantos dias no mínimo os lançamentos do período letivo especial no Siscad devem trazer a data de matrícula do período letivo regular subsequente ? 0
#    17741 - Quantos dias no mínimo os lançamentos do período letivo especial no Siscad devem receberam a data de matrícula do período letivo regular subsequente ? 0
#    17742 - Em qual semestre o acadêmico deve ser enquadrado no caso de existir pré-requisitos que o efeito de se matricular no semestre mais próximo ao inicial em que apresentar maior carga horária de disciplinas a serem cursadas ? 0

# %% [markdown]
# #### Lista Documentos Perturbados(0-incoerente) Classificados incorretamente(1-coerente)

# %%
def listaPerturbadoClassificadoIncorretamente(dfDadosClassificacao):
  listaRetorno = []  
  for i, linha in dfDadosClassificacao.iterrows():
    if linha['classe'] == 0 and linha['predicao'] == 1:
        listaRetorno.append(linha['id'])
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaDocumentoPerturbadoClassificadoIncorretamente = listaPerturbadoClassificadoIncorretamente(dfDadosClassificacao)
print('listaDocumentoPerturbadoClassificadoIncorretamente:', len(listaDocumentoPerturbadoClassificadoIncorretamente))
# Out:
# listaDocumentoPerturbadoClassificadoIncorretamente: 257

# %%
print("Lista de documentos perturbados classificados incorretamente(coerente)(classe=0 & previsão=1):", len(listaDocumentoPerturbadoClassificadoIncorretamente))
for i, documento in listaDocumentoPerturbadoClassificadoIncorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos perturbados classificados incorretamente(coerente)(classe=0 & previsão=1): 257
#    0 - Quais disciplinas tem tratamento diferenciado quanto ao processo de verificação de aprendizagem ? 0
#    1 - Quais os resultados finais que devem ser considerados para trabalho de conclusão de curso ? 0
#    2 - Estudos realizados no exterior vão ser aproveitados ? 0
#    3 - Qual um termo matematicamente equivalente às expressões regulares ? 0
#    4 - Onde vai ser feita a matrícula em disciplinas optativas ? 0
#    5 - Como são chamadas as instruções no computador ? 0
#    6 - Em quais áreas a ciência é uma grande força ? 0
#    7 - O que envolve o TCC em cursos voltados à ciências ? 0
#    8 - Desde quando o curso de engenharia de computação tem sido associado às universidades ? 0
#    9 - Quais os modos de abordagem da pesquisa de campo ? 0
#    10 - Qual a formação pioneira no brasil em engenharia de software ? 0
#    11 - Qual lei inclui o estágio de estudantes na lei brasileira ? 0
#    12 - A monografia é produzida a partir do quê ? 0
#    13 - Qual o objetivo do reitor ? 0
#    14 - Qual o funcionamento do Redecomep ? 0
#    15 - Do que decorre a validação de matrículas ? 0
#    16 - Quem identifica e registra a frequência das atividades acadêmicas ? 0
#    17 - Quantos bytes em sequência geralmente são divididos para armazenar números maiores ? 0
#    18 - o que verifica com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente ? 0
#    19 - O que e PBL ? 0
#    20 - Qual curso foi criada através da parceria entre a Escola de Engenharia de São Carlos e o Instituto de Ciências Matemáticas e de Computação da Universidade de São Paulo ? 0
#    21 - Quais são os aspectos da ULA ? 0
#    22 - O que o trabalho de conclusão de curso aborda ? 0
#    23 - Qual deve ser a frequência do acadêmico para que seja suficiente em uma disciplina ? 0
#    24 - Por que grande parte dos eletroeletrônicos são acessórios de computação ? 0
#    25 - Quais são as instituições orgânicas de ensino de uma universidade ? 0
#    26 - Quais matérias Al-Azhar representa ? 0
#    27 - Quais são os integrantes da CPU ? 0
#    28 - Quais são os efeitos da ULA ? 0
#    29 - Ao que os candidatos tem acesso ? 0
#    30 - O que permite com que profissionais que não tenham educação superior compram o papel de analista de sistemas ? 0
#    31 - quem possui a solicitação de regime de exercícios domiciliares ? 0
#    32 - Quais são os órgãos acadêmicos superiores da UFMS ? 0
#    33 - O que deverá ser anexado no SigProj ? 0
#    34 - Qual era o objetivo do curso de engenharia de arquitetura e computação ? 0
#    35 - Quando os alunos especiais podem fazer matrícula em disciplinas equivalentes ? 0
#    36 - Onde está calculado o número máximo para integralização curricular ? 0
#    37 - Qual o objetivo do curso ? 0
#    38 - Quem foi o primeiro presidente da República ? 0
#    39 - Quando os alunos especiais podem fazer matrícula em disciplinas somente ? 0
#    40 - como é construída a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    41 - Qual era o dever do Ministério da Educação anteriormente ? 0
#    42 - O que sabe dizer quando um professor opta por avaliar a sua matéria através de seminários ao invés de provas ? 0
#    43 - Qual o problema de Hilbert que fez os matemáticos se debruçarem tentanto testar quais problemas matemáticos poderiam ser resolvidos por um método efetivo ? 0
#    44 - O que a Secretaria Acadêmica avalia durante a etapa de validação de matrículas ? 0
#    45 - Como era caracterizada a máquina de tecer números de Babbage ? 0
#    46 - Para que a triagem pode contribuir eventualmente ? 0
#    47 - Em quais áreas a TI é uma grande alternativa ? 0
#    48 - Quanto dos sistemas de computação são vistos como “ sistemas embarcados ” ? 0
#    49 - O que é caracterizado pelas gramáticas livres de contexto ? 0
#    50 - Quantas horas haverá cada reunião de participação em órgãos colegiados ? 0
#    51 - Através de qual sistema o teclado da biblioteca da UFMS está disponível para consulta na internet ? 0
#    52 - Quem são os atores da investigação empírica ? 0
#    53 - O que veio a abrir novas opções para a transformação de dados em informação ? 0
#    54 - A UFMS construiu uma área geográfico-educacional de quantos km ? 0
#    55 - Qual modelo computacional mostra a construção de uma máquina universal capaz de operar com uma sequência de instruções ? 0
#    56 - Como os programas podem , por exemplo , realizar os resultados dos exames ? 0
#    57 - O que pode realizar caso uma empresa possua mais uma porta para o mundo aberta ? 0
#    58 - Para o que o analista de sistemas deve ter ? 0
#    59 - Por que o dispositivo de Babbage se distingue de outros dispositivos ? 0
#    60 - Quem é o núcleo da universidade de brasília ? 0
#    61 - O que os modelos dados pelos fundamentos científicos da engenharia de software devem permitir ao engenheiro ? 0
#    62 - Quais órgãos centrais são comuns em computador ? 0
#    63 - Em que a máquina de Hollerith foi dividida ? 0
#    64 - Qual um forte papel dado pelo POSCOMP ? 0
#    65 - Em que tem inicio os avanços recentes na ciência da computação ? 0
#    66 - O que a flexibilização do terminal fez ao computador ? 0
#    67 - A resolução nº 342 age recorre o quê ? 0
#    68 - quem é responsável pela apuração de conduta inadequadas de alunos e aplicação de medidas corretivas ? 0
#    69 - Por que em 2019 o ENEM conquistou um número bastante considerável de inscritos ? 0
#    70 - Quem informa as instruções para o computador ? 0
#    71 - O que a ciência da computação sofre ? 0
#    72 - Quem define a universidade de Nalanda ? 0
#    73 - Qual ferramenta é utilizada pela análise individual e análise essencial para modelar o funcionamento do sistema ? 0
#    74 - Quem cria os programas ? 0
#    75 - Por que uma máquina que possui uma fita de tamanho infinito não pode ser criada ? 0
#    76 - Por que uma máquina que possui uma fita de tamanho infinito não pode ser descrita ? 0
#    77 - Em que é baseada o sistema de numeração binário ? 0
#    78 - Como é conhecida a empresa tocada por Hollerith atualmente ? 0
#    79 - Quem orienta e prepara os alunos no ajuste de matrícula ? 0
#    80 - Em que o prolog é especializado ? 0
#    81 - Qual o estímulo acadêmico para obtenção do título de mestre ? 0
#    82 - Desde quando os processadores vêm sendo construídos em um único circuito ffer ? 0
#    83 - Qual a exigência para a promoção ao nível de trabalho na Alemanha ? 0
#    84 - onde o acadêmico deve requisitar graduação por extraordinário rendimento acadêmico ? 0
#    85 - Para que os alunos tenham atividades complementares ? 0
#    86 - Onde o professor irá passar as provas ? 0
#    87 - Para que cada profissional exerce um papel nas organizações ? 0
#    88 - Como a Universidade do Paraná é construída hoje em dia ? 0
#    89 - O que o discente deve realizar na seleção de disciplinas on-line ? 0
#    90 - quantos dos membros do nde devem possuir titulação acadêmica recebida em programas de pósgraduação ? 0
#    91 - A quem deve ser solicitado o aproveitamento das disciplinas AD em outro curso de graduação ? 0
#    92 - O que o plano de ensino deve permitir ? 0
#    93 - Qual a função do governador ? 0
#    94 - O que a área visa ? 0
#    95 - Como a pesquisa empírica ocorreu ? 0
#    96 - Por que a matemática de sistemas é uma área ampla ? 0
#    97 - o que os membros do nde devem formar ? 0
#    98 - Onde uma pessoa deve ministrar aula para ser contratada professor nos Estados Unidos ? 0
#    99 - Onde uma pessoa deve ministrar aula para ser a professor nos Estados Unidos ? 0
#    100 - Para que seria a fonte de energia ? 0
#    101 - Qual parece ser a ênfase do curso universitário dos analistas de sistemas ? 0
#    102 - O que o desenvolvimento cada vez mais rápido de novas tecnologias melhorou ? 0
#    103 - Quantos dias complementares o estagiário possui de recesso ? 0
#    104 - como deve ser distribuidas as disciplinas que o acadêmico está apto a obter ? 0
#    105 - Por que a contagem do tempo mensal é feita a partir do ingresso do acadêmico na UFMS ? 0
#    106 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de políticas corretivas ? 0
#    107 - Quem desenvolve o programa criado da necessidade do usuário pelo analista de sistemas ? 0
#    108 - O que o desenvolvimento cada vez mais rápido de novas tecnologias mudou ? 0
#    109 - Para onde deve ser enviado o material científico nas pesquisas ? 0
#    110 - O que os Programas de Pós-Graduação obtiveram em seu processo seletivo ? 0
#    111 - Qual um órgão brasileiro que usa pesquisas descritivas ? 0
#    112 - Qual o principal setor da PBL ? 0
#    113 - O que é Educação ? 0
#    114 - Onde são apresentados os conteúdos de uma disciplina ? 0
#    115 - Qual a limitação de um período letivo especial ? 0
#    116 - A quem é usada a frase " Ciência é para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos " ? 0
#    117 - Qual o prazo para o acadêmico fazer revisão da avaliação acadêmica ? 0
#    118 - como ficou a componente curricular não disciplinar no siscad ? 0
#    119 - O que a FAPDF criou ? 0
#    120 - Quais as exigências da pesquisa de ponta ? 0
#    121 - qual a designação do núcleo docente estruturante ( nde ) ? 0
#    122 - Qual era o objetivo do curso de ciências de sistemas e computação ? 0
#    123 - Como deve ser considerado o pedido de aproveitamento das atividades complementares ? 0
#    124 - Ao que o trabalho de Mestrado em Engenharia de Computação está associado ? 0
#    125 - Quais as áreas que há mais impactado a sociedade contemporânea ? 0
#    126 - Quantas pessoas geralmente fazem a monografia ? 0
#    127 - As especializações são destinadas ao quê ? 0
#    128 - O que é Secac ? 0
#    129 - O que é integração de sistemas ? 0
#    130 - O que foram WebApps ? 0
#    131 - Quem é responsável por criar e produzir novas tecnologias ? 0
#    132 - O que o profissional de computação precisa utilizar ? 0
#    133 - Como o trabalho de conclusão de curso é obrigatório ? 0
#    134 - Em quais áreas a mídia é uma grande força ? 0
#    135 - Qual o termo utilizado para calcular sequências de passos para completar uma tarefa ? 0
#    136 - Ao que a exigência do exame não está vinculada ? 0
#    137 - Qual tipo de estudo é geralmente baseado em uma monografia ? 0
#    138 - A quem o coordenador de curso poderia consultar se necessário ? 0
#    139 - Com o que estão relacionados as inovações e aspectos teóricos da economia ? 0
#    140 - Qual a finalidade da aplicação empírica ? 0
#    141 - Qual um órgão brasileiro que executa pesquisas descritivas ? 0
#    142 - Quem possui a primeira máquina de verdade ? 0
#    143 - Qual fase é fundamental em qualquer atividade empresarial ? 0
#    144 - Por quem é utilizado a pesquisa acadêmica ? 0
#    145 - O que foi iniciado com a subdivisão do Departamento de Matemática da UFMS ? 0
#    146 - Em que deve ser contratado um profissional em análise e desenvolvimento de sistemas ? 0
#    147 - Onde está prevista a tabela horária dos componentes curriculares ? 0
#    148 - Quando o acadêmico em regime de exercícios domiciliares pode prestar as provas que foram aplicadas durante o afastamento ? 0
#    149 - O que é teoria de sistemas ? 0
#    150 - quais são as tarefas da renovação de matrícula ? 0
#    151 - Onde está o MIT ? 0
#    152 - Qual a finalidade da criação do plano de estudos ? 0
#    153 - Quem deve identificar e indicar o motivo da ausência de renovação de matrícula sem justificativa ? 0
#    154 - Pelo que é responsável o Estado da educação em Portugal ? 0
#    155 - Desde quando os processadores vêm sendo construídos em um único circuito avançado ? 0
#    156 - Onde geralmente entra a próxima instrução ? 0
#    157 - Para que servem os sistemas modernos ? 0
#    158 - Qual a carga horária para publicação de pesquisadores ? 0
#    159 - A partir de qual momento o tempo sempre será contabilizado ? 0
#    160 - Como o TCC é desenvolvido em instituições ? 0
#    161 - Após quantos anos de estágio o estagiário tem direito a recesso virtual ? 0
#    162 - A teoria da engenharia é um subcampo de quais áreas ? 0
#    163 - o que consta com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente ? 0
#    164 - Por que é importante descobrir os problemas que a tecnologia traz para as empresas ? 0
#    165 - Qual geralmente é a base de uma máquina ? 0
#    166 - Por quem é responsável o sistema de bibliotecas da UFMS ? 0
#    167 - Em que os sistemas de informação de computador são de extrema importância ? 0
#    168 - Onde pode ser aprovada a matrícula em disciplinas optativas ? 0
#    169 - Por que o analista de sistemas poderia traduzir a necessidade do usuário ? 0
#    170 - Onde deverão ser executadas os sistemas de software complexo ? 0
#    171 - O que atende os portadores de traumatismos ? 0
#    172 - Por que uma máquina que rete uma fita de tamanho infinito não pode ser construída ? 0
#    173 - por meio de quem as instituições de ensino superior devem desenvolver as atribuições e os critérios de constituição do nde ? 0
#    174 - Como o tema deve ser inserido ? 0
#    175 - Onde poderá ser lançadas as notas e as frequências ? 0
#    176 - Qual foi a necessidade que permitiu a lei da criação da FAPDF ser alterada pela lei nº 3.652 ? 0
#    177 - A quem era aplicada o termo computador ? 0
#    178 - quais são as partes curriculares não disciplinares no projeto pedagógico de um curso de gradução ? 0
#    179 - Qual o prazo de aprovação do plano de absorção das disciplinas ? 0
#    180 - O que acontece com os alunos que não conseguiram vaga na turma comum ? 0
#    181 - O que acontece com os alunos que não conseguiram vaga na turma docente ? 0
#    182 - Em qual semestre o acadêmico deve ser inserido de preferência ? 0
#    183 - O que é necessário para um engenheiro de computação definir a profissão ? 0
#    184 - Em que eram empregados os funcionários antes da década de 1920 ? 0
#    185 - Quais as formas mais comuns de programa em uso ? 0
#    186 - Quais disciplinas estão inclusas nas atividades complementares ? 0
#    187 - Qual é o aproveitamento da bolsa de monitoria ? 0
#    188 - Qual a duração de um programa letivo especial ? 0
#    189 - Quando o acadêmico em regime de exercícios domiciliares poderá livrar as provas que foram aplicadas durante o afastamento ? 0
#    190 - em quantas discplinas o acadêmico poderá ter durante o período letivo especial ? 0
#    191 - Em que os profissionais atuando em cursos de graduação tecnológicos ou superiores de tecnologias são especializados ? 0
#    192 - O que é rapidamente modificado com as transformações contínuas conhecidas pela área da computação ? 0
#    193 - Com qual intuito foi destinado o curso de Análise de Sistemas ? 0
#    194 - o que a resolução no 401 contem ? 0
#    195 - qual etapa a distribuição das vagas disponíveis deve seguir ? 0
#    196 - Onde foi constituída a conferência internacional de engenharia de requisitos em 2013 ? 0
#    197 - Qual a área que atua e avalia os processos da engenharia de software ? 0
#    198 - O que acontece caso o Aluno Especial não requeira o aproveitamento das duas disciplinas anualmente até a data de matrícula ? 0
#    199 - Qual é a utilidade dos cursos de pós-graduação profissionais para a instituição ? 0
#    200 - Qual o número mínimo de créditos para uma turma de período letivo especial ? 0
#    201 - Quando o computador foi originalmente transformado ? 0
#    202 - Qual a carga horária para publicação de currículo ? 0
#    203 - quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de educação ? 0
#    204 - Qual precisa ser a frequência do acadêmico para que seja aprovado em uma disciplina ? 0
#    205 - Quem é excluído por jubilação obstante o vínculo acadêmico com quem ? 0
#    206 - Quem é excluído por jubilação tirar o vínculo acadêmico com quem ? 0
#    207 - Quem é excluído por jubilação alimentar o vínculo acadêmico com quem ? 0
#    208 - Qual o número mínimo de componentes para uma turma de período letivo especial ? 0
#    209 - O que o plano de ensino visa conter ? 0
#    210 - Qual o valor de um especialista na maioria das universidades ? 0
#    211 - Em que ano o ENEM atingiu 9,2 milhões de escritos ? 0
#    212 - O que o compartilhamento de tempo da CPU atende ? 0
#    213 - Quem deve incluir e registrar o motivo da ausência de renovação de matrícula sem justificativa ? 0
#    214 - por quem será executado o plano de estudos ? 0
#    215 - por quem será aplicado o plano de estudos ? 0
#    216 - O que o professor deve proporcionar ao acadêmico ? 0
#    217 - O que é estágio ? 0
#    218 - O que eram os portadores de traumatismos ? 0
#    219 - Quando foi sediado o Instituto Superior de Pedagogia em Corumbá ? 0
#    220 - Quem foi o primeiro associado da instituição ? 0
#    221 - O que põe a enfatização de uma universidade ao sistema ? 0
#    222 - Quando a avaliação do coordenador de curso é indispensável ? 0
#    223 - Como são denominadas as versões mais modernas do ábaco ? 0
#    224 - como o aluno deverá solicitar a revisão de sua frequência em uma disciplina ? 0
#    225 - Quais eram as unidades do Ministério da Educação e Saúde ? 0
#    226 - Quando é feito o cálculo do período de posicionamento do discente no curso ? 0
#    227 - o que é regime de atividades domiciliares ? 0
#    228 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é realizada pelo orgão competente ? 0
#    229 - O que são dispositivos de entradas e saída ? 0
#    230 - Quem irá elaborar as atividades que deverão ser cumpridas durante o regime de exercícios domiciliares ? 0
#    231 - Qual o objetivo da atuação de campo para a Ciência ? 0
#    232 - Qual o currículo acadêmico para obtenção do título de mestre ? 0
#    233 - O que é função da computação ? 0
#    234 - Qual era o embrião do ensino superior público no Noroeste do Mato Grosso ? 0
#    235 - A quem Zuse decidiu vender o Z1 ? 0
#    236 - Por quem eram criadas as tabelas logarítmicas ? 0
#    237 - Para que servem os sistemas utilizados ? 0
#    238 - Qual o prazo para a issão de frequência ? 0
#    239 - O que deve ser usada no SigProj ? 0
#    240 - Quantas regras Pānini utilizou para escrever a gramática de Sânscrito ? 0
#    241 - Qual a base da teoria da computação ? 0
#    242 - O que o regime de exercícios domiciliares permite ao acadêmico ? 0
#    243 - Qual o intuito do POSCOMP ? 0
#    244 - Qual a metragem horária para publicação de trabalhos ? 0
#    245 - O que garante o uso da TI nas empresas do mundo todo ? 0
#    246 - A bolsa será entregue para quem ? 0
#    247 - Qual o objeto da revisão do curso de engenharia de sistemas e computação ? 0
#    248 - Do que surgiu a aplicação da gestão do conhecimento ? 0
#    249 - O que fazer com os alunos que não conseguiram vaga na turma pretendida ? 0
#    250 - Qual geralmente é a grafia de uma monografia ? 0
#    251 - O que o plano de ensino deve apresentar ? 0
#    252 - Quem também utiliza a sigla inglesa ? 0
#    253 - Quando as vagas nas disciplinas estão no período de posicionamento do discente não são garantidas ? 0
#    254 - Onde foi chamada oficialmente o termo engenharia de software ? 0
#    255 - Como é feito a memória da CPU ? 0
#    256 - Como o TCC é classificado em instituições ? 0

# %% [markdown]
# # 3 Resultado do Cálculo das Medidas de (In)coerência

# %%
# Nome base das saidas do projeto
NOMEBASESAIDA = "MedidaCoerenciaFaquad_v1"

# Definição dos parâmetros a serem avaliados

# %% [markdown]
# ## 3.1 Carrega os dados das medidas

# %% [markdown]
# ### 3.1.1 Função que encontra a melhor mensuração

# %%
# Import das bibliotecas.
import os
import pandas as pd

def getResultadosMensuracao(DIRETORIO_COHEBERT, 
                            DOCUMENTOS_PERTURBADOS, 
                            TOP_K_PREDICAO):
  
  # Quantidade de documentos a serem perturbados a partir do original.    
  DOCUMENTOS_PERTURBADOS = DOCUMENTOS_PERTURBADOS

  # Quantidade de palavras a serem recuperadas mais próximas da máscara. 
  TOP_K_PREDICAO = TOP_K_PREDICAO

  # MCL a serem avaliados
  MODELO_BERT = ['_BERTimbau', '_BERTmultilingual']
  
  TAMANHO_BERT = ['_base','_large']
  
  MODELO = ['_pretreinado', '_ajustado'] 

  ESTRATEGIA_MEDIDA_NUM = [0, 1]  
  ESTRATEGIA_MEDIDA = ['_mean', '_max']
    
  #["TODAS_AS_PALAVRAS", "SEM_STOPWORDS", "SOMENTE_VERBOS_SUBSTANTIVOS"]
  FILTRO_PALAVRAS_NUM = [0, 1, 2, 3, 4]
  FILTRO_PALAVRAS = ['_tap','_ssw', '_ssb', '_sve', '_svs'] 
  
  # Diretório para salvar o arquivo.
  DIRETORIO_AVALIACAO = "/content/drive/My Drive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_medicao_palavra/Avaliacao/"  


  MELHOR_MODELO_BERT = ""
  MELHOR_TAMANHO_BERT = ""
  MELHOR_MODELO = ""
  MELHOR_DOCUMENTOS_PERTURBADOS = 0
  MELHOR_TOP_K_PREDICAO = 0  
  MELHOR_ESTRATEGIA_MEDIDA = 0
  MELHOR_FILTRO_PALAVRAS = 0  
  MELHOR_MEDIDA_GERAL = 0  
  MELHOR_MEDIDA_GERAL_STR = ""  
  MELHOR_RESULTADO = -1
  MELHOR_TEMPO = 0

  lista_resultados = []

  listaTempoTotal = []  
  
  # Verifica se o diretório dos resultados existe.
  if os.path.exists(DIRETORIO_AVALIACAO):    
    arquivos = os.listdir(DIRETORIO_AVALIACAO) 
    for modelo_bert in MODELO_BERT:
      for tamanho in TAMANHO_BERT:        
        if modelo_bert != '_BERTmultilingual' or tamanho != '_large':  
          for modelo in MODELO:        
            for documentos_perturbados in DOCUMENTOS_PERTURBADOS:
              for top_k_predicao in TOP_K_PREDICAO:                      
                for estrategia in ESTRATEGIA_MEDIDA:  
                  for filtro_palavra in FILTRO_PALAVRAS:  
                    # Acumuladores.
                    somaAcuracia = 0                    
                    contaReg = 0
                    for i in range(len(arquivos)):                                    
                      if ((("_P_" + str(documentos_perturbados)+"_") in arquivos[i]) 
                          and (("_K_" + str(top_k_predicao)+"_") in arquivos[i])                                 
                          and (modelo_bert in arquivos[i]) 
                          and (tamanho in arquivos[i]) 
                          and (modelo in arquivos[i]) 
                          and (estrategia in arquivos[i]) 
                          and (filtro_palavra in arquivos[i])):
                             
                        NOME_ARQUIVO_AVALIACAO_COMPLETO = DIRETORIO_AVALIACAO + arquivos[i]                              
                        # Verifica se o arquivo existe.
                        if os.path.isfile(NOME_ARQUIVO_AVALIACAO_COMPLETO):
                          # Carrega os dados do arquivo  
                          dados = pd.read_csv(NOME_ARQUIVO_AVALIACAO_COMPLETO, sep=';')
                      
                          # Mostra os dados do teste da medida.
                          for index, linha in dados.iterrows():        
                              # Cálculo das estatísticas
                              ccos = (linha['ccos'])
                              cman = (linha['cman'])
                              ceuc = (linha['ceuc'])
                              
                              MELHOR_MEDIDA = -1
                              MELHOR_MEDIDA_STR = ""
                              if ccos >= cman and ccos >= ceuc:
                                  MELHOR_MEDIDA_STR = 'ccos'
                                  MELHOR_MEDIDA = ccos
                              else:
                                  if ceuc >= ccos and ceuc >= cman:
                                      MELHOR_MEDIDA_STR = 'ceuc'
                                      MELHOR_MEDIDA = ceuc
                                  else:
                                      if cman >= ccos and cman >= ceuc:
                                         MELHOR_MEDIDA_STR = 'cman'
                                         MELHOR_MEDIDA = cman
                              
                              if MELHOR_MEDIDA > MELHOR_RESULTADO:
                                MELHOR_DOCUMENTOS_PERTURBADOS = documentos_perturbados
                                MELHOR_TOP_K_PREDICAO = top_k_predicao
                                MELHOR_ESTRATEGIA_MEDIDA = estrategia
                                MELHOR_FILTRO_PALAVRAS = filtro_palavra
                                MELHOR_RESULTADO = MELHOR_MEDIDA                                
                                MELHOR_TEMPO = linha['tempo']
                                MELHOR_MEDIDA_GERAL = MELHOR_MEDIDA
                                MELHOR_MEDIDA_GERAL_STR = MELHOR_MEDIDA_STR 
                                MELHOR_MODELO_BERT = modelo_bert
                                MELHOR_TAMANHO_BERT = tamanho
                                MELHOR_MODELO = modelo

                              lista_resultados.append([MELHOR_MODELO_BERT,
                                                       MELHOR_TAMANHO_BERT,
                                                       MELHOR_MODELO,
                                                       documentos_perturbados,
                                                       top_k_predicao, 
                                                       estrategia, 
                                                       filtro_palavra, 
                                                       ccos, 
                                                       ceuc, 
                                                       cman,
                                                       MELHOR_MEDIDA_STR,
                                                       MELHOR_MEDIDA,                                                        
                                                       linha['tempo']])
    
    # Retorno do melhor valor
    if MELHOR_MEDIDA_GERAL_STR == "ccos":
      lista_resultado_ordenado = sorted(lista_resultados, key=lambda x: x[7], reverse=True)  
    else:
      if MELHOR_MEDIDA_GERAL_STR == "ceuc":
        lista_resultado_ordenado = sorted(lista_resultados, key=lambda x: x[8], reverse=True)
      else:
        lista_resultado_ordenado = sorted(lista_resultados, key=lambda x: x[9], reverse=True)

    return MELHOR_MODELO_BERT, MELHOR_TAMANHO_BERT, MELHOR_MODELO, MELHOR_DOCUMENTOS_PERTURBADOS, MELHOR_TOP_K_PREDICAO, MELHOR_ESTRATEGIA_MEDIDA, MELHOR_FILTRO_PALAVRAS, MELHOR_RESULTADO, MELHOR_TEMPO, MELHOR_MEDIDA_GERAL, MELHOR_MEDIDA_GERAL_STR, lista_resultado_ordenado
  else:
      print('Diretório com os resultados não encontrado')

# %%
# Parametros para o Cohebert Manual
DOCUMENTOS_PERTURBADOS = [1, 20]
TOP_K_PREDICAO = [1, 10, 100, 1000]

# Recupera os melhores parâmetros
MELHOR_MODELO_BERT, MELHOR_TAMANHO_BERT, MELHOR_MODELO, MELHOR_DOCUMENTOS_PERTURBADOS, MELHOR_TOP_K_PREDICAO, MELHOR_ESTRATEGIA_MEDIDA, MELHOR_FILTRO_PALAVRAS, MELHOR_RESULTADO, MELHOR_TEMPO, MELHOR_MEDIDA_GERAL, MELHOR_MEDIDA_GERAL_STR, lista_resultados = getResultadosMensuracao(DIRETORIO_COHEBERT, DOCUMENTOS_PERTURBADOS, TOP_K_PREDICAO)

# %%
print("Parâmetros do melhor resultado do mensurador")
print("\n  Modelo BERT           :", MELHOR_MODELO_BERT, 
      "\n  Tamanho BERT          :", MELHOR_TAMANHO_BERT, 
      "\n  Modelo                :", MELHOR_MODELO,     
      "\n  Documentos Perturbados:", MELHOR_DOCUMENTOS_PERTURBADOS, 
      "\n  Top k predição        :", MELHOR_TOP_K_PREDICAO, 
      "\n  Estratégia            :", MELHOR_ESTRATEGIA_MEDIDA, 
      "\n  Filtro                :", MELHOR_FILTRO_PALAVRAS, 
      "\n  Resultado             :", MELHOR_RESULTADO, 
      "\n  Medida                :", MELHOR_MEDIDA_GERAL_STR,       
      "\n  Tempo execução        :", MELHOR_TEMPO)

print("\nLista dos resultados ranqueados")
for i, linha in enumerate(lista_resultados):
    print((i+1),"=", linha)
# Out:
# Parâmetros do melhor resultado do mensurador
#
#   Modelo BERT           : _BERTimbau
#   Tamanho BERT          : _large
#   Modelo                : _pretreinado
#   Documentos Perturbados: 20
#   Top k predição        : 1000
#   Estratégia            : _mean
#   Filtro                : _tap
#   Resultado             : 0.8763333333333333
#   Medida                : ceuc
#   Tempo execução        : 3:27:27
#
# Lista dos resultados ranqueados
# 1 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_mean', '_tap', 0.3705555555555556, 0.8763333333333333, 0.7445, 'ceuc', 0.8763333333333333, '3:27:27']
# 2 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_mean', '_tap', 0.3711111111111111, 0.8633333333333333, 0.7488888888888889, 'ceuc', 0.8633333333333333, '0:11:57']
# 3 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_mean', '_ssw', 0.5411111111111111, 0.8588888888888889, 0.7966666666666666, 'ceuc', 0.8588888888888889, '0:12:03']
# 4 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_mean', '_ssw', 0.5292222222222223, 0.8455555555555555, 0.793, 'ceuc', 0.8455555555555555, '3:42:47']
# 5 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_max', '_tap', 0.3253333333333333, 0.8429444444444445, 0.6828888888888889, 'ceuc', 0.8429444444444445, '3:32:36']
# 6 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_max', '_tap', 0.3366666666666666, 0.8244444444444444, 0.6833333333333333, 'ceuc', 0.8244444444444444, '0:12:28']
# 7 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_max', '_ssw', 0.4854444444444444, 0.8236666666666667, 0.75, 'ceuc', 0.8236666666666667, '3:43:52']
# 8 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_max', '_ssw', 0.4944444444444444, 0.8222222222222222, 0.7411111111111112, 'ceuc', 0.8222222222222222, '0:12:23']
# 9 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_mean', '_svs', 0.5977777777777777, 0.8044444444444444, 0.7711111111111111, 'ceuc', 0.8044444444444444, '0:12:09']
# 10 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_mean', '_svs', 0.5981666666666666, 0.8007222222222222, 0.7705, 'ceuc', 0.8007222222222222, '3:25:38']
# 11 = ['_BERTimbau', '_large', '_pretreinado', 20, 1000, '_max', '_svs', 0.5461111111111111, 0.7712222222222223, 0.7263888888888889, 'ceuc', 0.7712222222222223, '3:46:31']
# 12 = ['_BERTimbau', '_large', '_pretreinado', 1, 1000, '_max', '_svs', 0.5388888888888889, 0.7644444444444445, 0.72, 'ceuc', 0.7644444444444445, '0:13:57']
# 13 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_mean', '_tap', 0.5083333333333333, 0.7421111111111112, 0.6958333333333333, 'ceuc', 0.7421111111111112, '3:26:54']
# 14 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_mean', '_svs', 0.5761666666666667, 0.7286111111111111, 0.7079444444444445, 'ceuc', 0.7286111111111111, '3:30:37']
# 15 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_mean', '_svs', 0.5722222222222222, 0.7177777777777777, 0.7177777777777777, 'ceuc', 0.7177777777777777, '0:13:44']
# 16 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_mean', '_tap', 0.4922222222222222, 0.7166666666666667, 0.6788888888888889, 'ceuc', 0.7166666666666667, '0:14:01']
# 17 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_mean', '_ssw', 0.4778333333333333, 0.6911111111111111, 0.6561666666666667, 'ceuc', 0.6911111111111111, '3:31:11']
# 18 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_mean', '_ssw', 0.4866666666666667, 0.69, 0.6533333333333333, 'ceuc', 0.69, '0:13:39']
# 19 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_max', '_tap', 0.4440555555555555, 0.6827222222222222, 0.621, 'ceuc', 0.6827222222222222, '3:36:30']
# 20 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_max', '_svs', 0.5156666666666667, 0.6716666666666666, 0.6398888888888888, 'ceuc', 0.6716666666666666, '3:02:40']
# 21 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_max', '_svs', 0.5211111111111111, 0.6588888888888889, 0.6377777777777778, 'ceuc', 0.6588888888888889, '0:13:39']
# 22 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_max', '_tap', 0.4211111111111111, 0.6533333333333333, 0.6, 'ceuc', 0.6533333333333333, '0:13:34']
# 23 = ['_BERTimbau', '_large', '_pretreinado', 20, 100, '_max', '_ssw', 0.4362222222222222, 0.6408888888888888, 0.5946111111111111, 'ceuc', 0.6408888888888888, '3:34:11']
# 24 = ['_BERTimbau', '_large', '_pretreinado', 1, 100, '_max', '_ssw', 0.4422222222222222, 0.6255555555555555, 0.5944444444444444, 'ceuc', 0.6255555555555555, '0:13:38']
# 25 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_mean', '_svs', 0.5644444444444444, 0.6, 0.5966666666666667, 'ceuc', 0.6, '0:11:53']
# 26 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_mean', '_svs', 0.5508888888888889, 0.5923888888888889, 0.5882777777777778, 'ceuc', 0.5923888888888889, '3:47:26']
# 27 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_mean', '_tap', 0.5032222222222222, 0.5695555555555556, 0.5525, 'ceuc', 0.5695555555555556, '3:33:37']
# 28 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_mean', '_ssw', 0.4955555555555556, 0.5688888888888889, 0.5433333333333333, 'ceuc', 0.5688888888888889, '0:11:48']
# 29 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_mean', '_tap', 0.5033333333333333, 0.5677777777777778, 0.5555555555555556, 'ceuc', 0.5677777777777778, '0:11:41']
# 30 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_mean', '_ssw', 0.4865, 0.547, 0.5342222222222223, 'ceuc', 0.547, '3:54:51']
# 31 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_max', '_svs', 0.4955555555555556, 0.5166666666666667, 0.5122222222222222, 'ceuc', 0.5166666666666667, '0:11:53']
# 32 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_max', '_svs', 0.4845555555555556, 0.5133888888888889, 0.5027222222222222, 'ceuc', 0.5133888888888889, '2:58:09']
# 33 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_mean', '_svs', 0.5215, 0.5087222222222222, 0.5105555555555555, 'ccos', 0.5215, '3:30:21']
# 34 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_mean', '_svs', 0.5166666666666667, 0.5077777777777778, 0.5066666666666667, 'ccos', 0.5166666666666667, '0:13:34']
# 35 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_max', '_ssw', 0.4466666666666666, 0.4988888888888889, 0.4922222222222222, 'ceuc', 0.4988888888888889, '0:11:54']
# 36 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_max', '_tap', 0.43, 0.4898888888888889, 0.4688888888888889, 'ceuc', 0.4898888888888889, '3:47:15']
# 37 = ['_BERTimbau', '_large', '_pretreinado', 1, 10, '_max', '_tap', 0.4366666666666666, 0.4822222222222222, 0.4633333333333333, 'ceuc', 0.4822222222222222, '0:11:54']
# 38 = ['_BERTimbau', '_large', '_pretreinado', 20, 10, '_max', '_ssw', 0.4442777777777777, 0.4806111111111111, 0.4678333333333333, 'ceuc', 0.4806111111111111, '2:56:39']
# 39 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_mean', '_ssw', 0.4833333333333333, 0.4777777777777778, 0.4777777777777778, 'ccos', 0.4833333333333333, '0:13:35']
# 40 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_mean', '_ssw', 0.4878888888888888, 0.4752222222222222, 0.4792777777777778, 'ccos', 0.4878888888888888, '3:07:19']
# 41 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_mean', '_tap', 0.4442222222222222, 0.4618333333333333, 0.4517222222222222, 'ceuc', 0.4618333333333333, '3:09:22']
# 42 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_mean', '_tap', 0.4177777777777778, 0.4322222222222222, 0.4222222222222222, 'ceuc', 0.4322222222222222, '0:13:40']
# 43 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_max', '_svs', 0.454, 0.4245555555555556, 0.4284444444444444, 'ccos', 0.454, '3:36:24']
# 44 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_max', '_svs', 0.4411111111111111, 0.4222222222222222, 0.4177777777777778, 'ccos', 0.4411111111111111, '0:13:40']
# 45 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_max', '_ssw', 0.4491666666666666, 0.4132777777777778, 0.4145555555555555, 'ccos', 0.4491666666666666, '3:31:35']
# 46 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_max', '_ssw', 0.4411111111111111, 0.4066666666666667, 0.4077777777777778, 'ccos', 0.4411111111111111, '0:13:32']
# 47 = ['_BERTimbau', '_large', '_pretreinado', 20, 1, '_max', '_tap', 0.3795, 0.3740555555555555, 0.3666666666666666, 'ccos', 0.3795, '3:36:32']
# 48 = ['_BERTimbau', '_large', '_pretreinado', 1, 1, '_max', '_tap', 0.3522222222222222, 0.3477777777777778, 0.3355555555555555, 'ccos', 0.3522222222222222, '0:13:44']

# %% [markdown]
# ### Escolhendo um resultado diferente do melhor

# %%
#MELHOR_MODELO_BERT = "_BERTimbau"
#MELHOR_TAMANHO_BERT = "_large"
#MELHOR_MODELO = "_pretreinado"
#MELHOR_DOCUMENTOS_PERTURBADOS = 1
#MELHOR_TOP_K_PREDICAO = 1000
#MELHOR_ESTRATEGIA_MEDIDA = "_max"
#MELHOR_FILTRO_PALAVRAS = "_ssw"
#lista_resultados= []

# %% [markdown]
# ### 3.1.1 Função que carrega os parâmetros do resultado da melhor mensuração

# %%
def carregaMedidasCompactada(MODELO_BERT, 
                   TAMANHO_BERT, 
                   MODELO, 
                   DOCUMENTOS_PERTURBADOS, 
                   TOP_K_PREDICOES,
                   EQUACAO_MEDIDA, 
                   ESTRATEGIA_MEDIDA, 
                   FILTRO_PALAVRAS):
  # Import das bibliotecas.
  import os
  import pandas as pd

  # Nome arquivo a ser aberto
  NOME_ARQUIVO_MEDICAO = NOME_BASE_SAIDA + "_P_" + str(DOCUMENTOS_PERTURBADOS) + "_K_" + str(TOP_K_PREDICOES) + EQUACAO_MEDIDA + ESTRATEGIA_MEDIDA + FILTRO_PALAVRAS + MODELO_BERT + TAMANHO_BERT + MODELO

  # Diretório do drive do arquivo
  DIRETORIO_MEDICAO_DRIVE = DIRETORIO_DRIVE + "validacao_medicao_palavra/Medicao/"

  # Diretório local para salvar o arquivo
  DIRETORIO_MEDICAO_LOCAL = DIRETORIO_LOCAL + "Medicao/"

  # Verifica se o diretório existe
  if not os.path.exists(DIRETORIO_MEDICAO_LOCAL):  
    # Cria o diretório
    os.makedirs(DIRETORIO_MEDICAO_LOCAL)
    logging.info("Diretório criado: {}.".format(DIRETORIO_MEDICAO_LOCAL))
  else:
    logging.info("Diretório já existe: {}.".format(DIRETORIO_MEDICAO_LOCAL))

  # Verifica se o diretório dos resultados existem.
  if os.path.exists(DIRETORIO_MEDICAO_DRIVE):        

    # Caminho completo do arquivo compactado no drive
    NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO = DIRETORIO_MEDICAO_DRIVE + NOME_ARQUIVO_MEDICAO + ".zip"
    # print("NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO:", NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO)

    # Caminho completo do arquivo compactado no local
    NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO = DIRETORIO_MEDICAO_LOCAL + NOME_ARQUIVO_MEDICAO + ".zip"
    # print("NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO:", NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO)

    # Caminho completo do arquivo no local
    NOME_ARQUIVO_MEDICAO_LOCAL = DIRETORIO_MEDICAO_LOCAL + NOME_ARQUIVO_MEDICAO + ".csv"
    # print("NOME_ARQUIVO_MEDICAO_LOCAL:", NOME_ARQUIVO_MEDICAO_LOCAL)

    # Verifica se o arquivo existe.
    if os.path.isfile(NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO):
      
      # Copia arquivo da medição compactado do google drive para o drive local
      # !cp "$NOME_ARQUIVO_MEDICAO_DRIVE_COMPACTADO" "$NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO"  
                        
      # Descompacta arquivo da medição compactado no drive local
      # !unzip -o -j -q "$NOME_ARQUIVO_MEDICAO_LOCAL_COMPACTADO" -d "$DIRETORIO_MEDICAO_LOCAL"

      # Carrega os dados do arquivo  
      dados_medida = pd.read_csv(NOME_ARQUIVO_MEDICAO_LOCAL, sep=';')

      #print('Registros: ', len(dados_medida))
      print('Arquivo encontrado e carregado')        

      return dados_medida
      
    else:
      print('Arquivo com as medições não encontrado')        

  else:
    print('Diretório com as medições não encontrado')
  
  return None

# %%
def carregaMedidas1(MODELO_BERT, 
                   TAMANHO_BERT, 
                   MODELO, 
                   DOCUMENTOS_PERTURBADOS, 
                   TOP_K_PREDICOES, 
                   ESTRATEGIA_MEDIDA, 
                   FILTRO_PALAVRAS):
  # Import das bibliotecas.
  import os
  import pandas as pd

  # Nome arquivo a ser aberto
  NOME_ARQUIVO_MEDICAO = NOMEBASESAIDA + "_P_" + str(DOCUMENTOS_PERTURBADOS) + "_K_" + str(TOP_K_PREDICOES) + MODELO + ESTRATEGIA_MEDIDA + FILTRO_PALAVRAS + MODELO_BERT + TAMANHO_BERT + ".csv"

  # Diretório para salvar o arquivo.
  DIRETORIO_MEDICAO = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_COHEBERT + "/validacao_medicao_palavra/Medicao/"
                     
  # Verifica se o diretório dos resultados existem.
  if os.path.exists(DIRETORIO_MEDICAO):

    # Caminho completo do arquivo
    NOME_ARQUIVO_MEDICAO_COMPLETO = DIRETORIO_MEDICAO + NOME_ARQUIVO_MEDICAO

    # Verifica se o arquivo existe.
    if os.path.isfile(NOME_ARQUIVO_MEDICAO_COMPLETO):
      # Carrega os dados do arquivo  
      dadosMedida = pd.read_csv(NOME_ARQUIVO_MEDICAO_COMPLETO, sep=';')

      print('Registros: ', len(dadosMedida))

      return dadosMedida
      
    else:
      print('Arquivo com as medições não encontrado')        

  else:
    print('Diretório com as medições não encontrado')
  
  return None

# %% [markdown]
# ## 3.2 Carregamento dos arquivos de dados originais e perturbados

# %% [markdown]
# ### 3.2.1 Especifica os nomes dos arquivos de dados

# %%
# Nome do arquivo
NOMEARQUIVOORIGINAL = "original.csv"
NOMEARQUIVOORIGINALCOMPACTADO = "original.zip"
NOMEARQUIVOORIGINALPOS = "originalpos.csv"
NOMEARQUIVOORIGINALPOSCOMPACTADO = "originalpos.zip"

NOMEARQUIVOPERTURBADO = "perturbado_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".csv"
NOMEARQUIVOPERTURBADOCOMPACTADO = "perturbado_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".zip"
NOMEARQUIVOPERTURBADOPOS = "perturbadopos_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".csv"
NOMEARQUIVOPERTURBADOPOSCOMPACTADO = "perturbadopos_p" + str(MELHOR_DOCUMENTOS_PERTURBADOS) + "_k" + str(MELHOR_TOP_K_PREDICAO) + ".zip"

# %% [markdown]
# ### 3.2.2 Cria o diretório local para receber os dados

# %%
# Import das bibliotecas.
import os

# Cria o diretório para receber os arquivos Originais e Perturbados
# Diretório a ser criado
dirbase = DIRETORIO_LOCAL[:-1]

if not os.path.exists(dirbase):  
    # Cria o diretório
    os.makedirs(dirbase)    
    logging.info("Diretório criado: {}".format(dirbase))
else:    
    logging.info("Diretório já existe: {}".format(dirbase))
# Out:
# 2022-03-18 12:51:00,295 : INFO : Diretório já existe: /content/FAQUAD

# %% [markdown]
# ### 3.2.3 Copia e descompacta os arquivos do Google Drive para o Colaboratory

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:

  # !cp "$DIRETORIO_DRIVE$NOMEARQUIVOORIGINALCOMPACTADO" "$DIRETORIO_LOCAL"
  # !cp "$DIRETORIO_DRIVE$NOMEARQUIVOORIGINALPOSCOMPACTADO" "$DIRETORIO_LOCAL"

  # !cp "$DIRETORIO_DRIVE$NOMEARQUIVOPERTURBADOCOMPACTADO" "$DIRETORIO_LOCAL"
  # !cp "$DIRETORIO_DRIVE$NOMEARQUIVOPERTURBADOPOSCOMPACTADO" "$DIRETORIO_LOCAL"

  logging.info("Terminei a cópia!")
# Out:
# 2022-03-18 12:51:00,849 : INFO : Terminei a cópia!

# %% [markdown]
# Descompacta os arquivos.
#
# Usa o unzip para descompactar:
# *   `-o` sobrescreve o arquivo se existir
# *   `-j` Não cria nenhum diretório
# *   `-q` Desliga as mensagens
# *   `-d` Diretório de destino

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOMEARQUIVOORIGINALCOMPACTADO" -d "$DIRETORIO_LOCAL"
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOMEARQUIVOORIGINALPOSCOMPACTADO" -d "$DIRETORIO_LOCAL"

  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOMEARQUIVOPERTURBADOCOMPACTADO" -d "$DIRETORIO_LOCAL"
  # !unzip -o -j -q "$DIRETORIO_LOCAL$NOMEARQUIVOPERTURBADOPOSCOMPACTADO" -d "$DIRETORIO_LOCAL"

  logging.info("Terminei a descompactação!")
# Out:
# 2022-03-18 12:51:01,393 : INFO : Terminei a descompactação!

# %% [markdown]
# ### 3.2.4 Carregamento das lista com os dados dos arquivos originais e perturbados

# %% [markdown]
# #### Carrega o arquivo dos dados originais e POS

# %%
#Biblioteca
import pandas as pd

# Abre o arquivo e retorna o DataFrame
lista_documentos_originais = pd.read_csv(DIRETORIO_LOCAL + NOMEARQUIVOORIGINAL, sep=";", encoding="UTF-8")
lista_documentos_originais_pos = pd.read_csv(DIRETORIO_LOCAL + NOMEARQUIVOORIGINALPOS, sep=";", encoding="UTF-8")

logging.info("TERMINADO ORIGINAIS: {}.".format(len(lista_documentos_originais)))
logging.info("TERMINADO ORIGINAIS POS: {}.".format(len(lista_documentos_originais_pos)))
# Out:
# 2022-03-18 12:51:01,425 : INFO : TERMINADO ORIGINAIS: 900.
# 2022-03-18 12:51:01,426 : INFO : TERMINADO ORIGINAIS POS: 900.

# %%
lista_documentos_originais.sample(5)
# Out:
#                                    id  \
# 122  0211e41566044a14859c928290110cbb
# 697  5def773266584a979d37f1dbafae4f0f
# 525  a9814c246dee46b59b733c3a473b595e
# 91   ee2a6e83216b47f5b390be193221f4e5
# 418  778225ad9bbf4465bc02c22af67402ce
#
#                                              sentencas  \
# 122  ['Por que uma máquina que possui uma fita de t...
# 697  ['Quais tipos de eventos científicos podem ser...
# 525  ['O que a máquina de turing utilizava para ope...
# 91   ['Com quem o computador moderno começou a ganh...
# 418  ['O que é a monografia segundo o dicionário Au...
#
#                                              documento
# 122  Por que uma máquina que possui uma fita de tam...
# 697  Quais tipos de eventos científicos podem ser u...
# 525  O que a máquina de turing utilizava para opera...
# 91   Com quem o computador moderno começou a ganhar...
# 418  O que é a monografia segundo o dicionário Auré...

# %%
lista_documentos_originais_pos.sample(5)
# Out:
#                                    id  \
# 418  778225ad9bbf4465bc02c22af67402ce
# 593  fae4ebdaf7aa482b978b7b0b472b141f
# 720  d4e72ad45eee4e64bd9e37a82ecc91b9
# 599  5d670b9c1fa442129c2c4cd6348c4392
# 165  582872d1a6084badad5bb572535c742c
#
#                                          pos_documento
# 418  [[['O', 'que', 'é', 'a', 'monografia', 'segund...
# 593  [[['A', 'matrícula', 'em', 'disciplinas', 'iso...
# 720  [[['Quem', 'coleta', 'informações', 'sobre', '...
# 599  [[['Quais', 'disciplinas', 'possuem', 'tratame...
# 165  [[['Qual', 'era', 'o', 'sonho', 'de', 'Gottfri...

# %% [markdown]
# #### Corrigir os tipos de colunas dos dados originais e POS
#
# Em dados originais:
# - coluna 1 - `sentenças` carregadas do arquivo vem como string e não como lista.
#
# Em dados originais pos:
# - coluna 1 - `pos_documento` carregadas do arquivo vem como string e não como lista.

# %%
# Import das bibliotecas.
import ast # Biblioteca para conversão de string em lista

# Verifica se o tipo da coluna não é list e converte
lista_documentos_originais["sentencas"] = lista_documentos_originais["sentencas"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

lista_documentos_originais_pos["pos_documento"] = lista_documentos_originais_pos["pos_documento"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

logging.info("TERMINADO CORREÇÃO ORIGINAIS: {}.".format(len(lista_documentos_originais)))
logging.info("TERMINADO CORREÇÃO ORIGINAIS POS: {}.".format(len(lista_documentos_originais_pos)))
# Out:
# 2022-03-18 12:51:01,538 : INFO : TERMINADO CORREÇÃO ORIGINAIS: 900.
# 2022-03-18 12:51:01,540 : INFO : TERMINADO CORREÇÃO ORIGINAIS POS: 900.

# %% [markdown]
# #### Carrega o arquivo dos dados perturbados e POS

# %%
# Abre o arquivo e retorna o DataFrame
lista_documentos_perturbados = pd.read_csv(DIRETORIO_LOCAL + NOMEARQUIVOPERTURBADO, sep=";", encoding="UTF-8")
lista_documentos_perturbados_pos = pd.read_csv(DIRETORIO_LOCAL + NOMEARQUIVOPERTURBADOPOS, sep=";", encoding="UTF-8")

logging.info("TERMINADO PERTURBADOS: {}.".format(len(lista_documentos_perturbados)))
logging.info("TERMINADO PERTURBADOS POS: {}.".format(len(lista_documentos_perturbados_pos)))
# Out:
# 2022-03-18 12:51:01,739 : INFO : TERMINADO PERTURBADOS: 18000.
# 2022-03-18 12:51:01,741 : INFO : TERMINADO PERTURBADOS POS: 18000.

# %%
lista_documentos_perturbados.sample(5)
# Out:
#                                              id  \
# 3101    77c2e4b820704cd9ad5d07ef366a5994_pert_1
# 11909   01ca0fcf3d2744a68ea0efb6e97dcee9_pert_9
# 14056  87ea7b87e9464969824a2c692e0b8994_pert_16
# 7090   24c7b90289b34ed6b47f7f14fa388233_pert_10
# 11268   f0da62e14d584bb69061ceb644c2a906_pert_8
#
#                                               perturbado  \
# 3101   ['Como a CPU executado as instruções de um pro...
# 11909  ['Em quais matérias o aluno especial não pode ...
# 14056  ['Quando devem ser líquidos os pedidos de apro...
# 7090   ['Qual lei compôs a lei da criação da fundação...
# 11268               ['Qual a duração média de um set ?']
#
#                                      documentoPerturbado  \
# 3101   Como a CPU executado as instruções de um progr...
# 11909  Em quais matérias o aluno especial não pode se...
# 14056  Quando devem ser líquidos os pedidos de aprove...
# 7090      Qual lei compôs a lei da criação da fundação ?
# 11268                   Qual a duração média de um set ?
#
#                                                sentencas
# 3101   [['Como a CPU [MASK] as instruções de um progr...
# 11909  [['Em quais matérias o aluno especial não pode...
# 14056  [['Quando devem ser [MASK] os pedidos de aprov...
# 7090   [['Qual lei [MASK] a lei da criação da fundaçã...
# 11268  [['Qual a duração média de um [MASK] ?', 'dout...

# %%
lista_documentos_perturbados_pos.sample(5)
# Out:
#                                              id  \
# 8515   e5fb7004194c4effbe41d3fca32ddff2_pert_15
# 2746    3b7293145a384882b3fd99feb0310c8f_pert_6
# 7422    75e60c95e8c04286adbca511f0660e82_pert_2
# 11488   4a9d7e7b04f0430b9f82cef937ae6e61_pert_8
# 3017   5b5f263d3c1546ddaee84a1a848d2704_pert_17
#
#                                            pos_documento
# 8515   [[['Para', 'quem', 'começar', 'a', 'renovação'...
# 2746   [[['O', 'que', 'era', 'o', 'banho', 'analítico...
# 7422   [[['Com', 'quem', 'a', 'Facom', 'possui', 'par...
# 11488  [[['O', 'que', 'os', 'professors', 'no', 'Rein...
# 3017   [[['O', 'que', 'é', 'crença', '?'], ['PRON', '...

# %% [markdown]
# #### Corrigir os tipos de colunas dos dados perturbados e POS
#
# Em dados perturbados:
# - coluna 1 - `perturbado` carregadas do arquivo vem como string e não como lista.
# - coluna 3 - `sentencas` carregadas do arquivo vem como string e não como lista.
#
# Em dados perturbados pos:
# - coluna 1 - `pos_documento` carregadas do arquivo vem como string e não como lista.

# %%
# Import das bibliotecas.
import ast # Biblioteca para conversão de string em lista

# Verifica se o tipo da coluna não é list e converte
lista_documentos_perturbados["perturbado"] = lista_documentos_perturbados["perturbado"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)
lista_documentos_perturbados["sentencas"] = lista_documentos_perturbados["sentencas"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

lista_documentos_perturbados_pos["pos_documento"] = lista_documentos_perturbados_pos["pos_documento"].apply(lambda x: ast.literal_eval(x) if type(x)!=list else x)

logging.info("TERMINADO CORREÇÃO PERTURBADO: {}.".format(len(lista_documentos_perturbados)))
logging.info("TERMINADO CORREÇÃO PERTURBADO POS: {}.".format(len(lista_documentos_perturbados_pos)))
# Out:
# 2022-03-18 12:51:03,563 : INFO : TERMINADO CORREÇÃO PERTURBADO: 18000.
# 2022-03-18 12:51:03,565 : INFO : TERMINADO CORREÇÃO PERTURBADO POS: 18000.

# %% [markdown]
# ### 3.2.5 Agrupar os dados originais e perturbados

# %%
# Import das bibliotecas.
import ast
from tqdm.notebook import tqdm as tqdm_notebook

print("Processando",len(lista_documentos_originais),"documentos originais")

lista_documentos_agrupados = []

# Barra de progresso dos documentos
lista_documentos_originais_bar = tqdm_notebook(lista_documentos_originais.iterrows(), desc=f"Documentos", unit=f" documento", total=len(lista_documentos_originais))

# Percorre os documentos
for i, linha_documento in lista_documentos_originais_bar: 
  #if i < 2:
    #print("linha_documento:",linha_documento)
    # Recupera o id do documento
    id_documento = linha_documento[0]     
    #print("id_documento:",id_documento)     
 
    # Carrega a lista das sentenças do documento
    lista_sentenca_documento = linha_documento[1]    
    #print("\nlista_sentenca_documento:",lista_sentenca_documento)
    #print("len(lista_sentenca_documento):",len(lista_sentenca_documento)) 

    # Adiciona o original a lista dos dados agrupados, considerando como coerente(1)
    lista_documentos_agrupados.append([id_documento, lista_sentenca_documento, linha_documento[2], 1])
  
    # Percorre os documentos perturbados apartir do original
    for j in range(0, MELHOR_DOCUMENTOS_PERTURBADOS):

      # Id do documento perturbado
      id_perturbado = str(id_documento) + "_pert_" + str(j)

      # localiza o documento perturbado 
      documento_perturbado = lista_documentos_perturbados.loc[lista_documentos_perturbados['id']==id_perturbado].values[0]
      # Recupera a sentença do documento perturbado
      lista_perturbado = documento_perturbado[1]
          
      # Adiciona o perturbado a lista dos dados agrupados considerando como incoerente(0)
      lista_documentos_agrupados.append([id_perturbado, lista_perturbado, documento_perturbado[2], 0])    

logging.info("TERMINADO AGRUPAMENTO: {}.".format(len(lista_documentos_agrupados)))
# Out:
# Processando 900 documentos originais
# Documentos:   0%|          | 0/900 [00:00<?, ? documento/s]
# 2022-03-18 12:51:32,060 : INFO : TERMINADO AGRUPAMENTO: 18900.

# %% [markdown]
# Converte em um dataframe

# %%
# Cria o dataframe da lista
dflista_documentos_agrupados = pd.DataFrame(lista_documentos_agrupados, columns = ["id","sentencas","documento","classe"])

# %%
# Corrige os tipos dos dados da lista agrupada
tipos = {"id": str, "sentencas": object, "documento": str, "classe": int}

dflista_documentos_agrupados = dflista_documentos_agrupados.astype(tipos)

# %%
dflista_documentos_agrupados.sample(5)
# Out:
#                                              id  \
# 930     59486cdac8c94e37898e004c62e4047a_pert_5
# 11382          e59606c41a424b57992a7da4920dd4b6
# 18507   1239bbf8a6b2479390bc55f05e1f2835_pert_5
# 5629    9f9aef06261e43478d3025740ed4cc92_pert_0
# 15575  1133c29b5e0640b29263e5b1f194c2e9_pert_13
#
#                                                sentencas  \
# 930    [O que a metodologia da auto-aprendizagem agra...
# 11382  [Em qual ano de curso se dá o estágio sanduíche?]
# 18507      [o que deverá descobrir o plano de estudos ?]
# 5629   [Onde continua um destaque para a engenharia d...
# 15575  [Pelo que os avanços da informática eram ados ...
#
#                                                documento  classe
# 930    O que a metodologia da auto-aprendizagem agrad...       0
# 11382    Em qual ano de curso se dá o estágio sanduíche?       1
# 18507        o que deverá descobrir o plano de estudos ?       0
# 5629   Onde continua um destaque para a engenharia de...       0
# 15575  Pelo que os avanços da informática eram ados e...       0

# %%
# Importa das bibliotecas
import pandas as pd

# Concatena as listas de documentos originais e perturbados
dflista_documentos_agrupados_pos = pd.concat([lista_documentos_originais_pos, lista_documentos_perturbados_pos])

logging.info("TERMINADO AGRUPAMENTO POS: {}.".format(len(dflista_documentos_agrupados_pos)))
# Out:
# 2022-03-18 12:51:32,150 : INFO : TERMINADO AGRUPAMENTO POS: 18900.

# %%
# Corrige os tipos dos dados da lista agrupada
tipos = {"id": str}

dflista_documentos_agrupados_pos = dflista_documentos_agrupados_pos.astype(tipos)

# %%
dflista_documentos_agrupados_pos.sample(5)
# Out:
#                                              id  \
# 14595  5ad7ec48d7b24069bebc0f3848d3b66d_pert_15
# 354            24c7b90289b34ed6b47f7f14fa388233
# 1227    2c5c585eebcf49e1b6ceb926a85cceef_pert_7
# 2011   1100cf4cf2b54d88bea2eac0e93df77e_pert_11
# 2344    f6d39f5220f947d4b625afdfa89f1acc_pert_4
#
#                                            pos_documento
# 14595  [[[Do, que, a, última, de, decisão, no, setor,...
# 354    [[[Qual, lei, alterou, a, lei, da, criação, da...
# 1227   [[[Por, quem, eram, ificadas, as, tabelas, log...
# 2011   [[[Em, que, tem, perdido, os, avanços, recente...
# 2344   [[[O, que, indicavam, as, áreas, não, furadas,...

# %% [markdown]
# ## 3.3 Carregando o resultado da melhor mensuração

# %%
MODELO_BERT = [MELHOR_MODELO_BERT]
TAMANHO_BERT = [MELHOR_TAMANHO_BERT]
MODELO = [MELHOR_MODELO] 
DOCUMENTOS_PERTURBADOS = [MELHOR_DOCUMENTOS_PERTURBADOS]
TOP_K_PREDICAO = [MELHOR_TOP_K_PREDICAO]
ESTRATEGIA_MEDIDA = [MELHOR_ESTRATEGIA_MEDIDA]
FILTRO_PALAVRAS = [MELHOR_FILTRO_PALAVRAS]  

dadosMensuracao = carregaMedidasCompactada(MELHOR_MODELO_BERT, 
                                 MELHOR_TAMANHO_BERT,
                                 MELHOR_MODELO,
                                 MELHOR_DOCUMENTOS_PERTURBADOS, 
                                 MELHOR_TOP_K_PREDICAO,
                                 MELHOR_ESTRATEGIA_MEDIDA,
                                 MELHOR_FILTRO_PALAVRAS)
# Out:
# Registros:  36000

# %%
dadosMensuracao.sample(5)
# Out:
#                    data                                   arquivo      ccos  \
# 25617  01/03/2022 01:39   cc9cefb6786542a682c0b99f26bd4358_pert_8  0.696407
# 13086  01/03/2022 01:39          ad7f31c0c7c942a4a00c6ab589794583  0.678604
# 14301  01/03/2022 01:39  6066b65076d145658e78b885fcf5496e_pert_10  0.605273
# 1553   01/03/2022 01:39  ecefc6cb3cc44bef8c606567e8ae756b_pert_16  0.722395
# 4229   01/03/2022 01:39  b9d4a99cc94e4df9b52a33db272f6360_pert_14  0.622914
#
#             ceuc         cman
# 25617  33.142518  1512.529609
# 13086  31.889677  1537.063644
# 14301  37.284840  1786.564582
# 1553   30.227405  1424.791667
# 4229   34.384428  1590.341896

# %% [markdown]
# ### Separa os documentos e remove as repetições

# %%
def separaDocumentos(dadosMedida):
  
  # Separa os originais
  dfOriginalMedida = dadosMedida.loc[dadosMedida['arquivo'].str.contains('pert')==False]
  # Remove os duplicados
  dfOriginalMedida = dfOriginalMedida.drop_duplicates(subset=['arquivo'])
  print('Registros: ', len(dfOriginalMedida))

  # Separa os perturbados
  dfPerturbadoMedida = dadosMedida.loc[dadosMedida['arquivo'].str.contains('pert')==True]
  # Remove os duplicados
  dfPerturbadoMedida = dfPerturbadoMedida.drop_duplicates(subset=['arquivo'])
  print('Registros: ', len(dfPerturbadoMedida))

  return dfOriginalMedida, dfPerturbadoMedida

# %%
dfOriginalMedidaBERT, dfPerturbadoMedidaBERT = separaDocumentos(dadosMensuracao)
# Out:
# Registros:  900
# Registros:  18000

# %% [markdown]
# ### Organiza os pares de documentos

# %%
def organizaParesDocumentos(dfOriginalMedida, dfPerturbadoMedida):

  # Import das bibliotecas.
  import pandas as pd

  listaParesDocumentosMedidas = []
  # Refaz os pares de documentos
  for i, linha1 in dfOriginalMedida.iterrows():
    
    for j in range(0,MELHOR_DOCUMENTOS_PERTURBADOS):
      
      nome_arquivo_perturbado = str(linha1['arquivo']) + "_pert_" + str(j)
      
      docperturbado = dfPerturbadoMedida.loc[dfPerturbadoMedida['arquivo'] == nome_arquivo_perturbado]

      listaParesDocumentosMedidas.append(
                                      [linha1['data'], 
                                       linha1['arquivo'],	
                                       linha1['ccos'], 
                                       linha1['ceuc'], 
                                       linha1['cman'],
                                       
                                       docperturbado['data'].values[0], 
                                       docperturbado['arquivo'].values[0],	
                                       docperturbado['ccos'].values[0], 
                                       docperturbado['ceuc'].values[0], 
                                       docperturbado['cman'].values[0] ],)
      
  print('Registros antes:', len(listaParesDocumentosMedidas))

  dfListaParesDocumentosMedidas = pd.DataFrame(listaParesDocumentosMedidas, columns=('dataDO', 'idDO','ccosDO', 'ceucDO', 'cmanDO', 'dataPert', 'idPert', 'ccosPert', 'ceucPert', 'cmanPert')) 
  
  print('Registros depois:', len(dfListaParesDocumentosMedidas))

  return dfListaParesDocumentosMedidas

# %%
dfListaParesDocumentosMedidasBERT = organizaParesDocumentos(dfOriginalMedidaBERT, dfPerturbadoMedidaBERT)
# Out:
# Registros antes: 18000
# Registros depois: 18000

# %%
dfListaParesDocumentosMedidasBERT.sample(5)
# Out:
#                  dataDO                              idDO    ccosDO  \
# 2667   01/03/2022 01:39  1dae3fc8d01144af82a247679e1698e3  0.641070
# 17116  01/03/2022 01:39  bb7dc667337b4cf2af309d60a1f1ecb2  0.673822
# 13488  01/03/2022 01:39  6195e07726c44dfdb5db36360e8f6ebd  0.695677
# 9903   01/03/2022 01:39  3d263b97f9ee48b195790dd190d80224  0.779584
# 8308   01/03/2022 01:39  a5cafcd0bbbd4c74bb60de2f810db23b  0.707026
#
#           ceucDO       cmanDO          dataPert  \
# 2667   35.450508  1636.929956  01/03/2022 01:39
# 17116  31.234112  1513.100107  01/03/2022 01:39
# 13488  30.159805  1438.167636  01/03/2022 01:39
# 9903   23.836351  1153.175037  01/03/2022 01:39
# 8308   30.135051  1450.722400  01/03/2022 01:39
#
#                                          idPert  ccosPert   ceucPert  \
# 2667    1dae3fc8d01144af82a247679e1698e3_pert_7  0.658819  35.735585
# 17116  bb7dc667337b4cf2af309d60a1f1ecb2_pert_16  0.678064  32.265917
# 13488   6195e07726c44dfdb5db36360e8f6ebd_pert_8  0.690028  32.043951
# 9903    3d263b97f9ee48b195790dd190d80224_pert_3  0.738437  26.384783
# 8308    a5cafcd0bbbd4c74bb60de2f810db23b_pert_8  0.679746  31.410085
#
#           cmanPert
# 2667   1621.729187
# 17116  1535.620230
# 13488  1493.123502
# 9903   1272.343286
# 8308   1512.034985

# %%
lista_documentos_originais.sample(5)
# Out:
#                                    id  \
# 128  33c59ddc361a4288b6594f2152db7b9d
# 173  db2a4c7266bf44d6ab07d90227c1312b
# 758  36ae775a973e4b2db6c200e972a98b83
# 615  f3a38e6e0cb6480bac4b6661a9558acc
# 210  63a1241f10134c59a6f7d6f70f6e043a
#
#                                              sentencas  \
# 128  [Como podemos armazenar números maiores na mem...
# 173                 [Quais são os componentes da CPU?]
# 758  [Para que cada profissional tem um papel nas o...
# 615  [Quando o acadêmico em regime de exercícios do...
# 210  [Quantas instruções dos programas de computado...
#
#                                              documento
# 128  Como podemos armazenar números maiores na memó...
# 173                   Quais são os componentes da CPU?
# 758  Para que cada profissional tem um papel nas or...
# 615  Quando o acadêmico em regime de exercícios dom...
# 210  Quantas instruções dos programas de computador...

# %% [markdown]
# ## 3.4 Estatísticas das Medidas

# %% [markdown]
# ### Listas em pares

# %% [markdown]
# #### Listas de pares de documentos originais e perturbados medidos corretamente

# %%
# Lista os documentos medidos corretamente
def listaMedidaCorretamente(dfListaParesDocumentosMedidas, medida):
  listaRetorno = []  
  for i, linha in dfListaParesDocumentosMedidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + 'DO'] <= linha[ medida + 'Pert']:
        listaRetorno.append(linha['idDO'])        
        listaRetorno.append(linha['idPert'])
    else:
        # Medida de distância (euc, man)
        if linha[medida + 'DO'] <= linha[ medida + 'Pert']:
          listaRetorno.append(linha['idDO'])          
          listaRetorno.append(linha['idPert'])

  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaRetornoMedidoCorretamente = listaMedidaCorretamente(dfListaParesDocumentosMedidasBERT,"ccos")
print('listaRetornoMedidoCorretamente:', len(listaRetornoMedidoCorretamente))
# Out:
# listaRetornoMedidoCorretamente: 13340

# %% [markdown]
# #### Listas de pares de documentos originais e perturbados classificados incorretamente

# %%
# Lista os documentos medidos incorretamente
def listaMedidaIncorretamente(dfListaParesDocumentosMedidas, medida):
  listaRetorno = []  
  for i, linha in dfListaParesDocumentosMedidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == 'ccos':
      if linha[medida + 'DO'] < linha[ medida + 'Pert']:
        listaRetorno.append(linha['idDO'])        
        listaRetorno.append(linha['idPert'])
    else:
       # Medida de distância (euc, man)
       if linha[medida + 'DO'] > linha[ medida + 'Pert']:
          listaRetorno.append(linha['idDO'])          
          listaRetorno.append(linha['idPert'])


  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaRetornoMedidoIncorretamente = listaMedidaIncorretamente(dfListaParesDocumentosMedidasBERT,'ccos')
print('listaRetornoMedidoIncorretamente:', len(listaRetornoMedidoIncorretamente))
# Out:
# listaRetornoMedidoIncorretamente: 22660

# %% [markdown]
# #### Acertos das listas

# %%
total = len(listaRetornoMedidoCorretamente) + len(listaRetornoMedidoIncorretamente)
print("Total de documentos:", total)
print("Total de acertos   :", len(listaRetornoMedidoCorretamente))
print("Total de erros     :", len(listaRetornoMedidoIncorretamente))
print("Percentual acerto  :", len(listaRetornoMedidoCorretamente)/total)
# Out:
# Total de documentos: 36000
# Total de acertos   : 13340
# Total de erros     : 22660
# Percentual acerto  : 0.3705555555555556

# %% [markdown]
# #### Listas documentos originais e perturbados e suas medições sem repetições

# %% [markdown]
# Remove as duplicidades dos dados originais.

# %%
print("Com repetição:",len(listaRetornoMedidoCorretamente))
listaRetornoMedidoCorretamenteSemRepeticao = listaRetornoMedidoCorretamente.drop_duplicates(subset=['id'])
print("Sem repetição:", len(listaRetornoMedidoCorretamente))
# Out:
# Com repetição: 13340
# Sem repetição: 13340

# %% [markdown]
# Remove as duplicidades dos dados perturbados.

# %%
print("Com repetição:",len(listaRetornoMedidoIncorretamente))
listaRetornoMedidoIncorretamenteSemRepeticao = listaRetornoMedidoIncorretamente.drop_duplicates(subset=['id'])
print("Sem repetição:", len(listaRetornoMedidoIncorretamenteSemRepeticao))
# Out:
# Com repetição: 22660
# Sem repetição: 12178

# %% [markdown]
# #### Listas documentos originais e perturbados medidos corretamente

# %%
print("Documentos originais e perturbados medidos corretamente(CSm(DO) >= CSm(pertDO)):", len(listaRetornoMedidoCorretamente))
conta = 0
for i, linha in listaRetornoMedidoCorretamente.iterrows():
  conta = conta + 1
  if i < 100:    
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == linha["id"]]       
    if len(documento)!= 0:    
      print("   ", conta, documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Documentos originais e perturbados medidos corretamente(CSm(DO) >= CSm(pertDO)): 13340
#     1 Como pode ser definido um sistema de informação? 1
#     2 Como ciência ser definido um sistema de informação ? 0
#     3 Como pode ser definido um sistema de informação? 1
#     4 Como expressa ser definido um sistema de informação ? 0
#     5 Como pode ser definido um sistema de informação? 1
#     6 Como significado ser definido um sistema de informação ? 0
#     7 Como pode ser definido um sistema de informação? 1
#     8 Como age ser definido um sistema de informação ? 0
#     9 Como pode ser definido um sistema de informação? 1
#     10 Como devem ser definido um sistema de informação ? 0
#     11 Como pode ser definido um sistema de informação? 1
#     12 Como rede ser definido um sistema de informação ? 0
#     13 Como pode ser definido um sistema de informação? 1
#     14 Como essencial ser definido um sistema de informação ? 0
#     15 Como pode ser definido um sistema de informação? 1
#     16 Como evoluiu ser definido um sistema de informação ? 0
#     17 Como pode ser definido um sistema de informação? 1
#     18 Como geralmente ser definido um sistema de informação ? 0
#     19 Como pode ser definido um sistema de informação? 1
#     20 Como define ser definido um sistema de informação ? 0
#     21 Como pode ser definido um sistema de informação? 1
#     22 Como precisão ser definido um sistema de informação ? 0
#     23 O que as soluções tecnológicas automatizam? 1
#     24 O que as soluções tecnológicas derrotaram ? 0
#     25 O que as soluções tecnológicas automatizam? 1
#     26 O que as soluções tecnológicas recomenda ? 0
#     27 O que as soluções tecnológicas automatizam? 1
#     28 O que as soluções tecnológicas alcançar ? 0
#     29 O que as soluções tecnológicas automatizam? 1
#     30 O que as soluções tecnológicas derrotaram ? 0
#     31 O que as soluções tecnológicas automatizam? 1
#     32 O que as soluções tecnológicas Melhor ? 0
#     33 O que as soluções tecnológicas automatizam? 1
#     34 O que as soluções tecnológicas permaneceram ? 0
#     35 O que as soluções tecnológicas automatizam? 1
#     36 O que as soluções tecnológicas acabaram ? 0
#     37 O que as soluções tecnológicas automatizam? 1
#     38 O que as soluções tecnológicas fornecer ? 0
#     39 O que as soluções tecnológicas automatizam? 1
#     40 O que as soluções tecnológicas atrás ? 0
#     41 O que as soluções tecnológicas automatizam? 1
#     42 O que as soluções tecnológicas das ? 0
#     43 O que as soluções tecnológicas automatizam? 1
#     44 O que as soluções tecnológicas tocaram ? 0
#     45 O que as soluções tecnológicas automatizam? 1
#     46 O que as soluções tecnológicas tomaram ? 0
#     47 O que as soluções tecnológicas automatizam? 1
#     48 O que as soluções tecnológicas adicionais ? 0
#     49 O que as soluções tecnológicas automatizam? 1
#     50 O que as soluções tecnológicas tomaram ? 0
#     51 O que as soluções tecnológicas automatizam? 1
#     52 O que as soluções tecnológicas serviram ? 0
#     53 O que as soluções tecnológicas automatizam? 1
#     54 O que as soluções tecnológicas fará ? 0
#     55 O que as soluções tecnológicas automatizam? 1
#     56 O que as soluções tecnológicas incluíam ? 0
#     57 O que as soluções tecnológicas automatizam? 1
#     58 O que as soluções tecnológicas só ? 0
#     59 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     60 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação integrada ? 0
#     61 Qual um componente indispensável nas organizações? 1
#     62 Qual um exemplar indispensável nas organizações ? 0
#     63 Qual um componente indispensável nas organizações? 1
#     64 Qual um futuro indispensável nas organizações ? 0
#     65 Qual um componente indispensável nas organizações? 1
#     66 Qual um componente indispensável nas sementes ? 0
#     67 Qual um componente indispensável nas organizações? 1
#     68 Qual um dia indispensável nas organizações ? 0
#     69 Em que se concentram as responsabilidades do analista de sistemas? 1
#     70 Em que se descreveu as responsabilidades do analista de sistemas ? 0
#     71 Em que se concentram as responsabilidades do analista de sistemas? 1
#     72 Em que se expressar as responsabilidades do analista de sistemas ? 0
#     73 Em que se concentram as responsabilidades do analista de sistemas? 1
#     74 Em que se localizadas as responsabilidades do analista de sistemas ? 0
#     75 Em que se concentram as responsabilidades do analista de sistemas? 1
#     76 Em que se baseado as responsabilidades do analista de sistemas ? 0
#     77 Em que se concentram as responsabilidades do analista de sistemas? 1
#     78 Em que se vem as responsabilidades do analista de sistemas ? 0
#     79 Em que se concentram as responsabilidades do analista de sistemas? 1
#     80 Em que se revelam as responsabilidades do analista de sistemas ? 0
#     81 Em que se concentram as responsabilidades do analista de sistemas? 1
#     82 Em que se afirmam as responsabilidades do analista de sistemas ? 0
#     83 Em que se concentram as responsabilidades do analista de sistemas? 1
#     84 Em que se na as responsabilidades do analista de sistemas ? 0
#     85 Em que se concentram as responsabilidades do analista de sistemas? 1
#     86 Em que se existem as responsabilidades do analista de sistemas ? 0
#     87 Em que se concentram as responsabilidades do analista de sistemas? 1
#     88 Em que se joga as responsabilidades do analista de sistemas ? 0
#     89 Em que se concentram as responsabilidades do analista de sistemas? 1
#     90 Em que se vis as responsabilidades do analista de sistemas ? 0
#     91 Em que se concentram as responsabilidades do analista de sistemas? 1
#     92 Em que se destacou as responsabilidades do analista de sistemas ? 0
#     93 Em que se concentram as responsabilidades do analista de sistemas? 1
#     94 Em que se substitui as responsabilidades do analista de sistemas ? 0
#     95 Em que se concentram as responsabilidades do analista de sistemas? 1
#     96 Em que se incluíram as responsabilidades do analista de sistemas ? 0
#     97 Em que se concentram as responsabilidades do analista de sistemas? 1
#     98 Em que se determina as responsabilidades do analista de sistemas ? 0
#     99 Em que se concentram as responsabilidades do analista de sistemas? 1
#     100 Em que se lugar as responsabilidades do analista de sistemas ? 0

# %% [markdown]
# #### Listas documentos originais e perturbados medidos incorretamente

# %%
print("Documentos originais e perturbados classificados incorretamente(CSm(DO) < CSm(pertDO)):", len(listaRetornoMedidoIncorretamente))
conta = 0
for i, linha in listaRetornoMedidoIncorretamente.iterrows():
  conta = conta + 1
  if i < 100:    
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == linha["id"]]       
    if len(documento)!= 0:    
      print("   ", conta, documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Documentos originais e perturbados classificados incorretamente(CSm(DO) < CSm(pertDO)): 22660
#     1 Como pode ser definido um sistema de informação? 1
#     2 Como iria ser definido um sistema de informação ? 0
#     3 Como pode ser definido um sistema de informação? 1
#     4 Como pode ser parte um sistema de informação ? 0
#     5 Como pode ser definido um sistema de informação? 1
#     6 Como pode ser futuro um sistema de informação ? 0
#     7 Como pode ser definido um sistema de informação? 1
#     8 Como pode ser essa um sistema de informação ? 0
#     9 Como pode ser definido um sistema de informação? 1
#     10 Como pode ser emprestado um sistema de informação ? 0
#     11 Como pode ser definido um sistema de informação? 1
#     12 Como pode ser coberto um sistema de informação ? 0
#     13 Como pode ser definido um sistema de informação? 1
#     14 Como pode ser controlado um sistema de informação ? 0
#     15 Como pode ser definido um sistema de informação? 1
#     16 Como pode ser adaptado um sistema de informação ? 0
#     17 Como pode ser definido um sistema de informação? 1
#     18 Como pode ser atingido um sistema de informação ? 0
#     19 O que as soluções tecnológicas automatizam? 1
#     20 O que as soluções tecnológicas ainda ? 0
#     21 O que as soluções tecnológicas automatizam? 1
#     22 O que as soluções tecnológicas encontram ? 0
#     23 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     24 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação apresentada ? 0
#     25 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     26 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação chegou ? 0
#     27 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     28 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação travada ? 0
#     29 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     30 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação aliada ? 0
#     31 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     32 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação pesquisa ? 0
#     33 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     34 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação iniciada ? 0
#     35 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     36 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação perigosa ? 0
#     37 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     38 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação alta ? 0
#     39 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     40 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação alimenta ? 0
#     41 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     42 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação restrita ? 0
#     43 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     44 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação há ? 0
#     45 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     46 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação compreende ? 0
#     47 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     48 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação apresentada ? 0
#     49 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     50 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação Antiga ? 0
#     51 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     52 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação sonora ? 0
#     53 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     54 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação publicado ? 0
#     55 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     56 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação substancial ? 0
#     57 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     58 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação aguda ? 0
#     59 Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#     60 Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação relevantes ? 0
#     61 Qual um componente indispensável nas organizações? 1
#     62 Qual um componente indispensável nas nucleares ? 0
#     63 Qual um componente indispensável nas organizações? 1
#     64 Qual um judeu indispensável nas organizações ? 0
#     65 Qual um componente indispensável nas organizações? 1
#     66 Qual um Estado indispensável nas organizações ? 0
#     67 Qual um componente indispensável nas organizações? 1
#     68 Qual um sexto indispensável nas organizações ? 0
#     69 Qual um componente indispensável nas organizações? 1
#     70 Qual um componente indispensável nas clientes ? 0
#     71 Qual um componente indispensável nas organizações? 1
#     72 Qual um cronista indispensável nas organizações ? 0
#     73 Qual um componente indispensável nas organizações? 1
#     74 Qual um constante indispensável nas organizações ? 0
#     75 Qual um componente indispensável nas organizações? 1
#     76 Qual um componente indispensável nas seguintes ? 0
#     77 Qual um componente indispensável nas organizações? 1
#     78 Qual um componente indispensável nas nucleares ? 0
#     79 Qual um componente indispensável nas organizações? 1
#     80 Qual um componente indispensável nas instituições ? 0
#     81 Qual um componente indispensável nas organizações? 1
#     82 Qual um time indispensável nas organizações ? 0
#     83 Qual um componente indispensável nas organizações? 1
#     84 Qual um componente indispensável nas sistemas ? 0
#     85 Qual um componente indispensável nas organizações? 1
#     86 Qual um componente indispensável nas poesia ? 0
#     87 Qual um componente indispensável nas organizações? 1
#     88 Qual um componente indispensável nas água ? 0
#     89 Qual um componente indispensável nas organizações? 1
#     90 Qual um adolescente indispensável nas organizações ? 0
#     91 Qual um componente indispensável nas organizações? 1
#     92 Qual um componente indispensável nas fontes ? 0
#     93 O que é análise de sistemas? 1
#     94 O que é teoria de sistemas ? 0
#     95 O que é análise de sistemas? 1
#     96 O que é análise de assuntos ? 0
#     97 O que é análise de sistemas? 1
#     98 O que é análise de prestígio ? 0
#     99 O que é análise de sistemas? 1
#     100 O que é recursos de sistemas ? 0

# %% [markdown]
# ### Listas

# %% [markdown]
# #### Lista de documentos originais(1-coerente) medidos corretamente(1-coerente)

# %%
def listaOriginalMedidoCorretamente(dfListaParesDocumentosMedidas, medida):
  listaRetorno = []  
  for i, linha in dfListaParesDocumentosMedidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + 'DO'] <= linha[ medida + 'Pert']:
        listaRetorno.append(linha['idDO'])                
    else:
        # Medida de distância (euc, man)
        if linha[medida + 'DO'] <= linha[ medida + 'Pert']:
          listaRetorno.append(linha['idDO'])
          
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaDocumentoOriginalMedidoCorretamente = listaOriginalMedidoCorretamente(dfListaParesDocumentosMedidasBERT, MELHOR_MEDIDA_GERAL_STR)
print('listaDocumentoOriginalMedidoCorretamente:', len(listaDocumentoOriginalMedidoCorretamente))
# Out:
# listaDocumentoOriginalMedidoCorretamente: 15774

# %%
print("Lista de documentos originais medidos corretamente(coerentes) (CSm(DO) >= CSm(pertDO)):", len(listaDocumentoOriginalMedidoCorretamente))
for i, documento in listaDocumentoOriginalMedidoCorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#    10774 - Em qual ano os alunos de colação de grau poderão ser matriculados em disciplinas sem que tenham cumprido todos os pré-requisitos? 1
#    10775 - Em qual ano os alunos de colação de grau poderão ser matriculados em disciplinas sem que tenham cumprido todos os pré-requisitos? 1
#    10776 - Em qual ano os alunos de colação de grau poderão ser matriculados em disciplinas sem que tenham cumprido todos os pré-requisitos? 1
#    10777 - Em qual ano os alunos de colação de grau poderão ser matriculados em disciplinas sem que tenham cumprido todos os pré-requisitos? 1
#    10778 - Em qual ano os alunos de colação de grau poderão ser matriculados em disciplinas sem que tenham cumprido todos os pré-requisitos? 1
#    10779 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10780 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10781 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10782 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10783 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10784 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10785 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10786 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10787 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10788 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10789 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10790 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10791 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10792 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10793 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10794 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10795 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10796 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10797 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10798 - O que deve ser respeitado na inscrição das disciplinas? 1
#    10799 - Quais as fases de renovação de matrícula? 1
#    10800 - Quais as fases de renovação de matrícula? 1
#    10801 - Quais as fases de renovação de matrícula? 1
#    10802 - Quais as fases de renovação de matrícula? 1
#    10803 - Quais as fases de renovação de matrícula? 1
#    10804 - Quais as fases de renovação de matrícula? 1
#    10805 - Quais as fases de renovação de matrícula? 1
#    10806 - Quais as fases de renovação de matrícula? 1
#    10807 - Quais as fases de renovação de matrícula? 1
#    10808 - Quais as fases de renovação de matrícula? 1
#    10809 - Quais as fases de renovação de matrícula? 1
#    10810 - Quais as fases de renovação de matrícula? 1
#    10811 - Quais as fases de renovação de matrícula? 1
#    10812 - Quais as fases de renovação de matrícula? 1
#    10813 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10814 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10815 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10816 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10817 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10818 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10819 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10820 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10821 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10822 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10823 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10824 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10825 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10826 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10827 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10828 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10829 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10830 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10831 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10832 - Quando a renovação de matrícula é convertida em trancamento? 1
#    10833 - Quem aprova a validação da matrícula? 1
#    10834 - Quem aprova a validação da matrícula? 1
#    10835 - Quem aprova a validação da matrícula? 1
#    10836 - Quem aprova a validação da matrícula? 1
#    10837 - Quem aprova a validação da matrícula? 1
#    10838 - Quem aprova a validação da matrícula? 1
#    10839 - Quem aprova a validação da matrícula? 1
#    10840 - Quem aprova a validação da matrícula? 1
#    10841 - Quem aprova a validação da matrícula? 1
#    10842 - Quem aprova a validação da matrícula? 1
#    10843 - Quem aprova a validação da matrícula? 1
#    10844 - Quem aprova a validação da matrícula? 1
#    10845 - Quem aprova a validação da matrícula? 1
#    10846 - Quem aprova a validação da matrícula? 1
#    10847 - Quem aprova a validação da matrícula? 1
#    10848 - Quem aprova a validação da matrícula? 1
#    10849 - Quem aprova a validação da matrícula? 1
#    10850 - Quem aprova a validação da matrícula? 1
#    10851 - Quem aprova a validação da matrícula? 1
#    10852 - Quem aprova a validação da matrícula? 1
#    10853 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10854 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10855 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10856 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10857 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10858 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10859 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10860 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10861 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10862 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10863 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10864 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10865 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10866 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10867 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10868 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10869 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10870 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10871 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10872 - Quem deve apresentar o formulário de inscrição na confirmação de matrícula? 1
#    10873 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10874 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10875 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10876 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10877 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10878 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10879 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10880 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10881 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10882 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10883 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10884 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10885 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10886 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10887 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10888 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10889 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10890 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10891 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10892 - O ano letivo compreende quais períodos regulares de atividades? 1
#    10893 - O calendário acadêmico é aprovado por quem? 1
#    10894 - O calendário acadêmico é aprovado por quem? 1
#    10895 - O calendário acadêmico é aprovado por quem? 1
#    10896 - O calendário acadêmico é aprovado por quem? 1
#    10897 - O calendário acadêmico é aprovado por quem? 1
#    10898 - O calendário acadêmico é aprovado por quem? 1
#    10899 - O calendário acadêmico é aprovado por quem? 1
#    10900 - O calendário acadêmico é aprovado por quem? 1
#    10901 - O calendário acadêmico é aprovado por quem? 1
#    10902 - O calendário acadêmico é aprovado por quem? 1
#    10903 - O calendário acadêmico é aprovado por quem? 1
#    10904 - O calendário acadêmico é aprovado por quem? 1
#    10905 - O calendário acadêmico é aprovado por quem? 1
#    10906 - O calendário acadêmico é aprovado por quem? 1
#    10907 - O calendário acadêmico é aprovado por quem? 1
#    10908 - O calendário acadêmico é aprovado por quem? 1
#    10909 - O calendário acadêmico é aprovado por quem? 1
#    10910 - Quando são oferecidos os períodos letivos especiais? 1
#    10911 - Quando são oferecidos os períodos letivos especiais? 1
#    10912 - Quando são oferecidos os períodos letivos especiais? 1
#    10913 - Quando são oferecidos os períodos letivos especiais? 1
#    10914 - Quando são oferecidos os períodos letivos especiais? 1
#    10915 - Quando são oferecidos os períodos letivos especiais? 1
#    10916 - Quando são oferecidos os períodos letivos especiais? 1
#    10917 - Quando são oferecidos os períodos letivos especiais? 1
#    10918 - Quando são oferecidos os períodos letivos especiais? 1
#    10919 - Quando são oferecidos os períodos letivos especiais? 1
#    10920 - Quando são oferecidos os períodos letivos especiais? 1
#    10921 - Quando são oferecidos os períodos letivos especiais? 1
#    10922 - Quando são oferecidos os períodos letivos especiais? 1
#    10923 - Quando são oferecidos os períodos letivos especiais? 1
#    10924 - Quando são oferecidos os períodos letivos especiais? 1
#    10925 - Quando são oferecidos os períodos letivos especiais? 1
#    10926 - Quando são oferecidos os períodos letivos especiais? 1
#    10927 - Quando são oferecidos os períodos letivos especiais? 1
#    10928 - Quando são oferecidos os períodos letivos especiais? 1
#    10929 - Quando são oferecidos os períodos letivos especiais? 1
#    10930 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10931 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10932 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10933 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10934 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10935 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10936 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10937 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10938 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10939 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10940 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10941 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10942 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10943 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10944 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10945 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10946 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10947 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10948 - Quantos dias os períodos regulares de um ano letivo abrangem? 1
#    10949 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10950 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10951 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10952 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10953 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10954 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10955 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10956 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10957 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10958 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10959 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10960 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10961 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10962 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10963 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10964 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10965 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10966 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10967 - Quem estabelece os prazos para a efetivação das atividades acadêmicas? 1
#    10968 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10969 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10970 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10971 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10972 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10973 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10974 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10975 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10976 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10977 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10978 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10979 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10980 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10981 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10982 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10983 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10984 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10985 - Com o que será completada a carga horária se for constatada a falta para integralização curricular? 1
#    10986 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10987 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10988 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10989 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10990 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10991 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10992 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10993 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10994 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10995 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10996 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10997 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10998 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    10999 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    11000 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    11001 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    11002 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    11003 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    11004 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    11005 - O Colegiado de Curso poderá propor alterações na matriz curricular? 1
#    11006 - Qual a finalidade da elaboração do plano de estudos? 1
#    11007 - Qual a finalidade da elaboração do plano de estudos? 1
#    11008 - Qual a finalidade da elaboração do plano de estudos? 1
#    11009 - Qual a finalidade da elaboração do plano de estudos? 1
#    11010 - Qual a finalidade da elaboração do plano de estudos? 1
#    11011 - Qual a finalidade da elaboração do plano de estudos? 1
#    11012 - Qual a finalidade da elaboração do plano de estudos? 1
#    11013 - Qual a finalidade da elaboração do plano de estudos? 1
#    11014 - Qual a finalidade da elaboração do plano de estudos? 1
#    11015 - Qual a finalidade da elaboração do plano de estudos? 1
#    11016 - Qual a finalidade da elaboração do plano de estudos? 1
#    11017 - Qual a finalidade da elaboração do plano de estudos? 1
#    11018 - Qual a finalidade da elaboração do plano de estudos? 1
#    11019 - Qual a finalidade da elaboração do plano de estudos? 1
#    11020 - Qual a finalidade da elaboração do plano de estudos? 1
#    11021 - Qual a finalidade da elaboração do plano de estudos? 1
#    11022 - Qual a finalidade da elaboração do plano de estudos? 1
#    11023 - Qual a finalidade da elaboração do plano de estudos? 1
#    11024 - Qual a finalidade da elaboração do plano de estudos? 1
#    11025 - Qual a finalidade da elaboração do plano de estudos? 1
#    11026 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11027 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11028 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11029 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11030 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11031 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11032 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11033 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11034 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11035 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11036 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11037 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11038 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11039 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11040 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11041 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11042 - Quem elabora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular? 1
#    11043 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11044 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11045 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11046 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11047 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11048 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11049 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11050 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11051 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11052 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11053 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11054 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11055 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11056 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11057 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11058 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11059 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11060 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11061 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11062 - A quem o acadêmico deve ir para revisar suas avaliações acadêmicas? 1
#    11063 - Por quantos docentes deve ser composta a comissão? 1
#    11064 - Por quantos docentes deve ser composta a comissão? 1
#    11065 - Por quantos docentes deve ser composta a comissão? 1
#    11066 - Por quantos docentes deve ser composta a comissão? 1
#    11067 - Por quantos docentes deve ser composta a comissão? 1
#    11068 - Por quantos docentes deve ser composta a comissão? 1
#    11069 - Por quantos docentes deve ser composta a comissão? 1
#    11070 - Por quantos docentes deve ser composta a comissão? 1
#    11071 - Por quantos docentes deve ser composta a comissão? 1
#    11072 - Por quantos docentes deve ser composta a comissão? 1
#    11073 - Por quantos docentes deve ser composta a comissão? 1
#    11074 - Por quantos docentes deve ser composta a comissão? 1
#    11075 - Por quantos docentes deve ser composta a comissão? 1
#    11076 - Por quantos docentes deve ser composta a comissão? 1
#    11077 - Por quantos docentes deve ser composta a comissão? 1
#    11078 - Por quantos docentes deve ser composta a comissão? 1
#    11079 - Por quantos docentes deve ser composta a comissão? 1
#    11080 - Por quantos docentes deve ser composta a comissão? 1
#    11081 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11082 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11083 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11084 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11085 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11086 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11087 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11088 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11089 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11090 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11091 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11092 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11093 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11094 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11095 - Qual o prazo para o acadêmico requisitar revisão da avaliação acadêmica? 1
#    11096 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11097 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11098 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11099 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11100 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11101 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11102 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11103 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11104 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11105 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11106 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11107 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11108 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11109 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11110 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11111 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11112 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11113 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11114 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11115 - Quem será responsável por alterar a nota do aluno no Siscad? 1
#    11116 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11117 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11118 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11119 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11120 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11121 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11122 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11123 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11124 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11125 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11126 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11127 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11128 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11129 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11130 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11131 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11132 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11133 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11134 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11135 - O que acontece caso o candidato não compareça no prazo estabelecido em edital para matrícula? 1
#    11136 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11137 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11138 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11139 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11140 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11141 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11142 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11143 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11144 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11145 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11146 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11147 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11148 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11149 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11150 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11151 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11152 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11153 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11154 - Onde está mencionada a documentação que deve ser providenciada pelo candidato ingressante? 1
#    11155 - Ao que o abono de faltas deve obedecer? 1
#    11156 - Ao que o abono de faltas deve obedecer? 1
#    11157 - Ao que o abono de faltas deve obedecer? 1
#    11158 - Ao que o abono de faltas deve obedecer? 1
#    11159 - Ao que o abono de faltas deve obedecer? 1
#    11160 - Ao que o abono de faltas deve obedecer? 1
#    11161 - Ao que o abono de faltas deve obedecer? 1
#    11162 - Ao que o abono de faltas deve obedecer? 1
#    11163 - Ao que o abono de faltas deve obedecer? 1
#    11164 - Ao que o abono de faltas deve obedecer? 1
#    11165 - Ao que o abono de faltas deve obedecer? 1
#    11166 - Ao que o abono de faltas deve obedecer? 1
#    11167 - Ao que o abono de faltas deve obedecer? 1
#    11168 - Ao que o abono de faltas deve obedecer? 1
#    11169 - Ao que o abono de faltas deve obedecer? 1
#    11170 - Ao que o abono de faltas deve obedecer? 1
#    11171 - Ao que o abono de faltas deve obedecer? 1
#    11172 - Ao que o abono de faltas deve obedecer? 1
#    11173 - Ao que o abono de faltas deve obedecer? 1
#    11174 - Ao que o abono de faltas deve obedecer? 1
#    11175 - Qual o prazo para a recontagem de frequência? 1
#    11176 - Qual o prazo para a recontagem de frequência? 1
#    11177 - Qual o prazo para a recontagem de frequência? 1
#    11178 - Qual o prazo para a recontagem de frequência? 1
#    11179 - Qual o prazo para a recontagem de frequência? 1
#    11180 - Qual o prazo para a recontagem de frequência? 1
#    11181 - Qual o prazo para a recontagem de frequência? 1
#    11182 - Qual o prazo para a recontagem de frequência? 1
#    11183 - Qual o prazo para a recontagem de frequência? 1
#    11184 - Qual o prazo para a recontagem de frequência? 1
#    11185 - Qual o prazo para a recontagem de frequência? 1
#    11186 - Qual o prazo para a recontagem de frequência? 1
#    11187 - Qual o prazo para a recontagem de frequência? 1
#    11188 - Qual o prazo para a recontagem de frequência? 1
#    11189 - Qual o prazo para a recontagem de frequência? 1
#    11190 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11191 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11192 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11193 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11194 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11195 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11196 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11197 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11198 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11199 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11200 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11201 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11202 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11203 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11204 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11205 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11206 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11207 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11208 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11209 - Quando o professor da disciplina deve divulgar o número de presenças? 1
#    11210 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11211 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11212 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11213 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11214 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11215 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11216 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11217 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11218 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11219 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11220 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11221 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11222 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11223 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11224 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11225 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11226 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11227 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11228 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11229 - Quem controla e registra a frequência das atividades acadêmicas? 1
#    11230 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11231 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11232 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11233 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11234 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11235 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11236 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11237 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11238 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11239 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11240 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11241 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11242 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11243 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11244 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11245 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11246 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11247 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11248 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11249 - O turno matutino compreende as atividades realizadas em quais horas? 1
#    11250 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11251 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11252 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11253 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11254 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11255 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11256 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11257 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11258 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11259 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11260 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11261 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11262 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11263 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11264 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11265 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11266 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11267 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11268 - Onde são definidos os prazos para elaboração dos horários das aulas? 1
#    11269 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11270 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11271 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11272 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11273 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11274 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11275 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11276 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11277 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11278 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11279 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11280 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11281 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11282 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11283 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11284 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11285 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11286 - Quem a coordenação de curso consulta para elaborar o horário das aulas? 1
#    11287 - Quem elabora os horários das aulas? 1
#    11288 - Quem elabora os horários das aulas? 1
#    11289 - Quem elabora os horários das aulas? 1
#    11290 - Quem elabora os horários das aulas? 1
#    11291 - Quem elabora os horários das aulas? 1
#    11292 - Quem elabora os horários das aulas? 1
#    11293 - Quem elabora os horários das aulas? 1
#    11294 - Quem elabora os horários das aulas? 1
#    11295 - Quem elabora os horários das aulas? 1
#    11296 - Quem elabora os horários das aulas? 1
#    11297 - Quem elabora os horários das aulas? 1
#    11298 - Quem elabora os horários das aulas? 1
#    11299 - Quem elabora os horários das aulas? 1
#    11300 - Quem elabora os horários das aulas? 1
#    11301 - Quem elabora os horários das aulas? 1
#    11302 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11303 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11304 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11305 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11306 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11307 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11308 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11309 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11310 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11311 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11312 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11313 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11314 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11315 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11316 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11317 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11318 - Em quais casos o acadêmico pode trancar a matrícula nos dois primeiros períodos letivos? 1
#    11319 - Por quanto tempo a matrícula pode ser trancada? 1
#    11320 - Por quanto tempo a matrícula pode ser trancada? 1
#    11321 - Por quanto tempo a matrícula pode ser trancada? 1
#    11322 - Por quanto tempo a matrícula pode ser trancada? 1
#    11323 - Por quanto tempo a matrícula pode ser trancada? 1
#    11324 - Por quanto tempo a matrícula pode ser trancada? 1
#    11325 - Por quanto tempo a matrícula pode ser trancada? 1
#    11326 - Por quanto tempo a matrícula pode ser trancada? 1
#    11327 - Por quanto tempo a matrícula pode ser trancada? 1
#    11328 - Por quanto tempo a matrícula pode ser trancada? 1
#    11329 - Por quanto tempo a matrícula pode ser trancada? 1
#    11330 - Por quanto tempo a matrícula pode ser trancada? 1
#    11331 - Por quanto tempo a matrícula pode ser trancada? 1
#    11332 - Por quanto tempo a matrícula pode ser trancada? 1
#    11333 - Por quanto tempo a matrícula pode ser trancada? 1
#    11334 - Por quanto tempo a matrícula pode ser trancada? 1
#    11335 - Por quanto tempo a matrícula pode ser trancada? 1
#    11336 - Por quanto tempo a matrícula pode ser trancada? 1
#    11337 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11338 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11339 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11340 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11341 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11342 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11343 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11344 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11345 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11346 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11347 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11348 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11349 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11350 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11351 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11352 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11353 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11354 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11355 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11356 - O que o professor deve apresentar aos alunos na primeira aula? 1
#    11357 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11358 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11359 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11360 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11361 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11362 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11363 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11364 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11365 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11366 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11367 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11368 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11369 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11370 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11371 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11372 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11373 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11374 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11375 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11376 - Qual o prazo de aprovação do plano de ensino das disciplinas? 1
#    11377 - Quando os professores podem lançar no Siscad? 1
#    11378 - Quando os professores podem lançar no Siscad? 1
#    11379 - Quando os professores podem lançar no Siscad? 1
#    11380 - Quando os professores podem lançar no Siscad? 1
#    11381 - Quando os professores podem lançar no Siscad? 1
#    11382 - Quando os professores podem lançar no Siscad? 1
#    11383 - Quando os professores podem lançar no Siscad? 1
#    11384 - Quando os professores podem lançar no Siscad? 1
#    11385 - Quando os professores podem lançar no Siscad? 1
#    11386 - Quando os professores podem lançar no Siscad? 1
#    11387 - Quando os professores podem lançar no Siscad? 1
#    11388 - Quando os professores podem lançar no Siscad? 1
#    11389 - Quando os professores podem lançar no Siscad? 1
#    11390 - Quando os professores podem lançar no Siscad? 1
#    11391 - Quando os professores podem lançar no Siscad? 1
# ...
#    15569 - qual o número mínimo de alunos para se ter uma disciplina regular? 1
#    15570 - qual o número mínimo de alunos para se ter uma disciplina regular? 1
#    15571 - qual o número mínimo de alunos para se ter uma disciplina regular? 1
#    15572 - qual o número mínimo de alunos para se ter uma disciplina regular? 1
#    15573 - qual o número mínimo de alunos para se ter uma disciplina regular? 1
#    15574 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15575 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15576 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15577 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15578 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15579 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15580 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15581 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15582 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15583 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15584 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15585 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15586 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15587 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15588 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15589 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    15590 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15591 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15592 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15593 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15594 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15595 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15596 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15597 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15598 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15599 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15600 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15601 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15602 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15603 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15604 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15605 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15606 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15607 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15608 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15609 - qual a frequência mínima exigida para aprovação em uma disciplina? 1
#    15610 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15611 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15612 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15613 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15614 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15615 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15616 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15617 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15618 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15619 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15620 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15621 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15622 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15623 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15624 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    15625 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15626 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15627 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15628 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15629 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15630 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15631 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15632 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15633 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15634 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15635 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15636 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15637 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15638 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15639 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15640 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15641 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15642 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    15643 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15644 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15645 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15646 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15647 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15648 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15649 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15650 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15651 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15652 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15653 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15654 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15655 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15656 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15657 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15658 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15659 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15660 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15661 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15662 - como o aluno deve solicitar a revisão de sua frequência em uma disciplina? 1
#    15663 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15664 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15665 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15666 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15667 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15668 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15669 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15670 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15671 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15672 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15673 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15674 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15675 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15676 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15677 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15678 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15679 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    15680 - qual o período maximo de duração do trancamento? 1
#    15681 - qual o período maximo de duração do trancamento? 1
#    15682 - qual o período maximo de duração do trancamento? 1
#    15683 - qual o período maximo de duração do trancamento? 1
#    15684 - qual o período maximo de duração do trancamento? 1
#    15685 - qual o período maximo de duração do trancamento? 1
#    15686 - qual o período maximo de duração do trancamento? 1
#    15687 - qual o período maximo de duração do trancamento? 1
#    15688 - qual o período maximo de duração do trancamento? 1
#    15689 - qual o período maximo de duração do trancamento? 1
#    15690 - qual o período maximo de duração do trancamento? 1
#    15691 - qual o período maximo de duração do trancamento? 1
#    15692 - qual o período maximo de duração do trancamento? 1
#    15693 - qual o período maximo de duração do trancamento? 1
#    15694 - qual o período maximo de duração do trancamento? 1
#    15695 - qual o período maximo de duração do trancamento? 1
#    15696 - qual o período maximo de duração do trancamento? 1
#    15697 - qual o período maximo de duração do trancamento? 1
#    15698 - qual o período maximo de duração do trancamento? 1
#    15699 - qual o período maximo de duração do trancamento? 1
#    15700 - como faço para não perder o vínculo acadêmico? 1
#    15701 - como faço para não perder o vínculo acadêmico? 1
#    15702 - como faço para não perder o vínculo acadêmico? 1
#    15703 - como faço para não perder o vínculo acadêmico? 1
#    15704 - como faço para não perder o vínculo acadêmico? 1
#    15705 - como faço para não perder o vínculo acadêmico? 1
#    15706 - como faço para não perder o vínculo acadêmico? 1
#    15707 - como faço para não perder o vínculo acadêmico? 1
#    15708 - como faço para não perder o vínculo acadêmico? 1
#    15709 - como faço para não perder o vínculo acadêmico? 1
#    15710 - como faço para não perder o vínculo acadêmico? 1
#    15711 - como faço para não perder o vínculo acadêmico? 1
#    15712 - como faço para não perder o vínculo acadêmico? 1
#    15713 - como faço para não perder o vínculo acadêmico? 1
#    15714 - como faço para não perder o vínculo acadêmico? 1
#    15715 - como faço para não perder o vínculo acadêmico? 1
#    15716 - qual a carga horária mínima do encontro presencial? 1
#    15717 - qual a carga horária mínima do encontro presencial? 1
#    15718 - qual a carga horária mínima do encontro presencial? 1
#    15719 - qual a carga horária mínima do encontro presencial? 1
#    15720 - qual a carga horária mínima do encontro presencial? 1
#    15721 - qual a carga horária mínima do encontro presencial? 1
#    15722 - qual a carga horária mínima do encontro presencial? 1
#    15723 - qual a carga horária mínima do encontro presencial? 1
#    15724 - qual a carga horária mínima do encontro presencial? 1
#    15725 - qual a carga horária mínima do encontro presencial? 1
#    15726 - qual a carga horária mínima do encontro presencial? 1
#    15727 - qual a carga horária mínima do encontro presencial? 1
#    15728 - qual a carga horária mínima do encontro presencial? 1
#    15729 - qual a carga horária mínima do encontro presencial? 1
#    15730 - qual a carga horária mínima do encontro presencial? 1
#    15731 - qual a carga horária mínima do encontro presencial? 1
#    15732 - qual a carga horária mínima do encontro presencial? 1
#    15733 - qual a carga horária mínima do encontro presencial? 1
#    15734 - qual a carga horária mínima do encontro presencial? 1
#    15735 - qual a carga horária mínima do encontro presencial? 1
#    15736 - de quando é a resolução no 401? 1
#    15737 - o que a resolução no 401 estabelece? 1
#    15738 - o que a resolução no 401 estabelece? 1
#    15739 - o que a resolução no 401 estabelece? 1
#    15740 - o que a resolução no 401 estabelece? 1
#    15741 - o que a resolução no 401 estabelece? 1
#    15742 - o que a resolução no 401 estabelece? 1
#    15743 - o que a resolução no 401 estabelece? 1
#    15744 - o que a resolução no 401 estabelece? 1
#    15745 - o que a resolução no 401 estabelece? 1
#    15746 - o que a resolução no 401 estabelece? 1
#    15747 - o que a resolução no 401 estabelece? 1
#    15748 - o que a resolução no 401 estabelece? 1
#    15749 - o que a resolução no 401 estabelece? 1
#    15750 - o que a resolução no 401 estabelece? 1
#    15751 - o que a resolução no 401 estabelece? 1
#    15752 - o que a resolução no 401 estabelece? 1
#    15753 - o que a resolução no 401 estabelece? 1
#    15754 - o que a resolução no 401 estabelece? 1
#    15755 - o que a resolução no 401 estabelece? 1
#    15756 - existe lei sobre a transferência compulsória? 1
#    15757 - existe lei sobre a transferência compulsória? 1
#    15758 - existe lei sobre a transferência compulsória? 1
#    15759 - existe lei sobre a transferência compulsória? 1
#    15760 - existe lei sobre a transferência compulsória? 1
#    15761 - existe lei sobre a transferência compulsória? 1
#    15762 - existe lei sobre a transferência compulsória? 1
#    15763 - existe lei sobre a transferência compulsória? 1
#    15764 - existe lei sobre a transferência compulsória? 1
#    15765 - existe lei sobre a transferência compulsória? 1
#    15766 - existe lei sobre a transferência compulsória? 1
#    15767 - existe lei sobre a transferência compulsória? 1
#    15768 - existe lei sobre a transferência compulsória? 1
#    15769 - existe lei sobre a transferência compulsória? 1
#    15770 - existe lei sobre a transferência compulsória? 1
#    15771 - existe lei sobre a transferência compulsória? 1
#    15772 - existe lei sobre a transferência compulsória? 1
#    15773 - existe lei sobre a transferência compulsória? 1

# %% [markdown]
# #### Lista de documento originais(1-coerente) medidos incorretamente(0-incoerente)

# %%
def listaOriginalMedidoIncorretamente(dfListaParesDocumentosMedidas, medida):
  listaRetorno = []  
  for i, linha in dfListaParesDocumentosMedidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + 'DO'] > linha[ medida + 'Pert']:
        listaRetorno.append(linha['idDO'])                
    else:
        # Medida de distância (euc, man)
        if linha[medida + 'DO'] > linha[ medida + 'Pert']:
          listaRetorno.append(linha['idDO'])
          
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaDocumentoOriginalMedidoIncorretamente = listaOriginalMedidoIncorretamente(dfListaParesDocumentosMedidasBERT, MELHOR_MEDIDA_GERAL_STR)

print("Lista de documentos originais medidos incorretamente:",len(listaDocumentoOriginalMedidoIncorretamente))
# Out:
# Lista de documentos originais medidos incorretamente: 2226

# %%
print("Lista de documentos originais medidos incorretamente(incoerentes)(CSm(DO) < CSm(pertDO)):", len(listaDocumentoOriginalMedidoIncorretamente))
for i, documento in listaDocumentoOriginalMedidoIncorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos originais medidos incorretamente(incoerentes)(CSm(DO) < CSm(pertDO)): 2226
#    0 - Como pode ser definido um sistema de informação? 1
#    1 - Como pode ser definido um sistema de informação? 1
#    2 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    3 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    4 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    5 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    6 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    7 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    8 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    9 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    10 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    11 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    12 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    13 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    14 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    15 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    16 - Por que a preocupação com a coleta, armazenamento, processamento e transmissão da informação cresce? 1
#    17 - Qual um componente indispensável nas organizações? 1
#    18 - Qual um componente indispensável nas organizações? 1
#    19 - Qual um componente indispensável nas organizações? 1
#    20 - Qual um componente indispensável nas organizações? 1
#    21 - O que é análise de sistemas? 1
#    22 - O que é análise de sistemas? 1
#    23 - O que é análise de sistemas? 1
#    24 - O que é análise de sistemas? 1
#    25 - O que é análise de sistemas? 1
#    26 - O que é análise de sistemas? 1
#    27 - O que é análise de sistemas? 1
#    28 - O que é análise de sistemas? 1
#    29 - O que é análise de sistemas? 1
#    30 - Onde são executados os softwares gerados pelos profissionais da área? 1
#    31 - Onde são utilizadas as informações levantadas sobre uma empresa? 1
#    32 - Onde são utilizadas as informações levantadas sobre uma empresa? 1
#    33 - O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? 1
#    34 - O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? 1
#    35 - O que permite com que profissionais que não possuem educação superior compram o papel de analista de sistemas? 1
#    36 - Por que o analista de sistemas deve traduzir a necessidade do usuário? 1
#    37 - Quem desenvolve o programa traduzido da necessidade do usuário pelo analista de sistemas? 1
#    38 - Quem desenvolve o programa traduzido da necessidade do usuário pelo analista de sistemas? 1
#    39 - Por quem foi designada a profissão de tecnólogo em análise e desenvolvimento de sistemas? 1
#    40 - Por quem foi designada a profissão de tecnólogo em análise e desenvolvimento de sistemas? 1
#    41 - Qual ferramenta é fundamental em qualquer atividade empresarial? 1
#    42 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    43 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    44 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    45 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    46 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    47 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    48 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    49 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    50 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    51 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    52 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    53 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    54 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    55 - Por que o estágio é a mais procurada forma dentre as opções de atividade complementar de extensão? 1
#    56 - Quais alguns exemplos de atividades de extensão? 1
#    57 - Quais alguns exemplos de atividades de extensão? 1
#    58 - Quais alguns exemplos de atividades de extensão? 1
#    59 - Qual a mais famosa opção de atividade complementar de extensão? 1
#    60 - Qual a mais famosa opção de atividade complementar de extensão? 1
#    61 - Qual a mais famosa opção de atividade complementar de extensão? 1
#    62 - Qual a mais famosa opção de atividade complementar de extensão? 1
#    63 - Qual a mais famosa opção de atividade complementar de extensão? 1
#    64 - Qual a mais famosa opção de atividade complementar de extensão? 1
#    65 - Qual a mais famosa opção de atividade complementar de extensão? 1
#    66 - Qual o objetivo das atividades complementares de extensão? 1
#    67 - Qual o objetivo das atividades complementares de extensão? 1
#    68 - Qual o objetivo das atividades complementares de extensão? 1
#    69 - Qual o objetivo das atividades complementares de extensão? 1
#    70 - Qual o objetivo das atividades complementares de extensão? 1
#    71 - Quantas horas de atividade complementar os estudantes de licenciatura precisam realizar? 1
#    72 - O que significa conhecer outras coisas fora do ambiente de ensino acadêmico? 1
#    73 - Qual a principal vantagem das atividades complementares? 1
#    74 - Qual a principal vantagem das atividades complementares? 1
#    75 - Qual a principal vantagem das atividades complementares? 1
#    76 - Qual a principal vantagem das atividades complementares? 1
#    77 - Com o que as atividades complementares contribuem? 1
#    78 - O que quer dizer quando um professor opta por avaliar a sua matéria através de seminários ao invés de provas? 1
#    79 - O que quer dizer quando um professor opta por avaliar a sua matéria através de seminários ao invés de provas? 1
#    80 - Qual o objetivo das ativdades complementares? 1
#    81 - Qual o objetivo das ativdades complementares? 1
#    82 - Qual o objetivo das ativdades complementares? 1
#    83 - O que é necessário apresentar para comprovar a participação em um evento? 1
#    84 - O que é necessário apresentar para comprovar a participação em um evento? 1
#    85 - O que é necessário apresentar para comprovar a participação em um evento? 1
#    86 - Qual o valor de um crédito na maioria das universidades? 1
#    87 - Qual o valor de um crédito na maioria das universidades? 1
#    88 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade exige 30 créditos? 1
#    89 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade exige 30 créditos? 1
#    90 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade exige 30 créditos? 1
#    91 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade exige 30 créditos? 1
#    92 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade exige 30 créditos? 1
#    93 - Qual uma semelhança entre o ensino médio e faculdade? 1
#    94 - Qual uma semelhança entre o ensino médio e faculdade? 1
#    95 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    96 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    97 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    98 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    99 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    100 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    101 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    102 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    103 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    104 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    105 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    106 - Compreender diferentes formas de pesquisa nos ajudam com o quê? 1
#    107 - Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#    108 - Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#    109 - Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#    110 - Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#    111 - Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#    112 - Por que aprender diversas metodologias, sistemas e análise e outros meios de guiar um estudo é tão importante? 1
#    113 - Para que os alunos realizam atividades complementares? 1
#    114 - Para que os alunos realizam atividades complementares? 1
#    115 - O ensino superior é composto por quais cursos? 1
#    116 - Em que ano o ENEM registrou 9,2 milhões de escritos? 1
#    117 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    118 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    119 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    120 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    121 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    122 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    123 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    124 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    125 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    126 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    127 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    128 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    129 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    130 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    131 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    132 - Por que em 2019 o ENEM registrou um número bastante considerável de inscritos? 1
#    133 - Como são utilizadas as versões mais modernas do ábaco? 1
#    134 - Por quem eram produzidas as tabelas logarítmicas? 1
#    135 - Por quem eram produzidas as tabelas logarítmicas? 1
#    136 - Por quem eram produzidas as tabelas logarítmicas? 1
#    137 - Por quem eram produzidas as tabelas logarítmicas? 1
#    138 - Qual era o uso original do ábaco? 1
#    139 - Qual era o uso original do ábaco? 1
#    140 - Qual era o uso original do ábaco? 1
#    141 - Qual era o uso original do ábaco? 1
#    142 - Qual era o uso original do ábaco? 1
#    143 - Qual era o uso original do ábaco? 1
#    144 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    145 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    146 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    147 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    148 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    149 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    150 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    151 - Qual foi a primeira ferramenta conhecida para a computação? 1
#    152 - Quantas regras Pānini utilizou para formular a gramática de Sânscrito? 1
#    153 - Quem inventou o logaritmo? 1
#    154 - A quem era associado o termo computador? 1
#    155 - Em que eram empregados os computadores antes da década de 1920? 1
#    156 - Em que eram empregados os computadores antes da década de 1920? 1
#    157 - Em que eram empregados os computadores antes da década de 1920? 1
#    158 - Em que eram empregados os computadores antes da década de 1920? 1
#    159 - Em que eram empregados os computadores antes da década de 1920? 1
#    160 - Em que eram empregados os computadores antes da década de 1920? 1
#    161 - Quando o termo máquina computacional perdeu espaço para o termo computador? 1
#    162 - Quando o termo máquina computacional perdeu espaço para o termo computador? 1
#    163 - Ao que a ciência da computação contribuiu? 1
#    164 - Ao que a ciência da computação contribuiu? 1
#    165 - Ao que a ciência da computação contribuiu? 1
#    166 - Ao que a ciência da computação contribuiu? 1
#    167 - Ao que a ciência da computação contribuiu? 1
#    168 - Ao que a ciência da computação contribuiu? 1
#    169 - Quais disciplinas estão fora do contexto da ciência da computação? 1
#    170 - Quais disciplinas estão fora do contexto da ciência da computação? 1
#    171 - Quais disciplinas estão fora do contexto da ciência da computação? 1
#    172 - Quais disciplinas estão fora do contexto da ciência da computação? 1
#    173 - Quais disciplinas estão fora do contexto da ciência da computação? 1
#    174 - Quais disciplinas estão fora do contexto da ciência da computação? 1
#    175 - Quem é considerado o autor da frase ”Ciência da Computação tem tanto a ver com o computador como a astronomia com o telescópio […]"? 1
#    176 - Quem é considerado o autor da frase ”Ciência da Computação tem tanto a ver com o computador como a astronomia com o telescópio […]"? 1
#    177 - O que Claude Shannon desenvolveu no artigo A Mathematical Theory of Communication? 1
#    178 - O que Claude Shannon desenvolveu no artigo A Mathematical Theory of Communication? 1
#    179 - Quais áreas são fundamentadas no conteúdo da teoria da informação? 1
#    180 - O que é ciência da computação? 1
#    181 - Quais estudos além dos algoritmos a ciência da computação envolve? 1
#    182 - Quais estudos além dos algoritmos a ciência da computação envolve? 1
#    183 - Quais estudos além dos algoritmos a ciência da computação envolve? 1
#    184 - Quais estudos além dos algoritmos a ciência da computação envolve? 1
#    185 - O que a área de ciência da computação sofre? 1
#    186 - O que a área de ciência da computação sofre? 1
#    187 - O que a área de ciência da computação sofre? 1
#    188 - O que a área de ciência da computação sofre? 1
#    189 - O que a área de ciência da computação sofre? 1
#    190 - O que o profissional de computação precisa ter? 1
#    191 - Como a ciência da computação se classifica enquanto ciência? 1
#    192 - Como a ciência da computação se classifica enquanto ciência? 1
#    193 - Como a ciência da computação se classifica enquanto ciência? 1
#    194 - Por que o dispositivo de Babbage se diferenciava de outros dispositivos? 1
#    195 - Quando o computador foi originalmente descrito? 1
#    196 - Quando o computador foi originalmente descrito? 1
#    197 - Quando o computador foi originalmente descrito? 1
#    198 - Quando o computador foi originalmente descrito? 1
#    199 - Quando o computador foi originalmente descrito? 1
#    200 - Quando o computador foi originalmente descrito? 1
#    201 - Quando o computador foi originalmente descrito? 1
#    202 - Quem é considerada a primeira programadora? 1
#    203 - Quem é considerada a primeira programadora? 1
#    204 - Quem é considerada a primeira programadora? 1
#    205 - Quando o livro Calculando com numerais hindus foi traduzido para o latim? 1
#    206 - Quem foi o primeiro a explicar o sistema de numeração hindu-arábico? 1
#    207 - Quem foi o primeiro a explicar o sistema de numeração hindu-arábico? 1
#    208 - Quem foi o primeiro a explicar o uso do 0? 1
#    209 - Quem foi o primeiro a explicar o uso do 0? 1
#    210 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    211 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    212 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    213 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    214 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    215 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    216 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    217 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    218 - Quem foi responsável pela difusão do sistema de numeração hindu-arábico no Oriente Médio? 1
#    219 - Os estudos da ciência da computação podem ser aplicadas em quais áreas? 1
#    220 - Quais as áreas que tem mais impactado a sociedade contemporânea? 1
#    221 - O que deve haver para que um cálculo possa ser realizado por um algoritmo sendo executado em um computador? 1
#    222 - O que deve haver para que um cálculo possa ser realizado por um algoritmo sendo executado em um computador? 1
#    223 - O que deve haver para que um cálculo possa ser realizado por um algoritmo sendo executado em um computador? 1
#    224 - O que deve haver para que um cálculo possa ser realizado por um algoritmo sendo executado em um computador? 1
#    225 - O que foi definido com a formalização de um algoritmo por Alan Turing e Alonzo Church? 1
#    226 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    227 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    228 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    229 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    230 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    231 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    232 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    233 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    234 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    235 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    236 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    237 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    238 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    239 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    240 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    241 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    242 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    243 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    244 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    245 - Qual teorema levou a definição de conceitos como recursividade e cálculo lambda? 1
#    246 - Com o que estão relacionados as inovações e aspectos teóricos da computação? 1
#    247 - Com o que estão relacionados as inovações e aspectos teóricos da computação? 1
#    248 - Com o que estão relacionados as inovações e aspectos teóricos da computação? 1
#    249 - Com o que estão relacionados as inovações e aspectos teóricos da computação? 1
#    250 - Com o que estão relacionados as inovações e aspectos teóricos da computação? 1
#    251 - Por que existem várias definições alternativas para a ciência da computação? 1
#    252 - Por que existem várias definições alternativas para a ciência da computação? 1
#    253 - A quem é credita a frase "Ciência é para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos"? 1
#    254 - A quem é credita a frase "Ciência é para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos"? 1
#    255 - A quem é credita a frase "Ciência é para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos"? 1
#    256 - A quem é credita a frase "Ciência é para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos"? 1
#    257 - Por que a ciência da computação é criticada? 1
#    258 - Por que a ciência da computação é criticada? 1
#    259 - Por que a ciência da computação é criticada? 1
#    260 - Por que a ciência da computação é criticada? 1
#    261 - Por que a ciência da computação é criticada? 1
#    262 - Por que a ciência da computação é criticada? 1
#    263 - Por que a ciência da computação é criticada? 1
#    264 - Por que a ciência da computação é criticada? 1
#    265 - Por que a ciência da computação é criticada? 1
#    266 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    267 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    268 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    269 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    270 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    271 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    272 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    273 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    274 - O que foi ilustrado pelo tear controlado por cartão perfurado? 1
#    275 - O que indicavam as áreas não furadas no tear controlado por cartão perfurado? 1
#    276 - O que indicavam as áreas não furadas no tear controlado por cartão perfurado? 1
#    277 - O que indicavam as áreas não furadas no tear controlado por cartão perfurado? 1
#    278 - O que indicavam as áreas não furadas no tear controlado por cartão perfurado? 1
#    279 - Quais informações podem ser representadas por uns e zeros? 1
#    280 - Quais informações podem ser representadas por uns e zeros? 1
#    281 - Quando foi publicada a álgebra booleana? 1
#    282 - Quem inventou o sistema de numeração binário? 1
#    283 - Quem inventou o sistema de numeração binário? 1
#    284 - Em que é utilizado o nome de Turing? 1
#    285 - Em que é utilizado o nome de Turing? 1
#    286 - Por que uma máquina que possui uma fita de tamanho infinito não pode ser construída? 1
#    287 - Por que uma máquina que possui uma fita de tamanho infinito não pode ser construída? 1
#    288 - Quando Turing cometeu suicídio? 1
#    289 - Quando Turing cometeu suicídio? 1
#    290 - Quando Turing cometeu suicídio? 1
#    291 - Quando Turing cometeu suicídio? 1
#    292 - Quando Turing cometeu suicídio? 1
#    293 - Quando Turing cometeu suicídio? 1
#    294 - À que Turing contribuiu? 1
#    295 - Como a ciência da computação é chamada em francês? 1
#    296 - Como a ciência da computação é chamada em francês? 1
#    297 - Como a ciência da computação é chamada em francês? 1
#    298 - Como a ciência da computação é chamada em francês? 1
#    299 - Como a ciência da computação é chamada em francês? 1
#    300 - Como a ciência da computação é chamada em francês? 1
#    301 - O termo informática é sinônimo de que em Portugal? 1
#    302 - O termo informática é sinônimo de que em Portugal? 1
#    303 - O termo informática é sinônimo de que em Portugal? 1
#    304 - O termo informática é sinônimo de que em Portugal? 1
#    305 - O termo informática é sinônimo de que em Portugal? 1
#    306 - O termo informática é sinônimo de que em Portugal? 1
#    307 - O termo informática é sinônimo de que em Portugal? 1
#    308 - O termo informática é sinônimo de que em Portugal? 1
#    309 - O termo informática é sinônimo de que em Portugal? 1
#    310 - O termo informática é sinônimo de que em Portugal? 1
#    311 - O termo informática é sinônimo de que em Portugal? 1
#    312 - O termo informática é sinônimo de que em Portugal? 1
#    313 - O termo informática é sinônimo de que em Portugal? 1
#    314 - O termo informática é sinônimo de que em Portugal? 1
#    315 - O termo informática é sinônimo de que em Portugal? 1
#    316 - O termo informática é sinônimo de que em Portugal? 1
#    317 - O termo informática é sinônimo de que em Portugal? 1
#    318 - O termo informática é sinônimo de que em Portugal? 1
#    319 - O termo informática é sinônimo de que em Portugal? 1
#    320 - Para que é usado o termo informática no inglês e no português? 1
#    321 - Como podemos armazenar números maiores na memória? 1
#    322 - Como é dividida a memória do computador? 1
#    323 - Como é dividida a memória do computador? 1
#    324 - Como é dividida a memória do computador? 1
#    325 - Como é dividida a memória do computador? 1
#    326 - Onde é feita parte da memória do computador? 1
#    327 - Onde é feita parte da memória do computador? 1
#    328 - Onde é feita parte da memória do computador? 1
#    329 - Qual a utilidade da memória? 1
#    330 - Qual a utilidade da memória? 1
#    331 - Qual a utilidade da memória? 1
#    332 - Qual a utilidade da memória? 1
#    333 - Qual a utilidade da memória? 1
#    334 - Qual a utilidade da memória? 1
#    335 - Qual a utilidade da memória? 1
#    336 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    337 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    338 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    339 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    340 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    341 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    342 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    343 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    344 - Quantos bits as posições de memória nos computadores modernos armazena? 1
#    345 - Quantos bytes em sequência geralmente são utilizados para armazenar números maiores? 1
#    346 - Quantos números um byte representa? 1
#    347 - Como era controlada a máquina de tecer números de Babbage? 1
#    348 - Como era controlada a máquina de tecer números de Babbage? 1
#    349 - Como era controlada a máquina de tecer números de Babbage? 1
#    350 - Quem inventou o tear mecânico? 1
#    351 - O que distingue o computador de outras máquinas? 1
#    352 - O que distingue o computador de outras máquinas? 1
#    353 - O que distingue o computador de outras máquinas? 1
#    354 - O que distingue o computador de outras máquinas? 1
#    355 - O que distingue o computador de outras máquinas? 1
#    356 - O que distingue o computador de outras máquinas? 1
#    357 - Qual a principal característica dos computadores de hoje em dia? 1
#    358 - Qual a principal característica dos computadores de hoje em dia? 1
#    359 - Qual a principal característica dos computadores de hoje em dia? 1
#    360 - Como é chamada a memória da CPU? 1
#    361 - Como é chamada a memória da CPU? 1
#    362 - Como é chamada a memória da CPU? 1
#    363 - O que a unidade de controle informa à ULA? 1
#    364 - O que é armazenado na unidade de controle? 1
#    365 - O que é armazenado na unidade de controle? 1
#    366 - O que é armazenado na unidade de controle? 1
#    367 - Onde a unidade de controle busca a informação que a ULA precisa? 1
#    368 - Onde a unidade de controle busca a informação que a ULA precisa? 1
#    369 - Onde a unidade de controle busca a informação que a ULA precisa? 1
#    370 - Onde geralmente fica a próxima instrução? 1
#    371 - Onde geralmente fica a próxima instrução? 1
#    372 - Para que servem os registradores? 1
#    373 - A quem foi aplicado o termo computador? 1
#    374 - O que é computador? 1
#    375 - O que é computador? 1
#    376 - O que é computador? 1
#    377 - O que é computador? 1
#    378 - O que é computador? 1
#    379 - O que é computador? 1
#    380 - O que é computador? 1
#    381 - O que é computador? 1
#    382 - O que é computador? 1
#    383 - O que é computador? 1
#    384 - O que é computador? 1
#    385 - O que é computador? 1
#    386 - O que é computador? 1
#    387 - O que é computador? 1
#    388 - O que é computador? 1
#    389 - O que é computador? 1
#    390 - Para que servem os sistemas embarcados? 1
#    391 - Para que servem os sistemas embarcados? 1
#    392 - Quais as formas mais comuns de computador em uso? 1
#    393 - Quais as formas mais comuns de computador em uso? 1
#    394 - Quais as formas mais comuns de computador em uso? 1
#    395 - Quais as formas mais comuns de computador em uso? 1
#    396 - Quais as formas mais comuns de computador em uso? 1
#    397 - Quais as formas mais comuns de computador em uso? 1
#    398 - Quais as formas mais comuns de computador em uso? 1
#    399 - Quais as formas mais comuns de computador em uso? 1
#    400 - Quais as formas mais comuns de computador em uso? 1
#    401 - Quais as formas mais comuns de computador em uso? 1
#    402 - Quais as formas mais comuns de computador em uso? 1
#    403 - Quem são os ícones da era da informação? 1
#    404 - Como a CPU executa as instruções de um programa? 1
#    405 - Como a CPU executa as instruções de um programa? 1
#    406 - Como a CPU executa as instruções de um programa? 1
#    407 - Em que o prolog é baseado? 1
#    408 - Em que o prolog é baseado? 1
#    409 - Em que o prolog é baseado? 1
#    410 - O que é linguagem de máquina? 1
#    411 - O que é linguagem de máquina? 1
#    412 - Qual linguagem de programação é parecida com a linguagem de máquina? 1
#    413 - Qual linguagem de programação é parecida com a linguagem de máquina? 1
#    414 - Qual linguagem de programação é parecida com a linguagem de máquina? 1
#    415 - Como eram gravadas as tabelas de multiplicação de John Napier? 1
#    416 - Como eram gravadas as tabelas de multiplicação de John Napier? 1
#    417 - Qual era o objetivo da máquina de pascal? 1
#    418 - Qual era o objetivo da máquina de pascal? 1
#    419 - Qual era o sonho de Gottfried? 1
#    420 - Qual era o sonho de Gottfried? 1
#    421 - Qual era o sonho de Gottfried? 1
#    422 - Qual era o sonho de Gottfried? 1
#    423 - Qual era o sonho de Gottfried? 1
#    424 - Quem inventou os logarítmos? 1
#    425 - Quem inventou os logarítmos? 1
#    426 - De quando eram os primeiros computadores? 1
#    427 - De quando eram os primeiros computadores? 1
#    428 - De quando eram os primeiros computadores? 1
#    429 - De quando eram os primeiros computadores? 1
#    430 - De quando eram os primeiros computadores? 1
#    431 - De quando eram os primeiros computadores? 1
#    432 - De quando eram os primeiros computadores? 1
#    433 - De quando eram os primeiros computadores? 1
#    434 - De quando eram os primeiros computadores? 1
#    435 - De quando eram os primeiros computadores? 1
#    436 - O que interconecta os setores do computador? 1
#    437 - Por quem foi proposta a arquitetura de von Neumann? 1
#    438 - Quais são os componentes da CPU? 1
#    439 - Quais são os componentes da CPU? 1
#    440 - Quais são os componentes da CPU? 1
#    441 - Quais são os componentes da CPU? 1
#    442 - Quais são os componentes da CPU? 1
#    443 - Quais são os componentes da CPU? 1
#    444 - Quais são os componentes da CPU? 1
#    445 - Quais são os componentes da CPU? 1
#    446 - Quais são os principais setores do computador? 1
#    447 - Quais são os principais setores do computador? 1
#    448 - Quais são os principais setores do computador? 1
#    449 - Quais são os principais setores do computador? 1
#    450 - Quais são os principais setores do computador? 1
#    451 - Quais são os principais setores do computador? 1
#    452 - Quais são os principais setores do computador? 1
#    453 - Quais são os principais setores do computador? 1
#    454 - Quais são os principais setores do computador? 1
#    455 - Quais são os principais setores do computador? 1
#    456 - Quantas sessões principais o computador possui? 1
#    457 - A quem Zuse tentou vender o Z1? 1
#    458 - A quem Zuse tentou vender o Z1? 1
#    459 - A quem Zuse tentou vender o Z1? 1
#    460 - A quem Zuse tentou vender o Z1? 1
#    461 - A quem Zuse tentou vender o Z1? 1
#    462 - A quem Zuse tentou vender o Z1? 1
#    463 - Como Zuse construiu o Z1? 1
#    464 - Como Zuse construiu o Z1? 1
#    465 - Como Zuse construiu o Z1? 1
#    466 - Como Zuse construiu o Z1? 1
#    467 - Como Zuse construiu o Z1? 1
#    468 - Como Zuse construiu o Z1? 1
#    469 - Como Zuse construiu o Z1? 1
#    470 - Como Zuse construiu o Z1? 1
#    471 - Como Zuse construiu o Z1? 1
#    472 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    473 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    474 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    475 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    476 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    477 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    478 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    479 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    480 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    481 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    482 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    483 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    484 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    485 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    486 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    487 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    488 - Em quantos segundos o Mark I conseguia multiplicar dois números de dez dígitos? 1
#    489 - Em que foi baseado o Mark I? 1
#    490 - Em que foi baseado o Mark I? 1
#    491 - Em que foi baseado o Mark I? 1
#    492 - Em que foi baseado o Mark I? 1
#    493 - Para que servia o ENIAC? 1
#    494 - Qual foi o primeiro computador a válvulas? 1
#    495 - Qual foi o primeiro computador a válvulas? 1
#    496 - Qual foi o primeiro computador a válvulas? 1
#    497 - Qual foi o primeiro computador a válvulas? 1
#    498 - Qual foi o primeiro computador a válvulas? 1
#    499 - Qual foi o primeiro computador a válvulas? 1
#    500 - Qual foi o primeiro computador a válvulas? 1
#    501 - Qual foi o primeiro computador a válvulas? 1
#    502 - Qual foi o primeiro computador a válvulas? 1
#    503 - Qual foi o primeiro computador a válvulas? 1
#    504 - Qual foi o primeiro computador a válvulas? 1
#    505 - Qual foi o primeiro computador a válvulas? 1
#    506 - Qual foi o primeiro computador a válvulas? 1
#    507 - Qual foi o primeiro computador a válvulas? 1
#    508 - Qual foi o primeiro computador a válvulas? 1
#    509 - Quando nasceram os computadores atuais? 1
#    510 - Quem criou o Mark I? 1
#    511 - Quem criou o Mark I? 1
#    512 - Quem criou o Mark I? 1
#    513 - Quem criou o Mark I? 1
#    514 - Como os primeiros processadores eram construídos? 1
#    515 - Como os primeiros processadores eram construídos? 1
#    516 - Como os primeiros processadores eram construídos? 1
#    517 - Como os primeiros processadores eram construídos? 1
#    518 - Como os primeiros processadores eram construídos? 1
#    519 - Como os primeiros processadores eram construídos? 1
#    520 - Como os primeiros processadores eram construídos? 1
#    521 - Como os primeiros processadores eram construídos? 1
#    522 - O que a unidade lógica e aritmética faz? 1
#    523 - O que a unidade lógica e aritmética faz? 1
#    524 - O que a unidade lógica e aritmética faz? 1
#    525 - O que é a unidade lógica e aritmética? 1
#    526 - Para que servem os pontos flutuantes? 1
#    527 - Para que servem os pontos flutuantes? 1
#    528 - Quais são os parâmetros da ULA? 1
#    529 - Quais são os parâmetros da ULA? 1
#    530 - Quais são os parâmetros da ULA? 1
#    531 - Quais são os parâmetros da ULA? 1
#    532 - Quais são os parâmetros da ULA? 1
#    533 - Quais são os parâmetros da ULA? 1
#    534 - Qual as tarefas do processador? 1
#    535 - Qual as tarefas do processador? 1
#    536 - Qual as tarefas do processador? 1
#    537 - Qual as tarefas do processador? 1
#    538 - Qual as tarefas do processador? 1
#    539 - Qual as tarefas do processador? 1
#    540 - Qual as tarefas do processador? 1
#    541 - Qual as tarefas do processador? 1
#    542 - Qual as tarefas do processador? 1
#    543 - Qual as tarefas do processador? 1
#    544 - Em que a máquina de Hollerith foi pioneira? 1
#    545 - Em que a máquina de Hollerith foi pioneira? 1
#    546 - Em que a máquina de Hollerith foi pioneira? 1
#    547 - Em que a máquina de Hollerith foi pioneira? 1
#    548 - Em que a máquina de Hollerith foi pioneira? 1
#    549 - Em que a máquina de Hollerith foi pioneira? 1
#    550 - Em que a máquina de Hollerith foi pioneira? 1
#    551 - Em que a máquina de Hollerith foi pioneira? 1
#    552 - Em que a máquina de Hollerith foi pioneira? 1
#    553 - Em que a máquina de Hollerith foi pioneira? 1
#    554 - Em que a máquina de Hollerith foi pioneira? 1
#    555 - Em que a máquina de Hollerith foi pioneira? 1
#    556 - Em que a máquina de Hollerith foi pioneira? 1
#    557 - Em que a máquina de Hollerith foi pioneira? 1
#    558 - Em que a máquina de Hollerith foi pioneira? 1
#    559 - Em que a máquina de Hollerith foi pioneira? 1
#    560 - Em que a máquina de Hollerith foi pioneira? 1
#    561 - Em que a máquina de Hollerith foi pioneira? 1
#    562 - Em que a máquina de Hollerith foi pioneira? 1
#    563 - Em que a máquina de Hollerith foi pioneira? 1
#    564 - Em que a máquina de Hollerith foi pioneira? 1
#    565 - Em que a máquina de Hollerith foi pioneira? 1
#    566 - Em que a máquina de Hollerith foi pioneira? 1
#    567 - Em que a máquina de Hollerith foi pioneira? 1
#    568 - Em que a máquina de Hollerith foi pioneira? 1
#    569 - Em que a máquina de Hollerith foi pioneira? 1
#    570 - Em que a máquina de Hollerith foi pioneira? 1
#    571 - Em que a máquina de Hollerith foi pioneira? 1
#    572 - Em que a máquina de Hollerith foi pioneira? 1
#    573 - Em que a máquina de Hollerith foi pioneira? 1
#    574 - Em que a máquina de Hollerith foi pioneira? 1
#    575 - Em que a máquina de Hollerith foi pioneira? 1
#    576 - Em que a máquina de Hollerith foi pioneira? 1
#    577 - Em que a máquina de Hollerith foi pioneira? 1
#    578 - O que Hollerith inventou? 1
#    579 - O que Hollerith inventou? 1
#    580 - O que Hollerith inventou? 1
#    581 - O que Hollerith inventou? 1
#    582 - O que Hollerith inventou? 1
#    583 - O que Hollerith inventou? 1
#    584 - O que Hollerith inventou? 1
#    585 - O que Hollerith inventou? 1
#    586 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    587 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    588 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    589 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    590 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    591 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    592 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    593 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    594 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    595 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    596 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    597 - Para quantos anos a máquina de Hollerith reduziu o tempo de processamento de dados? 1
#    598 - O que são dispositivos de entrada e saída? 1
#    599 - O que são dispositivos de entrada e saída? 1
#    600 - Quais são os dispositivos de entrada mais comuns em computadores pessoais modernos? 1
#    601 - Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#    602 - Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#    603 - Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#    604 - Quantas fases o processamento de dados de um sistema de computadores digital possui? 1
#    605 - Para que serve a fonte de energia? 1
#    606 - Quais tipos de interface o barramento pode utilizar? 1
#    607 - Quais tipos de interface o barramento pode utilizar? 1
#    608 - Como as instruções geralmente são executadas? 1
#    609 - O que são programas? 1
#    610 - O que são programas? 1
#    611 - Quantas instruções dos programas de computador possuem? 1
#    612 - Quantas instruções dos programas de computador possuem? 1
#    613 - Quem escreve as instruções para o computador? 1
#    614 - Quem escreve as instruções para o computador? 1
#    615 - Quem escreve as instruções para o computador? 1
#    616 - Quem escreve as instruções para o computador? 1
#    617 - Quem executa os programas? 1
#    618 - Como geralmente surge o primeiro emprego do engenheiro de computação? 1
#    619 - Como geralmente surge o primeiro emprego do engenheiro de computação? 1
#    620 - Em quais empresas o engenheiro da computação pode atuar? 1
#    621 - Em que a rápida mudança promovida pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação? 1
#    622 - Em que a rápida mudança promovida pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação? 1
#    623 - Em que a rápida mudança promovida pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação? 1
#    624 - Em que a rápida mudança promovida pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação? 1
#    625 - Em que a rápida mudança promovida pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação? 1
#    626 - Quando ocorre investimentos na linha de produção da indústra? 1
#    627 - Quando ocorre investimentos na linha de produção da indústra? 1
#    628 - Quando ocorre investimentos na linha de produção da indústra? 1
#    629 - Quando ocorre investimentos na linha de produção da indústra? 1
#    630 - Quando ocorre investimentos na linha de produção da indústra? 1
#    631 - Quando ocorre investimentos na linha de produção da indústra? 1
#    632 - Quando ocorre investimentos na linha de produção da indústra? 1
#    633 - Quando ocorre investimentos na linha de produção da indústra? 1
#    634 - Quando ocorre investimentos na linha de produção da indústra? 1
#    635 - Quem foi a pioneira em PBL no Brasil? 1
#    636 - Quem foi a pioneira em PBL no Brasil? 1
#    637 - Quanto dos sistemas de computação são conhecidos como “sistemas embarcados”? 1
#    638 - Quanto o computador representa de todo o sistema de computação do mundo? 1
#    639 - Quanto o computador representa de todo o sistema de computação do mundo? 1
#    640 - Quanto o computador representa de todo o sistema de computação do mundo? 1
#    641 - Quanto o computador representa de todo o sistema de computação do mundo? 1
#    642 - Quanto o computador representa de todo o sistema de computação do mundo? 1
#    643 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    644 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    645 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    646 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    647 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    648 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    649 - O que o curso de Engenharia da Computação da UFRG visa? 1
#    650 - Quando se iniciou a primeira turma de engenheiros de computação? 1
#    651 - Como surgiu a maioria dos cursos de Engenharia de Computação? 1
#    652 - Como surgiu a maioria dos cursos de Engenharia de Computação? 1
#    653 - Como surgiu a maioria dos cursos de Engenharia de Computação? 1
#    654 - Como surgiu a maioria dos cursos de Engenharia de Computação? 1
#    655 - Como surgiu a maioria dos cursos de Engenharia de Computação? 1
#    656 - De qual curso são provenientes as disciplinas de engenharia da computação? 1
#    657 - De qual curso são provenientes as disciplinas de engenharia da computação? 1
#    658 - Onde a engenharia elétrica ainda integra a engenharia da computação? 1
#    659 - Onde a engenharia elétrica ainda integra a engenharia da computação? 1
#    660 - Onde a engenharia elétrica ainda integra a engenharia da computação? 1
#    661 - Quando os primeiros docentes do curso de Engenharia de Computação da UNIVASF iniciaram suas atividades? 1
#    662 - Quando os primeiros docentes do curso de Engenharia de Computação da UNIVASF iniciaram suas atividades? 1
#    663 - Quando os primeiros docentes do curso de Engenharia de Computação da UNIVASF iniciaram suas atividades? 1
#    664 - Quantos membros haviam no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008? 1
#    665 - Quantos membros haviam no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008? 1
#    666 - Quem autorizou o curso de Engenharia de Computação da UNIVASF? 1
#    667 - Quem autorizou o curso de Engenharia de Computação da UNIVASF? 1
#    668 - Desde quando o curso de engenharia de computação tem sido adicionado às universidades? 1
#    669 - Desde quando o curso de engenharia de computação tem sido adicionado às universidades? 1
#    670 - Desde quando o curso de engenharia de computação tem sido adicionado às universidades? 1
#    671 - Desde quando o curso de engenharia de computação tem sido adicionado às universidades? 1
#    672 - Como o curso de engenharia de sistemas e computação passará a se chamar? 1
#    673 - O que é UERJ? 1
#    674 - O que é UERJ? 1
#    675 - O que é UERJ? 1
#    676 - Qual era o objetivo do curso de engenharia de sistemas e computação? 1
#    677 - Qual o objetivo da revisão do curso de engenharia de sistemas e computação? 1
#    678 - Qual o objetivo da revisão do curso de engenharia de sistemas e computação? 1
#    679 - O que é necessário para um engenheiro de computação exercer a profissão? 1
#    680 - Quem é considerado engenheiro de computação no Brasil? 1
#    681 - Como consta o curso de Engenharia de Computação da UFSC atualmente? 1
#    682 - Como consta o curso de Engenharia de Computação da UFSC atualmente? 1
#    683 - Como consta o curso de Engenharia de Computação da UFSC atualmente? 1
#    684 - Como consta o curso de Engenharia de Computação da UFSC atualmente? 1
#    685 - Como consta o curso de Engenharia de Computação da UFSC atualmente? 1
#    686 - Como consta o curso de Engenharia de Computação da UFSC atualmente? 1
#    687 - Como consta o curso de Engenharia de Computação da UFSC atualmente? 1
#    688 - Como consta o curso de Engenharia de Computação da UFSC atualmente? 1
# ...
#    2018 - quem avaliará a proposta para projeto pedagógico de curso? 1
#    2019 - quem avaliará a proposta para projeto pedagógico de curso? 1
#    2020 - quem avaliará a proposta para projeto pedagógico de curso? 1
#    2021 - quem avaliará a proposta para projeto pedagógico de curso? 1
#    2022 - quem avaliará a proposta para projeto pedagógico de curso? 1
#    2023 - quem avaliará a proposta para projeto pedagógico de curso? 1
#    2024 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2025 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2026 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2027 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2028 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2029 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2030 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2031 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2032 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2033 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2034 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas? 1
#    2035 - onde é realizada a matrícula em disciplinas obrigatórias? 1
#    2036 - onde é realizada a matrícula em disciplinas obrigatórias? 1
#    2037 - onde está definido o prazo para renovação de matrícula? 1
#    2038 - onde está definido o prazo para renovação de matrícula? 1
#    2039 - onde está definido o prazo para renovação de matrícula? 1
#    2040 - o que acontece com o acadêmico com vínculo trancado em caso de não renovação de sua matrícula no semestre seguinte? 1
#    2041 - o que o acadêmico deve preencher na fase de inscrição? 1
#    2042 - quais incisos os acadêmicos deve cumprir? 1
#    2043 - quais são as fases da renovação de matrícula? 1
#    2044 - quais são as fases da renovação de matrícula? 1
#    2045 - quais são as fases da renovação de matrícula? 1
#    2046 - quais são as fases da renovação de matrícula? 1
#    2047 - qual ordem a distribuição das vagas disponíveis deve seguir? 1
#    2048 - qual ordem a distribuição das vagas disponíveis deve seguir? 1
#    2049 - qual ordem a distribuição das vagas disponíveis deve seguir? 1
#    2050 - qual ordem a distribuição das vagas disponíveis deve seguir? 1
#    2051 - qual ordem a distribuição das vagas disponíveis deve seguir? 1
#    2052 - o que os membros do nde devem assegurar? 1
#    2053 - o que os membros do nde devem assegurar? 1
#    2054 - o que os membros do nde devem assegurar? 1
#    2055 - o que os membros do nde devem assegurar? 1
#    2056 - o que os membros do nde devem assegurar? 1
#    2057 - por meio de quem as instituições de ensino superior devem definir as atribuições e os critérios de constituição do nde? 1
#    2058 - por meio de quem as instituições de ensino superior devem definir as atribuições e os critérios de constituição do nde? 1
#    2059 - por meio de quem as instituições de ensino superior devem definir as atribuições e os critérios de constituição do nde? 1
#    2060 - por meio de quem as instituições de ensino superior devem definir as atribuições e os critérios de constituição do nde? 1
#    2061 - por meio de quem as instituições de ensino superior devem definir as atribuições e os critérios de constituição do nde? 1
#    2062 - por meio de quem as instituições de ensino superior devem definir as atribuições e os critérios de constituição do nde? 1
#    2063 - quais os critérios de constituição do nde? 1
#    2064 - quais os critérios de constituição do nde? 1
#    2065 - quais os critérios de constituição do nde? 1
#    2066 - quais os critérios de constituição do nde? 1
#    2067 - quais os critérios de constituição do nde? 1
#    2068 - quais os critérios de constituição do nde? 1
#    2069 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2070 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2071 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2072 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2073 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2074 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2075 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2076 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2077 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2078 - quantos dos membros do nde devem possuir titulação acadêmica obtidas em programas de pósgraduação? 1
#    2079 - o que os membros do nde devem exercer? 1
#    2080 - o que os membros do nde devem exercer? 1
#    2081 - o que os membros do nde devem exercer? 1
#    2082 - o que os membros do nde devem exercer? 1
#    2083 - o que os membros do nde devem exercer? 1
#    2084 - o que os membros do nde devem exercer? 1
#    2085 - o que os membros do nde devem exercer? 1
#    2086 - o que os membros do nde devem exercer? 1
#    2087 - o que os membros do nde devem exercer? 1
#    2088 - o que os membros do nde devem exercer? 1
#    2089 - o que os membros do nde devem exercer? 1
#    2090 - o que os membros do nde devem exercer? 1
#    2091 - o que os membros do nde devem exercer? 1
#    2092 - o que os membros do nde devem exercer? 1
#    2093 - o que os membros do nde devem exercer? 1
#    2094 - o que é nde? 1
#    2095 - o que é nde? 1
#    2096 - o que é nde? 1
#    2097 - o que é nde? 1
#    2098 - o que é nde? 1
#    2099 - o que é nde? 1
#    2100 - o que é nde? 1
#    2101 - o que é nde? 1
#    2102 - o que é nde? 1
#    2103 - quais são as atribuições acadêmicas do nde? 1
#    2104 - quais são as atribuições acadêmicas do nde? 1
#    2105 - quais são as atribuições acadêmicas do nde? 1
#    2106 - quais são as atribuições acadêmicas do nde? 1
#    2107 - quais são as atribuições acadêmicas do nde? 1
#    2108 - quais são as atribuições acadêmicas do nde? 1
#    2109 - quais são as atribuições acadêmicas do nde? 1
#    2110 - qual a constituição do núcleo docente estruturante (nde)? 1
#    2111 - qual a constituição do núcleo docente estruturante (nde)? 1
#    2112 - qual a constituição do núcleo docente estruturante (nde)? 1
#    2113 - qual a constituição do núcleo docente estruturante (nde)? 1
#    2114 - qual a constituição do núcleo docente estruturante (nde)? 1
#    2115 - o que deve o núcleo docente estruturante zelar? 1
#    2116 - como fica a componente curricular não disciplinar no siscad? 1
#    2117 - como fica a componente curricular não disciplinar no siscad? 1
#    2118 - como fica a componente curricular não disciplinar no siscad? 1
#    2119 - como fica a componente curricular não disciplinar no siscad? 1
#    2120 - como fica a componente curricular não disciplinar no siscad? 1
#    2121 - como fica a componente curricular não disciplinar no siscad? 1
#    2122 - como fica a componente curricular não disciplinar no siscad? 1
#    2123 - como fica a componente curricular não disciplinar no siscad? 1
#    2124 - como fica a componente curricular não disciplinar no siscad? 1
#    2125 - como fica a componente curricular não disciplinar no siscad? 1
#    2126 - como fica a componente curricular não disciplinar no siscad? 1
#    2127 - como fica a componente curricular não disciplinar no siscad? 1
#    2128 - como fica a componente curricular não disciplinar no siscad? 1
#    2129 - quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de gradução? 1
#    2130 - quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de gradução? 1
#    2131 - quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de gradução? 1
#    2132 - quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de gradução? 1
#    2133 - quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de gradução? 1
#    2134 - quais são as componentes curriculares não disciplinares no projeto pedagógico de um curso de gradução? 1
#    2135 - quem avalia a solicitação de regime de exercícios domiciliares? 1
#    2136 - quem avalia a solicitação de regime de exercícios domiciliares? 1
#    2137 - quem avalia a solicitação de regime de exercícios domiciliares? 1
#    2138 - quem avalia a solicitação de regime de exercícios domiciliares? 1
#    2139 - quem avalia a solicitação de regime de exercícios domiciliares? 1
#    2140 - o que é regime de exercícios domiciliares? 1
#    2141 - o que é regime de exercícios domiciliares? 1
#    2142 - o que é regime de exercícios domiciliares? 1
#    2143 - o que é regime de exercícios domiciliares? 1
#    2144 - o que é regime de exercícios domiciliares? 1
#    2145 - o que é regime de exercícios domiciliares? 1
#    2146 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2147 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2148 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2149 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2150 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2151 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2152 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2153 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2154 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2155 - quais são as atividades para o regime de exercícios domiciliares? 1
#    2156 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2157 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2158 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2159 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2160 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2161 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2162 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2163 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2164 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é alterada pelo orgão competente? 1
#    2165 - quantas vezes posso solicitar aproveitamento de estudos? 1
#    2166 - quantas vezes posso solicitar aproveitamento de estudos? 1
#    2167 - quantas vezes posso solicitar aproveitamento de estudos? 1
#    2168 - o que deverá conter o plano de estudos? 1
#    2169 - o que deverá conter o plano de estudos? 1
#    2170 - o que deverá conter o plano de estudos? 1
#    2171 - por quem será aprovado o plano de estudos? 1
#    2172 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2173 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2174 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2175 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2176 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2177 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2178 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2179 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2180 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2181 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2182 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2183 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de medidas corretivas? 1
#    2184 - a aprovação nas disciplinas depende do que? 1
#    2185 - a aprovação nas disciplinas depende do que? 1
#    2186 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    2187 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    2188 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    2189 - quem é responsável pela verificação do cumprimento das atividades complementares? 1
#    2190 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    2191 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    2192 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    2193 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    2194 - como o acadêmico solicita revisão de avaliação de disciplina? 1
#    2195 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    2196 - como é organizada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas? 1
#    2197 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    2198 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    2199 - em quantas discplinas o acadêmico poderá inscrever-se durante o período letivo especial? 1
#    2200 - como faço para não perder o vínculo acadêmico? 1
#    2201 - como faço para não perder o vínculo acadêmico? 1
#    2202 - como faço para não perder o vínculo acadêmico? 1
#    2203 - como faço para não perder o vínculo acadêmico? 1
#    2204 - de quando é a resolução no 401? 1
#    2205 - de quando é a resolução no 401? 1
#    2206 - de quando é a resolução no 401? 1
#    2207 - de quando é a resolução no 401? 1
#    2208 - de quando é a resolução no 401? 1
#    2209 - de quando é a resolução no 401? 1
#    2210 - de quando é a resolução no 401? 1
#    2211 - de quando é a resolução no 401? 1
#    2212 - de quando é a resolução no 401? 1
#    2213 - de quando é a resolução no 401? 1
#    2214 - de quando é a resolução no 401? 1
#    2215 - de quando é a resolução no 401? 1
#    2216 - de quando é a resolução no 401? 1
#    2217 - de quando é a resolução no 401? 1
#    2218 - de quando é a resolução no 401? 1
#    2219 - de quando é a resolução no 401? 1
#    2220 - de quando é a resolução no 401? 1
#    2221 - de quando é a resolução no 401? 1
#    2222 - de quando é a resolução no 401? 1
#    2223 - o que a resolução no 401 estabelece? 1
#    2224 - existe lei sobre a transferência compulsória? 1
#    2225 - existe lei sobre a transferência compulsória? 1

# %% [markdown]
# #### Lista Documentos Perturbados(0-incoerente) medidos corretamente(0-incoerente)

# %%
def listaPerturbadoMedidosCorretamente(dfListaParesDocumentosMedidas, medida):
  listaRetorno = []  
  for i, linha in dfListaParesDocumentosMedidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + 'DO'] <= linha[ medida + 'Pert']:
         listaRetorno.append(linha['idPert'])
    else:
        # Medida de distância (euc, man)
        if linha[medida + 'DO'] <= linha[ medida + 'Pert']:
           listaRetorno.append(linha['idPert'])
          
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaDocumentoPerturbadoMedidoCorretamente  = listaPerturbadoMedidosCorretamente(dfListaParesDocumentosMedidasBERT, MELHOR_MEDIDA_GERAL_STR)

print("Lista de documentos perturbados medidos corretamente:",len(listaDocumentoPerturbadoMedidoCorretamente ))
# Out:
# Lista de documentos perturbados medidos corretamente: 15774

# %%
print("Lista de documentos perturbados medidos corretamente(incoerentes)(CSm(DO) >= CSm(pertDO)):", len(listaDocumentoPerturbadoMedidoCorretamente ))
for i, documento in listaDocumentoPerturbadoMedidoCorretamente .iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#    10774 - Em qual ano os alunos de colação de grau P ser matriculados em disciplinas sem que tenham cumprido todos os pré-requisitos ? 0
#    10775 - Em qual ano os alunos de colação de grau poderão ser frequ em disciplinas sem que tenham cumprido todos os pré-requisitos ? 0
#    10776 - Em qual ano os alunos de colação de grau poderão ser Campeões em disciplinas sem que tenham cumprido todos os pré-requisitos ? 0
#    10777 - Em qual ano os alunos de colação de grau poderão ser livros em disciplinas sem que tenham cumprido todos os pré-requisitos ? 0
#    10778 - Em qual ano os alunos de colação de grau poderão ser suficientes em disciplinas sem que tenham cumprido todos os pré-requisitos ? 0
#    10779 - O que importância ser respeitado na inscrição das disciplinas ? 0
#    10780 - O que deve ser lar na inscrição das disciplinas ? 0
#    10781 - O que deve ser alvo na inscrição das disciplinas ? 0
#    10782 - O que deve ser Carta na inscrição das disciplinas ? 0
#    10783 - O que fiel ser respeitado na inscrição das disciplinas ? 0
#    10784 - O que deve ser exame na inscrição das disciplinas ? 0
#    10785 - O que vem ser respeitado na inscrição das disciplinas ? 0
#    10786 - O que deve ser demonstrar na inscrição das disciplinas ? 0
#    10787 - O que _ ser respeitado na inscrição das disciplinas ? 0
#    10788 - O que deve ser proposta na inscrição das disciplinas ? 0
#    10789 - O que deve ser questão na inscrição das disciplinas ? 0
#    10790 - O que seguida ser respeitado na inscrição das disciplinas ? 0
#    10791 - O que deve ser " na inscrição das disciplinas ? 0
#    10792 - O que seu ser respeitado na inscrição das disciplinas ? 0
#    10793 - O que comum ser respeitado na inscrição das disciplinas ? 0
#    10794 - O que e ser respeitado na inscrição das disciplinas ? 0
#    10795 - O que deve ser eliminados na inscrição das disciplinas ? 0
#    10796 - O que deve ser filmado na inscrição das disciplinas ? 0
#    10797 - O que ass ser respeitado na inscrição das disciplinas ? 0
#    10798 - O que li ser respeitado na inscrição das disciplinas ? 0
#    10799 - Quais as renovação de renovação de matrícula ? 0
#    10800 - Quais as competências de renovação de matrícula ? 0
#    10801 - Quais as categoria de renovação de matrícula ? 0
#    10802 - Quais as fases de renovação de situação ? 0
#    10803 - Quais as fases de renovação de cópias ? 0
#    10804 - Quais as fases de dissolução de matrícula ? 0
#    10805 - Quais as fases de renovação de abastecimento ? 0
#    10806 - Quais as planos de renovação de matrícula ? 0
#    10807 - Quais as fases de dificuldades de matrícula ? 0
#    10808 - Quais as fases de concessões de matrícula ? 0
#    10809 - Quais as necessárias de renovação de matrícula ? 0
#    10810 - Quais as fases de horário de matrícula ? 0
#    10811 - Quais as . de renovação de matrícula ? 0
#    10812 - Quais as tar de renovação de matrícula ? 0
#    10813 - Quando a renovação de matrícula é tificação em trancamento ? 0
#    10814 - Quando a renovação de matrícula é modalidade em trancamento ? 0
#    10815 - Quando a renovação de matrícula é chave em trancamento ? 0
#    10816 - Quando a renovação de matrícula é modificado em trancamento ? 0
#    10817 - Quando a renovação de matrícula é inversa em trancamento ? 0
#    10818 - Quando a renovação de matrícula é muda em trancamento ? 0
#    10819 - Quando a renovação de matrícula é orientada em trancamento ? 0
#    10820 - Quando a renovação de matrícula é fiscal em trancamento ? 0
#    10821 - Quando a renovação de matrícula é datada em trancamento ? 0
#    10822 - Quando a renovação de matrícula é tentativa em trancamento ? 0
#    10823 - Quando a renovação de matrícula é resultou em trancamento ? 0
#    10824 - Quando a renovação de matrícula é 1964 em trancamento ? 0
#    10825 - Quando a renovação de matrícula é de em trancamento ? 0
#    10826 - Quando a renovação de matrícula é fundada em trancamento ? 0
#    10827 - Quando a renovação de matrícula é hora em trancamento ? 0
#    10828 - Quando a renovação de matrícula é import em trancamento ? 0
#    10829 - Quando a renovação de matrícula é conver em trancamento ? 0
#    10830 - Quando a renovação de matrícula é plena em trancamento ? 0
#    10831 - Quando a renovação de matrícula é va em trancamento ? 0
#    10832 - Quando a renovação de matrícula é parceira em trancamento ? 0
#    10833 - Quem Com a validação da matrícula ? 0
#    10834 - Quem estranha a validação da matrícula ? 0
#    10835 - Quem sujeito a validação da matrícula ? 0
#    10836 - Quem demonstrou a validação da matrícula ? 0
#    10837 - Quem propor a validação da matrícula ? 0
#    10838 - Quem pesso a validação da matrícula ? 0
#    10839 - Quem mora a validação da matrícula ? 0
#    10840 - Quem combina a validação da matrícula ? 0
#    10841 - Quem poder a validação da matrícula ? 0
#    10842 - Quem respeita a validação da matrícula ? 0
#    10843 - Quem dispens a validação da matrícula ? 0
#    10844 - Quem competência a validação da matrícula ? 0
#    10845 - Quem receber a validação da matrícula ? 0
#    10846 - Quem obriga a validação da matrícula ? 0
#    10847 - Quem testemunha a validação da matrícula ? 0
#    10848 - Quem direito a validação da matrícula ? 0
#    10849 - Quem cabe a validação da matrícula ? 0
#    10850 - Quem contratou a validação da matrícula ? 0
#    10851 - Quem implementar a validação da matrícula ? 0
#    10852 - Quem coopera a validação da matrícula ? 0
#    10853 - Quem deve este o formulário de inscrição na confirmação de matrícula ? 0
#    10854 - Quem deve incluída o formulário de inscrição na confirmação de matrícula ? 0
#    10855 - Quem deve expor o formulário de inscrição na confirmação de matrícula ? 0
#    10856 - Quem par apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10857 - Quem á apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10858 - Quem tempo apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10859 - Quem deve substitui o formulário de inscrição na confirmação de matrícula ? 0
#    10860 - Quem idade apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10861 - Quem fas apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10862 - Quem considerou apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10863 - Quem especifica apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10864 - Quem nta apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10865 - Quem deve beber o formulário de inscrição na confirmação de matrícula ? 0
#    10866 - Quem confere apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10867 - Quem deve pintar o formulário de inscrição na confirmação de matrícula ? 0
#    10868 - Quem receber apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10869 - Quem salva apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10870 - Quem deve Ir o formulário de inscrição na confirmação de matrícula ? 0
#    10871 - Quem MA apresentar o formulário de inscrição na confirmação de matrícula ? 0
#    10872 - Quem deve acompanha o formulário de inscrição na confirmação de matrícula ? 0
#    10873 - O ano letivo explicou quais períodos regulares de atividades ? 0
#    10874 - O ano letivo fixa quais períodos regulares de atividades ? 0
#    10875 - O ano letivo dá quais períodos regulares de atividades ? 0
#    10876 - O ano letivo marcou quais períodos regulares de atividades ? 0
#    10877 - O ano letivo escreve quais períodos regulares de atividades ? 0
#    10878 - O ano letivo transmite quais períodos regulares de atividades ? 0
#    10879 - O ano letivo nega quais períodos regulares de atividades ? 0
#    10880 - O ano letivo terminou quais períodos regulares de atividades ? 0
#    10881 - O ano letivo seguia quais períodos regulares de atividades ? 0
#    10882 - O ano letivo formam quais períodos regulares de atividades ? 0
#    10883 - O ano letivo substituiu quais períodos regulares de atividades ? 0
#    10884 - O ano letivo propor quais períodos regulares de atividades ? 0
#    10885 - O ano letivo obede quais períodos regulares de atividades ? 0
#    10886 - O ano letivo Estuda quais períodos regulares de atividades ? 0
#    10887 - O ano letivo participa quais períodos regulares de atividades ? 0
#    10888 - O ano letivo pôs quais períodos regulares de atividades ? 0
#    10889 - O ano letivo estabelec quais períodos regulares de atividades ? 0
#    10890 - O ano letivo segue quais períodos regulares de atividades ? 0
#    10891 - O ano letivo tutela quais períodos regulares de atividades ? 0
#    10892 - O ano letivo compostos quais períodos regulares de atividades ? 0
#    10893 - O calendário acadêmico é — por quem ? 0
#    10894 - O calendário acadêmico é passado por quem ? 0
#    10895 - O calendário acadêmico é referido por quem ? 0
#    10896 - O calendário acadêmico é específico por quem ? 0
#    10897 - O calendário acadêmico é candidato por quem ? 0
#    10898 - O calendário acadêmico é considerado por quem ? 0
#    10899 - O calendário acadêmico é selecionado por quem ? 0
#    10900 - O calendário acadêmico é possível por quem ? 0
#    10901 - O calendário acadêmico é conhecido por quem ? 0
#    10902 - O calendário acadêmico é subordinado por quem ? 0
#    10903 - O calendário acadêmico é por por quem ? 0
#    10904 - O calendário acadêmico é organização por quem ? 0
#    10905 - O calendário acadêmico é rígido por quem ? 0
#    10906 - O calendário acadêmico é adotado por quem ? 0
#    10907 - O calendário acadêmico é vig por quem ? 0
#    10908 - O calendário acadêmico é particular por quem ? 0
#    10909 - O calendário acadêmico é designado por quem ? 0
#    10910 - Quando são termos os períodos letivos especiais ? 0
#    10911 - Quando são básicos os períodos letivos especiais ? 0
#    10912 - Quando são ) os períodos letivos especiais ? 0
#    10913 - Quando são implementação os períodos letivos especiais ? 0
#    10914 - Quando são fechadas os períodos letivos especiais ? 0
#    10915 - Quando são disponíveis os períodos letivos especiais ? 0
#    10916 - Quando são começo os períodos letivos especiais ? 0
#    10917 - Quando são considerando os períodos letivos especiais ? 0
#    10918 - Quando são passados os períodos letivos especiais ? 0
#    10919 - Quando são começam os períodos letivos especiais ? 0
#    10920 - Quando são rápidos os períodos letivos especiais ? 0
#    10921 - Quando são trazidos os períodos letivos especiais ? 0
#    10922 - Quando são civis os períodos letivos especiais ? 0
#    10923 - Quando são determinados os períodos letivos especiais ? 0
#    10924 - Quando são raros os períodos letivos especiais ? 0
#    10925 - Quando são ocorrer os períodos letivos especiais ? 0
#    10926 - Quando são referência os períodos letivos especiais ? 0
#    10927 - Quando são promovendo os períodos letivos especiais ? 0
#    10928 - Quando são válidos os períodos letivos especiais ? 0
#    10929 - Quando são tantos os períodos letivos especiais ? 0
#    10930 - Quantos dias os períodos regulares de um ano letivo escritos ? 0
#    10931 - Quantos dias os períodos regulares de um ano letivo contribuíram ? 0
#    10932 - Quantos dias os períodos regulares de um ano letivo divididas ? 0
#    10933 - Quantos dias os períodos regulares de um ano letivo 6 ? 0
#    10934 - Quantos dias os períodos regulares de um ano letivo entraram ? 0
#    10935 - Quantos dias os períodos regulares de um ano letivo atualmente ? 0
#    10936 - Quantos dias os períodos regulares de um ano letivo inteira ? 0
#    10937 - Quantos dias os períodos regulares de um ano letivo terrestres ? 0
#    10938 - Quantos dias os períodos regulares de um ano letivo oferece ? 0
#    10939 - Quantos dias os períodos regulares de um ano letivo lunar ? 0
#    10940 - Quantos dias os períodos regulares de um ano letivo tenho ? 0
#    10941 - Quantos dias os períodos regulares de um ano letivo substituir ? 0
#    10942 - Quantos dias os períodos regulares de um ano letivo tam ? 0
#    10943 - Quantos dias os períodos regulares de um ano letivo entraram ? 0
#    10944 - Quantos dias os períodos regulares de um ano letivo designados ? 0
#    10945 - Quantos dias os períodos regulares de um ano letivo usam ? 0
#    10946 - Quantos dias os períodos regulares de um ano letivo desempenha ? 0
#    10947 - Quantos dias os períodos regulares de um ano letivo consta ? 0
#    10948 - Quantos dias os períodos regulares de um ano letivo semanas ? 0
#    10949 - Quem ona os prazos para a efetivação das atividades acadêmicas ? 0
#    10950 - Quem orienta os prazos para a efetivação das atividades acadêmicas ? 0
#    10951 - Quem lançou os prazos para a efetivação das atividades acadêmicas ? 0
#    10952 - Quem u os prazos para a efetivação das atividades acadêmicas ? 0
#    10953 - Quem separa os prazos para a efetivação das atividades acadêmicas ? 0
#    10954 - Quem reúne os prazos para a efetivação das atividades acadêmicas ? 0
#    10955 - Quem chefia os prazos para a efetivação das atividades acadêmicas ? 0
#    10956 - Quem dados os prazos para a efetivação das atividades acadêmicas ? 0
#    10957 - Quem quando os prazos para a efetivação das atividades acadêmicas ? 0
#    10958 - Quem solicitou os prazos para a efetivação das atividades acadêmicas ? 0
#    10959 - Quem serem os prazos para a efetivação das atividades acadêmicas ? 0
#    10960 - Quem resolve os prazos para a efetivação das atividades acadêmicas ? 0
#    10961 - Quem encerrou os prazos para a efetivação das atividades acadêmicas ? 0
#    10962 - Quem anda os prazos para a efetivação das atividades acadêmicas ? 0
#    10963 - Quem caracteriza os prazos para a efetivação das atividades acadêmicas ? 0
#    10964 - Quem testa os prazos para a efetivação das atividades acadêmicas ? 0
#    10965 - Quem recebe os prazos para a efetivação das atividades acadêmicas ? 0
#    10966 - Quem preparou os prazos para a efetivação das atividades acadêmicas ? 0
#    10967 - Quem defendem os prazos para a efetivação das atividades acadêmicas ? 0
#    10968 - Com o que será completada a carga horária se for existe a falta para integralização curricular ? 0
#    10969 - Com o que será adequada a carga horária se for constatada a falta para integralização curricular ? 0
#    10970 - Com o que será avalia a carga horária se for constatada a falta para integralização curricular ? 0
#    10971 - Com o que será completada a carga horária se for assinar a falta para integralização curricular ? 0
#    10972 - Com o que será sinal a carga horária se for constatada a falta para integralização curricular ? 0
#    10973 - Com o que será completada a carga horária se for entrada a falta para integralização curricular ? 0
#    10974 - Com o que será completada a carga horária se for fazendo a falta para integralização curricular ? 0
#    10975 - Com o que será parte a carga horária se for constatada a falta para integralização curricular ? 0
#    10976 - Com o que será vital a carga horária se for constatada a falta para integralização curricular ? 0
#    10977 - Com o que será diminui a carga horária se for constatada a falta para integralização curricular ? 0
#    10978 - Com o que será fonte a carga horária se for constatada a falta para integralização curricular ? 0
#    10979 - Com o que será futura a carga horária se for constatada a falta para integralização curricular ? 0
#    10980 - Com o que será constituir a carga horária se for constatada a falta para integralização curricular ? 0
#    10981 - Com o que será constituído a carga horária se for constatada a falta para integralização curricular ? 0
#    10982 - Com o que será completada a carga horária se for levantar a falta para integralização curricular ? 0
#    10983 - Com o que será lançado a carga horária se for constatada a falta para integralização curricular ? 0
#    10984 - Com o que será completada a carga horária se for esse a falta para integralização curricular ? 0
#    10985 - Com o que será demais a carga horária se for constatada a falta para integralização curricular ? 0
#    10986 - O Colegiado de Curso poderá posteriormente alterações na matriz curricular ? 0
#    10987 - O Colegiado de Curso poderá ocorreram alterações na matriz curricular ? 0
#    10988 - O Colegiado de Curso poderá necessária alterações na matriz curricular ? 0
#    10989 - O Colegiado de Curso a propor alterações na matriz curricular ? 0
#    10990 - O Colegiado de Curso poderá rever alterações na matriz curricular ? 0
#    10991 - O Colegiado de Curso nega propor alterações na matriz curricular ? 0
#    10992 - O Colegiado de Curso poderá algumas alterações na matriz curricular ? 0
#    10993 - O Colegiado de Curso aprovado propor alterações na matriz curricular ? 0
#    10994 - O Colegiado de Curso deu propor alterações na matriz curricular ? 0
#    10995 - O Colegiado de Curso decisão propor alterações na matriz curricular ? 0
#    10996 - O Colegiado de Curso assume propor alterações na matriz curricular ? 0
#    10997 - O Colegiado de Curso ilegal propor alterações na matriz curricular ? 0
#    10998 - O Colegiado de Curso mínimo propor alterações na matriz curricular ? 0
#    10999 - O Colegiado de Curso poderá terem alterações na matriz curricular ? 0
#    11000 - O Colegiado de Curso si propor alterações na matriz curricular ? 0
#    11001 - O Colegiado de Curso Profissional propor alterações na matriz curricular ? 0
#    11002 - O Colegiado de Curso poderá tão alterações na matriz curricular ? 0
#    11003 - O Colegiado de Curso poderá sempre alterações na matriz curricular ? 0
#    11004 - O Colegiado de Curso ativo propor alterações na matriz curricular ? 0
#    11005 - O Colegiado de Curso Media propor alterações na matriz curricular ? 0
#    11006 - Qual a finalidade da criação do plano de estudos ? 0
#    11007 - Qual a biblioteca da elaboração do plano de estudos ? 0
#    11008 - Qual a finalidade da elaboração do plano de aulas ? 0
#    11009 - Qual a finalidade da elaboração do além de estudos ? 0
#    11010 - Qual a finalidade da elaboração do plano de pobreza ? 0
#    11011 - Qual a finalidade da adoção do plano de estudos ? 0
#    11012 - Qual a finalidade da elaboração do plano de gasto ? 0
#    11013 - Qual a finalidade da elaboração do plano de exercícios ? 0
#    11014 - Qual a produtividade da elaboração do plano de estudos ? 0
#    11015 - Qual a finalidade da elaboração do padre de estudos ? 0
#    11016 - Qual a tentativa da elaboração do plano de estudos ? 0
#    11017 - Qual a unidade da elaboração do plano de estudos ? 0
#    11018 - Qual a parâmetros da elaboração do plano de estudos ? 0
#    11019 - Qual a inscrição da elaboração do plano de estudos ? 0
#    11020 - Qual a finalidade da detecção do plano de estudos ? 0
#    11021 - Qual a comunidade da elaboração do plano de estudos ? 0
#    11022 - Qual a finalidade da elaboração do Dia de estudos ? 0
#    11023 - Qual a finalidade da elaboração do rito de estudos ? 0
#    11024 - Qual a finalidade da elaboração do plano de ater ? 0
#    11025 - Qual a finalidade da elaboração do plano de participação ? 0
#    11026 - Quem reorganização o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11027 - Quem aval o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11028 - Quem parcela o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11029 - Quem elabora o plano de estudos do acadêmico quando percebe migração para uma nova matriz curricular ? 0
#    11030 - Quem gostaria o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11031 - Quem editora o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11032 - Quem elabora o plano de estudos do acadêmico quando conseguem migração para uma nova matriz curricular ? 0
#    11033 - Quem age o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11034 - Quem elabora o plano de estudos do acadêmico quando exerce migração para uma nova matriz curricular ? 0
#    11035 - Quem elabora o plano de estudos do acadêmico quando detec migração para uma nova matriz curricular ? 0
#    11036 - Quem elabora o plano de estudos do acadêmico quando chamada migração para uma nova matriz curricular ? 0
#    11037 - Quem adquire o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11038 - Quem elabora o plano de estudos do acadêmico quando atua migração para uma nova matriz curricular ? 0
#    11039 - Quem reno o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11040 - Quem elabora o plano de estudos do acadêmico quando cita migração para uma nova matriz curricular ? 0
#    11041 - Quem elabora o plano de estudos do acadêmico quando nova migração para uma nova matriz curricular ? 0
#    11042 - Quem associa o plano de estudos do acadêmico quando ocorre migração para uma nova matriz curricular ? 0
#    11043 - A quem o acadêmico deve agir para revisar suas avaliações acadêmicas ? 0
#    11044 - A quem o acadêmico deve decidir para revisar suas avaliações acadêmicas ? 0
#    11045 - A quem o acadêmico deve ir para co suas avaliações acadêmicas ? 0
#    11046 - A quem o acadêmico va ir para revisar suas avaliações acadêmicas ? 0
#    11047 - A quem o acadêmico deve ir para envio suas avaliações acadêmicas ? 0
#    11048 - A quem o acadêmico deve cobra para revisar suas avaliações acadêmicas ? 0
#    11049 - A quem o acadêmico deve referir para revisar suas avaliações acadêmicas ? 0
#    11050 - A quem o acadêmico deve prevenir para revisar suas avaliações acadêmicas ? 0
#    11051 - A quem o acadêmico deve ir para planeja suas avaliações acadêmicas ? 0
#    11052 - A quem o acadêmico deve filmar para revisar suas avaliações acadêmicas ? 0
#    11053 - A quem o acadêmico deve ir para certific suas avaliações acadêmicas ? 0
#    11054 - A quem o acadêmico deve ir para estudar suas avaliações acadêmicas ? 0
#    11055 - A quem o acadêmico deve ir para assassinar suas avaliações acadêmicas ? 0
#    11056 - A quem o acadêmico deve voar para revisar suas avaliações acadêmicas ? 0
#    11057 - A quem o acadêmico deve pesquisador para revisar suas avaliações acadêmicas ? 0
#    11058 - A quem o acadêmico deve ir para formar suas avaliações acadêmicas ? 0
#    11059 - A quem o acadêmico requis ir para revisar suas avaliações acadêmicas ? 0
#    11060 - A quem o acadêmico ordena ir para revisar suas avaliações acadêmicas ? 0
#    11061 - A quem o acadêmico ha ir para revisar suas avaliações acadêmicas ? 0
#    11062 - A quem o acadêmico interna ir para revisar suas avaliações acadêmicas ? 0
#    11063 - Por quantos docentes total ser composta a comissão ? 0
#    11064 - Por quantos docentes deve ser será a comissão ? 0
#    11065 - Por quantos docentes deve ser tarefa a comissão ? 0
#    11066 - Por quantos docentes : ser composta a comissão ? 0
#    11067 - Por quantos docentes deve ser presidido a comissão ? 0
#    11068 - Por quantos docentes tradicional ser composta a comissão ? 0
#    11069 - Por quantos docentes quando ser composta a comissão ? 0
#    11070 - Por quantos docentes capacidade ser composta a comissão ? 0
#    11071 - Por quantos docentes deve ser prática a comissão ? 0
#    11072 - Por quantos docentes prometeu ser composta a comissão ? 0
#    11073 - Por quantos docentes civil ser composta a comissão ? 0
#    11074 - Por quantos docentes deve ser incorporada a comissão ? 0
#    11075 - Por quantos docentes demonstrou ser composta a comissão ? 0
#    11076 - Por quantos docentes já ser composta a comissão ? 0
#    11077 - Por quantos docentes deve ser representava a comissão ? 0
#    11078 - Por quantos docentes deve ser fechado a comissão ? 0
#    11079 - Por quantos docentes assembleia ser composta a comissão ? 0
#    11080 - Por quantos docentes apos ser composta a comissão ? 0
#    11081 - Qual o prazo para o acadêmico recurso revisão da avaliação acadêmica ? 0
#    11082 - Qual o prazo para o acadêmico ab revisão da avaliação acadêmica ? 0
#    11083 - Qual o prazo para o acadêmico melhorar revisão da avaliação acadêmica ? 0
#    11084 - Qual o prazo para o acadêmico salvar revisão da avaliação acadêmica ? 0
#    11085 - Qual o prazo para o acadêmico definir revisão da avaliação acadêmica ? 0
#    11086 - Qual o prazo para o acadêmico executa revisão da avaliação acadêmica ? 0
#    11087 - Qual o prazo para o acadêmico resolver revisão da avaliação acadêmica ? 0
#    11088 - Qual o prazo para o acadêmico recorrente revisão da avaliação acadêmica ? 0
#    11089 - Qual o prazo para o acadêmico car revisão da avaliação acadêmica ? 0
#    11090 - Qual o prazo para o acadêmico conseguir revisão da avaliação acadêmica ? 0
#    11091 - Qual o prazo para o acadêmico garantir revisão da avaliação acadêmica ? 0
#    11092 - Qual o prazo para o acadêmico devol revisão da avaliação acadêmica ? 0
#    11093 - Qual o prazo para o acadêmico possibilita revisão da avaliação acadêmica ? 0
#    11094 - Qual o prazo para o acadêmico ajudar revisão da avaliação acadêmica ? 0
#    11095 - Qual o prazo para o acadêmico ao revisão da avaliação acadêmica ? 0
#    11096 - Quem será responsável por passada a nota do aluno no Siscad ? 0
#    11097 - Quem será responsável por tanto a nota do aluno no Siscad ? 0
#    11098 - Quem será responsável por concluir a nota do aluno no Siscad ? 0
#    11099 - Quem será responsável por registra a nota do aluno no Siscad ? 0
#    11100 - Quem será responsável por resultar a nota do aluno no Siscad ? 0
#    11101 - Quem será responsável por remover a nota do aluno no Siscad ? 0
#    11102 - Quem será responsável por ger a nota do aluno no Siscad ? 0
#    11103 - Quem será responsável por principal a nota do aluno no Siscad ? 0
#    11104 - Quem será responsável por positiva a nota do aluno no Siscad ? 0
#    11105 - Quem será responsável por pontuação a nota do aluno no Siscad ? 0
#    11106 - Quem será responsável por pensar a nota do aluno no Siscad ? 0
#    11107 - Quem será responsável por substituir a nota do aluno no Siscad ? 0
#    11108 - Quem será responsável por entender a nota do aluno no Siscad ? 0
#    11109 - Quem será responsável por registros a nota do aluno no Siscad ? 0
#    11110 - Quem será responsável por i a nota do aluno no Siscad ? 0
#    11111 - Quem será responsável por inser a nota do aluno no Siscad ? 0
#    11112 - Quem será responsável por comentar a nota do aluno no Siscad ? 0
#    11113 - Quem será responsável por notícias a nota do aluno no Siscad ? 0
#    11114 - Quem será responsável por passada a nota do aluno no Siscad ? 0
#    11115 - Quem será responsável por gerenciamento a nota do aluno no Siscad ? 0
#    11116 - O que pretende caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    11117 - O que acontece caso o candidato não retorn no prazo estabelecido em edital para matrícula ? 0
#    11118 - O que acontece caso o candidato não à no prazo estabelecido em edital para matrícula ? 0
#    11119 - O que perdeu caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    11120 - O que por caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    11121 - O que conduzir caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    11122 - O que acontece caso o candidato não compareça no prazo acordo em edital para matrícula ? 0
#    11123 - O que Temer caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    11124 - O que acontece caso o candidato não compareça no prazo claramente em edital para matrícula ? 0
#    11125 - O que acontece caso o candidato não viaja no prazo estabelecido em edital para matrícula ? 0
#    11126 - O que adquire caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    11127 - O que acontece caso o candidato não janeiro no prazo estabelecido em edital para matrícula ? 0
#    11128 - O que acontece caso o candidato não compareça no prazo restante em edital para matrícula ? 0
#    11129 - O que acontece caso o candidato não compareça no prazo AB em edital para matrícula ? 0
#    11130 - O que acontece caso o candidato não compareça no prazo sinal em edital para matrícula ? 0
#    11131 - O que acontece caso o candidato não compareça no prazo pedido em edital para matrícula ? 0
#    11132 - O que investir caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    11133 - O que acontece caso o candidato não compareça no prazo efetivo em edital para matrícula ? 0
#    11134 - O que ameaça caso o candidato não compareça no prazo estabelecido em edital para matrícula ? 0
#    11135 - O que acontece caso o candidato não compareça no prazo 49 em edital para matrícula ? 0
#    11136 - Onde está mencionada a documentação que ve ser providenciada pelo candidato ingressante ? 0
#    11137 - Onde está mencionada a documentação que podem ser providenciada pelo candidato ingressante ? 0
#    11138 - Onde está mencionada a documentação que ara ser providenciada pelo candidato ingressante ? 0
#    11139 - Onde está mencionada a documentação que prove ser providenciada pelo candidato ingressante ? 0
#    11140 - Onde está mencionada a documentação que destaca ser providenciada pelo candidato ingressante ? 0
#    11141 - Onde está mencionada a documentação que deve ser teste pelo candidato ingressante ? 0
#    11142 - Onde está mencionada a documentação que deve ser seguido pelo candidato ingressante ? 0
#    11143 - Onde está mencionada a documentação que deve ser legal pelo candidato ingressante ? 0
#    11144 - Onde está mencionada a documentação que deve ser jogada pelo candidato ingressante ? 0
#    11145 - Onde está mencionada a documentação que vamos ser providenciada pelo candidato ingressante ? 0
#    11146 - Onde está mencionada a documentação que deve ser controlado pelo candidato ingressante ? 0
#    11147 - Onde está mencionada a documentação que n ser providenciada pelo candidato ingressante ? 0
#    11148 - Onde está mencionada a documentação que deve ser anexação pelo candidato ingressante ? 0
#    11149 - Onde está mencionada a documentação que acontece ser providenciada pelo candidato ingressante ? 0
#    11150 - Onde está mencionada a documentação que admite ser providenciada pelo candidato ingressante ? 0
#    11151 - Onde está mencionada a documentação que deve ser controlado pelo candidato ingressante ? 0
#    11152 - Onde está mencionada a documentação que monitora ser providenciada pelo candidato ingressante ? 0
#    11153 - Onde está mencionada a documentação que participou ser providenciada pelo candidato ingressante ? 0
#    11154 - Onde está mencionada a documentação que aplica ser providenciada pelo candidato ingressante ? 0
#    11155 - Ao que o abono de faltas deve relacionados ? 0
#    11156 - Ao que o abono de faltas ordena obedecer ? 0
#    11157 - Ao que o abono de faltas obede obedecer ? 0
#    11158 - Ao que o abono de faltas deve chegado ? 0
#    11159 - Ao que o abono de faltas deve ainda ? 0
#    11160 - Ao que o abono de faltas deve tomar ? 0
#    11161 - Ao que o abono de faltas alinha obedecer ? 0
#    11162 - Ao que o abono de faltas im obedecer ? 0
#    11163 - Ao que o abono de faltas imp obedecer ? 0
#    11164 - Ao que o abono de faltas necessária obedecer ? 0
#    11165 - Ao que o abono de faltas deve frequentar ? 0
#    11166 - Ao que o abono de faltas cobra obedecer ? 0
#    11167 - Ao que o abono de faltas fez obedecer ? 0
#    11168 - Ao que o abono de faltas deve ligada ? 0
#    11169 - Ao que o abono de faltas deve isso ? 0
#    11170 - Ao que o abono de faltas escolhe obedecer ? 0
#    11171 - Ao que o abono de faltas deve exposto ? 0
#    11172 - Ao que o abono de faltas deve aproveitar ? 0
#    11173 - Ao que o abono de faltas caminha obedecer ? 0
#    11174 - Ao que o abono de faltas real obedecer ? 0
#    11175 - Qual o prazo para a recontagem de Israel ? 0
#    11176 - Qual o estágio para a recontagem de frequência ? 0
#    11177 - Qual o prazo para a issão de frequência ? 0
#    11178 - Qual o prazo para a ate de frequência ? 0
#    11179 - Qual o seguir para a recontagem de frequência ? 0
#    11180 - Qual o prazo para a recontagem de diretoria ? 0
#    11181 - Qual o prazo para a distância de frequência ? 0
#    11182 - Qual o prazo para a recontagem de uso ? 0
#    11183 - Qual o prazo para a valorização de frequência ? 0
#    11184 - Qual o permissão para a recontagem de frequência ? 0
#    11185 - Qual o prazo para a recontagem de sede ? 0
#    11186 - Qual o prazo para a recontagem de assembleia ? 0
#    11187 - Qual o anúncio para a recontagem de frequência ? 0
#    11188 - Qual o clima para a recontagem de frequência ? 0
#    11189 - Qual o prazo para a rimento de frequência ? 0
#    11190 - Quando o professor da disciplina deve considerando o número de presenças ? 0
#    11191 - Quando o professor da disciplina grande divulgar o número de presenças ? 0
#    11192 - Quando o professor da disciplina deve início o número de presenças ? 0
#    11193 - Quando o professor da disciplina * divulgar o número de presenças ? 0
#    11194 - Quando o professor da disciplina deve funcionar o número de presenças ? 0
#    11195 - Quando o professor da disciplina deve olhar o número de presenças ? 0
#    11196 - Quando o professor da disciplina envia divulgar o número de presenças ? 0
#    11197 - Quando o professor da disciplina prática divulgar o número de presenças ? 0
#    11198 - Quando o professor da disciplina deixa divulgar o número de presenças ? 0
#    11199 - Quando o professor da disciplina deve mim o número de presenças ? 0
#    11200 - Quando o professor da disciplina deve soma o número de presenças ? 0
#    11201 - Quando o professor da disciplina corresponde divulgar o número de presenças ? 0
#    11202 - Quando o professor da disciplina solic divulgar o número de presenças ? 0
#    11203 - Quando o professor da disciplina deve confirma o número de presenças ? 0
#    11204 - Quando o professor da disciplina deve dado o número de presenças ? 0
#    11205 - Quando o professor da disciplina , divulgar o número de presenças ? 0
#    11206 - Quando o professor da disciplina deve filmar o número de presenças ? 0
#    11207 - Quando o professor da disciplina deve vender o número de presenças ? 0
#    11208 - Quando o professor da disciplina determinar divulgar o número de presenças ? 0
#    11209 - Quando o professor da disciplina suficiente divulgar o número de presenças ? 0
#    11210 - Quem controla e reta a frequência das atividades acadêmicas ? 0
#    11211 - Quem controla e tenta a frequência das atividades acadêmicas ? 0
#    11212 - Quem solicitou e registra a frequência das atividades acadêmicas ? 0
#    11213 - Quem pessoal e registra a frequência das atividades acadêmicas ? 0
#    11214 - Quem controla e acontece a frequência das atividades acadêmicas ? 0
#    11215 - Quem sabia e registra a frequência das atividades acadêmicas ? 0
#    11216 - Quem controla e corresponde a frequência das atividades acadêmicas ? 0
#    11217 - Quem identifica e registra a frequência das atividades acadêmicas ? 0
#    11218 - Quem vig e registra a frequência das atividades acadêmicas ? 0
#    11219 - Quem arrecadação e registra a frequência das atividades acadêmicas ? 0
#    11220 - Quem alcança e registra a frequência das atividades acadêmicas ? 0
#    11221 - Quem controla e porque a frequência das atividades acadêmicas ? 0
#    11222 - Quem compreende e registra a frequência das atividades acadêmicas ? 0
#    11223 - Quem consiste e registra a frequência das atividades acadêmicas ? 0
#    11224 - Quem acorda e registra a frequência das atividades acadêmicas ? 0
#    11225 - Quem controla e ora a frequência das atividades acadêmicas ? 0
#    11226 - Quem votou e registra a frequência das atividades acadêmicas ? 0
#    11227 - Quem medida e registra a frequência das atividades acadêmicas ? 0
#    11228 - Quem determina e registra a frequência das atividades acadêmicas ? 0
#    11229 - Quem controla e promove a frequência das atividades acadêmicas ? 0
#    11230 - O turno matutino nem as atividades realizadas em quais horas ? 0
#    11231 - O turno matutino compreende as atividades curso em quais horas ? 0
#    11232 - O turno matutino interpretou as atividades realizadas em quais horas ? 0
#    11233 - O turno matutino compreende as atividades atribuídas em quais horas ? 0
#    11234 - O turno matutino organizar as atividades realizadas em quais horas ? 0
#    11235 - O turno matutino compreende as atividades brilhantes em quais horas ? 0
#    11236 - O turno matutino compreende as atividades matemática em quais horas ? 0
#    11237 - O turno matutino será as atividades realizadas em quais horas ? 0
#    11238 - O turno matutino começa as atividades realizadas em quais horas ? 0
#    11239 - O turno matutino compreende as atividades mães em quais horas ? 0
#    11240 - O turno matutino Considera as atividades realizadas em quais horas ? 0
#    11241 - O turno matutino compreende as atividades tais em quais horas ? 0
#    11242 - O turno matutino aprovou as atividades realizadas em quais horas ? 0
#    11243 - O turno matutino transferiu as atividades realizadas em quais horas ? 0
#    11244 - O turno matutino vendeu as atividades realizadas em quais horas ? 0
#    11245 - O turno matutino compreende as atividades exceto em quais horas ? 0
#    11246 - O turno matutino compreende as atividades estaduais em quais horas ? 0
#    11247 - O turno matutino compreende as atividades humanas em quais horas ? 0
#    11248 - O turno matutino toca as atividades realizadas em quais horas ? 0
#    11249 - O turno matutino preparou as atividades realizadas em quais horas ? 0
#    11250 - Onde são próprios os prazos para elaboração dos horários das aulas ? 0
#    11251 - Onde são instituído os prazos para elaboração dos horários das aulas ? 0
#    11252 - Onde são integrados os prazos para elaboração dos horários das aulas ? 0
#    11253 - Onde são forne os prazos para elaboração dos horários das aulas ? 0
#    11254 - Onde são idem os prazos para elaboração dos horários das aulas ? 0
#    11255 - Onde são Dado os prazos para elaboração dos horários das aulas ? 0
#    11256 - Onde são marco os prazos para elaboração dos horários das aulas ? 0
#    11257 - Onde são hados os prazos para elaboração dos horários das aulas ? 0
#    11258 - Onde são encontros os prazos para elaboração dos horários das aulas ? 0
#    11259 - Onde são respectivos os prazos para elaboração dos horários das aulas ? 0
#    11260 - Onde são variados os prazos para elaboração dos horários das aulas ? 0
#    11261 - Onde são rigor os prazos para elaboração dos horários das aulas ? 0
#    11262 - Onde são prever os prazos para elaboração dos horários das aulas ? 0
#    11263 - Onde são obtida os prazos para elaboração dos horários das aulas ? 0
#    11264 - Onde são menos os prazos para elaboração dos horários das aulas ? 0
#    11265 - Onde são situados os prazos para elaboração dos horários das aulas ? 0
#    11266 - Onde são desenvolvido os prazos para elaboração dos horários das aulas ? 0
#    11267 - Onde são visíveis os prazos para elaboração dos horários das aulas ? 0
#    11268 - Onde são dispostos os prazos para elaboração dos horários das aulas ? 0
#    11269 - Quem a coordenação de curso revista para elaborar o horário das aulas ? 0
#    11270 - Quem a coordenação de curso consulta para fol o horário das aulas ? 0
#    11271 - Quem a coordenação de curso consulta para assistência o horário das aulas ? 0
#    11272 - Quem a coordenação de curso consulta para lhe o horário das aulas ? 0
#    11273 - Quem a coordenação de curso consulta para compro o horário das aulas ? 0
#    11274 - Quem a coordenação de curso consulta para refere o horário das aulas ? 0
#    11275 - Quem a coordenação de curso declarou para elaborar o horário das aulas ? 0
#    11276 - Quem a coordenação de curso consulta para intervalo o horário das aulas ? 0
#    11277 - Quem a coordenação de curso envolvem para elaborar o horário das aulas ? 0
#    11278 - Quem a coordenação de curso baixa para elaborar o horário das aulas ? 0
#    11279 - Quem a coordenação de curso consulta para banco o horário das aulas ? 0
#    11280 - Quem a coordenação de curso consulta para todos o horário das aulas ? 0
#    11281 - Quem a coordenação de curso consulta para votação o horário das aulas ? 0
#    11282 - Quem a coordenação de curso seja para elaborar o horário das aulas ? 0
#    11283 - Quem a coordenação de curso manteve para elaborar o horário das aulas ? 0
#    11284 - Quem a coordenação de curso lança para elaborar o horário das aulas ? 0
#    11285 - Quem a coordenação de curso consulta para entre o horário das aulas ? 0
#    11286 - Quem a coordenação de curso autorização para elaborar o horário das aulas ? 0
#    11287 - Quem indicar os horários das aulas ? 0
#    11288 - Quem autor os horários das aulas ? 0
#    11289 - Quem formam os horários das aulas ? 0
#    11290 - Quem percebeu os horários das aulas ? 0
#    11291 - Quem alterar os horários das aulas ? 0
#    11292 - Quem realmente os horários das aulas ? 0
#    11293 - Quem visita os horários das aulas ? 0
#    11294 - Quem mod os horários das aulas ? 0
#    11295 - Quem qual os horários das aulas ? 0
#    11296 - Quem admite os horários das aulas ? 0
#    11297 - Quem trabalham os horários das aulas ? 0
#    11298 - Quem carrega os horários das aulas ? 0
#    11299 - Quem possuía os horários das aulas ? 0
#    11300 - Quem concentra os horários das aulas ? 0
#    11301 - Quem ampliou os horários das aulas ? 0
#    11302 - Em quais casos o acadêmico pode imediata a matrícula nos dois primeiros períodos letivos ? 0
#    11303 - Em quais casos o acadêmico observar trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11304 - Em quais casos o acadêmico passou trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11305 - Em quais casos o acadêmico vão trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11306 - Em quais casos o acadêmico testemunha trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11307 - Em quais casos o acadêmico lembra trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11308 - Em quais casos o acadêmico 2016 trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11309 - Em quais casos o acadêmico per trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11310 - Em quais casos o acadêmico pode estender a matrícula nos dois primeiros períodos letivos ? 0
#    11311 - Em quais casos o acadêmico pode pedido a matrícula nos dois primeiros períodos letivos ? 0
#    11312 - Em quais casos o acadêmico pode sucessivamente a matrícula nos dois primeiros períodos letivos ? 0
#    11313 - Em quais casos o acadêmico obrigação trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11314 - Em quais casos o acadêmico pode buscar a matrícula nos dois primeiros períodos letivos ? 0
#    11315 - Em quais casos o acadêmico procurado trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11316 - Em quais casos o acadêmico obriga trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11317 - Em quais casos o acadêmico manda trancar a matrícula nos dois primeiros períodos letivos ? 0
#    11318 - Em quais casos o acadêmico pode militar a matrícula nos dois primeiros períodos letivos ? 0
#    11319 - Por quanto tempo a matrícula pode ser post ? 0
#    11320 - Por quanto tempo a matrícula pode ser utilizado ? 0
#    11321 - Por quanto tempo a matrícula provou ser trancada ? 0
#    11322 - Por quanto tempo a matrícula pode ser masculina ? 0
#    11323 - Por quanto tempo a matrícula pode ser afeta ? 0
#    11324 - Por quanto tempo a matrícula força ser trancada ? 0
#    11325 - Por quanto tempo a matrícula passe ser trancada ? 0
#    11326 - Por quanto tempo a matrícula pode ser amiga ? 0
#    11327 - Por quanto tempo a matrícula lava ser trancada ? 0
#    11328 - Por quanto tempo a matrícula E ser trancada ? 0
#    11329 - Por quanto tempo a matrícula pode ser mesmo ? 0
#    11330 - Por quanto tempo a matrícula FI ser trancada ? 0
#    11331 - Por quanto tempo a matrícula pode ser d ? 0
#    11332 - Por quanto tempo a matrícula pode ser início ? 0
#    11333 - Por quanto tempo a matrícula pode ser referente ? 0
#    11334 - Por quanto tempo a matrícula pode ser original ? 0
#    11335 - Por quanto tempo a matrícula pode ser defendida ? 0
#    11336 - Por quanto tempo a matrícula pode ser indicada ? 0
#    11337 - O que o professor deve simples aos alunos na primeira aula ? 0
#    11338 - O que o professor devem apresentar aos alunos na primeira aula ? 0
#    11339 - O que o professor eficiente apresentar aos alunos na primeira aula ? 0
#    11340 - O que o professor ganha apresentar aos alunos na primeira aula ? 0
#    11341 - O que o professor prevê apresentar aos alunos na primeira aula ? 0
#    11342 - O que o professor te apresentar aos alunos na primeira aula ? 0
#    11343 - O que o professor docente apresentar aos alunos na primeira aula ? 0
#    11344 - O que o professor geralmente apresentar aos alunos na primeira aula ? 0
#    11345 - O que o professor deve retomar aos alunos na primeira aula ? 0
#    11346 - O que o professor considera apresentar aos alunos na primeira aula ? 0
#    11347 - O que o professor ambiental apresentar aos alunos na primeira aula ? 0
#    11348 - O que o professor deve aparecer aos alunos na primeira aula ? 0
#    11349 - O que o professor deve pouco aos alunos na primeira aula ? 0
#    11350 - O que o professor deve ger aos alunos na primeira aula ? 0
#    11351 - O que o professor encaminh apresentar aos alunos na primeira aula ? 0
#    11352 - O que o professor mínimo apresentar aos alunos na primeira aula ? 0
#    11353 - O que o professor estabelece apresentar aos alunos na primeira aula ? 0
#    11354 - O que o professor deve aviso aos alunos na primeira aula ? 0
#    11355 - O que o professor deixou apresentar aos alunos na primeira aula ? 0
#    11356 - O que o professor deve importante aos alunos na primeira aula ? 0
#    11357 - Qual o prazo de aprovação do plano de fases das disciplinas ? 0
#    11358 - Qual o prazo de aprovação do plano de maioria das disciplinas ? 0
#    11359 - Qual o prazo de edições do plano de ensino das disciplinas ? 0
#    11360 - Qual o prazo de aprovação do plano de exigências das disciplinas ? 0
#    11361 - Qual o prazo de aprovação do plano de quebra das disciplinas ? 0
#    11362 - Qual o prazo de aprovação do plano de direção das disciplinas ? 0
#    11363 - Qual o prazo de decorrer do plano de ensino das disciplinas ? 0
#    11364 - Qual o previsão de aprovação do plano de ensino das disciplinas ? 0
#    11365 - Qual o prazo de aprovação do plano de ensino das finalistas ? 0
#    11366 - Qual o prazo de fato do plano de ensino das disciplinas ? 0
#    11367 - Qual o s de aprovação do plano de ensino das disciplinas ? 0
#    11368 - Qual o recomenda de aprovação do plano de ensino das disciplinas ? 0
#    11369 - Qual o prazo de aprovação do plano de ensino das portuguesas ? 0
#    11370 - Qual o prazo de aprovação do plano de absorção das disciplinas ? 0
#    11371 - Qual o prazo de aprovação do agente de ensino das disciplinas ? 0
#    11372 - Qual o desenvolvimento de aprovação do plano de ensino das disciplinas ? 0
#    11373 - Qual o prazo de equilíbrio do plano de ensino das disciplinas ? 0
#    11374 - Qual o prazo de aprovação do plano de localização das disciplinas ? 0
#    11375 - Qual o jogo de aprovação do plano de ensino das disciplinas ? 0
#    11376 - Qual o prazo de aprovação do plano de outra das disciplinas ? 0
#    11377 - Quando os professores podem ingressou no Siscad ? 0
#    11378 - Quando os professores w lançar no Siscad ? 0
#    11379 - Quando os professores inov lançar no Siscad ? 0
#    11380 - Quando os professores sem lançar no Siscad ? 0
#    11381 - Quando os professores podem créditos no Siscad ? 0
#    11382 - Quando os professores fará lançar no Siscad ? 0
#    11383 - Quando os professores requis lançar no Siscad ? 0
#    11384 - Quando os professores introduzir lançar no Siscad ? 0
#    11385 - Quando os professores passaria lançar no Siscad ? 0
#    11386 - Quando os professores podem presença no Siscad ? 0
#    11387 - Quando os professores CP lançar no Siscad ? 0
#    11388 - Quando os professores podem para no Siscad ? 0
#    11389 - Quando os professores podem informou no Siscad ? 0
#    11390 - Quando os professores v lançar no Siscad ? 0
# ...
#    15569 - qual o número mínimo de alunos para se retomar uma disciplina regular ? 0
#    15570 - qual o número mínimo de alunos para se chegar uma disciplina regular ? 0
#    15571 - qual o número mínimo de alunos para se vive uma disciplina regular ? 0
#    15572 - qual o número mínimo de alunos para se que uma disciplina regular ? 0
#    15573 - qual o número mínimo de alunos para se cometer uma disciplina regular ? 0
#    15574 - quem é responsável pela introdução do cumprimento das atividades complementares ? 0
#    15575 - quem é responsável pela certificado do cumprimento das atividades complementares ? 0
#    15576 - quem é responsável pela ; do cumprimento das atividades complementares ? 0
#    15577 - quem é responsável pela verificação do cumprimento das doações complementares ? 0
#    15578 - quem é responsável pela família do cumprimento das atividades complementares ? 0
#    15579 - quem é responsável pela valorização do cumprimento das atividades complementares ? 0
#    15580 - quem é responsável pela verificação do cumprimento das art complementares ? 0
#    15581 - quem é responsável pela verificação do cumprimento das escavações complementares ? 0
#    15582 - quem é responsável pela verificação do gerente das atividades complementares ? 0
#    15583 - quem é responsável pela verificação do cumprimento das cer complementares ? 0
#    15584 - quem é responsável pela verificação do carbono das atividades complementares ? 0
#    15585 - quem é responsável pela verificação do log das atividades complementares ? 0
#    15586 - quem é responsável pela verificação do turismo das atividades complementares ? 0
#    15587 - quem é responsável pela verificação do cumprimento das cadeiras complementares ? 0
#    15588 - quem é responsável pela encarregado do cumprimento das atividades complementares ? 0
#    15589 - quem é responsável pela verificação do cumprimento das causas complementares ? 0
#    15590 - qual a frequência mínima política para aprovação em uma disciplina ? 0
#    15591 - qual a frequência mínima corresponde para aprovação em uma disciplina ? 0
#    15592 - qual a frequência mínima consciente para aprovação em uma disciplina ? 0
#    15593 - qual a frequência mínima montada para aprovação em uma disciplina ? 0
#    15594 - qual a frequência mínima estatística para aprovação em uma disciplina ? 0
#    15595 - qual a frequência mínima quo para aprovação em uma disciplina ? 0
#    15596 - qual a frequência mínima entregue para aprovação em uma disciplina ? 0
#    15597 - qual a frequência mínima referente para aprovação em uma disciplina ? 0
#    15598 - qual a frequência mínima ncia para aprovação em uma disciplina ? 0
#    15599 - qual a frequência mínima celular para aprovação em uma disciplina ? 0
#    15600 - qual a frequência mínima casada para aprovação em uma disciplina ? 0
#    15601 - qual a frequência mínima ? para aprovação em uma disciplina ? 0
#    15602 - qual a frequência mínima dever para aprovação em uma disciplina ? 0
#    15603 - qual a frequência mínima islâmica para aprovação em uma disciplina ? 0
#    15604 - qual a frequência mínima medida para aprovação em uma disciplina ? 0
#    15605 - qual a frequência mínima financeira para aprovação em uma disciplina ? 0
#    15606 - qual a frequência mínima denominada para aprovação em uma disciplina ? 0
#    15607 - qual a frequência mínima II para aprovação em uma disciplina ? 0
#    15608 - qual a frequência mínima definida para aprovação em uma disciplina ? 0
#    15609 - qual a frequência mínima natural para aprovação em uma disciplina ? 0
#    15610 - como o acadêmico apoia revisão de avaliação de disciplina ? 0
#    15611 - como o acadêmico alimenta revisão de avaliação de disciplina ? 0
#    15612 - como o acadêmico oferece revisão de avaliação de disciplina ? 0
#    15613 - como o acadêmico pronuncia revisão de avaliação de disciplina ? 0
#    15614 - como o acadêmico consta revisão de avaliação de disciplina ? 0
#    15615 - como o acadêmico exercer revisão de avaliação de disciplina ? 0
#    15616 - como o acadêmico perio revisão de avaliação de disciplina ? 0
#    15617 - como o acadêmico reconhecer revisão de avaliação de disciplina ? 0
#    15618 - como o acadêmico question revisão de avaliação de disciplina ? 0
#    15619 - como o acadêmico venceu revisão de avaliação de disciplina ? 0
#    15620 - como o acadêmico citou revisão de avaliação de disciplina ? 0
#    15621 - como o acadêmico perante revisão de avaliação de disciplina ? 0
#    15622 - como o acadêmico cometeu revisão de avaliação de disciplina ? 0
#    15623 - como o acadêmico nota revisão de avaliação de disciplina ? 0
#    15624 - como o acadêmico garante revisão de avaliação de disciplina ? 0
#    15625 - como é integrado a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15626 - como é sob a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15627 - como é celebrada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15628 - como é necessária a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15629 - como é definir a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15630 - como é entender a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15631 - como é mantidas a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15632 - como é observando a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15633 - como é construída a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15634 - como é indicado a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15635 - como é óptica a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15636 - como é teórica a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15637 - como é prioridade a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15638 - como é nomeada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15639 - como é presente a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15640 - como é diferencia a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15641 - como é utilizado a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15642 - como é referente a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    15643 - como o aluno Federal solicitar a revisão de sua frequência em uma disciplina ? 0
#    15644 - como o aluno deve conforme a revisão de sua frequência em uma disciplina ? 0
#    15645 - como o aluno ameaça solicitar a revisão de sua frequência em uma disciplina ? 0
#    15646 - como o aluno deve ele a revisão de sua frequência em uma disciplina ? 0
#    15647 - como o aluno deve alvo a revisão de sua frequência em uma disciplina ? 0
#    15648 - como o aluno informou solicitar a revisão de sua frequência em uma disciplina ? 0
#    15649 - como o aluno deve – a revisão de sua frequência em uma disciplina ? 0
#    15650 - como o aluno prevê solicitar a revisão de sua frequência em uma disciplina ? 0
#    15651 - como o aluno pessoa solicitar a revisão de sua frequência em uma disciplina ? 0
#    15652 - como o aluno escola solicitar a revisão de sua frequência em uma disciplina ? 0
#    15653 - como o aluno sei solicitar a revisão de sua frequência em uma disciplina ? 0
#    15654 - como o aluno data solicitar a revisão de sua frequência em uma disciplina ? 0
#    15655 - como o aluno deve seria a revisão de sua frequência em uma disciplina ? 0
#    15656 - como o aluno prefere solicitar a revisão de sua frequência em uma disciplina ? 0
#    15657 - como o aluno deve confirmar a revisão de sua frequência em uma disciplina ? 0
#    15658 - como o aluno a solicitar a revisão de sua frequência em uma disciplina ? 0
#    15659 - como o aluno através solicitar a revisão de sua frequência em uma disciplina ? 0
#    15660 - como o aluno deverá solicitar a revisão de sua frequência em uma disciplina ? 0
#    15661 - como o aluno percebe solicitar a revisão de sua frequência em uma disciplina ? 0
#    15662 - como o aluno faz solicitar a revisão de sua frequência em uma disciplina ? 0
#    15663 - em quantas discplinas o acadêmico funda inscrever-se durante o período letivo especial ? 0
#    15664 - em quantas discplinas o acadêmico tenta inscrever-se durante o período letivo especial ? 0
#    15665 - em quantas discplinas o acadêmico poderá agenda durante o período letivo especial ? 0
#    15666 - em quantas discplinas o acadêmico devem inscrever-se durante o período letivo especial ? 0
#    15667 - em quantas discplinas o acadêmico poderá envolver durante o período letivo especial ? 0
#    15668 - em quantas discplinas o acadêmico ativo inscrever-se durante o período letivo especial ? 0
#    15669 - em quantas discplinas o acadêmico poderá acreditar durante o período letivo especial ? 0
#    15670 - em quantas discplinas o acadêmico poderá compor durante o período letivo especial ? 0
#    15671 - em quantas discplinas o acadêmico poderá trans durante o período letivo especial ? 0
#    15672 - em quantas discplinas o acadêmico poderá transmitir durante o período letivo especial ? 0
#    15673 - em quantas discplinas o acadêmico poderá ele durante o período letivo especial ? 0
#    15674 - em quantas discplinas o acadêmico poderá altern durante o período letivo especial ? 0
#    15675 - em quantas discplinas o acadêmico poderá provar durante o período letivo especial ? 0
#    15676 - em quantas discplinas o acadêmico médico inscrever-se durante o período letivo especial ? 0
#    15677 - em quantas discplinas o acadêmico poderá tira durante o período letivo especial ? 0
#    15678 - em quantas discplinas o acadêmico poderá descobrir durante o período letivo especial ? 0
#    15679 - em quantas discplinas o acadêmico entrou inscrever-se durante o período letivo especial ? 0
#    15680 - qual o eu maximo de duração do trancamento ? 0
#    15681 - qual o HD maximo de duração do trancamento ? 0
#    15682 - qual o período maximo de duração do arquivo ? 0
#    15683 - qual o durante maximo de duração do trancamento ? 0
#    15684 - qual o download maximo de duração do trancamento ? 0
#    15685 - qual o novo maximo de duração do trancamento ? 0
#    15686 - qual o período maximo de contrato do trancamento ? 0
#    15687 - qual o fica maximo de duração do trancamento ? 0
#    15688 - qual o período maximo de duração do tempo ? 0
#    15689 - qual o potencial maximo de duração do trancamento ? 0
#    15690 - qual o do maximo de duração do trancamento ? 0
#    15691 - qual o período maximo de duração do circuito ? 0
#    15692 - qual o sentimento maximo de duração do trancamento ? 0
#    15693 - qual o endereço maximo de duração do trancamento ? 0
#    15694 - qual o período maximo de escalada do trancamento ? 0
#    15695 - qual o período maximo de dinheiro do trancamento ? 0
#    15696 - qual o período maximo de duração do clube ? 0
#    15697 - qual o período maximo de duração do escudo ? 0
#    15698 - qual o ? maximo de duração do trancamento ? 0
#    15699 - qual o período maximo de duração do partido ? 0
#    15700 - como faço para não mantêm o vínculo acadêmico ? 0
#    15701 - como ensino para não perder o vínculo acadêmico ? 0
#    15702 - como faço para não paga o vínculo acadêmico ? 0
#    15703 - como dificuldades para não perder o vínculo acadêmico ? 0
#    15704 - como faço para não assassinar o vínculo acadêmico ? 0
#    15705 - como liderar para não perder o vínculo acadêmico ? 0
#    15706 - como faço para não questiona o vínculo acadêmico ? 0
#    15707 - como ganhar para não perder o vínculo acadêmico ? 0
#    15708 - como apresentar para não perder o vínculo acadêmico ? 0
#    15709 - como ponto para não perder o vínculo acadêmico ? 0
#    15710 - como faço para não complicações o vínculo acadêmico ? 0
#    15711 - como faço para não complicações o vínculo acadêmico ? 0
#    15712 - como responder para não perder o vínculo acadêmico ? 0
#    15713 - como faço para não dificuldades o vínculo acadêmico ? 0
#    15714 - como faço para não financiar o vínculo acadêmico ? 0
#    15715 - como faço para não comprome o vínculo acadêmico ? 0
#    15716 - qual a palestra horária mínima do encontro presencial ? 0
#    15717 - qual a carga interessante mínima do encontro presencial ? 0
#    15718 - qual a carga notur mínima do encontro presencial ? 0
#    15719 - qual a carga orça mínima do encontro presencial ? 0
#    15720 - qual a carga super mínima do encontro presencial ? 0
#    15721 - qual a carga avalia mínima do encontro presencial ? 0
#    15722 - qual a carga ! mínima do encontro presencial ? 0
#    15723 - qual a carga horária mínima do passado presencial ? 0
#    15724 - qual a superioridade horária mínima do encontro presencial ? 0
#    15725 - qual a carga curta mínima do encontro presencial ? 0
#    15726 - qual a carga preciso mínima do encontro presencial ? 0
#    15727 - qual a carga horária mínima do intérprete presencial ? 0
#    15728 - qual a carga horária mínima do índice presencial ? 0
#    15729 - qual a carga v mínima do encontro presencial ? 0
#    15730 - qual a peça horária mínima do encontro presencial ? 0
#    15731 - qual a palavra horária mínima do encontro presencial ? 0
#    15732 - qual a expo horária mínima do encontro presencial ? 0
#    15733 - qual a carga gratuita mínima do encontro presencial ? 0
#    15734 - qual a carga horária mínima do prático presencial ? 0
#    15735 - qual a próxima horária mínima do encontro presencial ? 0
#    15736 - de quando é a filial no 401 ? 0
#    15737 - o que a resolução no 401 autorização ? 0
#    15738 - o que a resolução no 401 adia ? 0
#    15739 - o que a resolução no 401 nega ? 0
#    15740 - o que a resolução no 401 registra ? 0
#    15741 - o que a resolução no 401 en ? 0
#    15742 - o que a resolução no 401 grava ? 0
#    15743 - o que a resolução no 401 consulta ? 0
#    15744 - o que a resolução no 401 objetivo ? 0
#    15745 - o que a resolução no 401 contem ? 0
#    15746 - o que a resolução no 401 inclusão ? 0
#    15747 - o que a resolução no 401 objeto ? 0
#    15748 - o que a resolução no 401 expressa ? 0
#    15749 - o que a resolução no 401 continha ? 0
#    15750 - o que a resolução no 401 acrescenta ? 0
#    15751 - o que a resolução no 401 ) ? 0
#    15752 - o que a resolução no 401 2014 ? 0
#    15753 - o que a resolução no 401 dizia ? 0
#    15754 - o que a resolução no 401 criticou ? 0
#    15755 - o que a resolução no 401 supri ? 0
#    15756 - reconhece lei sobre a transferência compulsória ? 0
#    15757 - pergunta lei sobre a transferência compulsória ? 0
#    15758 - Química lei sobre a transferência compulsória ? 0
#    15759 - § lei sobre a transferência compulsória ? 0
#    15760 - Lua lei sobre a transferência compulsória ? 0
#    15761 - apresentou lei sobre a transferência compulsória ? 0
#    15762 - objetiva lei sobre a transferência compulsória ? 0
#    15763 - estabelecer lei sobre a transferência compulsória ? 0
#    15764 - Difere lei sobre a transferência compulsória ? 0
#    15765 - Eu lei sobre a transferência compulsória ? 0
#    15766 - Lí lei sobre a transferência compulsória ? 0
#    15767 - Cad lei sobre a transferência compulsória ? 0
#    15768 - Meta lei sobre a transferência compulsória ? 0
#    15769 - Penal lei sobre a transferência compulsória ? 0
#    15770 - propõe lei sobre a transferência compulsória ? 0
#    15771 - Come lei sobre a transferência compulsória ? 0
#    15772 - Movimento lei sobre a transferência compulsória ? 0
#    15773 - tens lei sobre a transferência compulsória ? 0

# %% [markdown]
# #### Lista Documentos Perturbados(0-incoerente) medidos  incorretamente(1-coerente)

# %%
def listaPerturbadoMedidosIncorretamente(dfListaParesDocumentosMedidas, medida):
  listaRetorno = []  
  for i, linha in dfListaParesDocumentosMedidas.iterrows():
    # Medida de similaridade do cosseno
    if medida == "ccos":
      if linha[medida + 'DO'] > linha[ medida + 'Pert']:
         listaRetorno.append(linha['idPert'])
    else:
        # Medida de distância (euc, man)
        if linha[medida + 'DO'] > linha[ medida + 'Pert']:
           listaRetorno.append(linha['idPert'])
          
  dflistaRetorno = pd.DataFrame(listaRetorno, columns = ["id"])
  return dflistaRetorno

# %%
listaDocumentoPerturbadoMedidoIncorretamente = listaPerturbadoMedidosIncorretamente(dfListaParesDocumentosMedidasBERT,MELHOR_MEDIDA_GERAL_STR)

print("Lista de documentos perturbados medidos incorretamente:",len(listaDocumentoPerturbadoMedidoIncorretamente))
# Out:
# Lista de documentos perturbados medidos incorretamente: 2226

# %%
print("Lista de documentos perturbados medidos incorretamente(coerentes)(CSm(DO) < CSm(pertDO)):", len(listaDocumentoPerturbadoMedidoIncorretamente))
for i, documento in listaDocumentoPerturbadoMedidoIncorretamente.iterrows():
    # Recupera o documento a ser exibido   
    documento = dflista_documentos_agrupados.loc[dflista_documentos_agrupados["id"] == documento["id"]]   
    
    print("  ",i, "-", documento['documento'].values[0], documento['classe'].values[0])
# Out:
# Lista de documentos perturbados medidos incorretamente(coerentes)(CSm(DO) < CSm(pertDO)): 2226
#    0 - Como iria ser definido um sistema de informação ? 0
#    1 - Como pode ser controlado um sistema de informação ? 0
#    2 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação chegou ? 0
#    3 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação travada ? 0
#    4 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação aliada ? 0
#    5 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação pesquisa ? 0
#    6 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação iniciada ? 0
#    7 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação perigosa ? 0
#    8 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação alta ? 0
#    9 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação restrita ? 0
#    10 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação compreende ? 0
#    11 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação Antiga ? 0
#    12 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação sonora ? 0
#    13 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação publicado ? 0
#    14 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação substancial ? 0
#    15 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação aguda ? 0
#    16 - Por que a preocupação com a coleta , armazenamento , processamento e transmissão da informação relevantes ? 0
#    17 - Qual um futuro indispensável nas organizações ? 0
#    18 - Qual um componente indispensável nas seguintes ? 0
#    19 - Qual um componente indispensável nas instituições ? 0
#    20 - Qual um componente indispensável nas fontes ? 0
#    21 - O que é teoria de sistemas ? 0
#    22 - O que é análise de assuntos ? 0
#    23 - O que é análise de cor ? 0
#    24 - O que é análise de doenças ? 0
#    25 - O que é análise de agenda ? 0
#    26 - O que é análise de culpa ? 0
#    27 - O que é análise de preço ? 0
#    28 - O que é análise de custos ? 0
#    29 - O que é integração de sistemas ? 0
#    30 - Onde são os os softwares gerados pelos profissionais da área ? 0
#    31 - Onde são presentes as informações levantadas sobre uma empresa ? 0
#    32 - Onde são utilizadas as informações positivas sobre uma empresa ? 0
#    33 - O que mais com que profissionais que não possuem educação superior compram o papel de analista de sistemas ? 0
#    34 - O que permite com que profissionais que não tenham educação superior compram o papel de analista de sistemas ? 0
#    35 - O que permite com que profissionais que não issem educação superior compram o papel de analista de sistemas ? 0
#    36 - Por que o analista de sistemas poderia traduzir a necessidade do usuário ? 0
#    37 - Quem desenvolve o programa criado da necessidade do usuário pelo analista de sistemas ? 0
#    38 - Quem administra o programa traduzido da necessidade do usuário pelo analista de sistemas ? 0
#    39 - Por quem foi mesmo a profissão de tecnólogo em análise e desenvolvimento de sistemas ? 0
#    40 - Por quem foi tem a profissão de tecnólogo em análise e desenvolvimento de sistemas ? 0
#    41 - Qual diálogo é fundamental em qualquer atividade empresarial ? 0
#    42 - Por que o estágio é a mais outra forma dentre as opções de atividade complementar de extensão ? 0
#    43 - Por que o estágio é a mais repu forma dentre as opções de atividade complementar de extensão ? 0
#    44 - Por que o estágio é a mais suave forma dentre as opções de atividade complementar de extensão ? 0
#    45 - Por que o estágio é a mais visa forma dentre as opções de atividade complementar de extensão ? 0
#    46 - Por que o estágio é a mais brilhante forma dentre as opções de atividade complementar de extensão ? 0
#    47 - Por que o estágio é a mais envolve forma dentre as opções de atividade complementar de extensão ? 0
#    48 - Por que o estágio é a mais utiliza forma dentre as opções de atividade complementar de extensão ? 0
#    49 - Por que o estágio é a mais sens forma dentre as opções de atividade complementar de extensão ? 0
#    50 - Por que o estágio é a mais hon forma dentre as opções de atividade complementar de extensão ? 0
#    51 - Por que o estágio é a mais subl forma dentre as opções de atividade complementar de extensão ? 0
#    52 - Por que o estágio é a mais agress forma dentre as opções de atividade complementar de extensão ? 0
#    53 - Por que o estágio é a mais aque forma dentre as opções de atividade complementar de extensão ? 0
#    54 - Por que o estágio é a mais proba forma dentre as opções de atividade complementar de extensão ? 0
#    55 - Por que o estágio é a mais aguda forma dentre as opções de atividade complementar de extensão ? 0
#    56 - Quais alguns exemplos de atividades de atletas ? 0
#    57 - Quais alguns exemplos de atividades de bastidores ? 0
#    58 - Quais alguns exemplos de atividades de estética ? 0
#    59 - Qual a mais famosa opção de atividade complementar de transporte ? 0
#    60 - Qual a mais famosa opção de atividade complementar de negócio ? 0
#    61 - Qual a mais famosa opção de atividade complementar de dinossauros ? 0
#    62 - Qual a mais famosa explicação de atividade complementar de extensão ? 0
#    63 - Qual a mais famosa opção de atividade complementar de tratamento ? 0
#    64 - Qual a mais famosa célula de atividade complementar de extensão ? 0
#    65 - Qual a mais famosa opção de atividade complementar de integração ? 0
#    66 - Qual o objetivo das atividades complementares de restauração ? 0
#    67 - Qual o objetivo das atividades complementares de área ? 0
#    68 - Qual o objetivo das atividades complementares de professores ? 0
#    69 - Qual o objetivo das atividades complementares de exercícios ? 0
#    70 - Qual o objetivo das atividades complementares de professor ? 0
#    71 - Quantas horas de atividade complementar os estudantes de licenciatura erem realizar ? 0
#    72 - O que significa olhar outras coisas fora do ambiente de ensino acadêmico ? 0
#    73 - Qual a principal programação das atividades complementares ? 0
#    74 - Qual a principal escala das atividades complementares ? 0
#    75 - Qual a principal associação das atividades complementares ? 0
#    76 - Qual a principal entrada das atividades complementares ? 0
#    77 - Com o que as atividades complementares estão ? 0
#    78 - O que quer dizer quando um professor opta por registrar a sua matéria através de seminários ao invés de provas ? 0
#    79 - O que quer dizer quando um professor opta por fortemente a sua matéria através de seminários ao invés de provas ? 0
#    80 - Qual o objetivo das frentes complementares ? 0
#    81 - Qual o objetivo das centrais complementares ? 0
#    82 - Qual o ano das ativdades complementares ? 0
#    83 - O que é necessário itado para comprovar a participação em um evento ? 0
#    84 - O que é necessário descobrir para comprovar a participação em um evento ? 0
#    85 - O que é necessário apresentar para continuar a participação em um evento ? 0
#    86 - Qual o valor de um especialista na maioria das universidades ? 0
#    87 - Qual o valor de um assessor na maioria das universidades ? 0
#    88 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade bus 30 créditos ? 0
#    89 - Quantas horas de atividades extra-curriculares devem ser adas caso a faculdade exige 30 créditos ? 0
#    90 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade vol 30 créditos ? 0
#    91 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade cadas 30 créditos ? 0
#    92 - Quantas horas de atividades extra-curriculares devem ser realizadas caso a faculdade som 30 créditos ? 0
#    93 - Qual uma rotina entre o ensino médio e faculdade ? 0
#    94 - Qual uma disputa entre o ensino médio e faculdade ? 0
#    95 - É diferentes formas de pesquisa nos ajudam com o quê ? 0
#    96 - Má diferentes formas de pesquisa nos ajudam com o quê ? 0
#    97 - 19 diferentes formas de pesquisa nos ajudam com o quê ? 0
#    98 - Corre diferentes formas de pesquisa nos ajudam com o quê ? 0
#    99 - At diferentes formas de pesquisa nos ajudam com o quê ? 0
#    100 - _ diferentes formas de pesquisa nos ajudam com o quê ? 0
#    101 - Sociais diferentes formas de pesquisa nos ajudam com o quê ? 0
#    102 - Corte diferentes formas de pesquisa nos ajudam com o quê ? 0
#    103 - Compreender diferentes formas de pesquisa nos artigos com o quê ? 0
#    104 - L diferentes formas de pesquisa nos ajudam com o quê ? 0
#    105 - Primeiro diferentes formas de pesquisa nos ajudam com o quê ? 0
#    106 - Real diferentes formas de pesquisa nos ajudam com o quê ? 0
#    107 - Por que ceder diversas metodologias , sistemas e análise e outros meios de guiar um estudo é tão importante ? 0
#    108 - Por que comprar diversas metodologias , sistemas e análise e outros meios de guiar um estudo é tão importante ? 0
#    109 - Por que influenciar diversas metodologias , sistemas e análise e outros meios de guiar um estudo é tão importante ? 0
#    110 - Por que comandar diversas metodologias , sistemas e análise e outros meios de guiar um estudo é tão importante ? 0
#    111 - Por que prosseguir diversas metodologias , sistemas e análise e outros meios de guiar um estudo é tão importante ? 0
#    112 - Por que eventualmente diversas metodologias , sistemas e análise e outros meios de guiar um estudo é tão importante ? 0
#    113 - Para que os alunos fizeram atividades complementares ? 0
#    114 - Para que os alunos tenham atividades complementares ? 0
#    115 - O ensino superior é distribuído por quais cursos ? 0
#    116 - Em que ano o ENEM ificou 9,2 milhões de escritos ? 0
#    117 - Por que em 2019 o ENEM abriga um número bastante considerável de inscritos ? 0
#    118 - Por que em 2019 o ENEM reuniram um número bastante considerável de inscritos ? 0
#    119 - Por que em 2019 o ENEM + um número bastante considerável de inscritos ? 0
#    120 - Por que em 2019 o ENEM acredita um número bastante considerável de inscritos ? 0
#    121 - Por que em 2019 o ENEM buscava um número bastante considerável de inscritos ? 0
#    122 - Por que em 2019 o ENEM trazia um número bastante considerável de inscritos ? 0
#    123 - Por que em 2019 o ENEM estabelece um número bastante considerável de inscritos ? 0
#    124 - Por que em 2019 o ENEM acabou um número bastante considerável de inscritos ? 0
#    125 - Por que em 2019 o ENEM afeta um número bastante considerável de inscritos ? 0
#    126 - Por que em 2019 o ENEM tentou um número bastante considerável de inscritos ? 0
#    127 - Por que em 2019 o ENEM ficaria um número bastante considerável de inscritos ? 0
#    128 - Por que em 2019 o ENEM explica um número bastante considerável de inscritos ? 0
#    129 - Por que em 2019 o ENEM inicia um número bastante considerável de inscritos ? 0
#    130 - Por que em 2019 o ENEM estuda um número bastante considerável de inscritos ? 0
#    131 - Por que em 2019 o ENEM abre um número bastante considerável de inscritos ? 0
#    132 - Por que em 2019 o ENEM retorna um número bastante considerável de inscritos ? 0
#    133 - Como são mentadas as versões mais modernas do ábaco ? 0
#    134 - Por quem eram ificadas as tabelas logarítmicas ? 0
#    135 - Por quem eram aquelas as tabelas logarítmicas ? 0
#    136 - Por quem eram nós as tabelas logarítmicas ? 0
#    137 - Por quem eram criadas as tabelas logarítmicas ? 0
#    138 - Qual era o uso original do menino ? 0
#    139 - Qual era o uso original do ritual ? 0
#    140 - Qual era o uso original do circo ? 0
#    141 - Qual era o uso original do xadrez ? 0
#    142 - Qual era o uso original do gato ? 0
#    143 - Qual era o uso original do Centro ? 0
#    144 - Qual foi a primeira ferramenta cristã para a computação ? 0
#    145 - Qual foi a primeira ferramenta central para a computação ? 0
#    146 - Qual foi a primeira ferramenta mental para a computação ? 0
#    147 - Qual foi a primeira ferramenta prática para a computação ? 0
#    148 - Qual foi a primeira ferramenta doméstica para a computação ? 0
#    149 - Qual foi a primeira ferramenta avançada para a computação ? 0
#    150 - Qual foi a primeira ferramenta mínima para a computação ? 0
#    151 - Qual foi a primeira ferramenta organizada para a computação ? 0
#    152 - Quantas regras Pānini surgiram para formular a gramática de Sânscrito ? 0
#    153 - Quem quer o logaritmo ? 0
#    154 - A quem era Jesus o termo computador ? 0
#    155 - Em que eram empregados os ingleses antes da década de 1920 ? 0
#    156 - Em que eram empregados os funcionários antes da década de 1920 ? 0
#    157 - Em que eram empregados os ministros antes da década de 1920 ? 0
#    158 - Em que eram empregados os limites antes da década de 1920 ? 0
#    159 - Em que eram empregados os exercícios antes da década de 1920 ? 0
#    160 - Em que eram empregados os estúdios antes da década de 1920 ? 0
#    161 - Quando o termo máquina computacional fez espaço para o termo computador ? 0
#    162 - Quando o termo máquina computacional cria espaço para o termo computador ? 0
#    163 - Ao que a ciência da computação demanda ? 0
#    164 - Ao que a ciência da computação permite ? 0
#    165 - Ao que a ciência da computação pensava ? 0
#    166 - Ao que a ciência da computação chega ? 0
#    167 - Ao que a ciência da computação está ? 0
#    168 - Ao que a ciência da computação avalia ? 0
#    169 - Quais recursos estão fora do contexto da ciência da computação ? 0
#    170 - Quais contatos estão fora do contexto da ciência da computação ? 0
#    171 - Quais disciplinas estão fora do oceano da ciência da computação ? 0
#    172 - Quais palestras estão fora do contexto da ciência da computação ? 0
#    173 - Quais dificuldades estão fora do contexto da ciência da computação ? 0
#    174 - Quais salários estão fora do contexto da ciência da computação ? 0
#    175 - Quem é considerado o autor da frase ” Ciência da Computação tem tanto a crédito com o computador como a astronomia com o telescópio [ … ] " ? 0
#    176 - Quem é considerado o autor da frase ” Ciência da Computação tem tanto a chinesa com o computador como a astronomia com o telescópio [ … ] " ? 0
#    177 - O que Claude Shannon tizou no artigo A Mathematical Theory of Communication ? 0
#    178 - O que Claude Shannon deu no artigo A Mathematical Theory of Communication ? 0
#    179 - Quais áreas são postas no conteúdo da teoria da informação ? 0
#    180 - O que é ciência da fala ? 0
#    181 - Quais estudos além dos algoritmos a ciência da computação possibilita ? 0
#    182 - Quais estudos além dos algoritmos a ciência da computação exigia ? 0
#    183 - Quais estudos além dos algoritmos a ciência da computação pretendia ? 0
#    184 - Quais estudos além dos algoritmos a ciência da computação produz ? 0
#    185 - O que a área de ciência da computação precisava ? 0
#    186 - O que a área de ciência da computação acrescentou ? 0
#    187 - O que a área de ciência da computação divulgou ? 0
#    188 - O que a área de ciência da computação exigiu ? 0
#    189 - O que a área de ciência da computação recebe ? 0
#    190 - O que o profissional de computação precisa utilizar ? 0
#    191 - Como a ciência da computação se mou enquanto ciência ? 0
#    192 - Como a ciência da computação se izou enquanto ciência ? 0
#    193 - Como a ciência da computação se representa enquanto ciência ? 0
#    194 - Por que o dispositivo de Babbage se aproximou de outros dispositivos ? 0
#    195 - Quando o computador foi originalmente acusado ? 0
#    196 - Quando o computador foi originalmente transformado ? 0
#    197 - Quando o computador foi originalmente bonito ? 0
#    198 - Quando o computador foi originalmente mentado ? 0
#    199 - Quando o computador foi originalmente doméstico ? 0
#    200 - Quando o computador foi originalmente armado ? 0
#    201 - Quando o computador foi originalmente japonês ? 0
#    202 - Quem é então a primeira programadora ? 0
#    203 - Quem é apenas a primeira programadora ? 0
#    204 - Quem é certamente a primeira programadora ? 0
#    205 - Quando o livro dela com numerais hindus foi traduzido para o latim ? 0
#    206 - Quem foi o primeiro a formar o sistema de numeração hindu-arábico ? 0
#    207 - Quem foi o primeiro a ouvir o sistema de numeração hindu-arábico ? 0
#    208 - Quem foi o primeiro a identificar o uso do 0 ? 0
#    209 - Quem foi o primeiro a promover o uso do 0 ? 0
#    210 - Quem foi responsável pela paródia do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    211 - Quem foi responsável pela experiência do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    212 - Quem foi responsável pela consequência do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    213 - Quem foi responsável pela concorrência do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    214 - Quem foi responsável pela instrução do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    215 - Quem foi responsável pela trama do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    216 - Quem foi responsável pela introduziu do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    217 - Quem foi responsável pela firma do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    218 - Quem foi responsável pela corte do sistema de numeração hindu-arábico no Oriente Médio ? 0
#    219 - Os estudos da ciência da computação podem ser seguidos em quais áreas ? 0
#    220 - Quais as áreas que tem mais em a sociedade contemporânea ? 0
#    221 - O que deve haver para que um cálculo possa ser realizado por um algoritmo sendo avançado em um computador ? 0
#    222 - O que deve haver para que um cálculo possa ser realizado por um algoritmo sendo treinado em um computador ? 0
#    223 - O que deve haver para que um cálculo possa ser baseados por um algoritmo sendo executado em um computador ? 0
#    224 - O que deve haver para que um cálculo possa ser realizado por um algoritmo sendo uma em um computador ? 0
#    225 - O que foi dele com a formalização de um algoritmo por Alan Turing e Alonzo Church ? 0
#    226 - Qual teorema será a definição de conceitos como recursividade e cálculo lambda ? 0
#    227 - Qual teorema correspondência a definição de conceitos como recursividade e cálculo lambda ? 0
#    228 - Qual teorema ir a definição de conceitos como recursividade e cálculo lambda ? 0
#    229 - Qual teorema ir a definição de conceitos como recursividade e cálculo lambda ? 0
#    230 - Qual teorema i a definição de conceitos como recursividade e cálculo lambda ? 0
#    231 - Qual teorema esta a definição de conceitos como recursividade e cálculo lambda ? 0
#    232 - Qual teorema da a definição de conceitos como recursividade e cálculo lambda ? 0
#    233 - Qual teorema deu a definição de conceitos como recursividade e cálculo lambda ? 0
#    234 - Qual teorema troca a definição de conceitos como recursividade e cálculo lambda ? 0
#    235 - Qual teorema história a definição de conceitos como recursividade e cálculo lambda ? 0
#    236 - Qual teorema parâmetros a definição de conceitos como recursividade e cálculo lambda ? 0
#    237 - Qual teorema dele a definição de conceitos como recursividade e cálculo lambda ? 0
#    238 - Qual teorema fica a definição de conceitos como recursividade e cálculo lambda ? 0
#    239 - Qual teorema gerar a definição de conceitos como recursividade e cálculo lambda ? 0
#    240 - Qual teorema amar a definição de conceitos como recursividade e cálculo lambda ? 0
#    241 - Qual teorema ) a definição de conceitos como recursividade e cálculo lambda ? 0
#    242 - Qual teorema bases a definição de conceitos como recursividade e cálculo lambda ? 0
#    243 - Qual teorema anda a definição de conceitos como recursividade e cálculo lambda ? 0
#    244 - Qual teorema iza a definição de conceitos como recursividade e cálculo lambda ? 0
#    245 - Qual teorema representação a definição de conceitos como recursividade e cálculo lambda ? 0
#    246 - Com o que estão relacionados as inovações e aspectos teóricos da estratégia ? 0
#    247 - Com o que estão relacionados as formações e aspectos teóricos da computação ? 0
#    248 - Com o que estão relacionados as inovações e aspectos teóricos da economia ? 0
#    249 - Com o que estão relacionados as exposições e aspectos teóricos da computação ? 0
#    250 - Com o que estão relacionados as gramática e aspectos teóricos da computação ? 0
#    251 - Por que trouxeram várias definições alternativas para a ciência da computação ? 0
#    252 - Por que apenas várias definições alternativas para a ciência da computação ? 0
#    253 - A quem é rada a frase " Ciência é para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos " ? 0
#    254 - A quem é credita a frase " Ciência Alemã para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos " ? 0
#    255 - A quem é credita a frase " Ciência móvel para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos " ? 0
#    256 - A quem é credita a frase " Ciência ística para a Ciência da Computação assim como a hidrodinâmica é para a construção de encanamentos " ? 0
#    257 - Por que a ciência da computação é violenta ? 0
#    258 - Por que a ciência da computação é matemática ? 0
#    259 - Por que a ciência da computação é difícil ? 0
#    260 - Por que a ciência da computação é maior ? 0
#    261 - Por que a ciência da computação é surpreendente ? 0
#    262 - Por que a ciência da computação é nuclear ? 0
#    263 - Por que a ciência da computação é poderosa ? 0
#    264 - Por que a ciência da computação é útil ? 0
#    265 - Por que a ciência da computação é restrita ? 0
#    266 - O que foi ilustrado pelo consumo controlado por cartão perfurado ? 0
#    267 - O que foi ilustrado pelo tear controlado por cartão educacional ? 0
#    268 - O que foi ilustrado pelo tear premiado por cartão perfurado ? 0
#    269 - O que foi ilustrado pelo campeonato controlado por cartão perfurado ? 0
#    270 - O que foi ilustrado pelo tear controlado por cartão e ? 0
#    271 - O que foi ilustrado pelo foguete controlado por cartão perfurado ? 0
#    272 - O que foi ilustrado pelo contacto controlado por cartão perfurado ? 0
#    273 - O que foi ilustrado pelo tear traçado por cartão perfurado ? 0
#    274 - O que foi ilustrado pelo triângulo controlado por cartão perfurado ? 0
#    275 - O que indicavam as áreas não furadas no passo controlado por cartão perfurado ? 0
#    276 - O que indicavam as áreas não furadas no tear controlado por cartão operacional ? 0
#    277 - O que indicavam as áreas não furadas no tear controlado por cartão adulto ? 0
#    278 - O que indicavam as áreas não furadas no território controlado por cartão perfurado ? 0
#    279 - Quais informações podem ser radas por uns e zeros ? 0
#    280 - Quais informações podem ser conhecidas por uns e zeros ? 0
#    281 - Quando foi gada a álgebra booleana ? 0
#    282 - Quem faz o sistema de numeração binário ? 0
#    283 - Quem usava o sistema de numeração binário ? 0
#    284 - Em que é definido o nome de Turing ? 0
#    285 - Em que é escrito o nome de Turing ? 0
#    286 - Por que uma máquina que rete uma fita de tamanho infinito não pode ser construída ? 0
#    287 - Por que uma máquina que bina uma fita de tamanho infinito não pode ser construída ? 0
#    288 - Quando Turing admitiu suicídio ? 0
#    289 - Quando Turing quer suicídio ? 0
#    290 - Quando Turing parece suicídio ? 0
#    291 - Quando Turing demonstra suicídio ? 0
#    292 - Quando Turing suicídio suicídio ? 0
#    293 - Quando Turing fará suicídio ? 0
#    294 - À que Turing interpreta ? 0
#    295 - Como a ciência da computação é utilizada em francês ? 0
#    296 - Como a ciência da computação é em em francês ? 0
#    297 - Como a ciência da computação é falar em francês ? 0
#    298 - Como a ciência da computação é notável em francês ? 0
#    299 - Como a ciência da computação é governada em francês ? 0
#    300 - Como a ciência da computação é ainda em francês ? 0
#    301 - O pole informática é sinônimo de que em Portugal ? 0
#    302 - O « informática é sinônimo de que em Portugal ? 0
#    303 - O Lat informática é sinônimo de que em Portugal ? 0
#    304 - O rock informática é sinônimo de que em Portugal ? 0
#    305 - O AC informática é sinônimo de que em Portugal ? 0
#    306 - O Sara informática é sinônimo de que em Portugal ? 0
#    307 - O acorda informática é sinônimo de que em Portugal ? 0
#    308 - O tant informática é sinônimo de que em Portugal ? 0
#    309 - O . informática é sinônimo de que em Portugal ? 0
#    310 - O Tit informática é sinônimo de que em Portugal ? 0
#    311 - O bel informática é sinônimo de que em Portugal ? 0
#    312 - O Pai informática é sinônimo de que em Portugal ? 0
#    313 - O UN informática é sinônimo de que em Portugal ? 0
#    314 - O regional informática é sinônimo de que em Portugal ? 0
#    315 - O be informática é sinônimo de que em Portugal ? 0
#    316 - O ag informática é sinônimo de que em Portugal ? 0
#    317 - O frase informática é sinônimo de que em Portugal ? 0
#    318 - O Sobre informática é sinônimo de que em Portugal ? 0
#    319 - O ciclo informática é sinônimo de que em Portugal ? 0
#    320 - Para que é diferente o termo informática no inglês e no português ? 0
#    321 - Como podemos montar números maiores na memória ? 0
#    322 - Como é tirar a memória do computador ? 0
#    323 - Como é criar a memória do computador ? 0
#    324 - Como é construir a memória do computador ? 0
#    325 - Como é grande a memória do computador ? 0
#    326 - Onde é muito parte da memória do computador ? 0
#    327 - Onde é destruída parte da memória do computador ? 0
#    328 - Onde é ver parte da memória do computador ? 0
#    329 - Qual a utilidade da especialidade ? 0
#    330 - Qual a repercussão da memória ? 0
#    331 - Qual a utilidade da página ? 0
#    332 - Qual a utilidade da ideia ? 0
#    333 - Qual a utilidade da técnica ? 0
#    334 - Qual a utilidade da ditadura ? 0
#    335 - Qual a utilidade da coloração ? 0
#    336 - Quantos bits as posições de memória nos computadores modernos sabiam ? 0
#    337 - Quantos bits as posições de memória nos computadores modernos o ? 0
#    338 - Quantos bits as posições de memória nos computadores modernos – ? 0
#    339 - Quantos bits as posições de memória nos computadores modernos ? ? 0
#    340 - Quantos bits as posições de memória nos computadores modernos avam ? 0
#    341 - Quantos bits as posições de memória nos computadores modernos passavam ? 0
#    342 - Quantos bits as posições de memória nos computadores modernos disponíveis ? 0
#    343 - Quantos bits as posições de memória nos computadores modernos entram ? 0
#    344 - Quantos bits as posições de memória nos computadores modernos modernos ? 0
#    345 - Quantos bytes em sequência geralmente são apenas para armazenar números maiores ? 0
#    346 - Quantos números um byte inteiro ? 0
#    347 - Como era controlada a máquina de alguns números de Babbage ? 0
#    348 - Como era controlada a máquina de menores números de Babbage ? 0
#    349 - Como era uma a máquina de tecer números de Babbage ? 0
#    350 - Quem controla o tear mecânico ? 0
#    351 - O que acelera o computador de outras máquinas ? 0
#    352 - O que há o computador de outras máquinas ? 0
#    353 - O que tira o computador de outras máquinas ? 0
#    354 - O que todo o computador de outras máquinas ? 0
#    355 - O que aconteceu o computador de outras máquinas ? 0
#    356 - O que transformou o computador de outras máquinas ? 0
#    357 - Qual a principal característica dos estrangeiros de hoje em dia ? 0
#    358 - Qual a principal característica dos desafios de hoje em dia ? 0
#    359 - Qual a principal característica dos parentes de hoje em dia ? 0
#    360 - Como é qual a memória da CPU ? 0
#    361 - Como é carregar a memória da CPU ? 0
#    362 - Como é feito a memória da CPU ? 0
#    363 - O que a unidade de controle envia à ULA ? 0
#    364 - O que é negativo na unidade de controle ? 0
#    365 - O que é lá na unidade de controle ? 0
#    366 - O que é crime na unidade de controle ? 0
#    367 - Onde a unidade de controle busca a informação que a ULA importa ? 0
#    368 - Onde a unidade de controle busca a informação que a ULA descobriu ? 0
#    369 - Onde a unidade de controle busca a informação que a ULA produziu ? 0
#    370 - Onde geralmente entra a próxima instrução ? 0
#    371 - Onde geralmente iar a próxima instrução ? 0
#    372 - Para que mostrar os registradores ? 0
#    373 - A quem foi informado o termo computador ? 0
#    374 - O que é Verde ? 0
#    375 - O que é legal ? 0
#    376 - O que é consciência ? 0
#    377 - O que é pobreza ? 0
#    378 - O que é radiação ? 0
#    379 - O que é ansiedade ? 0
#    380 - O que é competência ? 0
#    381 - O que é realmente ? 0
#    382 - O que é argumento ? 0
#    383 - O que é Brasil ? 0
#    384 - O que é composto ? 0
#    385 - O que é inglês ? 0
#    386 - O que é estética ? 0
#    387 - O que é crença ? 0
#    388 - O que é respiração ? 0
#    389 - O que é democracia ? 0
#    390 - Para que servem os sistemas químicos ? 0
#    391 - Para que servem os sistemas utilizados ? 0
#    392 - Quais as formas mais comuns de computador em Inglaterra ? 0
#    393 - Quais as formas mais comuns de atualização em uso ? 0
#    394 - Quais as formas mais comuns de computador em comunicação ? 0
#    395 - Quais as formas mais comuns de cobertura em uso ? 0
#    396 - Quais as formas mais comuns de estruturas em uso ? 0
#    397 - Quais as discos mais comuns de computador em uso ? 0
#    398 - Quais as formas mais comuns de programa em uso ? 0
#    399 - Quais as formas mais comuns de cultura em uso ? 0
#    400 - Quais as formas mais comuns de sobrevivência em uso ? 0
#    401 - Quais as formas mais comuns de computador em guerra ? 0
#    402 - Quais as celebridades mais comuns de computador em uso ? 0
#    403 - Quem são os ícones da era da libertação ? 0
#    404 - Como a CPU leu as instruções de um programa ? 0
#    405 - Como a CPU move as instruções de um programa ? 0
#    406 - Como a CPU reduz as instruções de um programa ? 0
#    407 - Em que o prolog é intenso ? 0
#    408 - Em que o prolog é possível ? 0
#    409 - Em que o prolog é geral ? 0
#    410 - O que é linguagem de classificação ? 0
#    411 - O que é linguagem de interpretação ? 0
#    412 - Qual linguagem de programação é parecida com a linguagem de marcas ? 0
#    413 - Qual linguagem de programação é parecida com a linguagem de redação ? 0
#    414 - Qual linguagem de programação é parecida com a linguagem de origem ? 0
#    415 - Como eram melhores as tabelas de multiplicação de John Napier ? 0
#    416 - Como eram ainda as tabelas de multiplicação de John Napier ? 0
#    417 - Qual era o objetivo da batalha de pascal ? 0
#    418 - Qual era o objetivo da batalha de pascal ? 0
#    419 - Qual era o departamento de Gottfried ? 0
#    420 - Qual era o discurso de Gottfried ? 0
#    421 - Qual era o palácio de Gottfried ? 0
#    422 - Qual era o palácio de Gottfried ? 0
#    423 - Qual era o pedido de Gottfried ? 0
#    424 - Quem inventou os meninos ? 0
#    425 - Quem inventou os equipamentos ? 0
#    426 - De quando eram os primeiros vistos ? 0
#    427 - De quando eram os primeiros carros ? 0
#    428 - De quando eram os primeiros itens ? 0
#    429 - De quando eram os primeiros combatentes ? 0
#    430 - De quando eram os primeiros humanos ? 0
#    431 - De quando eram os primeiros oficiais ? 0
#    432 - De quando eram os primeiros meses ? 0
#    433 - De quando eram os primeiros mundos ? 0
#    434 - De quando eram os primeiros aspectos ? 0
#    435 - De quando eram os primeiros dólares ? 0
#    436 - O que é os setores do computador ? 0
#    437 - Por quem foi iada a arquitetura de von Neumann ? 0
#    438 - Quais são os depósitos da CPU ? 0
#    439 - Quais são os hábitos da CPU ? 0
#    440 - Quais são os buracos da CPU ? 0
#    441 - Quais são os materiais da CPU ? 0
#    442 - Quais são os padrões da CPU ? 0
#    443 - Quais são os integrantes da CPU ? 0
#    444 - Quais são os palcos da CPU ? 0
#    445 - Quais são os círculos da CPU ? 0
#    446 - Quais são os principais setores do representado ? 0
#    447 - Quais são os principais produtos do computador ? 0
#    448 - Quais são os principais planos do computador ? 0
#    449 - Quais são os principais setores do radar ? 0
#    450 - Quais são os principais agentes do computador ? 0
#    451 - Quais são os principais setores do Mark ? 0
#    452 - Quais são os principais técnicos do computador ? 0
#    453 - Quais são os principais blocos do computador ? 0
#    454 - Quais são os principais setores do Benfica ? 0
#    455 - Quais são os principais setores do grupo ? 0
#    456 - Quantas sessões principais o computador ganhou ? 0
#    457 - A quem Zuse tentou convencer o Z1 ? 0
#    458 - A quem Zuse tentou vir o Z1 ? 0
#    459 - A quem Zuse saber vender o Z1 ? 0
#    460 - A quem Zuse jando vender o Z1 ? 0
#    461 - A quem Zuse tta vender o Z1 ? 0
#    462 - A quem Zuse tentou adotar o Z1 ? 0
#    463 - Como Zuse tocar o Z1 ? 0
#    464 - Como Zuse atacou o Z1 ? 0
#    465 - Como Zuse fala o Z1 ? 0
#    466 - Como Zuse fazia o Z1 ? 0
#    467 - Como Zuse cionou o Z1 ? 0
#    468 - Como Zuse em o Z1 ? 0
#    469 - Como Zuse pega o Z1 ? 0
#    470 - Como Zuse dizia o Z1 ? 0
#    471 - Como Zuse acertou o Z1 ? 0
#    472 - Em quantos segundos o Mark I conseguia já dois números de dez dígitos ? 0
#    473 - Em quantos segundos o Mark I mite multiplicar dois números de dez dígitos ? 0
#    474 - Em quantos segundos o Mark I X multiplicar dois números de dez dígitos ? 0
#    475 - Em quantos segundos o Mark I ava multiplicar dois números de dez dígitos ? 0
#    476 - Em quantos segundos o Mark I conseguia parecer dois números de dez dígitos ? 0
#    477 - Em quantos segundos o Mark I imediatamente multiplicar dois números de dez dígitos ? 0
#    478 - Em quantos segundos o Mark I conseguia fabrica dois números de dez dígitos ? 0
#    479 - Em quantos segundos o Mark I conseguia verdadeiramente dois números de dez dígitos ? 0
#    480 - Em quantos segundos o Mark I num multiplicar dois números de dez dígitos ? 0
#    481 - Em quantos segundos o Mark I r multiplicar dois números de dez dígitos ? 0
#    482 - Em quantos segundos o Mark I conseguia este dois números de dez dígitos ? 0
#    483 - Em quantos segundos o Mark I conseguia te dois números de dez dígitos ? 0
#    484 - Em quantos segundos o Mark I x multiplicar dois números de dez dígitos ? 0
#    485 - Em quantos segundos o Mark I ie multiplicar dois números de dez dígitos ? 0
#    486 - Em quantos segundos o Mark I OR multiplicar dois números de dez dígitos ? 0
#    487 - Em quantos segundos o Mark I conseguia daqueles dois números de dez dígitos ? 0
#    488 - Em quantos segundos o Mark I dado multiplicar dois números de dez dígitos ? 0
#    489 - Em que foi reconhecido o Mark I ? 0
#    490 - Em que foi certificado o Mark I ? 0
#    491 - Em que foi lançado o Mark I ? 0
#    492 - Em que foi passado o Mark I ? 0
#    493 - Para que ler o ENIAC ? 0
#    494 - Qual foi o primeiro computador a AR ? 0
#    495 - Qual foi o primeiro visto a válvulas ? 0
#    496 - Qual foi o primeiro concorrente a válvulas ? 0
#    497 - Qual foi o primeiro colocado a válvulas ? 0
#    498 - Qual foi o primeiro berço a válvulas ? 0
#    499 - Qual foi o primeiro indivíduo a válvulas ? 0
#    500 - Qual foi o primeiro aumento a válvulas ? 0
#    501 - Qual foi o primeiro chumbo a válvulas ? 0
#    502 - Qual foi o primeiro continente a válvulas ? 0
#    503 - Qual foi o primeiro gão a válvulas ? 0
#    504 - Qual foi o primeiro primeiro a válvulas ? 0
#    505 - Qual foi o primeiro gênero a válvulas ? 0
#    506 - Qual foi o primeiro vidro a válvulas ? 0
#    507 - Qual foi o primeiro computador a prevenir ? 0
#    508 - Qual foi o primeiro choque a válvulas ? 0
#    509 - Quando apenas os computadores atuais ? 0
#    510 - Quem controla o Mark I ? 0
#    511 - Quem encontra o Mark I ? 0
#    512 - Quem era o Mark I ? 0
#    513 - Quem I o Mark I ? 0
#    514 - Como os primeiros andares eram construídos ? 0
#    515 - Como os primeiros sonhos eram construídos ? 0
#    516 - Como os primeiros conteúdos eram construídos ? 0
#    517 - Como os primeiros talentos eram construídos ? 0
#    518 - Como os primeiros fatos eram construídos ? 0
#    519 - Como os primeiros terrenos eram construídos ? 0
#    520 - Como os primeiros intelectuais eram construídos ? 0
#    521 - Como os primeiros povoados eram construídos ? 0
#    522 - O que a unidade lógica e aritmética básica ? 0
#    523 - O que a unidade lógica e aritmética mostra ? 0
#    524 - O que a unidade lógica e aritmética inicial ? 0
#    525 - O que é a participação lógica e aritmética ? 0
#    526 - Para que quebrar os pontos flutuantes ? 0
#    527 - Para que vencer os pontos flutuantes ? 0
#    528 - Quais são os jogadores da ULA ? 0
#    529 - Quais são os ataques da ULA ? 0
#    530 - Quais são os preços da ULA ? 0
#    531 - Quais são os aspectos da ULA ? 0
#    532 - Quais são os ataques da ULA ? 0
#    533 - Quais são os efeitos da ULA ? 0
#    534 - Qual as tarefas do PMDB ? 0
#    535 - Qual as tarefas do filósofo ? 0
#    536 - Qual as tarefas do documento ? 0
#    537 - Qual as tarefas do Presidente ? 0
#    538 - Qual as tarefas do Guarda ? 0
#    539 - Qual as tarefas do celular ? 0
#    540 - Qual as tarefas do Lula ? 0
#    541 - Qual as tarefas do Guia ? 0
#    542 - Qual as tarefas do Alemão ? 0
#    543 - Qual as tarefas do equipamento ? 0
#    544 - Em que a máquina de Hollerith igualmente pioneira ? 0
#    545 - Em que a máquina de Hollerith escapou pioneira ? 0
#    546 - Em que a máquina de Hollerith tentava pioneira ? 0
#    547 - Em que a máquina de Hollerith estuda pioneira ? 0
#    548 - Em que a máquina de Hollerith colabora pioneira ? 0
#    549 - Em que a máquina de Hollerith especial pioneira ? 0
#    550 - Em que a máquina de Hollerith sabia pioneira ? 0
#    551 - Em que a máquina de Hollerith za pioneira ? 0
#    552 - Em que a máquina de Hollerith le pioneira ? 0
#    553 - Em que a máquina de Hollerith nessa pioneira ? 0
#    554 - Em que a máquina de Hollerith " pioneira ? 0
#    555 - Em que a máquina de Hollerith vez pioneira ? 0
#    556 - Em que a máquina de Hollerith qual pioneira ? 0
#    557 - Em que a máquina de Hollerith escolha pioneira ? 0
#    558 - Em que a máquina de Hollerith uso pioneira ? 0
#    559 - Em que a máquina de Hollerith acrescentou pioneira ? 0
#    560 - Em que a máquina de Hollerith momento pioneira ? 0
#    561 - Em que a máquina de Hollerith man pioneira ? 0
#    562 - Em que a máquina de Hollerith / pioneira ? 0
#    563 - Em que a máquina de Hollerith sido pioneira ? 0
#    564 - Em que a máquina de Hollerith reag pioneira ? 0
#    565 - Em que a máquina de Hollerith conver pioneira ? 0
#    566 - Em que a máquina de Hollerith i pioneira ? 0
#    567 - Em que a máquina de Hollerith fer pioneira ? 0
#    568 - Em que a máquina de Hollerith pretendia pioneira ? 0
#    569 - Em que a máquina de Hollerith figura pioneira ? 0
#    570 - Em que a máquina de Hollerith velocidade pioneira ? 0
#    571 - Em que a máquina de Hollerith definiu pioneira ? 0
#    572 - Em que a máquina de Hollerith 1 pioneira ? 0
#    573 - Em que a máquina de Hollerith demonstrou pioneira ? 0
#    574 - Em que a máquina de Hollerith prepara pioneira ? 0
#    575 - Em que a máquina de Hollerith consideram pioneira ? 0
#    576 - Em que a máquina de Hollerith chegou pioneira ? 0
#    577 - Em que a máquina de Hollerith foca pioneira ? 0
#    578 - O que Hollerith entender ? 0
#    579 - O que Hollerith queria ? 0
#    580 - O que Hollerith perceber ? 0
#    581 - O que Hollerith aponta ? 0
#    582 - O que Hollerith avalia ? 0
#    583 - O que Hollerith apresentou ? 0
#    584 - O que Hollerith percebeu ? 0
#    585 - O que Hollerith pesquisa ? 0
#    586 - Para quantos anos a máquina de Hollerith conter o tempo de processamento de dados ? 0
#    587 - Para quantos anos a máquina de Hollerith anunciou o tempo de processamento de dados ? 0
#    588 - Para quantos anos a máquina de Hollerith usado o tempo de processamento de dados ? 0
#    589 - Para quantos anos a máquina de Hollerith concentra o tempo de processamento de dados ? 0
#    590 - Para quantos anos a máquina de Hollerith inou o tempo de processamento de dados ? 0
#    591 - Para quantos anos a máquina de Hollerith rou o tempo de processamento de dados ? 0
#    592 - Para quantos anos a máquina de Hollerith indicar o tempo de processamento de dados ? 0
#    593 - Para quantos anos a máquina de Hollerith informou o tempo de processamento de dados ? 0
#    594 - Para quantos anos a máquina de Hollerith incluiu o tempo de processamento de dados ? 0
#    595 - Para quantos anos a máquina de Hollerith passar o tempo de processamento de dados ? 0
#    596 - Para quantos anos a máquina de Hollerith observou o tempo de processamento de dados ? 0
#    597 - Para quantos anos a máquina de Hollerith reproduzir o tempo de processamento de dados ? 0
#    598 - O que são dispositivos de entradas e saída ? 0
#    599 - O que são momentos de entrada e saída ? 0
#    600 - Quais são os dispositivos de calor mais comuns em computadores pessoais modernos ? 0
#    601 - Quantas fases o processamento de dados de um sistema de computadores digital analis ? 0
#    602 - Quantas fases o processamento de dados de um sistema de computadores digital compree ? 0
#    603 - Quantas fases o processamento de dados de um sistema de computadores digital ras ? 0
#    604 - Quantas fases o processamento de dados de um sistema de computadores digital orda ? 0
#    605 - Para que seria a fonte de energia ? 0
#    606 - Quais tipos de interface o barramento pode perceber ? 0
#    607 - Quais tipos de interface o barramento pode aproveitar ? 0
#    608 - Como as instruções geralmente são postas ? 0
#    609 - O que são esses ? 0
#    610 - O que são animais ? 0
#    611 - Quantas instruções dos programas de computador usava ? 0
#    612 - Quantas instruções dos programas de computador trouxe ? 0
#    613 - Quem divide as instruções para o computador ? 0
#    614 - Quem adquire as instruções para o computador ? 0
#    615 - Quem informa as instruções para o computador ? 0
#    616 - Quem queria as instruções para o computador ? 0
#    617 - Quem encara os programas ? 0
#    618 - Como geralmente estaria o primeiro emprego do engenheiro de computação ? 0
#    619 - Como geralmente a o primeiro emprego do engenheiro de computação ? 0
#    620 - Em quais empresas o engenheiro da computação pode mostrar ? 0
#    621 - Em que a rápida mudança livre pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação ? 0
#    622 - Em que a rápida mudança humana pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação ? 0
#    623 - Em que a rápida mudança web pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação ? 0
#    624 - Em que a rápida mudança ulada pelos computadores tornou a oferta de vagas para o profissional da engenharia de computação ? 0
#    625 - Em que a rápida mudança promovida pelos computadores comprome a oferta de vagas para o profissional da engenharia de computação ? 0
#    626 - Quando muitos investimentos na linha de produção da indústra ? 0
#    627 - Quando bons investimentos na linha de produção da indústra ? 0
#    628 - Quando segue investimentos na linha de produção da indústra ? 0
#    629 - Quando gera investimentos na linha de produção da indústra ? 0
#    630 - Quando desenvolvem investimentos na linha de produção da indústra ? 0
#    631 - Quando pensar investimentos na linha de produção da indústra ? 0
#    632 - Quando realmente investimentos na linha de produção da indústra ? 0
#    633 - Quando seriam investimentos na linha de produção da indústra ? 0
#    634 - Quando aconteceu investimentos na linha de produção da indústra ? 0
#    635 - Quem foi a maioria em PBL no Brasil ? 0
#    636 - Quem foi a polícia em PBL no Brasil ? 0
#    637 - Quanto dos sistemas de computação são divididos como “ sistemas embarcados ” ? 0
#    638 - Quanto o computador pode de todo o sistema de computação do mundo ? 0
#    639 - Quanto o computador paga de todo o sistema de computação do mundo ? 0
#    640 - Quanto o computador traz de todo o sistema de computação do mundo ? 0
#    641 - Quanto o computador lembra de todo o sistema de computação do mundo ? 0
#    642 - Quanto o computador irá de todo o sistema de computação do mundo ? 0
#    643 - O que o curso de Engenharia da Computação da UFRG revela ? 0
#    644 - O que o curso de Engenharia da Computação da UFRG executa ? 0
#    645 - O que o curso de Engenharia da Computação da UFRG procurou ? 0
#    646 - O que o curso de Engenharia da Computação da UFRG apresenta ? 0
#    647 - O que o curso de Engenharia da Computação da UFRG acrescenta ? 0
#    648 - O que o curso de Engenharia da Computação da UFRG definiu ? 0
#    649 - O que o curso de Engenharia da Computação da UFRG esperava ? 0
#    650 - Quando se encerrou a primeira turma de engenheiros de computação ? 0
#    651 - Como saiu a maioria dos cursos de Engenharia de Computação ? 0
#    652 - Como antigamente a maioria dos cursos de Engenharia de Computação ? 0
#    653 - Como funcionar a maioria dos cursos de Engenharia de Computação ? 0
#    654 - Como atualmente a maioria dos cursos de Engenharia de Computação ? 0
#    655 - Como acaba a maioria dos cursos de Engenharia de Computação ? 0
#    656 - De qual programa são provenientes as disciplinas de engenharia da computação ? 0
#    657 - De qual relevância são provenientes as disciplinas de engenharia da computação ? 0
#    658 - Onde a engenharia elétrica ainda domina a engenharia da computação ? 0
#    659 - Onde a engenharia elétrica ainda tinha a engenharia da computação ? 0
#    660 - Onde a engenharia elétrica ainda entende a engenharia da computação ? 0
#    661 - Quando os primeiros docentes do curso de Engenharia de Computação da UNIVASF terão suas atividades ? 0
#    662 - Quando os primeiros docentes do curso de Engenharia de Computação da UNIVASF as suas atividades ? 0
#    663 - Quando os primeiros docentes do curso de Engenharia de Computação da UNIVASF viam suas atividades ? 0
#    664 - Quantos membros só no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008 ? 0
#    665 - Quantos membros morreram no corpo docente do curso de Engenharia de Computação da UNIVASF em 2008 ? 0
#    666 - Quem critica o curso de Engenharia de Computação da UNIVASF ? 0
#    667 - Quem enta o curso de Engenharia de Computação da UNIVASF ? 0
#    668 - Desde quando o curso de engenharia de computação tem sido associado às universidades ? 0
#    669 - Desde quando o curso de engenharia de computação tem sido duzido às universidades ? 0
#    670 - Desde quando o curso de engenharia de computação tem sido emprestado às universidades ? 0
#    671 - Desde quando o curso de engenharia de computação tem sido informado às universidades ? 0
#    672 - Como o curso de engenharia de sistemas e computação passará a se provar ? 0
#    673 - O que é ruim ? 0
#    674 - O que é futebol ? 0
#    675 - O que é Educação ? 0
#    676 - Qual era o objetivo do curso de engenharia de arquitetura e computação ? 0
#    677 - Qual o episódio da revisão do curso de engenharia de sistemas e computação ? 0
#    678 - Qual o objetivo da idéia do curso de engenharia de sistemas e computação ? 0
#    679 - O que é necessário para um engenheiro de computação começar a profissão ? 0
#    680 - Quem é mais engenheiro de computação no Brasil ? 0
#    681 - Como combina o curso de Engenharia de Computação da UFSC atualmente ? 0
#    682 - Como trabalhou o curso de Engenharia de Computação da UFSC atualmente ? 0
#    683 - Como parado o curso de Engenharia de Computação da UFSC atualmente ? 0
#    684 - Como identificar o curso de Engenharia de Computação da UFSC atualmente ? 0
#    685 - Como avança o curso de Engenharia de Computação da UFSC atualmente ? 0
#    686 - Como ificar o curso de Engenharia de Computação da UFSC atualmente ? 0
#    687 - Como trabalho o curso de Engenharia de Computação da UFSC atualmente ? 0
#    688 - Como dá o curso de Engenharia de Computação da UFSC atualmente ? 0
#    689 - Como usam o curso de Engenharia de Computação da UFSC atualmente ? 0
# ...
#    2019 - quem quero a proposta para projeto pedagógico de curso ? 0
#    2020 - quem ique a proposta para projeto pedagógico de curso ? 0
#    2021 - quem esta a proposta para projeto pedagógico de curso ? 0
#    2022 - quem " a proposta para projeto pedagógico de curso ? 0
#    2023 - quem já a proposta para projeto pedagógico de curso ? 0
#    2024 - como é itada a seleção de alunos para uma disciplina cujo número de inscritos exceda o número de vagas ? 0
#    2025 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos compatível o número de vagas ? 0
#    2026 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos discrimin o número de vagas ? 0
#    2027 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos indicar o número de vagas ? 0
#    2028 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos abaixo o número de vagas ? 0
#    2029 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos impacto o número de vagas ? 0
#    2030 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos resolveu o número de vagas ? 0
#    2031 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos ataque o número de vagas ? 0
#    2032 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos implica o número de vagas ? 0
#    2033 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos dendo o número de vagas ? 0
#    2034 - como é realizada a seleção de alunos para uma disciplina cujo número de inscritos visita o número de vagas ? 0
#    2035 - onde é ilegal a matrícula em disciplinas obrigatórias ? 0
#    2036 - onde é melhor a matrícula em disciplinas obrigatórias ? 0
#    2037 - onde está definido o prazo para renovação de recurso ? 0
#    2038 - onde está definido o prazo para renovação de residências ? 0
#    2039 - onde está definido o prazo para renovação de aviões ? 0
#    2040 - o que acontece com o acadêmico com vínculo 2009 em caso de não renovação de sua matrícula no semestre seguinte ? 0
#    2041 - o que o acadêmico deve de na fase de inscrição ? 0
#    2042 - quais incisos os acadêmicos deve têm ? 0
#    2043 - quais são as fases da renovação de aviões ? 0
#    2044 - quais são as tarefas da renovação de matrícula ? 0
#    2045 - quais são as fases da renovação de espaço ? 0
#    2046 - quais são as tecnologias da renovação de matrícula ? 0
#    2047 - qual vertical a distribuição das vagas disponíveis deve seguir ? 0
#    2048 - qual identificação a distribuição das vagas disponíveis deve seguir ? 0
#    2049 - qual coloração a distribuição das vagas disponíveis deve seguir ? 0
#    2050 - qual etapa a distribuição das vagas disponíveis deve seguir ? 0
#    2051 - qual interface a distribuição das vagas disponíveis deve seguir ? 0
#    2052 - o que os membros do nde devem impor ? 0
#    2053 - o que os membros do nde devem notar ? 0
#    2054 - o que os membros do nde devem modificar ? 0
#    2055 - o que os membros do nde devem lançar ? 0
#    2056 - o que os membros do nde devem tentar ? 0
#    2057 - por meio de quem as instituições de ensino superior devem sustentar as atribuições e os critérios de constituição do nde ? 0
#    2058 - por meio de quem as instituições de ensino superior devem garantir as atribuições e os critérios de constituição do nde ? 0
#    2059 - por meio de quem as instituições de ensino superior devem te as atribuições e os critérios de constituição do nde ? 0
#    2060 - por meio de quem as instituições de ensino superior devem exercendo as atribuições e os critérios de constituição do nde ? 0
#    2061 - por meio de quem as instituições de ensino superior devem cair as atribuições e os critérios de constituição do nde ? 0
#    2062 - por meio de quem as instituições de ensino superior devem constituem as atribuições e os critérios de constituição do nde ? 0
#    2063 - quais os critérios de constituição do estabelecimento ? 0
#    2064 - quais os critérios de ranking do nde ? 0
#    2065 - quais os critérios de constituição do dinheiro ? 0
#    2066 - quais os critérios de continuidade do nde ? 0
#    2067 - quais os exemplos de constituição do nde ? 0
#    2068 - quais os critérios de constituição do ranking ? 0
#    2069 - quantos dos membros do nde devem possuir titulação acadêmica ganha em programas de pósgraduação ? 0
#    2070 - quantos dos membros do nde devem possuir titulação acadêmica afiliada em programas de pósgraduação ? 0
#    2071 - quantos dos membros do nde devem possuir titulação acadêmica premiada em programas de pósgraduação ? 0
#    2072 - quantos dos membros do nde devem possuir titulação acadêmica superior em programas de pósgraduação ? 0
#    2073 - quantos dos membros do nde devem possuir titulação acadêmica dos em programas de pósgraduação ? 0
#    2074 - quantos dos membros do nde devem possuir titulação acadêmica recebida em programas de pósgraduação ? 0
#    2075 - quantos dos membros do nde devem possuir titulação acadêmica positivas em programas de pósgraduação ? 0
#    2076 - quantos dos membros do nde devem possuir titulação acadêmica marcada em programas de pósgraduação ? 0
#    2077 - quantos dos membros do nde devem possuir titulação acadêmica III em programas de pósgraduação ? 0
#    2078 - quantos dos membros do nde devem possuir titulação acadêmica clínica em programas de pósgraduação ? 0
#    2079 - o que os membros do nde parece exercer ? 0
#    2080 - o que os membros do nde devem por ? 0
#    2081 - o que os membros do nde co exercer ? 0
#    2082 - o que os membros do nde devem realiza ? 0
#    2083 - o que os membros do nde des exercer ? 0
#    2084 - o que os membros do nde devem certamente ? 0
#    2085 - o que os membros do nde devem formar ? 0
#    2086 - o que os membros do nde espiritual exercer ? 0
#    2087 - o que os membros do nde sim exercer ? 0
#    2088 - o que os membros do nde cus exercer ? 0
#    2089 - o que os membros do nde devem es ? 0
#    2090 - o que os membros do nde devem sab ? 0
#    2091 - o que os membros do nde devem reconhece ? 0
#    2092 - o que os membros do nde bem exercer ? 0
#    2093 - o que os membros do nde devem ve ? 0
#    2094 - o que é consumo ? 0
#    2095 - o que é vitória ? 0
#    2096 - o que é algo ? 0
#    2097 - o que é poeta ? 0
#    2098 - o que é professor ? 0
#    2099 - o que é então ? 0
#    2100 - o que é texto ? 0
#    2101 - o que é científico ? 0
#    2102 - o que é tecnologia ? 0
#    2103 - quais são as entrevistas acadêmicas do nde ? 0
#    2104 - quais são as correntes acadêmicas do nde ? 0
#    2105 - quais são as mulheres acadêmicas do nde ? 0
#    2106 - quais são as políticas acadêmicas do nde ? 0
#    2107 - quais são as reivindicações acadêmicas do nde ? 0
#    2108 - quais são as instruções acadêmicas do nde ? 0
#    2109 - quais são as sociedades acadêmicas do nde ? 0
#    2110 - qual a água do núcleo docente estruturante ( nde ) ? 0
#    2111 - qual a parti do núcleo docente estruturante ( nde ) ? 0
#    2112 - qual a capa do núcleo docente estruturante ( nde ) ? 0
#    2113 - qual a regional do núcleo docente estruturante ( nde ) ? 0
#    2114 - qual a trata do núcleo docente estruturante ( nde ) ? 0
#    2115 - o que deve o núcleo docente estruturante discutir ? 0
#    2116 - como render a componente curricular não disciplinar no siscad ? 0
#    2117 - como a a componente curricular não disciplinar no siscad ? 0
#    2118 - como localizar a componente curricular não disciplinar no siscad ? 0
#    2119 - como transformar a componente curricular não disciplinar no siscad ? 0
#    2120 - como substituiu a componente curricular não disciplinar no siscad ? 0
#    2121 - como convencer a componente curricular não disciplinar no siscad ? 0
#    2122 - como nasceu a componente curricular não disciplinar no siscad ? 0
#    2123 - como encerrar a componente curricular não disciplinar no siscad ? 0
#    2124 - como atende a componente curricular não disciplinar no siscad ? 0
#    2125 - como falou a componente curricular não disciplinar no siscad ? 0
#    2126 - como ficou a componente curricular não disciplinar no siscad ? 0
#    2127 - como distinguir a componente curricular não disciplinar no siscad ? 0
#    2128 - como formal a componente curricular não disciplinar no siscad ? 0
#    2129 - quais são as pedras curriculares não disciplinares no projeto pedagógico de um curso de gradução ? 0
#    2130 - quais são as ou curriculares não disciplinares no projeto pedagógico de um curso de gradução ? 0
#    2131 - quais são as telas curriculares não disciplinares no projeto pedagógico de um curso de gradução ? 0
#    2132 - quais são as contemp curriculares não disciplinares no projeto pedagógico de um curso de gradução ? 0
#    2133 - quais são as base curriculares não disciplinares no projeto pedagógico de um curso de gradução ? 0
#    2134 - quais são as partes curriculares não disciplinares no projeto pedagógico de um curso de gradução ? 0
#    2135 - quem enciou a solicitação de regime de exercícios domiciliares ? 0
#    2136 - quem nda a solicitação de regime de exercícios domiciliares ? 0
#    2137 - quem iar a solicitação de regime de exercícios domiciliares ? 0
#    2138 - quem tem a solicitação de regime de exercícios domiciliares ? 0
#    2139 - quem ende a solicitação de regime de exercícios domiciliares ? 0
#    2140 - o que é regime de empresas domiciliares ? 0
#    2141 - o que é regime de atividades domiciliares ? 0
#    2142 - o que é projeto de exercícios domiciliares ? 0
#    2143 - o que é regime de depósitos domiciliares ? 0
#    2144 - o que é regime de fronteiras domiciliares ? 0
#    2145 - o que é regime de vagas domiciliares ? 0
#    2146 - quais são as categoria para o regime de exercícios domiciliares ? 0
#    2147 - quais são as combinações para o regime de exercícios domiciliares ? 0
#    2148 - quais são as atividades para o clima de exercícios domiciliares ? 0
#    2149 - quais são as atividades para o sentimento de exercícios domiciliares ? 0
#    2150 - quais são as alianças para o regime de exercícios domiciliares ? 0
#    2151 - quais são as atividades para o apoio de exercícios domiciliares ? 0
#    2152 - quais são as referências para o regime de exercícios domiciliares ? 0
#    2153 - quais são as atividades para o Grupo de exercícios domiciliares ? 0
#    2154 - quais são as atividades para o bloqueio de exercícios domiciliares ? 0
#    2155 - quais são as vantagem para o regime de exercícios domiciliares ? 0
#    2156 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é posto pelo orgão competente ? 0
#    2157 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é tida pelo orgão competente ? 0
#    2158 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é novamente pelo orgão competente ? 0
#    2159 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é regional pelo orgão competente ? 0
#    2160 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é escola pelo orgão competente ? 0
#    2161 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é preta pelo orgão competente ? 0
#    2162 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é recebe pelo orgão competente ? 0
#    2163 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é externa pelo orgão competente ? 0
#    2164 - o que acontece com a grade curricular do curso para alunos veteranos quando a mesma é realizada pelo orgão competente ? 0
#    2165 - quantas vezes possa solicitar aproveitamento de estudos ? 0
#    2166 - quantas vezes aceito solicitar aproveitamento de estudos ? 0
#    2167 - quantas vezes vi solicitar aproveitamento de estudos ? 0
#    2168 - o que sente conter o plano de estudos ? 0
#    2169 - o que promete conter o plano de estudos ? 0
#    2170 - o que deverá definir o plano de estudos ? 0
#    2171 - por quem será apresentado o plano de estudos ? 0
#    2172 - quem é responsável pela totalidade de atitudes inadequadas de alunos e aplicação de medidas corretivas ? 0
#    2173 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de < corretivas ? 0
#    2174 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de podem corretivas ? 0
#    2175 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de guarda corretivas ? 0
#    2176 - quem é responsável pela reputação de atitudes inadequadas de alunos e aplicação de medidas corretivas ? 0
#    2177 - quem é responsável pela apuração de tes inadequadas de alunos e aplicação de medidas corretivas ? 0
#    2178 - quem é responsável pela presença de atitudes inadequadas de alunos e aplicação de medidas corretivas ? 0
#    2179 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de fazer corretivas ? 0
#    2180 - quem é responsável pela apuração de atitudes inadequadas de alunos e aplicação de buscar corretivas ? 0
#    2181 - quem é responsável pela apuração de atitudes inadequadas de alunos e negociação de medidas corretivas ? 0
#    2182 - quem é responsável pela apuração de atitudes inadequadas de alunos e sintomas de medidas corretivas ? 0
#    2183 - quem é responsável pela procura de atitudes inadequadas de alunos e aplicação de medidas corretivas ? 0
#    2184 - a aprovação nas disciplinas intelectuais do que ? 0
#    2185 - a aprovação nas disciplinas disciplinas do que ? 0
#    2186 - quem é responsável pela verificação do frequência das atividades complementares ? 0
#    2187 - quem é responsável pela verificação do detalhe das atividades complementares ? 0
#    2188 - quem é responsável pela verificação do gênero das atividades complementares ? 0
#    2189 - quem é responsável pela verificação do intercâmbio das atividades complementares ? 0
#    2190 - como o acadêmico analisar revisão de avaliação de disciplina ? 0
#    2191 - como o acadêmico contém revisão de avaliação de disciplina ? 0
#    2192 - como o acadêmico fazem revisão de avaliação de disciplina ? 0
#    2193 - como o acadêmico cobre revisão de avaliação de disciplina ? 0
#    2194 - como o acadêmico opera revisão de avaliação de disciplina ? 0
#    2195 - como é rada a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    2196 - como é sempre a estruta curricular para acadêmicos ingressantes com aproveitamento de crédito ou disciplinas ? 0
#    2197 - em quantas discplinas o acadêmico poderá ter durante o período letivo especial ? 0
#    2198 - em quantas discplinas o acadêmico poderá tal durante o período letivo especial ? 0
#    2199 - em quantas discplinas o acadêmico poderá manter durante o período letivo especial ? 0
#    2200 - como sempre para não perder o vínculo acadêmico ? 0
#    2201 - como medidas para não perder o vínculo acadêmico ? 0
#    2202 - como faço para não permitir o vínculo acadêmico ? 0
#    2203 - como luta para não perder o vínculo acadêmico ? 0
#    2204 - de quando é a região no 401 ? 0
#    2205 - de quando é a corte no 401 ? 0
#    2206 - de quando é a borracha no 401 ? 0
#    2207 - de quando é a Barra no 401 ? 0
#    2208 - de quando é a pesca no 401 ? 0
#    2209 - de quando é a descrição no 401 ? 0
#    2210 - de quando é a velocidade no 401 ? 0
#    2211 - de quando é a suspensão no 401 ? 0
#    2212 - de quando é a empregada no 401 ? 0
#    2213 - de quando é a regra no 401 ? 0
#    2214 - de quando é a filosofia no 401 ? 0
#    2215 - de quando é a demanda no 401 ? 0
#    2216 - de quando é a entrevista no 401 ? 0
#    2217 - de quando é a V no 401 ? 0
#    2218 - de quando é a era no 401 ? 0
#    2219 - de quando é a noite no 401 ? 0
#    2220 - de quando é a determinação no 401 ? 0
#    2221 - de quando é a bicicleta no 401 ? 0
#    2222 - de quando é a decadência no 401 ? 0
#    2223 - o que a resolução no 401 sugere ? 0
#    2224 - Municipal lei sobre a transferência compulsória ? 0
#    2225 - a lei sobre a transferência compulsória ? 0

# %% [markdown]
# # 5 Compara os resultados
#
# Listas das classificações
# * listaDocumentoOriginalClassificadoCorretamente
# * listaDocumentoOriginalClassificadoIncorretamente
# * listaDocumentoPerturbadoClassificadoCorretamente
# * listaDocumentoPerturbadoClassificadoIncorretamente
#
#
# Lista das medições
# * listaDocumentoOriginalMedidoCorretamente 12
# * listaDocumentoOriginalMedidoIncorretamente 8
# * listaDocumentoPerturbadoMedidoCorretamente 12
# * listaDocumentoPerturbadoMedidoIncorretamente 8

# %%
total_classificacao = (len(listaDocumentoOriginalClassificadoCorretamente) + 
                       len(listaDocumentoOriginalClassificadoIncorretamente) + 
                       len(listaDocumentoPerturbadoClassificadoCorretamente) + 
                       len(listaDocumentoPerturbadoClassificadoIncorretamente))
print("total_classificacao:", total_classificacao)

print("DO classificados corretamente:", 
      len(listaDocumentoOriginalClassificadoCorretamente), 
      " / {0:.2%} do total".format(len(listaDocumentoOriginalClassificadoCorretamente)/total_classificacao))
print("DO classificados incorretamente:", 
      len(listaDocumentoOriginalClassificadoIncorretamente), 
      " / {0:.2%} do total".format(len(listaDocumentoOriginalClassificadoIncorretamente)/total_classificacao))
print("pertDO classificados corretamente:", 
      len(listaDocumentoPerturbadoClassificadoCorretamente), 
      " / {0:.2%} do total".format(len(listaDocumentoPerturbadoClassificadoCorretamente)/total_classificacao))
print("pertDO classificados incorretamente:", 
      len(listaDocumentoPerturbadoClassificadoIncorretamente), 
      " / {0:.2%} do total".format(len(listaDocumentoPerturbadoClassificadoIncorretamente)/total_classificacao))

total_medicao = (len(listaDocumentoOriginalMedidoCorretamente) +
                 len(listaDocumentoOriginalMedidoIncorretamente) + 
                 len(listaDocumentoPerturbadoMedidoCorretamente) + 
                 len(listaDocumentoPerturbadoMedidoIncorretamente))

print()
print("total_medicao:",total_medicao)

print("DO medidos corretamente:", 
      len(listaDocumentoOriginalMedidoCorretamente), 
      " / {0:.2%} do total".format(len(listaDocumentoOriginalMedidoCorretamente)/total_medicao))
print("DO medidos incorretamente:", 
      len(listaDocumentoOriginalMedidoIncorretamente), 
      " / {0:.2%} do total".format(len(listaDocumentoOriginalMedidoIncorretamente)/total_medicao))
print("pertDO medidos corretamente:", 
      len(listaDocumentoPerturbadoMedidoCorretamente), 
      " / {0:.2%} do total".format(len(listaDocumentoPerturbadoMedidoCorretamente)/total_medicao))
print("pertDO medidos incorretamente:", 
      len(listaDocumentoPerturbadoMedidoIncorretamente), 
      " / {0:.2%} do total".format(len(listaDocumentoPerturbadoMedidoIncorretamente)/total_medicao))
# Out:
# total_classificacao: 36000
# DO classificados corretamente: 17825  / 49.51% do total
# DO classificados incorretamente: 175  / 0.49% do total
# pertDO classificados corretamente: 17743  / 49.29% do total
# pertDO classificados incorretamente: 257  / 0.71% do total
#
# total_medicao: 36000
# DO medidos corretamente: 15774  / 43.82% do total
# DO medidos incorretamente: 2226  / 6.18% do total
# pertDO medidos corretamente: 15774  / 43.82% do total
# pertDO medidos incorretamente: 2226  / 6.18% do total

# %% [markdown]
# ## Documentos originais classificados e medidos corretamente

# %%
listaIntersecao = []
for i, documento1 in listaDocumentoOriginalClassificadoCorretamente.iterrows():
  procura = documento1["id"]
  documento2 = listaDocumentoOriginalMedidoCorretamente.loc[listaDocumentoOriginalMedidoCorretamente["id"] == procura]
  if len(documento2) != 0:        
      listaIntersecao.append(documento1["id"])

# %%
if len(listaIntersecao) != 0:    
  percentual = len(listaIntersecao)/total_classificacao
  print ("Lista de documentos originais que foram classificados e medidos corretamente: ", len(listaIntersecao), " / {0:.2%} do total".format( percentual))
  for i, x in enumerate(listaIntersecao):
    if i < 100:
      print(x)
else:
  print("Não existe documentos originais que foram classificados e medidos corretamente ")
# Out:
# Lista de documentos originais que foram classificados e medidos corretamente:  17729  / 49.25% do total
# bbca4bfb0a98484e87709baa4b0105be
# 4b0569a40aa24c4d9e842d78a922b832
# 4b0569a40aa24c4d9e842d78a922b832
# d35a68e1e8344f38aee681eb5ba72c77
# d35a68e1e8344f38aee681eb5ba72c77
# 2f8b4896dd3d4692a4e286fb40826df5
# 2f8b4896dd3d4692a4e286fb40826df5
# b4bf6ca3ed294ec6ad5410f1071031a9
# afb217fec90c418f9df75a46eb329f78
# afb217fec90c418f9df75a46eb329f78
# 98355d419f664393ad000940492a80a3
# a522ca722b5046c498e41d97b36fe029
# a522ca722b5046c498e41d97b36fe029
# 13c20d4e1a8a4ae9a556e6986524cefa
# 13c20d4e1a8a4ae9a556e6986524cefa
# 939e08851c6c469da76d0c58d47e225c
# 939e08851c6c469da76d0c58d47e225c
# e751f65638fc4f70acbea26a49ad5992
# e751f65638fc4f70acbea26a49ad5992
# e751f65638fc4f70acbea26a49ad5992
# e751f65638fc4f70acbea26a49ad5992
# e751f65638fc4f70acbea26a49ad5992
# b40be90835fa413fa7c65547c4bfdf3d
# 5d670b9c1fa442129c2c4cd6348c4392
# 5d670b9c1fa442129c2c4cd6348c4392
# 5d670b9c1fa442129c2c4cd6348c4392
# 5d670b9c1fa442129c2c4cd6348c4392
# cb9a0ac3fafd4772b5735300a0e1223a
# cb9a0ac3fafd4772b5735300a0e1223a
# cb9a0ac3fafd4772b5735300a0e1223a
# cb9a0ac3fafd4772b5735300a0e1223a
# 01abaa15500d49c5bc0b370986aea86f
# 992c12a7782a470ea48a1438c5ae7a0e
# 992c12a7782a470ea48a1438c5ae7a0e
# 9ae58ffb344042d68c2f8cd740dd5c55
# 09646c629655424090feb82da04be1e7
# 09646c629655424090feb82da04be1e7
# 09646c629655424090feb82da04be1e7
# 09646c629655424090feb82da04be1e7
# cb63d786efff403ba85f3fad95a6042e
# d67dd5989ed6424195a43beeaf28488a
# 2b39c68e2909418692137633f67bab3b
# 2b39c68e2909418692137633f67bab3b
# 45126b93eec143108826eb0349f25cad
# 45126b93eec143108826eb0349f25cad
# aba04e9bfad3472fa09c805a1dfab192
# 4e0d8cf561384af29bee1345bd55b543
# 85b1de669bde4998bf7c5943bd3e3558
# 71ac22147ac8441fbc10b432370c4c6c
# c330f27f8f4d49e2b6cc95fb205cab76
# c330f27f8f4d49e2b6cc95fb205cab76
# 1133c29b5e0640b29263e5b1f194c2e9
# d737529e861540a0aa33d277d981a28e
# c022e0c917d148d784d2594b4652e20b
# c022e0c917d148d784d2594b4652e20b
# c022e0c917d148d784d2594b4652e20b
# b4079d7b11734c08af93080784ec032f
# 1d36e686f4144616a960651b3aa4c1a7
# 1d36e686f4144616a960651b3aa4c1a7
# 4f5e0fca2de74f499a98731c7af28c95
# 6165fa80922a40a6b14d8e7beba5fa8f
# 69c6acf4d43e4af999464b87b3cf19e2
# 69c6acf4d43e4af999464b87b3cf19e2
# 69c6acf4d43e4af999464b87b3cf19e2
# 69c6acf4d43e4af999464b87b3cf19e2
# 69c6acf4d43e4af999464b87b3cf19e2
# a5cafcd0bbbd4c74bb60de2f810db23b
# a5cafcd0bbbd4c74bb60de2f810db23b
# 859b15a179714620906bf10f0b284e95
# a1cfe1ca367e4408a2dcca04bb27d477
# a1cfe1ca367e4408a2dcca04bb27d477
# a1cfe1ca367e4408a2dcca04bb27d477
# a1cfe1ca367e4408a2dcca04bb27d477
# a1cfe1ca367e4408a2dcca04bb27d477
# d725cd9a59e8416198255731a69e3393
# d725cd9a59e8416198255731a69e3393
# 085d702214924761adb42e7334749124
# 085d702214924761adb42e7334749124
# 085d702214924761adb42e7334749124
# e598bbb0f3ad48adb40b7df47b9894d8
# 556e4b43389e4ea1a4090c3e6a86db02
# 79930e6eb5864d2fa831be504fb7bf98
# dbc27c80bdf8447ea1ef546dc162a168
# b4079d7b11734c08af93080784ec032f
# 824a7cde3e8348ecbf050e5d582d464d
# 9d8269df2477477d8df6635bf7612027
# 9d8269df2477477d8df6635bf7612027
# 9d8269df2477477d8df6635bf7612027
# 9d8269df2477477d8df6635bf7612027
# b40be90835fa413fa7c65547c4bfdf3d
# 2db891709f7d44ddaae6a1016cc4c51b
# 2db891709f7d44ddaae6a1016cc4c51b
# cb15aef2f647472c9b4f87e21b169e63
# cb15aef2f647472c9b4f87e21b169e63
# cb15aef2f647472c9b4f87e21b169e63
# cb15aef2f647472c9b4f87e21b169e63
# 4ca3471fa4314310a457304a2505fd1d
# 4ca3471fa4314310a457304a2505fd1d
# 9f246d4cc95f4ae7a1831f54443bb1eb
# 63a1241f10134c59a6f7d6f70f6e043a

# %% [markdown]
# ## Documentos originais classificados e medidos incorretamente

# %%
listaIntersecao = []
for i, documento1 in listaDocumentoOriginalClassificadoIncorretamente.iterrows():
  procura = documento1["id"]
  documento2 = listaDocumentoOriginalMedidoIncorretamente.loc[listaDocumentoOriginalMedidoIncorretamente["id"] == procura]
  if len(documento2) != 0:        
      listaIntersecao.append(documento1["id"])

# %%
if len(listaIntersecao) != 0:    
  percentual = len(listaIntersecao)/total_classificacao
  print ("Lista de documentos originais que foram classificados e medidos incorretamente: ", len(listaIntersecao), " / {0:.2%} do total".format( percentual))
  for i, x in enumerate(listaIntersecao):
    if i < 100:
      print(x)
else:
  print("Não existe documentos originais que foram classificados e medidos incorretamente ")
# Out:
# Lista de documentos originais que foram classificados e medidos incorretamente:  95  / 0.26% do total
# 10b4f7a2173242bea85ffe5781439384
# 10b4f7a2173242bea85ffe5781439384
# 10b4f7a2173242bea85ffe5781439384
# 3f8ee2355e1f4745a10f55a9cc41396f
# 71dbbf324d054924a3c503480486bb74
# 71dbbf324d054924a3c503480486bb74
# 483b327d3f80408fa56ffa3e3778aabf
# 68e685786c0745cf9d4529e10c79f316
# 68e685786c0745cf9d4529e10c79f316
# 0d9152126eb14923a0110320e0868290
# 0d9152126eb14923a0110320e0868290
# c62511babcc444ae9f76d9c672ab30a7
# c62511babcc444ae9f76d9c672ab30a7
# b11d5b1f4a1c4f69b982320656943681
# b11d5b1f4a1c4f69b982320656943681
# 39c4c128a2cf4a3ea948786c5388902f
# 39c4c128a2cf4a3ea948786c5388902f
# 39c4c128a2cf4a3ea948786c5388902f
# 39c4c128a2cf4a3ea948786c5388902f
# 1d746320923348268c07ffb59dff6a5f
# 1d746320923348268c07ffb59dff6a5f
# 1d746320923348268c07ffb59dff6a5f
# b74772acc3f149498a35481c365dbf97
# b74772acc3f149498a35481c365dbf97
# 0f2f727416a14b6d8abab36816e04f9f
# e8413a5836124c9f85fbeec8ac228621
# e8413a5836124c9f85fbeec8ac228621
# e8413a5836124c9f85fbeec8ac228621
# 6066b65076d145658e78b885fcf5496e
# 6066b65076d145658e78b885fcf5496e
# 928f6b56e7be42febf43cbbafae7c28a
# 928f6b56e7be42febf43cbbafae7c28a
# 6066b65076d145658e78b885fcf5496e
# 6066b65076d145658e78b885fcf5496e
# d0b4d7d5901643719e812aab15d70068
# d0b4d7d5901643719e812aab15d70068
# dbb1cbe85bbd438b82fdd9bcb4b6a01f
# dbb1cbe85bbd438b82fdd9bcb4b6a01f
# dbb1cbe85bbd438b82fdd9bcb4b6a01f
# dbb1cbe85bbd438b82fdd9bcb4b6a01f
# fa1bcf9d63e348fda7210b82a3c3688b
# fd40ac195d574ea2954a216db362f354
# d0b4d7d5901643719e812aab15d70068
# d0b4d7d5901643719e812aab15d70068
# 129a155d098d4a2f9a66d06ea95138fa
# 129a155d098d4a2f9a66d06ea95138fa
# 129a155d098d4a2f9a66d06ea95138fa
# 37ad9583e16142979c5b7a64cd22f0b9
# 37ad9583e16142979c5b7a64cd22f0b9
# 37ad9583e16142979c5b7a64cd22f0b9
# e5d7007ea34f4eaf8cd556e08994e07a
# 5fd244c2f54f4ad39a13b18d05b330d1
# 5fd244c2f54f4ad39a13b18d05b330d1
# 5fd244c2f54f4ad39a13b18d05b330d1
# 30d8a3928853486c89b457c0780793a7
# 30d8a3928853486c89b457c0780793a7
# 3a52a2716b384ea180d2887fb0885352
# 3a52a2716b384ea180d2887fb0885352
# 26d9ec76d75344b393dc167c202be724
# 26d9ec76d75344b393dc167c202be724
# cd4563f0032e4a88bb9ebbf7fe2bd181
# cd4563f0032e4a88bb9ebbf7fe2bd181
# cd4563f0032e4a88bb9ebbf7fe2bd181
# 8c315266ef62458c9b670c25963cea9b
# 8c315266ef62458c9b670c25963cea9b
# 8c315266ef62458c9b670c25963cea9b
# 8c315266ef62458c9b670c25963cea9b
# 1be21a9cc55a41a5b3d98a094e4b3fbe
# f1146e1e59e648a8b095e7d6d7e39f7f
# f1146e1e59e648a8b095e7d6d7e39f7f
# f1146e1e59e648a8b095e7d6d7e39f7f
# 1be21a9cc55a41a5b3d98a094e4b3fbe
# 1be21a9cc55a41a5b3d98a094e4b3fbe
# 1be21a9cc55a41a5b3d98a094e4b3fbe
# 6f4eb95dc93f48198347a8d6ed994587
# 6f4eb95dc93f48198347a8d6ed994587
# 59ca719898f047158aead30e19e65d36
# 59ca719898f047158aead30e19e65d36
# fc24539d600841aab8164f7894d475a2
# fc24539d600841aab8164f7894d475a2
# 2f3279d8e55b43138ffbba56fea2d224
# 2f3279d8e55b43138ffbba56fea2d224
# 5fd244c2f54f4ad39a13b18d05b330d1
# 5fd244c2f54f4ad39a13b18d05b330d1
# 4a9655eba0094bab94312408ba385223
# 4a9655eba0094bab94312408ba385223
# 4a9655eba0094bab94312408ba385223
# 0c24ac82543747b0a6503a39a9bdd774
# 11bb37f4a9d340fbbadffe26feb6aad1
# 11bb37f4a9d340fbbadffe26feb6aad1
# 10b4f7a2173242bea85ffe5781439384
# af5d21b04e894151b0bab76d200abfa6
# af5d21b04e894151b0bab76d200abfa6
# fd8de2206a504159ab3f3164798fefc2
# fd8de2206a504159ab3f3164798fefc2

# %% [markdown]
# ## Documentos perturbados classificados e medidos corretamente

# %%
listaIntersecao = []
for i, documento1 in listaDocumentoPerturbadoClassificadoCorretamente.iterrows():
  procura = documento1["id"]
  documento2 = listaDocumentoPerturbadoMedidoCorretamente.loc[listaDocumentoPerturbadoMedidoCorretamente["id"] == procura]
  if len(documento2) != 0:        
      listaIntersecao.append(documento1["id"])

# %%
if len(listaIntersecao) != 0:    
  percentual = len(listaIntersecao)/total_classificacao
  print ("Lista de documentos perturbados que foram classificados e medidos corretamente: ", len(listaIntersecao), " / {0:.2%} do total".format( percentual))
  for i, x in enumerate(listaIntersecao):
    if i < 100:
      print(x)
else:
  print("Não existe documentos perturbados que foram classificados e medidos corretamente ")
# Out:
# Lista de documentos perturbados que foram classificados e medidos corretamente:  15610  / 43.36% do total
# 32ff57978a214146b797eeea9214df41_pert_15
# 4b0569a40aa24c4d9e842d78a922b832_pert_10
# 4b0569a40aa24c4d9e842d78a922b832_pert_14
# d35a68e1e8344f38aee681eb5ba72c77_pert_9
# d35a68e1e8344f38aee681eb5ba72c77_pert_15
# 920b6cce13e14bf1b93469532a7051cf_pert_18
# 2f8b4896dd3d4692a4e286fb40826df5_pert_9
# b4bf6ca3ed294ec6ad5410f1071031a9_pert_16
# afb217fec90c418f9df75a46eb329f78_pert_13
# afb217fec90c418f9df75a46eb329f78_pert_18
# a522ca722b5046c498e41d97b36fe029_pert_7
# a522ca722b5046c498e41d97b36fe029_pert_19
# 13c20d4e1a8a4ae9a556e6986524cefa_pert_7
# e98e9e52a66c420ba22910c17265c229_pert_0
# 42f1e4ed6b614b149ab18de686215571_pert_0
# 42f1e4ed6b614b149ab18de686215571_pert_5
# 939e08851c6c469da76d0c58d47e225c_pert_6
# 939e08851c6c469da76d0c58d47e225c_pert_11
# e751f65638fc4f70acbea26a49ad5992_pert_7
# e751f65638fc4f70acbea26a49ad5992_pert_13
# e751f65638fc4f70acbea26a49ad5992_pert_15
# e751f65638fc4f70acbea26a49ad5992_pert_18
# e751f65638fc4f70acbea26a49ad5992_pert_19
# b40be90835fa413fa7c65547c4bfdf3d_pert_4
# 5d670b9c1fa442129c2c4cd6348c4392_pert_1
# cb9a0ac3fafd4772b5735300a0e1223a_pert_9
# 01abaa15500d49c5bc0b370986aea86f_pert_0
# 01abaa15500d49c5bc0b370986aea86f_pert_11
# 992c12a7782a470ea48a1438c5ae7a0e_pert_12
# 3b7293145a384882b3fd99feb0310c8f_pert_8
# 09646c629655424090feb82da04be1e7_pert_5
# 09646c629655424090feb82da04be1e7_pert_7
# 09646c629655424090feb82da04be1e7_pert_18
# 9f3db258b4f4402cb4f4dc104deafa7a_pert_15
# 2b39c68e2909418692137633f67bab3b_pert_18
# 2b39c68e2909418692137633f67bab3b_pert_19
# 45126b93eec143108826eb0349f25cad_pert_3
# 45126b93eec143108826eb0349f25cad_pert_5
# a4a83e154fa049c6b3ae74d9feeb7b55_pert_14
# a4a83e154fa049c6b3ae74d9feeb7b55_pert_16
# aba04e9bfad3472fa09c805a1dfab192_pert_8
# 71ac22147ac8441fbc10b432370c4c6c_pert_1
# c330f27f8f4d49e2b6cc95fb205cab76_pert_1
# d737529e861540a0aa33d277d981a28e_pert_12
# c022e0c917d148d784d2594b4652e20b_pert_7
# 6165fa80922a40a6b14d8e7beba5fa8f_pert_13
# 69c6acf4d43e4af999464b87b3cf19e2_pert_2
# 69c6acf4d43e4af999464b87b3cf19e2_pert_5
# 69c6acf4d43e4af999464b87b3cf19e2_pert_7
# 69c6acf4d43e4af999464b87b3cf19e2_pert_12
# a5cafcd0bbbd4c74bb60de2f810db23b_pert_1
# a5cafcd0bbbd4c74bb60de2f810db23b_pert_5
# a5cafcd0bbbd4c74bb60de2f810db23b_pert_11
# bffe78be4a284a2f8b5186d69e8ec290_pert_11
# 859b15a179714620906bf10f0b284e95_pert_12
# a1cfe1ca367e4408a2dcca04bb27d477_pert_0
# a1cfe1ca367e4408a2dcca04bb27d477_pert_1
# a1cfe1ca367e4408a2dcca04bb27d477_pert_5
# 02404840820d42b0a9002b2f0847aa34_pert_7
# 02404840820d42b0a9002b2f0847aa34_pert_17
# ae519b3c655c4f18802c75166d20ef82_pert_4
# d725cd9a59e8416198255731a69e3393_pert_7
# d725cd9a59e8416198255731a69e3393_pert_14
# 501d80597c4d4b65b8a5466c022c455b_pert_1
# 501d80597c4d4b65b8a5466c022c455b_pert_2
# 501d80597c4d4b65b8a5466c022c455b_pert_4
# 085d702214924761adb42e7334749124_pert_3
# 085d702214924761adb42e7334749124_pert_6
# 085d702214924761adb42e7334749124_pert_10
# 79930e6eb5864d2fa831be504fb7bf98_pert_18
# dbc27c80bdf8447ea1ef546dc162a168_pert_18
# 69c6acf4d43e4af999464b87b3cf19e2_pert_18
# 824a7cde3e8348ecbf050e5d582d464d_pert_16
# b40be90835fa413fa7c65547c4bfdf3d_pert_1
# 7d461349c9a54560af24d18a40e7ef30_pert_8
# cb15aef2f647472c9b4f87e21b169e63_pert_14
# cb15aef2f647472c9b4f87e21b169e63_pert_17
# 4ca3471fa4314310a457304a2505fd1d_pert_7
# 4ca3471fa4314310a457304a2505fd1d_pert_8
# 63a1241f10134c59a6f7d6f70f6e043a_pert_11
# 93bf3712ea5b4a10871da99bcf6236c3_pert_3
# 93bf3712ea5b4a10871da99bcf6236c3_pert_13
# 2da840d7bc4548529a000a251dcb26af_pert_10
# 2da840d7bc4548529a000a251dcb26af_pert_11
# 2da840d7bc4548529a000a251dcb26af_pert_17
# a47d1d22b50f4d818216dee5bb56c008_pert_4
# ef30d6277aac4363b59e398e6b8815eb_pert_12
# 1100cf4cf2b54d88bea2eac0e93df77e_pert_12
# 1100cf4cf2b54d88bea2eac0e93df77e_pert_14
# 17de82e57fe7429388a3cd03d9230fbf_pert_11
# 3b903d50fe304c0bbeb031034d4444b8_pert_7
# 6bf4fc5e7c284d6a92bad7a9398947ac_pert_19
# b6cd60a93a0e47b387289b8c2accaa27_pert_2
# b6cd60a93a0e47b387289b8c2accaa27_pert_4
# b6cd60a93a0e47b387289b8c2accaa27_pert_9
# b6cd60a93a0e47b387289b8c2accaa27_pert_10
# 0b70044075784d24ae6743c4ebb9c0e9_pert_2
# 0b70044075784d24ae6743c4ebb9c0e9_pert_11
# 592e2fd9a4c44440a3af872c8fa1e1ac_pert_4
# 4ef1d63262d847ff83627070d824c2af_pert_8

# %% [markdown]
# ## Documentos perturbados classificados e medidos incorretamente

# %%
listaIntersecao = []
for i, documento1 in listaDocumentoPerturbadoClassificadoIncorretamente.iterrows():
  procura = documento1["id"]
  documento2 = listaDocumentoPerturbadoMedidoIncorretamente.loc[listaDocumentoPerturbadoMedidoIncorretamente["id"] == procura]
  if len(documento2) != 0:        
      listaIntersecao.append(documento1["id"])

# %%
if len(listaIntersecao) != 0:    
  percentual = len(listaIntersecao)/total_classificacao
  print ("Lista de documentos perturbados que foram classificados e medidos incorretamente: ", len(listaIntersecao), " / {0:.2%} do total".format( percentual))
  for i, x in enumerate(listaIntersecao):
    if i < 20:
      print(x)
else:
  print("Não existe documentos perturbados que foram classificados e medidos incorretamente ")
# Out:
# Lista de documentos perturbados que foram classificados e medidos incorretamente:  93  / 0.26% do total
# cb9a0ac3fafd4772b5735300a0e1223a_pert_4
# d67dd5989ed6424195a43beeaf28488a_pert_3
# 1a36740cd52d416a9472e7a56a2a80f2_pert_4
# 4a9655eba0094bab94312408ba385223_pert_18
# 11bb37f4a9d340fbbadffe26feb6aad1_pert_0
# 97cd8d9df5c746228be10421176b486a_pert_6
# 76213c50ab0b47c7b465562ae17ba98c_pert_3
# e8504b304dfc47a096167d0f13f52774_pert_14
# e88ce7b72b864607a3ba7f55a782dcbd_pert_15
# 0c8d7a0093b6433d838a427425788606_pert_19
# db2a4c7266bf44d6ab07d90227c1312b_pert_14
# e8504b304dfc47a096167d0f13f52774_pert_17
# bc649c8e94fd489b96bc6274af04ca6c_pert_2
# 7e00d87ee5c5462686e4c5ce506a673f_pert_14
# 879f1d34d55b42fb9a0250288ca2537e_pert_15
# 4c40f79958644cf598797fa5da085ec6_pert_3
# 806c7408b59a424e8e086c3cb83ae9eb_pert_18
# 4a9655eba0094bab94312408ba385223_pert_17
# 06759927776b4321889dbeb37b29582c_pert_10
# e91c36b57c7b4cfbb156d31e5f00a845_pert_10

# %% [markdown]
# # 6 Finalização

# %% [markdown]
# ## 6.3 Tempo final de processamento
#
# Tempo processamento:  1:34:52 (h:mm:ss)

# %%
 # Pega o tempo atual menos o tempo do início do processamento.
finalProcessamento = time.time()
tempoTotalProcessamento = formataTempo(finalProcessamento - inicioProcessamento)

print('')
print('  Tempo processamento:  {:} (h:mm:ss)'.format(tempoTotalProcessamento))
# Out:
#   Tempo processamento:  0:10:13 (h:mm:ss)
